# %% [markdown]
# # ResNet-9 on CIFAR-10 Dataset

# %% [markdown]
# Importing PyTorch and a few Python Libraries

# %%
pip install torch-summary
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch-summary in /home/rrm9598/.local/lib/python3.11/site-packages (1.4.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import sys
import time
import math

import torch
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import random_split, DataLoader
from torchvision.utils import make_grid

import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
import torch.nn.init as init

from torchsummary import summary

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Preparing the dataset
#
# We will be downloading the train and test CIFAR-10 dataset from torchvision. We will normalize and transform the dataset. For the training dataset, we will also be adding Random Crops and Random Horizontal Flips to generalize the model better.

# %%
data_statistics = (
    (0.49139968, 0.48215827, 0.44653124),
     (0.24703233, 0.24348505, 0.26158768)
) # Mean, Standard Deviation of CIFAR-10 dataset channels

train_transforms = transforms.Compose([
    transforms.RandomCrop(32, padding=4, padding_mode='reflect'), # Adding Random Crops
    transforms.RandomHorizontalFlip(), # Adding Random Horizontal Flips
    transforms.ToTensor(), # Channel x Image Height x Image Width
    transforms.Normalize(*data_statistics, inplace=True) # Output in the range of [-1, 1]
])

test_transforms = transforms.Compose([
    transforms.ToTensor(), # Channel x Image Height x Image Width
    transforms.Normalize(*data_statistics, inplace=True) # Output in the range of [-1, 1]
])

# %%
train_dataset = torchvision.datasets.CIFAR10(root='./data/', download=True, train=True, transform=train_transforms)
test_dataset = torchvision.datasets.CIFAR10(root='./data/', download=True, train=False, transform=test_transforms)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:01<00:00, 97899518.82it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data/
# Files already downloaded and verified

# %% [markdown]
# <!-- We will also be splitting the dataset further into training and validation dataset with a validation ratio of `0.2` -->
#
# We will now create data loaders to retreive images in batches. We are selecting the batch size as `128` images for our train loader. And we are selecting the batch size as `100` images for our test loader.
#
# *From PyTorch Documentation: For data loading, passing pin_memory=True to a DataLoader will automatically put the fetched data Tensors in pinned memory, and thus enables faster data transfer to CUDA-enabled GPUs.*

# %%
# validation_ratio = 0.2
# train_dataset, validation_dataset = random_split(
#     dataset,
#     [int((1 - validation_ratio) * len(dataset)), int(validation_ratio * len(dataset))]
# )

train_batch_size = 128
test_batch_size = 100

train_dl = DataLoader(train_dataset, train_batch_size, shuffle=True, num_workers=2, pin_memory=True)
# validation_dl = DataLoader(validation_dataset, batch_size, shuffle=True, num_workers=3, pin_memory=True)
test_dl = DataLoader(test_dataset, test_batch_size, shuffle=False, num_workers=2, pin_memory=True)

classes = ('plane', 'car', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck')

# %% [markdown]
# We create the following function to display a batch of images from the dataset. And we also need to denormalize the pixels values to bring them back into the range (0,1).

# %%
def denormalize(images, means, stds):
  means = torch.tensor(means).reshape(1, 3, 1, 1)
  stds = torch.tensor(stds).reshape(1, 3, 1, 1)
  return images * stds + means

def show_batch(dl):
  for images, labels in dl:
    fig, ax = plt.subplots(figsize=(12, 12))
    ax.set_xticks([])
    ax.set_yticks([])
    denorm_images = denormalize(images, *data_statistics)
    ax.imshow(make_grid(denorm_images[:64], 8).permute(1, 2, 0))
    break

# %%
show_batch(train_dl)

# %% [markdown]
# To seamlessly use a GPU, if one is available, we define a couple of helper functions (`get_default_device` & `to_device`) and a helper class `DeviceDataLoader` to move our model & data to the GPU as required.

# %%
def get_default_device():
  # Pick GPU, if available, else CPU
  if torch.cuda.is_available():
    return torch.device('cuda')
  else:
    return torch.device('cpu')

def to_device(data, device):
  # Move tensors to chosen device
  if isinstance(data, (list, tuple)):
    # If the instance is a list/tuple, transfer each element to chosen device
    return [to_device(x, device) for x in data]
  return data.to(device, non_blocking=True)
  # non_blocking=True doesn't block the execution of the host device until transfers complete

class DeviceDataLoader():
  # Wrap a dataloader to move data to a device
  def __init__(self, dl, device):
    self.dl = dl
    self.device = device

  def __iter__(self):
    # Yield a batch of data after moving it to device
    for b in self.dl:
      yield to_device(b, self.device)

  def __len__(self):
    # Number of batches
    return len(self.dl)

# %%
# Get the default device
device = get_default_device()
device
# Out:
# device(type='cuda')

# %%
train_dl = DeviceDataLoader(train_dl, device)
# validation_dl = DeviceDataLoader(validation_dl, device)
test_dl = DeviceDataLoader(test_dl, device)

# %% [markdown]
# ## Network Architecture

# %% [markdown]
# Testing the models mentioned in the `pytorch-cifar` [GitHub Repository](https://github.com/kuangliu/pytorch-cifar).

# %% [markdown]
# ### PreActResNet18

# %%
class PreActBlock(nn.Module):
  '''Pre-activation version of the BasicBlock.'''
  expansion = 1

  def __init__(self, in_planes, planes, stride=1):
    super(PreActBlock, self).__init__()
    self.bn1 = nn.BatchNorm2d(in_planes)
    self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
    self.bn2 = nn.BatchNorm2d(planes)
    self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)

    if stride != 1 or in_planes != self.expansion*planes:
      self.shortcut = nn.Sequential(
          nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False)
      )

  def forward(self, x):
    out = F.relu(self.bn1(x))
    shortcut = self.shortcut(out) if hasattr(self, 'shortcut') else x
    out = self.conv1(out)
    out = self.conv2(F.relu(self.bn2(out)))
    out += shortcut
    return out

class PreActResNet(nn.Module):
  def __init__(self, block, num_blocks, num_classes=10):
    super(PreActResNet, self).__init__()
    self.in_planes = 64

    self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
    self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
    self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
    self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
    self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
    self.linear = nn.Linear(512*block.expansion, num_classes)

  def _make_layer(self, block, planes, num_blocks, stride):
    strides = [stride] + [1]*(num_blocks-1)
    layers = []
    for stride in strides:
        layers.append(block(self.in_planes, planes, stride))
        self.in_planes = planes * block.expansion
    return nn.Sequential(*layers)

  def forward(self, x):
    out = self.conv1(x)
    out = self.layer1(out)
    out = self.layer2(out)
    out = self.layer3(out)
    out = self.layer4(out)
    out = F.avg_pool2d(out, 4)
    out = out.view(out.size(0), -1)
    out = self.linear(out)
    return out

def PreActResNet18():
  return PreActResNet(PreActBlock, [2,2,2,2])

# %%
# model = PreActResNet18()

# %% [markdown]
# The number of parameters is `11,171,146`, which exceeds the 5 million limit.

# %% [markdown]
# ### ResNet18

# %%
class BasicBlock(nn.Module):
  expansion = 1

  def __init__(self, in_planes, planes, stride=1):
    super(BasicBlock, self).__init__()
    self.conv1 = nn.Conv2d(
        in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
    self.bn1 = nn.BatchNorm2d(planes)
    self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                            stride=1, padding=1, bias=False)
    self.bn2 = nn.BatchNorm2d(planes)

    self.shortcut = nn.Sequential()
    if stride != 1 or in_planes != self.expansion*planes:
      self.shortcut = nn.Sequential(
          nn.Conv2d(in_planes, self.expansion*planes,
                    kernel_size=1, stride=stride, bias=False),
          nn.BatchNorm2d(self.expansion*planes)
      )

  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))
    out = self.bn2(self.conv2(out))
    out += self.shortcut(x)
    out = F.relu(out)
    return out

class ResNet(nn.Module):
  def __init__(self, block, num_blocks, num_classes=10):
    super(ResNet, self).__init__()
    self.in_planes = 64

    self.conv1 = nn.Conv2d(3, 64, kernel_size=3,
                            stride=1, padding=1, bias=False)
    self.bn1 = nn.BatchNorm2d(64)
    self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
    self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
    self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
    self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
    self.linear = nn.Linear(512*block.expansion, num_classes)

  def _make_layer(self, block, planes, num_blocks, stride):
    strides = [stride] + [1]*(num_blocks-1)
    layers = []
    for stride in strides:
      layers.append(block(self.in_planes, planes, stride))
      self.in_planes = planes * block.expansion
    return nn.Sequential(*layers)

  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))
    out = self.layer1(out)
    out = self.layer2(out)
    out = self.layer3(out)
    out = self.layer4(out)
    out = F.avg_pool2d(out, 4)
    out = out.view(out.size(0), -1)
    out = self.linear(out)
    return out

def ResNet18():
  return ResNet(BasicBlock, [2, 2, 2, 2])

# %%
# model = ResNet18()

# %% [markdown]
# The number of parameters is `11,173,962`, which exceeds the 5 million limit.

# %% [markdown]
# ### ResNet9

# %%
def ResNet9():
  return ResNet(BasicBlock, [1, 1, 1, 1])

# %%
model = ResNet9()

# %% [markdown]
# ### PreActResNet9

# %%
def PreActResNet9():
  return PreActResNet(PreActBlock, [1,1,1,1])

# %%
# model = PreActResNet9()

# %%
model =  model.to(device)
if device == 'cuda':
  model = torch.nn.DataParallel(model)
  cudnn.benchmark = True

# %%
summary(model, input_size=(3, 32, 32))
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            1,728
# ├─BatchNorm2d: 1-2                       128
# ├─Sequential: 1-3                        --
# |    └─BasicBlock: 2-1                   --
# |    |    └─Conv2d: 3-1                  36,864
# |    |    └─BatchNorm2d: 3-2             128
# |    |    └─Conv2d: 3-3                  36,864
# |    |    └─BatchNorm2d: 3-4             128
# |    |    └─Sequential: 3-5              --
# ├─Sequential: 1-4                        --
# |    └─BasicBlock: 2-2                   --
# |    |    └─Conv2d: 3-6                  73,728
# |    |    └─BatchNorm2d: 3-7             256
# |    |    └─Conv2d: 3-8                  147,456
# |    |    └─BatchNorm2d: 3-9             256
# |    |    └─Sequential: 3-10             8,448
# ├─Sequential: 1-5                        --
# |    └─BasicBlock: 2-3                   --
# |    |    └─Conv2d: 3-11                 294,912
# |    |    └─BatchNorm2d: 3-12            512
# |    |    └─Conv2d: 3-13                 589,824
# |    |    └─BatchNorm2d: 3-14            512
# |    |    └─Sequential: 3-15             33,280
# ├─Sequential: 1-6                        --
# |    └─BasicBlock: 2-4                   --
# |    |    └─Conv2d: 3-16                 1,179,648
# |    |    └─BatchNorm2d: 3-17            1,024
# |    |    └─Conv2d: 3-18                 2,359,296
# |    |    └─BatchNorm2d: 3-19            1,024
# |    |    └─Sequential: 3-20             132,096
# ├─Linear: 1-7                            5,130
# =================================================================
# Total params: 4,903,242
# Trainable params: 4,903,242
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            1,728
# ├─BatchNorm2d: 1-2                       128
# ├─Sequential: 1-3                        --
# |    └─BasicBlock: 2-1                   --
# |    |    └─Conv2d: 3-1                  36,864
# |    |    └─BatchNorm2d: 3-2             128
# |    |    └─Conv2d: 3-3                  36,864
# |    |    └─BatchNorm2d: 3-4             128
# |    |    └─Sequential: 3-5              --
# ├─Sequential: 1-4                        --
# |    └─BasicBlock: 2-2                   --
# |    |    └─Conv2d: 3-6                  73,728
# |    |    └─BatchNorm2d: 3-7             256
# |    |    └─Conv2d: 3-8                  147,456
# |    |    └─BatchNorm2d: 3-9             256
# |    |    └─Sequential: 3-10             8,448
# ├─Sequential: 1-5                        --
# |    └─BasicBlock: 2-3                   --
# |    |    └─Conv2d: 3-11                 294,912
# |    |    └─BatchNorm2d: 3-12            512
# |    |    └─Conv2d: 3-13                 589,824
# |    |    └─BatchNorm2d: 3-14            512
# |    |    └─Sequential: 3-15             33,280
# ├─Sequential: 1-6                        --
# |    └─BasicBlock: 2-4                   --
# |    |    └─Conv2d: 3-16                 1,179,648
# |    |    └─BatchNorm2d: 3-17            1,024
# |    |    └─Conv2d: 3-18                 2,359,296
# |    |    └─BatchNorm2d: 3-19            1,024
# |    |    └─Sequential: 3-20             132,096
# ├─Linear: 1-7                            5,130
# =================================================================
# Total params: 4,903,242
# Trainable params: 4,903,242
# Non-trainable params: 0
# =================================================================

# %% [markdown]
# ## Model Training

# %%
# Helper Function
# term_width = int(100)

# TOTAL_BAR_LENGTH = 65.
# last_time = time.time()
# begin_time = last_time

# def progress_bar(current, total, msg=None):
#   global last_time, begin_time
#   if current == 0:
#     begin_time = time.time()  # Reset for new bar.

#   cur_len = int(TOTAL_BAR_LENGTH * current/total)
#   rest_len = int(TOTAL_BAR_LENGTH - cur_len) - 1

#   sys.stdout.write(' [')
#   for i in range(cur_len):
#     sys.stdout.write('=')
#   sys.stdout.write('>')
#   for i in range(rest_len):
#     sys.stdout.write('.')
#   sys.stdout.write(']')

#   cur_time = time.time()
#   step_time = cur_time - last_time
#   last_time = cur_time
#   tot_time = cur_time - begin_time

#   L = []
#   L.append('  Step: %s' % format_time(step_time))
#   L.append(' | Tot: %s' % format_time(tot_time))
#   if msg:
#     L.append(' | ' + msg)

#   msg = ''.join(L)
#   sys.stdout.write(msg)
#   for i in range(term_width-int(TOTAL_BAR_LENGTH)-len(msg)-3):
#     sys.stdout.write(' ')

#   # Go back to the center of the bar.
#   for i in range(term_width-int(TOTAL_BAR_LENGTH/2)+2):
#     sys.stdout.write('\b')
#   sys.stdout.write(' %d/%d ' % (current+1, total))

#   if current < total-1:
#     sys.stdout.write('\r')
#   else:
#     sys.stdout.write('\n')
#   sys.stdout.flush()

# %%
def format_time(seconds):
  days = int(seconds / 3600/24)
  seconds = seconds - days*3600*24
  hours = int(seconds / 3600)
  seconds = seconds - hours*3600
  minutes = int(seconds / 60)
  seconds = seconds - minutes*60
  secondsf = int(seconds)
  seconds = seconds - secondsf
  millis = int(seconds*1000)

  f = ''
  i = 1
  if days > 0:
    f += str(days) + 'D'
    i += 1
  if hours > 0 and i <= 2:
    f += str(hours) + 'h'
    i += 1
  if minutes > 0 and i <= 2:
    f += str(minutes) + 'm'
    i += 1
  if secondsf > 0 and i <= 2:
    f += str(secondsf) + 's'
    i += 1
  if millis > 0 and i <= 2:
    f += str(millis) + 'ms'
    i += 1
  if f == '':
    f = '0ms'
  return f

# %%
lr = 0.1
momentum = 0.9
weight_decay = 4e-4

start_epoch = 1
number_of_epochs = 150
best_acc = 0


criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=lr,
                      momentum=momentum, weight_decay=weight_decay)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=number_of_epochs)

# %%
def get_lr(optimizer):
  for param_group in optimizer.param_groups:
    return param_group['lr']

# %%
def train(epoch):
  print('\nEpoch: %d' % epoch)
  start_time = time.time()

  model.train()
  train_loss = 0
  correct = 0
  total = 0
  for batch_idx, (inputs, targets) in enumerate(train_dl):
    # inputs, targets = inputs.to(device), targets.to(device)
    optimizer.zero_grad()
    outputs = model(inputs)
    loss = criterion(outputs, targets)
    loss.backward()
    optimizer.step()

    train_loss += loss.item()
    _, predicted = outputs.max(1)
    total += targets.size(0)
    correct += predicted.eq(targets).sum().item()

    if batch_idx % 50 == 0:
      print(f"Batch: {batch_idx}/{len(train_dl)} | Loss: {(train_loss/(batch_idx+1)):.3f} | Acc: {(100.*correct/total):.3f}%")

  cur_time = time.time()
  epoch_time = cur_time - start_time
  print(f"Time taken : {format_time(epoch_time)}")

  return train_loss/(batch_idx+1), 100.*correct/total, get_lr(optimizer)

# %%
def test(epoch):
  global best_acc
  model.eval()
  test_loss = 0
  correct = 0
  total = 0
  with torch.no_grad():
    for batch_idx, (inputs, targets) in enumerate(test_dl):
      # inputs, targets = inputs.to(device), targets.to(device)
      outputs = model(inputs)
      loss = criterion(outputs, targets)

      test_loss += loss.item()
      _, predicted = outputs.max(1)
      total += targets.size(0)
      correct += predicted.eq(targets).sum().item()
      
      if batch_idx % 50 == 0:
        print(f"Batch: {batch_idx}/{len(test_dl)} | Loss: {(test_loss/(batch_idx+1)):.3f} | Acc: {(100.*correct/total):.3f}%")
      # progress_bar(batch_idx, len(test_dl), 'Loss: %.3f | Acc: %.3f%% (%d/%d)'
      #               % (test_loss/(batch_idx+1), 100.*correct/total, correct, total))

  # Save checkpoint.
  acc = 100.*correct/total
  if acc > best_acc:
    print('Saving..')
    state = {
        'net': model.state_dict(),
        'acc': acc,
        'epoch': epoch,
    }
    if not os.path.isdir('checkpoint'):
      os.mkdir('checkpoint')
    torch.save(state, './checkpoint/ckpt.pth')
    best_acc = acc

  return test_loss/(batch_idx+1), 100.*correct/total

# %%
train_losses = []
train_accuracies = []
train_lrs = []

test_losses = []
test_accuracies = []

for epoch in range(start_epoch, start_epoch + number_of_epochs):
  epoch_train_loss, epoch_train_accuracy, epoch_lr = train(epoch)
  train_losses.append(epoch_train_loss)
  train_accuracies.append(epoch_train_accuracy)
  train_lrs.append(epoch_lr)

  epoch_test_loss, epoch_test_accuracy = test(epoch)
  test_losses.append(epoch_test_loss)
  test_accuracies.append(epoch_test_accuracy)

  scheduler.step()
# Out:
# Epoch: 1
# Batch: 0/391 | Loss: 2.347 | Acc: 8.594%
# Batch: 50/391 | Loss: 2.100 | Acc: 25.873%
# Batch: 100/391 | Loss: 1.896 | Acc: 31.536%
# Batch: 150/391 | Loss: 1.783 | Acc: 35.042%
# Batch: 200/391 | Loss: 1.713 | Acc: 37.554%
# Batch: 250/391 | Loss: 1.649 | Acc: 39.875%
# Batch: 300/391 | Loss: 1.596 | Acc: 41.814%
# Batch: 350/391 | Loss: 1.551 | Acc: 43.461%
# Time taken : 21s987ms
# Batch: 0/100 | Loss: 1.341 | Acc: 57.000%
# Batch: 50/100 | Loss: 1.375 | Acc: 54.275%
# Saving..
#
# Epoch: 2
# Batch: 0/391 | Loss: 1.098 | Acc: 55.469%
# Batch: 50/391 | Loss: 1.151 | Acc: 58.487%
# Batch: 100/391 | Loss: 1.128 | Acc: 59.646%
# Batch: 150/391 | Loss: 1.108 | Acc: 60.518%
# Batch: 200/391 | Loss: 1.097 | Acc: 60.965%
# Batch: 250/391 | Loss: 1.079 | Acc: 61.619%
# Batch: 300/391 | Loss: 1.059 | Acc: 62.318%
# Batch: 350/391 | Loss: 1.045 | Acc: 62.829%
# Time taken : 15s245ms
# Batch: 0/100 | Loss: 0.962 | Acc: 63.000%
# Batch: 50/100 | Loss: 1.049 | Acc: 63.373%
# Saving..
#
# Epoch: 3
# Batch: 0/391 | Loss: 0.982 | Acc: 64.062%
# Batch: 50/391 | Loss: 0.891 | Acc: 68.459%
# Batch: 100/391 | Loss: 0.893 | Acc: 68.286%
# Batch: 150/391 | Loss: 0.882 | Acc: 68.729%
# Batch: 200/391 | Loss: 0.870 | Acc: 69.076%
# Batch: 250/391 | Loss: 0.862 | Acc: 69.432%
# Batch: 300/391 | Loss: 0.850 | Acc: 69.936%
# Batch: 350/391 | Loss: 0.839 | Acc: 70.375%
# Time taken : 15s202ms
# Batch: 0/100 | Loss: 0.817 | Acc: 73.000%
# Batch: 50/100 | Loss: 0.779 | Acc: 72.745%
# Saving..
#
# Epoch: 4
# Batch: 0/391 | Loss: 0.813 | Acc: 68.750%
# Batch: 50/391 | Loss: 0.734 | Acc: 73.591%
# Batch: 100/391 | Loss: 0.726 | Acc: 74.273%
# Batch: 150/391 | Loss: 0.724 | Acc: 74.369%
# Batch: 200/391 | Loss: 0.718 | Acc: 74.728%
# Batch: 250/391 | Loss: 0.707 | Acc: 75.149%
# Batch: 300/391 | Loss: 0.704 | Acc: 75.249%
# Batch: 350/391 | Loss: 0.696 | Acc: 75.585%
# Time taken : 15s421ms
# Batch: 0/100 | Loss: 0.806 | Acc: 71.000%
# Batch: 50/100 | Loss: 0.787 | Acc: 74.059%
# Saving..
#
# Epoch: 5
# Batch: 0/391 | Loss: 0.805 | Acc: 72.656%
# Batch: 50/391 | Loss: 0.617 | Acc: 78.493%
# Batch: 100/391 | Loss: 0.627 | Acc: 78.055%
# Batch: 150/391 | Loss: 0.630 | Acc: 77.897%
# Batch: 200/391 | Loss: 0.624 | Acc: 78.253%
# Batch: 250/391 | Loss: 0.619 | Acc: 78.433%
# Batch: 300/391 | Loss: 0.616 | Acc: 78.520%
# Batch: 350/391 | Loss: 0.615 | Acc: 78.555%
# Time taken : 15s394ms
# Batch: 0/100 | Loss: 0.653 | Acc: 80.000%
# Batch: 50/100 | Loss: 0.823 | Acc: 72.216%
#
# Epoch: 6
# Batch: 0/391 | Loss: 0.587 | Acc: 77.344%
# Batch: 50/391 | Loss: 0.569 | Acc: 80.377%
# Batch: 100/391 | Loss: 0.566 | Acc: 80.415%
# Batch: 150/391 | Loss: 0.564 | Acc: 80.339%
# Batch: 200/391 | Loss: 0.566 | Acc: 80.387%
# Batch: 250/391 | Loss: 0.562 | Acc: 80.450%
# Batch: 300/391 | Loss: 0.560 | Acc: 80.513%
# Batch: 350/391 | Loss: 0.559 | Acc: 80.560%
# Time taken : 15s361ms
# Batch: 0/100 | Loss: 0.610 | Acc: 81.000%
# Batch: 50/100 | Loss: 0.604 | Acc: 79.529%
# Saving..
#
# Epoch: 7
# Batch: 0/391 | Loss: 0.557 | Acc: 76.562%
# Batch: 50/391 | Loss: 0.523 | Acc: 81.710%
# Batch: 100/391 | Loss: 0.524 | Acc: 81.621%
# Batch: 150/391 | Loss: 0.522 | Acc: 81.659%
# Batch: 200/391 | Loss: 0.520 | Acc: 81.755%
# Batch: 250/391 | Loss: 0.524 | Acc: 81.636%
# Batch: 300/391 | Loss: 0.524 | Acc: 81.670%
# Batch: 350/391 | Loss: 0.523 | Acc: 81.778%
# Time taken : 15s207ms
# Batch: 0/100 | Loss: 0.558 | Acc: 82.000%
# Batch: 50/100 | Loss: 0.580 | Acc: 79.451%
#
# Epoch: 8
# Batch: 0/391 | Loss: 0.357 | Acc: 89.844%
# Batch: 50/391 | Loss: 0.482 | Acc: 83.670%
# Batch: 100/391 | Loss: 0.487 | Acc: 83.277%
# Batch: 150/391 | Loss: 0.493 | Acc: 83.159%
# Batch: 200/391 | Loss: 0.488 | Acc: 83.244%
# Batch: 250/391 | Loss: 0.488 | Acc: 83.214%
# Batch: 300/391 | Loss: 0.490 | Acc: 83.080%
# Batch: 350/391 | Loss: 0.492 | Acc: 82.966%
# Time taken : 15s178ms
# Batch: 0/100 | Loss: 0.648 | Acc: 80.000%
# Batch: 50/100 | Loss: 0.699 | Acc: 76.725%
#
# Epoch: 9
# Batch: 0/391 | Loss: 0.427 | Acc: 85.156%
# Batch: 50/391 | Loss: 0.459 | Acc: 84.023%
# Batch: 100/391 | Loss: 0.472 | Acc: 83.563%
# Batch: 150/391 | Loss: 0.478 | Acc: 83.433%
# Batch: 200/391 | Loss: 0.482 | Acc: 83.353%
# Batch: 250/391 | Loss: 0.485 | Acc: 83.208%
# Batch: 300/391 | Loss: 0.481 | Acc: 83.329%
# Batch: 350/391 | Loss: 0.478 | Acc: 83.445%
# Time taken : 15s317ms
# Batch: 0/100 | Loss: 0.676 | Acc: 80.000%
# Batch: 50/100 | Loss: 0.635 | Acc: 79.667%
#
# Epoch: 10
# Batch: 0/391 | Loss: 0.575 | Acc: 78.906%
# Batch: 50/391 | Loss: 0.468 | Acc: 84.145%
# Batch: 100/391 | Loss: 0.454 | Acc: 84.491%
# Batch: 150/391 | Loss: 0.447 | Acc: 84.732%
# Batch: 200/391 | Loss: 0.451 | Acc: 84.534%
# Batch: 250/391 | Loss: 0.454 | Acc: 84.484%
# Batch: 300/391 | Loss: 0.453 | Acc: 84.455%
# Batch: 350/391 | Loss: 0.451 | Acc: 84.500%
# Time taken : 15s278ms
# Batch: 0/100 | Loss: 0.408 | Acc: 89.000%
# Batch: 50/100 | Loss: 0.498 | Acc: 83.255%
# Saving..
#
# Epoch: 11
# Batch: 0/391 | Loss: 0.362 | Acc: 85.938%
# Batch: 50/391 | Loss: 0.415 | Acc: 85.478%
# Batch: 100/391 | Loss: 0.426 | Acc: 85.002%
# Batch: 150/391 | Loss: 0.422 | Acc: 85.234%
# Batch: 200/391 | Loss: 0.426 | Acc: 85.051%
# Batch: 250/391 | Loss: 0.425 | Acc: 85.097%
# Batch: 300/391 | Loss: 0.427 | Acc: 85.045%
# Batch: 350/391 | Loss: 0.430 | Acc: 84.903%
# Time taken : 15s225ms
# Batch: 0/100 | Loss: 0.597 | Acc: 80.000%
# Batch: 50/100 | Loss: 0.591 | Acc: 80.275%
#
# Epoch: 12
# Batch: 0/391 | Loss: 0.398 | Acc: 86.719%
# Batch: 50/391 | Loss: 0.405 | Acc: 86.305%
# Batch: 100/391 | Loss: 0.413 | Acc: 85.883%
# Batch: 150/391 | Loss: 0.414 | Acc: 85.824%
# Batch: 200/391 | Loss: 0.413 | Acc: 85.794%
# Batch: 250/391 | Loss: 0.417 | Acc: 85.707%
# Batch: 300/391 | Loss: 0.420 | Acc: 85.626%
# Batch: 350/391 | Loss: 0.419 | Acc: 85.724%
# Time taken : 15s178ms
# Batch: 0/100 | Loss: 0.712 | Acc: 77.000%
# Batch: 50/100 | Loss: 0.608 | Acc: 79.216%
#
# Epoch: 13
# Batch: 0/391 | Loss: 0.355 | Acc: 89.062%
# Batch: 50/391 | Loss: 0.392 | Acc: 86.443%
# Batch: 100/391 | Loss: 0.399 | Acc: 86.293%
# Batch: 150/391 | Loss: 0.400 | Acc: 86.129%
# Batch: 200/391 | Loss: 0.405 | Acc: 86.054%
# Batch: 250/391 | Loss: 0.408 | Acc: 85.987%
# Batch: 300/391 | Loss: 0.405 | Acc: 86.130%
# Batch: 350/391 | Loss: 0.405 | Acc: 86.020%
# Time taken : 15s276ms
# Batch: 0/100 | Loss: 0.670 | Acc: 76.000%
# Batch: 50/100 | Loss: 0.634 | Acc: 79.118%
#
# Epoch: 14
# Batch: 0/391 | Loss: 0.241 | Acc: 92.969%
# Batch: 50/391 | Loss: 0.371 | Acc: 87.117%
# Batch: 100/391 | Loss: 0.378 | Acc: 86.928%
# Batch: 150/391 | Loss: 0.381 | Acc: 86.889%
# Batch: 200/391 | Loss: 0.385 | Acc: 86.882%
# Batch: 250/391 | Loss: 0.391 | Acc: 86.713%
# Batch: 300/391 | Loss: 0.390 | Acc: 86.724%
# Batch: 350/391 | Loss: 0.395 | Acc: 86.599%
# Time taken : 15s367ms
# Batch: 0/100 | Loss: 0.602 | Acc: 80.000%
# Batch: 50/100 | Loss: 0.631 | Acc: 79.922%
#
# Epoch: 15
# Batch: 0/391 | Loss: 0.321 | Acc: 90.625%
# Batch: 50/391 | Loss: 0.364 | Acc: 87.408%
# Batch: 100/391 | Loss: 0.374 | Acc: 87.098%
# Batch: 150/391 | Loss: 0.381 | Acc: 86.869%
# Batch: 200/391 | Loss: 0.385 | Acc: 86.855%
# Batch: 250/391 | Loss: 0.387 | Acc: 86.769%
# Batch: 300/391 | Loss: 0.390 | Acc: 86.592%
# Batch: 350/391 | Loss: 0.388 | Acc: 86.648%
# Time taken : 15s280ms
# Batch: 0/100 | Loss: 0.487 | Acc: 86.000%
# Batch: 50/100 | Loss: 0.491 | Acc: 83.451%
# Saving..
#
# Epoch: 16
# Batch: 0/391 | Loss: 0.356 | Acc: 89.062%
# Batch: 50/391 | Loss: 0.364 | Acc: 87.500%
# Batch: 100/391 | Loss: 0.366 | Acc: 87.361%
# Batch: 150/391 | Loss: 0.373 | Acc: 87.060%
# Batch: 200/391 | Loss: 0.376 | Acc: 86.909%
# Batch: 250/391 | Loss: 0.378 | Acc: 86.818%
# Batch: 300/391 | Loss: 0.379 | Acc: 86.820%
# Batch: 350/391 | Loss: 0.383 | Acc: 86.725%
# Time taken : 15s287ms
# Batch: 0/100 | Loss: 0.848 | Acc: 78.000%
# Batch: 50/100 | Loss: 0.693 | Acc: 79.667%
#
# Epoch: 17
# Batch: 0/391 | Loss: 0.388 | Acc: 86.719%
# Batch: 50/391 | Loss: 0.363 | Acc: 87.515%
# Batch: 100/391 | Loss: 0.360 | Acc: 87.655%
# Batch: 150/391 | Loss: 0.361 | Acc: 87.479%
# Batch: 200/391 | Loss: 0.360 | Acc: 87.617%
# Batch: 250/391 | Loss: 0.363 | Acc: 87.593%
# Batch: 300/391 | Loss: 0.366 | Acc: 87.435%
# Batch: 350/391 | Loss: 0.366 | Acc: 87.404%
# Time taken : 15s291ms
# Batch: 0/100 | Loss: 0.356 | Acc: 88.000%
# Batch: 50/100 | Loss: 0.460 | Acc: 84.059%
# Saving..
#
# Epoch: 18
# Batch: 0/391 | Loss: 0.242 | Acc: 92.188%
# Batch: 50/391 | Loss: 0.353 | Acc: 87.975%
# Batch: 100/391 | Loss: 0.347 | Acc: 87.941%
# Batch: 150/391 | Loss: 0.358 | Acc: 87.412%
# Batch: 200/391 | Loss: 0.360 | Acc: 87.422%
# Batch: 250/391 | Loss: 0.360 | Acc: 87.531%
# Batch: 300/391 | Loss: 0.364 | Acc: 87.427%
# Batch: 350/391 | Loss: 0.363 | Acc: 87.516%
# Time taken : 15s286ms
# Batch: 0/100 | Loss: 0.827 | Acc: 74.000%
# Batch: 50/100 | Loss: 0.613 | Acc: 80.647%
#
# Epoch: 19
# Batch: 0/391 | Loss: 0.280 | Acc: 88.281%
# Batch: 50/391 | Loss: 0.337 | Acc: 88.741%
# Batch: 100/391 | Loss: 0.355 | Acc: 87.848%
# Batch: 150/391 | Loss: 0.354 | Acc: 87.914%
# Batch: 200/391 | Loss: 0.357 | Acc: 87.838%
# Batch: 250/391 | Loss: 0.360 | Acc: 87.684%
# Batch: 300/391 | Loss: 0.359 | Acc: 87.695%
# Batch: 350/391 | Loss: 0.360 | Acc: 87.676%
# Time taken : 15s286ms
# Batch: 0/100 | Loss: 0.446 | Acc: 89.000%
# Batch: 50/100 | Loss: 0.510 | Acc: 83.549%
#
# Epoch: 20
# Batch: 0/391 | Loss: 0.391 | Acc: 85.156%
# Batch: 50/391 | Loss: 0.346 | Acc: 88.235%
# Batch: 100/391 | Loss: 0.343 | Acc: 88.529%
# Batch: 150/391 | Loss: 0.341 | Acc: 88.483%
# Batch: 200/391 | Loss: 0.346 | Acc: 88.266%
# Batch: 250/391 | Loss: 0.348 | Acc: 88.207%
# Batch: 300/391 | Loss: 0.350 | Acc: 88.151%
# Batch: 350/391 | Loss: 0.349 | Acc: 88.161%
# Time taken : 15s289ms
# Batch: 0/100 | Loss: 0.455 | Acc: 83.000%
# Batch: 50/100 | Loss: 0.683 | Acc: 78.353%
#
# Epoch: 21
# Batch: 0/391 | Loss: 0.274 | Acc: 91.406%
# Batch: 50/391 | Loss: 0.332 | Acc: 88.542%
# Batch: 100/391 | Loss: 0.344 | Acc: 87.980%
# Batch: 150/391 | Loss: 0.342 | Acc: 88.095%
# Batch: 200/391 | Loss: 0.349 | Acc: 87.908%
# Batch: 250/391 | Loss: 0.351 | Acc: 87.886%
# Batch: 300/391 | Loss: 0.353 | Acc: 87.845%
# Batch: 350/391 | Loss: 0.355 | Acc: 87.796%
# Time taken : 15s207ms
# Batch: 0/100 | Loss: 0.474 | Acc: 82.000%
# Batch: 50/100 | Loss: 0.506 | Acc: 84.059%
#
# Epoch: 22
# Batch: 0/391 | Loss: 0.302 | Acc: 87.500%
# Batch: 50/391 | Loss: 0.329 | Acc: 88.787%
# Batch: 100/391 | Loss: 0.334 | Acc: 88.722%
# Batch: 150/391 | Loss: 0.344 | Acc: 88.349%
# Batch: 200/391 | Loss: 0.341 | Acc: 88.479%
# Batch: 250/391 | Loss: 0.343 | Acc: 88.381%
# Batch: 300/391 | Loss: 0.343 | Acc: 88.372%
# Batch: 350/391 | Loss: 0.342 | Acc: 88.386%
# Time taken : 15s292ms
# Batch: 0/100 | Loss: 0.517 | Acc: 83.000%
# Batch: 50/100 | Loss: 0.490 | Acc: 83.980%
#
# Epoch: 23
# Batch: 0/391 | Loss: 0.248 | Acc: 91.406%
# Batch: 50/391 | Loss: 0.317 | Acc: 89.185%
# Batch: 100/391 | Loss: 0.329 | Acc: 88.830%
# Batch: 150/391 | Loss: 0.330 | Acc: 88.633%
# Batch: 200/391 | Loss: 0.330 | Acc: 88.643%
# Batch: 250/391 | Loss: 0.334 | Acc: 88.490%
# Batch: 300/391 | Loss: 0.331 | Acc: 88.538%
# Batch: 350/391 | Loss: 0.333 | Acc: 88.450%
# Time taken : 15s290ms
# Batch: 0/100 | Loss: 0.432 | Acc: 84.000%
# Batch: 50/100 | Loss: 0.542 | Acc: 82.451%
#
# Epoch: 24
# Batch: 0/391 | Loss: 0.405 | Acc: 84.375%
# Batch: 50/391 | Loss: 0.320 | Acc: 89.078%
# Batch: 100/391 | Loss: 0.325 | Acc: 88.784%
# Batch: 150/391 | Loss: 0.332 | Acc: 88.592%
# Batch: 200/391 | Loss: 0.337 | Acc: 88.402%
# Batch: 250/391 | Loss: 0.337 | Acc: 88.468%
# Batch: 300/391 | Loss: 0.340 | Acc: 88.346%
# Batch: 350/391 | Loss: 0.339 | Acc: 88.350%
# Time taken : 15s251ms
# Batch: 0/100 | Loss: 0.562 | Acc: 81.000%
# Batch: 50/100 | Loss: 0.541 | Acc: 82.647%
#
# Epoch: 25
# Batch: 0/391 | Loss: 0.282 | Acc: 88.281%
# Batch: 50/391 | Loss: 0.319 | Acc: 89.415%
# Batch: 100/391 | Loss: 0.328 | Acc: 88.807%
# Batch: 150/391 | Loss: 0.325 | Acc: 88.804%
# Batch: 200/391 | Loss: 0.329 | Acc: 88.748%
# Batch: 250/391 | Loss: 0.332 | Acc: 88.621%
# Batch: 300/391 | Loss: 0.335 | Acc: 88.504%
# Batch: 350/391 | Loss: 0.331 | Acc: 88.633%
# Time taken : 15s248ms
# Batch: 0/100 | Loss: 0.556 | Acc: 86.000%
# Batch: 50/100 | Loss: 0.494 | Acc: 83.863%
#
# Epoch: 26
# Batch: 0/391 | Loss: 0.420 | Acc: 84.375%
# Batch: 50/391 | Loss: 0.329 | Acc: 88.603%
# Batch: 100/391 | Loss: 0.325 | Acc: 88.892%
# Batch: 150/391 | Loss: 0.321 | Acc: 89.006%
# Batch: 200/391 | Loss: 0.319 | Acc: 89.012%
# Batch: 250/391 | Loss: 0.319 | Acc: 89.003%
# Batch: 300/391 | Loss: 0.321 | Acc: 88.925%
# Batch: 350/391 | Loss: 0.326 | Acc: 88.744%
# Time taken : 15s250ms
# Batch: 0/100 | Loss: 0.534 | Acc: 84.000%
# Batch: 50/100 | Loss: 0.461 | Acc: 84.608%
# Saving..
#
# Epoch: 27
# Batch: 0/391 | Loss: 0.442 | Acc: 85.156%
# Batch: 50/391 | Loss: 0.319 | Acc: 89.017%
# Batch: 100/391 | Loss: 0.313 | Acc: 89.109%
# Batch: 150/391 | Loss: 0.317 | Acc: 88.897%
# Batch: 200/391 | Loss: 0.317 | Acc: 88.919%
# Batch: 250/391 | Loss: 0.317 | Acc: 88.904%
# Batch: 300/391 | Loss: 0.320 | Acc: 88.803%
# Batch: 350/391 | Loss: 0.320 | Acc: 88.860%
# Time taken : 15s251ms
# Batch: 0/100 | Loss: 0.355 | Acc: 85.000%
# Batch: 50/100 | Loss: 0.468 | Acc: 84.804%
#
# Epoch: 28
# Batch: 0/391 | Loss: 0.340 | Acc: 86.719%
# Batch: 50/391 | Loss: 0.310 | Acc: 89.660%
# Batch: 100/391 | Loss: 0.307 | Acc: 89.542%
# Batch: 150/391 | Loss: 0.310 | Acc: 89.507%
# Batch: 300/391 | Loss: 0.288 | Acc: 89.997%
# Batch: 350/391 | Loss: 0.292 | Acc: 89.884%
# Time taken : 15s218ms
# Batch: 0/100 | Loss: 0.473 | Acc: 82.000%
# Batch: 50/100 | Loss: 0.472 | Acc: 84.608%
#
# Epoch: 38
# Batch: 0/391 | Loss: 0.239 | Acc: 92.188%
# Batch: 50/391 | Loss: 0.280 | Acc: 90.074%
# Batch: 100/391 | Loss: 0.271 | Acc: 90.347%
# Batch: 150/391 | Loss: 0.274 | Acc: 90.299%
# Batch: 200/391 | Loss: 0.287 | Acc: 89.863%
# Batch: 250/391 | Loss: 0.288 | Acc: 89.946%
# Batch: 300/391 | Loss: 0.287 | Acc: 89.981%
# Batch: 350/391 | Loss: 0.288 | Acc: 89.904%
# Time taken : 15s261ms
# Batch: 0/100 | Loss: 0.360 | Acc: 86.000%
# Batch: 50/100 | Loss: 0.376 | Acc: 87.608%
# Saving..
#
# Epoch: 39
# Batch: 0/391 | Loss: 0.212 | Acc: 92.969%
# Batch: 50/391 | Loss: 0.276 | Acc: 90.533%
# Batch: 100/391 | Loss: 0.278 | Acc: 90.455%
# Batch: 150/391 | Loss: 0.281 | Acc: 90.201%
# Batch: 200/391 | Loss: 0.282 | Acc: 90.205%
# Batch: 250/391 | Loss: 0.287 | Acc: 90.012%
# Batch: 300/391 | Loss: 0.285 | Acc: 90.103%
# Batch: 350/391 | Loss: 0.287 | Acc: 90.095%
# Time taken : 15s380ms
# Batch: 0/100 | Loss: 0.283 | Acc: 90.000%
# Batch: 50/100 | Loss: 0.410 | Acc: 86.490%
#
# Epoch: 40
# Batch: 0/391 | Loss: 0.269 | Acc: 89.844%
# Batch: 50/391 | Loss: 0.286 | Acc: 90.135%
# Batch: 100/391 | Loss: 0.279 | Acc: 90.285%
# Batch: 150/391 | Loss: 0.280 | Acc: 90.154%
# Batch: 200/391 | Loss: 0.282 | Acc: 90.151%
# Batch: 250/391 | Loss: 0.285 | Acc: 90.018%
# Batch: 300/391 | Loss: 0.286 | Acc: 90.031%
# Batch: 350/391 | Loss: 0.286 | Acc: 90.118%
# Time taken : 15s339ms
# Batch: 0/100 | Loss: 0.326 | Acc: 89.000%
# Batch: 50/100 | Loss: 0.453 | Acc: 85.235%
#
# Epoch: 41
# Batch: 0/391 | Loss: 0.209 | Acc: 92.969%
# Batch: 50/391 | Loss: 0.272 | Acc: 91.330%
# Batch: 100/391 | Loss: 0.268 | Acc: 91.166%
# Batch: 150/391 | Loss: 0.270 | Acc: 90.910%
# Batch: 200/391 | Loss: 0.269 | Acc: 90.936%
# Batch: 250/391 | Loss: 0.274 | Acc: 90.743%
# Batch: 300/391 | Loss: 0.277 | Acc: 90.573%
# Batch: 350/391 | Loss: 0.280 | Acc: 90.447%
# Time taken : 15s341ms
# Batch: 0/100 | Loss: 0.260 | Acc: 90.000%
# Batch: 50/100 | Loss: 0.441 | Acc: 86.176%
#
# Epoch: 42
# Batch: 0/391 | Loss: 0.294 | Acc: 89.844%
# Batch: 50/391 | Loss: 0.273 | Acc: 90.594%
# Batch: 100/391 | Loss: 0.278 | Acc: 90.401%
# Batch: 150/391 | Loss: 0.274 | Acc: 90.672%
# Batch: 200/391 | Loss: 0.281 | Acc: 90.396%
# Batch: 250/391 | Loss: 0.285 | Acc: 90.348%
# Batch: 300/391 | Loss: 0.287 | Acc: 90.230%
# Batch: 350/391 | Loss: 0.289 | Acc: 90.162%
# Time taken : 15s391ms
# Batch: 0/100 | Loss: 0.382 | Acc: 89.000%
# Batch: 50/100 | Loss: 0.387 | Acc: 87.216%
#
# Epoch: 43
# Batch: 0/391 | Loss: 0.226 | Acc: 95.312%
# Batch: 50/391 | Loss: 0.253 | Acc: 91.161%
# Batch: 100/391 | Loss: 0.263 | Acc: 90.679%
# Batch: 150/391 | Loss: 0.269 | Acc: 90.599%
# Batch: 200/391 | Loss: 0.271 | Acc: 90.567%
# Batch: 250/391 | Loss: 0.277 | Acc: 90.469%
# Batch: 300/391 | Loss: 0.279 | Acc: 90.399%
# Batch: 350/391 | Loss: 0.279 | Acc: 90.422%
# Time taken : 15s325ms
# Batch: 0/100 | Loss: 0.329 | Acc: 87.000%
# Batch: 50/100 | Loss: 0.367 | Acc: 87.686%
#
# Epoch: 44
# Batch: 0/391 | Loss: 0.192 | Acc: 92.188%
# Batch: 50/391 | Loss: 0.252 | Acc: 90.916%
# Batch: 100/391 | Loss: 0.259 | Acc: 90.818%
# Batch: 150/391 | Loss: 0.265 | Acc: 90.687%
# Batch: 200/391 | Loss: 0.271 | Acc: 90.516%
# Batch: 250/391 | Loss: 0.273 | Acc: 90.485%
# Batch: 300/391 | Loss: 0.277 | Acc: 90.342%
# Batch: 350/391 | Loss: 0.280 | Acc: 90.191%
# Time taken : 15s241ms
# Batch: 0/100 | Loss: 0.490 | Acc: 85.000%
# Batch: 50/100 | Loss: 0.371 | Acc: 88.098%
# Saving..
#
# Epoch: 45
# Batch: 0/391 | Loss: 0.264 | Acc: 90.625%
# Batch: 50/391 | Loss: 0.258 | Acc: 91.330%
# Batch: 100/391 | Loss: 0.267 | Acc: 90.826%
# Batch: 150/391 | Loss: 0.268 | Acc: 90.791%
# Batch: 200/391 | Loss: 0.271 | Acc: 90.606%
# Batch: 250/391 | Loss: 0.270 | Acc: 90.600%
# Batch: 300/391 | Loss: 0.275 | Acc: 90.428%
# Batch: 350/391 | Loss: 0.279 | Acc: 90.320%
# Time taken : 15s231ms
# Batch: 0/100 | Loss: 0.377 | Acc: 90.000%
# Batch: 50/100 | Loss: 0.493 | Acc: 84.549%
#
# Epoch: 46
# Batch: 0/391 | Loss: 0.268 | Acc: 92.969%
# Batch: 50/391 | Loss: 0.265 | Acc: 90.855%
# Batch: 100/391 | Loss: 0.265 | Acc: 91.019%
# Batch: 150/391 | Loss: 0.267 | Acc: 90.972%
# Batch: 200/391 | Loss: 0.267 | Acc: 90.936%
# Batch: 250/391 | Loss: 0.267 | Acc: 90.890%
# Batch: 300/391 | Loss: 0.274 | Acc: 90.664%
# Batch: 350/391 | Loss: 0.274 | Acc: 90.643%
# Batch: 350/391 | Loss: 0.134 | Acc: 95.377%
# Time taken : 15s296ms
# Batch: 0/100 | Loss: 0.297 | Acc: 91.000%
# Batch: 50/100 | Loss: 0.305 | Acc: 90.373%
# Saving..
#
# Epoch: 93
# Batch: 0/391 | Loss: 0.124 | Acc: 95.312%
# Batch: 50/391 | Loss: 0.106 | Acc: 96.400%
# Batch: 100/391 | Loss: 0.111 | Acc: 96.357%
# Batch: 150/391 | Loss: 0.112 | Acc: 96.306%
# Batch: 200/391 | Loss: 0.112 | Acc: 96.261%
# Batch: 250/391 | Loss: 0.117 | Acc: 96.103%
# Batch: 300/391 | Loss: 0.119 | Acc: 96.050%
# Batch: 350/391 | Loss: 0.122 | Acc: 95.882%
# Time taken : 15s376ms
# Batch: 0/100 | Loss: 0.402 | Acc: 86.000%
# Batch: 50/100 | Loss: 0.356 | Acc: 89.098%
#
# Epoch: 94
# Batch: 0/391 | Loss: 0.187 | Acc: 93.750%
# Batch: 50/391 | Loss: 0.127 | Acc: 95.695%
# Batch: 100/391 | Loss: 0.124 | Acc: 95.877%
# Batch: 150/391 | Loss: 0.122 | Acc: 95.892%
# Batch: 200/391 | Loss: 0.121 | Acc: 95.931%
# Batch: 250/391 | Loss: 0.123 | Acc: 95.848%
# Batch: 300/391 | Loss: 0.123 | Acc: 95.816%
# Batch: 350/391 | Loss: 0.125 | Acc: 95.751%
# Time taken : 15s457ms
# Batch: 0/100 | Loss: 0.230 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.306 | Acc: 91.059%
# Saving..
#
# Epoch: 95
# Batch: 0/391 | Loss: 0.156 | Acc: 95.312%
# Batch: 50/391 | Loss: 0.106 | Acc: 96.661%
# Batch: 100/391 | Loss: 0.105 | Acc: 96.465%
# Batch: 150/391 | Loss: 0.110 | Acc: 96.233%
# Batch: 200/391 | Loss: 0.112 | Acc: 96.179%
# Batch: 250/391 | Loss: 0.112 | Acc: 96.147%
# Batch: 300/391 | Loss: 0.114 | Acc: 96.115%
# Batch: 350/391 | Loss: 0.115 | Acc: 96.043%
# Time taken : 15s451ms
# Batch: 0/100 | Loss: 0.159 | Acc: 96.000%
# Batch: 50/100 | Loss: 0.332 | Acc: 90.157%
#
# Epoch: 96
# Batch: 0/391 | Loss: 0.075 | Acc: 97.656%
# Batch: 50/391 | Loss: 0.106 | Acc: 96.584%
# Batch: 100/391 | Loss: 0.105 | Acc: 96.504%
# Batch: 150/391 | Loss: 0.105 | Acc: 96.528%
# Batch: 200/391 | Loss: 0.105 | Acc: 96.541%
# Batch: 250/391 | Loss: 0.108 | Acc: 96.365%
# Batch: 300/391 | Loss: 0.111 | Acc: 96.244%
# Batch: 350/391 | Loss: 0.113 | Acc: 96.169%
# Time taken : 15s281ms
# Batch: 0/100 | Loss: 0.223 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.297 | Acc: 90.902%
#
# Epoch: 97
# Batch: 0/391 | Loss: 0.069 | Acc: 96.875%
# Batch: 50/391 | Loss: 0.103 | Acc: 96.523%
# Batch: 100/391 | Loss: 0.100 | Acc: 96.604%
# Batch: 150/391 | Loss: 0.101 | Acc: 96.482%
# Batch: 200/391 | Loss: 0.106 | Acc: 96.350%
# Batch: 250/391 | Loss: 0.106 | Acc: 96.374%
# Batch: 300/391 | Loss: 0.107 | Acc: 96.304%
# Batch: 350/391 | Loss: 0.111 | Acc: 96.165%
# Time taken : 15s375ms
# Batch: 0/100 | Loss: 0.368 | Acc: 92.000%
# Batch: 50/100 | Loss: 0.330 | Acc: 89.745%
#
# Epoch: 98
# Batch: 0/391 | Loss: 0.068 | Acc: 97.656%
# Batch: 50/391 | Loss: 0.100 | Acc: 96.829%
# Batch: 100/391 | Loss: 0.101 | Acc: 96.759%
# Batch: 150/391 | Loss: 0.105 | Acc: 96.502%
# Batch: 200/391 | Loss: 0.105 | Acc: 96.451%
# Batch: 250/391 | Loss: 0.104 | Acc: 96.520%
# Batch: 300/391 | Loss: 0.105 | Acc: 96.457%
# Batch: 350/391 | Loss: 0.106 | Acc: 96.405%
# Time taken : 15s422ms
# Batch: 0/100 | Loss: 0.196 | Acc: 93.000%
# Batch: 50/100 | Loss: 0.302 | Acc: 91.255%
# Saving..
#
# Epoch: 99
# Batch: 0/391 | Loss: 0.102 | Acc: 96.094%
# Batch: 50/391 | Loss: 0.101 | Acc: 96.722%
# Batch: 100/391 | Loss: 0.100 | Acc: 96.666%
# Batch: 150/391 | Loss: 0.101 | Acc: 96.627%
# Batch: 200/391 | Loss: 0.100 | Acc: 96.681%
# Batch: 250/391 | Loss: 0.101 | Acc: 96.694%
# Batch: 300/391 | Loss: 0.101 | Acc: 96.649%
# Batch: 350/391 | Loss: 0.102 | Acc: 96.644%
# Time taken : 15s312ms
# Batch: 0/100 | Loss: 0.291 | Acc: 90.000%
# Batch: 50/100 | Loss: 0.351 | Acc: 89.725%
#
# Epoch: 100
# Batch: 0/391 | Loss: 0.107 | Acc: 96.875%
# Batch: 50/391 | Loss: 0.089 | Acc: 97.105%
# Batch: 100/391 | Loss: 0.091 | Acc: 96.952%
# Batch: 150/391 | Loss: 0.091 | Acc: 96.901%
# Batch: 200/391 | Loss: 0.089 | Acc: 96.992%
# Batch: 250/391 | Loss: 0.092 | Acc: 96.887%
# Batch: 300/391 | Loss: 0.094 | Acc: 96.831%
# Batch: 350/391 | Loss: 0.095 | Acc: 96.802%
# Time taken : 15s337ms
# Batch: 0/100 | Loss: 0.286 | Acc: 91.000%
# Batch: 50/100 | Loss: 0.319 | Acc: 90.608%
#
# Epoch: 101
# Batch: 0/391 | Loss: 0.044 | Acc: 99.219%
# Batch: 50/391 | Loss: 0.086 | Acc: 97.028%
# Batch: 100/391 | Loss: 0.082 | Acc: 97.192%
# Batch: 150/391 | Loss: 0.088 | Acc: 97.010%
# Batch: 200/391 | Loss: 0.088 | Acc: 97.077%
# Batch: 250/391 | Loss: 0.088 | Acc: 97.049%
# Batch: 300/391 | Loss: 0.090 | Acc: 96.994%
# Batch: 350/391 | Loss: 0.091 | Acc: 96.993%
# Time taken : 15s347ms
# Batch: 0/100 | Loss: 0.231 | Acc: 90.000%
# Batch: 50/100 | Loss: 0.296 | Acc: 91.157%
# Saving..
#
# Epoch: 102
# Batch: 0/391 | Loss: 0.107 | Acc: 96.875%
# Batch: 50/391 | Loss: 0.092 | Acc: 96.982%
# Batch: 100/391 | Loss: 0.091 | Acc: 97.053%
# Batch: 150/391 | Loss: 0.089 | Acc: 97.087%
# Batch: 200/391 | Loss: 0.089 | Acc: 97.081%
# Batch: 250/391 | Loss: 0.087 | Acc: 97.127%
# Batch: 300/391 | Loss: 0.088 | Acc: 97.101%
# Batch: 350/391 | Loss: 0.089 | Acc: 97.031%
# Time taken : 15s245ms
# Batch: 0/100 | Loss: 0.289 | Acc: 92.000%
# Batch: 50/100 | Loss: 0.330 | Acc: 89.863%
#
# Epoch: 103
# Batch: 0/391 | Loss: 0.095 | Acc: 95.312%
# Batch: 50/391 | Loss: 0.091 | Acc: 97.028%
# Batch: 100/391 | Loss: 0.090 | Acc: 96.991%
# Batch: 150/391 | Loss: 0.087 | Acc: 97.066%
# ...
# Batch: 50/391 | Loss: 0.032 | Acc: 99.020%
# Batch: 100/391 | Loss: 0.033 | Acc: 99.049%
# Batch: 150/391 | Loss: 0.031 | Acc: 99.084%
# Batch: 200/391 | Loss: 0.031 | Acc: 99.098%
# Batch: 250/391 | Loss: 0.031 | Acc: 99.072%
# Batch: 300/391 | Loss: 0.031 | Acc: 99.105%
# Batch: 350/391 | Loss: 0.030 | Acc: 99.119%
# Time taken : 15s364ms
# Batch: 0/100 | Loss: 0.229 | Acc: 93.000%
# Batch: 50/100 | Loss: 0.249 | Acc: 93.275%
# Saving..
#
# Epoch: 118
# Batch: 0/391 | Loss: 0.060 | Acc: 96.875%
# Batch: 50/391 | Loss: 0.027 | Acc: 99.280%
# Batch: 100/391 | Loss: 0.029 | Acc: 99.211%
# Batch: 150/391 | Loss: 0.029 | Acc: 99.157%
# Batch: 200/391 | Loss: 0.029 | Acc: 99.188%
# Batch: 250/391 | Loss: 0.029 | Acc: 99.166%
# Batch: 300/391 | Loss: 0.029 | Acc: 99.156%
# Batch: 350/391 | Loss: 0.029 | Acc: 99.172%
# Time taken : 15s236ms
# Batch: 0/100 | Loss: 0.274 | Acc: 92.000%
# Batch: 50/100 | Loss: 0.264 | Acc: 92.529%
#
# Epoch: 119
# Batch: 0/391 | Loss: 0.023 | Acc: 98.438%
# Batch: 50/391 | Loss: 0.028 | Acc: 99.157%
# Batch: 100/391 | Loss: 0.027 | Acc: 99.242%
# Batch: 150/391 | Loss: 0.026 | Acc: 99.255%
# Batch: 200/391 | Loss: 0.026 | Acc: 99.277%
# Batch: 250/391 | Loss: 0.025 | Acc: 99.287%
# Batch: 300/391 | Loss: 0.025 | Acc: 99.325%
# Batch: 350/391 | Loss: 0.024 | Acc: 99.361%
# Time taken : 15s342ms
# Batch: 0/100 | Loss: 0.247 | Acc: 93.000%
# Batch: 50/100 | Loss: 0.257 | Acc: 92.902%
#
# Epoch: 120
# Batch: 0/391 | Loss: 0.023 | Acc: 99.219%
# Batch: 50/391 | Loss: 0.021 | Acc: 99.433%
# Batch: 100/391 | Loss: 0.019 | Acc: 99.528%
# Batch: 150/391 | Loss: 0.019 | Acc: 99.534%
# Batch: 200/391 | Loss: 0.019 | Acc: 99.502%
# Batch: 250/391 | Loss: 0.019 | Acc: 99.480%
# Batch: 300/391 | Loss: 0.020 | Acc: 99.447%
# Batch: 350/391 | Loss: 0.020 | Acc: 99.452%
# Time taken : 15s346ms
# Batch: 0/100 | Loss: 0.314 | Acc: 92.000%
# Batch: 50/100 | Loss: 0.247 | Acc: 93.647%
# Saving..
#
# Epoch: 121
# Batch: 0/391 | Loss: 0.016 | Acc: 99.219%
# Batch: 50/391 | Loss: 0.016 | Acc: 99.602%
# Batch: 100/391 | Loss: 0.017 | Acc: 99.575%
# Batch: 150/391 | Loss: 0.018 | Acc: 99.550%
# Batch: 200/391 | Loss: 0.018 | Acc: 99.534%
# Batch: 250/391 | Loss: 0.019 | Acc: 99.527%
# Batch: 300/391 | Loss: 0.019 | Acc: 99.533%
# Batch: 350/391 | Loss: 0.019 | Acc: 99.546%
# Time taken : 15s278ms
# Batch: 0/100 | Loss: 0.260 | Acc: 93.000%
# Batch: 50/100 | Loss: 0.243 | Acc: 93.431%
#
# Epoch: 122
# Batch: 0/391 | Loss: 0.019 | Acc: 99.219%
# Batch: 50/391 | Loss: 0.014 | Acc: 99.724%
# Batch: 100/391 | Loss: 0.014 | Acc: 99.714%
# Batch: 150/391 | Loss: 0.014 | Acc: 99.715%
# Batch: 200/391 | Loss: 0.014 | Acc: 99.685%
# Batch: 250/391 | Loss: 0.015 | Acc: 99.655%
# Batch: 300/391 | Loss: 0.015 | Acc: 99.660%
# Batch: 350/391 | Loss: 0.015 | Acc: 99.646%
# Time taken : 15s279ms
# Batch: 0/100 | Loss: 0.241 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.229 | Acc: 93.882%
# Saving..
#
# Epoch: 123
# Batch: 0/391 | Loss: 0.015 | Acc: 99.219%
# Batch: 50/391 | Loss: 0.012 | Acc: 99.709%
# Batch: 100/391 | Loss: 0.013 | Acc: 99.706%
# Batch: 150/391 | Loss: 0.013 | Acc: 99.674%
# Batch: 200/391 | Loss: 0.014 | Acc: 99.658%
# Batch: 250/391 | Loss: 0.015 | Acc: 99.626%
# Batch: 300/391 | Loss: 0.015 | Acc: 99.650%
# Batch: 350/391 | Loss: 0.014 | Acc: 99.653%
# Time taken : 15s163ms
# Batch: 0/100 | Loss: 0.196 | Acc: 97.000%
# Batch: 50/100 | Loss: 0.232 | Acc: 93.843%
#
# Epoch: 124
# Batch: 0/391 | Loss: 0.007 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.014 | Acc: 99.724%
# Batch: 100/391 | Loss: 0.014 | Acc: 99.729%
# Batch: 150/391 | Loss: 0.012 | Acc: 99.757%
# Batch: 200/391 | Loss: 0.012 | Acc: 99.778%
# Batch: 250/391 | Loss: 0.012 | Acc: 99.791%
# Batch: 300/391 | Loss: 0.011 | Acc: 99.785%
# Batch: 350/391 | Loss: 0.012 | Acc: 99.777%
# Time taken : 15s307ms
# Batch: 0/100 | Loss: 0.246 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.228 | Acc: 93.882%
#
# Epoch: 125
# Batch: 0/391 | Loss: 0.015 | Acc: 99.219%
# Batch: 50/391 | Loss: 0.009 | Acc: 99.847%
# Batch: 100/391 | Loss: 0.009 | Acc: 99.853%
# Batch: 150/391 | Loss: 0.009 | Acc: 99.855%
# Batch: 200/391 | Loss: 0.010 | Acc: 99.821%
# Batch: 250/391 | Loss: 0.010 | Acc: 99.819%
# Batch: 300/391 | Loss: 0.010 | Acc: 99.818%
# Batch: 350/391 | Loss: 0.010 | Acc: 99.822%
# Time taken : 15s325ms
# Batch: 0/100 | Loss: 0.265 | Acc: 93.000%
# Batch: 50/100 | Loss: 0.231 | Acc: 94.000%
#
# Epoch: 126
# Batch: 0/391 | Loss: 0.011 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.008 | Acc: 99.908%
# Batch: 100/391 | Loss: 0.008 | Acc: 99.907%
# Batch: 150/391 | Loss: 0.009 | Acc: 99.886%
# Batch: 200/391 | Loss: 0.009 | Acc: 99.856%
# Batch: 250/391 | Loss: 0.009 | Acc: 99.835%
# Batch: 300/391 | Loss: 0.010 | Acc: 99.834%
# Batch: 350/391 | Loss: 0.009 | Acc: 99.835%
# Time taken : 15s337ms
# Batch: 0/100 | Loss: 0.165 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.225 | Acc: 94.020%
# Saving..
#
# Epoch: 127
# Batch: 0/391 | Loss: 0.033 | Acc: 98.438%
# Batch: 50/391 | Loss: 0.009 | Acc: 99.831%
# Batch: 100/391 | Loss: 0.009 | Acc: 99.830%
# Batch: 150/391 | Loss: 0.009 | Acc: 99.829%
# Batch: 200/391 | Loss: 0.009 | Acc: 99.829%
# Batch: 250/391 | Loss: 0.009 | Acc: 99.844%
# Batch: 300/391 | Loss: 0.009 | Acc: 99.836%
# Batch: 350/391 | Loss: 0.009 | Acc: 99.831%
# Time taken : 15s355ms
# Batch: 0/100 | Loss: 0.204 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.228 | Acc: 93.863%
#
# Epoch: 128
# Batch: 0/391 | Loss: 0.010 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.009 | Acc: 99.786%
# Batch: 100/391 | Loss: 0.008 | Acc: 99.845%
# Batch: 150/391 | Loss: 0.008 | Acc: 99.855%
# Batch: 200/391 | Loss: 0.008 | Acc: 99.864%
# Batch: 250/391 | Loss: 0.008 | Acc: 99.875%
# Batch: 300/391 | Loss: 0.007 | Acc: 99.883%
# Batch: 350/391 | Loss: 0.007 | Acc: 99.891%
# Time taken : 15s265ms
# Batch: 0/100 | Loss: 0.195 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.228 | Acc: 93.647%
#
# Epoch: 129
# Batch: 0/391 | Loss: 0.003 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.006 | Acc: 99.939%
# Batch: 100/391 | Loss: 0.007 | Acc: 99.869%
# Batch: 150/391 | Loss: 0.007 | Acc: 99.891%
# Batch: 200/391 | Loss: 0.007 | Acc: 99.887%
# Batch: 250/391 | Loss: 0.007 | Acc: 99.891%
# Batch: 300/391 | Loss: 0.007 | Acc: 99.899%
# Batch: 350/391 | Loss: 0.007 | Acc: 99.902%
# Time taken : 15s338ms
# Batch: 0/100 | Loss: 0.194 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.223 | Acc: 93.980%
#
# Epoch: 130
# Batch: 0/391 | Loss: 0.002 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.007 | Acc: 99.877%
# Batch: 100/391 | Loss: 0.007 | Acc: 99.907%
# Batch: 150/391 | Loss: 0.007 | Acc: 99.917%
# Batch: 200/391 | Loss: 0.006 | Acc: 99.918%
# Batch: 250/391 | Loss: 0.006 | Acc: 99.922%
# Batch: 300/391 | Loss: 0.006 | Acc: 99.914%
# Batch: 350/391 | Loss: 0.006 | Acc: 99.918%
# Time taken : 15s419ms
# Batch: 0/100 | Loss: 0.159 | Acc: 96.000%
# Batch: 50/100 | Loss: 0.216 | Acc: 94.275%
# Saving..
#
# Epoch: 131
# Batch: 0/391 | Loss: 0.005 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.006 | Acc: 99.893%
# Batch: 100/391 | Loss: 0.006 | Acc: 99.930%
# Batch: 150/391 | Loss: 0.006 | Acc: 99.928%
# Batch: 200/391 | Loss: 0.006 | Acc: 99.938%
# Batch: 250/391 | Loss: 0.006 | Acc: 99.944%
# Batch: 300/391 | Loss: 0.006 | Acc: 99.940%
# Batch: 350/391 | Loss: 0.006 | Acc: 99.931%
# Time taken : 15s240ms
# Batch: 0/100 | Loss: 0.172 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.218 | Acc: 94.039%
#
# Epoch: 132
# Batch: 0/391 | Loss: 0.011 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.006 | Acc: 99.939%
# Batch: 100/391 | Loss: 0.005 | Acc: 99.961%
# Batch: 150/391 | Loss: 0.005 | Acc: 99.953%
# Batch: 200/391 | Loss: 0.006 | Acc: 99.946%
# Batch: 250/391 | Loss: 0.006 | Acc: 99.947%
# Batch: 300/391 | Loss: 0.006 | Acc: 99.945%
# Batch: 350/391 | Loss: 0.006 | Acc: 99.942%
# Time taken : 15s361ms
# Batch: 0/100 | Loss: 0.194 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.218 | Acc: 94.373%
# Saving..
#
# Epoch: 133
# Batch: 0/391 | Loss: 0.002 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.005 | Acc: 99.954%
# Batch: 100/391 | Loss: 0.005 | Acc: 99.977%
# Batch: 150/391 | Loss: 0.005 | Acc: 99.964%
# Batch: 200/391 | Loss: 0.005 | Acc: 99.969%
# Batch: 250/391 | Loss: 0.005 | Acc: 99.966%
# Batch: 300/391 | Loss: 0.005 | Acc: 99.953%
# Batch: 350/391 | Loss: 0.005 | Acc: 99.951%
# Time taken : 15s219ms
# Batch: 0/100 | Loss: 0.153 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.215 | Acc: 94.176%
#
# Epoch: 134
# Batch: 0/391 | Loss: 0.009 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.006 | Acc: 99.908%
# Batch: 100/391 | Loss: 0.005 | Acc: 99.954%
# Batch: 150/391 | Loss: 0.005 | Acc: 99.964%
# Batch: 200/391 | Loss: 0.005 | Acc: 99.965%
# Batch: 250/391 | Loss: 0.005 | Acc: 99.960%
# Batch: 300/391 | Loss: 0.005 | Acc: 99.961%
# Batch: 350/391 | Loss: 0.005 | Acc: 99.958%
# Time taken : 15s274ms
# Batch: 0/100 | Loss: 0.166 | Acc: 96.000%
# Batch: 50/100 | Loss: 0.218 | Acc: 94.137%
#
# Epoch: 135
# Batch: 0/391 | Loss: 0.003 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.004 | Acc: 99.985%
# Batch: 100/391 | Loss: 0.004 | Acc: 99.977%
# Batch: 150/391 | Loss: 0.004 | Acc: 99.979%
# Batch: 200/391 | Loss: 0.004 | Acc: 99.981%
# Batch: 250/391 | Loss: 0.005 | Acc: 99.975%
# Batch: 300/391 | Loss: 0.005 | Acc: 99.971%
# Batch: 350/391 | Loss: 0.005 | Acc: 99.973%
# Time taken : 15s267ms
# Batch: 0/100 | Loss: 0.174 | Acc: 96.000%
# Batch: 50/100 | Loss: 0.215 | Acc: 94.176%
#
# Epoch: 136
# Batch: 0/391 | Loss: 0.002 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.004 | Acc: 99.954%
# Batch: 100/391 | Loss: 0.004 | Acc: 99.961%
# Batch: 150/391 | Loss: 0.004 | Acc: 99.969%
# Batch: 200/391 | Loss: 0.004 | Acc: 99.973%
# Batch: 250/391 | Loss: 0.004 | Acc: 99.969%
# Batch: 300/391 | Loss: 0.004 | Acc: 99.969%
# Batch: 350/391 | Loss: 0.005 | Acc: 99.962%
# Time taken : 15s409ms
# Batch: 0/100 | Loss: 0.188 | Acc: 96.000%
# Batch: 50/100 | Loss: 0.211 | Acc: 94.235%
# Saving..
#
# Epoch: 137
# Batch: 0/391 | Loss: 0.003 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.004 | Acc: 100.000%
# Batch: 100/391 | Loss: 0.004 | Acc: 99.985%
# Batch: 150/391 | Loss: 0.004 | Acc: 99.979%
# Batch: 200/391 | Loss: 0.005 | Acc: 99.969%
# Batch: 250/391 | Loss: 0.005 | Acc: 99.963%
# Batch: 300/391 | Loss: 0.005 | Acc: 99.969%
# Batch: 350/391 | Loss: 0.005 | Acc: 99.967%
# Time taken : 15s398ms
# Batch: 0/100 | Loss: 0.184 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.212 | Acc: 94.294%
#
# Epoch: 138
# Batch: 0/391 | Loss: 0.003 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.005 | Acc: 99.954%
# Batch: 100/391 | Loss: 0.004 | Acc: 99.961%
# Batch: 150/391 | Loss: 0.004 | Acc: 99.964%
# Batch: 200/391 | Loss: 0.004 | Acc: 99.965%
# Batch: 250/391 | Loss: 0.004 | Acc: 99.966%
# Batch: 300/391 | Loss: 0.004 | Acc: 99.966%
# Batch: 350/391 | Loss: 0.004 | Acc: 99.971%
# Time taken : 15s338ms
# Batch: 0/100 | Loss: 0.186 | Acc: 96.000%
# Batch: 50/100 | Loss: 0.209 | Acc: 94.392%
#
# Epoch: 139
# Batch: 0/391 | Loss: 0.004 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.004 | Acc: 99.954%
# Batch: 100/391 | Loss: 0.004 | Acc: 99.969%
# Batch: 150/391 | Loss: 0.004 | Acc: 99.979%
# Batch: 200/391 | Loss: 0.004 | Acc: 99.981%
# Batch: 250/391 | Loss: 0.004 | Acc: 99.981%
# Batch: 300/391 | Loss: 0.004 | Acc: 99.982%
# Batch: 350/391 | Loss: 0.004 | Acc: 99.982%
# Time taken : 15s305ms
# Batch: 0/100 | Loss: 0.184 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.212 | Acc: 94.314%
#
# Epoch: 140
# Batch: 0/391 | Loss: 0.006 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.003 | Acc: 100.000%
# Batch: 100/391 | Loss: 0.004 | Acc: 99.992%
# Batch: 150/391 | Loss: 0.004 | Acc: 99.984%
# Batch: 200/391 | Loss: 0.004 | Acc: 99.977%
# Batch: 250/391 | Loss: 0.004 | Acc: 99.972%
# Batch: 300/391 | Loss: 0.004 | Acc: 99.969%
# Batch: 350/391 | Loss: 0.004 | Acc: 99.967%
# Time taken : 15s271ms
# Batch: 0/100 | Loss: 0.211 | Acc: 96.000%
# Batch: 50/100 | Loss: 0.211 | Acc: 94.392%
# Saving..
#
# Epoch: 141
# Batch: 0/391 | Loss: 0.002 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.004 | Acc: 100.000%
# Batch: 100/391 | Loss: 0.004 | Acc: 99.985%
# Batch: 150/391 | Loss: 0.004 | Acc: 99.990%
# Batch: 200/391 | Loss: 0.004 | Acc: 99.988%
# Batch: 250/391 | Loss: 0.004 | Acc: 99.984%
# Batch: 300/391 | Loss: 0.004 | Acc: 99.984%
# Batch: 350/391 | Loss: 0.004 | Acc: 99.987%
# Time taken : 15s415ms
# Batch: 0/100 | Loss: 0.191 | Acc: 96.000%
# Batch: 50/100 | Loss: 0.208 | Acc: 94.549%
# Saving..
#
# Epoch: 142
# Batch: 0/391 | Loss: 0.004 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.004 | Acc: 100.000%
# Batch: 100/391 | Loss: 0.004 | Acc: 100.000%
# Batch: 150/391 | Loss: 0.004 | Acc: 100.000%
# Batch: 200/391 | Loss: 0.004 | Acc: 99.996%
# Batch: 250/391 | Loss: 0.004 | Acc: 99.994%
# Batch: 300/391 | Loss: 0.004 | Acc: 99.992%
# Batch: 350/391 | Loss: 0.004 | Acc: 99.989%
# Time taken : 15s350ms
# Batch: 0/100 | Loss: 0.178 | Acc: 96.000%
# Batch: 50/100 | Loss: 0.209 | Acc: 94.373%
#
# Epoch: 143
# Batch: 0/391 | Loss: 0.003 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.004 | Acc: 99.969%
# Batch: 100/391 | Loss: 0.004 | Acc: 99.977%
# Batch: 150/391 | Loss: 0.004 | Acc: 99.969%
# Batch: 200/391 | Loss: 0.004 | Acc: 99.973%
# Batch: 250/391 | Loss: 0.004 | Acc: 99.969%
# Batch: 300/391 | Loss: 0.004 | Acc: 99.974%
# Batch: 350/391 | Loss: 0.004 | Acc: 99.971%
# Time taken : 15s330ms
# Batch: 0/100 | Loss: 0.196 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.210 | Acc: 94.157%
#
# Epoch: 144
# Batch: 0/391 | Loss: 0.007 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.004 | Acc: 100.000%
# Batch: 100/391 | Loss: 0.004 | Acc: 99.992%
# Batch: 150/391 | Loss: 0.004 | Acc: 99.984%
# Batch: 200/391 | Loss: 0.004 | Acc: 99.988%
# Batch: 250/391 | Loss: 0.004 | Acc: 99.991%
# Batch: 300/391 | Loss: 0.004 | Acc: 99.987%
# Batch: 350/391 | Loss: 0.004 | Acc: 99.989%
# Time taken : 15s338ms
# Batch: 0/100 | Loss: 0.178 | Acc: 96.000%
# Batch: 50/100 | Loss: 0.209 | Acc: 94.216%
#
# Epoch: 145
# Batch: 0/391 | Loss: 0.004 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.004 | Acc: 99.969%
# Batch: 100/391 | Loss: 0.004 | Acc: 99.985%
# Batch: 150/391 | Loss: 0.004 | Acc: 99.984%
# Batch: 200/391 | Loss: 0.004 | Acc: 99.984%
# Batch: 250/391 | Loss: 0.004 | Acc: 99.988%
# Batch: 300/391 | Loss: 0.004 | Acc: 99.987%
# Batch: 350/391 | Loss: 0.004 | Acc: 99.987%
# Time taken : 15s349ms
# Batch: 0/100 | Loss: 0.196 | Acc: 96.000%
# Batch: 50/100 | Loss: 0.210 | Acc: 94.255%
#
# Epoch: 146
# Batch: 0/391 | Loss: 0.003 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.004 | Acc: 100.000%
# Batch: 100/391 | Loss: 0.004 | Acc: 99.977%
# Batch: 150/391 | Loss: 0.004 | Acc: 99.984%
# Batch: 200/391 | Loss: 0.004 | Acc: 99.977%
# Batch: 250/391 | Loss: 0.004 | Acc: 99.975%
# Batch: 300/391 | Loss: 0.004 | Acc: 99.966%
# Batch: 350/391 | Loss: 0.004 | Acc: 99.967%
# Time taken : 15s393ms
# Batch: 0/100 | Loss: 0.190 | Acc: 96.000%
# Batch: 50/100 | Loss: 0.209 | Acc: 94.294%
#
# Epoch: 147
# Batch: 0/391 | Loss: 0.008 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.004 | Acc: 100.000%
# Batch: 100/391 | Loss: 0.004 | Acc: 99.985%
# Batch: 150/391 | Loss: 0.004 | Acc: 99.990%
# Batch: 200/391 | Loss: 0.004 | Acc: 99.988%
# Batch: 250/391 | Loss: 0.004 | Acc: 99.991%
# Batch: 300/391 | Loss: 0.004 | Acc: 99.992%
# Batch: 350/391 | Loss: 0.004 | Acc: 99.991%
# Time taken : 15s311ms
# Batch: 0/100 | Loss: 0.191 | Acc: 96.000%
# Batch: 50/100 | Loss: 0.209 | Acc: 94.314%
#
# Epoch: 148
# Batch: 0/391 | Loss: 0.002 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.004 | Acc: 99.985%
# Batch: 100/391 | Loss: 0.004 | Acc: 99.985%
# Batch: 150/391 | Loss: 0.003 | Acc: 99.984%
# Batch: 200/391 | Loss: 0.003 | Acc: 99.988%
# Batch: 250/391 | Loss: 0.004 | Acc: 99.991%
# Batch: 300/391 | Loss: 0.004 | Acc: 99.990%
# Batch: 350/391 | Loss: 0.004 | Acc: 99.987%
# Time taken : 15s223ms
# Batch: 0/100 | Loss: 0.198 | Acc: 96.000%
# Batch: 50/100 | Loss: 0.211 | Acc: 94.216%
#
# Epoch: 149
# Batch: 0/391 | Loss: 0.003 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.004 | Acc: 99.969%
# Batch: 100/391 | Loss: 0.004 | Acc: 99.954%
# Batch: 150/391 | Loss: 0.004 | Acc: 99.964%
# Batch: 200/391 | Loss: 0.004 | Acc: 99.973%
# Batch: 250/391 | Loss: 0.004 | Acc: 99.978%
# Batch: 300/391 | Loss: 0.004 | Acc: 99.982%
# Batch: 350/391 | Loss: 0.004 | Acc: 99.982%
# Time taken : 15s337ms
# Batch: 0/100 | Loss: 0.187 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.208 | Acc: 94.314%
#
# Epoch: 150
# Batch: 0/391 | Loss: 0.006 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.004 | Acc: 100.000%
# Batch: 100/391 | Loss: 0.004 | Acc: 100.000%
# Batch: 150/391 | Loss: 0.004 | Acc: 99.995%
# Batch: 200/391 | Loss: 0.004 | Acc: 99.992%
# Batch: 250/391 | Loss: 0.004 | Acc: 99.988%
# Batch: 300/391 | Loss: 0.004 | Acc: 99.990%
# Batch: 350/391 | Loss: 0.004 | Acc: 99.984%
# Time taken : 15s348ms
# Batch: 0/100 | Loss: 0.186 | Acc: 96.000%
# Batch: 50/100 | Loss: 0.210 | Acc: 94.333%

# %%
def plot_accuracies(train_accuracies, test_accuracies):
  plt.plot(train_accuracies, label='Train Accuracy')
  plt.plot(test_accuracies, label='Test Accuracy')
  plt.xlabel('Epochs')
  plt.ylabel('Accuracy')
  plt.legend()
  plt.grid(True)
  plt.title('Accuracy vs. No. of epochs')

# %%
def plot_losses(train_losses, test_losses):
  plt.plot(train_losses, label='Train Losses')
  plt.plot(test_losses, label='Test Losses')
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.legend()
  plt.grid(True)
  plt.title('Loss vs. No. of epochs')

# %%
def plot_lrs(train_lrs):
  plt.plot(train_lrs)
  plt.xlabel('Epochs')
  plt.ylabel('Learning rate')
  plt.grid(True)
  plt.title('Learning Rate vs. Epochs')

# %%
plot_accuracies(train_accuracies, test_accuracies)

# %%
plot_losses(train_losses, test_losses)

# %%
plot_lrs(train_lrs)

# %%
print('Saving final model..')
state = {
    'net': model.state_dict(),
    'acc': test_accuracies[-1],
    'epoch': number_of_epochs,
}
if not os.path.isdir('checkpoint'):
  os.mkdir('checkpoint')
torch.save(state, './checkpoint/model_final.pth')
# Out:
# Saving final model..

# %%
import numpy as np
import pickle
from tqdm import tqdm
import pandas as pd

# Function to load CIFAR batch
def load_cifar_batch(file):
    with open(file, 'rb') as fo:
        batch = pickle.load(fo, encoding='bytes')
    return batch

# Specify the folder where the CIFAR-10 batch files are
cifar10_dir = './data/cifar-10-batches-py'

# Load the label names
meta_data_dict = load_cifar_batch(os.path.join(cifar10_dir, 'batches.meta'))
label_names = meta_data_dict[b'label_names']

# Load test data
test_batch = load_cifar_batch('./cifar_test_nolabels.pkl')
test_images = test_batch[b'data'].reshape(-1, 3, 32, 32).transpose(0, 2, 3, 1)

data_statistics = (
    (0.49139968, 0.48215827, 0.44653124),
     (0.24703233, 0.24348505, 0.26158768)
)

# Define transformation for data augmentation
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(*data_statistics, inplace=True)
])

# Apply data augmentation
augmented_test_images = torch.stack([transform(image) for image in test_images])

# Load the trained model
model = ResNet9()

final = torch.load('./checkpoint/ckpt.pth')
# final = torch.load('./checkpoint/model_final.pth')

# Check the keys in the checkpoint dictionary
print(final.keys())

# Assuming the model state dictionary is saved under a different key
# Adjust this according to the actual key in your checkpoint file
model.load_state_dict(final['net'])

model =  model.to(device)
augmented_test_images = augmented_test_images.to(device)

# Evaluate the model on test data
model.eval()
with torch.no_grad():
    outputs = model(augmented_test_images)
_, predicted = torch.max(outputs, 1)

predicted = predicted.to('cpu')

# Display the first 10 test images and predicted labels
plt.figure(figsize=(20, 4))
for i in range(10):
    plt.subplot(1, 10, i+1)
    plt.imshow(test_images[i])
    plt.title(label_names[predicted[i].item()].decode('utf-8'))
    plt.axis('off')
plt.show()

# Save the output in output.csv containing ID, Labels
output_data = {'ID': np.arange(len(predicted)), 'Labels': predicted.numpy()}
output_df = pd.DataFrame(output_data)
output_df.to_csv('output_rugved_resnet9_2.csv', index=False)
# Out:
# dict_keys(['net', 'acc', 'epoch'])

# %%
# Display the second 10 test images and predicted labels
plt.figure(figsize=(20, 4))
for i in range(10, 20):
    plt.subplot(1, 10, i-10+1)
    plt.imshow(test_images[i])
    plt.title(label_names[predicted[i].item()].decode('utf-8'))
    plt.axis('off')
plt.show()

# %%
# Display the second 10 test images and predicted labels
plt.figure(figsize=(20, 4))
for i in range(20, 30):
    plt.subplot(1, 10, i-20+1)
    plt.imshow(test_images[i])
    plt.title(label_names[predicted[i].item()].decode('utf-8'))
    plt.axis('off')
plt.show()

# %%
start_index = 30

# Display the second 10 test images and predicted labels
plt.figure(figsize=(20, 4))
for i in range(start_index, start_index + 10):
    plt.subplot(1, 10, i - start_index + 1)
    plt.imshow(test_images[i])
    plt.title(label_names[predicted[i].item()].decode('utf-8'))
    plt.axis('off')
plt.show()

# %%
start_index = 40

# Display the second 10 test images and predicted labels
plt.figure(figsize=(20, 4))
for i in range(start_index, start_index + 10):
    plt.subplot(1, 10, i - start_index + 1)
    plt.imshow(test_images[i])
    plt.title(label_names[predicted[i].item()].decode('utf-8'))
    plt.axis('off')
plt.show()

# %%
start_index = 100

# Display the second 10 test images and predicted labels
plt.figure(figsize=(20, 4))
for i in range(start_index, start_index + 10):
    plt.subplot(1, 10, i - start_index + 1)
    plt.imshow(test_images[i])
    plt.title(label_names[predicted[i].item()].decode('utf-8'))
    plt.axis('off')
plt.show()

# %%
start_index = 1000

# Display the second 10 test images and predicted labels
plt.figure(figsize=(20, 4))
for i in range(start_index, start_index + 10):
    plt.subplot(1, 10, i - start_index + 1)
    plt.imshow(test_images[i])
    plt.title(label_names[predicted[i].item()].decode('utf-8'))
    plt.axis('off')
plt.show()

# %%
start_index = 2000

# Display the second 10 test images and predicted labels
plt.figure(figsize=(20, 4))
for i in range(start_index, start_index + 10):
    plt.subplot(1, 10, i - start_index + 1)
    plt.imshow(test_images[i])
    plt.title(label_names[predicted[i].item()].decode('utf-8'))
    plt.axis('off')
plt.show()

# %%
start_index = 3000

# Display the second 10 test images and predicted labels
plt.figure(figsize=(20, 4))
for i in range(start_index, start_index + 10):
    plt.subplot(1, 10, i - start_index + 1)
    plt.imshow(test_images[i])
    plt.title(label_names[predicted[i].item()].decode('utf-8'))
    plt.axis('off')
plt.show()

# %%
start_index = 4000

# Display the second 10 test images and predicted labels
plt.figure(figsize=(20, 4))
for i in range(start_index, start_index + 10):
    plt.subplot(1, 10, i - start_index + 1)
    plt.imshow(test_images[i])
    plt.title(label_names[predicted[i].item()].decode('utf-8'))
    plt.axis('off')
plt.show()

# %%
start_index = 5000

# Display the second 10 test images and predicted labels
plt.figure(figsize=(20, 4))
for i in range(start_index, start_index + 10):
    plt.subplot(1, 10, i - start_index + 1)
    plt.imshow(test_images[i])
    plt.title(label_names[predicted[i].item()].decode('utf-8'))
    plt.axis('off')
plt.show()

# %%
start_index = 6000

# Display the second 10 test images and predicted labels
plt.figure(figsize=(20, 4))
for i in range(start_index, start_index + 10):
    plt.subplot(1, 10, i - start_index + 1)
    plt.imshow(test_images[i])
    plt.title(label_names[predicted[i].item()].decode('utf-8'))
    plt.axis('off')
plt.show()

# %%
start_index = 7000

# Display the second 10 test images and predicted labels
plt.figure(figsize=(20, 4))
for i in range(start_index, start_index + 10):
    plt.subplot(1, 10, i - start_index + 1)
    plt.imshow(test_images[i])
    plt.title(label_names[predicted[i].item()].decode('utf-8'))
    plt.axis('off')
plt.show()

# %%
start_index = 8000

# Display the second 10 test images and predicted labels
plt.figure(figsize=(20, 4))
for i in range(start_index, start_index + 10):
    plt.subplot(1, 10, i - start_index + 1)
    plt.imshow(test_images[i])
    plt.title(label_names[predicted[i].item()].decode('utf-8'))
    plt.axis('off')
plt.show()

# %%
start_index = 9000

# Display the second 10 test images and predicted labels
plt.figure(figsize=(20, 4))
for i in range(start_index, start_index + 10):
    plt.subplot(1, 10, i - start_index + 1)
    plt.imshow(test_images[i])
    plt.title(label_names[predicted[i].item()].decode('utf-8'))
    plt.axis('off')
plt.show()

# %% [markdown]
# # ResNet-34 on CIFAR-10 Dataset

# %% [markdown]
# Importing PyTorch and a few Python Libraries

# %%
pip install torch-summary
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch-summary in /home/rrm9598/.local/lib/python3.11/site-packages (1.4.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import sys
import time
import math

import torch
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import random_split, DataLoader
from torchvision.utils import make_grid

import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
import torch.nn.init as init

from torchsummary import summary

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Preparing the dataset
#
# We will be downloading the train and test CIFAR-10 dataset from torchvision. We will normalize and transform the dataset. For the training dataset, we will also be adding Random Crops and Random Horizontal Flips to generalize the model better.

# %%
data_statistics = (
    (0.49139968, 0.48215827, 0.44653124),
     (0.24703233, 0.24348505, 0.26158768)
) # Mean, Standard Deviation of CIFAR-10 dataset channels

train_transforms = transforms.Compose([
    transforms.RandomCrop(32, padding=4, padding_mode='reflect'), # Adding Random Crops
    transforms.RandomHorizontalFlip(), # Adding Random Horizontal Flips
    transforms.ToTensor(), # Channel x Image Height x Image Width
    transforms.Normalize(*data_statistics, inplace=True) # Output in the range of [-1, 1]
])

test_transforms = transforms.Compose([
    transforms.ToTensor(), # Channel x Image Height x Image Width
    transforms.Normalize(*data_statistics, inplace=True) # Output in the range of [-1, 1]
])

# %%
train_dataset = torchvision.datasets.CIFAR10(root='./data/', download=True, train=True, transform=train_transforms)
test_dataset = torchvision.datasets.CIFAR10(root='./data/', download=True, train=False, transform=test_transforms)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# <!-- We will also be splitting the dataset further into training and validation dataset with a validation ratio of `0.2` -->
#
# We will now create data loaders to retreive images in batches. We are selecting the batch size as `128` images for our train loader. And we are selecting the batch size as `100` images for our test loader.
#
# *From PyTorch Documentation: For data loading, passing pin_memory=True to a DataLoader will automatically put the fetched data Tensors in pinned memory, and thus enables faster data transfer to CUDA-enabled GPUs.*

# %%
train_batch_size = 128
test_batch_size = 100

train_dl = DataLoader(train_dataset, train_batch_size, shuffle=True, num_workers=3, pin_memory=True)
test_dl = DataLoader(test_dataset, test_batch_size, shuffle=False, num_workers=3, pin_memory=True)

classes = ('plane', 'car', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck')

# %% [markdown]
# We create the following function to display a batch of images from the dataset. And we also need to denormalize the pixels values to bring them back into the range (0,1).

# %%
def denormalize(images, means, stds):
  means = torch.tensor(means).reshape(1, 3, 1, 1)
  stds = torch.tensor(stds).reshape(1, 3, 1, 1)
  return images * stds + means

def show_batch(dl):
  for images, labels in dl:
    fig, ax = plt.subplots(figsize=(12, 12))
    ax.set_xticks([])
    ax.set_yticks([])
    denorm_images = denormalize(images, *data_statistics)
    ax.imshow(make_grid(denorm_images[:64], 8).permute(1, 2, 0))
    break

# %%
show_batch(train_dl)

# %% [markdown]
# To seamlessly use a GPU, if one is available, we define a couple of helper functions (`get_default_device` & `to_device`) and a helper class `DeviceDataLoader` to move our model & data to the GPU as required.

# %%
def get_default_device():
  # Pick GPU, if available, else CPU
  if torch.cuda.is_available():
    return torch.device('cuda')
  else:
    return torch.device('cpu')

def to_device(data, device):
  # Move tensors to chosen device
  if isinstance(data, (list, tuple)):
    # If the instance is a list/tuple, transfer each element to chosen device
    return [to_device(x, device) for x in data]
  return data.to(device, non_blocking=True)
  # non_blocking=True doesn't block the execution of the host device until transfers complete

class DeviceDataLoader():
  # Wrap a dataloader to move data to a device
  def __init__(self, dl, device):
    self.dl = dl
    self.device = device

  def __iter__(self):
    # Yield a batch of data after moving it to device
    for b in self.dl:
      yield to_device(b, self.device)

  def __len__(self):
    # Number of batches
    return len(self.dl)

# %%
# Get the default device
device = get_default_device()
device
# Out:
# device(type='cuda')

# %%
train_dl = DeviceDataLoader(train_dl, device)
test_dl = DeviceDataLoader(test_dl, device)

# %% [markdown]
# ## Network Architecture

# %% [markdown]
# Testing the models mentioned in the `pytorch-cifar` [GitHub Repository](https://github.com/kuangliu/pytorch-cifar).

# %% [markdown]
# ### ResNet Architecture

# %%
class BasicBlock(nn.Module):
  expansion = 1

  def __init__(self, in_planes, planes, stride=1):
    super(BasicBlock, self).__init__()
    self.conv1 = nn.Conv2d(
        in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
    self.bn1 = nn.BatchNorm2d(planes)
    self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                            stride=1, padding=1, bias=False)
    self.bn2 = nn.BatchNorm2d(planes)

    self.shortcut = nn.Sequential()
    if stride != 1 or in_planes != self.expansion*planes:
      self.shortcut = nn.Sequential(
          nn.Conv2d(in_planes, self.expansion*planes,
                    kernel_size=1, stride=stride, bias=False),
          nn.BatchNorm2d(self.expansion*planes)
      )

  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))
    out = self.bn2(self.conv2(out))
    out += self.shortcut(x)
    out = F.relu(out)
    return out

class ResNet(nn.Module):
  def __init__(self, block, num_blocks, num_classes=10):
    super(ResNet, self).__init__()
    self.in_planes = 64

    self.conv1 = nn.Conv2d(3, 64, kernel_size=3,
                            stride=1, padding=1, bias=False)
    self.bn1 = nn.BatchNorm2d(64)
    self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
    self.layer2 = self._make_layer(block, 96, num_blocks[1], stride=2)
    self.layer3 = self._make_layer(block, 128, num_blocks[2], stride=2)
    self.layer4 = self._make_layer(block, 192, num_blocks[3], stride=2)
    self.linear = nn.Linear(192*block.expansion, num_classes)

  def _make_layer(self, block, planes, num_blocks, stride):
    strides = [stride] + [1]*(num_blocks-1)
    layers = []
    for stride in strides:
      layers.append(block(self.in_planes, planes, stride))
      self.in_planes = planes * block.expansion
    return nn.Sequential(*layers)

  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))
    out = self.layer1(out)
    out = self.layer2(out)
    out = self.layer3(out)
    out = self.layer4(out)
    out = F.avg_pool2d(out, 4)
    out = out.view(out.size(0), -1)
    out = self.linear(out)
    return out

def ResNet18():
  return ResNet(BasicBlock, [2, 2, 2, 2])

def ResNet9():
  return ResNet(BasicBlock, [1, 1, 1, 1])

def ResNet34():
    return ResNet(BasicBlock, [3, 4, 6, 3])

# %% [markdown]
# ### ResNet34

# %%
model = ResNet34()

# %%
model =  model.to(device)
if device == 'cuda':
  model = torch.nn.DataParallel(model)
  cudnn.benchmark = True

# %%
summary(model, input_size=(3, 32, 32))
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            1,728
# ├─BatchNorm2d: 1-2                       128
# ├─Sequential: 1-3                        --
# |    └─BasicBlock: 2-1                   --
# |    |    └─Conv2d: 3-1                  36,864
# |    |    └─BatchNorm2d: 3-2             128
# |    |    └─Conv2d: 3-3                  36,864
# |    |    └─BatchNorm2d: 3-4             128
# |    |    └─Sequential: 3-5              --
# |    └─BasicBlock: 2-2                   --
# |    |    └─Conv2d: 3-6                  36,864
# |    |    └─BatchNorm2d: 3-7             128
# |    |    └─Conv2d: 3-8                  36,864
# |    |    └─BatchNorm2d: 3-9             128
# |    |    └─Sequential: 3-10             --
# |    └─BasicBlock: 2-3                   --
# |    |    └─Conv2d: 3-11                 36,864
# |    |    └─BatchNorm2d: 3-12            128
# |    |    └─Conv2d: 3-13                 36,864
# |    |    └─BatchNorm2d: 3-14            128
# |    |    └─Sequential: 3-15             --
# ├─Sequential: 1-4                        --
# |    └─BasicBlock: 2-4                   --
# |    |    └─Conv2d: 3-16                 55,296
# |    |    └─BatchNorm2d: 3-17            192
# |    |    └─Conv2d: 3-18                 82,944
# |    |    └─BatchNorm2d: 3-19            192
# |    |    └─Sequential: 3-20             6,336
# |    └─BasicBlock: 2-5                   --
# |    |    └─Conv2d: 3-21                 82,944
# |    |    └─BatchNorm2d: 3-22            192
# |    |    └─Conv2d: 3-23                 82,944
# |    |    └─BatchNorm2d: 3-24            192
# |    |    └─Sequential: 3-25             --
# |    └─BasicBlock: 2-6                   --
# |    |    └─Conv2d: 3-26                 82,944
# |    |    └─BatchNorm2d: 3-27            192
# |    |    └─Conv2d: 3-28                 82,944
# |    |    └─BatchNorm2d: 3-29            192
# |    |    └─Sequential: 3-30             --
# |    └─BasicBlock: 2-7                   --
# |    |    └─Conv2d: 3-31                 82,944
# |    |    └─BatchNorm2d: 3-32            192
# |    |    └─Conv2d: 3-33                 82,944
# |    |    └─BatchNorm2d: 3-34            192
# |    |    └─Sequential: 3-35             --
# ├─Sequential: 1-5                        --
# |    └─BasicBlock: 2-8                   --
# |    |    └─Conv2d: 3-36                 110,592
# |    |    └─BatchNorm2d: 3-37            256
# |    |    └─Conv2d: 3-38                 147,456
# |    |    └─BatchNorm2d: 3-39            256
# |    |    └─Sequential: 3-40             12,544
# |    └─BasicBlock: 2-9                   --
# |    |    └─Conv2d: 3-41                 147,456
# |    |    └─BatchNorm2d: 3-42            256
# |    |    └─Conv2d: 3-43                 147,456
# |    |    └─BatchNorm2d: 3-44            256
# |    |    └─Sequential: 3-45             --
# |    └─BasicBlock: 2-10                  --
# |    |    └─Conv2d: 3-46                 147,456
# |    |    └─BatchNorm2d: 3-47            256
# |    |    └─Conv2d: 3-48                 147,456
# |    |    └─BatchNorm2d: 3-49            256
# |    |    └─Sequential: 3-50             --
# |    └─BasicBlock: 2-11                  --
# |    |    └─Conv2d: 3-51                 147,456
# |    |    └─BatchNorm2d: 3-52            256
# |    |    └─Conv2d: 3-53                 147,456
# |    |    └─BatchNorm2d: 3-54            256
# |    |    └─Sequential: 3-55             --
# |    └─BasicBlock: 2-12                  --
# |    |    └─Conv2d: 3-56                 147,456
# |    |    └─BatchNorm2d: 3-57            256
# |    |    └─Conv2d: 3-58                 147,456
# |    |    └─BatchNorm2d: 3-59            256
# |    |    └─Sequential: 3-60             --
# |    └─BasicBlock: 2-13                  --
# |    |    └─Conv2d: 3-61                 147,456
# |    |    └─BatchNorm2d: 3-62            256
# |    |    └─Conv2d: 3-63                 147,456
# |    |    └─BatchNorm2d: 3-64            256
# |    |    └─Sequential: 3-65             --
# ├─Sequential: 1-6                        --
# |    └─BasicBlock: 2-14                  --
# |    |    └─Conv2d: 3-66                 221,184
# |    |    └─BatchNorm2d: 3-67            384
# |    |    └─Conv2d: 3-68                 331,776
# |    |    └─BatchNorm2d: 3-69            384
# |    |    └─Sequential: 3-70             24,960
# |    └─BasicBlock: 2-15                  --
# |    |    └─Conv2d: 3-71                 331,776
# |    |    └─BatchNorm2d: 3-72            384
# |    |    └─Conv2d: 3-73                 331,776
# |    |    └─BatchNorm2d: 3-74            384
# |    |    └─Sequential: 3-75             --
# |    └─BasicBlock: 2-16                  --
# |    |    └─Conv2d: 3-76                 331,776
# |    |    └─BatchNorm2d: 3-77            384
# |    |    └─Conv2d: 3-78                 331,776
# |    |    └─BatchNorm2d: 3-79            384
# |    |    └─Sequential: 3-80             --
# ├─Linear: 1-7                            1,930
# =================================================================
# Total params: 4,525,066
# Trainable params: 4,525,066
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            1,728
# ├─BatchNorm2d: 1-2                       128
# ├─Sequential: 1-3                        --
# |    └─BasicBlock: 2-1                   --
# |    |    └─Conv2d: 3-1                  36,864
# |    |    └─BatchNorm2d: 3-2             128
# |    |    └─Conv2d: 3-3                  36,864
# |    |    └─BatchNorm2d: 3-4             128
# |    |    └─Sequential: 3-5              --
# |    └─BasicBlock: 2-2                   --
# |    |    └─Conv2d: 3-6                  36,864
# |    |    └─BatchNorm2d: 3-7             128
# |    |    └─Conv2d: 3-8                  36,864
# |    |    └─BatchNorm2d: 3-9             128
# |    |    └─Sequential: 3-10             --
# |    └─BasicBlock: 2-3                   --
# |    |    └─Conv2d: 3-11                 36,864
# |    |    └─BatchNorm2d: 3-12            128
# |    |    └─Conv2d: 3-13                 36,864
# |    |    └─BatchNorm2d: 3-14            128
# |    |    └─Sequential: 3-15             --
# ├─Sequential: 1-4                        --
# |    └─BasicBlock: 2-4                   --
# |    |    └─Conv2d: 3-16                 55,296
# |    |    └─BatchNorm2d: 3-17            192
# |    |    └─Conv2d: 3-18                 82,944
# |    |    └─BatchNorm2d: 3-19            192
# |    |    └─Sequential: 3-20             6,336
# |    └─BasicBlock: 2-5                   --
# |    |    └─Conv2d: 3-21                 82,944
# |    |    └─BatchNorm2d: 3-22            192
# |    |    └─Conv2d: 3-23                 82,944
# |    |    └─BatchNorm2d: 3-24            192
# |    |    └─Sequential: 3-25             --
# |    └─BasicBlock: 2-6                   --
# |    |    └─Conv2d: 3-26                 82,944
# |    |    └─BatchNorm2d: 3-27            192
# |    |    └─Conv2d: 3-28                 82,944
# |    |    └─BatchNorm2d: 3-29            192
# |    |    └─Sequential: 3-30             --
# |    └─BasicBlock: 2-7                   --
# |    |    └─Conv2d: 3-31                 82,944
# |    |    └─BatchNorm2d: 3-32            192
# |    |    └─Conv2d: 3-33                 82,944
# |    |    └─BatchNorm2d: 3-34            192
# |    |    └─Sequential: 3-35             --
# ├─Sequential: 1-5                        --
# |    └─BasicBlock: 2-8                   --
# |    |    └─Conv2d: 3-36                 110,592
# |    |    └─BatchNorm2d: 3-37            256
# |    |    └─Conv2d: 3-38                 147,456
# |    |    └─BatchNorm2d: 3-39            256
# |    |    └─Sequential: 3-40             12,544
# |    └─BasicBlock: 2-9                   --
# |    |    └─Conv2d: 3-41                 147,456
# |    |    └─BatchNorm2d: 3-42            256
# |    |    └─Conv2d: 3-43                 147,456
# |    |    └─BatchNorm2d: 3-44            256
# |    |    └─Sequential: 3-45             --
# |    └─BasicBlock: 2-10                  --
# |    |    └─Conv2d: 3-46                 147,456
# |    |    └─BatchNorm2d: 3-47            256
# |    |    └─Conv2d: 3-48                 147,456
# |    |    └─BatchNorm2d: 3-49            256
# |    |    └─Sequential: 3-50             --
# |    └─BasicBlock: 2-11                  --
# |    |    └─Conv2d: 3-51                 147,456
# |    |    └─BatchNorm2d: 3-52            256
# |    |    └─Conv2d: 3-53                 147,456
# |    |    └─BatchNorm2d: 3-54            256
# |    |    └─Sequential: 3-55             --
# |    └─BasicBlock: 2-12                  --
# |    |    └─Conv2d: 3-56                 147,456
# |    |    └─BatchNorm2d: 3-57            256
# |    |    └─Conv2d: 3-58                 147,456
# |    |    └─BatchNorm2d: 3-59            256
# |    |    └─Sequential: 3-60             --
# |    └─BasicBlock: 2-13                  --
# |    |    └─Conv2d: 3-61                 147,456
# |    |    └─BatchNorm2d: 3-62            256
# |    |    └─Conv2d: 3-63                 147,456
# |    |    └─BatchNorm2d: 3-64            256
# |    |    └─Sequential: 3-65             --
# ├─Sequential: 1-6                        --
# |    └─BasicBlock: 2-14                  --
# |    |    └─Conv2d: 3-66                 221,184
# |    |    └─BatchNorm2d: 3-67            384
# |    |    └─Conv2d: 3-68                 331,776
# |    |    └─BatchNorm2d: 3-69            384
# |    |    └─Sequential: 3-70             24,960
# |    └─BasicBlock: 2-15                  --
# |    |    └─Conv2d: 3-71                 331,776
# |    |    └─BatchNorm2d: 3-72            384
# |    |    └─Conv2d: 3-73                 331,776
# |    |    └─BatchNorm2d: 3-74            384
# |    |    └─Sequential: 3-75             --
# |    └─BasicBlock: 2-16                  --
# |    |    └─Conv2d: 3-76                 331,776
# |    |    └─BatchNorm2d: 3-77            384
# |    |    └─Conv2d: 3-78                 331,776
# |    |    └─BatchNorm2d: 3-79            384
# |    |    └─Sequential: 3-80             --
# ├─Linear: 1-7                            1,930
# =================================================================
# Total params: 4,525,066
# Trainable params: 4,525,066
# Non-trainable params: 0
# =================================================================

# %% [markdown]
# ## Model Training

# %%
# Helper Function to Format Time
def format_time(seconds):
  days = int(seconds / 3600/24)
  seconds = seconds - days*3600*24
  hours = int(seconds / 3600)
  seconds = seconds - hours*3600
  minutes = int(seconds / 60)
  seconds = seconds - minutes*60
  secondsf = int(seconds)
  seconds = seconds - secondsf
  millis = int(seconds*1000)

  f = ''
  i = 1
  if days > 0:
    f += str(days) + 'D'
    i += 1
  if hours > 0 and i <= 2:
    f += str(hours) + 'h'
    i += 1
  if minutes > 0 and i <= 2:
    f += str(minutes) + 'm'
    i += 1
  if secondsf > 0 and i <= 2:
    f += str(secondsf) + 's'
    i += 1
  if millis > 0 and i <= 2:
    f += str(millis) + 'ms'
    i += 1
  if f == '':
    f = '0ms'
  return f

# %% [markdown]
# Loss: CrossEntropyLoss
#
# Optimizer: SGD
#
# Learning Rate: 0.1
#
# Momentum: 0.9
#
# Weight Decay: 5e-4
#
# Number of Epochs: 100
#
# Scheduler: CosineAnnealingLR

# %%
lr = 0.1
momentum = 0.9
weight_decay = 5e-4

start_epoch = 1
number_of_epochs = 100
best_acc = 0


criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=lr,
                      momentum=momentum, weight_decay=weight_decay)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=number_of_epochs)

# %%
# Helper Function to get Learning Rate
def get_lr(optimizer):
  for param_group in optimizer.param_groups:
    return param_group['lr']

# %%
def train(epoch):
  print('\nEpoch: %d' % epoch)
  start_time = time.time()

  model.train()
  train_loss = 0
  correct = 0
  total = 0
  for batch_idx, (inputs, targets) in enumerate(train_dl):
    # inputs, targets = inputs.to(device), targets.to(device)
    optimizer.zero_grad()
    outputs = model(inputs)
    loss = criterion(outputs, targets)
    loss.backward()
    optimizer.step()

    train_loss += loss.item()
    _, predicted = outputs.max(1)
    total += targets.size(0)
    correct += predicted.eq(targets).sum().item()

  cur_time = time.time()
  epoch_time = cur_time - start_time
  print(f"Training Time : {format_time(epoch_time)}")

  return train_loss/(batch_idx+1), 100.*correct/total, get_lr(optimizer)

# %%
def test(epoch):
  global best_acc
  model.eval()
  test_loss = 0
  correct = 0
  total = 0
  with torch.no_grad():
    for batch_idx, (inputs, targets) in enumerate(test_dl):
      outputs = model(inputs)
      loss = criterion(outputs, targets)

      test_loss += loss.item()
      _, predicted = outputs.max(1)
      total += targets.size(0)
      correct += predicted.eq(targets).sum().item()
      
  # Save checkpoint.
  acc = 100.*correct/total
  if acc > best_acc:
    print('Saving..')
    state = {
        'net': model.state_dict(),
        'acc': acc,
        'epoch': epoch,
    }
    if not os.path.isdir('checkpoint'):
      os.mkdir('checkpoint')
    torch.save(state, './checkpoint/resnet_34_best.pth')
    best_acc = acc

  return test_loss/(batch_idx+1), 100.*correct/total

# %%
train_losses = []
train_accuracies = []
train_lrs = []

test_losses = []
test_accuracies = []

for epoch in range(start_epoch, start_epoch + number_of_epochs):
  epoch_train_loss, epoch_train_accuracy, epoch_lr = train(epoch)
  train_losses.append(epoch_train_loss)
  train_accuracies.append(epoch_train_accuracy)
  train_lrs.append(epoch_lr)

  epoch_test_loss, epoch_test_accuracy = test(epoch)
  test_losses.append(epoch_test_loss)
  test_accuracies.append(epoch_test_accuracy)

  scheduler.step()
  print(f"Train Loss: {epoch_train_loss:.3f} | Train Accuracy: {epoch_train_accuracy:.3f}% | Test Loss: {epoch_test_loss:.3f} | Test Accuracy: {epoch_test_accuracy:.3f}%")
# Out:
# Epoch: 1
# Training Time : 29s539ms
# Saving..
# Train Loss: 1.862 | Train Accuracy: 32.080% | Test Loss: 1.509 | Test Accuracy: 43.700%
#
# Epoch: 2
# Training Time : 20s596ms
# Saving..
# Train Loss: 1.393 | Train Accuracy: 49.182% | Test Loss: 1.182 | Test Accuracy: 56.940%
#
# Epoch: 3
# Training Time : 20s575ms
# Saving..
# Train Loss: 1.132 | Train Accuracy: 59.470% | Test Loss: 1.081 | Test Accuracy: 61.820%
#
# Epoch: 4
# Training Time : 20s552ms
# Saving..
# Train Loss: 0.954 | Train Accuracy: 66.288% | Test Loss: 0.886 | Test Accuracy: 68.930%
#
# Epoch: 5
# Training Time : 20s580ms
# Train Loss: 0.840 | Train Accuracy: 70.522% | Test Loss: 0.982 | Test Accuracy: 66.400%
#
# Epoch: 6
# Training Time : 20s591ms
# Saving..
# Train Loss: 0.745 | Train Accuracy: 73.836% | Test Loss: 0.766 | Test Accuracy: 73.840%
#
# Epoch: 7
# Training Time : 20s583ms
# Saving..
# Train Loss: 0.665 | Train Accuracy: 76.930% | Test Loss: 0.673 | Test Accuracy: 77.680%
#
# Epoch: 8
# Training Time : 20s592ms
# Train Loss: 0.623 | Train Accuracy: 78.468% | Test Loss: 0.672 | Test Accuracy: 77.350%
#
# Epoch: 9
# Training Time : 20s551ms
# Saving..
# Train Loss: 0.585 | Train Accuracy: 79.910% | Test Loss: 0.555 | Test Accuracy: 80.530%
#
# Epoch: 10
# Training Time : 20s565ms
# Train Loss: 0.551 | Train Accuracy: 80.796% | Test Loss: 0.688 | Test Accuracy: 76.520%
#
# Epoch: 11
# Training Time : 20s551ms
# Saving..
# Train Loss: 0.531 | Train Accuracy: 81.854% | Test Loss: 0.569 | Test Accuracy: 80.850%
#
# Epoch: 12
# Training Time : 20s565ms
# Train Loss: 0.510 | Train Accuracy: 82.554% | Test Loss: 0.583 | Test Accuracy: 80.360%
#
# Epoch: 13
# Training Time : 20s575ms
# Train Loss: 0.487 | Train Accuracy: 83.170% | Test Loss: 0.717 | Test Accuracy: 75.870%
#
# Epoch: 14
# Training Time : 20s556ms
# Train Loss: 0.478 | Train Accuracy: 83.712% | Test Loss: 0.595 | Test Accuracy: 79.990%
#
# Epoch: 15
# Training Time : 20s569ms
# Train Loss: 0.459 | Train Accuracy: 84.036% | Test Loss: 0.580 | Test Accuracy: 80.620%
#
# Epoch: 16
# Training Time : 20s614ms
# Saving..
# Train Loss: 0.449 | Train Accuracy: 84.650% | Test Loss: 0.569 | Test Accuracy: 81.030%
#
# Epoch: 17
# Training Time : 20s575ms
# Saving..
# Train Loss: 0.434 | Train Accuracy: 85.300% | Test Loss: 0.500 | Test Accuracy: 83.120%
#
# Epoch: 18
# Training Time : 20s558ms
# Train Loss: 0.427 | Train Accuracy: 85.400% | Test Loss: 0.520 | Test Accuracy: 82.190%
#
# Epoch: 19
# Training Time : 20s590ms
# Train Loss: 0.413 | Train Accuracy: 85.880% | Test Loss: 0.511 | Test Accuracy: 82.630%
#
# Epoch: 20
# Training Time : 20s568ms
# Saving..
# Train Loss: 0.409 | Train Accuracy: 85.950% | Test Loss: 0.489 | Test Accuracy: 83.350%
#
# Epoch: 21
# Training Time : 20s577ms
# Train Loss: 0.397 | Train Accuracy: 86.516% | Test Loss: 0.540 | Test Accuracy: 82.420%
#
# Epoch: 22
# Training Time : 20s561ms
# Train Loss: 0.392 | Train Accuracy: 86.556% | Test Loss: 0.513 | Test Accuracy: 82.360%
#
# Epoch: 23
# Training Time : 20s565ms
# Train Loss: 0.388 | Train Accuracy: 86.802% | Test Loss: 0.511 | Test Accuracy: 82.340%
#
# Epoch: 24
# Training Time : 20s571ms
# Train Loss: 0.382 | Train Accuracy: 86.962% | Test Loss: 0.535 | Test Accuracy: 82.870%
#
# Epoch: 25
# Training Time : 20s546ms
# Train Loss: 0.372 | Train Accuracy: 87.298% | Test Loss: 0.626 | Test Accuracy: 79.850%
#
# Epoch: 26
# Training Time : 20s576ms
# Saving..
# Train Loss: 0.365 | Train Accuracy: 87.578% | Test Loss: 0.459 | Test Accuracy: 84.340%
#
# Epoch: 27
# Training Time : 20s574ms
# Train Loss: 0.363 | Train Accuracy: 87.710% | Test Loss: 0.592 | Test Accuracy: 80.240%
#
# Epoch: 28
# Training Time : 20s569ms
# Train Loss: 0.353 | Train Accuracy: 87.858% | Test Loss: 0.491 | Test Accuracy: 83.530%
#
# Epoch: 29
# Training Time : 20s570ms
# Train Loss: 0.357 | Train Accuracy: 87.776% | Test Loss: 0.603 | Test Accuracy: 80.270%
#
# Epoch: 30
# Training Time : 20s574ms
# Train Loss: 0.343 | Train Accuracy: 88.164% | Test Loss: 0.486 | Test Accuracy: 83.480%
#
# Epoch: 31
# Training Time : 20s566ms
# Saving..
# Train Loss: 0.340 | Train Accuracy: 88.324% | Test Loss: 0.450 | Test Accuracy: 85.440%
#
# Epoch: 32
# Training Time : 20s625ms
# Train Loss: 0.336 | Train Accuracy: 88.396% | Test Loss: 0.539 | Test Accuracy: 82.280%
#
# Epoch: 33
# Training Time : 20s551ms
# Train Loss: 0.326 | Train Accuracy: 88.834% | Test Loss: 0.592 | Test Accuracy: 80.720%
#
# Epoch: 34
# Training Time : 20s555ms
# Train Loss: 0.322 | Train Accuracy: 89.054% | Test Loss: 0.462 | Test Accuracy: 84.900%
#
# Epoch: 35
# Training Time : 20s571ms
# Train Loss: 0.321 | Train Accuracy: 88.978% | Test Loss: 0.557 | Test Accuracy: 82.290%
#
# Epoch: 36
# Training Time : 20s551ms
# Train Loss: 0.316 | Train Accuracy: 89.196% | Test Loss: 0.539 | Test Accuracy: 82.670%
#
# Epoch: 37
# Training Time : 20s543ms
# Train Loss: 0.304 | Train Accuracy: 89.634% | Test Loss: 0.510 | Test Accuracy: 83.500%
#
# Epoch: 38
# Training Time : 20s568ms
# Saving..
# Train Loss: 0.303 | Train Accuracy: 89.682% | Test Loss: 0.394 | Test Accuracy: 86.360%
#
# Epoch: 39
# Training Time : 20s589ms
# Train Loss: 0.303 | Train Accuracy: 89.582% | Test Loss: 0.487 | Test Accuracy: 83.990%
#
# Epoch: 40
# Training Time : 20s546ms
# Saving..
# Train Loss: 0.294 | Train Accuracy: 89.964% | Test Loss: 0.390 | Test Accuracy: 87.020%
#
# Epoch: 41
# Training Time : 20s562ms
# Saving..
# Train Loss: 0.286 | Train Accuracy: 90.150% | Test Loss: 0.387 | Test Accuracy: 87.350%
#
# Epoch: 42
# Training Time : 20s576ms
# Train Loss: 0.278 | Train Accuracy: 90.510% | Test Loss: 0.464 | Test Accuracy: 85.240%
#
# Epoch: 43
# Training Time : 20s604ms
# Train Loss: 0.277 | Train Accuracy: 90.452% | Test Loss: 0.516 | Test Accuracy: 84.330%
#
# Epoch: 44
# Training Time : 20s544ms
# Train Loss: 0.271 | Train Accuracy: 90.748% | Test Loss: 0.677 | Test Accuracy: 78.990%
#
# Epoch: 45
# Training Time : 20s564ms
# Train Loss: 0.269 | Train Accuracy: 90.904% | Test Loss: 0.484 | Test Accuracy: 84.280%
#
# Epoch: 46
# Training Time : 20s555ms
# Saving..
# Train Loss: 0.264 | Train Accuracy: 91.040% | Test Loss: 0.341 | Test Accuracy: 88.500%
#
# Epoch: 47
# Training Time : 20s531ms
# Train Loss: 0.256 | Train Accuracy: 91.204% | Test Loss: 0.393 | Test Accuracy: 87.410%
#
# Epoch: 48
# Training Time : 20s550ms
# Train Loss: 0.253 | Train Accuracy: 91.332% | Test Loss: 0.497 | Test Accuracy: 83.790%
#
# Epoch: 49
# Training Time : 20s571ms
# Saving..
# Train Loss: 0.247 | Train Accuracy: 91.448% | Test Loss: 0.311 | Test Accuracy: 89.380%
#
# Epoch: 50
# Training Time : 20s563ms
# Train Loss: 0.234 | Train Accuracy: 91.954% | Test Loss: 0.390 | Test Accuracy: 87.240%
#
# Epoch: 51
# Training Time : 20s557ms
# Train Loss: 0.235 | Train Accuracy: 91.964% | Test Loss: 0.324 | Test Accuracy: 88.870%
#
# Epoch: 52
# Training Time : 20s530ms
# Train Loss: 0.223 | Train Accuracy: 92.344% | Test Loss: 0.385 | Test Accuracy: 87.500%
#
# Epoch: 53
# Training Time : 20s549ms
# Train Loss: 0.227 | Train Accuracy: 92.240% | Test Loss: 0.387 | Test Accuracy: 87.440%
#
# Epoch: 54
# Training Time : 20s540ms
# Saving..
# Train Loss: 0.213 | Train Accuracy: 92.732% | Test Loss: 0.321 | Test Accuracy: 89.720%
#
# Epoch: 55
# Training Time : 20s575ms
# Train Loss: 0.213 | Train Accuracy: 92.678% | Test Loss: 0.331 | Test Accuracy: 89.270%
#
# Epoch: 56
# Training Time : 20s543ms
# Train Loss: 0.208 | Train Accuracy: 92.936% | Test Loss: 0.310 | Test Accuracy: 89.660%
#
# Epoch: 57
# Training Time : 20s537ms
# Train Loss: 0.195 | Train Accuracy: 93.312% | Test Loss: 0.409 | Test Accuracy: 86.980%
#
# Epoch: 58
# Training Time : 20s562ms
# Train Loss: 0.188 | Train Accuracy: 93.574% | Test Loss: 0.339 | Test Accuracy: 89.140%
#
# Epoch: 59
# Training Time : 20s530ms
# Saving..
# Train Loss: 0.182 | Train Accuracy: 93.714% | Test Loss: 0.306 | Test Accuracy: 90.280%
#
# Epoch: 60
# Training Time : 20s543ms
# Saving..
# Train Loss: 0.179 | Train Accuracy: 93.948% | Test Loss: 0.293 | Test Accuracy: 90.400%
#
# Epoch: 61
# Training Time : 20s565ms
# Saving..
# Train Loss: 0.173 | Train Accuracy: 94.170% | Test Loss: 0.259 | Test Accuracy: 91.370%
#
# Epoch: 62
# Training Time : 20s540ms
# Train Loss: 0.170 | Train Accuracy: 94.138% | Test Loss: 0.363 | Test Accuracy: 88.280%
#
# Epoch: 63
# Training Time : 20s529ms
# Train Loss: 0.156 | Train Accuracy: 94.750% | Test Loss: 0.343 | Test Accuracy: 88.820%
#
# Epoch: 64
# Training Time : 20s583ms
# Train Loss: 0.152 | Train Accuracy: 94.802% | Test Loss: 0.312 | Test Accuracy: 90.150%
#
# Epoch: 65
# Training Time : 20s560ms
# Train Loss: 0.147 | Train Accuracy: 94.984% | Test Loss: 0.274 | Test Accuracy: 91.080%
#
# Epoch: 66
# Training Time : 20s525ms
# Train Loss: 0.140 | Train Accuracy: 95.120% | Test Loss: 0.270 | Test Accuracy: 90.950%
#
# Epoch: 67
# Training Time : 20s542ms
# Train Loss: 0.131 | Train Accuracy: 95.504% | Test Loss: 0.268 | Test Accuracy: 91.200%
#
# Epoch: 68
# Training Time : 20s562ms
# Train Loss: 0.128 | Train Accuracy: 95.570% | Test Loss: 0.287 | Test Accuracy: 91.010%
#
# Epoch: 69
# Training Time : 20s533ms
# Train Loss: 0.119 | Train Accuracy: 95.946% | Test Loss: 0.295 | Test Accuracy: 90.760%
#
# Epoch: 70
# Training Time : 20s547ms
# Train Loss: 0.110 | Train Accuracy: 96.208% | Test Loss: 0.274 | Test Accuracy: 91.280%
#
# Epoch: 71
# Training Time : 20s570ms
# Saving..
# Train Loss: 0.100 | Train Accuracy: 96.496% | Test Loss: 0.270 | Test Accuracy: 91.790%
#
# Epoch: 72
# Training Time : 20s548ms
# Saving..
# Train Loss: 0.098 | Train Accuracy: 96.674% | Test Loss: 0.267 | Test Accuracy: 91.810%
#
# Epoch: 73
# Training Time : 20s566ms
# Train Loss: 0.087 | Train Accuracy: 97.028% | Test Loss: 0.272 | Test Accuracy: 91.480%
#
# Epoch: 74
# Training Time : 20s556ms
# Train Loss: 0.083 | Train Accuracy: 97.216% | Test Loss: 0.262 | Test Accuracy: 91.730%
#
# Epoch: 75
# Training Time : 20s544ms
# Saving..
# Train Loss: 0.077 | Train Accuracy: 97.362% | Test Loss: 0.259 | Test Accuracy: 92.010%
#
# Epoch: 76
# Training Time : 20s556ms
# Saving..
# Train Loss: 0.067 | Train Accuracy: 97.748% | Test Loss: 0.262 | Test Accuracy: 92.540%
#
# Epoch: 77
# Training Time : 20s563ms
# Saving..
# Train Loss: 0.060 | Train Accuracy: 97.946% | Test Loss: 0.234 | Test Accuracy: 93.130%
#
# Epoch: 78
# Training Time : 20s558ms
# Train Loss: 0.056 | Train Accuracy: 98.082% | Test Loss: 0.238 | Test Accuracy: 92.910%
#
# Epoch: 79
# Training Time : 20s578ms
# Train Loss: 0.052 | Train Accuracy: 98.216% | Test Loss: 0.238 | Test Accuracy: 93.080%
#
# Epoch: 80
# Training Time : 20s564ms
# Train Loss: 0.043 | Train Accuracy: 98.550% | Test Loss: 0.250 | Test Accuracy: 93.110%
#
# Epoch: 81
# Training Time : 20s525ms
# Saving..
# Train Loss: 0.040 | Train Accuracy: 98.688% | Test Loss: 0.236 | Test Accuracy: 93.470%
#
# Epoch: 82
# Training Time : 20s562ms
# Train Loss: 0.032 | Train Accuracy: 98.960% | Test Loss: 0.244 | Test Accuracy: 93.440%
#
# Epoch: 83
# Training Time : 20s543ms
# Saving..
# Train Loss: 0.027 | Train Accuracy: 99.128% | Test Loss: 0.220 | Test Accuracy: 94.020%
#
# Epoch: 84
# Training Time : 20s565ms
# Saving..
# Train Loss: 0.023 | Train Accuracy: 99.258% | Test Loss: 0.220 | Test Accuracy: 94.140%
#
# Epoch: 85
# Training Time : 20s563ms
# Train Loss: 0.018 | Train Accuracy: 99.460% | Test Loss: 0.238 | Test Accuracy: 93.860%
#
# Epoch: 86
# Training Time : 20s553ms
# Saving..
# Train Loss: 0.015 | Train Accuracy: 99.506% | Test Loss: 0.223 | Test Accuracy: 94.260%
#
# Epoch: 87
# Training Time : 20s547ms
# Saving..
# Train Loss: 0.012 | Train Accuracy: 99.620% | Test Loss: 0.226 | Test Accuracy: 94.380%
#
# Epoch: 88
# Training Time : 20s583ms
# Saving..
# Train Loss: 0.010 | Train Accuracy: 99.710% | Test Loss: 0.227 | Test Accuracy: 94.510%
#
# Epoch: 89
# Training Time : 20s548ms
# Saving..
# Train Loss: 0.008 | Train Accuracy: 99.778% | Test Loss: 0.212 | Test Accuracy: 94.720%
#
# Epoch: 90
# Training Time : 20s542ms
# Saving..
# Train Loss: 0.006 | Train Accuracy: 99.830% | Test Loss: 0.211 | Test Accuracy: 94.930%
#
# Epoch: 91
# Training Time : 20s551ms
# Train Loss: 0.006 | Train Accuracy: 99.866% | Test Loss: 0.213 | Test Accuracy: 94.910%
#
# Epoch: 92
# Training Time : 20s546ms
# Train Loss: 0.005 | Train Accuracy: 99.890% | Test Loss: 0.216 | Test Accuracy: 94.870%
#
# Epoch: 93
# Training Time : 20s573ms
# Saving..
# Train Loss: 0.005 | Train Accuracy: 99.890% | Test Loss: 0.215 | Test Accuracy: 94.970%
#
# Epoch: 94
# Training Time : 20s556ms
# Saving..
# Train Loss: 0.004 | Train Accuracy: 99.922% | Test Loss: 0.213 | Test Accuracy: 94.980%
#
# Epoch: 95
# Training Time : 20s563ms
# Saving..
# Train Loss: 0.004 | Train Accuracy: 99.922% | Test Loss: 0.212 | Test Accuracy: 95.030%
#
# Epoch: 96
# Training Time : 20s606ms
# Train Loss: 0.004 | Train Accuracy: 99.916% | Test Loss: 0.209 | Test Accuracy: 95.010%
#
# Epoch: 97
# Training Time : 20s580ms
# Saving..
# Train Loss: 0.003 | Train Accuracy: 99.934% | Test Loss: 0.209 | Test Accuracy: 95.100%
#
# Epoch: 98
# Training Time : 20s557ms
# Train Loss: 0.003 | Train Accuracy: 99.950% | Test Loss: 0.207 | Test Accuracy: 94.990%
#
# Epoch: 99
# Training Time : 20s539ms
# Train Loss: 0.003 | Train Accuracy: 99.944% | Test Loss: 0.211 | Test Accuracy: 95.030%
#
# Epoch: 100
# Training Time : 20s555ms
# Train Loss: 0.003 | Train Accuracy: 99.956% | Test Loss: 0.210 | Test Accuracy: 94.920%

# %%
print(f"Best Accuracy: {best_acc:.3f}%")
# Out:
# Best Accuracy: 95.100%

# %%
def plot_accuracies(train_accuracies, test_accuracies):
  plt.plot(train_accuracies, label='Train Accuracy')
  plt.plot(test_accuracies, label='Test Accuracy')
  plt.xlabel('Epochs')
  plt.ylabel('Accuracy')
  plt.legend()
  plt.grid(True)
  plt.title('Accuracy vs. No. of epochs')

# %%
def plot_losses(train_losses, test_losses):
  plt.plot(train_losses, label='Train Losses')
  plt.plot(test_losses, label='Test Losses')
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.legend()
  plt.grid(True)
  plt.title('Loss vs. No. of epochs')

# %%
def plot_lrs(train_lrs):
  plt.plot(train_lrs)
  plt.xlabel('Epochs')
  plt.ylabel('Learning rate')
  plt.grid(True)
  plt.title('Learning Rate vs. Epochs')

# %%
plot_accuracies(train_accuracies, test_accuracies)

# %%
plot_losses(train_losses, test_losses)

# %%
plot_lrs(train_lrs)

# %%
print('Saving final model..')
state = {
    'net': model.state_dict(),
    'acc': test_accuracies[-1],
    'epoch': number_of_epochs,
    'best_acc' : best_acc,
    'train_acc' : train_accuracies,
    'test_acc' : test_accuracies,
    'train_loss' : train_losses,
    'test_loss' : test_losses,
    'lr' : train_lrs
}
if not os.path.isdir('checkpoint'):
  os.mkdir('checkpoint')
torch.save(state, './checkpoint/resnet_34_final.pth')
# Out:
# Saving final model..

# %%
import numpy as np
import pickle
import pandas as pd

# Function to load CIFAR batch
def load_cifar_batch(file):
    with open(file, 'rb') as fo:
        batch = pickle.load(fo, encoding='bytes')
    return batch

# Specify the folder where the CIFAR-10 batch files are
cifar10_dir = './data/cifar-10-batches-py'

# Load the label names
meta_data_dict = load_cifar_batch(os.path.join(cifar10_dir, 'batches.meta'))
label_names = meta_data_dict[b'label_names']

# Load test data
test_batch = load_cifar_batch('./cifar_test_nolabels.pkl')
test_images = test_batch[b'data'].reshape(-1, 3, 32, 32).transpose(0, 2, 3, 1)

data_statistics = (
    (0.49139968, 0.48215827, 0.44653124),
     (0.24703233, 0.24348505, 0.26158768)
)

# Define transformation for data augmentation
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(*data_statistics, inplace=True)
])

# Apply data augmentation
augmented_test_images = torch.stack([transform(image) for image in test_images])

# Load the trained model
model = ResNet34()

checkpoint = torch.load('./checkpoint/resnet_34_best.pth')

# Check the keys in the checkpoint dictionary
print(checkpoint.keys())

# Assuming the model state dictionary is saved under a different key
# Adjust this according to the actual key in your checkpoint file
model.load_state_dict(checkpoint['net'])

model =  model.to(device)
augmented_test_images = augmented_test_images.to(device)

# Evaluate the model on test data
model.eval()
with torch.no_grad():
    outputs = model(augmented_test_images)
_, predicted = torch.max(outputs, 1)

predicted = predicted.to('cpu')

# Display the first 10 test images and predicted labels
plt.figure(figsize=(20, 4))
for i in range(10):
    plt.subplot(1, 10, i+1)
    plt.imshow(test_images[i])
    plt.title(label_names[predicted[i].item()].decode('utf-8'))
    plt.axis('off')
plt.show()

# Save the output in output.csv containing ID, Labels
output_data = {'ID': np.arange(len(predicted)), 'Labels': predicted.numpy()}
output_df = pd.DataFrame(output_data)
output_df.to_csv('resnet_34_best_output.csv', index=False)
# Out:
# dict_keys(['net', 'acc', 'epoch'])

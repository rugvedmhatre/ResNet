# %% [markdown]
# # ResNet-18 on CIFAR-10 Dataset

# %% [markdown]
# Importing PyTorch and a few Python Libraries

# %%
import os
import sys
import time
import math

import torch
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import random_split, DataLoader
from torchvision.utils import make_grid

import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
import torch.nn.init as init

from torchsummary import summary

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Preparing the dataset
#
# We will be downloading the train and test CIFAR-10 dataset from torchvision. We will normalize and transform the dataset. For the training dataset, we will also be adding Random Crops and Random Horizontal Flips to generalize the model better.

# %%
data_statistics = (
    (0.49139968, 0.48215827, 0.44653124),
     (0.24703233, 0.24348505, 0.26158768)
) # Mean, Standard Deviation of CIFAR-10 dataset channels

train_transforms = transforms.Compose([
    transforms.RandomCrop(32, padding=4, padding_mode='reflect'), # Adding Random Crops
    transforms.RandomHorizontalFlip(), # Adding Random Horizontal Flips
    transforms.ToTensor(), # Channel x Image Height x Image Width
    transforms.Normalize(*data_statistics, inplace=True) # Output in the range of [-1, 1]
])

test_transforms = transforms.Compose([
    transforms.ToTensor(), # Channel x Image Height x Image Width
    transforms.Normalize(*data_statistics, inplace=True) # Output in the range of [-1, 1]
])

# %%
train_dataset = torchvision.datasets.CIFAR10(root='./data/', download=True, train=True, transform=train_transforms)
test_dataset = torchvision.datasets.CIFAR10(root='./data/', download=True, train=False, transform=test_transforms)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# <!-- We will also be splitting the dataset further into training and validation dataset with a validation ratio of `0.2` -->
#
# We will now create data loaders to retreive images in batches. We are selecting the batch size as `128` images for our train loader. And we are selecting the batch size as `100` images for our test loader.
#
# *From PyTorch Documentation: For data loading, passing pin_memory=True to a DataLoader will automatically put the fetched data Tensors in pinned memory, and thus enables faster data transfer to CUDA-enabled GPUs.*

# %%
# validation_ratio = 0.2
# train_dataset, validation_dataset = random_split(
#     dataset,
#     [int((1 - validation_ratio) * len(dataset)), int(validation_ratio * len(dataset))]
# )

train_batch_size = 128
test_batch_size = 100

train_dl = DataLoader(train_dataset, train_batch_size, shuffle=True, num_workers=2, pin_memory=True)
# validation_dl = DataLoader(validation_dataset, batch_size, shuffle=True, num_workers=3, pin_memory=True)
test_dl = DataLoader(test_dataset, test_batch_size, shuffle=False, num_workers=2, pin_memory=True)

classes = ('plane', 'car', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck')

# %% [markdown]
# We create the following function to display a batch of images from the dataset. And we also need to denormalize the pixels values to bring them back into the range (0,1).

# %%
def denormalize(images, means, stds):
  means = torch.tensor(means).reshape(1, 3, 1, 1)
  stds = torch.tensor(stds).reshape(1, 3, 1, 1)
  return images * stds + means

def show_batch(dl):
  for images, labels in dl:
    fig, ax = plt.subplots(figsize=(12, 12))
    ax.set_xticks([])
    ax.set_yticks([])
    denorm_images = denormalize(images, *data_statistics)
    ax.imshow(make_grid(denorm_images[:64], 8).permute(1, 2, 0))
    break

# %%
show_batch(train_dl)

# %% [markdown]
# To seamlessly use a GPU, if one is available, we define a couple of helper functions (`get_default_device` & `to_device`) and a helper class `DeviceDataLoader` to move our model & data to the GPU as required.

# %%
def get_default_device():
  # Pick GPU, if available, else CPU
  if torch.cuda.is_available():
    return torch.device('cuda')
  else:
    return torch.device('cpu')

def to_device(data, device):
  # Move tensors to chosen device
  if isinstance(data, (list, tuple)):
    # If the instance is a list/tuple, transfer each element to chosen device
    return [to_device(x, device) for x in data]
  return data.to(device, non_blocking=True)
  # non_blocking=True doesn't block the execution of the host device until transfers complete

class DeviceDataLoader():
  # Wrap a dataloader to move data to a device
  def __init__(self, dl, device):
    self.dl = dl
    self.device = device

  def __iter__(self):
    # Yield a batch of data after moving it to device
    for b in self.dl:
      yield to_device(b, self.device)

  def __len__(self):
    # Number of batches
    return len(self.dl)

# %%
# Get the default device
device = get_default_device()
device
# Out:
# device(type='cuda')

# %%
train_dl = DeviceDataLoader(train_dl, device)
# validation_dl = DeviceDataLoader(validation_dl, device)
test_dl = DeviceDataLoader(test_dl, device)

# %% [markdown]
# ## Network Architecture

# %% [markdown]
# Testing the models mentioned in the `pytorch-cifar` [GitHub Repository](https://github.com/kuangliu/pytorch-cifar).

# %% [markdown]
# ### PreActResNet18

# %%
class PreActBlock(nn.Module):
  '''Pre-activation version of the BasicBlock.'''
  expansion = 1

  def __init__(self, in_planes, planes, stride=1):
    super(PreActBlock, self).__init__()
    self.bn1 = nn.BatchNorm2d(in_planes)
    self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
    self.bn2 = nn.BatchNorm2d(planes)
    self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)

    if stride != 1 or in_planes != self.expansion*planes:
      self.shortcut = nn.Sequential(
          nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False)
      )

  def forward(self, x):
    out = F.relu(self.bn1(x))
    shortcut = self.shortcut(out) if hasattr(self, 'shortcut') else x
    out = self.conv1(out)
    out = self.conv2(F.relu(self.bn2(out)))
    out += shortcut
    return out

class PreActResNet(nn.Module):
  def __init__(self, block, num_blocks, num_classes=10):
    super(PreActResNet, self).__init__()
    self.in_planes = 64

    self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
    self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
    self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
    self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
    self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
    self.linear = nn.Linear(512*block.expansion, num_classes)

  def _make_layer(self, block, planes, num_blocks, stride):
    strides = [stride] + [1]*(num_blocks-1)
    layers = []
    for stride in strides:
        layers.append(block(self.in_planes, planes, stride))
        self.in_planes = planes * block.expansion
    return nn.Sequential(*layers)

  def forward(self, x):
    out = self.conv1(x)
    out = self.layer1(out)
    out = self.layer2(out)
    out = self.layer3(out)
    out = self.layer4(out)
    out = F.avg_pool2d(out, 4)
    out = out.view(out.size(0), -1)
    out = self.linear(out)
    return out

def PreActResNet18():
  return PreActResNet(PreActBlock, [2,2,2,2])

# %%
# model = PreActResNet18()

# %% [markdown]
# The number of parameters is `11,171,146`, which exceeds the 5 million limit.

# %% [markdown]
# ### ResNet18

# %%
class BasicBlock(nn.Module):
  expansion = 1

  def __init__(self, in_planes, planes, stride=1):
    super(BasicBlock, self).__init__()
    self.conv1 = nn.Conv2d(
        in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
    self.bn1 = nn.BatchNorm2d(planes)
    self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                            stride=1, padding=1, bias=False)
    self.bn2 = nn.BatchNorm2d(planes)
    self.bn2 = nn.Dropout(p = 0.2)

    self.shortcut = nn.Sequential()
    if stride != 1 or in_planes != self.expansion*planes:
      self.shortcut = nn.Sequential(
          nn.Conv2d(in_planes, self.expansion*planes,
                    kernel_size=1, stride=stride, bias=False),
          nn.BatchNorm2d(self.expansion*planes)
      )

  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))
    out = self.bn2(self.conv2(out))
    out += self.shortcut(x)
    out = F.relu(out)
    return out

class ResNet(nn.Module):
  def __init__(self, block, num_blocks, num_classes=10):
    super(ResNet, self).__init__()
    self.in_planes = 64

    self.conv1 = nn.Conv2d(3, 64, kernel_size=3,
                            stride=1, padding=1, bias=False)
    self.bn1 = nn.BatchNorm2d(64)
    self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
    self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
    self.layer3 = self._make_layer(block, 192, num_blocks[2], stride=2)
    self.layer4 = self._make_layer(block, 256, num_blocks[3], stride=2)
    self.linear = nn.Linear(256*block.expansion, num_classes)

  def _make_layer(self, block, planes, num_blocks, stride):
    strides = [stride] + [1]*(num_blocks-1)
    layers = []
    for stride in strides:
      layers.append(block(self.in_planes, planes, stride))
      self.in_planes = planes * block.expansion
    return nn.Sequential(*layers)

  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))
    out = self.layer1(out)
    out = self.layer2(out)
    out = self.layer3(out)
    out = self.layer4(out)
    out = F.avg_pool2d(out, 4)
    out = out.view(out.size(0), -1)
    out = self.linear(out)
    return out

def ResNet18():
  return ResNet(BasicBlock, [2, 3, 2, 2])

# %%
model = ResNet18()

# %% [markdown]
# The number of parameters is `11,173,962`, which exceeds the 5 million limit.

# %% [markdown]
# ### ResNet9

# %%
def ResNet9():
  return ResNet(BasicBlock, [1, 1, 1, 1])

# %%
# model = ResNet9()

# %% [markdown]
# ### PreActResNet9

# %%
def PreActResNet9():
  return PreActResNet(PreActBlock, [1,1,1,1])

# %%
# model = PreActResNet9()

# %%
model =  model.to(device)
if device == 'cuda':
  model = torch.nn.DataParallel(model)
  cudnn.benchmark = True

# %%
summary(model, input_size=(3, 32, 32))
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            1,728
# ├─BatchNorm2d: 1-2                       128
# ├─Sequential: 1-3                        --
# |    └─BasicBlock: 2-1                   --
# |    |    └─Conv2d: 3-1                  36,864
# |    |    └─BatchNorm2d: 3-2             128
# |    |    └─Conv2d: 3-3                  36,864
# |    |    └─Dropout: 3-4                 --
# |    |    └─Sequential: 3-5              --
# |    └─BasicBlock: 2-2                   --
# |    |    └─Conv2d: 3-6                  36,864
# |    |    └─BatchNorm2d: 3-7             128
# |    |    └─Conv2d: 3-8                  36,864
# |    |    └─Dropout: 3-9                 --
# |    |    └─Sequential: 3-10             --
# ├─Sequential: 1-4                        --
# |    └─BasicBlock: 2-3                   --
# |    |    └─Conv2d: 3-11                 73,728
# |    |    └─BatchNorm2d: 3-12            256
# |    |    └─Conv2d: 3-13                 147,456
# |    |    └─Dropout: 3-14                --
# |    |    └─Sequential: 3-15             8,448
# |    └─BasicBlock: 2-4                   --
# |    |    └─Conv2d: 3-16                 147,456
# |    |    └─BatchNorm2d: 3-17            256
# |    |    └─Conv2d: 3-18                 147,456
# |    |    └─Dropout: 3-19                --
# |    |    └─Sequential: 3-20             --
# |    └─BasicBlock: 2-5                   --
# |    |    └─Conv2d: 3-21                 147,456
# |    |    └─BatchNorm2d: 3-22            256
# |    |    └─Conv2d: 3-23                 147,456
# |    |    └─Dropout: 3-24                --
# |    |    └─Sequential: 3-25             --
# ├─Sequential: 1-5                        --
# |    └─BasicBlock: 2-6                   --
# |    |    └─Conv2d: 3-26                 221,184
# |    |    └─BatchNorm2d: 3-27            384
# |    |    └─Conv2d: 3-28                 331,776
# |    |    └─Dropout: 3-29                --
# |    |    └─Sequential: 3-30             24,960
# |    └─BasicBlock: 2-7                   --
# |    |    └─Conv2d: 3-31                 331,776
# |    |    └─BatchNorm2d: 3-32            384
# |    |    └─Conv2d: 3-33                 331,776
# |    |    └─Dropout: 3-34                --
# |    |    └─Sequential: 3-35             --
# ├─Sequential: 1-6                        --
# |    └─BasicBlock: 2-8                   --
# |    |    └─Conv2d: 3-36                 442,368
# |    |    └─BatchNorm2d: 3-37            512
# |    |    └─Conv2d: 3-38                 589,824
# |    |    └─Dropout: 3-39                --
# |    |    └─Sequential: 3-40             49,664
# |    └─BasicBlock: 2-9                   --
# |    |    └─Conv2d: 3-41                 589,824
# |    |    └─BatchNorm2d: 3-42            512
# |    |    └─Conv2d: 3-43                 589,824
# |    |    └─Dropout: 3-44                --
# |    |    └─Sequential: 3-45             --
# ├─Linear: 1-7                            2,570
# =================================================================
# Total params: 4,477,130
# Trainable params: 4,477,130
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            1,728
# ├─BatchNorm2d: 1-2                       128
# ├─Sequential: 1-3                        --
# |    └─BasicBlock: 2-1                   --
# |    |    └─Conv2d: 3-1                  36,864
# |    |    └─BatchNorm2d: 3-2             128
# |    |    └─Conv2d: 3-3                  36,864
# |    |    └─Dropout: 3-4                 --
# |    |    └─Sequential: 3-5              --
# |    └─BasicBlock: 2-2                   --
# |    |    └─Conv2d: 3-6                  36,864
# |    |    └─BatchNorm2d: 3-7             128
# |    |    └─Conv2d: 3-8                  36,864
# |    |    └─Dropout: 3-9                 --
# |    |    └─Sequential: 3-10             --
# ├─Sequential: 1-4                        --
# |    └─BasicBlock: 2-3                   --
# |    |    └─Conv2d: 3-11                 73,728
# |    |    └─BatchNorm2d: 3-12            256
# |    |    └─Conv2d: 3-13                 147,456
# |    |    └─Dropout: 3-14                --
# |    |    └─Sequential: 3-15             8,448
# |    └─BasicBlock: 2-4                   --
# |    |    └─Conv2d: 3-16                 147,456
# |    |    └─BatchNorm2d: 3-17            256
# |    |    └─Conv2d: 3-18                 147,456
# |    |    └─Dropout: 3-19                --
# |    |    └─Sequential: 3-20             --
# |    └─BasicBlock: 2-5                   --
# |    |    └─Conv2d: 3-21                 147,456
# |    |    └─BatchNorm2d: 3-22            256
# |    |    └─Conv2d: 3-23                 147,456
# |    |    └─Dropout: 3-24                --
# |    |    └─Sequential: 3-25             --
# ├─Sequential: 1-5                        --
# |    └─BasicBlock: 2-6                   --
# |    |    └─Conv2d: 3-26                 221,184
# |    |    └─BatchNorm2d: 3-27            384
# |    |    └─Conv2d: 3-28                 331,776
# |    |    └─Dropout: 3-29                --
# |    |    └─Sequential: 3-30             24,960
# |    └─BasicBlock: 2-7                   --
# |    |    └─Conv2d: 3-31                 331,776
# |    |    └─BatchNorm2d: 3-32            384
# |    |    └─Conv2d: 3-33                 331,776
# |    |    └─Dropout: 3-34                --
# |    |    └─Sequential: 3-35             --
# ├─Sequential: 1-6                        --
# |    └─BasicBlock: 2-8                   --
# |    |    └─Conv2d: 3-36                 442,368
# |    |    └─BatchNorm2d: 3-37            512
# |    |    └─Conv2d: 3-38                 589,824
# |    |    └─Dropout: 3-39                --
# |    |    └─Sequential: 3-40             49,664
# |    └─BasicBlock: 2-9                   --
# |    |    └─Conv2d: 3-41                 589,824
# |    |    └─BatchNorm2d: 3-42            512
# |    |    └─Conv2d: 3-43                 589,824
# |    |    └─Dropout: 3-44                --
# |    |    └─Sequential: 3-45             --
# ├─Linear: 1-7                            2,570
# =================================================================
# Total params: 4,477,130
# Trainable params: 4,477,130
# Non-trainable params: 0
# =================================================================

# %% [markdown]
# ## Model Training

# %%
# Helper Function
# term_width = int(100)

# TOTAL_BAR_LENGTH = 65.
# last_time = time.time()
# begin_time = last_time

# def progress_bar(current, total, msg=None):
#   global last_time, begin_time
#   if current == 0:
#     begin_time = time.time()  # Reset for new bar.

#   cur_len = int(TOTAL_BAR_LENGTH * current/total)
#   rest_len = int(TOTAL_BAR_LENGTH - cur_len) - 1

#   sys.stdout.write(' [')
#   for i in range(cur_len):
#     sys.stdout.write('=')
#   sys.stdout.write('>')
#   for i in range(rest_len):
#     sys.stdout.write('.')
#   sys.stdout.write(']')

#   cur_time = time.time()
#   step_time = cur_time - last_time
#   last_time = cur_time
#   tot_time = cur_time - begin_time

#   L = []
#   L.append('  Step: %s' % format_time(step_time))
#   L.append(' | Tot: %s' % format_time(tot_time))
#   if msg:
#     L.append(' | ' + msg)

#   msg = ''.join(L)
#   sys.stdout.write(msg)
#   for i in range(term_width-int(TOTAL_BAR_LENGTH)-len(msg)-3):
#     sys.stdout.write(' ')

#   # Go back to the center of the bar.
#   for i in range(term_width-int(TOTAL_BAR_LENGTH/2)+2):
#     sys.stdout.write('\b')
#   sys.stdout.write(' %d/%d ' % (current+1, total))

#   if current < total-1:
#     sys.stdout.write('\r')
#   else:
#     sys.stdout.write('\n')
#   sys.stdout.flush()

# %%
def format_time(seconds):
  days = int(seconds / 3600/24)
  seconds = seconds - days*3600*24
  hours = int(seconds / 3600)
  seconds = seconds - hours*3600
  minutes = int(seconds / 60)
  seconds = seconds - minutes*60
  secondsf = int(seconds)
  seconds = seconds - secondsf
  millis = int(seconds*1000)

  f = ''
  i = 1
  if days > 0:
    f += str(days) + 'D'
    i += 1
  if hours > 0 and i <= 2:
    f += str(hours) + 'h'
    i += 1
  if minutes > 0 and i <= 2:
    f += str(minutes) + 'm'
    i += 1
  if secondsf > 0 and i <= 2:
    f += str(secondsf) + 's'
    i += 1
  if millis > 0 and i <= 2:
    f += str(millis) + 'ms'
    i += 1
  if f == '':
    f = '0ms'
  return f

# %%
lr = 0.1
momentum = 0.9
weight_decay = 5e-4

start_epoch = 1
number_of_epochs = 100
best_acc = 0


criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=lr,
                      momentum=momentum, weight_decay=weight_decay)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=number_of_epochs)

# %%
def get_lr(optimizer):
  for param_group in optimizer.param_groups:
    return param_group['lr']

# %%
def train(epoch):
  print('\nEpoch: %d' % epoch)
  start_time = time.time()

  model.train()
  train_loss = 0
  correct = 0
  total = 0
  for batch_idx, (inputs, targets) in enumerate(train_dl):
    # inputs, targets = inputs.to(device), targets.to(device)
    optimizer.zero_grad()
    outputs = model(inputs)
    loss = criterion(outputs, targets)
    loss.backward()
    optimizer.step()

    train_loss += loss.item()
    _, predicted = outputs.max(1)
    total += targets.size(0)
    correct += predicted.eq(targets).sum().item()

    if batch_idx % 50 == 0:
      print(f"Batch: {batch_idx}/{len(train_dl)} | Loss: {(train_loss/(batch_idx+1)):.3f} | Acc: {(100.*correct/total):.3f}%")

  cur_time = time.time()
  epoch_time = cur_time - start_time
  print(f"Time taken : {format_time(epoch_time)}")

  return train_loss/(batch_idx+1), 100.*correct/total, get_lr(optimizer)

# %%
def test(epoch):
  global best_acc
  model.eval()
  test_loss = 0
  correct = 0
  total = 0
  with torch.no_grad():
    for batch_idx, (inputs, targets) in enumerate(test_dl):
      # inputs, targets = inputs.to(device), targets.to(device)
      outputs = model(inputs)
      loss = criterion(outputs, targets)

      test_loss += loss.item()
      _, predicted = outputs.max(1)
      total += targets.size(0)
      correct += predicted.eq(targets).sum().item()
      
      if batch_idx % 50 == 0:
        print(f"Batch: {batch_idx}/{len(test_dl)} | Loss: {(test_loss/(batch_idx+1)):.3f} | Acc: {(100.*correct/total):.3f}%")
      # progress_bar(batch_idx, len(test_dl), 'Loss: %.3f | Acc: %.3f%% (%d/%d)'
      #               % (test_loss/(batch_idx+1), 100.*correct/total, correct, total))

  # Save checkpoint.
  acc = 100.*correct/total
  if acc > best_acc:
    print('Saving..')
    state = {
        'net': model.state_dict(),
        'acc': acc,
        'epoch': epoch,
    }
    if not os.path.isdir('checkpoint_18_dp'):
      os.mkdir('checkpoint_18_dp')
    torch.save(state, './checkpoint_18_dp/ckpt.pth')
    best_acc = acc

  return test_loss/(batch_idx+1), 100.*correct/total

# %%
train_losses = []
train_accuracies = []
train_lrs = []

test_losses = []
test_accuracies = []

for epoch in range(start_epoch, start_epoch + number_of_epochs):
  epoch_train_loss, epoch_train_accuracy, epoch_lr = train(epoch)
  train_losses.append(epoch_train_loss)
  train_accuracies.append(epoch_train_accuracy)
  train_lrs.append(epoch_lr)

  epoch_test_loss, epoch_test_accuracy = test(epoch)
  test_losses.append(epoch_test_loss)
  test_accuracies.append(epoch_test_accuracy)

  scheduler.step()
# Out:
# Epoch: 1
# Batch: 0/391 | Loss: 2.332 | Acc: 10.156%
# Batch: 50/391 | Loss: 1.975 | Acc: 24.571%
# Batch: 100/391 | Loss: 1.861 | Acc: 29.223%
# Batch: 150/391 | Loss: 1.793 | Acc: 31.902%
# Batch: 200/391 | Loss: 1.731 | Acc: 34.620%
# Batch: 250/391 | Loss: 1.686 | Acc: 36.765%
# Batch: 300/391 | Loss: 1.644 | Acc: 38.517%
# Batch: 350/391 | Loss: 1.609 | Acc: 39.911%
# Time taken : 21s165ms
# Batch: 0/100 | Loss: 1.590 | Acc: 46.000%
# Batch: 50/100 | Loss: 1.681 | Acc: 43.922%
# Saving..
#
# Epoch: 2
# Batch: 0/391 | Loss: 1.451 | Acc: 47.656%
# Batch: 50/391 | Loss: 1.268 | Acc: 53.569%
# Batch: 100/391 | Loss: 1.237 | Acc: 55.221%
# Batch: 150/391 | Loss: 1.213 | Acc: 56.105%
# Batch: 200/391 | Loss: 1.201 | Acc: 56.580%
# Batch: 250/391 | Loss: 1.183 | Acc: 57.283%
# Batch: 300/391 | Loss: 1.161 | Acc: 58.033%
# Batch: 350/391 | Loss: 1.147 | Acc: 58.609%
# Time taken : 18s217ms
# Batch: 0/100 | Loss: 0.983 | Acc: 68.000%
# Batch: 50/100 | Loss: 1.002 | Acc: 64.431%
# Saving..
#
# Epoch: 3
# Batch: 0/391 | Loss: 0.825 | Acc: 72.656%
# Batch: 50/391 | Loss: 0.997 | Acc: 64.813%
# Batch: 100/391 | Loss: 0.989 | Acc: 64.944%
# Batch: 150/391 | Loss: 0.987 | Acc: 65.087%
# Batch: 200/391 | Loss: 0.969 | Acc: 65.536%
# Batch: 250/391 | Loss: 0.955 | Acc: 65.961%
# Batch: 300/391 | Loss: 0.951 | Acc: 66.258%
# Batch: 350/391 | Loss: 0.945 | Acc: 66.442%
# Time taken : 18s781ms
# Batch: 0/100 | Loss: 0.970 | Acc: 69.000%
# Batch: 50/100 | Loss: 0.943 | Acc: 69.176%
# Saving..
#
# Epoch: 4
# Batch: 0/391 | Loss: 0.836 | Acc: 72.656%
# Batch: 50/391 | Loss: 0.867 | Acc: 69.179%
# Batch: 100/391 | Loss: 0.853 | Acc: 69.647%
# Batch: 150/391 | Loss: 0.842 | Acc: 70.028%
# Batch: 200/391 | Loss: 0.835 | Acc: 70.235%
# Batch: 250/391 | Loss: 0.828 | Acc: 70.593%
# Batch: 300/391 | Loss: 0.821 | Acc: 70.868%
# Batch: 350/391 | Loss: 0.813 | Acc: 71.181%
# Time taken : 18s163ms
# Batch: 0/100 | Loss: 0.723 | Acc: 75.000%
# Batch: 50/100 | Loss: 0.738 | Acc: 74.020%
# Saving..
#
# Epoch: 5
# Batch: 0/391 | Loss: 0.771 | Acc: 68.750%
# Batch: 50/391 | Loss: 0.723 | Acc: 74.694%
# Batch: 100/391 | Loss: 0.732 | Acc: 74.358%
# Batch: 150/391 | Loss: 0.729 | Acc: 74.250%
# Batch: 200/391 | Loss: 0.724 | Acc: 74.464%
# Batch: 250/391 | Loss: 0.724 | Acc: 74.608%
# Batch: 300/391 | Loss: 0.714 | Acc: 74.984%
# Batch: 350/391 | Loss: 0.713 | Acc: 75.024%
# Time taken : 18s721ms
# Batch: 0/100 | Loss: 0.666 | Acc: 81.000%
# Batch: 50/100 | Loss: 0.694 | Acc: 76.157%
# Saving..
#
# Epoch: 6
# Batch: 0/391 | Loss: 0.906 | Acc: 70.312%
# Batch: 50/391 | Loss: 0.672 | Acc: 77.007%
# Batch: 100/391 | Loss: 0.672 | Acc: 76.996%
# Batch: 150/391 | Loss: 0.659 | Acc: 77.318%
# Batch: 200/391 | Loss: 0.658 | Acc: 77.208%
# Batch: 250/391 | Loss: 0.653 | Acc: 77.397%
# Batch: 300/391 | Loss: 0.652 | Acc: 77.393%
# Batch: 350/391 | Loss: 0.653 | Acc: 77.342%
# Time taken : 18s530ms
# Batch: 0/100 | Loss: 0.854 | Acc: 75.000%
# Batch: 50/100 | Loss: 0.779 | Acc: 73.627%
#
# Epoch: 7
# Batch: 0/391 | Loss: 0.647 | Acc: 75.781%
# Batch: 50/391 | Loss: 0.601 | Acc: 78.937%
# Batch: 100/391 | Loss: 0.610 | Acc: 78.736%
# Batch: 150/391 | Loss: 0.616 | Acc: 78.523%
# Batch: 200/391 | Loss: 0.614 | Acc: 78.595%
# Batch: 250/391 | Loss: 0.617 | Acc: 78.486%
# Batch: 300/391 | Loss: 0.612 | Acc: 78.603%
# Batch: 350/391 | Loss: 0.608 | Acc: 78.746%
# Time taken : 18s364ms
# Batch: 0/100 | Loss: 0.552 | Acc: 81.000%
# Batch: 50/100 | Loss: 0.724 | Acc: 75.627%
#
# Epoch: 8
# Batch: 0/391 | Loss: 0.536 | Acc: 78.906%
# Batch: 50/391 | Loss: 0.571 | Acc: 80.484%
# Batch: 100/391 | Loss: 0.577 | Acc: 80.190%
# Batch: 150/391 | Loss: 0.574 | Acc: 80.298%
# Batch: 200/391 | Loss: 0.577 | Acc: 80.119%
# Batch: 250/391 | Loss: 0.576 | Acc: 80.154%
# Batch: 300/391 | Loss: 0.576 | Acc: 80.162%
# Batch: 350/391 | Loss: 0.576 | Acc: 80.193%
# Time taken : 18s763ms
# Batch: 0/100 | Loss: 0.859 | Acc: 72.000%
# Batch: 50/100 | Loss: 0.821 | Acc: 73.765%
#
# Epoch: 9
# Batch: 0/391 | Loss: 0.521 | Acc: 80.469%
# Batch: 50/391 | Loss: 0.540 | Acc: 81.725%
# Batch: 100/391 | Loss: 0.540 | Acc: 81.536%
# Batch: 150/391 | Loss: 0.545 | Acc: 81.245%
# Batch: 200/391 | Loss: 0.549 | Acc: 81.157%
# Batch: 250/391 | Loss: 0.555 | Acc: 80.926%
# Batch: 300/391 | Loss: 0.553 | Acc: 81.105%
# Batch: 350/391 | Loss: 0.552 | Acc: 81.121%
# Time taken : 18s571ms
# Batch: 0/100 | Loss: 0.701 | Acc: 74.000%
# Batch: 50/100 | Loss: 0.720 | Acc: 76.294%
# Saving..
#
# Epoch: 10
# Batch: 0/391 | Loss: 0.456 | Acc: 85.156%
# Batch: 50/391 | Loss: 0.522 | Acc: 82.292%
# Batch: 100/391 | Loss: 0.520 | Acc: 82.155%
# Batch: 150/391 | Loss: 0.536 | Acc: 81.535%
# Batch: 200/391 | Loss: 0.535 | Acc: 81.662%
# Batch: 250/391 | Loss: 0.531 | Acc: 81.748%
# Batch: 300/391 | Loss: 0.534 | Acc: 81.691%
# Batch: 350/391 | Loss: 0.535 | Acc: 81.706%
# Time taken : 18s539ms
# Batch: 0/100 | Loss: 0.586 | Acc: 80.000%
# Batch: 50/100 | Loss: 0.586 | Acc: 80.020%
# Saving..
#
# Epoch: 11
# Batch: 0/391 | Loss: 0.462 | Acc: 82.812%
# Batch: 50/391 | Loss: 0.506 | Acc: 83.563%
# Batch: 100/391 | Loss: 0.501 | Acc: 83.331%
# Batch: 150/391 | Loss: 0.503 | Acc: 83.252%
# Batch: 200/391 | Loss: 0.510 | Acc: 82.851%
# Batch: 250/391 | Loss: 0.514 | Acc: 82.722%
# Batch: 300/391 | Loss: 0.512 | Acc: 82.685%
# Batch: 350/391 | Loss: 0.517 | Acc: 82.410%
# Time taken : 18s608ms
# Batch: 0/100 | Loss: 0.637 | Acc: 76.000%
# Batch: 50/100 | Loss: 0.948 | Acc: 70.275%
#
# Epoch: 12
# Batch: 0/391 | Loss: 0.324 | Acc: 89.844%
# Batch: 50/391 | Loss: 0.506 | Acc: 82.613%
# Batch: 100/391 | Loss: 0.505 | Acc: 82.727%
# Batch: 150/391 | Loss: 0.504 | Acc: 82.875%
# Batch: 200/391 | Loss: 0.504 | Acc: 82.863%
# Batch: 250/391 | Loss: 0.504 | Acc: 82.738%
# Batch: 300/391 | Loss: 0.505 | Acc: 82.665%
# Batch: 350/391 | Loss: 0.504 | Acc: 82.686%
# Time taken : 18s765ms
# Batch: 0/100 | Loss: 0.738 | Acc: 81.000%
# Batch: 50/100 | Loss: 0.616 | Acc: 80.000%
#
# Epoch: 13
# Batch: 0/391 | Loss: 0.472 | Acc: 83.594%
# Batch: 50/391 | Loss: 0.463 | Acc: 84.069%
# Batch: 100/391 | Loss: 0.477 | Acc: 83.718%
# Batch: 150/391 | Loss: 0.482 | Acc: 83.723%
# Batch: 200/391 | Loss: 0.486 | Acc: 83.582%
# Batch: 250/391 | Loss: 0.488 | Acc: 83.388%
# Batch: 300/391 | Loss: 0.488 | Acc: 83.425%
# Batch: 350/391 | Loss: 0.489 | Acc: 83.469%
# Time taken : 18s549ms
# Batch: 0/100 | Loss: 0.558 | Acc: 85.000%
# Batch: 50/100 | Loss: 0.551 | Acc: 81.176%
# Saving..
#
# Epoch: 14
# Batch: 0/391 | Loss: 0.646 | Acc: 80.469%
# Batch: 50/391 | Loss: 0.480 | Acc: 83.456%
# Batch: 100/391 | Loss: 0.475 | Acc: 83.826%
# Batch: 150/391 | Loss: 0.478 | Acc: 83.801%
# Batch: 200/391 | Loss: 0.472 | Acc: 84.006%
# Batch: 250/391 | Loss: 0.474 | Acc: 83.927%
# Batch: 300/391 | Loss: 0.471 | Acc: 84.043%
# Batch: 350/391 | Loss: 0.475 | Acc: 83.894%
# Time taken : 18s414ms
# Batch: 0/100 | Loss: 0.978 | Acc: 68.000%
# Batch: 50/100 | Loss: 0.980 | Acc: 71.039%
#
# Epoch: 15
# Batch: 0/391 | Loss: 0.413 | Acc: 82.031%
# Batch: 50/391 | Loss: 0.463 | Acc: 84.452%
# Batch: 100/391 | Loss: 0.464 | Acc: 84.251%
# Batch: 150/391 | Loss: 0.462 | Acc: 84.344%
# Batch: 200/391 | Loss: 0.465 | Acc: 84.204%
# Batch: 250/391 | Loss: 0.465 | Acc: 84.117%
# Batch: 300/391 | Loss: 0.465 | Acc: 84.079%
# Batch: 350/391 | Loss: 0.466 | Acc: 84.039%
# Time taken : 18s464ms
# Batch: 0/100 | Loss: 0.446 | Acc: 86.000%
# Batch: 50/100 | Loss: 0.496 | Acc: 83.412%
# Saving..
#
# Epoch: 16
# Batch: 0/391 | Loss: 0.461 | Acc: 83.594%
# Batch: 50/391 | Loss: 0.456 | Acc: 84.574%
# Batch: 100/391 | Loss: 0.455 | Acc: 84.499%
# Batch: 150/391 | Loss: 0.449 | Acc: 84.742%
# Batch: 200/391 | Loss: 0.453 | Acc: 84.565%
# Batch: 250/391 | Loss: 0.453 | Acc: 84.552%
# Batch: 300/391 | Loss: 0.454 | Acc: 84.533%
# Batch: 350/391 | Loss: 0.456 | Acc: 84.460%
# Time taken : 18s625ms
# Batch: 0/100 | Loss: 0.579 | Acc: 77.000%
# Batch: 50/100 | Loss: 0.561 | Acc: 81.706%
#
# Epoch: 17
# Batch: 0/391 | Loss: 0.381 | Acc: 85.156%
# Batch: 50/391 | Loss: 0.435 | Acc: 85.080%
# Batch: 100/391 | Loss: 0.445 | Acc: 84.847%
# Batch: 150/391 | Loss: 0.446 | Acc: 84.629%
# Batch: 200/391 | Loss: 0.445 | Acc: 84.663%
# Batch: 250/391 | Loss: 0.445 | Acc: 84.677%
# Batch: 300/391 | Loss: 0.452 | Acc: 84.502%
# Batch: 350/391 | Loss: 0.452 | Acc: 84.464%
# Time taken : 18s403ms
# Batch: 0/100 | Loss: 0.539 | Acc: 84.000%
# Batch: 50/100 | Loss: 0.670 | Acc: 79.039%
#
# Epoch: 18
# Batch: 0/391 | Loss: 0.503 | Acc: 85.938%
# Batch: 50/391 | Loss: 0.414 | Acc: 85.907%
# Batch: 100/391 | Loss: 0.427 | Acc: 85.365%
# Batch: 150/391 | Loss: 0.430 | Acc: 85.337%
# Batch: 200/391 | Loss: 0.426 | Acc: 85.413%
# Batch: 250/391 | Loss: 0.428 | Acc: 85.396%
# Batch: 300/391 | Loss: 0.435 | Acc: 85.161%
# Batch: 350/391 | Loss: 0.435 | Acc: 85.181%
# Time taken : 18s504ms
# Batch: 0/100 | Loss: 0.495 | Acc: 82.000%
# Batch: 50/100 | Loss: 0.545 | Acc: 82.039%
#
# Epoch: 19
# Batch: 0/391 | Loss: 0.415 | Acc: 85.938%
# Batch: 50/391 | Loss: 0.407 | Acc: 86.167%
# Batch: 100/391 | Loss: 0.424 | Acc: 85.520%
# Batch: 150/391 | Loss: 0.422 | Acc: 85.565%
# Batch: 200/391 | Loss: 0.427 | Acc: 85.494%
# Batch: 250/391 | Loss: 0.430 | Acc: 85.427%
# Batch: 300/391 | Loss: 0.430 | Acc: 85.385%
# Batch: 350/391 | Loss: 0.429 | Acc: 85.394%
# Time taken : 18s493ms
# Batch: 0/100 | Loss: 0.563 | Acc: 86.000%
# Batch: 50/100 | Loss: 0.507 | Acc: 83.235%
#
# Epoch: 20
# Batch: 0/391 | Loss: 0.394 | Acc: 87.500%
# Batch: 50/391 | Loss: 0.418 | Acc: 86.137%
# Batch: 100/391 | Loss: 0.423 | Acc: 85.582%
# Batch: 150/391 | Loss: 0.428 | Acc: 85.581%
# Batch: 200/391 | Loss: 0.423 | Acc: 85.739%
# Batch: 250/391 | Loss: 0.427 | Acc: 85.654%
# Batch: 300/391 | Loss: 0.425 | Acc: 85.673%
# Batch: 350/391 | Loss: 0.426 | Acc: 85.503%
# Time taken : 18s410ms
# Batch: 0/100 | Loss: 0.598 | Acc: 81.000%
# Batch: 50/100 | Loss: 0.614 | Acc: 81.529%
#
# Epoch: 21
# Batch: 0/391 | Loss: 0.410 | Acc: 85.156%
# Batch: 50/391 | Loss: 0.408 | Acc: 85.968%
# Batch: 100/391 | Loss: 0.418 | Acc: 85.435%
# Batch: 150/391 | Loss: 0.424 | Acc: 85.462%
# Batch: 200/391 | Loss: 0.426 | Acc: 85.475%
# Batch: 250/391 | Loss: 0.424 | Acc: 85.505%
# Batch: 300/391 | Loss: 0.424 | Acc: 85.444%
# Batch: 350/391 | Loss: 0.425 | Acc: 85.437%
# Time taken : 18s552ms
# Batch: 0/100 | Loss: 0.524 | Acc: 83.000%
# Batch: 50/100 | Loss: 0.480 | Acc: 83.804%
# Saving..
#
# Epoch: 22
# Batch: 0/391 | Loss: 0.293 | Acc: 89.844%
# Batch: 50/391 | Loss: 0.376 | Acc: 86.857%
# Batch: 100/391 | Loss: 0.407 | Acc: 86.077%
# Batch: 150/391 | Loss: 0.414 | Acc: 85.969%
# Batch: 200/391 | Loss: 0.410 | Acc: 86.035%
# Batch: 250/391 | Loss: 0.417 | Acc: 85.797%
# Batch: 300/391 | Loss: 0.415 | Acc: 85.886%
# Batch: 350/391 | Loss: 0.415 | Acc: 85.833%
# Time taken : 18s621ms
# Batch: 0/100 | Loss: 0.501 | Acc: 83.000%
# Batch: 50/100 | Loss: 0.475 | Acc: 84.529%
# Saving..
#
# Epoch: 23
# Batch: 0/391 | Loss: 0.354 | Acc: 88.281%
# Batch: 50/391 | Loss: 0.375 | Acc: 87.347%
# Batch: 100/391 | Loss: 0.386 | Acc: 86.843%
# Batch: 150/391 | Loss: 0.379 | Acc: 86.967%
# Batch: 200/391 | Loss: 0.388 | Acc: 86.692%
# Batch: 250/391 | Loss: 0.396 | Acc: 86.457%
# Batch: 300/391 | Loss: 0.399 | Acc: 86.355%
# Batch: 350/391 | Loss: 0.402 | Acc: 86.278%
# Time taken : 18s419ms
# Batch: 0/100 | Loss: 0.437 | Acc: 85.000%
# Batch: 50/100 | Loss: 0.485 | Acc: 84.137%
#
# Epoch: 24
# Batch: 0/391 | Loss: 0.316 | Acc: 89.844%
# Batch: 50/391 | Loss: 0.397 | Acc: 86.351%
# Batch: 100/391 | Loss: 0.411 | Acc: 85.922%
# Batch: 150/391 | Loss: 0.414 | Acc: 85.731%
# Batch: 200/391 | Loss: 0.412 | Acc: 85.926%
# Batch: 250/391 | Loss: 0.411 | Acc: 86.040%
# Batch: 300/391 | Loss: 0.409 | Acc: 86.109%
# Batch: 350/391 | Loss: 0.408 | Acc: 86.138%
# Time taken : 18s619ms
# Batch: 0/100 | Loss: 0.547 | Acc: 82.000%
# Batch: 50/100 | Loss: 0.555 | Acc: 81.863%
#
# Epoch: 25
# Batch: 0/391 | Loss: 0.413 | Acc: 83.594%
# Batch: 50/391 | Loss: 0.388 | Acc: 86.596%
# Batch: 100/391 | Loss: 0.387 | Acc: 86.641%
# Batch: 150/391 | Loss: 0.393 | Acc: 86.496%
# Batch: 200/391 | Loss: 0.392 | Acc: 86.563%
# Batch: 250/391 | Loss: 0.394 | Acc: 86.417%
# Batch: 300/391 | Loss: 0.396 | Acc: 86.355%
# Batch: 350/391 | Loss: 0.396 | Acc: 86.394%
# Time taken : 18s582ms
# Batch: 0/100 | Loss: 0.364 | Acc: 85.000%
# Batch: 50/100 | Loss: 0.459 | Acc: 84.765%
# Saving..
#
# Epoch: 26
# Batch: 0/391 | Loss: 0.355 | Acc: 85.938%
# Batch: 50/391 | Loss: 0.378 | Acc: 87.040%
# Batch: 100/391 | Loss: 0.384 | Acc: 86.742%
# Batch: 150/391 | Loss: 0.385 | Acc: 86.770%
# Batch: 200/391 | Loss: 0.390 | Acc: 86.575%
# Batch: 250/391 | Loss: 0.391 | Acc: 86.516%
# Batch: 300/391 | Loss: 0.392 | Acc: 86.490%
# Batch: 350/391 | Loss: 0.391 | Acc: 86.525%
# Time taken : 18s534ms
# Batch: 0/100 | Loss: 0.368 | Acc: 89.000%
# Batch: 50/100 | Loss: 0.548 | Acc: 82.353%
#
# Epoch: 27
# Batch: 0/391 | Loss: 0.337 | Acc: 87.500%
# Batch: 50/391 | Loss: 0.372 | Acc: 87.439%
# Batch: 100/391 | Loss: 0.381 | Acc: 87.260%
# Batch: 150/391 | Loss: 0.378 | Acc: 87.195%
# Batch: 200/391 | Loss: 0.384 | Acc: 86.878%
# Batch: 250/391 | Loss: 0.384 | Acc: 86.955%
# Batch: 300/391 | Loss: 0.382 | Acc: 86.963%
# Batch: 350/391 | Loss: 0.384 | Acc: 86.872%
# Time taken : 18s513ms
# Batch: 0/100 | Loss: 0.384 | Acc: 83.000%
# Batch: 50/100 | Loss: 0.462 | Acc: 84.961%
# Saving..
#
# Epoch: 28
# Batch: 0/391 | Loss: 0.261 | Acc: 91.406%
# Batch: 50/391 | Loss: 0.387 | Acc: 86.872%
# Batch: 100/391 | Loss: 0.376 | Acc: 87.260%
# Batch: 150/391 | Loss: 0.379 | Acc: 87.148%
# Batch: 200/391 | Loss: 0.383 | Acc: 86.824%
# Batch: 250/391 | Loss: 0.384 | Acc: 86.672%
# Batch: 300/391 | Loss: 0.381 | Acc: 86.851%
# Batch: 350/391 | Loss: 0.383 | Acc: 86.783%
# Time taken : 18s618ms
# Batch: 0/100 | Loss: 0.400 | Acc: 86.000%
# Batch: 50/100 | Loss: 0.545 | Acc: 82.059%
#
# Epoch: 29
# Batch: 0/391 | Loss: 0.353 | Acc: 85.938%
# Batch: 50/391 | Loss: 0.351 | Acc: 88.189%
# Batch: 100/391 | Loss: 0.358 | Acc: 87.933%
# Batch: 150/391 | Loss: 0.356 | Acc: 87.862%
# Batch: 200/391 | Loss: 0.362 | Acc: 87.667%
# Batch: 250/391 | Loss: 0.362 | Acc: 87.684%
# Batch: 300/391 | Loss: 0.365 | Acc: 87.505%
# Batch: 350/391 | Loss: 0.368 | Acc: 87.440%
# Time taken : 18s281ms
# Batch: 0/100 | Loss: 0.328 | Acc: 91.000%
# Batch: 50/100 | Loss: 0.443 | Acc: 84.784%
# Saving..
#
# Epoch: 30
# Batch: 0/391 | Loss: 0.256 | Acc: 93.750%
# Batch: 50/391 | Loss: 0.353 | Acc: 87.730%
# Batch: 100/391 | Loss: 0.350 | Acc: 87.856%
# Batch: 150/391 | Loss: 0.352 | Acc: 87.935%
# Batch: 200/391 | Loss: 0.360 | Acc: 87.671%
# Batch: 250/391 | Loss: 0.359 | Acc: 87.631%
# Batch: 300/391 | Loss: 0.362 | Acc: 87.632%
# Batch: 350/391 | Loss: 0.365 | Acc: 87.589%
# Time taken : 18s551ms
# Batch: 0/100 | Loss: 0.427 | Acc: 85.000%
# Batch: 50/100 | Loss: 0.537 | Acc: 83.333%
#
# Epoch: 31
# Batch: 0/391 | Loss: 0.269 | Acc: 93.750%
# Batch: 50/391 | Loss: 0.365 | Acc: 87.806%
# Batch: 100/391 | Loss: 0.356 | Acc: 88.018%
# Batch: 150/391 | Loss: 0.360 | Acc: 87.914%
# Batch: 200/391 | Loss: 0.361 | Acc: 87.807%
# Batch: 250/391 | Loss: 0.364 | Acc: 87.656%
# Batch: 300/391 | Loss: 0.365 | Acc: 87.635%
# Batch: 350/391 | Loss: 0.368 | Acc: 87.516%
# Time taken : 18s288ms
# Batch: 0/100 | Loss: 0.289 | Acc: 91.000%
# Batch: 50/100 | Loss: 0.431 | Acc: 86.510%
# Saving..
#
# Epoch: 32
# Batch: 0/391 | Loss: 0.401 | Acc: 85.156%
# Batch: 50/391 | Loss: 0.342 | Acc: 88.220%
# Batch: 100/391 | Loss: 0.354 | Acc: 87.794%
# Batch: 150/391 | Loss: 0.353 | Acc: 87.821%
# Batch: 200/391 | Loss: 0.360 | Acc: 87.663%
# Batch: 250/391 | Loss: 0.361 | Acc: 87.699%
# Batch: 300/391 | Loss: 0.361 | Acc: 87.676%
# Batch: 350/391 | Loss: 0.360 | Acc: 87.714%
# Time taken : 18s335ms
# Batch: 0/100 | Loss: 0.395 | Acc: 88.000%
# Batch: 50/100 | Loss: 0.493 | Acc: 85.412%
#
# Epoch: 33
# Batch: 0/391 | Loss: 0.355 | Acc: 88.281%
# Batch: 50/391 | Loss: 0.344 | Acc: 88.266%
# Batch: 100/391 | Loss: 0.348 | Acc: 88.212%
# Batch: 150/391 | Loss: 0.351 | Acc: 88.054%
# Batch: 200/391 | Loss: 0.352 | Acc: 88.013%
# Batch: 250/391 | Loss: 0.352 | Acc: 87.982%
# Batch: 300/391 | Loss: 0.351 | Acc: 87.985%
# Batch: 350/391 | Loss: 0.356 | Acc: 87.883%
# Time taken : 18s338ms
# Batch: 0/100 | Loss: 0.510 | Acc: 82.000%
# Batch: 50/100 | Loss: 0.643 | Acc: 80.588%
#
# Epoch: 34
# Batch: 0/391 | Loss: 0.353 | Acc: 88.281%
# Batch: 50/391 | Loss: 0.333 | Acc: 88.710%
# Batch: 100/391 | Loss: 0.340 | Acc: 88.335%
# Batch: 150/391 | Loss: 0.343 | Acc: 88.105%
# Batch: 200/391 | Loss: 0.348 | Acc: 87.966%
# Batch: 250/391 | Loss: 0.348 | Acc: 88.020%
# Batch: 300/391 | Loss: 0.351 | Acc: 87.910%
# Batch: 350/391 | Loss: 0.353 | Acc: 87.861%
# Time taken : 18s503ms
# Batch: 0/100 | Loss: 0.506 | Acc: 82.000%
# Batch: 50/100 | Loss: 0.428 | Acc: 86.431%
# Saving..
#
# Epoch: 35
# Batch: 0/391 | Loss: 0.351 | Acc: 90.625%
# Batch: 50/391 | Loss: 0.349 | Acc: 88.113%
# Batch: 100/391 | Loss: 0.340 | Acc: 88.304%
# Batch: 150/391 | Loss: 0.341 | Acc: 88.240%
# Batch: 200/391 | Loss: 0.339 | Acc: 88.305%
# Batch: 250/391 | Loss: 0.341 | Acc: 88.294%
# Batch: 300/391 | Loss: 0.342 | Acc: 88.302%
# Batch: 350/391 | Loss: 0.344 | Acc: 88.301%
# Time taken : 18s391ms
# Batch: 0/100 | Loss: 0.487 | Acc: 83.000%
# Batch: 50/100 | Loss: 0.411 | Acc: 86.333%
#
# Epoch: 36
# Batch: 0/391 | Loss: 0.373 | Acc: 89.062%
# Batch: 50/391 | Loss: 0.328 | Acc: 88.925%
# Batch: 100/391 | Loss: 0.337 | Acc: 88.343%
# Batch: 150/391 | Loss: 0.339 | Acc: 88.390%
# Batch: 200/391 | Loss: 0.341 | Acc: 88.200%
# Batch: 250/391 | Loss: 0.341 | Acc: 88.269%
# Batch: 300/391 | Loss: 0.345 | Acc: 88.185%
# Batch: 350/391 | Loss: 0.343 | Acc: 88.239%
# Time taken : 18s705ms
# Batch: 0/100 | Loss: 0.629 | Acc: 78.000%
# Batch: 50/100 | Loss: 0.720 | Acc: 78.118%
#
# Epoch: 37
# Batch: 0/391 | Loss: 0.357 | Acc: 89.062%
# Batch: 50/391 | Loss: 0.331 | Acc: 88.833%
# Batch: 100/391 | Loss: 0.343 | Acc: 88.328%
# Batch: 150/391 | Loss: 0.341 | Acc: 88.509%
# Batch: 200/391 | Loss: 0.338 | Acc: 88.627%
# Batch: 250/391 | Loss: 0.340 | Acc: 88.555%
# Batch: 300/391 | Loss: 0.341 | Acc: 88.515%
# Batch: 350/391 | Loss: 0.341 | Acc: 88.508%
# Time taken : 18s362ms
# Batch: 0/100 | Loss: 0.606 | Acc: 81.000%
# Batch: 50/100 | Loss: 0.559 | Acc: 82.549%
#
# Epoch: 38
# Batch: 0/391 | Loss: 0.296 | Acc: 90.625%
# Batch: 50/391 | Loss: 0.325 | Acc: 89.093%
# Batch: 100/391 | Loss: 0.335 | Acc: 88.908%
# Batch: 150/391 | Loss: 0.341 | Acc: 88.468%
# Batch: 200/391 | Loss: 0.335 | Acc: 88.666%
# Batch: 250/391 | Loss: 0.331 | Acc: 88.810%
# Batch: 300/391 | Loss: 0.333 | Acc: 88.694%
# Batch: 350/391 | Loss: 0.332 | Acc: 88.684%
# Time taken : 18s319ms
# Batch: 0/100 | Loss: 0.374 | Acc: 87.000%
# Batch: 50/100 | Loss: 0.430 | Acc: 86.039%
#
# Epoch: 39
# Batch: 0/391 | Loss: 0.322 | Acc: 88.281%
# Batch: 50/391 | Loss: 0.304 | Acc: 89.507%
# Batch: 100/391 | Loss: 0.316 | Acc: 89.070%
# Batch: 150/391 | Loss: 0.328 | Acc: 88.778%
# Batch: 200/391 | Loss: 0.328 | Acc: 88.915%
# Batch: 250/391 | Loss: 0.327 | Acc: 88.960%
# Batch: 300/391 | Loss: 0.328 | Acc: 88.902%
# Batch: 350/391 | Loss: 0.329 | Acc: 88.880%
# Time taken : 18s475ms
# Batch: 0/100 | Loss: 0.485 | Acc: 87.000%
# Batch: 50/100 | Loss: 0.464 | Acc: 85.000%
#
# Epoch: 40
# Batch: 0/391 | Loss: 0.240 | Acc: 92.188%
# Batch: 50/391 | Loss: 0.308 | Acc: 89.966%
# Batch: 100/391 | Loss: 0.320 | Acc: 89.148%
# Batch: 150/391 | Loss: 0.321 | Acc: 89.207%
# Batch: 200/391 | Loss: 0.324 | Acc: 89.059%
# Batch: 250/391 | Loss: 0.320 | Acc: 89.175%
# Batch: 300/391 | Loss: 0.323 | Acc: 89.050%
# Batch: 350/391 | Loss: 0.323 | Acc: 89.022%
# Time taken : 18s549ms
# Batch: 0/100 | Loss: 0.320 | Acc: 90.000%
# Batch: 50/100 | Loss: 0.482 | Acc: 84.412%
#
# Epoch: 41
# Batch: 0/391 | Loss: 0.248 | Acc: 91.406%
# Batch: 50/391 | Loss: 0.312 | Acc: 89.062%
# Batch: 100/391 | Loss: 0.316 | Acc: 88.939%
# Batch: 150/391 | Loss: 0.321 | Acc: 88.897%
# Batch: 200/391 | Loss: 0.318 | Acc: 89.055%
# Batch: 250/391 | Loss: 0.315 | Acc: 89.181%
# Batch: 300/391 | Loss: 0.314 | Acc: 89.197%
# Batch: 350/391 | Loss: 0.316 | Acc: 89.234%
# Time taken : 18s284ms
# Batch: 0/100 | Loss: 0.409 | Acc: 88.000%
# Batch: 50/100 | Loss: 0.406 | Acc: 86.863%
# Saving..
#
# Epoch: 42
# Batch: 0/391 | Loss: 0.215 | Acc: 92.188%
# Batch: 50/391 | Loss: 0.293 | Acc: 90.273%
# Batch: 100/391 | Loss: 0.295 | Acc: 90.292%
# Batch: 150/391 | Loss: 0.306 | Acc: 89.766%
# Batch: 200/391 | Loss: 0.308 | Acc: 89.715%
# Batch: 250/391 | Loss: 0.312 | Acc: 89.526%
# Batch: 300/391 | Loss: 0.311 | Acc: 89.519%
# Batch: 350/391 | Loss: 0.311 | Acc: 89.474%
# Time taken : 18s647ms
# Batch: 0/100 | Loss: 0.474 | Acc: 88.000%
# Batch: 50/100 | Loss: 0.404 | Acc: 86.608%
#
# Epoch: 43
# Batch: 0/391 | Loss: 0.343 | Acc: 85.938%
# Batch: 50/391 | Loss: 0.296 | Acc: 89.645%
# Batch: 100/391 | Loss: 0.301 | Acc: 89.697%
# Batch: 150/391 | Loss: 0.301 | Acc: 89.756%
# Batch: 200/391 | Loss: 0.304 | Acc: 89.638%
# Batch: 250/391 | Loss: 0.304 | Acc: 89.626%
# Batch: 300/391 | Loss: 0.306 | Acc: 89.576%
# Batch: 350/391 | Loss: 0.308 | Acc: 89.514%
# Time taken : 18s492ms
# Batch: 0/100 | Loss: 0.277 | Acc: 90.000%
# Batch: 50/100 | Loss: 0.444 | Acc: 86.294%
#
# Epoch: 44
# Batch: 0/391 | Loss: 0.278 | Acc: 89.844%
# Batch: 50/391 | Loss: 0.298 | Acc: 90.119%
# Batch: 100/391 | Loss: 0.310 | Acc: 89.650%
# Batch: 150/391 | Loss: 0.307 | Acc: 89.751%
# Batch: 200/391 | Loss: 0.310 | Acc: 89.665%
# Batch: 250/391 | Loss: 0.311 | Acc: 89.585%
# Batch: 300/391 | Loss: 0.310 | Acc: 89.605%
# Batch: 350/391 | Loss: 0.309 | Acc: 89.599%
# Time taken : 18s526ms
# Batch: 0/100 | Loss: 0.471 | Acc: 86.000%
# Batch: 50/100 | Loss: 0.431 | Acc: 86.137%
#
# Epoch: 45
# Batch: 0/391 | Loss: 0.252 | Acc: 90.625%
# Batch: 50/391 | Loss: 0.287 | Acc: 89.660%
# Batch: 100/391 | Loss: 0.295 | Acc: 89.689%
# Batch: 150/391 | Loss: 0.293 | Acc: 89.818%
# Batch: 200/391 | Loss: 0.294 | Acc: 89.980%
# Batch: 250/391 | Loss: 0.300 | Acc: 89.810%
# Batch: 300/391 | Loss: 0.304 | Acc: 89.688%
# Batch: 350/391 | Loss: 0.304 | Acc: 89.735%
# Time taken : 18s328ms
# Batch: 0/100 | Loss: 0.463 | Acc: 87.000%
# Batch: 50/100 | Loss: 0.439 | Acc: 86.314%
#
# Epoch: 46
# Batch: 0/391 | Loss: 0.340 | Acc: 89.844%
# Batch: 50/391 | Loss: 0.292 | Acc: 90.181%
# Batch: 100/391 | Loss: 0.297 | Acc: 90.145%
# Batch: 150/391 | Loss: 0.300 | Acc: 89.849%
# Batch: 200/391 | Loss: 0.296 | Acc: 89.972%
# Batch: 250/391 | Loss: 0.295 | Acc: 90.031%
# Batch: 300/391 | Loss: 0.295 | Acc: 90.005%
# Batch: 350/391 | Loss: 0.296 | Acc: 89.933%
# Time taken : 18s507ms
# Batch: 0/100 | Loss: 0.492 | Acc: 86.000%
# Batch: 50/100 | Loss: 0.446 | Acc: 86.059%
#
# Epoch: 47
# Batch: 0/391 | Loss: 0.326 | Acc: 89.844%
# Batch: 50/391 | Loss: 0.279 | Acc: 90.365%
# Batch: 100/391 | Loss: 0.297 | Acc: 89.991%
# Batch: 150/391 | Loss: 0.290 | Acc: 90.335%
# Batch: 200/391 | Loss: 0.294 | Acc: 90.197%
# Batch: 250/391 | Loss: 0.294 | Acc: 90.065%
# Batch: 300/391 | Loss: 0.293 | Acc: 90.124%
# Batch: 350/391 | Loss: 0.293 | Acc: 90.135%
# Time taken : 18s493ms
# Batch: 0/100 | Loss: 0.335 | Acc: 88.000%
# Batch: 50/100 | Loss: 0.404 | Acc: 87.451%
# Saving..
#
# Epoch: 48
# Batch: 0/391 | Loss: 0.261 | Acc: 91.406%
# Batch: 50/391 | Loss: 0.269 | Acc: 90.502%
# Batch: 100/391 | Loss: 0.268 | Acc: 90.702%
# Batch: 150/391 | Loss: 0.278 | Acc: 90.480%
# Batch: 200/391 | Loss: 0.282 | Acc: 90.337%
# Batch: 250/391 | Loss: 0.284 | Acc: 90.276%
# Batch: 300/391 | Loss: 0.287 | Acc: 90.194%
# Batch: 350/391 | Loss: 0.288 | Acc: 90.166%
# Time taken : 18s404ms
# Batch: 0/100 | Loss: 0.292 | Acc: 89.000%
# Batch: 50/100 | Loss: 0.333 | Acc: 89.157%
# Saving..
#
# Epoch: 49
# Batch: 0/391 | Loss: 0.286 | Acc: 90.625%
# Batch: 50/391 | Loss: 0.259 | Acc: 91.253%
# Batch: 100/391 | Loss: 0.263 | Acc: 91.019%
# Batch: 150/391 | Loss: 0.261 | Acc: 91.256%
# Batch: 200/391 | Loss: 0.260 | Acc: 91.282%
# Batch: 250/391 | Loss: 0.263 | Acc: 91.129%
# Batch: 300/391 | Loss: 0.269 | Acc: 90.911%
# Batch: 350/391 | Loss: 0.271 | Acc: 90.812%
# Time taken : 18s339ms
# Batch: 0/100 | Loss: 0.474 | Acc: 84.000%
# Batch: 50/100 | Loss: 0.533 | Acc: 84.020%
#
# Epoch: 50
# Batch: 0/391 | Loss: 0.340 | Acc: 89.062%
# Batch: 50/391 | Loss: 0.256 | Acc: 91.268%
# Batch: 100/391 | Loss: 0.264 | Acc: 90.950%
# Batch: 150/391 | Loss: 0.263 | Acc: 90.992%
# Batch: 200/391 | Loss: 0.266 | Acc: 90.909%
# Batch: 250/391 | Loss: 0.269 | Acc: 90.865%
# Batch: 300/391 | Loss: 0.272 | Acc: 90.747%
# Batch: 350/391 | Loss: 0.272 | Acc: 90.783%
# Time taken : 18s419ms
# Batch: 0/100 | Loss: 0.292 | Acc: 89.000%
# Batch: 50/100 | Loss: 0.293 | Acc: 90.392%
# Saving..
#
# Epoch: 51
# Batch: 0/391 | Loss: 0.240 | Acc: 89.844%
# Batch: 50/391 | Loss: 0.245 | Acc: 91.513%
# Batch: 100/391 | Loss: 0.244 | Acc: 91.553%
# Batch: 150/391 | Loss: 0.257 | Acc: 91.298%
# Batch: 200/391 | Loss: 0.259 | Acc: 91.134%
# Batch: 250/391 | Loss: 0.262 | Acc: 91.061%
# Batch: 300/391 | Loss: 0.262 | Acc: 91.064%
# Batch: 350/391 | Loss: 0.263 | Acc: 91.012%
# Time taken : 18s614ms
# Batch: 0/100 | Loss: 0.469 | Acc: 84.000%
# Batch: 50/100 | Loss: 0.456 | Acc: 85.176%
#
# Epoch: 52
# Batch: 0/391 | Loss: 0.395 | Acc: 87.500%
# Batch: 50/391 | Loss: 0.243 | Acc: 91.667%
# Batch: 100/391 | Loss: 0.253 | Acc: 91.306%
# Batch: 150/391 | Loss: 0.252 | Acc: 91.401%
# Batch: 200/391 | Loss: 0.252 | Acc: 91.313%
# Batch: 250/391 | Loss: 0.256 | Acc: 91.154%
# Batch: 300/391 | Loss: 0.256 | Acc: 91.173%
# Batch: 350/391 | Loss: 0.258 | Acc: 91.108%
# Time taken : 18s253ms
# Batch: 0/100 | Loss: 0.373 | Acc: 89.000%
# Batch: 50/100 | Loss: 0.394 | Acc: 87.765%
#
# Epoch: 53
# Batch: 0/391 | Loss: 0.335 | Acc: 91.406%
# Batch: 50/391 | Loss: 0.243 | Acc: 91.820%
# Batch: 100/391 | Loss: 0.244 | Acc: 91.770%
# Batch: 150/391 | Loss: 0.245 | Acc: 91.712%
# Batch: 200/391 | Loss: 0.252 | Acc: 91.538%
# Batch: 250/391 | Loss: 0.250 | Acc: 91.627%
# Batch: 300/391 | Loss: 0.252 | Acc: 91.492%
# Batch: 350/391 | Loss: 0.252 | Acc: 91.493%
# Time taken : 18s610ms
# Batch: 0/100 | Loss: 0.315 | Acc: 92.000%
# Batch: 50/100 | Loss: 0.390 | Acc: 87.667%
#
# Epoch: 54
# Batch: 0/391 | Loss: 0.193 | Acc: 93.750%
# Batch: 50/391 | Loss: 0.239 | Acc: 91.850%
# Batch: 100/391 | Loss: 0.244 | Acc: 91.708%
# Batch: 150/391 | Loss: 0.242 | Acc: 91.753%
# Batch: 200/391 | Loss: 0.244 | Acc: 91.616%
# Batch: 250/391 | Loss: 0.246 | Acc: 91.556%
# Batch: 300/391 | Loss: 0.246 | Acc: 91.552%
# Batch: 350/391 | Loss: 0.248 | Acc: 91.460%
# Time taken : 18s378ms
# Batch: 0/100 | Loss: 0.462 | Acc: 84.000%
# Batch: 50/100 | Loss: 0.418 | Acc: 87.431%
#
# Epoch: 55
# Batch: 0/391 | Loss: 0.174 | Acc: 93.750%
# Batch: 50/391 | Loss: 0.225 | Acc: 92.341%
# Batch: 100/391 | Loss: 0.227 | Acc: 92.327%
# Batch: 150/391 | Loss: 0.233 | Acc: 92.027%
# Batch: 200/391 | Loss: 0.239 | Acc: 91.853%
# Batch: 250/391 | Loss: 0.242 | Acc: 91.696%
# Batch: 300/391 | Loss: 0.243 | Acc: 91.733%
# Batch: 350/391 | Loss: 0.243 | Acc: 91.669%
# Time taken : 18s597ms
# Batch: 0/100 | Loss: 0.250 | Acc: 91.000%
# Batch: 50/100 | Loss: 0.338 | Acc: 88.843%
#
# Epoch: 56
# Batch: 0/391 | Loss: 0.189 | Acc: 94.531%
# Batch: 50/391 | Loss: 0.214 | Acc: 92.708%
# Batch: 100/391 | Loss: 0.225 | Acc: 92.350%
# Batch: 150/391 | Loss: 0.228 | Acc: 92.125%
# Batch: 200/391 | Loss: 0.231 | Acc: 92.083%
# Batch: 250/391 | Loss: 0.231 | Acc: 92.116%
# Batch: 300/391 | Loss: 0.233 | Acc: 91.988%
# Batch: 350/391 | Loss: 0.239 | Acc: 91.885%
# Time taken : 18s363ms
# Batch: 0/100 | Loss: 0.245 | Acc: 90.000%
# Batch: 50/100 | Loss: 0.308 | Acc: 90.510%
# Saving..
#
# Epoch: 57
# Batch: 0/391 | Loss: 0.215 | Acc: 91.406%
# Batch: 50/391 | Loss: 0.214 | Acc: 92.678%
# Batch: 100/391 | Loss: 0.216 | Acc: 92.582%
# Batch: 150/391 | Loss: 0.225 | Acc: 92.270%
# Batch: 200/391 | Loss: 0.223 | Acc: 92.219%
# Batch: 250/391 | Loss: 0.225 | Acc: 92.256%
# Batch: 300/391 | Loss: 0.230 | Acc: 92.071%
# Batch: 350/391 | Loss: 0.232 | Acc: 91.998%
# Time taken : 18s493ms
# Batch: 0/100 | Loss: 0.250 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.375 | Acc: 88.392%
#
# Epoch: 58
# Batch: 0/391 | Loss: 0.278 | Acc: 92.188%
# Batch: 50/391 | Loss: 0.223 | Acc: 92.586%
# Batch: 100/391 | Loss: 0.222 | Acc: 92.435%
# Batch: 150/391 | Loss: 0.225 | Acc: 92.275%
# Batch: 200/391 | Loss: 0.224 | Acc: 92.261%
# Batch: 250/391 | Loss: 0.225 | Acc: 92.222%
# Batch: 300/391 | Loss: 0.224 | Acc: 92.294%
# Batch: 350/391 | Loss: 0.225 | Acc: 92.219%
# Time taken : 18s577ms
# Batch: 0/100 | Loss: 0.137 | Acc: 96.000%
# Batch: 50/100 | Loss: 0.354 | Acc: 88.608%
#
# Epoch: 59
# Batch: 0/391 | Loss: 0.153 | Acc: 92.969%
# Batch: 50/391 | Loss: 0.203 | Acc: 92.984%
# Batch: 100/391 | Loss: 0.207 | Acc: 92.860%
# Batch: 150/391 | Loss: 0.215 | Acc: 92.462%
# Batch: 200/391 | Loss: 0.213 | Acc: 92.557%
# Batch: 250/391 | Loss: 0.215 | Acc: 92.527%
# Batch: 300/391 | Loss: 0.216 | Acc: 92.520%
# Batch: 350/391 | Loss: 0.218 | Acc: 92.419%
# Time taken : 18s484ms
# Batch: 0/100 | Loss: 0.350 | Acc: 87.000%
# Batch: 50/100 | Loss: 0.342 | Acc: 89.275%
#
# Epoch: 60
# Batch: 0/391 | Loss: 0.181 | Acc: 93.750%
# Batch: 50/391 | Loss: 0.197 | Acc: 92.999%
# Batch: 100/391 | Loss: 0.198 | Acc: 93.085%
# Batch: 150/391 | Loss: 0.211 | Acc: 92.684%
# Batch: 200/391 | Loss: 0.212 | Acc: 92.572%
# Batch: 250/391 | Loss: 0.214 | Acc: 92.539%
# Batch: 300/391 | Loss: 0.212 | Acc: 92.662%
# Batch: 350/391 | Loss: 0.213 | Acc: 92.650%
# Time taken : 18s437ms
# Batch: 0/100 | Loss: 0.211 | Acc: 93.000%
# Batch: 50/100 | Loss: 0.369 | Acc: 88.941%
#
# Epoch: 61
# Batch: 0/391 | Loss: 0.183 | Acc: 94.531%
# Batch: 50/391 | Loss: 0.183 | Acc: 93.873%
# Batch: 100/391 | Loss: 0.186 | Acc: 93.595%
# Batch: 150/391 | Loss: 0.190 | Acc: 93.393%
# Batch: 200/391 | Loss: 0.191 | Acc: 93.404%
# Batch: 250/391 | Loss: 0.195 | Acc: 93.311%
# Batch: 300/391 | Loss: 0.197 | Acc: 93.267%
# Batch: 350/391 | Loss: 0.199 | Acc: 93.216%
# Time taken : 18s515ms
# Batch: 0/100 | Loss: 0.326 | Acc: 88.000%
# Batch: 50/100 | Loss: 0.347 | Acc: 89.471%
#
# Epoch: 62
# Batch: 0/391 | Loss: 0.155 | Acc: 93.750%
# Batch: 50/391 | Loss: 0.187 | Acc: 93.444%
# Batch: 100/391 | Loss: 0.189 | Acc: 93.472%
# Batch: 150/391 | Loss: 0.190 | Acc: 93.455%
# Batch: 200/391 | Loss: 0.193 | Acc: 93.291%
# Batch: 250/391 | Loss: 0.193 | Acc: 93.286%
# Batch: 300/391 | Loss: 0.193 | Acc: 93.288%
# Batch: 350/391 | Loss: 0.194 | Acc: 93.298%
# Time taken : 18s519ms
# Batch: 0/100 | Loss: 0.145 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.315 | Acc: 90.392%
# Saving..
#
# Epoch: 63
# Batch: 0/391 | Loss: 0.161 | Acc: 90.625%
# Batch: 50/391 | Loss: 0.179 | Acc: 93.796%
# Batch: 100/391 | Loss: 0.184 | Acc: 93.495%
# Batch: 150/391 | Loss: 0.183 | Acc: 93.440%
# Batch: 200/391 | Loss: 0.188 | Acc: 93.233%
# Batch: 250/391 | Loss: 0.189 | Acc: 93.277%
# Batch: 300/391 | Loss: 0.189 | Acc: 93.291%
# Batch: 350/391 | Loss: 0.190 | Acc: 93.271%
# Time taken : 18s620ms
# Batch: 0/100 | Loss: 0.213 | Acc: 93.000%
# Batch: 50/100 | Loss: 0.325 | Acc: 90.392%
#
# Epoch: 64
# Batch: 0/391 | Loss: 0.211 | Acc: 92.188%
# Batch: 50/391 | Loss: 0.188 | Acc: 93.321%
# Batch: 100/391 | Loss: 0.181 | Acc: 93.696%
# Batch: 150/391 | Loss: 0.179 | Acc: 93.817%
# Batch: 200/391 | Loss: 0.179 | Acc: 93.793%
# Batch: 250/391 | Loss: 0.179 | Acc: 93.784%
# Batch: 300/391 | Loss: 0.182 | Acc: 93.711%
# Batch: 350/391 | Loss: 0.182 | Acc: 93.790%
# Time taken : 18s767ms
# Batch: 0/100 | Loss: 0.237 | Acc: 92.000%
# Batch: 50/100 | Loss: 0.338 | Acc: 89.765%
#
# Epoch: 65
# Batch: 0/391 | Loss: 0.183 | Acc: 92.969%
# Batch: 50/391 | Loss: 0.171 | Acc: 94.056%
# Batch: 100/391 | Loss: 0.173 | Acc: 94.114%
# Batch: 150/391 | Loss: 0.173 | Acc: 94.195%
# Batch: 200/391 | Loss: 0.174 | Acc: 94.119%
# Batch: 250/391 | Loss: 0.171 | Acc: 94.232%
# Batch: 300/391 | Loss: 0.173 | Acc: 94.194%
# Batch: 350/391 | Loss: 0.176 | Acc: 94.071%
# Time taken : 18s447ms
# Batch: 0/100 | Loss: 0.181 | Acc: 93.000%
# Batch: 50/100 | Loss: 0.259 | Acc: 91.941%
# Saving..
#
# Epoch: 66
# Batch: 0/391 | Loss: 0.154 | Acc: 93.750%
# Batch: 50/391 | Loss: 0.149 | Acc: 95.098%
# Batch: 100/391 | Loss: 0.154 | Acc: 94.794%
# Batch: 150/391 | Loss: 0.159 | Acc: 94.604%
# Batch: 200/391 | Loss: 0.163 | Acc: 94.349%
# Batch: 250/391 | Loss: 0.165 | Acc: 94.354%
# Batch: 300/391 | Loss: 0.166 | Acc: 94.337%
# Batch: 350/391 | Loss: 0.170 | Acc: 94.237%
# Time taken : 18s456ms
# Batch: 0/100 | Loss: 0.214 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.305 | Acc: 91.039%
#
# Epoch: 67
# Batch: 0/391 | Loss: 0.079 | Acc: 98.438%
# Batch: 50/391 | Loss: 0.158 | Acc: 94.470%
# Batch: 100/391 | Loss: 0.155 | Acc: 94.632%
# Batch: 150/391 | Loss: 0.158 | Acc: 94.547%
# Batch: 200/391 | Loss: 0.159 | Acc: 94.512%
# Batch: 250/391 | Loss: 0.165 | Acc: 94.335%
# Batch: 300/391 | Loss: 0.165 | Acc: 94.316%
# Batch: 350/391 | Loss: 0.164 | Acc: 94.331%
# Time taken : 18s566ms
# Batch: 0/100 | Loss: 0.172 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.294 | Acc: 90.804%
#
# Epoch: 68
# Batch: 0/391 | Loss: 0.101 | Acc: 96.094%
# Batch: 50/391 | Loss: 0.145 | Acc: 94.792%
# Batch: 100/391 | Loss: 0.138 | Acc: 95.127%
# Batch: 150/391 | Loss: 0.142 | Acc: 95.012%
# Batch: 200/391 | Loss: 0.147 | Acc: 94.842%
# Batch: 250/391 | Loss: 0.149 | Acc: 94.799%
# Batch: 300/391 | Loss: 0.151 | Acc: 94.747%
# Batch: 350/391 | Loss: 0.154 | Acc: 94.647%
# Time taken : 18s511ms
# Batch: 0/100 | Loss: 0.300 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.306 | Acc: 91.196%
#
# Epoch: 69
# Batch: 0/391 | Loss: 0.130 | Acc: 95.312%
# Batch: 50/391 | Loss: 0.133 | Acc: 95.221%
# Batch: 100/391 | Loss: 0.141 | Acc: 95.080%
# Batch: 150/391 | Loss: 0.145 | Acc: 94.945%
# Batch: 200/391 | Loss: 0.146 | Acc: 94.994%
# Batch: 250/391 | Loss: 0.145 | Acc: 95.048%
# Batch: 300/391 | Loss: 0.146 | Acc: 94.957%
# Batch: 350/391 | Loss: 0.149 | Acc: 94.852%
# Time taken : 18s616ms
# Batch: 0/100 | Loss: 0.306 | Acc: 89.000%
# Batch: 50/100 | Loss: 0.296 | Acc: 90.824%
#
# Epoch: 70
# Batch: 0/391 | Loss: 0.047 | Acc: 98.438%
# Batch: 50/391 | Loss: 0.126 | Acc: 95.650%
# Batch: 100/391 | Loss: 0.137 | Acc: 95.235%
# Batch: 150/391 | Loss: 0.141 | Acc: 95.028%
# Batch: 200/391 | Loss: 0.143 | Acc: 95.002%
# Batch: 250/391 | Loss: 0.141 | Acc: 95.113%
# Batch: 300/391 | Loss: 0.141 | Acc: 95.092%
# Batch: 350/391 | Loss: 0.142 | Acc: 95.016%
# Time taken : 18s735ms
# Batch: 0/100 | Loss: 0.132 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.277 | Acc: 91.549%
#
# Epoch: 71
# Batch: 0/391 | Loss: 0.140 | Acc: 94.531%
# Batch: 50/391 | Loss: 0.139 | Acc: 95.175%
# Batch: 100/391 | Loss: 0.131 | Acc: 95.467%
# Batch: 150/391 | Loss: 0.133 | Acc: 95.380%
# Batch: 200/391 | Loss: 0.132 | Acc: 95.394%
# Batch: 250/391 | Loss: 0.136 | Acc: 95.278%
# Batch: 300/391 | Loss: 0.137 | Acc: 95.263%
# Batch: 350/391 | Loss: 0.135 | Acc: 95.333%
# Time taken : 18s485ms
# Batch: 0/100 | Loss: 0.192 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.273 | Acc: 91.353%
#
# Epoch: 72
# Batch: 0/391 | Loss: 0.066 | Acc: 99.219%
# Batch: 50/391 | Loss: 0.123 | Acc: 95.895%
# Batch: 100/391 | Loss: 0.121 | Acc: 96.001%
# Batch: 150/391 | Loss: 0.116 | Acc: 96.104%
# Batch: 200/391 | Loss: 0.118 | Acc: 95.977%
# Batch: 250/391 | Loss: 0.123 | Acc: 95.811%
# Batch: 300/391 | Loss: 0.126 | Acc: 95.733%
# Batch: 350/391 | Loss: 0.126 | Acc: 95.695%
# Time taken : 18s672ms
# Batch: 0/100 | Loss: 0.190 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.277 | Acc: 91.784%
#
# Epoch: 73
# Batch: 0/391 | Loss: 0.200 | Acc: 93.750%
# Batch: 50/391 | Loss: 0.108 | Acc: 96.308%
# Batch: 100/391 | Loss: 0.111 | Acc: 96.233%
# Batch: 150/391 | Loss: 0.113 | Acc: 96.135%
# Batch: 200/391 | Loss: 0.114 | Acc: 96.070%
# Batch: 250/391 | Loss: 0.114 | Acc: 96.010%
# Batch: 300/391 | Loss: 0.115 | Acc: 95.985%
# Batch: 350/391 | Loss: 0.117 | Acc: 95.936%
# Time taken : 18s546ms
# Batch: 0/100 | Loss: 0.326 | Acc: 89.000%
# Batch: 50/100 | Loss: 0.284 | Acc: 91.353%
#
# Epoch: 74
# Batch: 0/391 | Loss: 0.119 | Acc: 96.094%
# Batch: 50/391 | Loss: 0.108 | Acc: 96.415%
# Batch: 100/391 | Loss: 0.109 | Acc: 96.341%
# Batch: 150/391 | Loss: 0.108 | Acc: 96.296%
# Batch: 200/391 | Loss: 0.107 | Acc: 96.370%
# Batch: 250/391 | Loss: 0.109 | Acc: 96.240%
# Batch: 300/391 | Loss: 0.112 | Acc: 96.151%
# Batch: 350/391 | Loss: 0.110 | Acc: 96.185%
# Time taken : 18s434ms
# Batch: 0/100 | Loss: 0.270 | Acc: 91.000%
# Batch: 50/100 | Loss: 0.263 | Acc: 92.529%
# Saving..
#
# Epoch: 75
# Batch: 0/391 | Loss: 0.062 | Acc: 98.438%
# Batch: 50/391 | Loss: 0.097 | Acc: 96.906%
# Batch: 100/391 | Loss: 0.094 | Acc: 96.829%
# Batch: 150/391 | Loss: 0.094 | Acc: 96.772%
# Batch: 200/391 | Loss: 0.096 | Acc: 96.688%
# Batch: 250/391 | Loss: 0.099 | Acc: 96.629%
# Batch: 300/391 | Loss: 0.102 | Acc: 96.504%
# Batch: 350/391 | Loss: 0.102 | Acc: 96.514%
# Time taken : 18s419ms
# Batch: 0/100 | Loss: 0.160 | Acc: 93.000%
# Batch: 50/100 | Loss: 0.259 | Acc: 92.510%
# Saving..
#
# Epoch: 76
# Batch: 0/391 | Loss: 0.221 | Acc: 93.750%
# Batch: 50/391 | Loss: 0.085 | Acc: 96.798%
# Batch: 100/391 | Loss: 0.086 | Acc: 96.883%
# Batch: 150/391 | Loss: 0.086 | Acc: 96.844%
# Batch: 200/391 | Loss: 0.087 | Acc: 96.801%
# Batch: 250/391 | Loss: 0.090 | Acc: 96.769%
# Batch: 300/391 | Loss: 0.095 | Acc: 96.670%
# Batch: 350/391 | Loss: 0.098 | Acc: 96.579%
# Time taken : 18s526ms
# Batch: 0/100 | Loss: 0.232 | Acc: 93.000%
# Batch: 50/100 | Loss: 0.262 | Acc: 92.490%
#
# Epoch: 77
# Batch: 0/391 | Loss: 0.115 | Acc: 94.531%
# Batch: 50/391 | Loss: 0.090 | Acc: 96.737%
# Batch: 100/391 | Loss: 0.091 | Acc: 96.798%
# Batch: 150/391 | Loss: 0.089 | Acc: 96.891%
# Batch: 200/391 | Loss: 0.090 | Acc: 96.906%
# Batch: 250/391 | Loss: 0.091 | Acc: 96.841%
# Batch: 300/391 | Loss: 0.092 | Acc: 96.800%
# Batch: 350/391 | Loss: 0.093 | Acc: 96.777%
# Time taken : 18s492ms
# Batch: 0/100 | Loss: 0.211 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.267 | Acc: 92.667%
# Saving..
#
# Epoch: 78
# Batch: 0/391 | Loss: 0.049 | Acc: 99.219%
# Batch: 50/391 | Loss: 0.078 | Acc: 97.411%
# Batch: 100/391 | Loss: 0.076 | Acc: 97.409%
# Batch: 150/391 | Loss: 0.075 | Acc: 97.403%
# Batch: 200/391 | Loss: 0.074 | Acc: 97.431%
# Batch: 250/391 | Loss: 0.075 | Acc: 97.367%
# Batch: 300/391 | Loss: 0.076 | Acc: 97.345%
# Batch: 350/391 | Loss: 0.078 | Acc: 97.276%
# Time taken : 18s299ms
# Batch: 0/100 | Loss: 0.271 | Acc: 92.000%
# Batch: 50/100 | Loss: 0.312 | Acc: 91.725%
#
# Epoch: 79
# Batch: 0/391 | Loss: 0.073 | Acc: 97.656%
# Batch: 50/391 | Loss: 0.059 | Acc: 97.963%
# Batch: 100/391 | Loss: 0.060 | Acc: 97.912%
# Batch: 150/391 | Loss: 0.063 | Acc: 97.837%
# Batch: 200/391 | Loss: 0.065 | Acc: 97.742%
# Batch: 250/391 | Loss: 0.067 | Acc: 97.669%
# Batch: 300/391 | Loss: 0.069 | Acc: 97.550%
# Batch: 350/391 | Loss: 0.072 | Acc: 97.454%
# Time taken : 18s421ms
# Batch: 0/100 | Loss: 0.127 | Acc: 96.000%
# Batch: 50/100 | Loss: 0.256 | Acc: 93.314%
# Saving..
#
# Epoch: 80
# Batch: 0/391 | Loss: 0.068 | Acc: 98.438%
# Batch: 50/391 | Loss: 0.064 | Acc: 97.855%
# Batch: 100/391 | Loss: 0.063 | Acc: 97.780%
# Batch: 150/391 | Loss: 0.065 | Acc: 97.744%
# Batch: 200/391 | Loss: 0.067 | Acc: 97.730%
# Batch: 250/391 | Loss: 0.067 | Acc: 97.681%
# Batch: 300/391 | Loss: 0.066 | Acc: 97.711%
# Batch: 350/391 | Loss: 0.067 | Acc: 97.681%
# Time taken : 18s863ms
# Batch: 0/100 | Loss: 0.139 | Acc: 97.000%
# Batch: 50/100 | Loss: 0.279 | Acc: 93.020%
#
# Epoch: 81
# Batch: 0/391 | Loss: 0.064 | Acc: 96.875%
# Batch: 50/391 | Loss: 0.058 | Acc: 98.024%
# Batch: 100/391 | Loss: 0.060 | Acc: 97.950%
# Batch: 150/391 | Loss: 0.059 | Acc: 98.029%
# Batch: 200/391 | Loss: 0.058 | Acc: 98.095%
# Batch: 250/391 | Loss: 0.057 | Acc: 98.108%
# Batch: 300/391 | Loss: 0.058 | Acc: 98.097%
# Batch: 350/391 | Loss: 0.059 | Acc: 98.046%
# Time taken : 18s468ms
# Batch: 0/100 | Loss: 0.060 | Acc: 97.000%
# Batch: 50/100 | Loss: 0.257 | Acc: 93.549%
# Saving..
#
# Epoch: 82
# Batch: 0/391 | Loss: 0.045 | Acc: 98.438%
# Batch: 50/391 | Loss: 0.048 | Acc: 98.361%
# Batch: 100/391 | Loss: 0.048 | Acc: 98.383%
# Batch: 150/391 | Loss: 0.049 | Acc: 98.355%
# Batch: 200/391 | Loss: 0.050 | Acc: 98.329%
# Batch: 250/391 | Loss: 0.050 | Acc: 98.325%
# Batch: 300/391 | Loss: 0.050 | Acc: 98.349%
# Batch: 350/391 | Loss: 0.050 | Acc: 98.313%
# Time taken : 18s444ms
# Batch: 0/100 | Loss: 0.191 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.274 | Acc: 93.059%
#
# Epoch: 83
# Batch: 0/391 | Loss: 0.062 | Acc: 96.875%
# Batch: 50/391 | Loss: 0.048 | Acc: 98.499%
# Batch: 100/391 | Loss: 0.049 | Acc: 98.321%
# Batch: 150/391 | Loss: 0.049 | Acc: 98.339%
# Batch: 200/391 | Loss: 0.051 | Acc: 98.278%
# Batch: 250/391 | Loss: 0.050 | Acc: 98.285%
# Batch: 300/391 | Loss: 0.049 | Acc: 98.326%
# Batch: 350/391 | Loss: 0.049 | Acc: 98.297%
# Time taken : 18s651ms
# Batch: 0/100 | Loss: 0.169 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.248 | Acc: 93.667%
# Saving..
#
# Epoch: 84
# Batch: 0/391 | Loss: 0.058 | Acc: 97.656%
# Batch: 50/391 | Loss: 0.040 | Acc: 98.698%
# Batch: 100/391 | Loss: 0.040 | Acc: 98.662%
# Batch: 150/391 | Loss: 0.040 | Acc: 98.681%
# Batch: 200/391 | Loss: 0.041 | Acc: 98.659%
# Batch: 250/391 | Loss: 0.041 | Acc: 98.640%
# Batch: 300/391 | Loss: 0.041 | Acc: 98.645%
# Batch: 350/391 | Loss: 0.042 | Acc: 98.636%
# Time taken : 18s700ms
# Batch: 0/100 | Loss: 0.231 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.263 | Acc: 93.529%
#
# Epoch: 85
# Batch: 0/391 | Loss: 0.020 | Acc: 99.219%
# Batch: 50/391 | Loss: 0.032 | Acc: 98.882%
# Batch: 100/391 | Loss: 0.034 | Acc: 98.809%
# Batch: 150/391 | Loss: 0.034 | Acc: 98.851%
# Batch: 200/391 | Loss: 0.035 | Acc: 98.818%
# Batch: 250/391 | Loss: 0.034 | Acc: 98.867%
# Batch: 300/391 | Loss: 0.035 | Acc: 98.801%
# Batch: 350/391 | Loss: 0.035 | Acc: 98.820%
# Time taken : 18s743ms
# Batch: 0/100 | Loss: 0.158 | Acc: 96.000%
# Batch: 50/100 | Loss: 0.249 | Acc: 93.824%
# Saving..
#
# Epoch: 86
# Batch: 0/391 | Loss: 0.026 | Acc: 99.219%
# Batch: 50/391 | Loss: 0.030 | Acc: 98.989%
# Batch: 100/391 | Loss: 0.030 | Acc: 99.018%
# Batch: 150/391 | Loss: 0.030 | Acc: 99.017%
# Batch: 200/391 | Loss: 0.030 | Acc: 99.009%
# Batch: 250/391 | Loss: 0.029 | Acc: 99.026%
# Batch: 300/391 | Loss: 0.029 | Acc: 99.029%
# Batch: 350/391 | Loss: 0.029 | Acc: 99.036%
# Time taken : 18s449ms
# Batch: 0/100 | Loss: 0.258 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.245 | Acc: 94.118%
# Saving..
#
# Epoch: 87
# Batch: 0/391 | Loss: 0.031 | Acc: 99.219%
# Batch: 50/391 | Loss: 0.025 | Acc: 99.173%
# Batch: 100/391 | Loss: 0.024 | Acc: 99.257%
# Batch: 150/391 | Loss: 0.025 | Acc: 99.203%
# Batch: 200/391 | Loss: 0.026 | Acc: 99.164%
# Batch: 250/391 | Loss: 0.026 | Acc: 99.163%
# Batch: 300/391 | Loss: 0.026 | Acc: 99.177%
# Batch: 350/391 | Loss: 0.025 | Acc: 99.185%
# Time taken : 18s736ms
# Batch: 0/100 | Loss: 0.172 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.227 | Acc: 94.314%
# Saving..
#
# Epoch: 88
# Batch: 0/391 | Loss: 0.012 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.022 | Acc: 99.326%
# Batch: 100/391 | Loss: 0.021 | Acc: 99.327%
# Batch: 150/391 | Loss: 0.022 | Acc: 99.327%
# Batch: 200/391 | Loss: 0.021 | Acc: 99.355%
# Batch: 250/391 | Loss: 0.022 | Acc: 99.325%
# Batch: 300/391 | Loss: 0.022 | Acc: 99.328%
# Batch: 350/391 | Loss: 0.022 | Acc: 99.337%
# Time taken : 18s476ms
# Batch: 0/100 | Loss: 0.223 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.239 | Acc: 94.255%
#
# Epoch: 89
# Batch: 0/391 | Loss: 0.011 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.018 | Acc: 99.449%
# Batch: 100/391 | Loss: 0.016 | Acc: 99.520%
# Batch: 150/391 | Loss: 0.017 | Acc: 99.514%
# Batch: 200/391 | Loss: 0.017 | Acc: 99.502%
# Batch: 250/391 | Loss: 0.017 | Acc: 99.521%
# Batch: 300/391 | Loss: 0.017 | Acc: 99.499%
# Batch: 350/391 | Loss: 0.018 | Acc: 99.468%
# Time taken : 18s299ms
# Batch: 0/100 | Loss: 0.228 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.233 | Acc: 94.608%
# Saving..
#
# Epoch: 90
# Batch: 0/391 | Loss: 0.029 | Acc: 99.219%
# Batch: 50/391 | Loss: 0.021 | Acc: 99.433%
# Batch: 100/391 | Loss: 0.020 | Acc: 99.412%
# Batch: 150/391 | Loss: 0.018 | Acc: 99.457%
# Batch: 200/391 | Loss: 0.017 | Acc: 99.499%
# Batch: 250/391 | Loss: 0.017 | Acc: 99.499%
# Batch: 300/391 | Loss: 0.017 | Acc: 99.512%
# Batch: 350/391 | Loss: 0.017 | Acc: 99.501%
# Time taken : 18s535ms
# Batch: 0/100 | Loss: 0.135 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.230 | Acc: 94.706%
# Saving..
#
# Epoch: 91
# Batch: 0/391 | Loss: 0.012 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.013 | Acc: 99.632%
# Batch: 100/391 | Loss: 0.013 | Acc: 99.636%
# Batch: 150/391 | Loss: 0.014 | Acc: 99.596%
# Batch: 200/391 | Loss: 0.014 | Acc: 99.611%
# Batch: 250/391 | Loss: 0.014 | Acc: 99.602%
# Batch: 300/391 | Loss: 0.014 | Acc: 99.587%
# Batch: 350/391 | Loss: 0.014 | Acc: 99.584%
# Time taken : 18s652ms
# Batch: 0/100 | Loss: 0.230 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.236 | Acc: 94.569%
#
# Epoch: 92
# Batch: 0/391 | Loss: 0.025 | Acc: 99.219%
# Batch: 50/391 | Loss: 0.015 | Acc: 99.479%
# Batch: 100/391 | Loss: 0.013 | Acc: 99.582%
# Batch: 150/391 | Loss: 0.013 | Acc: 99.581%
# Batch: 200/391 | Loss: 0.013 | Acc: 99.600%
# Batch: 250/391 | Loss: 0.013 | Acc: 99.592%
# Batch: 300/391 | Loss: 0.013 | Acc: 99.577%
# Batch: 350/391 | Loss: 0.013 | Acc: 99.590%
# Time taken : 18s623ms
# Batch: 0/100 | Loss: 0.203 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.229 | Acc: 94.745%
# Saving..
#
# Epoch: 93
# Batch: 0/391 | Loss: 0.008 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.013 | Acc: 99.632%
# Batch: 100/391 | Loss: 0.013 | Acc: 99.621%
# Batch: 150/391 | Loss: 0.012 | Acc: 99.653%
# Batch: 200/391 | Loss: 0.012 | Acc: 99.677%
# Batch: 250/391 | Loss: 0.011 | Acc: 99.698%
# Batch: 300/391 | Loss: 0.011 | Acc: 99.689%
# Batch: 350/391 | Loss: 0.012 | Acc: 99.679%
# Time taken : 18s372ms
# Batch: 0/100 | Loss: 0.203 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.233 | Acc: 94.902%
# Saving..
#
# Epoch: 94
# Batch: 0/391 | Loss: 0.058 | Acc: 97.656%
# Batch: 50/391 | Loss: 0.015 | Acc: 99.602%
# Batch: 100/391 | Loss: 0.012 | Acc: 99.636%
# Batch: 150/391 | Loss: 0.012 | Acc: 99.653%
# Batch: 200/391 | Loss: 0.012 | Acc: 99.627%
# Batch: 250/391 | Loss: 0.012 | Acc: 99.642%
# Batch: 300/391 | Loss: 0.012 | Acc: 99.639%
# Batch: 350/391 | Loss: 0.012 | Acc: 99.628%
# Time taken : 18s681ms
# Batch: 0/100 | Loss: 0.177 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.227 | Acc: 94.980%
# Saving..
#
# Epoch: 95
# Batch: 0/391 | Loss: 0.009 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.007 | Acc: 99.893%
# Batch: 100/391 | Loss: 0.010 | Acc: 99.768%
# Batch: 150/391 | Loss: 0.009 | Acc: 99.783%
# Batch: 200/391 | Loss: 0.009 | Acc: 99.790%
# Batch: 250/391 | Loss: 0.009 | Acc: 99.785%
# Batch: 300/391 | Loss: 0.010 | Acc: 99.774%
# Batch: 350/391 | Loss: 0.009 | Acc: 99.775%
# Time taken : 18s375ms
# Batch: 0/100 | Loss: 0.190 | Acc: 96.000%
# Batch: 50/100 | Loss: 0.227 | Acc: 94.980%
# Saving..
#
# Epoch: 96
# Batch: 0/391 | Loss: 0.009 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.010 | Acc: 99.724%
# Batch: 100/391 | Loss: 0.009 | Acc: 99.760%
# Batch: 150/391 | Loss: 0.009 | Acc: 99.752%
# Batch: 200/391 | Loss: 0.009 | Acc: 99.747%
# Batch: 250/391 | Loss: 0.009 | Acc: 99.757%
# Batch: 300/391 | Loss: 0.009 | Acc: 99.748%
# Batch: 350/391 | Loss: 0.009 | Acc: 99.746%
# Time taken : 18s500ms
# Batch: 0/100 | Loss: 0.185 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.229 | Acc: 94.882%
#
# Epoch: 97
# Batch: 0/391 | Loss: 0.004 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.008 | Acc: 99.740%
# Batch: 100/391 | Loss: 0.007 | Acc: 99.822%
# Batch: 150/391 | Loss: 0.009 | Acc: 99.783%
# Batch: 200/391 | Loss: 0.009 | Acc: 99.778%
# Batch: 250/391 | Loss: 0.009 | Acc: 99.770%
# Batch: 300/391 | Loss: 0.009 | Acc: 99.748%
# Batch: 350/391 | Loss: 0.009 | Acc: 99.751%
# Time taken : 18s515ms
# Batch: 0/100 | Loss: 0.184 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.228 | Acc: 94.961%
# Saving..
#
# Epoch: 98
# Batch: 0/391 | Loss: 0.007 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.009 | Acc: 99.678%
# Batch: 100/391 | Loss: 0.010 | Acc: 99.691%
# Batch: 150/391 | Loss: 0.009 | Acc: 99.721%
# Batch: 200/391 | Loss: 0.009 | Acc: 99.720%
# Batch: 250/391 | Loss: 0.009 | Acc: 99.732%
# Batch: 300/391 | Loss: 0.009 | Acc: 99.746%
# Batch: 350/391 | Loss: 0.009 | Acc: 99.764%
# Time taken : 18s446ms
# Batch: 0/100 | Loss: 0.179 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.226 | Acc: 94.902%
#
# Epoch: 99
# Batch: 0/391 | Loss: 0.003 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.007 | Acc: 99.893%
# Batch: 100/391 | Loss: 0.009 | Acc: 99.783%
# Batch: 150/391 | Loss: 0.008 | Acc: 99.783%
# Batch: 200/391 | Loss: 0.009 | Acc: 99.763%

# %%
def plot_accuracies(train_accuracies, test_accuracies):
  plt.plot(train_accuracies, label='Train Accuracy')
  plt.plot(test_accuracies, label='Test Accuracy')
  plt.xlabel('Epochs')
  plt.ylabel('Accuracy')
  plt.legend()
  plt.grid(True)
  plt.title('Accuracy vs. No. of epochs')

# %%
def plot_losses(train_losses, test_losses):
  plt.plot(train_losses, label='Train Losses')
  plt.plot(test_losses, label='Test Losses')
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.legend()
  plt.grid(True)
  plt.title('Loss vs. No. of epochs')

# %%
def plot_lrs(train_lrs):
  plt.plot(train_lrs)
  plt.xlabel('Epochs')
  plt.ylabel('Learning rate')
  plt.grid(True)
  plt.title('Learning Rate vs. Epochs')

# %%
plot_accuracies(train_accuracies, test_accuracies)

# %%
plot_losses(train_losses, test_losses)

# %%
plot_lrs(train_lrs)

# %%
print('Saving final model..')
state = {
    'net': model.state_dict(),
    'acc': test_accuracies[-1],
    'epoch': number_of_epochs,
}
if not os.path.isdir('checkpoint_18_dp'):
  os.mkdir('checkpoint_18_dp')
torch.save(state, './checkpoint_18_dp/model_final.pth')

# %%
import numpy as np
import pickle
from tqdm import tqdm
import pandas as pd

# Function to load CIFAR batch
def load_cifar_batch(file):
    with open(file, 'rb') as fo:
        batch = pickle.load(fo, encoding='bytes')
    return batch

# Specify the folder where the CIFAR-10 batch files are
cifar10_dir = 'data/cifar-10-batches-py/'

# Load the label names
meta_data_dict = load_cifar_batch(os.path.join(cifar10_dir, 'batches.meta'))
label_names = meta_data_dict[b'label_names']

# Load test data
test_batch = load_cifar_batch('CIFAR-10/cifar_test_nolabels.pkl')
test_images = test_batch[b'data'].reshape(-1, 3, 32, 32).transpose(0, 2, 3, 1)

data_statistics = (
    (0.49139968, 0.48215827, 0.44653124),
     (0.24703233, 0.24348505, 0.26158768)
)

# Define transformation for data augmentation
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(*data_statistics, inplace=True)
])

# Apply data augmentation
augmented_test_images = torch.stack([transform(image) for image in test_images])

# Load the trained model
model = ResNet18()

checkpoint = torch.load('./checkpoint_18_dp/ckpt.pth')

# Check the keys in the checkpoint dictionary
print(checkpoint.keys())

# Assuming the model state dictionary is saved under a different key
# Adjust this according to the actual key in your checkpoint file
model.load_state_dict(checkpoint['net'])

model =  model.to(device)

# Evaluate the model on test data
model.eval()
with torch.no_grad():
    outputs = model(augmented_test_images.to(device))
_, predicted = torch.max(outputs, 1)

predicted = predicted.to('cpu')

# Display the first 10 test images and predicted labels
plt.figure(figsize=(20, 4))
for i in range(10):
    plt.subplot(1, 10, i+1)
    plt.imshow(test_images[i])
    plt.title(label_names[predicted[i].item()].decode('utf-8'))
    plt.axis('off')
plt.show()

# Save the output in output.csv containing ID, Labels
output_data = {'ID': np.arange(len(predicted)), 'Labels': predicted.numpy()}
output_df = pd.DataFrame(output_data)
output_df.to_csv('output_rugved_resnet18_dp.csv', index=False)
# Out:
# dict_keys(['net', 'acc', 'epoch'])

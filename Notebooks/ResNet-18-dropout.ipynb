# %% [markdown]
# # ResNet-18 on CIFAR-10 Dataset

# %% [markdown]
# Importing PyTorch and a few Python Libraries

# %%
import os
import sys
import time
import math

import torch
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import random_split, DataLoader
from torchvision.utils import make_grid

import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
import torch.nn.init as init

from torchsummary import summary

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Preparing the dataset
#
# We will be downloading the train and test CIFAR-10 dataset from torchvision. We will normalize and transform the dataset. For the training dataset, we will also be adding Random Crops and Random Horizontal Flips to generalize the model better.

# %%
data_statistics = (
    (0.49139968, 0.48215827, 0.44653124),
     (0.24703233, 0.24348505, 0.26158768)
) # Mean, Standard Deviation of CIFAR-10 dataset channels

train_transforms = transforms.Compose([
    transforms.RandomCrop(32, padding=4, padding_mode='reflect'), # Adding Random Crops
    transforms.RandomHorizontalFlip(), # Adding Random Horizontal Flips
    transforms.ToTensor(), # Channel x Image Height x Image Width
    transforms.Normalize(*data_statistics, inplace=True) # Output in the range of [-1, 1]
])

test_transforms = transforms.Compose([
    transforms.ToTensor(), # Channel x Image Height x Image Width
    transforms.Normalize(*data_statistics, inplace=True) # Output in the range of [-1, 1]
])

# %%
train_dataset = torchvision.datasets.CIFAR10(root='./data/', download=True, train=True, transform=train_transforms)
test_dataset = torchvision.datasets.CIFAR10(root='./data/', download=True, train=False, transform=test_transforms)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# <!-- We will also be splitting the dataset further into training and validation dataset with a validation ratio of `0.2` -->
#
# We will now create data loaders to retreive images in batches. We are selecting the batch size as `128` images for our train loader. And we are selecting the batch size as `100` images for our test loader.
#
# *From PyTorch Documentation: For data loading, passing pin_memory=True to a DataLoader will automatically put the fetched data Tensors in pinned memory, and thus enables faster data transfer to CUDA-enabled GPUs.*

# %%
# validation_ratio = 0.2
# train_dataset, validation_dataset = random_split(
#     dataset,
#     [int((1 - validation_ratio) * len(dataset)), int(validation_ratio * len(dataset))]
# )

train_batch_size = 128
test_batch_size = 100

train_dl = DataLoader(train_dataset, train_batch_size, shuffle=True, num_workers=2, pin_memory=True)
# validation_dl = DataLoader(validation_dataset, batch_size, shuffle=True, num_workers=3, pin_memory=True)
test_dl = DataLoader(test_dataset, test_batch_size, shuffle=False, num_workers=2, pin_memory=True)

classes = ('plane', 'car', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck')

# %% [markdown]
# We create the following function to display a batch of images from the dataset. And we also need to denormalize the pixels values to bring them back into the range (0,1).

# %%
def denormalize(images, means, stds):
  means = torch.tensor(means).reshape(1, 3, 1, 1)
  stds = torch.tensor(stds).reshape(1, 3, 1, 1)
  return images * stds + means

def show_batch(dl):
  for images, labels in dl:
    fig, ax = plt.subplots(figsize=(12, 12))
    ax.set_xticks([])
    ax.set_yticks([])
    denorm_images = denormalize(images, *data_statistics)
    ax.imshow(make_grid(denorm_images[:64], 8).permute(1, 2, 0))
    break

# %%
show_batch(train_dl)

# %% [markdown]
# To seamlessly use a GPU, if one is available, we define a couple of helper functions (`get_default_device` & `to_device`) and a helper class `DeviceDataLoader` to move our model & data to the GPU as required.

# %%
def get_default_device():
  # Pick GPU, if available, else CPU
  if torch.cuda.is_available():
    return torch.device('cuda')
  else:
    return torch.device('cpu')

def to_device(data, device):
  # Move tensors to chosen device
  if isinstance(data, (list, tuple)):
    # If the instance is a list/tuple, transfer each element to chosen device
    return [to_device(x, device) for x in data]
  return data.to(device, non_blocking=True)
  # non_blocking=True doesn't block the execution of the host device until transfers complete

class DeviceDataLoader():
  # Wrap a dataloader to move data to a device
  def __init__(self, dl, device):
    self.dl = dl
    self.device = device

  def __iter__(self):
    # Yield a batch of data after moving it to device
    for b in self.dl:
      yield to_device(b, self.device)

  def __len__(self):
    # Number of batches
    return len(self.dl)

# %%
# Get the default device
device = get_default_device()
device
# Out:
# device(type='cuda')

# %%
train_dl = DeviceDataLoader(train_dl, device)
# validation_dl = DeviceDataLoader(validation_dl, device)
test_dl = DeviceDataLoader(test_dl, device)

# %% [markdown]
# ## Network Architecture

# %% [markdown]
# Testing the models mentioned in the `pytorch-cifar` [GitHub Repository](https://github.com/kuangliu/pytorch-cifar).

# %% [markdown]
# ### ResNet18

# %%
class BasicBlock(nn.Module):
  expansion = 1

  def __init__(self, in_planes, planes, stride=1):
    super(BasicBlock, self).__init__()
    self.conv1 = nn.Conv2d(
        in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
    self.bn1 = nn.BatchNorm2d(planes)
    self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                            stride=1, padding=1, bias=False)
    self.bn2 = nn.BatchNorm2d(planes)
    self.bn2 = nn.Dropout(p = 0.2)

    self.shortcut = nn.Sequential()
    if stride != 1 or in_planes != self.expansion*planes:
      self.shortcut = nn.Sequential(
          nn.Conv2d(in_planes, self.expansion*planes,
                    kernel_size=1, stride=stride, bias=False),
          nn.BatchNorm2d(self.expansion*planes)
      )

  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))
    out = self.bn2(self.conv2(out))
    out += self.shortcut(x)
    out = F.relu(out)
    return out

class ResNet(nn.Module):
  def __init__(self, block, num_blocks, num_classes=10):
    super(ResNet, self).__init__()
    self.in_planes = 64

    self.conv1 = nn.Conv2d(3, 64, kernel_size=3,
                            stride=1, padding=1, bias=False)
    self.bn1 = nn.BatchNorm2d(64)
    self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
    self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
    self.layer3 = self._make_layer(block, 192, num_blocks[2], stride=2)
    self.layer4 = self._make_layer(block, 256, num_blocks[3], stride=2)
    self.linear = nn.Linear(256*block.expansion, num_classes)

  def _make_layer(self, block, planes, num_blocks, stride):
    strides = [stride] + [1]*(num_blocks-1)
    layers = []
    for stride in strides:
      layers.append(block(self.in_planes, planes, stride))
      self.in_planes = planes * block.expansion
    return nn.Sequential(*layers)

  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))
    out = self.layer1(out)
    out = self.layer2(out)
    out = self.layer3(out)
    out = self.layer4(out)
    out = F.avg_pool2d(out, 4)
    out = out.view(out.size(0), -1)
    out = self.linear(out)
    return out

def ResNet18():
  return ResNet(BasicBlock, [2, 3, 2, 2])

# %%
model = ResNet18()

# %%
model =  model.to(device)
if device == 'cuda':
  model = torch.nn.DataParallel(model)
  cudnn.benchmark = True

# %%
summary(model, input_size=(3, 32, 32))
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            1,728
# ├─BatchNorm2d: 1-2                       128
# ├─Sequential: 1-3                        --
# |    └─BasicBlock: 2-1                   --
# |    |    └─Conv2d: 3-1                  36,864
# |    |    └─BatchNorm2d: 3-2             128
# |    |    └─Conv2d: 3-3                  36,864
# |    |    └─Dropout: 3-4                 --
# |    |    └─Sequential: 3-5              --
# |    └─BasicBlock: 2-2                   --
# |    |    └─Conv2d: 3-6                  36,864
# |    |    └─BatchNorm2d: 3-7             128
# |    |    └─Conv2d: 3-8                  36,864
# |    |    └─Dropout: 3-9                 --
# |    |    └─Sequential: 3-10             --
# ├─Sequential: 1-4                        --
# |    └─BasicBlock: 2-3                   --
# |    |    └─Conv2d: 3-11                 73,728
# |    |    └─BatchNorm2d: 3-12            256
# |    |    └─Conv2d: 3-13                 147,456
# |    |    └─Dropout: 3-14                --
# |    |    └─Sequential: 3-15             8,448
# |    └─BasicBlock: 2-4                   --
# |    |    └─Conv2d: 3-16                 147,456
# |    |    └─BatchNorm2d: 3-17            256
# |    |    └─Conv2d: 3-18                 147,456
# |    |    └─Dropout: 3-19                --
# |    |    └─Sequential: 3-20             --
# |    └─BasicBlock: 2-5                   --
# |    |    └─Conv2d: 3-21                 147,456
# |    |    └─BatchNorm2d: 3-22            256
# |    |    └─Conv2d: 3-23                 147,456
# |    |    └─Dropout: 3-24                --
# |    |    └─Sequential: 3-25             --
# ├─Sequential: 1-5                        --
# |    └─BasicBlock: 2-6                   --
# |    |    └─Conv2d: 3-26                 221,184
# |    |    └─BatchNorm2d: 3-27            384
# |    |    └─Conv2d: 3-28                 331,776
# |    |    └─Dropout: 3-29                --
# |    |    └─Sequential: 3-30             24,960
# |    └─BasicBlock: 2-7                   --
# |    |    └─Conv2d: 3-31                 331,776
# |    |    └─BatchNorm2d: 3-32            384
# |    |    └─Conv2d: 3-33                 331,776
# |    |    └─Dropout: 3-34                --
# |    |    └─Sequential: 3-35             --
# ├─Sequential: 1-6                        --
# |    └─BasicBlock: 2-8                   --
# |    |    └─Conv2d: 3-36                 442,368
# |    |    └─BatchNorm2d: 3-37            512
# |    |    └─Conv2d: 3-38                 589,824
# |    |    └─Dropout: 3-39                --
# |    |    └─Sequential: 3-40             49,664
# |    └─BasicBlock: 2-9                   --
# |    |    └─Conv2d: 3-41                 589,824
# |    |    └─BatchNorm2d: 3-42            512
# |    |    └─Conv2d: 3-43                 589,824
# |    |    └─Dropout: 3-44                --
# |    |    └─Sequential: 3-45             --
# ├─Linear: 1-7                            2,570
# =================================================================
# Total params: 4,477,130
# Trainable params: 4,477,130
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            1,728
# ├─BatchNorm2d: 1-2                       128
# ├─Sequential: 1-3                        --
# |    └─BasicBlock: 2-1                   --
# |    |    └─Conv2d: 3-1                  36,864
# |    |    └─BatchNorm2d: 3-2             128
# |    |    └─Conv2d: 3-3                  36,864
# |    |    └─Dropout: 3-4                 --
# |    |    └─Sequential: 3-5              --
# |    └─BasicBlock: 2-2                   --
# |    |    └─Conv2d: 3-6                  36,864
# |    |    └─BatchNorm2d: 3-7             128
# |    |    └─Conv2d: 3-8                  36,864
# |    |    └─Dropout: 3-9                 --
# |    |    └─Sequential: 3-10             --
# ├─Sequential: 1-4                        --
# |    └─BasicBlock: 2-3                   --
# |    |    └─Conv2d: 3-11                 73,728
# |    |    └─BatchNorm2d: 3-12            256
# |    |    └─Conv2d: 3-13                 147,456
# |    |    └─Dropout: 3-14                --
# |    |    └─Sequential: 3-15             8,448
# |    └─BasicBlock: 2-4                   --
# |    |    └─Conv2d: 3-16                 147,456
# |    |    └─BatchNorm2d: 3-17            256
# |    |    └─Conv2d: 3-18                 147,456
# |    |    └─Dropout: 3-19                --
# |    |    └─Sequential: 3-20             --
# |    └─BasicBlock: 2-5                   --
# |    |    └─Conv2d: 3-21                 147,456
# |    |    └─BatchNorm2d: 3-22            256
# |    |    └─Conv2d: 3-23                 147,456
# |    |    └─Dropout: 3-24                --
# |    |    └─Sequential: 3-25             --
# ├─Sequential: 1-5                        --
# |    └─BasicBlock: 2-6                   --
# |    |    └─Conv2d: 3-26                 221,184
# |    |    └─BatchNorm2d: 3-27            384
# |    |    └─Conv2d: 3-28                 331,776
# |    |    └─Dropout: 3-29                --
# |    |    └─Sequential: 3-30             24,960
# |    └─BasicBlock: 2-7                   --
# |    |    └─Conv2d: 3-31                 331,776
# |    |    └─BatchNorm2d: 3-32            384
# |    |    └─Conv2d: 3-33                 331,776
# |    |    └─Dropout: 3-34                --
# |    |    └─Sequential: 3-35             --
# ├─Sequential: 1-6                        --
# |    └─BasicBlock: 2-8                   --
# |    |    └─Conv2d: 3-36                 442,368
# |    |    └─BatchNorm2d: 3-37            512
# |    |    └─Conv2d: 3-38                 589,824
# |    |    └─Dropout: 3-39                --
# |    |    └─Sequential: 3-40             49,664
# |    └─BasicBlock: 2-9                   --
# |    |    └─Conv2d: 3-41                 589,824
# |    |    └─BatchNorm2d: 3-42            512
# |    |    └─Conv2d: 3-43                 589,824
# |    |    └─Dropout: 3-44                --
# |    |    └─Sequential: 3-45             --
# ├─Linear: 1-7                            2,570
# =================================================================
# Total params: 4,477,130
# Trainable params: 4,477,130
# Non-trainable params: 0
# =================================================================

# %% [markdown]
# ## Model Training

# %%
def format_time(seconds):
  days = int(seconds / 3600/24)
  seconds = seconds - days*3600*24
  hours = int(seconds / 3600)
  seconds = seconds - hours*3600
  minutes = int(seconds / 60)
  seconds = seconds - minutes*60
  secondsf = int(seconds)
  seconds = seconds - secondsf
  millis = int(seconds*1000)

  f = ''
  i = 1
  if days > 0:
    f += str(days) + 'D'
    i += 1
  if hours > 0 and i <= 2:
    f += str(hours) + 'h'
    i += 1
  if minutes > 0 and i <= 2:
    f += str(minutes) + 'm'
    i += 1
  if secondsf > 0 and i <= 2:
    f += str(secondsf) + 's'
    i += 1
  if millis > 0 and i <= 2:
    f += str(millis) + 'ms'
    i += 1
  if f == '':
    f = '0ms'
  return f

# %%
lr = 0.1
momentum = 0.9
weight_decay = 5e-4

start_epoch = 1
number_of_epochs = 150
best_acc = 0


criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=lr,
                      momentum=momentum, weight_decay=weight_decay)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=number_of_epochs)

# %%
def get_lr(optimizer):
  for param_group in optimizer.param_groups:
    return param_group['lr']

# %%
def train(epoch):
  print('\nEpoch: %d' % epoch)
  start_time = time.time()

  model.train()
  train_loss = 0
  correct = 0
  total = 0
  for batch_idx, (inputs, targets) in enumerate(train_dl):
    # inputs, targets = inputs.to(device), targets.to(device)
    optimizer.zero_grad()
    outputs = model(inputs)
    loss = criterion(outputs, targets)
    loss.backward()
    optimizer.step()

    train_loss += loss.item()
    _, predicted = outputs.max(1)
    total += targets.size(0)
    correct += predicted.eq(targets).sum().item()

    # if batch_idx % 50 == 0:
    #   print(f"Batch: {batch_idx}/{len(train_dl)} | Loss: {(train_loss/(batch_idx+1)):.3f} | Acc: {(100.*correct/total):.3f}%")

  cur_time = time.time()
  epoch_time = cur_time - start_time
  print(f"Time taken : {format_time(epoch_time)}")

  return train_loss/(batch_idx+1), 100.*correct/total, get_lr(optimizer)

# %%
def test(epoch):
  global best_acc
  model.eval()
  test_loss = 0
  correct = 0
  total = 0
  with torch.no_grad():
    for batch_idx, (inputs, targets) in enumerate(test_dl):
      # inputs, targets = inputs.to(device), targets.to(device)
      outputs = model(inputs)
      loss = criterion(outputs, targets)

      test_loss += loss.item()
      _, predicted = outputs.max(1)
      total += targets.size(0)
      correct += predicted.eq(targets).sum().item()
      
      # if batch_idx % 50 == 0:
      #   print(f"Batch: {batch_idx}/{len(test_dl)} | Loss: {(test_loss/(batch_idx+1)):.3f} | Acc: {(100.*correct/total):.3f}%")

  # Save checkpoint.
  acc = 100.*correct/total
  
  if acc > best_acc:
    print('Saving..')
    state = {
        'net': model.state_dict(),
        'acc': acc,
        'epoch': epoch,
    }
    if not os.path.isdir('checkpoint'):
      os.mkdir('checkpoint')
    torch.save(state, './checkpoint/ResNet_18_dropout_best.pth')
    best_acc = acc

  return test_loss/(batch_idx+1), 100.*correct/total

# %%
train_losses = []
train_accuracies = []
train_lrs = []

test_losses = []
test_accuracies = []

for epoch in range(start_epoch, start_epoch + number_of_epochs):
  epoch_train_loss, epoch_train_accuracy, epoch_lr = train(epoch)
  train_losses.append(epoch_train_loss)
  train_accuracies.append(epoch_train_accuracy)
  train_lrs.append(epoch_lr)

  epoch_test_loss, epoch_test_accuracy = test(epoch)
  test_losses.append(epoch_test_loss)
  test_accuracies.append(epoch_test_accuracy)
  scheduler.step()
  print(f"Train Loss: {epoch_train_loss:.3f} | Train Accuracy: {epoch_train_accuracy:.3f}% | Test Loss: {epoch_test_loss:.3f} | Test Accuracy: {epoch_test_accuracy:.3f}%")
# Out:
# Epoch: 1
# Time taken : 18s190ms
# Saving..
# Train Loss: 1.553 | Train Accuracy: 42.484% | Test Loss: 1.555 | Test Accuracy: 47.600%
#
# Epoch: 2
# Time taken : 17s945ms
# Saving..
# Train Loss: 1.085 | Train Accuracy: 61.108% | Test Loss: 1.063 | Test Accuracy: 63.110%
#
# Epoch: 3
# Time taken : 17s962ms
# Saving..
# Train Loss: 0.893 | Train Accuracy: 68.542% | Test Loss: 0.860 | Test Accuracy: 70.110%
#
# Epoch: 4
# Time taken : 18s29ms
# Saving..
# Train Loss: 0.764 | Train Accuracy: 73.164% | Test Loss: 0.754 | Test Accuracy: 74.550%
#
# Epoch: 5
# Time taken : 18s46ms
# Saving..
# Train Loss: 0.676 | Train Accuracy: 76.424% | Test Loss: 0.662 | Test Accuracy: 77.570%
#
# Epoch: 6
# Time taken : 17s979ms
# Saving..
# Train Loss: 0.620 | Train Accuracy: 78.780% | Test Loss: 0.613 | Test Accuracy: 79.560%
#
# Epoch: 7
# Time taken : 17s990ms
# Train Loss: 0.587 | Train Accuracy: 79.818% | Test Loss: 0.661 | Test Accuracy: 77.870%
#
# Epoch: 8
# Time taken : 17s936ms
# Saving..
# Train Loss: 0.556 | Train Accuracy: 80.864% | Test Loss: 0.554 | Test Accuracy: 81.090%
#
# Epoch: 9
# Time taken : 18s2ms
# Train Loss: 0.526 | Train Accuracy: 81.994% | Test Loss: 0.637 | Test Accuracy: 78.220%
#
# Epoch: 10
# Time taken : 18s38ms
# Train Loss: 0.510 | Train Accuracy: 82.430% | Test Loss: 0.652 | Test Accuracy: 78.930%
#
# Epoch: 11
# Time taken : 17s903ms
# Train Loss: 0.502 | Train Accuracy: 82.830% | Test Loss: 0.785 | Test Accuracy: 75.600%
#
# Epoch: 12
# Time taken : 17s982ms
# Train Loss: 0.485 | Train Accuracy: 83.460% | Test Loss: 0.718 | Test Accuracy: 77.740%
#
# Epoch: 13
# Time taken : 18s25ms
# Saving..
# Train Loss: 0.477 | Train Accuracy: 83.562% | Test Loss: 0.457 | Test Accuracy: 84.250%
#
# Epoch: 14
# Time taken : 18s21ms
# Train Loss: 0.459 | Train Accuracy: 84.388% | Test Loss: 0.522 | Test Accuracy: 82.860%
#
# Epoch: 15
# Time taken : 17s946ms
# Train Loss: 0.455 | Train Accuracy: 84.534% | Test Loss: 0.781 | Test Accuracy: 76.460%
#
# Epoch: 16
# Time taken : 17s959ms
# Train Loss: 0.444 | Train Accuracy: 84.782% | Test Loss: 0.495 | Test Accuracy: 84.080%
#
# Epoch: 17
# Time taken : 17s995ms
# Train Loss: 0.437 | Train Accuracy: 84.974% | Test Loss: 0.563 | Test Accuracy: 82.430%
#
# Epoch: 18
# Time taken : 17s949ms
# Train Loss: 0.440 | Train Accuracy: 85.032% | Test Loss: 0.937 | Test Accuracy: 72.830%
#
# Epoch: 19
# Time taken : 17s940ms
# Saving..
# Train Loss: 0.429 | Train Accuracy: 85.434% | Test Loss: 0.465 | Test Accuracy: 84.430%
#
# Epoch: 20
# Time taken : 18s50ms
# Train Loss: 0.423 | Train Accuracy: 85.602% | Test Loss: 0.502 | Test Accuracy: 83.620%
#
# Epoch: 21
# Time taken : 17s906ms
# Train Loss: 0.420 | Train Accuracy: 85.678% | Test Loss: 0.584 | Test Accuracy: 80.550%
#
# Epoch: 22
# Time taken : 17s974ms
# Train Loss: 0.417 | Train Accuracy: 85.658% | Test Loss: 0.488 | Test Accuracy: 83.760%
#
# Epoch: 23
# Time taken : 17s969ms
# Saving..
# Train Loss: 0.413 | Train Accuracy: 85.994% | Test Loss: 0.438 | Test Accuracy: 85.150%
#
# Epoch: 24
# Time taken : 18s40ms
# Train Loss: 0.406 | Train Accuracy: 86.098% | Test Loss: 0.494 | Test Accuracy: 83.480%
#
# Epoch: 25
# Time taken : 17s987ms
# Train Loss: 0.404 | Train Accuracy: 86.286% | Test Loss: 0.525 | Test Accuracy: 83.120%
#
# Epoch: 26
# Time taken : 18s3ms
# Train Loss: 0.399 | Train Accuracy: 86.368% | Test Loss: 0.502 | Test Accuracy: 83.120%
#
# Epoch: 27
# Time taken : 17s924ms
# Train Loss: 0.397 | Train Accuracy: 86.408% | Test Loss: 0.510 | Test Accuracy: 83.170%
#
# Epoch: 28
# Time taken : 17s901ms
# Train Loss: 0.385 | Train Accuracy: 86.868% | Test Loss: 0.809 | Test Accuracy: 76.930%
#
# Epoch: 29
# Time taken : 17s988ms
# Train Loss: 0.391 | Train Accuracy: 86.616% | Test Loss: 0.556 | Test Accuracy: 82.060%
#
# Epoch: 30
# Time taken : 17s959ms
# Train Loss: 0.387 | Train Accuracy: 86.776% | Test Loss: 0.579 | Test Accuracy: 81.790%
#
# Epoch: 31
# Time taken : 17s999ms
# Train Loss: 0.378 | Train Accuracy: 87.208% | Test Loss: 0.644 | Test Accuracy: 80.290%
#
# Epoch: 32
# Time taken : 17s964ms
# Train Loss: 0.382 | Train Accuracy: 87.040% | Test Loss: 0.491 | Test Accuracy: 83.500%
#
# Epoch: 33
# Time taken : 17s954ms
# Train Loss: 0.376 | Train Accuracy: 87.174% | Test Loss: 0.591 | Test Accuracy: 81.690%
#
# Epoch: 34
# Time taken : 18s217ms
# Saving..
# Train Loss: 0.374 | Train Accuracy: 87.192% | Test Loss: 0.437 | Test Accuracy: 85.770%
#
# Epoch: 35
# Time taken : 17s906ms
# Train Loss: 0.377 | Train Accuracy: 87.204% | Test Loss: 0.423 | Test Accuracy: 85.570%
#
# Epoch: 36
# Time taken : 17s965ms
# Train Loss: 0.366 | Train Accuracy: 87.634% | Test Loss: 0.599 | Test Accuracy: 80.790%
#
# Epoch: 37
# Time taken : 18s21ms
# Train Loss: 0.364 | Train Accuracy: 87.402% | Test Loss: 0.656 | Test Accuracy: 81.070%
#
# Epoch: 38
# Time taken : 17s938ms
# Saving..
# Train Loss: 0.365 | Train Accuracy: 87.372% | Test Loss: 0.432 | Test Accuracy: 85.900%
#
# Epoch: 39
# Time taken : 17s906ms
# Train Loss: 0.359 | Train Accuracy: 87.698% | Test Loss: 0.469 | Test Accuracy: 85.180%
#
# Epoch: 40
# Time taken : 17s926ms
# Train Loss: 0.358 | Train Accuracy: 87.832% | Test Loss: 0.452 | Test Accuracy: 85.340%
#
# Epoch: 41
# Time taken : 17s949ms
# Train Loss: 0.357 | Train Accuracy: 87.710% | Test Loss: 0.616 | Test Accuracy: 81.980%
#
# Epoch: 42
# Time taken : 17s990ms
# Train Loss: 0.347 | Train Accuracy: 88.076% | Test Loss: 0.417 | Test Accuracy: 85.880%
#
# Epoch: 43
# Time taken : 17s928ms
# Saving..
# Train Loss: 0.350 | Train Accuracy: 88.098% | Test Loss: 0.417 | Test Accuracy: 86.150%
#
# Epoch: 44
# Time taken : 17s967ms
# Train Loss: 0.345 | Train Accuracy: 88.150% | Test Loss: 0.561 | Test Accuracy: 82.340%
#
# Epoch: 45
# Time taken : 17s965ms
# Train Loss: 0.347 | Train Accuracy: 88.082% | Test Loss: 0.550 | Test Accuracy: 83.010%
#
# Epoch: 46
# Time taken : 17s816ms
# Train Loss: 0.335 | Train Accuracy: 88.620% | Test Loss: 0.428 | Test Accuracy: 86.030%
#
# Epoch: 47
# Time taken : 17s886ms
# Saving..
# Train Loss: 0.337 | Train Accuracy: 88.510% | Test Loss: 0.378 | Test Accuracy: 87.410%
#
# Epoch: 48
# Time taken : 18s12ms
# Train Loss: 0.332 | Train Accuracy: 88.678% | Test Loss: 0.473 | Test Accuracy: 84.560%
#
# Epoch: 49
# Time taken : 18s99ms
# Train Loss: 0.327 | Train Accuracy: 88.880% | Test Loss: 0.424 | Test Accuracy: 85.830%
#
# Epoch: 50
# Time taken : 18s71ms
# Train Loss: 0.331 | Train Accuracy: 88.698% | Test Loss: 0.412 | Test Accuracy: 86.560%
#
# Epoch: 51
# Time taken : 17s872ms
# Train Loss: 0.328 | Train Accuracy: 88.770% | Test Loss: 0.485 | Test Accuracy: 84.570%
#
# Epoch: 52
# Time taken : 17s927ms
# Train Loss: 0.329 | Train Accuracy: 88.684% | Test Loss: 0.375 | Test Accuracy: 87.400%
#
# Epoch: 53
# Time taken : 17s968ms
# Train Loss: 0.320 | Train Accuracy: 89.120% | Test Loss: 0.482 | Test Accuracy: 84.760%
#
# Epoch: 54
# Time taken : 20s535ms
# Saving..
# Train Loss: 0.319 | Train Accuracy: 89.120% | Test Loss: 0.372 | Test Accuracy: 87.640%
#
# Epoch: 55
# Time taken : 17s902ms
# Train Loss: 0.316 | Train Accuracy: 89.030% | Test Loss: 0.458 | Test Accuracy: 85.260%
#
# Epoch: 56
# Time taken : 18s761ms
# Train Loss: 0.312 | Train Accuracy: 89.270% | Test Loss: 0.459 | Test Accuracy: 85.350%
#
# Epoch: 57
# Time taken : 18s969ms
# Train Loss: 0.300 | Train Accuracy: 89.724% | Test Loss: 0.426 | Test Accuracy: 86.810%
#
# Epoch: 58
# Time taken : 18s17ms
# Train Loss: 0.303 | Train Accuracy: 89.614% | Test Loss: 0.415 | Test Accuracy: 87.150%
#
# Epoch: 59
# Time taken : 18s5ms
# Saving..
# Train Loss: 0.305 | Train Accuracy: 89.520% | Test Loss: 0.383 | Test Accuracy: 87.810%
#
# Epoch: 60
# Time taken : 19s793ms
# Saving..
# Train Loss: 0.302 | Train Accuracy: 89.550% | Test Loss: 0.357 | Test Accuracy: 88.110%
#
# Epoch: 61
# Time taken : 18s203ms
# Train Loss: 0.297 | Train Accuracy: 89.966% | Test Loss: 0.381 | Test Accuracy: 87.470%
#
# Epoch: 62
# Time taken : 18s9ms
# Train Loss: 0.293 | Train Accuracy: 90.086% | Test Loss: 0.391 | Test Accuracy: 87.260%
#
# Epoch: 63
# Time taken : 17s981ms
# Train Loss: 0.292 | Train Accuracy: 90.102% | Test Loss: 0.374 | Test Accuracy: 88.110%
#
# Epoch: 64
# Time taken : 17s954ms
# Train Loss: 0.289 | Train Accuracy: 90.170% | Test Loss: 0.413 | Test Accuracy: 86.320%
#
# Epoch: 65
# Time taken : 17s964ms
# Train Loss: 0.287 | Train Accuracy: 90.370% | Test Loss: 0.440 | Test Accuracy: 86.290%
#
# Epoch: 66
# Time taken : 17s948ms
# Train Loss: 0.284 | Train Accuracy: 90.348% | Test Loss: 0.380 | Test Accuracy: 87.460%
#
# Epoch: 67
# Time taken : 18s914ms
# Train Loss: 0.279 | Train Accuracy: 90.566% | Test Loss: 0.429 | Test Accuracy: 86.400%
#
# Epoch: 68
# Time taken : 18s709ms
# Train Loss: 0.282 | Train Accuracy: 90.410% | Test Loss: 0.366 | Test Accuracy: 88.010%
#
# Epoch: 69
# Time taken : 17s953ms
# Train Loss: 0.275 | Train Accuracy: 90.578% | Test Loss: 0.372 | Test Accuracy: 88.050%
#
# Epoch: 70
# Time taken : 18s37ms
# Train Loss: 0.268 | Train Accuracy: 90.820% | Test Loss: 0.446 | Test Accuracy: 86.410%
#
# Epoch: 71
# Time taken : 17s941ms
# Train Loss: 0.273 | Train Accuracy: 90.662% | Test Loss: 0.376 | Test Accuracy: 87.890%
#
# Epoch: 72
# Time taken : 17s935ms
# Train Loss: 0.261 | Train Accuracy: 91.044% | Test Loss: 0.420 | Test Accuracy: 86.920%
#
# Epoch: 73
# Time taken : 17s987ms
# Train Loss: 0.266 | Train Accuracy: 90.908% | Test Loss: 0.460 | Test Accuracy: 85.370%
#
# Epoch: 74
# Time taken : 17s926ms
# Saving..
# Train Loss: 0.255 | Train Accuracy: 91.150% | Test Loss: 0.357 | Test Accuracy: 88.930%
#
# Epoch: 75
# Time taken : 18s9ms
# Saving..
# Train Loss: 0.257 | Train Accuracy: 91.184% | Test Loss: 0.348 | Test Accuracy: 89.110%
#
# Epoch: 76
# Time taken : 17s933ms
# Train Loss: 0.251 | Train Accuracy: 91.488% | Test Loss: 0.407 | Test Accuracy: 87.370%
#
# Epoch: 77
# Time taken : 17s946ms
# Saving..
# Train Loss: 0.247 | Train Accuracy: 91.606% | Test Loss: 0.313 | Test Accuracy: 89.510%
#
# Epoch: 78
# Time taken : 17s992ms
# Train Loss: 0.241 | Train Accuracy: 91.738% | Test Loss: 0.351 | Test Accuracy: 88.930%
#
# Epoch: 79
# Time taken : 17s951ms
# Train Loss: 0.245 | Train Accuracy: 91.556% | Test Loss: 0.463 | Test Accuracy: 86.500%
#
# Epoch: 80
# Time taken : 17s982ms
# Saving..
# Train Loss: 0.236 | Train Accuracy: 91.802% | Test Loss: 0.313 | Test Accuracy: 89.950%
#
# Epoch: 81
# Time taken : 17s999ms
# Train Loss: 0.239 | Train Accuracy: 91.770% | Test Loss: 0.358 | Test Accuracy: 88.370%
#
# Epoch: 82

# %%
print('Best Accuracy : ', best_acc)

# %%
def plot_accuracies(train_accuracies, test_accuracies):
  plt.plot(train_accuracies, label='Train Accuracy')
  plt.plot(test_accuracies, label='Test Accuracy')
  plt.xlabel('Epochs')
  plt.ylabel('Accuracy')
  plt.legend()
  plt.grid(True)
  plt.title('Accuracy vs. No. of epochs')

# %%
def plot_losses(train_losses, test_losses):
  plt.plot(train_losses, label='Train Losses')
  plt.plot(test_losses, label='Test Losses')
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.legend()
  plt.grid(True)
  plt.title('Loss vs. No. of epochs')

# %%
def plot_lrs(train_lrs):
  plt.plot(train_lrs)
  plt.xlabel('Epochs')
  plt.ylabel('Learning rate')
  plt.grid(True)
  plt.title('Learning Rate vs. Epochs')

# %%
plot_accuracies(train_accuracies, test_accuracies)

# %%
plot_losses(train_losses, test_losses)

# %%
plot_lrs(train_lrs)

# %%
print('Saving final model..')
state = {
    'net': model.state_dict(),
    'acc': test_accuracies[-1],
    'epoch': number_of_epochs,
    'best_acc' : best_acc,
    'train_acc' : train_accuracies,
    'test_acc' : test_accuracies,
    'train_loss' : train_losses,
    'test_loss' : test_losses,
    'lr' : train_lrs
}
if not os.path.isdir('checkpoint'):
  os.mkdir('checkpoint')
torch.save(state, './checkpoint/ResNet_18_dropout_final.pth')
# Out:
# Saving final model..

# %%
import numpy as np
import pickle
from tqdm import tqdm


# Function to load CIFAR batch
def load_cifar_batch(file):
    with open(file, 'rb') as fo:
        batch = pickle.load(fo, encoding='bytes')
    return batch

# Specify the folder where the CIFAR-10 batch files are
cifar10_dir = 'data/cifar-10-batches-py/'

# Load the label names
meta_data_dict = load_cifar_batch(os.path.join(cifar10_dir, 'batches.meta'))
label_names = meta_data_dict[b'label_names']

# Load test data
test_batch = load_cifar_batch('CIFAR-10/cifar_test_nolabels.pkl')
test_images = test_batch[b'data'].reshape(-1, 3, 32, 32).transpose(0, 2, 3, 1)

data_statistics = (
    (0.49139968, 0.48215827, 0.44653124),
     (0.24703233, 0.24348505, 0.26158768)
)

# Define transformation for data augmentation
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(*data_statistics, inplace=True)
])

# Apply data augmentation
augmented_test_images = torch.stack([transform(image) for image in test_images])

# Load the trained model
model = ResNet18()

checkpoint = torch.load('./checkpoint/ResNet_18_dropout_best.pth')

# Check the keys in the checkpoint dictionary
print(checkpoint.keys())

# Assuming the model state dictionary is saved under a different key
# Adjust this according to the actual key in your checkpoint file
model.load_state_dict(checkpoint['net'])

model =  model.to(device)

# Evaluate the model on test data
model.eval()
with torch.no_grad():
    outputs = model(augmented_test_images.to(device))
_, predicted = torch.max(outputs, 1)

predicted = predicted.to('cpu')

# Display the first 10 test images and predicted labels
plt.figure(figsize=(20, 4))
for i in range(10):
    plt.subplot(1, 10, i+1)
    plt.imshow(test_images[i])
    plt.title(label_names[predicted[i].item()].decode('utf-8'))
    plt.axis('off')
plt.show()

# Save the output in output.csv containing ID, Labels
output_data = {'ID': np.arange(len(predicted)), 'Labels': predicted.numpy()}
output_df = pd.DataFrame(output_data)
output_df.to_csv('output_resnet18_dp.csv', index=False)
# Out:
# dict_keys(['net', 'acc', 'epoch'])
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[111], line 54
#      52 model.eval()
#      53 with torch.no_grad():
# ---> 54     outputs = model(augmented_test_images.to(device))
#      55 _, predicted = torch.max(outputs, 1)
#      57 predicted = predicted.to('cpu')
#
# File ~/.local/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# Cell In[93], line 52, in ResNet.forward(self, x)
#      51 def forward(self, x):
# ---> 52   out = F.relu(self.bn1(self.conv1(x)))
#      53   out = self.layer1(out)
#      54   out = self.layer2(out)
#
# File ~/.local/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.local/lib/python3.11/site-packages/torch/nn/modules/conv.py:460, in Conv2d.forward(self, input)
#     459 def forward(self, input: Tensor) -> Tensor:
# --> 460     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/.local/lib/python3.11/site-packages/torch/nn/modules/conv.py:456, in Conv2d._conv_forward(self, input, weight, bias)
#     452 if self.padding_mode != 'zeros':
#     453     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     454                     weight, bias, self.stride,
#     455                     _pair(0), self.dilation, self.groups)
# --> 456 return F.conv2d(input, weight, bias, self.stride,
#     457                 self.padding, self.dilation, self.groups)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 2.44 GiB. GPU 0 has a total capacity of 31.74 GiB of which 699.12 MiB is free. Including non-PyTorch memory, this process has 1.28 GiB memory in use. Process 646550 has 1.77 GiB memory in use. Process 649822 has 26.75 GiB memory in use. Process 657610 has 1.25 GiB memory in use. Of the allocated memory 351.85 MiB is allocated by PyTorch, and 560.15 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %% [markdown]
# # ResNet-18 on CIFAR-10 Dataset

# %% [markdown]
# Importing PyTorch and a few Python Libraries

# %%
import os
import sys
import time
import math

import torch
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import random_split, DataLoader
from torchvision.utils import make_grid

import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
import torch.nn.init as init

from torchsummary import summary

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Preparing the dataset
#
# We will be downloading the train and test CIFAR-10 dataset from torchvision. We will normalize and transform the dataset. For the training dataset, we will also be adding Random Crops and Random Horizontal Flips to generalize the model better.

# %%
data_statistics = (
    (0.49139968, 0.48215827, 0.44653124),
     (0.24703233, 0.24348505, 0.26158768)
) # Mean, Standard Deviation of CIFAR-10 dataset channels

train_transforms = transforms.Compose([
    transforms.RandomCrop(32, padding=4, padding_mode='reflect'), # Adding Random Crops
    transforms.RandomHorizontalFlip(), # Adding Random Horizontal Flips
    transforms.ToTensor(), # Channel x Image Height x Image Width
    transforms.Normalize(*data_statistics, inplace=True) # Output in the range of [-1, 1]
])

test_transforms = transforms.Compose([
    transforms.ToTensor(), # Channel x Image Height x Image Width
    transforms.Normalize(*data_statistics, inplace=True) # Output in the range of [-1, 1]
])

# %%
train_dataset = torchvision.datasets.CIFAR10(root='./data/', download=True, train=True, transform=train_transforms)
test_dataset = torchvision.datasets.CIFAR10(root='./data/', download=True, train=False, transform=test_transforms)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# <!-- We will also be splitting the dataset further into training and validation dataset with a validation ratio of `0.2` -->
#
# We will now create data loaders to retreive images in batches. We are selecting the batch size as `128` images for our train loader. And we are selecting the batch size as `100` images for our test loader.
#
# *From PyTorch Documentation: For data loading, passing pin_memory=True to a DataLoader will automatically put the fetched data Tensors in pinned memory, and thus enables faster data transfer to CUDA-enabled GPUs.*

# %%
# validation_ratio = 0.2
# train_dataset, validation_dataset = random_split(
#     dataset,
#     [int((1 - validation_ratio) * len(dataset)), int(validation_ratio * len(dataset))]
# )

train_batch_size = 128
test_batch_size = 100

train_dl = DataLoader(train_dataset, train_batch_size, shuffle=True, num_workers=2, pin_memory=True)
# validation_dl = DataLoader(validation_dataset, batch_size, shuffle=True, num_workers=3, pin_memory=True)
test_dl = DataLoader(test_dataset, test_batch_size, shuffle=False, num_workers=2, pin_memory=True)

classes = ('plane', 'car', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck')

# %% [markdown]
# We create the following function to display a batch of images from the dataset. And we also need to denormalize the pixels values to bring them back into the range (0,1).

# %%
def denormalize(images, means, stds):
  means = torch.tensor(means).reshape(1, 3, 1, 1)
  stds = torch.tensor(stds).reshape(1, 3, 1, 1)
  return images * stds + means

def show_batch(dl):
  for images, labels in dl:
    fig, ax = plt.subplots(figsize=(12, 12))
    ax.set_xticks([])
    ax.set_yticks([])
    denorm_images = denormalize(images, *data_statistics)
    ax.imshow(make_grid(denorm_images[:64], 8).permute(1, 2, 0))
    break

# %%
show_batch(train_dl)

# %% [markdown]
# To seamlessly use a GPU, if one is available, we define a couple of helper functions (`get_default_device` & `to_device`) and a helper class `DeviceDataLoader` to move our model & data to the GPU as required.

# %%
def get_default_device():
  # Pick GPU, if available, else CPU
  if torch.cuda.is_available():
    return torch.device('cuda')
  else:
    return torch.device('cpu')

def to_device(data, device):
  # Move tensors to chosen device
  if isinstance(data, (list, tuple)):
    # If the instance is a list/tuple, transfer each element to chosen device
    return [to_device(x, device) for x in data]
  return data.to(device, non_blocking=True)
  # non_blocking=True doesn't block the execution of the host device until transfers complete

class DeviceDataLoader():
  # Wrap a dataloader to move data to a device
  def __init__(self, dl, device):
    self.dl = dl
    self.device = device

  def __iter__(self):
    # Yield a batch of data after moving it to device
    for b in self.dl:
      yield to_device(b, self.device)

  def __len__(self):
    # Number of batches
    return len(self.dl)

# %%
# Get the default device
device = get_default_device()
device
# Out:
# device(type='cuda')

# %%
train_dl = DeviceDataLoader(train_dl, device)
# validation_dl = DeviceDataLoader(validation_dl, device)
test_dl = DeviceDataLoader(test_dl, device)

# %% [markdown]
# ## Network Architecture

# %% [markdown]
# Testing the models mentioned in the `pytorch-cifar` [GitHub Repository](https://github.com/kuangliu/pytorch-cifar).

# %% [markdown]
# ### PreActResNet18

# %% [markdown]
# ### ResNet18

# %%
class BasicBlock(nn.Module):
  expansion = 1

  def __init__(self, in_planes, planes, stride=1):
    super(BasicBlock, self).__init__()
    self.conv1 = nn.Conv2d(
        in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
    self.bn1 = nn.BatchNorm2d(planes)
    self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                            stride=1, padding=1, bias=False)
    self.bn2 = nn.BatchNorm2d(planes)
    self.bn2 = nn.Dropout(p = 0.2)

    self.shortcut = nn.Sequential()
    if stride != 1 or in_planes != self.expansion*planes:
      self.shortcut = nn.Sequential(
          nn.Conv2d(in_planes, self.expansion*planes,
                    kernel_size=1, stride=stride, bias=False),
          nn.BatchNorm2d(self.expansion*planes)
      )

  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))
    out = self.bn2(self.conv2(out))
    out += self.shortcut(x)
    out = F.relu(out)
    return out

class ResNet(nn.Module):
  def __init__(self, block, num_blocks, num_classes=10):
    super(ResNet, self).__init__()
    self.in_planes = 64

    self.conv1 = nn.Conv2d(3, 64, kernel_size=3,
                            stride=1, padding=1, bias=False)
    self.bn1 = nn.BatchNorm2d(64)
    self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
    self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
    self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
    self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
    self.linear = nn.Linear(512*block.expansion, num_classes)

  def _make_layer(self, block, planes, num_blocks, stride):
    strides = [stride] + [1]*(num_blocks-1)
    layers = []
    for stride in strides:
      layers.append(block(self.in_planes, planes, stride))
      self.in_planes = planes * block.expansion
    return nn.Sequential(*layers)

  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))
    out = self.layer1(out)
    out = self.layer2(out)
    out = self.layer3(out)
    out = self.layer4(out)
    out = F.avg_pool2d(out, 4)
    out = out.view(out.size(0), -1)
    out = self.linear(out)
    return out

# %% [markdown]
# The number of parameters is `11,173,962`, which exceeds the 5 million limit.

# %% [markdown]
# ### ResNet9

# %%
def ResNet9():
  return ResNet(BasicBlock, [1, 1, 1, 1])

# %%
model = ResNet9()

# %%
model =  model.to(device)
if device == 'cuda':
  model = torch.nn.DataParallel(model)
  cudnn.benchmark = True

# %%
summary(model, input_size=(3, 32, 32))
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            1,728
# ├─BatchNorm2d: 1-2                       128
# ├─Sequential: 1-3                        --
# |    └─BasicBlock: 2-1                   --
# |    |    └─Conv2d: 3-1                  36,864
# |    |    └─BatchNorm2d: 3-2             128
# |    |    └─Conv2d: 3-3                  36,864
# |    |    └─Dropout: 3-4                 --
# |    |    └─Sequential: 3-5              --
# ├─Sequential: 1-4                        --
# |    └─BasicBlock: 2-2                   --
# |    |    └─Conv2d: 3-6                  73,728
# |    |    └─BatchNorm2d: 3-7             256
# |    |    └─Conv2d: 3-8                  147,456
# |    |    └─Dropout: 3-9                 --
# |    |    └─Sequential: 3-10             8,448
# ├─Sequential: 1-5                        --
# |    └─BasicBlock: 2-3                   --
# |    |    └─Conv2d: 3-11                 294,912
# |    |    └─BatchNorm2d: 3-12            512
# |    |    └─Conv2d: 3-13                 589,824
# |    |    └─Dropout: 3-14                --
# |    |    └─Sequential: 3-15             33,280
# ├─Sequential: 1-6                        --
# |    └─BasicBlock: 2-4                   --
# |    |    └─Conv2d: 3-16                 1,179,648
# |    |    └─BatchNorm2d: 3-17            1,024
# |    |    └─Conv2d: 3-18                 2,359,296
# |    |    └─Dropout: 3-19                --
# |    |    └─Sequential: 3-20             132,096
# ├─Linear: 1-7                            5,130
# =================================================================
# Total params: 4,901,322
# Trainable params: 4,901,322
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            1,728
# ├─BatchNorm2d: 1-2                       128
# ├─Sequential: 1-3                        --
# |    └─BasicBlock: 2-1                   --
# |    |    └─Conv2d: 3-1                  36,864
# |    |    └─BatchNorm2d: 3-2             128
# |    |    └─Conv2d: 3-3                  36,864
# |    |    └─Dropout: 3-4                 --
# |    |    └─Sequential: 3-5              --
# ├─Sequential: 1-4                        --
# |    └─BasicBlock: 2-2                   --
# |    |    └─Conv2d: 3-6                  73,728
# |    |    └─BatchNorm2d: 3-7             256
# |    |    └─Conv2d: 3-8                  147,456
# |    |    └─Dropout: 3-9                 --
# |    |    └─Sequential: 3-10             8,448
# ├─Sequential: 1-5                        --
# |    └─BasicBlock: 2-3                   --
# |    |    └─Conv2d: 3-11                 294,912
# |    |    └─BatchNorm2d: 3-12            512
# |    |    └─Conv2d: 3-13                 589,824
# |    |    └─Dropout: 3-14                --
# |    |    └─Sequential: 3-15             33,280
# ├─Sequential: 1-6                        --
# |    └─BasicBlock: 2-4                   --
# |    |    └─Conv2d: 3-16                 1,179,648
# |    |    └─BatchNorm2d: 3-17            1,024
# |    |    └─Conv2d: 3-18                 2,359,296
# |    |    └─Dropout: 3-19                --
# |    |    └─Sequential: 3-20             132,096
# ├─Linear: 1-7                            5,130
# =================================================================
# Total params: 4,901,322
# Trainable params: 4,901,322
# Non-trainable params: 0
# =================================================================

# %% [markdown]
# ## Model Training

# %%
def format_time(seconds):
  days = int(seconds / 3600/24)
  seconds = seconds - days*3600*24
  hours = int(seconds / 3600)
  seconds = seconds - hours*3600
  minutes = int(seconds / 60)
  seconds = seconds - minutes*60
  secondsf = int(seconds)
  seconds = seconds - secondsf
  millis = int(seconds*1000)

  f = ''
  i = 1
  if days > 0:
    f += str(days) + 'D'
    i += 1
  if hours > 0 and i <= 2:
    f += str(hours) + 'h'
    i += 1
  if minutes > 0 and i <= 2:
    f += str(minutes) + 'm'
    i += 1
  if secondsf > 0 and i <= 2:
    f += str(secondsf) + 's'
    i += 1
  if millis > 0 and i <= 2:
    f += str(millis) + 'ms'
    i += 1
  if f == '':
    f = '0ms'
  return f

# %%
lr = 0.1
momentum = 0.9
weight_decay = 5e-4

start_epoch = 1
number_of_epochs = 100
best_acc = 0


criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=lr,
                      momentum=momentum, weight_decay=weight_decay)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=number_of_epochs)

# %%
def get_lr(optimizer):
  for param_group in optimizer.param_groups:
    return param_group['lr']

# %%
def train(epoch):
  print('\nEpoch: %d' % epoch)
  start_time = time.time()

  model.train()
  train_loss = 0
  correct = 0
  total = 0
  for batch_idx, (inputs, targets) in enumerate(train_dl):
    # inputs, targets = inputs.to(device), targets.to(device)
    optimizer.zero_grad()
    outputs = model(inputs)
    loss = criterion(outputs, targets)
    loss.backward()
    optimizer.step()

    train_loss += loss.item()
    _, predicted = outputs.max(1)
    total += targets.size(0)
    correct += predicted.eq(targets).sum().item()

  cur_time = time.time()
  epoch_time = cur_time - start_time
  print(f"Time taken : {format_time(epoch_time)}")

  return train_loss/(batch_idx+1), 100.*correct/total, get_lr(optimizer)

# %%
def test(epoch):
  global best_acc
  model.eval()
  test_loss = 0
  correct = 0
  total = 0
  with torch.no_grad():
    for batch_idx, (inputs, targets) in enumerate(test_dl):
      # inputs, targets = inputs.to(device), targets.to(device)
      outputs = model(inputs)
      loss = criterion(outputs, targets)

      test_loss += loss.item()
      _, predicted = outputs.max(1)
      total += targets.size(0)
      correct += predicted.eq(targets).sum().item()
      


  # Save checkpoint.
  acc = 100.*correct/total
  if acc > best_acc:
    print('Saving..')
    state = {
        'net': model.state_dict(),
        'acc': acc,
        'epoch': epoch,
    }
    if not os.path.isdir('checkpoint'):
      os.mkdir('checkpoint')
    torch.save(state, './checkpoint/ResNet_9_dropout_best.pth')
    best_acc = acc

  return test_loss/(batch_idx+1), 100.*correct/total

# %%
train_losses = []
train_accuracies = []
train_lrs = []

test_losses = []
test_accuracies = []

for epoch in range(start_epoch, start_epoch + number_of_epochs):
  epoch_train_loss, epoch_train_accuracy, epoch_lr = train(epoch)
  train_losses.append(epoch_train_loss)
  train_accuracies.append(epoch_train_accuracy)
  train_lrs.append(epoch_lr)

  epoch_test_loss, epoch_test_accuracy = test(epoch)
  test_losses.append(epoch_test_loss)
  test_accuracies.append(epoch_test_accuracy)

  scheduler.step()

  print(f"Train Loss: {epoch_train_loss:.3f} | Train Accuracy: {epoch_train_accuracy:.3f}% | Test Loss: {epoch_test_loss:.3f} | Test Accuracy: {epoch_test_accuracy:.3f}%")
# Out:
# Epoch: 1
# Time taken : 35s197ms
# Saving..
# Train Loss: 1.503 | Train Accuracy: 44.442% | Test Loss: 1.370 | Test Accuracy: 51.580%
#
# Epoch: 2
# Time taken : 32s487ms
# Saving..
# Train Loss: 1.058 | Train Accuracy: 62.080% | Test Loss: 1.082 | Test Accuracy: 62.450%
#
# Epoch: 3
# Time taken : 33s118ms
# Saving..
# Train Loss: 0.882 | Train Accuracy: 68.704% | Test Loss: 0.778 | Test Accuracy: 73.210%
#
# Epoch: 4
# Time taken : 34s349ms
# Train Loss: 0.767 | Train Accuracy: 73.048% | Test Loss: 0.791 | Test Accuracy: 72.680%
#
# Epoch: 5
# Time taken : 32s740ms
# Saving..
# Train Loss: 0.687 | Train Accuracy: 76.070% | Test Loss: 0.630 | Test Accuracy: 77.970%
#
# Epoch: 6
# Time taken : 33s648ms
# Train Loss: 0.632 | Train Accuracy: 78.268% | Test Loss: 0.686 | Test Accuracy: 77.460%
#
# Epoch: 7
# Time taken : 46s225ms
# Train Loss: 0.597 | Train Accuracy: 79.226% | Test Loss: 0.661 | Test Accuracy: 77.020%
#
# Epoch: 8
# Time taken : 43s121ms
# Saving..
# Train Loss: 0.575 | Train Accuracy: 80.130% | Test Loss: 0.626 | Test Accuracy: 78.520%
#
# Epoch: 9
# Time taken : 45s304ms
# Saving..
# Train Loss: 0.548 | Train Accuracy: 80.928% | Test Loss: 0.594 | Test Accuracy: 79.930%
#
# Epoch: 10
# Time taken : 44s18ms
# Train Loss: 0.523 | Train Accuracy: 81.968% | Test Loss: 0.614 | Test Accuracy: 79.870%
#
# Epoch: 11
# Time taken : 43s333ms
# Train Loss: 0.516 | Train Accuracy: 82.204% | Test Loss: 0.638 | Test Accuracy: 78.230%
#
# Epoch: 12
# Time taken : 46s747ms
# Train Loss: 0.499 | Train Accuracy: 82.880% | Test Loss: 0.773 | Test Accuracy: 75.660%
#
# Epoch: 13
# Time taken : 44s236ms
# Train Loss: 0.481 | Train Accuracy: 83.398% | Test Loss: 0.669 | Test Accuracy: 79.410%
#
# Epoch: 14
# Time taken : 42s487ms
# Train Loss: 0.476 | Train Accuracy: 83.636% | Test Loss: 0.649 | Test Accuracy: 78.480%
#
# Epoch: 15
# Time taken : 46s340ms
# Train Loss: 0.470 | Train Accuracy: 83.866% | Test Loss: 0.603 | Test Accuracy: 79.330%
#
# Epoch: 16
# Time taken : 43s27ms
# Train Loss: 0.460 | Train Accuracy: 84.282% | Test Loss: 0.662 | Test Accuracy: 79.310%
#
# Epoch: 17
# Time taken : 44s967ms
# Train Loss: 0.451 | Train Accuracy: 84.536% | Test Loss: 0.666 | Test Accuracy: 79.350%
#
# Epoch: 18
# Time taken : 45s837ms
# Train Loss: 0.443 | Train Accuracy: 84.730% | Test Loss: 0.640 | Test Accuracy: 79.460%
#
# Epoch: 19
# Time taken : 42s774ms
# Saving..
# Train Loss: 0.432 | Train Accuracy: 85.090% | Test Loss: 0.502 | Test Accuracy: 83.310%
#
# Epoch: 20
# Time taken : 45s697ms
# Train Loss: 0.428 | Train Accuracy: 85.296% | Test Loss: 0.531 | Test Accuracy: 81.940%
#
# Epoch: 21
# Time taken : 44s292ms
# Saving..
# Train Loss: 0.425 | Train Accuracy: 85.296% | Test Loss: 0.440 | Test Accuracy: 85.100%
#
# Epoch: 22
# Time taken : 43s688ms
# Train Loss: 0.422 | Train Accuracy: 85.410% | Test Loss: 0.549 | Test Accuracy: 82.200%
#
# Epoch: 23
# Time taken : 46s143ms
# Saving..
# Train Loss: 0.414 | Train Accuracy: 85.644% | Test Loss: 0.429 | Test Accuracy: 85.870%
#
# Epoch: 24
# Time taken : 44s961ms
# Train Loss: 0.399 | Train Accuracy: 86.320% | Test Loss: 0.488 | Test Accuracy: 84.000%
#
# Epoch: 25
# Time taken : 44s193ms
# Train Loss: 0.406 | Train Accuracy: 86.072% | Test Loss: 0.598 | Test Accuracy: 81.440%
#
# Epoch: 26
# Time taken : 45s943ms
# Train Loss: 0.400 | Train Accuracy: 86.376% | Test Loss: 0.487 | Test Accuracy: 84.310%
#
# Epoch: 27
# Time taken : 43s781ms
# Train Loss: 0.394 | Train Accuracy: 86.456% | Test Loss: 0.575 | Test Accuracy: 81.290%
#
# Epoch: 28
# Time taken : 44s564ms
# Train Loss: 0.390 | Train Accuracy: 86.638% | Test Loss: 0.610 | Test Accuracy: 80.480%
#
# Epoch: 29
# Time taken : 46s516ms
# Train Loss: 0.385 | Train Accuracy: 86.670% | Test Loss: 0.604 | Test Accuracy: 81.060%
#
# Epoch: 30
# Time taken : 44s533ms
# Train Loss: 0.381 | Train Accuracy: 86.926% | Test Loss: 0.552 | Test Accuracy: 82.490%
#
# Epoch: 31
# Time taken : 45s47ms
# Train Loss: 0.380 | Train Accuracy: 87.002% | Test Loss: 0.454 | Test Accuracy: 84.990%
#
# Epoch: 32
# Time taken : 45s850ms
# Train Loss: 0.374 | Train Accuracy: 87.262% | Test Loss: 0.443 | Test Accuracy: 85.300%
#
# Epoch: 33
# Time taken : 44s451ms
# Train Loss: 0.367 | Train Accuracy: 87.338% | Test Loss: 0.506 | Test Accuracy: 84.260%
#
# Epoch: 34
# Time taken : 44s62ms
# Train Loss: 0.361 | Train Accuracy: 87.510% | Test Loss: 0.483 | Test Accuracy: 83.960%
#
# Epoch: 35
# Time taken : 46s372ms
# Train Loss: 0.360 | Train Accuracy: 87.722% | Test Loss: 0.457 | Test Accuracy: 84.490%
#
# Epoch: 36
# Time taken : 42s967ms
# Train Loss: 0.359 | Train Accuracy: 87.726% | Test Loss: 0.471 | Test Accuracy: 84.530%
#
# Epoch: 37
# Time taken : 44s918ms
# Train Loss: 0.347 | Train Accuracy: 88.138% | Test Loss: 0.547 | Test Accuracy: 82.320%
#
# Epoch: 38
# Time taken : 46s194ms
# Train Loss: 0.347 | Train Accuracy: 88.078% | Test Loss: 0.454 | Test Accuracy: 84.660%
#
# Epoch: 39
# Time taken : 44s485ms
# Saving..
# Train Loss: 0.344 | Train Accuracy: 88.156% | Test Loss: 0.404 | Test Accuracy: 86.560%
#
# Epoch: 40
# Time taken : 45s949ms
# Saving..
# Train Loss: 0.341 | Train Accuracy: 88.370% | Test Loss: 0.403 | Test Accuracy: 86.770%
#
# Epoch: 41
# Time taken : 45s91ms
# Train Loss: 0.330 | Train Accuracy: 88.708% | Test Loss: 0.436 | Test Accuracy: 86.090%
#
# Epoch: 42
# Time taken : 44s41ms
# Train Loss: 0.326 | Train Accuracy: 88.768% | Test Loss: 0.459 | Test Accuracy: 85.370%
#
# Epoch: 43
# Time taken : 45s321ms
# Train Loss: 0.317 | Train Accuracy: 89.066% | Test Loss: 0.421 | Test Accuracy: 86.560%
#
# Epoch: 44
# Time taken : 44s765ms
# Saving..
# Train Loss: 0.318 | Train Accuracy: 89.086% | Test Loss: 0.400 | Test Accuracy: 86.850%
#
# Epoch: 45
# Time taken : 44s124ms
# Train Loss: 0.317 | Train Accuracy: 89.200% | Test Loss: 0.414 | Test Accuracy: 86.770%
#
# Epoch: 46
# Time taken : 45s979ms
# Train Loss: 0.306 | Train Accuracy: 89.552% | Test Loss: 0.581 | Test Accuracy: 82.570%
#
# Epoch: 47
# Time taken : 45s342ms
# Train Loss: 0.309 | Train Accuracy: 89.370% | Test Loss: 0.519 | Test Accuracy: 83.890%
#
# Epoch: 48
# Time taken : 43s662ms
# Saving..
# Train Loss: 0.295 | Train Accuracy: 89.868% | Test Loss: 0.392 | Test Accuracy: 87.170%
#
# Epoch: 49
# Time taken : 45s917ms
# Train Loss: 0.294 | Train Accuracy: 89.906% | Test Loss: 0.423 | Test Accuracy: 86.390%
#
# Epoch: 50
# Time taken : 45s62ms
# Train Loss: 0.283 | Train Accuracy: 90.254% | Test Loss: 0.440 | Test Accuracy: 86.320%
#
# Epoch: 51
# Time taken : 44s590ms
# Saving..
# Train Loss: 0.285 | Train Accuracy: 90.152% | Test Loss: 0.344 | Test Accuracy: 88.650%
#
# Epoch: 52
# Time taken : 43s200ms
# Train Loss: 0.282 | Train Accuracy: 90.334% | Test Loss: 0.419 | Test Accuracy: 86.200%
#
# Epoch: 53
# Time taken : 44s845ms
# Train Loss: 0.278 | Train Accuracy: 90.428% | Test Loss: 0.360 | Test Accuracy: 87.850%
#
# Epoch: 54
# Time taken : 43s856ms
# Train Loss: 0.268 | Train Accuracy: 90.824% | Test Loss: 0.454 | Test Accuracy: 86.030%
#
# Epoch: 55
# Time taken : 46s357ms
# Train Loss: 0.265 | Train Accuracy: 90.750% | Test Loss: 0.416 | Test Accuracy: 86.590%
#
# Epoch: 56
# Time taken : 45s277ms
# Train Loss: 0.259 | Train Accuracy: 91.126% | Test Loss: 0.386 | Test Accuracy: 87.770%
#
# Epoch: 57
# Time taken : 43s442ms
# Train Loss: 0.254 | Train Accuracy: 91.248% | Test Loss: 0.384 | Test Accuracy: 87.860%
#
# Epoch: 58
# Time taken : 44s639ms
# Saving..
# Train Loss: 0.245 | Train Accuracy: 91.568% | Test Loss: 0.316 | Test Accuracy: 89.880%
#
# Epoch: 59
# Time taken : 43s945ms
# Train Loss: 0.246 | Train Accuracy: 91.502% | Test Loss: 0.319 | Test Accuracy: 89.390%
#
# Epoch: 60
# Time taken : 46s70ms
# Train Loss: 0.238 | Train Accuracy: 91.718% | Test Loss: 0.354 | Test Accuracy: 88.710%
#
# Epoch: 61
# Time taken : 45s921ms
# Train Loss: 0.225 | Train Accuracy: 92.202% | Test Loss: 0.313 | Test Accuracy: 89.790%
#
# Epoch: 62
# Time taken : 44s237ms
# Saving..
# Train Loss: 0.228 | Train Accuracy: 91.924% | Test Loss: 0.317 | Test Accuracy: 89.950%
#
# Epoch: 63
# Time taken : 44s370ms
# Saving..
# Train Loss: 0.213 | Train Accuracy: 92.504% | Test Loss: 0.320 | Test Accuracy: 90.030%
#
# Epoch: 64
# Time taken : 45s618ms
# Train Loss: 0.210 | Train Accuracy: 92.730% | Test Loss: 0.323 | Test Accuracy: 89.760%
#
# Epoch: 65
# Time taken : 43s689ms
# Saving..
# Train Loss: 0.208 | Train Accuracy: 92.730% | Test Loss: 0.281 | Test Accuracy: 91.030%
#
# Epoch: 66
# Time taken : 46s456ms
# Train Loss: 0.196 | Train Accuracy: 93.300% | Test Loss: 0.395 | Test Accuracy: 88.600%
#
# Epoch: 67
# Time taken : 44s79ms
# Train Loss: 0.188 | Train Accuracy: 93.494% | Test Loss: 0.325 | Test Accuracy: 89.640%
#
# Epoch: 68
# Time taken : 44s65ms
# Train Loss: 0.185 | Train Accuracy: 93.582% | Test Loss: 0.348 | Test Accuracy: 89.360%
#
# Epoch: 69
# Time taken : 45s540ms
# Train Loss: 0.179 | Train Accuracy: 93.786% | Test Loss: 0.302 | Test Accuracy: 90.290%
#
# Epoch: 70
# Time taken : 43s90ms
# Train Loss: 0.170 | Train Accuracy: 94.210% | Test Loss: 0.320 | Test Accuracy: 90.120%
#
# Epoch: 71
# Time taken : 43s748ms
# Train Loss: 0.166 | Train Accuracy: 94.140% | Test Loss: 0.338 | Test Accuracy: 89.750%
#
# Epoch: 72
# Time taken : 46s439ms
# Train Loss: 0.157 | Train Accuracy: 94.538% | Test Loss: 0.306 | Test Accuracy: 90.950%
#
# Epoch: 73
# Time taken : 43s808ms
# Train Loss: 0.145 | Train Accuracy: 95.016% | Test Loss: 0.314 | Test Accuracy: 90.790%
#
# Epoch: 74
# Time taken : 44s479ms
# Train Loss: 0.140 | Train Accuracy: 95.148% | Test Loss: 0.319 | Test Accuracy: 90.570%
#
# Epoch: 75
# Time taken : 45s840ms
# Train Loss: 0.133 | Train Accuracy: 95.338% | Test Loss: 0.328 | Test Accuracy: 90.420%
#
# Epoch: 76
# Time taken : 42s759ms
# Train Loss: 0.128 | Train Accuracy: 95.548% | Test Loss: 0.309 | Test Accuracy: 90.800%
#
# Epoch: 77
# Time taken : 45s976ms
# Saving..
# Train Loss: 0.121 | Train Accuracy: 95.884% | Test Loss: 0.295 | Test Accuracy: 92.030%
#
# Epoch: 78
# Time taken : 45s190ms
# Train Loss: 0.110 | Train Accuracy: 96.188% | Test Loss: 0.279 | Test Accuracy: 91.850%
#
# Epoch: 79
# Time taken : 43s956ms
# Saving..
# Train Loss: 0.106 | Train Accuracy: 96.420% | Test Loss: 0.265 | Test Accuracy: 92.070%
#
# Epoch: 80
# Time taken : 45s578ms
# Saving..
# Train Loss: 0.095 | Train Accuracy: 96.666% | Test Loss: 0.241 | Test Accuracy: 92.860%
#
# Epoch: 81
# Time taken : 44s149ms
# Train Loss: 0.093 | Train Accuracy: 96.726% | Test Loss: 0.270 | Test Accuracy: 92.610%
#
# Epoch: 82
# Time taken : 44s121ms
# Train Loss: 0.082 | Train Accuracy: 97.200% | Test Loss: 0.263 | Test Accuracy: 92.490%
#
# Epoch: 83
# Time taken : 45s935ms
# Train Loss: 0.076 | Train Accuracy: 97.436% | Test Loss: 0.254 | Test Accuracy: 92.760%
#
# Epoch: 84
# Time taken : 44s432ms
# Train Loss: 0.070 | Train Accuracy: 97.658% | Test Loss: 0.271 | Test Accuracy: 92.440%
#
# Epoch: 85
# Time taken : 44s673ms
# Train Loss: 0.064 | Train Accuracy: 97.922% | Test Loss: 0.269 | Test Accuracy: 92.650%
#
# Epoch: 86
# Time taken : 45s718ms
# Saving..
# Train Loss: 0.059 | Train Accuracy: 98.072% | Test Loss: 0.245 | Test Accuracy: 93.370%
#
# Epoch: 87
# Time taken : 43s258ms
# Train Loss: 0.053 | Train Accuracy: 98.306% | Test Loss: 0.245 | Test Accuracy: 93.370%
#
# Epoch: 88
# Time taken : 44s398ms
# Saving..
# Train Loss: 0.052 | Train Accuracy: 98.294% | Test Loss: 0.228 | Test Accuracy: 93.630%
#
# Epoch: 89
# Time taken : 45s122ms
# Saving..
# Train Loss: 0.042 | Train Accuracy: 98.690% | Test Loss: 0.229 | Test Accuracy: 93.890%
#
# Epoch: 90
# Time taken : 42s912ms
# Train Loss: 0.040 | Train Accuracy: 98.670% | Test Loss: 0.233 | Test Accuracy: 93.610%
#
# Epoch: 91
# Time taken : 45s151ms
# Train Loss: 0.036 | Train Accuracy: 98.872% | Test Loss: 0.237 | Test Accuracy: 93.780%
#
# Epoch: 92
# Time taken : 47s72ms
# Saving..
# Train Loss: 0.033 | Train Accuracy: 99.032% | Test Loss: 0.227 | Test Accuracy: 93.900%
#
# Epoch: 93
# Time taken : 43s774ms
# Train Loss: 0.032 | Train Accuracy: 99.052% | Test Loss: 0.226 | Test Accuracy: 93.800%
#
# Epoch: 94
# Time taken : 46s284ms
# Saving..
# Train Loss: 0.030 | Train Accuracy: 99.150% | Test Loss: 0.225 | Test Accuracy: 94.030%
#
# Epoch: 95
# Time taken : 45s406ms
# Saving..
# Train Loss: 0.029 | Train Accuracy: 99.174% | Test Loss: 0.230 | Test Accuracy: 94.050%
#
# Epoch: 96
# Time taken : 44s307ms
# Saving..
# Train Loss: 0.028 | Train Accuracy: 99.240% | Test Loss: 0.225 | Test Accuracy: 94.130%
#
# Epoch: 97
# Time taken : 44s677ms
# Train Loss: 0.027 | Train Accuracy: 99.232% | Test Loss: 0.225 | Test Accuracy: 94.090%
#
# Epoch: 98
# Time taken : 44s763ms
# Train Loss: 0.026 | Train Accuracy: 99.272% | Test Loss: 0.228 | Test Accuracy: 94.050%
#
# Epoch: 99
# Time taken : 43s291ms
# Train Loss: 0.026 | Train Accuracy: 99.302% | Test Loss: 0.227 | Test Accuracy: 94.120%
#
# Epoch: 100
# Time taken : 46s251ms
# Saving..
# Train Loss: 0.027 | Train Accuracy: 99.232% | Test Loss: 0.227 | Test Accuracy: 94.140%

# %%
print('Best Accuracy : ', best_acc)
# Out:
# Best Accuracy :  94.14

# %%
def plot_accuracies(train_accuracies, test_accuracies):
  plt.plot(train_accuracies, label='Train Accuracy')
  plt.plot(test_accuracies, label='Test Accuracy')
  plt.xlabel('Epochs')
  plt.ylabel('Accuracy')
  plt.legend()
  plt.grid(True)
  plt.title('Accuracy vs. No. of epochs')

# %%
def plot_losses(train_losses, test_losses):
  plt.plot(train_losses, label='Train Losses')
  plt.plot(test_losses, label='Test Losses')
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.legend()
  plt.grid(True)
  plt.title('Loss vs. No. of epochs')

# %%
def plot_lrs(train_lrs):
  plt.plot(train_lrs)
  plt.xlabel('Epochs')
  plt.ylabel('Learning rate')
  plt.grid(True)
  plt.title('Learning Rate vs. Epochs')

# %%
plot_accuracies(train_accuracies, test_accuracies)

# %%
plot_losses(train_losses, test_losses)

# %%
plot_lrs(train_lrs)

# %%
print('Saving final model..')
state = {
    'net': model.state_dict(),
    'acc': test_accuracies[-1],
    'epoch': number_of_epochs,
    'best_acc' : best_acc,
    'train_acc' : train_accuracies,
    'test_acc' : test_accuracies,
    'train_loss' : train_losses,
    'test_loss' : test_losses,
    'lr' : train_lrs
}
if not os.path.isdir('checkpoint'):
  os.mkdir('checkpoint')
torch.save(state, './checkpoint/ResNet_9_dropout_final.pth')
# Out:
# Saving final model..

# %%
import numpy as np
import pickle
from tqdm import tqdm
import pandas as pd

# Function to load CIFAR batch
def load_cifar_batch(file):
    with open(file, 'rb') as fo:
        batch = pickle.load(fo, encoding='bytes')
    return batch

# Specify the folder where the CIFAR-10 batch files are
cifar10_dir = 'data/cifar-10-batches-py/'

# Load the label names
meta_data_dict = load_cifar_batch(os.path.join(cifar10_dir, 'batches.meta'))
label_names = meta_data_dict[b'label_names']

# Load test data
test_batch = load_cifar_batch('CIFAR-10/cifar_test_nolabels.pkl')
test_images = test_batch[b'data'].reshape(-1, 3, 32, 32).transpose(0, 2, 3, 1)

data_statistics = (
    (0.49139968, 0.48215827, 0.44653124),
     (0.24703233, 0.24348505, 0.26158768)
)

# Define transformation for data augmentation
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(*data_statistics, inplace=True)
])

# Apply data augmentation
augmented_test_images = torch.stack([transform(image) for image in test_images])

# Load the trained model
model = ResNet9()

checkpoint = torch.load('./checkpoint/ResNet_9_dropout_best.pth')

# Check the keys in the checkpoint dictionary
print(checkpoint.keys())

# Assuming the model state dictionary is saved under a different key
# Adjust this according to the actual key in your checkpoint file
model.load_state_dict(checkpoint['net'])

model =  model.to(device)

# Evaluate the model on test data
model.eval()
with torch.no_grad():
    outputs = model(augmented_test_images.to(device))
_, predicted = torch.max(outputs, 1)

predicted = predicted.to('cpu')

# Display the first 10 test images and predicted labels
plt.figure(figsize=(20, 4))
for i in range(10):
    plt.subplot(1, 10, i+1)
    plt.imshow(test_images[i])
    plt.title(label_names[predicted[i].item()].decode('utf-8'))
    plt.axis('off')
plt.show()

# Save the output in output.csv containing ID, Labels
output_data = {'ID': np.arange(len(predicted)), 'Labels': predicted.numpy()}
output_df = pd.DataFrame(output_data)
output_df.to_csv('output_resnet9_dropout.csv', index=False)
# Out:
# dict_keys(['net', 'acc', 'epoch'])

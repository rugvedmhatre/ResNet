# %% [markdown]
# # ResNet-18 on CIFAR-10 Dataset

# %% [markdown]
# Importing PyTorch and a few Python Libraries

# %%
import os
import sys
import time
import math

import torch
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import random_split, DataLoader
from torchvision.utils import make_grid

import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
import torch.nn.init as init

from torchsummary import summary

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Preparing the dataset
#
# We will be downloading the train and test CIFAR-10 dataset from torchvision. We will normalize and transform the dataset. For the training dataset, we will also be adding Random Crops and Random Horizontal Flips to generalize the model better.

# %%
data_statistics = (
    (0.49139968, 0.48215827, 0.44653124),
     (0.24703233, 0.24348505, 0.26158768)
) # Mean, Standard Deviation of CIFAR-10 dataset channels

train_transforms = transforms.Compose([
    transforms.RandomCrop(32, padding=4, padding_mode='reflect'), # Adding Random Crops
    transforms.RandomHorizontalFlip(), # Adding Random Horizontal Flips
    transforms.ToTensor(), # Channel x Image Height x Image Width
    transforms.Normalize(*data_statistics, inplace=True) # Output in the range of [-1, 1]
])

test_transforms = transforms.Compose([
    transforms.ToTensor(), # Channel x Image Height x Image Width
    transforms.Normalize(*data_statistics, inplace=True) # Output in the range of [-1, 1]
])

# %%
train_dataset = torchvision.datasets.CIFAR10(root='./data/', download=True, train=True, transform=train_transforms)
test_dataset = torchvision.datasets.CIFAR10(root='./data/', download=True, train=False, transform=test_transforms)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# <!-- We will also be splitting the dataset further into training and validation dataset with a validation ratio of `0.2` -->
#
# We will now create data loaders to retreive images in batches. We are selecting the batch size as `128` images for our train loader. And we are selecting the batch size as `100` images for our test loader.
#
# *From PyTorch Documentation: For data loading, passing pin_memory=True to a DataLoader will automatically put the fetched data Tensors in pinned memory, and thus enables faster data transfer to CUDA-enabled GPUs.*

# %%
# validation_ratio = 0.2
# train_dataset, validation_dataset = random_split(
#     dataset,
#     [int((1 - validation_ratio) * len(dataset)), int(validation_ratio * len(dataset))]
# )

train_batch_size = 128
test_batch_size = 100

train_dl = DataLoader(train_dataset, train_batch_size, shuffle=True, num_workers=2, pin_memory=True)
# validation_dl = DataLoader(validation_dataset, batch_size, shuffle=True, num_workers=3, pin_memory=True)
test_dl = DataLoader(test_dataset, test_batch_size, shuffle=False, num_workers=2, pin_memory=True)

classes = ('plane', 'car', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck')

# %% [markdown]
# We create the following function to display a batch of images from the dataset. And we also need to denormalize the pixels values to bring them back into the range (0,1).

# %%
def denormalize(images, means, stds):
  means = torch.tensor(means).reshape(1, 3, 1, 1)
  stds = torch.tensor(stds).reshape(1, 3, 1, 1)
  return images * stds + means

def show_batch(dl):
  for images, labels in dl:
    fig, ax = plt.subplots(figsize=(12, 12))
    ax.set_xticks([])
    ax.set_yticks([])
    denorm_images = denormalize(images, *data_statistics)
    ax.imshow(make_grid(denorm_images[:64], 8).permute(1, 2, 0))
    break

# %%
show_batch(train_dl)

# %% [markdown]
# To seamlessly use a GPU, if one is available, we define a couple of helper functions (`get_default_device` & `to_device`) and a helper class `DeviceDataLoader` to move our model & data to the GPU as required.

# %%
def get_default_device():
  # Pick GPU, if available, else CPU
  if torch.cuda.is_available():
    return torch.device('cuda')
  else:
    return torch.device('cpu')

def to_device(data, device):
  # Move tensors to chosen device
  if isinstance(data, (list, tuple)):
    # If the instance is a list/tuple, transfer each element to chosen device
    return [to_device(x, device) for x in data]
  return data.to(device, non_blocking=True)
  # non_blocking=True doesn't block the execution of the host device until transfers complete

class DeviceDataLoader():
  # Wrap a dataloader to move data to a device
  def __init__(self, dl, device):
    self.dl = dl
    self.device = device

  def __iter__(self):
    # Yield a batch of data after moving it to device
    for b in self.dl:
      yield to_device(b, self.device)

  def __len__(self):
    # Number of batches
    return len(self.dl)

# %%
# Get the default device
device = get_default_device()
device
# Out:
# device(type='cuda')

# %%
train_dl = DeviceDataLoader(train_dl, device)
# validation_dl = DeviceDataLoader(validation_dl, device)
test_dl = DeviceDataLoader(test_dl, device)

# %% [markdown]
# ## Network Architecture

# %% [markdown]
# Testing the models mentioned in the `pytorch-cifar` [GitHub Repository](https://github.com/kuangliu/pytorch-cifar).

# %% [markdown]
# ### PreActResNet18

# %%
class PreActBlock(nn.Module):
  '''Pre-activation version of the BasicBlock.'''
  expansion = 1

  def __init__(self, in_planes, planes, stride=1):
    super(PreActBlock, self).__init__()
    self.bn1 = nn.BatchNorm2d(in_planes)
    self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
    self.bn2 = nn.BatchNorm2d(planes)
    self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)

    if stride != 1 or in_planes != self.expansion*planes:
      self.shortcut = nn.Sequential(
          nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False)
      )

  def forward(self, x):
    out = F.relu(self.bn1(x))
    shortcut = self.shortcut(out) if hasattr(self, 'shortcut') else x
    out = self.conv1(out)
    out = self.conv2(F.relu(self.bn2(out)))
    out += shortcut
    return out

class PreActResNet(nn.Module):
  def __init__(self, block, num_blocks, num_classes=10):
    super(PreActResNet, self).__init__()
    self.in_planes = 64

    self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
    self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
    self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
    self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
    self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
    self.linear = nn.Linear(512*block.expansion, num_classes)

  def _make_layer(self, block, planes, num_blocks, stride):
    strides = [stride] + [1]*(num_blocks-1)
    layers = []
    for stride in strides:
        layers.append(block(self.in_planes, planes, stride))
        self.in_planes = planes * block.expansion
    return nn.Sequential(*layers)

  def forward(self, x):
    out = self.conv1(x)
    out = self.layer1(out)
    out = self.layer2(out)
    out = self.layer3(out)
    out = self.layer4(out)
    out = F.avg_pool2d(out, 4)
    out = out.view(out.size(0), -1)
    out = self.linear(out)
    return out

def PreActResNet18():
  return PreActResNet(PreActBlock, [2,2,2,2])

# %%
# model = PreActResNet18()

# %% [markdown]
# The number of parameters is `11,171,146`, which exceeds the 5 million limit.

# %% [markdown]
# ### ResNet18

# %%
class BasicBlock(nn.Module):
  expansion = 1

  def __init__(self, in_planes, planes, stride=1):
    super(BasicBlock, self).__init__()
    self.conv1 = nn.Conv2d(
        in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
    self.bn1 = nn.BatchNorm2d(planes)
    self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                            stride=1, padding=1, bias=False)
    self.bn2 = nn.BatchNorm2d(planes)
    self.bn2 = nn.Dropout(p = 0.2)

    self.shortcut = nn.Sequential()
    if stride != 1 or in_planes != self.expansion*planes:
      self.shortcut = nn.Sequential(
          nn.Conv2d(in_planes, self.expansion*planes,
                    kernel_size=1, stride=stride, bias=False),
          nn.BatchNorm2d(self.expansion*planes)
      )

  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))
    out = self.bn2(self.conv2(out))
    out += self.shortcut(x)
    out = F.relu(out)
    return out

class ResNet(nn.Module):
  def __init__(self, block, num_blocks, num_classes=10):
    super(ResNet, self).__init__()
    self.in_planes = 64

    self.conv1 = nn.Conv2d(3, 64, kernel_size=3,
                            stride=1, padding=1, bias=False)
    self.bn1 = nn.BatchNorm2d(64)
    self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
    self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
    self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
    self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
    self.linear = nn.Linear(512*block.expansion, num_classes)

  def _make_layer(self, block, planes, num_blocks, stride):
    strides = [stride] + [1]*(num_blocks-1)
    layers = []
    for stride in strides:
      layers.append(block(self.in_planes, planes, stride))
      self.in_planes = planes * block.expansion
    return nn.Sequential(*layers)

  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))
    out = self.layer1(out)
    out = self.layer2(out)
    out = self.layer3(out)
    out = self.layer4(out)
    out = F.avg_pool2d(out, 4)
    out = out.view(out.size(0), -1)
    out = self.linear(out)
    return out

def ResNet18():
  return ResNet(BasicBlock, [2, 2, 2, 2])

# %%
# model = ResNet18()

# %% [markdown]
# The number of parameters is `11,173,962`, which exceeds the 5 million limit.

# %% [markdown]
# ### ResNet9

# %%
def ResNet9():
  return ResNet(BasicBlock, [1, 1, 1, 1])

# %%
model = ResNet9()

# %% [markdown]
# ### PreActResNet9

# %%
def PreActResNet9():
  return PreActResNet(PreActBlock, [1,1,1,1])

# %%
# model = PreActResNet9()

# %%
model =  model.to(device)
if device == 'cuda':
  model = torch.nn.DataParallel(model)
  cudnn.benchmark = True

# %%
summary(model, input_size=(3, 32, 32))

# %% [markdown]
# ## Model Training

# %%
# Helper Function
# term_width = int(100)

# TOTAL_BAR_LENGTH = 65.
# last_time = time.time()
# begin_time = last_time

# def progress_bar(current, total, msg=None):
#   global last_time, begin_time
#   if current == 0:
#     begin_time = time.time()  # Reset for new bar.

#   cur_len = int(TOTAL_BAR_LENGTH * current/total)
#   rest_len = int(TOTAL_BAR_LENGTH - cur_len) - 1

#   sys.stdout.write(' [')
#   for i in range(cur_len):
#     sys.stdout.write('=')
#   sys.stdout.write('>')
#   for i in range(rest_len):
#     sys.stdout.write('.')
#   sys.stdout.write(']')

#   cur_time = time.time()
#   step_time = cur_time - last_time
#   last_time = cur_time
#   tot_time = cur_time - begin_time

#   L = []
#   L.append('  Step: %s' % format_time(step_time))
#   L.append(' | Tot: %s' % format_time(tot_time))
#   if msg:
#     L.append(' | ' + msg)

#   msg = ''.join(L)
#   sys.stdout.write(msg)
#   for i in range(term_width-int(TOTAL_BAR_LENGTH)-len(msg)-3):
#     sys.stdout.write(' ')

#   # Go back to the center of the bar.
#   for i in range(term_width-int(TOTAL_BAR_LENGTH/2)+2):
#     sys.stdout.write('\b')
#   sys.stdout.write(' %d/%d ' % (current+1, total))

#   if current < total-1:
#     sys.stdout.write('\r')
#   else:
#     sys.stdout.write('\n')
#   sys.stdout.flush()

# %%
def format_time(seconds):
  days = int(seconds / 3600/24)
  seconds = seconds - days*3600*24
  hours = int(seconds / 3600)
  seconds = seconds - hours*3600
  minutes = int(seconds / 60)
  seconds = seconds - minutes*60
  secondsf = int(seconds)
  seconds = seconds - secondsf
  millis = int(seconds*1000)

  f = ''
  i = 1
  if days > 0:
    f += str(days) + 'D'
    i += 1
  if hours > 0 and i <= 2:
    f += str(hours) + 'h'
    i += 1
  if minutes > 0 and i <= 2:
    f += str(minutes) + 'm'
    i += 1
  if secondsf > 0 and i <= 2:
    f += str(secondsf) + 's'
    i += 1
  if millis > 0 and i <= 2:
    f += str(millis) + 'ms'
    i += 1
  if f == '':
    f = '0ms'
  return f

# %%
lr = 0.1
momentum = 0.9
weight_decay = 5e-4

start_epoch = 1
number_of_epochs = 100
best_acc = 0


criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=lr,
                      momentum=momentum, weight_decay=weight_decay)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=number_of_epochs)

# %%
def get_lr(optimizer):
  for param_group in optimizer.param_groups:
    return param_group['lr']

# %%
def train(epoch):
  print('\nEpoch: %d' % epoch)
  start_time = time.time()

  model.train()
  train_loss = 0
  correct = 0
  total = 0
  for batch_idx, (inputs, targets) in enumerate(train_dl):
    # inputs, targets = inputs.to(device), targets.to(device)
    optimizer.zero_grad()
    outputs = model(inputs)
    loss = criterion(outputs, targets)
    loss.backward()
    optimizer.step()

    train_loss += loss.item()
    _, predicted = outputs.max(1)
    total += targets.size(0)
    correct += predicted.eq(targets).sum().item()

    if batch_idx % 50 == 0:
      print(f"Batch: {batch_idx}/{len(train_dl)} | Loss: {(train_loss/(batch_idx+1)):.3f} | Acc: {(100.*correct/total):.3f}%")

  cur_time = time.time()
  epoch_time = cur_time - start_time
  print(f"Time taken : {format_time(epoch_time)}")

  return train_loss/(batch_idx+1), 100.*correct/total, get_lr(optimizer)

# %%
def test(epoch):
  global best_acc
  model.eval()
  test_loss = 0
  correct = 0
  total = 0
  with torch.no_grad():
    for batch_idx, (inputs, targets) in enumerate(test_dl):
      # inputs, targets = inputs.to(device), targets.to(device)
      outputs = model(inputs)
      loss = criterion(outputs, targets)

      test_loss += loss.item()
      _, predicted = outputs.max(1)
      total += targets.size(0)
      correct += predicted.eq(targets).sum().item()
      
      if batch_idx % 50 == 0:
        print(f"Batch: {batch_idx}/{len(test_dl)} | Loss: {(test_loss/(batch_idx+1)):.3f} | Acc: {(100.*correct/total):.3f}%")
      # progress_bar(batch_idx, len(test_dl), 'Loss: %.3f | Acc: %.3f%% (%d/%d)'
      #               % (test_loss/(batch_idx+1), 100.*correct/total, correct, total))

  # Save checkpoint.
  acc = 100.*correct/total
  if acc > best_acc:
    print('Saving..')
    state = {
        'net': model.state_dict(),
        'acc': acc,
        'epoch': epoch,
    }
    if not os.path.isdir('dp_checkpoint'):
      os.mkdir('dp_checkpoint')
    torch.save(state, './dp_checkpoint/ckpt.pth')
    best_acc = acc

  return test_loss/(batch_idx+1), 100.*correct/total

# %%
train_losses = []
train_accuracies = []
train_lrs = []

test_losses = []
test_accuracies = []

for epoch in range(start_epoch, start_epoch + number_of_epochs):
  epoch_train_loss, epoch_train_accuracy, epoch_lr = train(epoch)
  train_losses.append(epoch_train_loss)
  train_accuracies.append(epoch_train_accuracy)
  train_lrs.append(epoch_lr)

  epoch_test_loss, epoch_test_accuracy = test(epoch)
  test_losses.append(epoch_test_loss)
  test_accuracies.append(epoch_test_accuracy)

  scheduler.step()
# Out:
# Epoch: 1
# Batch: 0/391 | Loss: 2.314 | Acc: 10.938%
# Batch: 50/391 | Loss: 1.970 | Acc: 26.057%
# Batch: 100/391 | Loss: 1.833 | Acc: 31.002%
# Batch: 150/391 | Loss: 1.734 | Acc: 35.265%
# Batch: 200/391 | Loss: 1.654 | Acc: 38.410%
# Batch: 250/391 | Loss: 1.602 | Acc: 40.606%
# Batch: 300/391 | Loss: 1.550 | Acc: 42.748%
# Batch: 350/391 | Loss: 1.505 | Acc: 44.605%
# Time taken : 48s384ms
# Batch: 0/100 | Loss: 1.062 | Acc: 60.000%
# Batch: 50/100 | Loss: 1.191 | Acc: 57.725%
# Saving..
#
# Epoch: 2
# Batch: 0/391 | Loss: 1.201 | Acc: 57.812%
# Batch: 50/391 | Loss: 1.138 | Acc: 58.854%
# Batch: 100/391 | Loss: 1.131 | Acc: 59.352%
# Batch: 150/391 | Loss: 1.119 | Acc: 59.577%
# Batch: 200/391 | Loss: 1.098 | Acc: 60.358%
# Batch: 250/391 | Loss: 1.084 | Acc: 61.059%
# Batch: 300/391 | Loss: 1.070 | Acc: 61.649%
# Batch: 350/391 | Loss: 1.057 | Acc: 62.097%
# Time taken : 59s798ms
# Batch: 0/100 | Loss: 0.869 | Acc: 72.000%
# Batch: 50/100 | Loss: 0.922 | Acc: 67.000%
# Saving..
#
# Epoch: 3
# Batch: 0/391 | Loss: 1.087 | Acc: 61.719%
# Batch: 50/391 | Loss: 0.929 | Acc: 66.192%
# Batch: 100/391 | Loss: 0.927 | Acc: 66.553%
# Batch: 150/391 | Loss: 0.920 | Acc: 66.810%
# Batch: 200/391 | Loss: 0.915 | Acc: 67.207%
# Batch: 250/391 | Loss: 0.903 | Acc: 67.773%
# Batch: 300/391 | Loss: 0.897 | Acc: 68.065%
# Batch: 350/391 | Loss: 0.891 | Acc: 68.345%
# Time taken : 59s525ms
# Batch: 0/100 | Loss: 0.943 | Acc: 66.000%
# Batch: 50/100 | Loss: 0.919 | Acc: 69.039%
# Saving..
#
# Epoch: 4
# Batch: 0/391 | Loss: 0.769 | Acc: 71.875%
# Batch: 50/391 | Loss: 0.808 | Acc: 71.844%
# Batch: 100/391 | Loss: 0.801 | Acc: 72.115%
# Batch: 150/391 | Loss: 0.791 | Acc: 72.367%
# Batch: 200/391 | Loss: 0.781 | Acc: 72.648%
# Batch: 250/391 | Loss: 0.776 | Acc: 72.793%
# Batch: 300/391 | Loss: 0.770 | Acc: 72.952%
# Batch: 350/391 | Loss: 0.764 | Acc: 73.077%
# Time taken : 59s244ms
# Batch: 0/100 | Loss: 0.723 | Acc: 75.000%
# Batch: 50/100 | Loss: 0.746 | Acc: 74.078%
# Saving..
#
# Epoch: 5
# Batch: 0/391 | Loss: 0.558 | Acc: 77.344%
# Batch: 50/391 | Loss: 0.713 | Acc: 75.000%
# Batch: 100/391 | Loss: 0.706 | Acc: 75.379%
# Batch: 150/391 | Loss: 0.699 | Acc: 75.605%
# Batch: 200/391 | Loss: 0.701 | Acc: 75.501%
# Batch: 250/391 | Loss: 0.697 | Acc: 75.632%
# Batch: 300/391 | Loss: 0.693 | Acc: 75.846%
# Batch: 350/391 | Loss: 0.690 | Acc: 75.950%
# Time taken : 59s366ms
# Batch: 0/100 | Loss: 0.921 | Acc: 67.000%
# Batch: 50/100 | Loss: 0.825 | Acc: 71.333%
#
# Epoch: 6
# Batch: 0/391 | Loss: 0.636 | Acc: 74.219%
# Batch: 50/391 | Loss: 0.648 | Acc: 77.558%
# Batch: 100/391 | Loss: 0.659 | Acc: 77.259%
# Batch: 150/391 | Loss: 0.645 | Acc: 77.659%
# Batch: 200/391 | Loss: 0.636 | Acc: 77.872%
# Batch: 250/391 | Loss: 0.632 | Acc: 78.016%
# Batch: 300/391 | Loss: 0.631 | Acc: 78.063%
# Batch: 350/391 | Loss: 0.631 | Acc: 78.101%
# Time taken : 59s352ms
# Batch: 0/100 | Loss: 0.526 | Acc: 83.000%
# Batch: 50/100 | Loss: 0.617 | Acc: 78.922%
# Saving..
#
# Epoch: 7
# Batch: 0/391 | Loss: 0.608 | Acc: 77.344%
# Batch: 50/391 | Loss: 0.606 | Acc: 79.151%
# Batch: 100/391 | Loss: 0.605 | Acc: 79.115%
# Batch: 150/391 | Loss: 0.607 | Acc: 78.948%
# Batch: 200/391 | Loss: 0.600 | Acc: 79.260%
# Batch: 250/391 | Loss: 0.599 | Acc: 79.367%
# Batch: 300/391 | Loss: 0.595 | Acc: 79.495%
# Batch: 350/391 | Loss: 0.593 | Acc: 79.514%
# Time taken : 59s102ms
# Batch: 0/100 | Loss: 0.601 | Acc: 81.000%
# Batch: 50/100 | Loss: 0.629 | Acc: 78.882%
#
# Epoch: 8
# Batch: 0/391 | Loss: 0.653 | Acc: 79.688%
# Batch: 50/391 | Loss: 0.547 | Acc: 81.327%
# Batch: 100/391 | Loss: 0.555 | Acc: 80.747%
# Batch: 150/391 | Loss: 0.566 | Acc: 80.319%
# Batch: 200/391 | Loss: 0.562 | Acc: 80.535%
# Batch: 250/391 | Loss: 0.564 | Acc: 80.481%
# Batch: 300/391 | Loss: 0.563 | Acc: 80.591%
# Batch: 350/391 | Loss: 0.562 | Acc: 80.636%
# Time taken : 59s836ms
# Batch: 0/100 | Loss: 0.680 | Acc: 72.000%
# Batch: 50/100 | Loss: 0.731 | Acc: 75.725%
#
# Epoch: 9
# Batch: 0/391 | Loss: 0.485 | Acc: 83.594%
# Batch: 50/391 | Loss: 0.558 | Acc: 80.576%
# Batch: 100/391 | Loss: 0.562 | Acc: 80.778%
# Batch: 150/391 | Loss: 0.558 | Acc: 80.909%
# Batch: 200/391 | Loss: 0.552 | Acc: 81.060%
# Batch: 250/391 | Loss: 0.549 | Acc: 81.088%
# Batch: 300/391 | Loss: 0.547 | Acc: 81.076%
# Batch: 350/391 | Loss: 0.546 | Acc: 81.067%
# Time taken : 1m152ms
# Batch: 0/100 | Loss: 0.480 | Acc: 83.000%
# Batch: 50/100 | Loss: 0.583 | Acc: 80.706%
# Saving..
#
# Epoch: 10
# Batch: 0/391 | Loss: 0.610 | Acc: 77.344%
# Batch: 50/391 | Loss: 0.530 | Acc: 81.572%
# Batch: 100/391 | Loss: 0.526 | Acc: 81.869%
# Batch: 150/391 | Loss: 0.519 | Acc: 82.155%
# Batch: 200/391 | Loss: 0.519 | Acc: 82.062%
# Batch: 250/391 | Loss: 0.522 | Acc: 81.960%
# Batch: 300/391 | Loss: 0.524 | Acc: 81.953%
# Batch: 350/391 | Loss: 0.525 | Acc: 81.969%
# Time taken : 1m290ms
# Batch: 0/100 | Loss: 0.584 | Acc: 78.000%
# Batch: 50/100 | Loss: 0.645 | Acc: 79.176%
#
# Epoch: 11
# Batch: 0/391 | Loss: 0.703 | Acc: 75.781%
# Batch: 50/391 | Loss: 0.505 | Acc: 82.920%
# Batch: 100/391 | Loss: 0.498 | Acc: 82.890%
# Batch: 150/391 | Loss: 0.502 | Acc: 82.704%
# Batch: 200/391 | Loss: 0.509 | Acc: 82.540%
# Batch: 250/391 | Loss: 0.505 | Acc: 82.663%
# Batch: 300/391 | Loss: 0.508 | Acc: 82.540%
# Batch: 350/391 | Loss: 0.507 | Acc: 82.545%
# Time taken : 1m10ms
# Batch: 0/100 | Loss: 0.584 | Acc: 81.000%
# Batch: 50/100 | Loss: 0.626 | Acc: 78.529%
#
# Epoch: 12
# Batch: 0/391 | Loss: 0.493 | Acc: 87.500%
# Batch: 50/391 | Loss: 0.483 | Acc: 83.793%
# Batch: 100/391 | Loss: 0.498 | Acc: 83.052%
# Batch: 150/391 | Loss: 0.500 | Acc: 82.931%
# Batch: 200/391 | Loss: 0.501 | Acc: 83.011%
# Batch: 250/391 | Loss: 0.499 | Acc: 83.033%
# Batch: 300/391 | Loss: 0.497 | Acc: 83.098%
# Batch: 350/391 | Loss: 0.498 | Acc: 82.995%
# Time taken : 1m22ms
# Batch: 0/100 | Loss: 0.498 | Acc: 86.000%
# Batch: 50/100 | Loss: 0.542 | Acc: 81.961%
# Saving..
#
# Epoch: 13
# Batch: 0/391 | Loss: 0.454 | Acc: 82.031%
# Batch: 50/391 | Loss: 0.473 | Acc: 83.287%
# Batch: 100/391 | Loss: 0.479 | Acc: 83.238%
# Batch: 150/391 | Loss: 0.478 | Acc: 83.439%
# Batch: 200/391 | Loss: 0.485 | Acc: 83.158%
# Batch: 250/391 | Loss: 0.486 | Acc: 83.068%
# Batch: 300/391 | Loss: 0.487 | Acc: 83.064%
# Batch: 350/391 | Loss: 0.484 | Acc: 83.193%
# Time taken : 1m14ms
# Batch: 0/100 | Loss: 0.441 | Acc: 86.000%
# Batch: 50/100 | Loss: 0.586 | Acc: 81.039%
#
# Epoch: 14
# Batch: 0/391 | Loss: 0.354 | Acc: 86.719%
# Batch: 50/391 | Loss: 0.417 | Acc: 85.600%
# Batch: 100/391 | Loss: 0.456 | Acc: 84.066%
# Batch: 150/391 | Loss: 0.457 | Acc: 84.147%
# Batch: 200/391 | Loss: 0.460 | Acc: 84.029%
# Batch: 250/391 | Loss: 0.459 | Acc: 84.020%
# Batch: 300/391 | Loss: 0.460 | Acc: 83.918%
# Batch: 350/391 | Loss: 0.466 | Acc: 83.732%
# Time taken : 1m789ms
# Batch: 0/100 | Loss: 0.485 | Acc: 82.000%
# Batch: 50/100 | Loss: 0.523 | Acc: 83.078%
# Saving..
#
# Epoch: 15
# Batch: 0/391 | Loss: 0.345 | Acc: 90.625%
# Batch: 50/391 | Loss: 0.440 | Acc: 85.018%
# Batch: 100/391 | Loss: 0.447 | Acc: 84.955%
# Batch: 150/391 | Loss: 0.452 | Acc: 84.701%
# Batch: 200/391 | Loss: 0.454 | Acc: 84.597%
# Batch: 250/391 | Loss: 0.462 | Acc: 84.288%
# Batch: 300/391 | Loss: 0.464 | Acc: 84.118%
# Batch: 350/391 | Loss: 0.463 | Acc: 84.135%
# Time taken : 59s539ms
# Batch: 0/100 | Loss: 0.528 | Acc: 83.000%
# Batch: 50/100 | Loss: 0.652 | Acc: 79.059%
#
# Epoch: 16
# Batch: 0/391 | Loss: 0.395 | Acc: 88.281%
# Batch: 50/391 | Loss: 0.465 | Acc: 83.931%
# Batch: 100/391 | Loss: 0.460 | Acc: 84.011%
# Batch: 150/391 | Loss: 0.458 | Acc: 84.142%
# Batch: 200/391 | Loss: 0.458 | Acc: 84.142%
# Batch: 250/391 | Loss: 0.457 | Acc: 84.095%
# Batch: 300/391 | Loss: 0.457 | Acc: 84.128%
# Batch: 350/391 | Loss: 0.457 | Acc: 84.195%
# Time taken : 59s608ms
# Batch: 0/100 | Loss: 0.511 | Acc: 83.000%
# Batch: 50/100 | Loss: 0.492 | Acc: 84.078%
# Saving..
#
# Epoch: 17
# Batch: 0/391 | Loss: 0.416 | Acc: 84.375%
# Batch: 50/391 | Loss: 0.439 | Acc: 84.957%
# Batch: 100/391 | Loss: 0.441 | Acc: 84.916%
# Batch: 150/391 | Loss: 0.442 | Acc: 84.856%
# Batch: 200/391 | Loss: 0.441 | Acc: 84.845%
# Batch: 250/391 | Loss: 0.442 | Acc: 84.786%
# Batch: 300/391 | Loss: 0.441 | Acc: 84.811%
# Batch: 350/391 | Loss: 0.441 | Acc: 84.840%
# Time taken : 59s311ms
# Batch: 0/100 | Loss: 0.594 | Acc: 80.000%
# Batch: 50/100 | Loss: 0.590 | Acc: 80.627%
#
# Epoch: 18
# Batch: 0/391 | Loss: 0.316 | Acc: 91.406%
# Batch: 50/391 | Loss: 0.430 | Acc: 85.172%
# Batch: 100/391 | Loss: 0.430 | Acc: 85.210%
# Batch: 150/391 | Loss: 0.429 | Acc: 85.125%
# Batch: 200/391 | Loss: 0.432 | Acc: 84.966%
# Batch: 250/391 | Loss: 0.434 | Acc: 84.920%
# Batch: 300/391 | Loss: 0.439 | Acc: 84.770%
# Batch: 350/391 | Loss: 0.441 | Acc: 84.693%
# Time taken : 58s920ms
# Batch: 0/100 | Loss: 0.557 | Acc: 82.000%
# Batch: 50/100 | Loss: 0.557 | Acc: 82.882%
#
# Epoch: 19
# Batch: 0/391 | Loss: 0.330 | Acc: 90.625%
# Batch: 50/391 | Loss: 0.396 | Acc: 86.550%
# Batch: 100/391 | Loss: 0.408 | Acc: 86.077%
# Batch: 150/391 | Loss: 0.419 | Acc: 85.720%
# Batch: 200/391 | Loss: 0.424 | Acc: 85.452%
# Batch: 250/391 | Loss: 0.431 | Acc: 85.247%
# Batch: 300/391 | Loss: 0.425 | Acc: 85.426%
# Batch: 350/391 | Loss: 0.430 | Acc: 85.190%
# Time taken : 59s877ms
# Batch: 0/100 | Loss: 0.624 | Acc: 75.000%
# Batch: 50/100 | Loss: 0.617 | Acc: 77.784%
#
# Epoch: 20
# Batch: 0/391 | Loss: 0.560 | Acc: 82.031%
# Batch: 50/391 | Loss: 0.420 | Acc: 85.677%
# Batch: 100/391 | Loss: 0.419 | Acc: 85.659%
# Batch: 150/391 | Loss: 0.409 | Acc: 86.144%
# Batch: 200/391 | Loss: 0.416 | Acc: 85.786%
# Batch: 250/391 | Loss: 0.422 | Acc: 85.474%
# Batch: 300/391 | Loss: 0.425 | Acc: 85.343%
# Batch: 350/391 | Loss: 0.424 | Acc: 85.361%
# Time taken : 1m1s
# Batch: 0/100 | Loss: 0.492 | Acc: 87.000%
# Batch: 50/100 | Loss: 0.515 | Acc: 83.569%
#
# Epoch: 21
# Batch: 0/391 | Loss: 0.410 | Acc: 85.938%
# Batch: 50/391 | Loss: 0.406 | Acc: 86.014%
# Batch: 100/391 | Loss: 0.417 | Acc: 85.814%
# Batch: 150/391 | Loss: 0.421 | Acc: 85.601%
# Batch: 200/391 | Loss: 0.422 | Acc: 85.708%
# Batch: 250/391 | Loss: 0.425 | Acc: 85.589%
# Batch: 300/391 | Loss: 0.423 | Acc: 85.551%
# Batch: 350/391 | Loss: 0.425 | Acc: 85.488%
# Time taken : 59s460ms
# Batch: 0/100 | Loss: 0.470 | Acc: 86.000%
# Batch: 50/100 | Loss: 0.485 | Acc: 84.059%
#
# Epoch: 22
# Batch: 0/391 | Loss: 0.316 | Acc: 87.500%
# Batch: 50/391 | Loss: 0.401 | Acc: 86.535%
# Batch: 100/391 | Loss: 0.414 | Acc: 85.999%
# Batch: 150/391 | Loss: 0.412 | Acc: 86.025%
# Batch: 200/391 | Loss: 0.410 | Acc: 86.035%
# Batch: 250/391 | Loss: 0.415 | Acc: 85.801%
# Batch: 300/391 | Loss: 0.416 | Acc: 85.787%
# Batch: 350/391 | Loss: 0.418 | Acc: 85.751%
# Time taken : 1m350ms
# Batch: 0/100 | Loss: 0.429 | Acc: 88.000%
# Batch: 50/100 | Loss: 0.533 | Acc: 83.118%
#
# Epoch: 23
# Batch: 0/391 | Loss: 0.418 | Acc: 86.719%
# Batch: 50/391 | Loss: 0.398 | Acc: 85.999%
# Batch: 100/391 | Loss: 0.405 | Acc: 85.945%
# Batch: 150/391 | Loss: 0.407 | Acc: 86.046%
# Batch: 200/391 | Loss: 0.411 | Acc: 85.961%
# Batch: 250/391 | Loss: 0.414 | Acc: 85.878%
# Batch: 300/391 | Loss: 0.413 | Acc: 85.834%
# Batch: 350/391 | Loss: 0.414 | Acc: 85.759%
# Time taken : 1m727ms
# Batch: 0/100 | Loss: 0.493 | Acc: 85.000%
# Batch: 50/100 | Loss: 0.560 | Acc: 81.510%
#
# Epoch: 24
# Batch: 0/391 | Loss: 0.388 | Acc: 83.594%
# Batch: 50/391 | Loss: 0.392 | Acc: 86.290%
# Batch: 100/391 | Loss: 0.392 | Acc: 86.487%
# Batch: 150/391 | Loss: 0.405 | Acc: 86.025%
# Batch: 200/391 | Loss: 0.404 | Acc: 86.039%
# Batch: 250/391 | Loss: 0.402 | Acc: 86.099%
# Batch: 300/391 | Loss: 0.403 | Acc: 86.088%
# Batch: 350/391 | Loss: 0.404 | Acc: 86.053%
# Time taken : 1m1s
# Batch: 0/100 | Loss: 0.598 | Acc: 78.000%
# Batch: 50/100 | Loss: 0.539 | Acc: 82.863%
#
# Epoch: 25
# Batch: 0/391 | Loss: 0.378 | Acc: 86.719%
# Batch: 50/391 | Loss: 0.393 | Acc: 86.382%
# Batch: 100/391 | Loss: 0.380 | Acc: 86.920%
# Batch: 150/391 | Loss: 0.386 | Acc: 86.703%
# Batch: 200/391 | Loss: 0.388 | Acc: 86.715%
# Batch: 250/391 | Loss: 0.391 | Acc: 86.538%
# Batch: 300/391 | Loss: 0.394 | Acc: 86.436%
# Batch: 350/391 | Loss: 0.399 | Acc: 86.303%
# Time taken : 1m1s
# Batch: 0/100 | Loss: 0.538 | Acc: 79.000%
# Batch: 50/100 | Loss: 0.653 | Acc: 79.118%
#
# Epoch: 26
# Batch: 0/391 | Loss: 0.435 | Acc: 84.375%
# Batch: 50/391 | Loss: 0.388 | Acc: 86.795%
# Batch: 100/391 | Loss: 0.388 | Acc: 86.680%
# Batch: 150/391 | Loss: 0.385 | Acc: 86.786%
# Batch: 200/391 | Loss: 0.389 | Acc: 86.540%
# Batch: 250/391 | Loss: 0.389 | Acc: 86.557%
# Batch: 300/391 | Loss: 0.390 | Acc: 86.529%
# Batch: 350/391 | Loss: 0.390 | Acc: 86.554%
# Time taken : 1m328ms
# Batch: 0/100 | Loss: 0.436 | Acc: 83.000%
# Batch: 50/100 | Loss: 0.430 | Acc: 85.118%
# Saving..
#
# Epoch: 27
# Batch: 0/391 | Loss: 0.404 | Acc: 86.719%
# Batch: 50/391 | Loss: 0.396 | Acc: 86.244%
# Batch: 100/391 | Loss: 0.398 | Acc: 86.494%
# Batch: 150/391 | Loss: 0.394 | Acc: 86.688%
# Batch: 200/391 | Loss: 0.394 | Acc: 86.641%
# Batch: 250/391 | Loss: 0.393 | Acc: 86.604%
# Batch: 300/391 | Loss: 0.393 | Acc: 86.625%
# Batch: 350/391 | Loss: 0.390 | Acc: 86.745%
# Time taken : 1m684ms
# Batch: 0/100 | Loss: 0.433 | Acc: 90.000%
# Batch: 50/100 | Loss: 0.503 | Acc: 83.314%
#
# Epoch: 28
# Batch: 0/391 | Loss: 0.461 | Acc: 83.594%
# Batch: 50/391 | Loss: 0.376 | Acc: 87.224%
# Batch: 100/391 | Loss: 0.386 | Acc: 86.804%
# Batch: 150/391 | Loss: 0.381 | Acc: 87.019%
# Batch: 200/391 | Loss: 0.385 | Acc: 86.866%
# Batch: 250/391 | Loss: 0.386 | Acc: 86.821%
# Batch: 300/391 | Loss: 0.385 | Acc: 86.882%
# Batch: 350/391 | Loss: 0.386 | Acc: 86.821%
# Time taken : 1m635ms
# Batch: 0/100 | Loss: 0.507 | Acc: 80.000%
# Batch: 50/100 | Loss: 0.643 | Acc: 80.392%
#
# Epoch: 29
# Batch: 0/391 | Loss: 0.377 | Acc: 86.719%
# Batch: 50/391 | Loss: 0.371 | Acc: 87.837%
# Batch: 100/391 | Loss: 0.375 | Acc: 87.345%
# Batch: 150/391 | Loss: 0.374 | Acc: 87.267%
# Batch: 200/391 | Loss: 0.379 | Acc: 87.119%
# Batch: 250/391 | Loss: 0.379 | Acc: 87.018%
# Batch: 300/391 | Loss: 0.383 | Acc: 86.906%
# Batch: 350/391 | Loss: 0.385 | Acc: 86.861%
# Time taken : 59s1ms
# Batch: 0/100 | Loss: 0.440 | Acc: 86.000%
# Batch: 50/100 | Loss: 0.405 | Acc: 87.137%
# Saving..
#
# Epoch: 30
# Batch: 0/391 | Loss: 0.378 | Acc: 86.719%
# Batch: 50/391 | Loss: 0.399 | Acc: 86.198%
# Batch: 100/391 | Loss: 0.378 | Acc: 86.912%
# Batch: 150/391 | Loss: 0.375 | Acc: 87.019%
# Batch: 200/391 | Loss: 0.378 | Acc: 86.933%
# Batch: 250/391 | Loss: 0.379 | Acc: 87.064%
# Batch: 300/391 | Loss: 0.379 | Acc: 87.046%
# Batch: 350/391 | Loss: 0.380 | Acc: 86.995%
# Time taken : 59s157ms
# Batch: 0/100 | Loss: 0.501 | Acc: 83.000%
# Batch: 50/100 | Loss: 0.506 | Acc: 83.784%
#
# Epoch: 31
# Batch: 0/391 | Loss: 0.309 | Acc: 89.062%
# Batch: 50/391 | Loss: 0.352 | Acc: 88.281%
# Batch: 100/391 | Loss: 0.354 | Acc: 88.003%
# Batch: 150/391 | Loss: 0.362 | Acc: 87.588%
# Batch: 200/391 | Loss: 0.367 | Acc: 87.348%
# Batch: 250/391 | Loss: 0.374 | Acc: 87.158%
# Batch: 300/391 | Loss: 0.375 | Acc: 87.118%
# Batch: 350/391 | Loss: 0.376 | Acc: 87.108%
# Time taken : 58s176ms
# Batch: 0/100 | Loss: 0.320 | Acc: 90.000%
# Batch: 50/100 | Loss: 0.427 | Acc: 85.902%
#
# Epoch: 32
# Batch: 0/391 | Loss: 0.390 | Acc: 89.062%
# Batch: 50/391 | Loss: 0.381 | Acc: 86.703%
# Batch: 100/391 | Loss: 0.372 | Acc: 87.044%
# Batch: 150/391 | Loss: 0.373 | Acc: 87.164%
# Batch: 200/391 | Loss: 0.374 | Acc: 87.201%
# Batch: 250/391 | Loss: 0.371 | Acc: 87.276%
# Batch: 300/391 | Loss: 0.373 | Acc: 87.207%
# Batch: 350/391 | Loss: 0.374 | Acc: 87.157%
# Time taken : 57s940ms
# Batch: 0/100 | Loss: 0.866 | Acc: 76.000%
# Batch: 50/100 | Loss: 0.712 | Acc: 79.137%
#
# Epoch: 33
# Batch: 0/391 | Loss: 0.332 | Acc: 89.062%
# Batch: 50/391 | Loss: 0.343 | Acc: 88.113%
# Batch: 100/391 | Loss: 0.354 | Acc: 87.709%
# Batch: 150/391 | Loss: 0.354 | Acc: 87.624%
# Batch: 200/391 | Loss: 0.357 | Acc: 87.617%
# Batch: 250/391 | Loss: 0.361 | Acc: 87.540%
# Batch: 300/391 | Loss: 0.366 | Acc: 87.352%
# Batch: 350/391 | Loss: 0.367 | Acc: 87.333%
# Time taken : 58s72ms
# Batch: 0/100 | Loss: 0.395 | Acc: 85.000%
# Batch: 50/100 | Loss: 0.474 | Acc: 84.078%
#
# Epoch: 34
# Batch: 0/391 | Loss: 0.422 | Acc: 82.812%
# Batch: 50/391 | Loss: 0.346 | Acc: 87.960%
# Batch: 100/391 | Loss: 0.342 | Acc: 88.250%
# Batch: 150/391 | Loss: 0.350 | Acc: 88.017%
# Batch: 200/391 | Loss: 0.354 | Acc: 87.885%
# Batch: 250/391 | Loss: 0.360 | Acc: 87.709%
# Batch: 300/391 | Loss: 0.361 | Acc: 87.658%
# Batch: 350/391 | Loss: 0.364 | Acc: 87.596%
# Time taken : 58s823ms
# Batch: 0/100 | Loss: 0.325 | Acc: 90.000%
# Batch: 50/100 | Loss: 0.435 | Acc: 85.608%
#
# Epoch: 35
# Batch: 0/391 | Loss: 0.386 | Acc: 90.625%
# Batch: 50/391 | Loss: 0.362 | Acc: 87.883%
# Batch: 100/391 | Loss: 0.356 | Acc: 88.026%
# Batch: 150/391 | Loss: 0.354 | Acc: 87.992%
# Batch: 200/391 | Loss: 0.358 | Acc: 87.792%
# Batch: 250/391 | Loss: 0.361 | Acc: 87.674%
# Batch: 300/391 | Loss: 0.362 | Acc: 87.567%
# Batch: 350/391 | Loss: 0.362 | Acc: 87.582%
# Time taken : 58s406ms
# Batch: 0/100 | Loss: 0.485 | Acc: 83.000%
# Batch: 50/100 | Loss: 0.464 | Acc: 84.706%
#
# Epoch: 36
# Batch: 0/391 | Loss: 0.239 | Acc: 89.844%
# Batch: 50/391 | Loss: 0.362 | Acc: 87.822%
# Batch: 100/391 | Loss: 0.359 | Acc: 87.771%
# Batch: 150/391 | Loss: 0.351 | Acc: 87.986%
# Batch: 200/391 | Loss: 0.352 | Acc: 87.974%
# Batch: 250/391 | Loss: 0.353 | Acc: 87.914%
# Batch: 300/391 | Loss: 0.355 | Acc: 87.837%
# Batch: 350/391 | Loss: 0.357 | Acc: 87.754%
# Time taken : 58s509ms
# Batch: 0/100 | Loss: 0.369 | Acc: 87.000%
# Batch: 50/100 | Loss: 0.395 | Acc: 87.373%
# Saving..
#
# Epoch: 37
# Batch: 0/391 | Loss: 0.322 | Acc: 89.844%
# Batch: 50/391 | Loss: 0.348 | Acc: 88.006%
# Batch: 100/391 | Loss: 0.343 | Acc: 88.204%
# Batch: 150/391 | Loss: 0.344 | Acc: 88.281%
# Batch: 200/391 | Loss: 0.346 | Acc: 88.141%
# Batch: 250/391 | Loss: 0.344 | Acc: 88.281%
# Batch: 300/391 | Loss: 0.347 | Acc: 88.164%
# Batch: 350/391 | Loss: 0.351 | Acc: 88.032%
# Time taken : 58s900ms
# Batch: 0/100 | Loss: 0.504 | Acc: 85.000%
# Batch: 50/100 | Loss: 0.502 | Acc: 83.882%
#
# Epoch: 38
# Batch: 0/391 | Loss: 0.312 | Acc: 90.625%
# Batch: 50/391 | Loss: 0.310 | Acc: 89.384%
# Batch: 100/391 | Loss: 0.335 | Acc: 88.482%
# Batch: 150/391 | Loss: 0.344 | Acc: 88.183%
# Batch: 200/391 | Loss: 0.341 | Acc: 88.196%
# Batch: 250/391 | Loss: 0.348 | Acc: 87.982%
# Batch: 300/391 | Loss: 0.350 | Acc: 87.892%
# Batch: 350/391 | Loss: 0.349 | Acc: 87.856%
# Time taken : 59s530ms
# Batch: 0/100 | Loss: 0.366 | Acc: 92.000%
# Batch: 50/100 | Loss: 0.449 | Acc: 85.059%
#
# Epoch: 39
# Batch: 0/391 | Loss: 0.430 | Acc: 84.375%
# Batch: 50/391 | Loss: 0.350 | Acc: 88.343%
# Batch: 100/391 | Loss: 0.338 | Acc: 88.583%
# Batch: 150/391 | Loss: 0.344 | Acc: 88.442%
# Batch: 200/391 | Loss: 0.342 | Acc: 88.448%
# Batch: 250/391 | Loss: 0.343 | Acc: 88.287%
# Batch: 300/391 | Loss: 0.342 | Acc: 88.222%
# Batch: 350/391 | Loss: 0.344 | Acc: 88.163%
# Time taken : 57s519ms
# Batch: 0/100 | Loss: 0.411 | Acc: 86.000%
# Batch: 50/100 | Loss: 0.397 | Acc: 87.000%
#
# Epoch: 40
# Batch: 0/391 | Loss: 0.275 | Acc: 91.406%
# Batch: 50/391 | Loss: 0.343 | Acc: 87.914%
# Batch: 100/391 | Loss: 0.338 | Acc: 88.297%
# Batch: 150/391 | Loss: 0.336 | Acc: 88.416%
# Batch: 200/391 | Loss: 0.336 | Acc: 88.472%
# Batch: 250/391 | Loss: 0.338 | Acc: 88.431%
# Batch: 300/391 | Loss: 0.339 | Acc: 88.364%
# Batch: 350/391 | Loss: 0.340 | Acc: 88.306%
# Time taken : 58s548ms
# Batch: 0/100 | Loss: 0.426 | Acc: 85.000%
# Batch: 50/100 | Loss: 0.426 | Acc: 86.078%
#
# Epoch: 41
# Batch: 0/391 | Loss: 0.528 | Acc: 81.250%
# Batch: 50/391 | Loss: 0.324 | Acc: 88.971%
# Batch: 100/391 | Loss: 0.321 | Acc: 89.024%
# Batch: 150/391 | Loss: 0.317 | Acc: 89.109%
# Batch: 200/391 | Loss: 0.320 | Acc: 89.082%
# Batch: 250/391 | Loss: 0.325 | Acc: 88.826%
# Batch: 300/391 | Loss: 0.329 | Acc: 88.722%
# Batch: 350/391 | Loss: 0.332 | Acc: 88.580%
# Time taken : 57s885ms
# Batch: 0/100 | Loss: 0.431 | Acc: 89.000%
# Batch: 50/100 | Loss: 0.455 | Acc: 85.255%
#
# Epoch: 42
# Batch: 0/391 | Loss: 0.357 | Acc: 88.281%
# Batch: 50/391 | Loss: 0.306 | Acc: 89.369%
# Batch: 100/391 | Loss: 0.322 | Acc: 88.691%
# Batch: 150/391 | Loss: 0.326 | Acc: 88.623%
# Batch: 200/391 | Loss: 0.325 | Acc: 88.631%
# Batch: 250/391 | Loss: 0.327 | Acc: 88.627%
# Batch: 300/391 | Loss: 0.327 | Acc: 88.660%
# Batch: 350/391 | Loss: 0.330 | Acc: 88.511%
# Time taken : 57s660ms
# Batch: 0/100 | Loss: 0.227 | Acc: 92.000%
# Batch: 50/100 | Loss: 0.382 | Acc: 87.745%
# Saving..
#
# Epoch: 43
# Batch: 0/391 | Loss: 0.230 | Acc: 92.188%
# Batch: 50/391 | Loss: 0.319 | Acc: 88.894%
# Batch: 100/391 | Loss: 0.316 | Acc: 89.148%
# Batch: 150/391 | Loss: 0.318 | Acc: 88.980%
# Batch: 200/391 | Loss: 0.316 | Acc: 89.094%
# Batch: 250/391 | Loss: 0.316 | Acc: 89.103%
# Batch: 300/391 | Loss: 0.319 | Acc: 88.969%
# Batch: 350/391 | Loss: 0.322 | Acc: 88.860%
# Time taken : 1m350ms
# Batch: 0/100 | Loss: 0.428 | Acc: 84.000%
# Batch: 50/100 | Loss: 0.436 | Acc: 86.529%
#
# Epoch: 44
# Batch: 0/391 | Loss: 0.280 | Acc: 90.625%
# Batch: 50/391 | Loss: 0.301 | Acc: 89.737%
# Batch: 100/391 | Loss: 0.304 | Acc: 89.712%
# Batch: 150/391 | Loss: 0.301 | Acc: 89.802%
# Batch: 200/391 | Loss: 0.306 | Acc: 89.564%
# Batch: 250/391 | Loss: 0.306 | Acc: 89.579%
# Batch: 300/391 | Loss: 0.309 | Acc: 89.486%
# Batch: 350/391 | Loss: 0.313 | Acc: 89.334%
# Time taken : 57s832ms
# Batch: 0/100 | Loss: 0.424 | Acc: 84.000%
# Batch: 50/100 | Loss: 0.600 | Acc: 82.059%
#
# Epoch: 45
# Batch: 0/391 | Loss: 0.230 | Acc: 92.188%
# Batch: 50/391 | Loss: 0.303 | Acc: 90.028%
# Batch: 100/391 | Loss: 0.300 | Acc: 89.998%
# Batch: 150/391 | Loss: 0.305 | Acc: 89.714%
# Batch: 200/391 | Loss: 0.309 | Acc: 89.599%
# Batch: 250/391 | Loss: 0.311 | Acc: 89.396%
# Batch: 300/391 | Loss: 0.316 | Acc: 89.244%
# Batch: 350/391 | Loss: 0.316 | Acc: 89.234%
# Time taken : 1m242ms
# Batch: 0/100 | Loss: 0.452 | Acc: 84.000%
# Batch: 50/100 | Loss: 0.464 | Acc: 85.392%
#
# Epoch: 46
# Batch: 0/391 | Loss: 0.310 | Acc: 89.844%
# Batch: 50/391 | Loss: 0.287 | Acc: 90.273%
# Batch: 100/391 | Loss: 0.299 | Acc: 90.045%
# Batch: 150/391 | Loss: 0.295 | Acc: 90.004%
# Batch: 200/391 | Loss: 0.299 | Acc: 89.937%
# Batch: 250/391 | Loss: 0.303 | Acc: 89.766%
# Batch: 300/391 | Loss: 0.303 | Acc: 89.810%
# Batch: 350/391 | Loss: 0.308 | Acc: 89.606%
# Time taken : 59s458ms
# Batch: 0/100 | Loss: 0.382 | Acc: 87.000%
# Batch: 50/100 | Loss: 0.414 | Acc: 86.706%
#
# Epoch: 47
# Batch: 0/391 | Loss: 0.349 | Acc: 87.500%
# Batch: 50/391 | Loss: 0.281 | Acc: 90.533%
# Batch: 100/391 | Loss: 0.286 | Acc: 90.308%
# Batch: 150/391 | Loss: 0.291 | Acc: 90.133%
# Batch: 200/391 | Loss: 0.298 | Acc: 89.859%
# Batch: 250/391 | Loss: 0.304 | Acc: 89.691%
# Batch: 300/391 | Loss: 0.305 | Acc: 89.685%
# Batch: 350/391 | Loss: 0.307 | Acc: 89.617%
# Time taken : 59s15ms
# Batch: 0/100 | Loss: 0.327 | Acc: 88.000%
# Batch: 50/100 | Loss: 0.422 | Acc: 86.941%
#
# Epoch: 48
# Batch: 0/391 | Loss: 0.294 | Acc: 92.188%
# Batch: 50/391 | Loss: 0.290 | Acc: 89.905%
# Batch: 100/391 | Loss: 0.295 | Acc: 89.697%
# Batch: 150/391 | Loss: 0.298 | Acc: 89.528%
# Batch: 200/391 | Loss: 0.302 | Acc: 89.443%
# Batch: 250/391 | Loss: 0.303 | Acc: 89.417%
# Batch: 300/391 | Loss: 0.303 | Acc: 89.462%
# Batch: 350/391 | Loss: 0.302 | Acc: 89.590%
# Time taken : 57s440ms
# Batch: 0/100 | Loss: 0.352 | Acc: 90.000%
# Batch: 50/100 | Loss: 0.390 | Acc: 87.490%
# Saving..
#
# Epoch: 49
# Batch: 0/391 | Loss: 0.225 | Acc: 92.188%
# Batch: 50/391 | Loss: 0.282 | Acc: 90.334%
# Batch: 100/391 | Loss: 0.286 | Acc: 90.114%
# Batch: 150/391 | Loss: 0.288 | Acc: 90.056%
# Batch: 200/391 | Loss: 0.289 | Acc: 90.019%
# Batch: 250/391 | Loss: 0.292 | Acc: 89.853%
# Batch: 300/391 | Loss: 0.296 | Acc: 89.768%
# Batch: 350/391 | Loss: 0.297 | Acc: 89.775%
# Time taken : 58s765ms
# Batch: 0/100 | Loss: 0.290 | Acc: 90.000%
# Batch: 50/100 | Loss: 0.377 | Acc: 88.118%
# Saving..
#
# Epoch: 50
# Batch: 0/391 | Loss: 0.219 | Acc: 93.750%
# Batch: 50/391 | Loss: 0.269 | Acc: 91.023%
# Batch: 100/391 | Loss: 0.282 | Acc: 90.416%
# Batch: 150/391 | Loss: 0.282 | Acc: 90.273%
# Batch: 200/391 | Loss: 0.282 | Acc: 90.194%
# Batch: 250/391 | Loss: 0.284 | Acc: 90.174%
# Batch: 300/391 | Loss: 0.287 | Acc: 90.106%
# Batch: 350/391 | Loss: 0.289 | Acc: 90.017%
# Time taken : 58s290ms
# Batch: 0/100 | Loss: 0.406 | Acc: 88.000%
# Batch: 50/100 | Loss: 0.372 | Acc: 88.098%
# Saving..
#
# Epoch: 51
# Batch: 0/391 | Loss: 0.313 | Acc: 88.281%
# Batch: 50/391 | Loss: 0.252 | Acc: 91.207%
# Batch: 100/391 | Loss: 0.258 | Acc: 90.911%
# Batch: 150/391 | Loss: 0.266 | Acc: 90.760%
# Batch: 200/391 | Loss: 0.269 | Acc: 90.707%
# Batch: 250/391 | Loss: 0.271 | Acc: 90.659%
# Batch: 300/391 | Loss: 0.275 | Acc: 90.495%
# Batch: 350/391 | Loss: 0.279 | Acc: 90.360%
# Time taken : 58s349ms
# Batch: 0/100 | Loss: 0.629 | Acc: 82.000%
# Batch: 50/100 | Loss: 0.414 | Acc: 86.510%
#
# Epoch: 52
# Batch: 0/391 | Loss: 0.315 | Acc: 87.500%
# Batch: 50/391 | Loss: 0.257 | Acc: 91.314%
# Batch: 100/391 | Loss: 0.265 | Acc: 90.942%
# Batch: 150/391 | Loss: 0.271 | Acc: 90.651%
# Batch: 200/391 | Loss: 0.274 | Acc: 90.528%
# Batch: 250/391 | Loss: 0.277 | Acc: 90.360%
# Batch: 300/391 | Loss: 0.280 | Acc: 90.251%
# Batch: 350/391 | Loss: 0.279 | Acc: 90.302%
# Time taken : 58s825ms
# Batch: 0/100 | Loss: 0.423 | Acc: 84.000%
# Batch: 50/100 | Loss: 0.386 | Acc: 87.333%
#
# Epoch: 53
# Batch: 0/391 | Loss: 0.282 | Acc: 91.406%
# Batch: 50/391 | Loss: 0.258 | Acc: 91.222%
# Batch: 100/391 | Loss: 0.265 | Acc: 90.811%
# Batch: 150/391 | Loss: 0.266 | Acc: 90.754%
# Batch: 200/391 | Loss: 0.267 | Acc: 90.742%
# Batch: 250/391 | Loss: 0.268 | Acc: 90.737%
# Batch: 300/391 | Loss: 0.271 | Acc: 90.622%
# Batch: 350/391 | Loss: 0.274 | Acc: 90.487%
# Time taken : 1m51ms
# Batch: 0/100 | Loss: 0.408 | Acc: 85.000%
# Batch: 50/100 | Loss: 0.350 | Acc: 88.784%
# Saving..
#
# Epoch: 54
# Batch: 0/391 | Loss: 0.235 | Acc: 91.406%
# Batch: 50/391 | Loss: 0.256 | Acc: 90.732%
# Batch: 100/391 | Loss: 0.261 | Acc: 90.826%
# Batch: 150/391 | Loss: 0.263 | Acc: 90.899%
# Batch: 200/391 | Loss: 0.264 | Acc: 90.847%
# Batch: 250/391 | Loss: 0.266 | Acc: 90.809%
# Batch: 300/391 | Loss: 0.264 | Acc: 90.843%
# Batch: 350/391 | Loss: 0.266 | Acc: 90.765%
# Time taken : 58s900ms
# Batch: 0/100 | Loss: 0.329 | Acc: 87.000%
# Batch: 50/100 | Loss: 0.365 | Acc: 88.255%
#
# Epoch: 55
# Batch: 0/391 | Loss: 0.197 | Acc: 93.750%
# Batch: 50/391 | Loss: 0.232 | Acc: 92.096%
# Batch: 100/391 | Loss: 0.241 | Acc: 91.708%
# Batch: 150/391 | Loss: 0.252 | Acc: 91.339%
# Batch: 200/391 | Loss: 0.259 | Acc: 91.029%
# Batch: 250/391 | Loss: 0.260 | Acc: 91.104%
# Batch: 300/391 | Loss: 0.262 | Acc: 91.069%
# Batch: 350/391 | Loss: 0.263 | Acc: 90.988%
# Time taken : 58s266ms
# Batch: 0/100 | Loss: 0.355 | Acc: 86.000%
# Batch: 50/100 | Loss: 0.383 | Acc: 87.725%
#
# Epoch: 56
# Batch: 0/391 | Loss: 0.302 | Acc: 87.500%
# Batch: 50/391 | Loss: 0.253 | Acc: 91.069%
# Batch: 100/391 | Loss: 0.254 | Acc: 91.043%
# Batch: 150/391 | Loss: 0.257 | Acc: 90.889%
# Batch: 200/391 | Loss: 0.257 | Acc: 90.948%
# Batch: 250/391 | Loss: 0.253 | Acc: 91.120%
# Batch: 300/391 | Loss: 0.255 | Acc: 91.025%
# Batch: 350/391 | Loss: 0.258 | Acc: 90.972%
# Time taken : 58s298ms
# Batch: 0/100 | Loss: 0.215 | Acc: 93.000%
# Batch: 50/100 | Loss: 0.368 | Acc: 88.020%
#
# Epoch: 57
# Batch: 0/391 | Loss: 0.298 | Acc: 92.969%
# Batch: 50/391 | Loss: 0.241 | Acc: 91.590%
# Batch: 100/391 | Loss: 0.252 | Acc: 91.352%
# Batch: 150/391 | Loss: 0.252 | Acc: 91.323%
# Batch: 200/391 | Loss: 0.249 | Acc: 91.352%
# Batch: 250/391 | Loss: 0.250 | Acc: 91.319%
# Batch: 300/391 | Loss: 0.252 | Acc: 91.225%
# Batch: 350/391 | Loss: 0.252 | Acc: 91.217%
# Time taken : 59s19ms
# Batch: 0/100 | Loss: 0.280 | Acc: 92.000%
# Batch: 50/100 | Loss: 0.424 | Acc: 87.314%
#
# Epoch: 58
# Batch: 0/391 | Loss: 0.331 | Acc: 86.719%
# Batch: 50/391 | Loss: 0.225 | Acc: 92.157%
# Batch: 100/391 | Loss: 0.231 | Acc: 92.002%
# Batch: 150/391 | Loss: 0.231 | Acc: 92.012%
# Batch: 200/391 | Loss: 0.235 | Acc: 91.744%
# Batch: 250/391 | Loss: 0.238 | Acc: 91.658%
# Batch: 300/391 | Loss: 0.242 | Acc: 91.541%
# Batch: 350/391 | Loss: 0.243 | Acc: 91.520%
# Time taken : 1m781ms
# Batch: 0/100 | Loss: 0.258 | Acc: 90.000%
# Batch: 50/100 | Loss: 0.422 | Acc: 86.804%
#
# Epoch: 59
# Batch: 0/391 | Loss: 0.221 | Acc: 91.406%
# Batch: 50/391 | Loss: 0.238 | Acc: 91.575%
# Batch: 100/391 | Loss: 0.235 | Acc: 91.839%
# Batch: 150/391 | Loss: 0.236 | Acc: 91.836%
# Batch: 200/391 | Loss: 0.239 | Acc: 91.616%
# Batch: 250/391 | Loss: 0.240 | Acc: 91.605%
# Batch: 300/391 | Loss: 0.242 | Acc: 91.549%
# Batch: 350/391 | Loss: 0.244 | Acc: 91.509%
# Time taken : 1m942ms
# Batch: 0/100 | Loss: 0.282 | Acc: 91.000%
# Batch: 50/100 | Loss: 0.414 | Acc: 87.314%
#
# Epoch: 60
# Batch: 0/391 | Loss: 0.227 | Acc: 92.188%
# Batch: 50/391 | Loss: 0.239 | Acc: 91.621%
# Batch: 100/391 | Loss: 0.237 | Acc: 91.770%
# Batch: 150/391 | Loss: 0.233 | Acc: 91.939%
# Batch: 200/391 | Loss: 0.230 | Acc: 92.075%
# Batch: 250/391 | Loss: 0.232 | Acc: 91.985%
# Batch: 300/391 | Loss: 0.236 | Acc: 91.845%
# Batch: 350/391 | Loss: 0.237 | Acc: 91.831%
# Time taken : 1m179ms
# Batch: 0/100 | Loss: 0.470 | Acc: 89.000%
# Batch: 50/100 | Loss: 0.431 | Acc: 86.902%
#
# Epoch: 61
# Batch: 0/391 | Loss: 0.339 | Acc: 87.500%
# Batch: 50/391 | Loss: 0.206 | Acc: 93.153%
# Batch: 100/391 | Loss: 0.214 | Acc: 92.706%
# Batch: 150/391 | Loss: 0.222 | Acc: 92.420%
# Batch: 200/391 | Loss: 0.223 | Acc: 92.242%
# Batch: 250/391 | Loss: 0.224 | Acc: 92.209%
# Batch: 300/391 | Loss: 0.227 | Acc: 92.104%
# Batch: 350/391 | Loss: 0.228 | Acc: 92.123%
# Time taken : 1m182ms
# Batch: 0/100 | Loss: 0.285 | Acc: 91.000%
# Batch: 50/100 | Loss: 0.360 | Acc: 89.255%
# Saving..
#
# Epoch: 62
# Batch: 0/391 | Loss: 0.138 | Acc: 94.531%
# Batch: 50/391 | Loss: 0.206 | Acc: 93.490%
# Batch: 100/391 | Loss: 0.210 | Acc: 92.946%
# Batch: 150/391 | Loss: 0.216 | Acc: 92.674%
# Batch: 200/391 | Loss: 0.221 | Acc: 92.460%
# Batch: 250/391 | Loss: 0.222 | Acc: 92.408%
# Batch: 300/391 | Loss: 0.223 | Acc: 92.351%
# Batch: 350/391 | Loss: 0.223 | Acc: 92.305%
# Time taken : 1m995ms
# Batch: 0/100 | Loss: 0.251 | Acc: 92.000%
# Batch: 50/100 | Loss: 0.376 | Acc: 88.569%
#
# Epoch: 63
# Batch: 0/391 | Loss: 0.138 | Acc: 93.750%
# Batch: 50/391 | Loss: 0.205 | Acc: 92.846%
# Batch: 100/391 | Loss: 0.211 | Acc: 92.474%
# Batch: 150/391 | Loss: 0.215 | Acc: 92.420%
# Batch: 200/391 | Loss: 0.218 | Acc: 92.308%
# Batch: 250/391 | Loss: 0.218 | Acc: 92.371%
# Batch: 300/391 | Loss: 0.221 | Acc: 92.297%
# Batch: 350/391 | Loss: 0.222 | Acc: 92.254%
# Time taken : 58s859ms
# Batch: 0/100 | Loss: 0.170 | Acc: 93.000%
# Batch: 50/100 | Loss: 0.310 | Acc: 90.569%
# Saving..
#
# Epoch: 64
# Batch: 0/391 | Loss: 0.181 | Acc: 93.750%
# Batch: 50/391 | Loss: 0.188 | Acc: 93.413%
# Batch: 100/391 | Loss: 0.197 | Acc: 93.209%
# Batch: 150/391 | Loss: 0.206 | Acc: 92.953%
# Batch: 200/391 | Loss: 0.206 | Acc: 92.949%
# Batch: 250/391 | Loss: 0.204 | Acc: 93.037%
# Batch: 300/391 | Loss: 0.204 | Acc: 92.974%
# Batch: 350/391 | Loss: 0.204 | Acc: 92.960%
# Time taken : 59s891ms
# Batch: 0/100 | Loss: 0.262 | Acc: 88.000%
# Batch: 50/100 | Loss: 0.365 | Acc: 88.549%
#
# Epoch: 65
# Batch: 0/391 | Loss: 0.253 | Acc: 87.500%
# Batch: 50/391 | Loss: 0.201 | Acc: 92.907%
# Batch: 100/391 | Loss: 0.199 | Acc: 93.069%
# Batch: 150/391 | Loss: 0.198 | Acc: 93.083%
# Batch: 200/391 | Loss: 0.203 | Acc: 92.934%
# Batch: 250/391 | Loss: 0.203 | Acc: 92.913%
# Batch: 300/391 | Loss: 0.206 | Acc: 92.787%
# Batch: 350/391 | Loss: 0.207 | Acc: 92.777%
# Time taken : 57s890ms
# Batch: 0/100 | Loss: 0.257 | Acc: 92.000%
# Batch: 50/100 | Loss: 0.364 | Acc: 88.765%
#
# Epoch: 66
# Batch: 0/391 | Loss: 0.108 | Acc: 98.438%
# Batch: 50/391 | Loss: 0.190 | Acc: 93.566%
# Batch: 100/391 | Loss: 0.185 | Acc: 93.649%
# Batch: 150/391 | Loss: 0.189 | Acc: 93.528%
# Batch: 200/391 | Loss: 0.192 | Acc: 93.377%
# Batch: 250/391 | Loss: 0.191 | Acc: 93.386%
# Batch: 300/391 | Loss: 0.191 | Acc: 93.353%
# Batch: 350/391 | Loss: 0.193 | Acc: 93.320%
# Time taken : 58s940ms
# Batch: 0/100 | Loss: 0.327 | Acc: 89.000%
# Batch: 50/100 | Loss: 0.333 | Acc: 90.020%
#
# Epoch: 67
# Batch: 0/391 | Loss: 0.155 | Acc: 95.312%
# Batch: 50/391 | Loss: 0.188 | Acc: 93.704%
# Batch: 100/391 | Loss: 0.183 | Acc: 93.626%
# Batch: 150/391 | Loss: 0.183 | Acc: 93.672%
# Batch: 200/391 | Loss: 0.186 | Acc: 93.618%
# Batch: 250/391 | Loss: 0.189 | Acc: 93.473%
# Batch: 300/391 | Loss: 0.188 | Acc: 93.475%
# Batch: 350/391 | Loss: 0.190 | Acc: 93.394%
# Time taken : 57s484ms
# Batch: 0/100 | Loss: 0.202 | Acc: 90.000%
# Batch: 50/100 | Loss: 0.341 | Acc: 89.510%
#
# Epoch: 68
# Batch: 0/391 | Loss: 0.167 | Acc: 93.750%
# Batch: 50/391 | Loss: 0.173 | Acc: 94.056%
# Batch: 100/391 | Loss: 0.172 | Acc: 94.083%
# Batch: 150/391 | Loss: 0.173 | Acc: 94.076%
# Batch: 200/391 | Loss: 0.174 | Acc: 93.972%
# Batch: 250/391 | Loss: 0.179 | Acc: 93.812%
# Batch: 300/391 | Loss: 0.182 | Acc: 93.651%
# Batch: 350/391 | Loss: 0.181 | Acc: 93.685%
# Time taken : 59s386ms
# Batch: 0/100 | Loss: 0.312 | Acc: 90.000%
# Batch: 50/100 | Loss: 0.328 | Acc: 89.902%
#
# Epoch: 69
# Batch: 0/391 | Loss: 0.273 | Acc: 89.844%
# Batch: 50/391 | Loss: 0.176 | Acc: 93.673%
# Batch: 100/391 | Loss: 0.175 | Acc: 93.796%
# Batch: 150/391 | Loss: 0.172 | Acc: 93.931%
# Batch: 200/391 | Loss: 0.172 | Acc: 93.960%
# Batch: 250/391 | Loss: 0.173 | Acc: 93.940%
# Batch: 300/391 | Loss: 0.176 | Acc: 93.854%
# Batch: 350/391 | Loss: 0.178 | Acc: 93.826%
# Time taken : 57s377ms
# Batch: 0/100 | Loss: 0.241 | Acc: 89.000%
# Batch: 50/100 | Loss: 0.330 | Acc: 90.176%
#
# Epoch: 70
# Batch: 0/391 | Loss: 0.141 | Acc: 96.094%
# Batch: 50/391 | Loss: 0.161 | Acc: 94.393%
# Batch: 100/391 | Loss: 0.163 | Acc: 94.222%
# Batch: 150/391 | Loss: 0.164 | Acc: 94.335%
# Batch: 200/391 | Loss: 0.163 | Acc: 94.337%
# Batch: 250/391 | Loss: 0.169 | Acc: 94.114%
# Batch: 300/391 | Loss: 0.172 | Acc: 94.059%
# Batch: 350/391 | Loss: 0.171 | Acc: 94.093%
# Time taken : 59s117ms
# Batch: 0/100 | Loss: 0.224 | Acc: 92.000%
# Batch: 50/100 | Loss: 0.305 | Acc: 90.961%
# Saving..
#
# Epoch: 71
# Batch: 0/391 | Loss: 0.113 | Acc: 97.656%
# Batch: 50/391 | Loss: 0.167 | Acc: 94.286%
# Batch: 100/391 | Loss: 0.155 | Acc: 94.578%
# Batch: 150/391 | Loss: 0.160 | Acc: 94.376%
# Batch: 200/391 | Loss: 0.160 | Acc: 94.419%
# Batch: 250/391 | Loss: 0.162 | Acc: 94.323%
# Batch: 300/391 | Loss: 0.164 | Acc: 94.267%
# Batch: 350/391 | Loss: 0.164 | Acc: 94.266%
# Time taken : 58s17ms
# Batch: 0/100 | Loss: 0.149 | Acc: 96.000%
# Batch: 50/100 | Loss: 0.314 | Acc: 90.961%
#
# Epoch: 72
# Batch: 0/391 | Loss: 0.101 | Acc: 96.875%
# Batch: 50/391 | Loss: 0.152 | Acc: 94.715%
# Batch: 100/391 | Loss: 0.146 | Acc: 94.910%
# Batch: 150/391 | Loss: 0.150 | Acc: 94.769%
# Batch: 200/391 | Loss: 0.151 | Acc: 94.807%
# Batch: 250/391 | Loss: 0.151 | Acc: 94.730%
# Batch: 300/391 | Loss: 0.152 | Acc: 94.721%
# Batch: 350/391 | Loss: 0.154 | Acc: 94.674%
# Time taken : 58s696ms
# Batch: 0/100 | Loss: 0.242 | Acc: 93.000%
# Batch: 50/100 | Loss: 0.306 | Acc: 91.020%
# Saving..
#
# Epoch: 73
# Batch: 0/391 | Loss: 0.122 | Acc: 95.312%
# Batch: 50/391 | Loss: 0.144 | Acc: 94.776%
# Batch: 100/391 | Loss: 0.140 | Acc: 95.026%
# Batch: 150/391 | Loss: 0.142 | Acc: 94.935%
# Batch: 200/391 | Loss: 0.142 | Acc: 94.912%
# Batch: 250/391 | Loss: 0.145 | Acc: 94.880%
# Batch: 300/391 | Loss: 0.146 | Acc: 94.874%
# Batch: 350/391 | Loss: 0.146 | Acc: 94.870%
# Time taken : 58s481ms
# Batch: 0/100 | Loss: 0.347 | Acc: 90.000%
# Batch: 50/100 | Loss: 0.383 | Acc: 88.922%
#
# Epoch: 74
# Batch: 0/391 | Loss: 0.079 | Acc: 97.656%
# Batch: 50/391 | Loss: 0.129 | Acc: 95.389%
# Batch: 100/391 | Loss: 0.130 | Acc: 95.374%
# Batch: 150/391 | Loss: 0.135 | Acc: 95.204%
# Batch: 200/391 | Loss: 0.137 | Acc: 95.079%
# Batch: 250/391 | Loss: 0.136 | Acc: 95.188%
# Batch: 300/391 | Loss: 0.137 | Acc: 95.146%
# Batch: 350/391 | Loss: 0.138 | Acc: 95.097%
# Time taken : 58s801ms
# Batch: 0/100 | Loss: 0.189 | Acc: 92.000%
# Batch: 50/100 | Loss: 0.306 | Acc: 91.098%
#
# Epoch: 75
# Batch: 0/391 | Loss: 0.165 | Acc: 93.750%
# Batch: 50/391 | Loss: 0.123 | Acc: 95.726%
# Batch: 100/391 | Loss: 0.126 | Acc: 95.606%
# Batch: 150/391 | Loss: 0.125 | Acc: 95.644%
# Batch: 200/391 | Loss: 0.127 | Acc: 95.631%
# Batch: 250/391 | Loss: 0.130 | Acc: 95.474%
# Batch: 300/391 | Loss: 0.133 | Acc: 95.377%
# Batch: 350/391 | Loss: 0.135 | Acc: 95.312%
# Time taken : 1m297ms
# Batch: 0/100 | Loss: 0.224 | Acc: 93.000%
# Batch: 50/100 | Loss: 0.298 | Acc: 91.059%
# Saving..
#
# Epoch: 76
# Batch: 0/391 | Loss: 0.115 | Acc: 96.875%
# Batch: 50/391 | Loss: 0.127 | Acc: 95.634%
# Batch: 100/391 | Loss: 0.125 | Acc: 95.823%
# Batch: 150/391 | Loss: 0.120 | Acc: 96.016%
# Batch: 200/391 | Loss: 0.125 | Acc: 95.810%
# Batch: 250/391 | Loss: 0.124 | Acc: 95.817%
# Batch: 300/391 | Loss: 0.124 | Acc: 95.780%
# Batch: 350/391 | Loss: 0.125 | Acc: 95.729%
# Time taken : 59s801ms
# Batch: 0/100 | Loss: 0.181 | Acc: 93.000%
# Batch: 50/100 | Loss: 0.299 | Acc: 91.235%
#
# Epoch: 77
# Batch: 0/391 | Loss: 0.148 | Acc: 93.750%
# Batch: 50/391 | Loss: 0.106 | Acc: 96.354%
# Batch: 100/391 | Loss: 0.111 | Acc: 96.187%
# Batch: 150/391 | Loss: 0.113 | Acc: 96.099%
# Batch: 200/391 | Loss: 0.113 | Acc: 96.113%
# Batch: 250/391 | Loss: 0.116 | Acc: 95.997%
# Batch: 300/391 | Loss: 0.117 | Acc: 95.972%
# Batch: 350/391 | Loss: 0.118 | Acc: 95.931%
# Time taken : 1m424ms
# Batch: 0/100 | Loss: 0.271 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.304 | Acc: 91.353%
# Saving..
#
# Epoch: 78
# Batch: 0/391 | Loss: 0.133 | Acc: 96.094%
# Batch: 50/391 | Loss: 0.095 | Acc: 97.028%
# Batch: 100/391 | Loss: 0.099 | Acc: 96.790%
# Batch: 150/391 | Loss: 0.102 | Acc: 96.658%
# Batch: 200/391 | Loss: 0.104 | Acc: 96.560%
# Batch: 250/391 | Loss: 0.107 | Acc: 96.433%
# Batch: 300/391 | Loss: 0.108 | Acc: 96.413%
# Batch: 350/391 | Loss: 0.108 | Acc: 96.401%
# Time taken : 59s235ms
# Batch: 0/100 | Loss: 0.217 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.304 | Acc: 91.745%
# Saving..
#
# Epoch: 79
# Batch: 0/391 | Loss: 0.084 | Acc: 96.094%
# Batch: 50/391 | Loss: 0.096 | Acc: 96.860%
# Batch: 100/391 | Loss: 0.102 | Acc: 96.527%
# Batch: 150/391 | Loss: 0.100 | Acc: 96.627%
# Batch: 200/391 | Loss: 0.102 | Acc: 96.615%
# Batch: 250/391 | Loss: 0.104 | Acc: 96.501%
# Batch: 300/391 | Loss: 0.104 | Acc: 96.517%
# Batch: 350/391 | Loss: 0.104 | Acc: 96.479%
# Time taken : 1m425ms
# Batch: 0/100 | Loss: 0.145 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.269 | Acc: 92.353%
# Saving..
#
# Epoch: 80
# Batch: 0/391 | Loss: 0.097 | Acc: 96.094%
# Batch: 50/391 | Loss: 0.090 | Acc: 97.059%
# Batch: 100/391 | Loss: 0.093 | Acc: 96.906%
# Batch: 150/391 | Loss: 0.093 | Acc: 96.766%
# Batch: 200/391 | Loss: 0.093 | Acc: 96.743%
# Batch: 250/391 | Loss: 0.095 | Acc: 96.626%
# Batch: 300/391 | Loss: 0.096 | Acc: 96.602%
# Batch: 350/391 | Loss: 0.097 | Acc: 96.579%
# Time taken : 1m889ms
# Batch: 0/100 | Loss: 0.136 | Acc: 97.000%
# Batch: 50/100 | Loss: 0.276 | Acc: 92.078%
#
# Epoch: 81
# Batch: 0/391 | Loss: 0.091 | Acc: 96.094%
# Batch: 50/391 | Loss: 0.082 | Acc: 97.273%
# Batch: 100/391 | Loss: 0.086 | Acc: 97.177%
# Batch: 150/391 | Loss: 0.084 | Acc: 97.232%
# Batch: 200/391 | Loss: 0.084 | Acc: 97.201%
# Batch: 250/391 | Loss: 0.085 | Acc: 97.127%
# Batch: 300/391 | Loss: 0.087 | Acc: 97.085%
# Batch: 350/391 | Loss: 0.087 | Acc: 97.049%
# Time taken : 1m352ms
# Batch: 0/100 | Loss: 0.256 | Acc: 91.000%
# Batch: 50/100 | Loss: 0.297 | Acc: 91.627%
#
# Epoch: 82
# Batch: 0/391 | Loss: 0.027 | Acc: 99.219%
# Batch: 50/391 | Loss: 0.081 | Acc: 97.044%
# Batch: 100/391 | Loss: 0.079 | Acc: 97.153%
# Batch: 150/391 | Loss: 0.080 | Acc: 97.139%
# Batch: 200/391 | Loss: 0.080 | Acc: 97.213%
# Batch: 250/391 | Loss: 0.079 | Acc: 97.277%
# Batch: 300/391 | Loss: 0.080 | Acc: 97.207%
# Batch: 350/391 | Loss: 0.080 | Acc: 97.193%
# Time taken : 59s540ms
# Batch: 0/100 | Loss: 0.140 | Acc: 93.000%
# Batch: 50/100 | Loss: 0.262 | Acc: 92.725%
# Saving..
#
# Epoch: 83
# Batch: 0/391 | Loss: 0.092 | Acc: 96.875%
# Batch: 50/391 | Loss: 0.071 | Acc: 97.641%
# Batch: 100/391 | Loss: 0.071 | Acc: 97.641%
# Batch: 150/391 | Loss: 0.072 | Acc: 97.594%
# Batch: 200/391 | Loss: 0.073 | Acc: 97.567%
# Batch: 250/391 | Loss: 0.074 | Acc: 97.541%
# Batch: 300/391 | Loss: 0.075 | Acc: 97.501%
# Batch: 350/391 | Loss: 0.076 | Acc: 97.447%
# Time taken : 1m494ms
# Batch: 0/100 | Loss: 0.323 | Acc: 90.000%
# Batch: 50/100 | Loss: 0.278 | Acc: 92.863%
# Saving..
#
# Epoch: 84
# Batch: 0/391 | Loss: 0.105 | Acc: 96.875%
# Batch: 50/391 | Loss: 0.072 | Acc: 97.457%
# Batch: 100/391 | Loss: 0.076 | Acc: 97.331%
# Batch: 150/391 | Loss: 0.071 | Acc: 97.558%
# Batch: 200/391 | Loss: 0.068 | Acc: 97.637%
# Batch: 250/391 | Loss: 0.068 | Acc: 97.619%
# Batch: 300/391 | Loss: 0.068 | Acc: 97.617%
# Batch: 350/391 | Loss: 0.068 | Acc: 97.634%
# Time taken : 1m146ms
# Batch: 0/100 | Loss: 0.184 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.275 | Acc: 92.745%
#
# Epoch: 85
# Batch: 0/391 | Loss: 0.043 | Acc: 99.219%
# Batch: 50/391 | Loss: 0.062 | Acc: 97.947%
# Batch: 100/391 | Loss: 0.065 | Acc: 97.734%
# Batch: 150/391 | Loss: 0.065 | Acc: 97.770%
# Batch: 200/391 | Loss: 0.063 | Acc: 97.870%
# Batch: 250/391 | Loss: 0.063 | Acc: 97.846%
# Batch: 300/391 | Loss: 0.063 | Acc: 97.838%
# Batch: 350/391 | Loss: 0.063 | Acc: 97.828%
# Time taken : 59s430ms
# Batch: 0/100 | Loss: 0.182 | Acc: 93.000%
# Batch: 50/100 | Loss: 0.270 | Acc: 93.118%
# Saving..
#
# Epoch: 86
# Batch: 0/391 | Loss: 0.064 | Acc: 99.219%
# Batch: 50/391 | Loss: 0.056 | Acc: 98.146%
# Batch: 100/391 | Loss: 0.055 | Acc: 98.113%
# Batch: 150/391 | Loss: 0.056 | Acc: 98.106%
# Batch: 200/391 | Loss: 0.055 | Acc: 98.150%
# Batch: 250/391 | Loss: 0.056 | Acc: 98.111%
# Batch: 300/391 | Loss: 0.056 | Acc: 98.121%
# Batch: 350/391 | Loss: 0.055 | Acc: 98.170%
# Time taken : 1m422ms
# Batch: 0/100 | Loss: 0.222 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.267 | Acc: 93.098%
# Saving..
#
# Epoch: 87
# Batch: 0/391 | Loss: 0.042 | Acc: 98.438%
# Batch: 50/391 | Loss: 0.054 | Acc: 98.177%
# Batch: 100/391 | Loss: 0.053 | Acc: 98.213%
# Batch: 150/391 | Loss: 0.052 | Acc: 98.308%
# Batch: 200/391 | Loss: 0.050 | Acc: 98.352%
# Batch: 250/391 | Loss: 0.050 | Acc: 98.366%
# Batch: 300/391 | Loss: 0.052 | Acc: 98.295%
# Batch: 350/391 | Loss: 0.052 | Acc: 98.264%
# Time taken : 1m1s
# Batch: 0/100 | Loss: 0.188 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.254 | Acc: 93.627%
# Saving..
#
# Epoch: 88
# Batch: 0/391 | Loss: 0.024 | Acc: 99.219%
# Batch: 50/391 | Loss: 0.046 | Acc: 98.438%
# Batch: 100/391 | Loss: 0.049 | Acc: 98.399%
# Batch: 150/391 | Loss: 0.048 | Acc: 98.432%
# Batch: 200/391 | Loss: 0.049 | Acc: 98.418%
# Batch: 250/391 | Loss: 0.049 | Acc: 98.447%
# Batch: 300/391 | Loss: 0.049 | Acc: 98.432%
# Batch: 350/391 | Loss: 0.048 | Acc: 98.446%
# Time taken : 1m108ms
# Batch: 0/100 | Loss: 0.161 | Acc: 93.000%
# Batch: 50/100 | Loss: 0.252 | Acc: 93.294%
#
# Epoch: 89
# Batch: 0/391 | Loss: 0.053 | Acc: 99.219%
# Batch: 50/391 | Loss: 0.045 | Acc: 98.529%
# Batch: 100/391 | Loss: 0.043 | Acc: 98.654%
# Batch: 150/391 | Loss: 0.043 | Acc: 98.675%
# Batch: 200/391 | Loss: 0.042 | Acc: 98.741%
# Batch: 250/391 | Loss: 0.042 | Acc: 98.743%
# Batch: 300/391 | Loss: 0.042 | Acc: 98.736%
# Batch: 350/391 | Loss: 0.043 | Acc: 98.696%
# Time taken : 59s802ms
# Batch: 0/100 | Loss: 0.192 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.263 | Acc: 93.451%
#
# Epoch: 90
# Batch: 0/391 | Loss: 0.030 | Acc: 99.219%
# Batch: 50/391 | Loss: 0.041 | Acc: 98.683%
# Batch: 100/391 | Loss: 0.042 | Acc: 98.716%
# Batch: 150/391 | Loss: 0.041 | Acc: 98.779%
# Batch: 200/391 | Loss: 0.041 | Acc: 98.752%
# Batch: 250/391 | Loss: 0.041 | Acc: 98.730%
# Batch: 300/391 | Loss: 0.041 | Acc: 98.757%
# Batch: 350/391 | Loss: 0.041 | Acc: 98.765%
# Time taken : 1m370ms
# Batch: 0/100 | Loss: 0.184 | Acc: 93.000%
# Batch: 50/100 | Loss: 0.250 | Acc: 93.392%
#
# Epoch: 91
# Batch: 0/391 | Loss: 0.024 | Acc: 99.219%
# Batch: 50/391 | Loss: 0.039 | Acc: 98.805%
# Batch: 100/391 | Loss: 0.035 | Acc: 98.994%
# Batch: 150/391 | Loss: 0.036 | Acc: 98.965%
# Batch: 200/391 | Loss: 0.036 | Acc: 98.962%
# Batch: 250/391 | Loss: 0.037 | Acc: 98.932%
# Batch: 300/391 | Loss: 0.037 | Acc: 98.920%
# Batch: 350/391 | Loss: 0.036 | Acc: 98.932%
# Time taken : 58s720ms
# Batch: 0/100 | Loss: 0.197 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.254 | Acc: 93.608%
#
# Epoch: 92
# Batch: 0/391 | Loss: 0.018 | Acc: 99.219%
# Batch: 50/391 | Loss: 0.030 | Acc: 99.203%
# Batch: 100/391 | Loss: 0.033 | Acc: 99.064%
# Batch: 150/391 | Loss: 0.034 | Acc: 99.022%
# Batch: 200/391 | Loss: 0.034 | Acc: 99.040%
# Batch: 250/391 | Loss: 0.034 | Acc: 99.035%
# Batch: 300/391 | Loss: 0.033 | Acc: 99.047%
# Batch: 350/391 | Loss: 0.033 | Acc: 99.056%
# Time taken : 1m1s
# Batch: 0/100 | Loss: 0.164 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.249 | Acc: 93.608%
#
# Epoch: 93
# Batch: 0/391 | Loss: 0.077 | Acc: 96.875%
# Batch: 50/391 | Loss: 0.030 | Acc: 99.188%
# Batch: 100/391 | Loss: 0.031 | Acc: 99.126%
# Batch: 150/391 | Loss: 0.032 | Acc: 99.105%
# Batch: 200/391 | Loss: 0.032 | Acc: 99.087%
# Batch: 250/391 | Loss: 0.032 | Acc: 99.054%
# Batch: 300/391 | Loss: 0.032 | Acc: 99.047%
# Batch: 350/391 | Loss: 0.032 | Acc: 99.043%
# Time taken : 59s98ms
# Batch: 0/100 | Loss: 0.199 | Acc: 93.000%
# Batch: 50/100 | Loss: 0.253 | Acc: 93.314%
#
# Epoch: 94
# Batch: 0/391 | Loss: 0.047 | Acc: 98.438%
# Batch: 50/391 | Loss: 0.030 | Acc: 99.188%
# Batch: 100/391 | Loss: 0.029 | Acc: 99.203%
# Batch: 150/391 | Loss: 0.030 | Acc: 99.167%
# Batch: 200/391 | Loss: 0.030 | Acc: 99.172%
# Batch: 250/391 | Loss: 0.030 | Acc: 99.160%
# Batch: 300/391 | Loss: 0.030 | Acc: 99.149%
# Batch: 350/391 | Loss: 0.030 | Acc: 99.139%
# Time taken : 1m333ms
# Batch: 0/100 | Loss: 0.193 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.254 | Acc: 93.725%
# Saving..
#
# Epoch: 95
# Batch: 0/391 | Loss: 0.015 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.027 | Acc: 99.295%
# Batch: 100/391 | Loss: 0.027 | Acc: 99.273%
# Batch: 150/391 | Loss: 0.028 | Acc: 99.250%
# Batch: 200/391 | Loss: 0.028 | Acc: 99.250%
# Batch: 250/391 | Loss: 0.027 | Acc: 99.284%
# Batch: 300/391 | Loss: 0.028 | Acc: 99.245%
# Batch: 350/391 | Loss: 0.028 | Acc: 99.250%
# Time taken : 1m410ms
# Batch: 0/100 | Loss: 0.194 | Acc: 93.000%
# Batch: 50/100 | Loss: 0.252 | Acc: 93.882%
# Saving..
#
# Epoch: 96
# Batch: 0/391 | Loss: 0.019 | Acc: 99.219%
# Batch: 50/391 | Loss: 0.028 | Acc: 99.249%
# Batch: 100/391 | Loss: 0.026 | Acc: 99.327%
# Batch: 150/391 | Loss: 0.027 | Acc: 99.270%
# Batch: 200/391 | Loss: 0.027 | Acc: 99.265%
# Batch: 250/391 | Loss: 0.028 | Acc: 99.244%
# Batch: 300/391 | Loss: 0.027 | Acc: 99.252%
# Batch: 350/391 | Loss: 0.027 | Acc: 99.268%
# Time taken : 1m367ms
# Batch: 0/100 | Loss: 0.175 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.247 | Acc: 93.824%
#
# Epoch: 97
# Batch: 0/391 | Loss: 0.030 | Acc: 99.219%
# Batch: 50/391 | Loss: 0.028 | Acc: 99.219%
# Batch: 100/391 | Loss: 0.027 | Acc: 99.265%
# Batch: 150/391 | Loss: 0.025 | Acc: 99.322%
# Batch: 200/391 | Loss: 0.025 | Acc: 99.328%
# Batch: 250/391 | Loss: 0.026 | Acc: 99.300%
# Batch: 300/391 | Loss: 0.026 | Acc: 99.304%
# Batch: 350/391 | Loss: 0.026 | Acc: 99.301%
# Time taken : 59s379ms
# Batch: 0/100 | Loss: 0.189 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.248 | Acc: 93.882%
# Saving..
#
# Epoch: 98
# Batch: 0/391 | Loss: 0.020 | Acc: 99.219%
# Batch: 50/391 | Loss: 0.027 | Acc: 99.265%
# Batch: 100/391 | Loss: 0.028 | Acc: 99.257%
# Batch: 150/391 | Loss: 0.027 | Acc: 99.270%
# Batch: 200/391 | Loss: 0.027 | Acc: 99.269%
# Batch: 250/391 | Loss: 0.026 | Acc: 99.262%
# Batch: 300/391 | Loss: 0.027 | Acc: 99.265%
# Batch: 350/391 | Loss: 0.027 | Acc: 99.259%
# Time taken : 1m839ms
# Batch: 0/100 | Loss: 0.175 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.245 | Acc: 94.039%
# Saving..
#
# Epoch: 99
# Batch: 0/391 | Loss: 0.024 | Acc: 99.219%
# Batch: 50/391 | Loss: 0.026 | Acc: 99.219%
# Batch: 100/391 | Loss: 0.024 | Acc: 99.389%
# Batch: 150/391 | Loss: 0.024 | Acc: 99.358%
# Batch: 200/391 | Loss: 0.025 | Acc: 99.335%
# Batch: 250/391 | Loss: 0.026 | Acc: 99.284%
# Batch: 300/391 | Loss: 0.025 | Acc: 99.307%
# Batch: 350/391 | Loss: 0.025 | Acc: 99.301%
# Time taken : 50s784ms
# Batch: 0/100 | Loss: 0.182 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.245 | Acc: 94.118%
# Saving..
#
# Epoch: 100
# Batch: 0/391 | Loss: 0.021 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.024 | Acc: 99.341%
# Batch: 100/391 | Loss: 0.026 | Acc: 99.296%
# Batch: 150/391 | Loss: 0.024 | Acc: 99.364%
# Batch: 200/391 | Loss: 0.025 | Acc: 99.355%
# Batch: 250/391 | Loss: 0.025 | Acc: 99.328%
# Batch: 300/391 | Loss: 0.025 | Acc: 99.325%
# Batch: 350/391 | Loss: 0.025 | Acc: 99.330%
# Time taken : 36s207ms
# Batch: 0/100 | Loss: 0.194 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.247 | Acc: 94.020%

# %%
def plot_accuracies(train_accuracies, test_accuracies):
  plt.plot(train_accuracies, label='Train Accuracy')
  plt.plot(test_accuracies, label='Test Accuracy')
  plt.xlabel('Epochs')
  plt.ylabel('Accuracy')
  plt.legend()
  plt.grid(True)
  plt.title('Accuracy vs. No. of epochs')

# %%
def plot_losses(train_losses, test_losses):
  plt.plot(train_losses, label='Train Losses')
  plt.plot(test_losses, label='Test Losses')
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.legend()
  plt.grid(True)
  plt.title('Loss vs. No. of epochs')

# %%
def plot_lrs(train_lrs):
  plt.plot(train_lrs)
  plt.xlabel('Epochs')
  plt.ylabel('Learning rate')
  plt.grid(True)
  plt.title('Learning Rate vs. Epochs')

# %%
plot_accuracies(train_accuracies, test_accuracies)

# %%
plot_losses(train_losses, test_losses)

# %%
plot_lrs(train_lrs)

# %%
print('Saving final model..')
state = {
    'net': model.state_dict(),
    'acc': test_accuracies[-1],
    'epoch': number_of_epochs,
}
if not os.path.isdir('dp_checkpoint'):
  os.mkdir('dp_checkpoint')
torch.save(state, './dp_checkpoint/model_final.pth')
# Out:
# Saving final model..

# %%
import numpy as np
import pickle
from tqdm import tqdm
import pandas as pd

# Function to load CIFAR batch
def load_cifar_batch(file):
    with open(file, 'rb') as fo:
        batch = pickle.load(fo, encoding='bytes')
    return batch

# Specify the folder where the CIFAR-10 batch files are
cifar10_dir = 'data/cifar-10-batches-py/'

# Load the label names
meta_data_dict = load_cifar_batch(os.path.join(cifar10_dir, 'batches.meta'))
label_names = meta_data_dict[b'label_names']

# Load test data
test_batch = load_cifar_batch('CIFAR-10/cifar_test_nolabels.pkl')
test_images = test_batch[b'data'].reshape(-1, 3, 32, 32).transpose(0, 2, 3, 1)

data_statistics = (
    (0.49139968, 0.48215827, 0.44653124),
     (0.24703233, 0.24348505, 0.26158768)
)

# Define transformation for data augmentation
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(*data_statistics, inplace=True)
])

# Apply data augmentation
augmented_test_images = torch.stack([transform(image) for image in test_images])

# Load the trained model
model = ResNet9()

checkpoint = torch.load('./dp_checkpoint/ckpt.pth')

# Check the keys in the checkpoint dictionary
print(checkpoint.keys())

# Assuming the model state dictionary is saved under a different key
# Adjust this according to the actual key in your checkpoint file
model.load_state_dict(checkpoint['net'])

model =  model.to(device)

# Evaluate the model on test data
model.eval()
with torch.no_grad():
    outputs = model(augmented_test_images.to(device))
_, predicted = torch.max(outputs, 1)

predicted = predicted.to('cpu')

# Display the first 10 test images and predicted labels
plt.figure(figsize=(20, 4))
for i in range(10):
    plt.subplot(1, 10, i+1)
    plt.imshow(test_images[i])
    plt.title(label_names[predicted[i].item()].decode('utf-8'))
    plt.axis('off')
plt.show()

# Save the output in output.csv containing ID, Labels
output_data = {'ID': np.arange(len(predicted)), 'Labels': predicted.numpy()}
output_df = pd.DataFrame(output_data)
output_df.to_csv('output_rugved_resnet9_dropout.csv', index=False)
# Out:
# dict_keys(['net', 'acc', 'epoch'])

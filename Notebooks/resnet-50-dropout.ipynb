# %% [markdown]
# # ResNet-50 (with Dropout) on CIFAR-10 Dataset

# %% [markdown]
# Importing PyTorch and a few Python Libraries

# %%
pip install torch-summary
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch-summary in /home/rrm9598/.local/lib/python3.11/site-packages (1.4.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import sys
import time
import math

import torch
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import random_split, DataLoader
from torchvision.utils import make_grid

import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
import torch.nn.init as init

from torchsummary import summary

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Preparing the dataset
#
# We will be downloading the train and test CIFAR-10 dataset from torchvision. We will normalize and transform the dataset. For the training dataset, we will also be adding Random Crops and Random Horizontal Flips to generalize the model better.

# %%
data_statistics = (
    (0.49139968, 0.48215827, 0.44653124),
     (0.24703233, 0.24348505, 0.26158768)
) # Mean, Standard Deviation of CIFAR-10 dataset channels

train_transforms = transforms.Compose([
    transforms.RandomCrop(32, padding=4, padding_mode='reflect'), # Adding Random Crops
    transforms.RandomHorizontalFlip(), # Adding Random Horizontal Flips
    transforms.ToTensor(), # Channel x Image Height x Image Width
    transforms.Normalize(*data_statistics, inplace=True) # Output in the range of [-1, 1]
])

test_transforms = transforms.Compose([
    transforms.ToTensor(), # Channel x Image Height x Image Width
    transforms.Normalize(*data_statistics, inplace=True) # Output in the range of [-1, 1]
])

# %%
train_dataset = torchvision.datasets.CIFAR10(root='./data/', download=True, train=True, transform=train_transforms)
test_dataset = torchvision.datasets.CIFAR10(root='./data/', download=True, train=False, transform=test_transforms)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# <!-- We will also be splitting the dataset further into training and validation dataset with a validation ratio of `0.2` -->
#
# We will now create data loaders to retreive images in batches. We are selecting the batch size as `128` images for our train loader. And we are selecting the batch size as `100` images for our test loader.
#
# *From PyTorch Documentation: For data loading, passing pin_memory=True to a DataLoader will automatically put the fetched data Tensors in pinned memory, and thus enables faster data transfer to CUDA-enabled GPUs.*

# %%
train_batch_size = 128
test_batch_size = 100

train_dl = DataLoader(train_dataset, train_batch_size, shuffle=True, num_workers=3, pin_memory=True)
test_dl = DataLoader(test_dataset, test_batch_size, shuffle=False, num_workers=3, pin_memory=True)

classes = ('plane', 'car', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck')

# %% [markdown]
# We create the following function to display a batch of images from the dataset. And we also need to denormalize the pixels values to bring them back into the range (0,1).

# %%
def denormalize(images, means, stds):
  means = torch.tensor(means).reshape(1, 3, 1, 1)
  stds = torch.tensor(stds).reshape(1, 3, 1, 1)
  return images * stds + means

def show_batch(dl):
  for images, labels in dl:
    fig, ax = plt.subplots(figsize=(12, 12))
    ax.set_xticks([])
    ax.set_yticks([])
    denorm_images = denormalize(images, *data_statistics)
    ax.imshow(make_grid(denorm_images[:64], 8).permute(1, 2, 0))
    break

# %%
show_batch(train_dl)

# %% [markdown]
# To seamlessly use a GPU, if one is available, we define a couple of helper functions (`get_default_device` & `to_device`) and a helper class `DeviceDataLoader` to move our model & data to the GPU as required.

# %%
def get_default_device():
  # Pick GPU, if available, else CPU
  if torch.cuda.is_available():
    return torch.device('cuda')
  else:
    return torch.device('cpu')

def to_device(data, device):
  # Move tensors to chosen device
  if isinstance(data, (list, tuple)):
    # If the instance is a list/tuple, transfer each element to chosen device
    return [to_device(x, device) for x in data]
  return data.to(device, non_blocking=True)
  # non_blocking=True doesn't block the execution of the host device until transfers complete

class DeviceDataLoader():
  # Wrap a dataloader to move data to a device
  def __init__(self, dl, device):
    self.dl = dl
    self.device = device

  def __iter__(self):
    # Yield a batch of data after moving it to device
    for b in self.dl:
      yield to_device(b, self.device)

  def __len__(self):
    # Number of batches
    return len(self.dl)

# %%
# Get the default device
device = get_default_device()
device
# Out:
# device(type='cuda')

# %%
train_dl = DeviceDataLoader(train_dl, device)
test_dl = DeviceDataLoader(test_dl, device)

# %% [markdown]
# ## Network Architecture

# %% [markdown]
# Testing the models mentioned in the `pytorch-cifar` [GitHub Repository](https://github.com/kuangliu/pytorch-cifar).

# %% [markdown]
# ### ResNet Architecture

# %%
class BasicBlock(nn.Module):
  expansion = 1

  def __init__(self, in_planes, planes, stride=1):
    super(BasicBlock, self).__init__()
    self.conv1 = nn.Conv2d(
        in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
    self.bn1 = nn.BatchNorm2d(planes)
    self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                            stride=1, padding=1, bias=False)
    self.bn2 = nn.BatchNorm2d(planes)
    self.dropout = nn.Dropout(0.2) # Adding Dropout Layer

    self.shortcut = nn.Sequential()
    if stride != 1 or in_planes != self.expansion*planes:
      self.shortcut = nn.Sequential(
          nn.Conv2d(in_planes, self.expansion*planes,
                    kernel_size=1, stride=stride, bias=False),
          nn.BatchNorm2d(self.expansion*planes)
      )

  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))
    out = self.dropout(self.bn2(self.conv2(out))) # Adding Dropout in Forward Pass
    out += self.shortcut(x)
    out = F.relu(out)
    return out

class Bottleneck(nn.Module):
  expansion = 4

  def __init__(self, in_planes, planes, stride=1):
    super(Bottleneck, self).__init__()
    self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=1, bias=False)
    self.bn1 = nn.BatchNorm2d(planes)
    self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                            stride=stride, padding=1, bias=False)
    self.bn2 = nn.BatchNorm2d(planes)
    self.conv3 = nn.Conv2d(planes, self.expansion *
                            planes, kernel_size=1, bias=False)
    self.bn3 = nn.BatchNorm2d(self.expansion*planes)
    self.dropout = nn.Dropout(0.2) # Adding Dropout Layer

    self.shortcut = nn.Sequential()
    if stride != 1 or in_planes != self.expansion*planes:
      self.shortcut = nn.Sequential(
          nn.Conv2d(in_planes, self.expansion*planes,
                    kernel_size=1, stride=stride, bias=False),
          nn.BatchNorm2d(self.expansion*planes)
      )

  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))
    out = F.relu(self.bn2(self.conv2(out)))
    out = self.dropout(self.bn3(self.conv3(out))) # Adding Dropout in Forward Pass
    out += self.shortcut(x)
    out = F.relu(out)
    return out

class ResNet(nn.Module):
  def __init__(self, block, num_blocks, num_classes=10):
    super(ResNet, self).__init__()
    self.in_planes = 64

    self.conv1 = nn.Conv2d(3, 64, kernel_size=3,
                            stride=1, padding=1, bias=False)
    self.bn1 = nn.BatchNorm2d(64)
    self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
    self.layer2 = self._make_layer(block, 96, num_blocks[1], stride=2)
    self.layer3 = self._make_layer(block, 128, num_blocks[2], stride=2)
    self.layer4 = self._make_layer(block, 160, num_blocks[3], stride=2)
    self.linear = nn.Linear(160*block.expansion, num_classes)

  def _make_layer(self, block, planes, num_blocks, stride):
    strides = [stride] + [1]*(num_blocks-1)
    layers = []
    for stride in strides:
      layers.append(block(self.in_planes, planes, stride))
      self.in_planes = planes * block.expansion
    return nn.Sequential(*layers)

  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))
    out = self.layer1(out)
    out = self.layer2(out)
    out = self.layer3(out)
    out = self.layer4(out)
    out = F.avg_pool2d(out, 4)
    out = out.view(out.size(0), -1)
    out = self.linear(out)
    return out

def ResNet18():
  return ResNet(BasicBlock, [2, 2, 2, 2])

def ResNet9():
  return ResNet(BasicBlock, [1, 1, 1, 1])

def ResNet34():
    return ResNet(BasicBlock, [3, 4, 6, 3])

def ResNet50():
    return ResNet(Bottleneck, [3, 4, 6, 3])

# %% [markdown]
# ### ResNet50

# %%
model = ResNet50()

# %%
model =  model.to(device)
if device == 'cuda':
  model = torch.nn.DataParallel(model)
  cudnn.benchmark = True

# %%
summary(model, input_size=(3, 32, 32))
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            1,728
# ├─BatchNorm2d: 1-2                       128
# ├─Sequential: 1-3                        --
# |    └─Bottleneck: 2-1                   --
# |    |    └─Conv2d: 3-1                  4,096
# |    |    └─BatchNorm2d: 3-2             128
# |    |    └─Conv2d: 3-3                  36,864
# |    |    └─BatchNorm2d: 3-4             128
# |    |    └─Conv2d: 3-5                  16,384
# |    |    └─BatchNorm2d: 3-6             512
# |    |    └─Dropout: 3-7                 --
# |    |    └─Sequential: 3-8              16,896
# |    └─Bottleneck: 2-2                   --
# |    |    └─Conv2d: 3-9                  16,384
# |    |    └─BatchNorm2d: 3-10            128
# |    |    └─Conv2d: 3-11                 36,864
# |    |    └─BatchNorm2d: 3-12            128
# |    |    └─Conv2d: 3-13                 16,384
# |    |    └─BatchNorm2d: 3-14            512
# |    |    └─Dropout: 3-15                --
# |    |    └─Sequential: 3-16             --
# |    └─Bottleneck: 2-3                   --
# |    |    └─Conv2d: 3-17                 16,384
# |    |    └─BatchNorm2d: 3-18            128
# |    |    └─Conv2d: 3-19                 36,864
# |    |    └─BatchNorm2d: 3-20            128
# |    |    └─Conv2d: 3-21                 16,384
# |    |    └─BatchNorm2d: 3-22            512
# |    |    └─Dropout: 3-23                --
# |    |    └─Sequential: 3-24             --
# ├─Sequential: 1-4                        --
# |    └─Bottleneck: 2-4                   --
# |    |    └─Conv2d: 3-25                 24,576
# |    |    └─BatchNorm2d: 3-26            192
# |    |    └─Conv2d: 3-27                 82,944
# |    |    └─BatchNorm2d: 3-28            192
# |    |    └─Conv2d: 3-29                 36,864
# |    |    └─BatchNorm2d: 3-30            768
# |    |    └─Dropout: 3-31                --
# |    |    └─Sequential: 3-32             99,072
# |    └─Bottleneck: 2-5                   --
# |    |    └─Conv2d: 3-33                 36,864
# |    |    └─BatchNorm2d: 3-34            192
# |    |    └─Conv2d: 3-35                 82,944
# |    |    └─BatchNorm2d: 3-36            192
# |    |    └─Conv2d: 3-37                 36,864
# |    |    └─BatchNorm2d: 3-38            768
# |    |    └─Dropout: 3-39                --
# |    |    └─Sequential: 3-40             --
# |    └─Bottleneck: 2-6                   --
# |    |    └─Conv2d: 3-41                 36,864
# |    |    └─BatchNorm2d: 3-42            192
# |    |    └─Conv2d: 3-43                 82,944
# |    |    └─BatchNorm2d: 3-44            192
# |    |    └─Conv2d: 3-45                 36,864
# |    |    └─BatchNorm2d: 3-46            768
# |    |    └─Dropout: 3-47                --
# |    |    └─Sequential: 3-48             --
# |    └─Bottleneck: 2-7                   --
# |    |    └─Conv2d: 3-49                 36,864
# |    |    └─BatchNorm2d: 3-50            192
# |    |    └─Conv2d: 3-51                 82,944
# |    |    └─BatchNorm2d: 3-52            192
# |    |    └─Conv2d: 3-53                 36,864
# |    |    └─BatchNorm2d: 3-54            768
# |    |    └─Dropout: 3-55                --
# |    |    └─Sequential: 3-56             --
# ├─Sequential: 1-5                        --
# |    └─Bottleneck: 2-8                   --
# |    |    └─Conv2d: 3-57                 49,152
# |    |    └─BatchNorm2d: 3-58            256
# |    |    └─Conv2d: 3-59                 147,456
# |    |    └─BatchNorm2d: 3-60            256
# |    |    └─Conv2d: 3-61                 65,536
# |    |    └─BatchNorm2d: 3-62            1,024
# |    |    └─Dropout: 3-63                --
# |    |    └─Sequential: 3-64             197,632
# |    └─Bottleneck: 2-9                   --
# |    |    └─Conv2d: 3-65                 65,536
# |    |    └─BatchNorm2d: 3-66            256
# |    |    └─Conv2d: 3-67                 147,456
# |    |    └─BatchNorm2d: 3-68            256
# |    |    └─Conv2d: 3-69                 65,536
# |    |    └─BatchNorm2d: 3-70            1,024
# |    |    └─Dropout: 3-71                --
# |    |    └─Sequential: 3-72             --
# |    └─Bottleneck: 2-10                  --
# |    |    └─Conv2d: 3-73                 65,536
# |    |    └─BatchNorm2d: 3-74            256
# |    |    └─Conv2d: 3-75                 147,456
# |    |    └─BatchNorm2d: 3-76            256
# |    |    └─Conv2d: 3-77                 65,536
# |    |    └─BatchNorm2d: 3-78            1,024
# |    |    └─Dropout: 3-79                --
# |    |    └─Sequential: 3-80             --
# |    └─Bottleneck: 2-11                  --
# |    |    └─Conv2d: 3-81                 65,536
# |    |    └─BatchNorm2d: 3-82            256
# |    |    └─Conv2d: 3-83                 147,456
# |    |    └─BatchNorm2d: 3-84            256
# |    |    └─Conv2d: 3-85                 65,536
# |    |    └─BatchNorm2d: 3-86            1,024
# |    |    └─Dropout: 3-87                --
# |    |    └─Sequential: 3-88             --
# |    └─Bottleneck: 2-12                  --
# |    |    └─Conv2d: 3-89                 65,536
# |    |    └─BatchNorm2d: 3-90            256
# |    |    └─Conv2d: 3-91                 147,456
# |    |    └─BatchNorm2d: 3-92            256
# |    |    └─Conv2d: 3-93                 65,536
# |    |    └─BatchNorm2d: 3-94            1,024
# |    |    └─Dropout: 3-95                --
# |    |    └─Sequential: 3-96             --
# |    └─Bottleneck: 2-13                  --
# |    |    └─Conv2d: 3-97                 65,536
# |    |    └─BatchNorm2d: 3-98            256
# |    |    └─Conv2d: 3-99                 147,456
# |    |    └─BatchNorm2d: 3-100           256
# |    |    └─Conv2d: 3-101                65,536
# |    |    └─BatchNorm2d: 3-102           1,024
# |    |    └─Dropout: 3-103               --
# |    |    └─Sequential: 3-104            --
# ├─Sequential: 1-6                        --
# |    └─Bottleneck: 2-14                  --
# |    |    └─Conv2d: 3-105                81,920
# |    |    └─BatchNorm2d: 3-106           320
# |    |    └─Conv2d: 3-107                230,400
# |    |    └─BatchNorm2d: 3-108           320
# |    |    └─Conv2d: 3-109                102,400
# |    |    └─BatchNorm2d: 3-110           1,280
# |    |    └─Dropout: 3-111               --
# |    |    └─Sequential: 3-112            328,960
# |    └─Bottleneck: 2-15                  --
# |    |    └─Conv2d: 3-113                102,400
# |    |    └─BatchNorm2d: 3-114           320
# |    |    └─Conv2d: 3-115                230,400
# |    |    └─BatchNorm2d: 3-116           320
# |    |    └─Conv2d: 3-117                102,400
# |    |    └─BatchNorm2d: 3-118           1,280
# |    |    └─Dropout: 3-119               --
# |    |    └─Sequential: 3-120            --
# |    └─Bottleneck: 2-16                  --
# |    |    └─Conv2d: 3-121                102,400
# |    |    └─BatchNorm2d: 3-122           320
# |    |    └─Conv2d: 3-123                230,400
# |    |    └─BatchNorm2d: 3-124           320
# |    |    └─Conv2d: 3-125                102,400
# |    |    └─BatchNorm2d: 3-126           1,280
# |    |    └─Dropout: 3-127               --
# |    |    └─Sequential: 3-128            --
# ├─Linear: 1-7                            6,410
# =================================================================
# Total params: 4,423,626
# Trainable params: 4,423,626
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            1,728
# ├─BatchNorm2d: 1-2                       128
# ├─Sequential: 1-3                        --
# |    └─Bottleneck: 2-1                   --
# |    |    └─Conv2d: 3-1                  4,096
# |    |    └─BatchNorm2d: 3-2             128
# |    |    └─Conv2d: 3-3                  36,864
# |    |    └─BatchNorm2d: 3-4             128
# |    |    └─Conv2d: 3-5                  16,384
# |    |    └─BatchNorm2d: 3-6             512
# |    |    └─Dropout: 3-7                 --
# |    |    └─Sequential: 3-8              16,896
# |    └─Bottleneck: 2-2                   --
# |    |    └─Conv2d: 3-9                  16,384
# |    |    └─BatchNorm2d: 3-10            128
# |    |    └─Conv2d: 3-11                 36,864
# |    |    └─BatchNorm2d: 3-12            128
# |    |    └─Conv2d: 3-13                 16,384
# |    |    └─BatchNorm2d: 3-14            512
# |    |    └─Dropout: 3-15                --
# |    |    └─Sequential: 3-16             --
# |    └─Bottleneck: 2-3                   --
# |    |    └─Conv2d: 3-17                 16,384
# |    |    └─BatchNorm2d: 3-18            128
# |    |    └─Conv2d: 3-19                 36,864
# |    |    └─BatchNorm2d: 3-20            128
# |    |    └─Conv2d: 3-21                 16,384
# |    |    └─BatchNorm2d: 3-22            512
# |    |    └─Dropout: 3-23                --
# |    |    └─Sequential: 3-24             --
# ├─Sequential: 1-4                        --
# |    └─Bottleneck: 2-4                   --
# |    |    └─Conv2d: 3-25                 24,576
# |    |    └─BatchNorm2d: 3-26            192
# |    |    └─Conv2d: 3-27                 82,944
# |    |    └─BatchNorm2d: 3-28            192
# |    |    └─Conv2d: 3-29                 36,864
# |    |    └─BatchNorm2d: 3-30            768
# |    |    └─Dropout: 3-31                --
# |    |    └─Sequential: 3-32             99,072
# |    └─Bottleneck: 2-5                   --
# |    |    └─Conv2d: 3-33                 36,864
# |    |    └─BatchNorm2d: 3-34            192
# |    |    └─Conv2d: 3-35                 82,944
# |    |    └─BatchNorm2d: 3-36            192
# |    |    └─Conv2d: 3-37                 36,864
# |    |    └─BatchNorm2d: 3-38            768
# |    |    └─Dropout: 3-39                --
# |    |    └─Sequential: 3-40             --
# |    └─Bottleneck: 2-6                   --
# |    |    └─Conv2d: 3-41                 36,864
# |    |    └─BatchNorm2d: 3-42            192
# |    |    └─Conv2d: 3-43                 82,944
# |    |    └─BatchNorm2d: 3-44            192
# |    |    └─Conv2d: 3-45                 36,864
# |    |    └─BatchNorm2d: 3-46            768
# |    |    └─Dropout: 3-47                --
# |    |    └─Sequential: 3-48             --
# |    └─Bottleneck: 2-7                   --
# |    |    └─Conv2d: 3-49                 36,864
# |    |    └─BatchNorm2d: 3-50            192
# |    |    └─Conv2d: 3-51                 82,944
# |    |    └─BatchNorm2d: 3-52            192
# |    |    └─Conv2d: 3-53                 36,864
# |    |    └─BatchNorm2d: 3-54            768
# |    |    └─Dropout: 3-55                --
# |    |    └─Sequential: 3-56             --
# ├─Sequential: 1-5                        --
# |    └─Bottleneck: 2-8                   --
# |    |    └─Conv2d: 3-57                 49,152
# |    |    └─BatchNorm2d: 3-58            256
# |    |    └─Conv2d: 3-59                 147,456
# |    |    └─BatchNorm2d: 3-60            256
# |    |    └─Conv2d: 3-61                 65,536
# |    |    └─BatchNorm2d: 3-62            1,024
# |    |    └─Dropout: 3-63                --
# |    |    └─Sequential: 3-64             197,632
# |    └─Bottleneck: 2-9                   --
# |    |    └─Conv2d: 3-65                 65,536
# |    |    └─BatchNorm2d: 3-66            256
# |    |    └─Conv2d: 3-67                 147,456
# |    |    └─BatchNorm2d: 3-68            256
# |    |    └─Conv2d: 3-69                 65,536
# |    |    └─BatchNorm2d: 3-70            1,024
# |    |    └─Dropout: 3-71                --
# |    |    └─Sequential: 3-72             --
# |    └─Bottleneck: 2-10                  --
# |    |    └─Conv2d: 3-73                 65,536
# |    |    └─BatchNorm2d: 3-74            256
# |    |    └─Conv2d: 3-75                 147,456
# |    |    └─BatchNorm2d: 3-76            256
# |    |    └─Conv2d: 3-77                 65,536
# |    |    └─BatchNorm2d: 3-78            1,024
# |    |    └─Dropout: 3-79                --
# |    |    └─Sequential: 3-80             --
# |    └─Bottleneck: 2-11                  --
# |    |    └─Conv2d: 3-81                 65,536
# |    |    └─BatchNorm2d: 3-82            256
# |    |    └─Conv2d: 3-83                 147,456
# |    |    └─BatchNorm2d: 3-84            256
# |    |    └─Conv2d: 3-85                 65,536
# |    |    └─BatchNorm2d: 3-86            1,024
# |    |    └─Dropout: 3-87                --
# |    |    └─Sequential: 3-88             --
# |    └─Bottleneck: 2-12                  --
# |    |    └─Conv2d: 3-89                 65,536
# |    |    └─BatchNorm2d: 3-90            256
# |    |    └─Conv2d: 3-91                 147,456
# |    |    └─BatchNorm2d: 3-92            256
# |    |    └─Conv2d: 3-93                 65,536
# |    |    └─BatchNorm2d: 3-94            1,024
# |    |    └─Dropout: 3-95                --
# |    |    └─Sequential: 3-96             --
# |    └─Bottleneck: 2-13                  --
# |    |    └─Conv2d: 3-97                 65,536
# |    |    └─BatchNorm2d: 3-98            256
# |    |    └─Conv2d: 3-99                 147,456
# |    |    └─BatchNorm2d: 3-100           256
# |    |    └─Conv2d: 3-101                65,536
# |    |    └─BatchNorm2d: 3-102           1,024
# |    |    └─Dropout: 3-103               --
# |    |    └─Sequential: 3-104            --
# ├─Sequential: 1-6                        --
# |    └─Bottleneck: 2-14                  --
# |    |    └─Conv2d: 3-105                81,920
# |    |    └─BatchNorm2d: 3-106           320
# |    |    └─Conv2d: 3-107                230,400
# |    |    └─BatchNorm2d: 3-108           320
# |    |    └─Conv2d: 3-109                102,400
# |    |    └─BatchNorm2d: 3-110           1,280
# |    |    └─Dropout: 3-111               --
# |    |    └─Sequential: 3-112            328,960
# |    └─Bottleneck: 2-15                  --
# |    |    └─Conv2d: 3-113                102,400
# |    |    └─BatchNorm2d: 3-114           320
# |    |    └─Conv2d: 3-115                230,400
# |    |    └─BatchNorm2d: 3-116           320
# |    |    └─Conv2d: 3-117                102,400
# |    |    └─BatchNorm2d: 3-118           1,280
# |    |    └─Dropout: 3-119               --
# |    |    └─Sequential: 3-120            --
# |    └─Bottleneck: 2-16                  --
# |    |    └─Conv2d: 3-121                102,400
# |    |    └─BatchNorm2d: 3-122           320
# |    |    └─Conv2d: 3-123                230,400
# |    |    └─BatchNorm2d: 3-124           320
# |    |    └─Conv2d: 3-125                102,400
# |    |    └─BatchNorm2d: 3-126           1,280
# |    |    └─Dropout: 3-127               --
# |    |    └─Sequential: 3-128            --
# ├─Linear: 1-7                            6,410
# =================================================================
# Total params: 4,423,626
# Trainable params: 4,423,626
# Non-trainable params: 0
# =================================================================

# %% [markdown]
# ## Model Training

# %%
# Helper Function to Format Time
def format_time(seconds):
  days = int(seconds / 3600/24)
  seconds = seconds - days*3600*24
  hours = int(seconds / 3600)
  seconds = seconds - hours*3600
  minutes = int(seconds / 60)
  seconds = seconds - minutes*60
  secondsf = int(seconds)
  seconds = seconds - secondsf
  millis = int(seconds*1000)

  f = ''
  i = 1
  if days > 0:
    f += str(days) + 'D'
    i += 1
  if hours > 0 and i <= 2:
    f += str(hours) + 'h'
    i += 1
  if minutes > 0 and i <= 2:
    f += str(minutes) + 'm'
    i += 1
  if secondsf > 0 and i <= 2:
    f += str(secondsf) + 's'
    i += 1
  if millis > 0 and i <= 2:
    f += str(millis) + 'ms'
    i += 1
  if f == '':
    f = '0ms'
  return f

# %% [markdown]
# Loss: CrossEntropyLoss
#
# Optimizer: SGD
#
# Learning Rate: 0.1
#
# Momentum: 0.9
#
# Weight Decay: 5e-4
#
# Number of Epochs: 100
#
# Scheduler: CosineAnnealingLR

# %%
lr = 0.1
momentum = 0.9
weight_decay = 5e-4

start_epoch = 1
number_of_epochs = 100
best_acc = 0


criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=lr,
                      momentum=momentum, weight_decay=weight_decay)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=number_of_epochs)

# %%
# Helper Function to get Learning Rate
def get_lr(optimizer):
  for param_group in optimizer.param_groups:
    return param_group['lr']

# %%
def train(epoch):
  print('\nEpoch: %d' % epoch)
  start_time = time.time()

  model.train()
  train_loss = 0
  correct = 0
  total = 0
  for batch_idx, (inputs, targets) in enumerate(train_dl):
    # inputs, targets = inputs.to(device), targets.to(device)
    optimizer.zero_grad()
    outputs = model(inputs)
    loss = criterion(outputs, targets)
    loss.backward()
    optimizer.step()

    train_loss += loss.item()
    _, predicted = outputs.max(1)
    total += targets.size(0)
    correct += predicted.eq(targets).sum().item()

  cur_time = time.time()
  epoch_time = cur_time - start_time
  print(f"Training Time : {format_time(epoch_time)}")

  return train_loss/(batch_idx+1), 100.*correct/total, get_lr(optimizer)

# %%
def test(epoch):
  global best_acc
  model.eval()
  test_loss = 0
  correct = 0
  total = 0
  with torch.no_grad():
    for batch_idx, (inputs, targets) in enumerate(test_dl):
      outputs = model(inputs)
      loss = criterion(outputs, targets)

      test_loss += loss.item()
      _, predicted = outputs.max(1)
      total += targets.size(0)
      correct += predicted.eq(targets).sum().item()
      
  # Save checkpoint.
  acc = 100.*correct/total
  if acc > best_acc:
    print('Saving..')
    state = {
        'net': model.state_dict(),
        'acc': acc,
        'epoch': epoch,
    }
    if not os.path.isdir('checkpoint'):
      os.mkdir('checkpoint')
    torch.save(state, './checkpoint/resnet_50_dropout_best.pth')
    best_acc = acc

  return test_loss/(batch_idx+1), 100.*correct/total

# %%
train_losses = []
train_accuracies = []
train_lrs = []

test_losses = []
test_accuracies = []

for epoch in range(start_epoch, start_epoch + number_of_epochs):
  epoch_train_loss, epoch_train_accuracy, epoch_lr = train(epoch)
  train_losses.append(epoch_train_loss)
  train_accuracies.append(epoch_train_accuracy)
  train_lrs.append(epoch_lr)

  epoch_test_loss, epoch_test_accuracy = test(epoch)
  test_losses.append(epoch_test_loss)
  test_accuracies.append(epoch_test_accuracy)

  scheduler.step()
  print(f"Train Loss: {epoch_train_loss:.3f} | Train Accuracy: {epoch_train_accuracy:.3f}% | Test Loss: {epoch_test_loss:.3f} | Test Accuracy: {epoch_test_accuracy:.3f}%")
# Out:
# Epoch: 1
# Training Time : 36s853ms
# Saving..
# Train Loss: 2.209 | Train Accuracy: 20.922% | Test Loss: 1.817 | Test Accuracy: 30.780%
#
# Epoch: 2
# Training Time : 35s61ms
# Saving..
# Train Loss: 1.729 | Train Accuracy: 34.818% | Test Loss: 1.579 | Test Accuracy: 41.530%
#
# Epoch: 3
# Training Time : 35s34ms
# Saving..
# Train Loss: 1.585 | Train Accuracy: 41.188% | Test Loss: 1.443 | Test Accuracy: 45.880%
#
# Epoch: 4
# Training Time : 35s24ms
# Saving..
# Train Loss: 1.417 | Train Accuracy: 48.040% | Test Loss: 1.369 | Test Accuracy: 50.720%
#
# Epoch: 5
# Training Time : 35s14ms
# Saving..
# Train Loss: 1.265 | Train Accuracy: 53.916% | Test Loss: 1.356 | Test Accuracy: 53.690%
#
# Epoch: 6
# Training Time : 34s978ms
# Saving..
# Train Loss: 1.090 | Train Accuracy: 60.864% | Test Loss: 0.996 | Test Accuracy: 64.600%
#
# Epoch: 7
# Training Time : 34s986ms
# Saving..
# Train Loss: 0.974 | Train Accuracy: 65.560% | Test Loss: 0.955 | Test Accuracy: 66.160%
#
# Epoch: 8
# Training Time : 35s17ms
# Saving..
# Train Loss: 0.869 | Train Accuracy: 69.374% | Test Loss: 0.826 | Test Accuracy: 70.270%
#
# Epoch: 9
# Training Time : 35s12ms
# Saving..
# Train Loss: 0.794 | Train Accuracy: 72.308% | Test Loss: 0.808 | Test Accuracy: 71.560%
#
# Epoch: 10
# Training Time : 35s21ms
# Saving..
# Train Loss: 0.730 | Train Accuracy: 74.390% | Test Loss: 0.791 | Test Accuracy: 73.320%
#
# Epoch: 11
# Training Time : 34s992ms
# Saving..
# Train Loss: 0.694 | Train Accuracy: 75.982% | Test Loss: 0.677 | Test Accuracy: 76.600%
#
# Epoch: 12
# Training Time : 34s987ms
# Train Loss: 0.665 | Train Accuracy: 77.132% | Test Loss: 0.762 | Test Accuracy: 74.060%
#
# Epoch: 13
# Training Time : 34s972ms
# Saving..
# Train Loss: 0.641 | Train Accuracy: 77.720% | Test Loss: 0.644 | Test Accuracy: 77.530%
#
# Epoch: 14
# Training Time : 34s989ms
# Saving..
# Train Loss: 0.619 | Train Accuracy: 78.594% | Test Loss: 0.647 | Test Accuracy: 77.660%
#
# Epoch: 15
# Training Time : 34s983ms
# Train Loss: 0.604 | Train Accuracy: 79.276% | Test Loss: 0.882 | Test Accuracy: 71.540%
#
# Epoch: 16
# Training Time : 35s1ms
# Train Loss: 0.588 | Train Accuracy: 79.864% | Test Loss: 0.966 | Test Accuracy: 70.020%
#
# Epoch: 17
# Training Time : 34s964ms
# Train Loss: 0.570 | Train Accuracy: 80.380% | Test Loss: 0.725 | Test Accuracy: 75.700%
#
# Epoch: 18
# Training Time : 34s965ms
# Train Loss: 0.559 | Train Accuracy: 80.558% | Test Loss: 0.782 | Test Accuracy: 74.270%
#
# Epoch: 19
# Training Time : 34s952ms
# Saving..
# Train Loss: 0.552 | Train Accuracy: 81.016% | Test Loss: 0.613 | Test Accuracy: 79.080%
#
# Epoch: 20
# Training Time : 34s994ms
# Train Loss: 0.536 | Train Accuracy: 81.506% | Test Loss: 0.664 | Test Accuracy: 77.490%
#
# Epoch: 21
# Training Time : 34s979ms
# Train Loss: 0.534 | Train Accuracy: 81.518% | Test Loss: 0.690 | Test Accuracy: 76.880%
#
# Epoch: 22
# Training Time : 34s986ms
# Train Loss: 0.526 | Train Accuracy: 82.062% | Test Loss: 0.635 | Test Accuracy: 78.400%
#
# Epoch: 23
# Training Time : 34s983ms
# Train Loss: 0.509 | Train Accuracy: 82.522% | Test Loss: 0.641 | Test Accuracy: 78.040%
#
# Epoch: 24
# Training Time : 34s977ms
# Train Loss: 0.506 | Train Accuracy: 82.532% | Test Loss: 0.638 | Test Accuracy: 78.160%
#
# Epoch: 25
# Training Time : 34s995ms
# Train Loss: 0.501 | Train Accuracy: 82.822% | Test Loss: 0.681 | Test Accuracy: 77.630%
#
# Epoch: 26
# Training Time : 35s3ms
# Saving..
# Train Loss: 0.491 | Train Accuracy: 83.030% | Test Loss: 0.596 | Test Accuracy: 80.110%
#
# Epoch: 27
# Training Time : 34s994ms
# Saving..
# Train Loss: 0.482 | Train Accuracy: 83.338% | Test Loss: 0.521 | Test Accuracy: 82.490%
#
# Epoch: 28
# Training Time : 34s976ms
# Saving..
# Train Loss: 0.481 | Train Accuracy: 83.364% | Test Loss: 0.483 | Test Accuracy: 83.180%
#
# Epoch: 29
# Training Time : 34s989ms
# Saving..
# Train Loss: 0.467 | Train Accuracy: 83.952% | Test Loss: 0.493 | Test Accuracy: 83.270%
#
# Epoch: 30
# Training Time : 34s983ms
# Train Loss: 0.466 | Train Accuracy: 83.998% | Test Loss: 0.686 | Test Accuracy: 77.300%
#
# Epoch: 31
# Training Time : 34s997ms
# Train Loss: 0.464 | Train Accuracy: 84.058% | Test Loss: 0.622 | Test Accuracy: 79.900%
#
# Epoch: 32
# Training Time : 34s945ms
# Train Loss: 0.446 | Train Accuracy: 84.712% | Test Loss: 0.609 | Test Accuracy: 79.680%
#
# Epoch: 33
# Training Time : 34s976ms
# Train Loss: 0.449 | Train Accuracy: 84.488% | Test Loss: 0.523 | Test Accuracy: 82.710%
#
# Epoch: 34
# Training Time : 35s8ms
# Train Loss: 0.440 | Train Accuracy: 84.826% | Test Loss: 0.631 | Test Accuracy: 79.770%
#
# Epoch: 35
# Training Time : 34s999ms
# Saving..
# Train Loss: 0.434 | Train Accuracy: 84.952% | Test Loss: 0.458 | Test Accuracy: 84.510%
#
# Epoch: 36
# Training Time : 35s2ms
# Train Loss: 0.427 | Train Accuracy: 85.222% | Test Loss: 0.471 | Test Accuracy: 83.930%
#
# Epoch: 37
# Training Time : 35s
# Train Loss: 0.420 | Train Accuracy: 85.464% | Test Loss: 0.482 | Test Accuracy: 83.570%
#
# Epoch: 38
# Training Time : 34s987ms
# Train Loss: 0.420 | Train Accuracy: 85.478% | Test Loss: 0.504 | Test Accuracy: 83.200%
#
# Epoch: 39
# Training Time : 34s999ms
# Train Loss: 0.412 | Train Accuracy: 85.858% | Test Loss: 0.480 | Test Accuracy: 83.910%
#
# Epoch: 40
# Training Time : 34s972ms
# Train Loss: 0.403 | Train Accuracy: 86.082% | Test Loss: 0.529 | Test Accuracy: 81.960%
#
# Epoch: 41
# Training Time : 34s996ms
# Train Loss: 0.397 | Train Accuracy: 86.528% | Test Loss: 0.490 | Test Accuracy: 83.150%
#
# Epoch: 42
# Training Time : 34s969ms
# Saving..
# Train Loss: 0.385 | Train Accuracy: 86.672% | Test Loss: 0.445 | Test Accuracy: 85.110%
#
# Epoch: 43
# Training Time : 34s990ms
# Train Loss: 0.390 | Train Accuracy: 86.712% | Test Loss: 0.479 | Test Accuracy: 84.410%
#
# Epoch: 44
# Training Time : 34s940ms
# Train Loss: 0.379 | Train Accuracy: 86.938% | Test Loss: 0.547 | Test Accuracy: 82.140%
#
# Epoch: 45
# Training Time : 34s990ms
# Saving..
# Train Loss: 0.377 | Train Accuracy: 86.814% | Test Loss: 0.414 | Test Accuracy: 86.070%
#
# Epoch: 46
# Training Time : 34s962ms
# Train Loss: 0.361 | Train Accuracy: 87.670% | Test Loss: 0.443 | Test Accuracy: 85.520%
#
# Epoch: 47
# Training Time : 34s966ms
# Train Loss: 0.364 | Train Accuracy: 87.488% | Test Loss: 0.443 | Test Accuracy: 85.120%
#
# Epoch: 48
# Training Time : 34s975ms
# Train Loss: 0.351 | Train Accuracy: 87.936% | Test Loss: 0.440 | Test Accuracy: 85.090%
#
# Epoch: 49
# Training Time : 34s990ms
# Saving..
# Train Loss: 0.345 | Train Accuracy: 88.112% | Test Loss: 0.410 | Test Accuracy: 86.430%
#
# Epoch: 50
# Training Time : 34s985ms
# Train Loss: 0.343 | Train Accuracy: 88.252% | Test Loss: 0.441 | Test Accuracy: 85.210%
#
# Epoch: 51
# Training Time : 34s947ms
# Train Loss: 0.331 | Train Accuracy: 88.562% | Test Loss: 0.508 | Test Accuracy: 84.160%
#
# Epoch: 52
# Training Time : 34s963ms
# Saving..
# Train Loss: 0.328 | Train Accuracy: 88.726% | Test Loss: 0.366 | Test Accuracy: 87.590%
#
# Epoch: 53
# Training Time : 34s966ms
# Saving..
# Train Loss: 0.319 | Train Accuracy: 89.012% | Test Loss: 0.357 | Test Accuracy: 87.730%
#
# Epoch: 54
# Training Time : 34s976ms
# Train Loss: 0.316 | Train Accuracy: 89.110% | Test Loss: 0.389 | Test Accuracy: 86.730%
#
# Epoch: 55
# Training Time : 34s934ms
# Train Loss: 0.306 | Train Accuracy: 89.442% | Test Loss: 0.429 | Test Accuracy: 85.830%
#
# Epoch: 56
# Training Time : 34s979ms
# Train Loss: 0.299 | Train Accuracy: 89.604% | Test Loss: 0.375 | Test Accuracy: 87.380%
#
# Epoch: 57
# Training Time : 34s977ms
# Train Loss: 0.292 | Train Accuracy: 89.820% | Test Loss: 0.369 | Test Accuracy: 87.580%
#
# Epoch: 58
# Training Time : 34s975ms
# Saving..
# Train Loss: 0.288 | Train Accuracy: 90.064% | Test Loss: 0.361 | Test Accuracy: 87.800%
#
# Epoch: 59
# Training Time : 34s975ms
# Saving..
# Train Loss: 0.289 | Train Accuracy: 89.952% | Test Loss: 0.358 | Test Accuracy: 88.050%
#
# Epoch: 60
# Training Time : 34s985ms
# Saving..
# Train Loss: 0.269 | Train Accuracy: 90.630% | Test Loss: 0.363 | Test Accuracy: 88.100%
#
# Epoch: 61
# Training Time : 34s950ms
# Saving..
# Train Loss: 0.264 | Train Accuracy: 90.890% | Test Loss: 0.330 | Test Accuracy: 89.350%
#
# Epoch: 62
# Training Time : 34s966ms
# Train Loss: 0.259 | Train Accuracy: 90.918% | Test Loss: 0.372 | Test Accuracy: 87.740%
#
# Epoch: 63
# Training Time : 34s937ms
# Train Loss: 0.250 | Train Accuracy: 91.414% | Test Loss: 0.358 | Test Accuracy: 88.220%
#
# Epoch: 64
# Training Time : 34s938ms
# Train Loss: 0.239 | Train Accuracy: 91.662% | Test Loss: 0.381 | Test Accuracy: 87.550%
#
# Epoch: 65
# Training Time : 34s944ms
# Train Loss: 0.240 | Train Accuracy: 91.692% | Test Loss: 0.332 | Test Accuracy: 89.260%
#
# Epoch: 66
# Training Time : 34s967ms
# Saving..
# Train Loss: 0.229 | Train Accuracy: 91.978% | Test Loss: 0.303 | Test Accuracy: 89.700%
#
# Epoch: 67
# Training Time : 34s960ms
# Saving..
# Train Loss: 0.216 | Train Accuracy: 92.572% | Test Loss: 0.301 | Test Accuracy: 89.780%
#
# Epoch: 68
# Training Time : 34s955ms
# Saving..
# Train Loss: 0.208 | Train Accuracy: 92.704% | Test Loss: 0.300 | Test Accuracy: 90.110%
#
# Epoch: 69
# Training Time : 34s926ms
# Saving..
# Train Loss: 0.197 | Train Accuracy: 93.108% | Test Loss: 0.290 | Test Accuracy: 90.710%
#
# Epoch: 70
# Training Time : 34s949ms
# Train Loss: 0.194 | Train Accuracy: 93.384% | Test Loss: 0.307 | Test Accuracy: 90.070%
#
# Epoch: 71
# Training Time : 34s959ms
# Train Loss: 0.182 | Train Accuracy: 93.802% | Test Loss: 0.284 | Test Accuracy: 90.470%
#
# Epoch: 72
# Training Time : 34s926ms
# Saving..
# Train Loss: 0.176 | Train Accuracy: 93.900% | Test Loss: 0.278 | Test Accuracy: 91.170%
#
# Epoch: 73
# Training Time : 34s969ms
# Train Loss: 0.167 | Train Accuracy: 94.302% | Test Loss: 0.282 | Test Accuracy: 91.120%
#
# Epoch: 74
# Training Time : 34s896ms
# Saving..
# Train Loss: 0.158 | Train Accuracy: 94.468% | Test Loss: 0.274 | Test Accuracy: 91.450%
#
# Epoch: 75
# Training Time : 34s927ms
# Train Loss: 0.146 | Train Accuracy: 94.950% | Test Loss: 0.294 | Test Accuracy: 90.960%
#
# Epoch: 76
# Training Time : 34s956ms
# Saving..
# Train Loss: 0.138 | Train Accuracy: 95.264% | Test Loss: 0.265 | Test Accuracy: 91.650%
#
# Epoch: 77
# Training Time : 34s926ms
# Saving..
# Train Loss: 0.130 | Train Accuracy: 95.390% | Test Loss: 0.260 | Test Accuracy: 91.860%
#
# Epoch: 78
# Training Time : 34s912ms
# Saving..
# Train Loss: 0.119 | Train Accuracy: 95.918% | Test Loss: 0.227 | Test Accuracy: 92.580%
#
# Epoch: 79
# Training Time : 34s929ms
# Train Loss: 0.111 | Train Accuracy: 96.160% | Test Loss: 0.256 | Test Accuracy: 92.180%
#
# Epoch: 80
# Training Time : 34s924ms
# Saving..
# Train Loss: 0.104 | Train Accuracy: 96.430% | Test Loss: 0.233 | Test Accuracy: 92.810%
#
# Epoch: 81
# Training Time : 34s907ms
# Train Loss: 0.090 | Train Accuracy: 96.864% | Test Loss: 0.248 | Test Accuracy: 92.330%
#
# Epoch: 82
# Training Time : 34s935ms
# Saving..
# Train Loss: 0.082 | Train Accuracy: 97.154% | Test Loss: 0.231 | Test Accuracy: 93.110%
#
# Epoch: 83
# Training Time : 34s928ms
# Saving..
# Train Loss: 0.074 | Train Accuracy: 97.430% | Test Loss: 0.225 | Test Accuracy: 93.240%
#
# Epoch: 84
# Training Time : 34s934ms
# Saving..
# Train Loss: 0.065 | Train Accuracy: 97.758% | Test Loss: 0.224 | Test Accuracy: 93.530%
#
# Epoch: 85
# Training Time : 34s931ms
# Saving..
# Train Loss: 0.059 | Train Accuracy: 98.042% | Test Loss: 0.222 | Test Accuracy: 93.540%
#
# Epoch: 86
# Training Time : 34s931ms
# Saving..
# Train Loss: 0.049 | Train Accuracy: 98.312% | Test Loss: 0.208 | Test Accuracy: 93.980%
#
# Epoch: 87
# Training Time : 34s922ms
# Train Loss: 0.044 | Train Accuracy: 98.560% | Test Loss: 0.221 | Test Accuracy: 93.640%
#
# Epoch: 88
# Training Time : 34s934ms
# Train Loss: 0.037 | Train Accuracy: 98.794% | Test Loss: 0.220 | Test Accuracy: 93.890%
#
# Epoch: 89
# Training Time : 34s933ms
# Saving..
# Train Loss: 0.031 | Train Accuracy: 99.022% | Test Loss: 0.215 | Test Accuracy: 94.200%
#
# Epoch: 90
# Training Time : 34s919ms
# Saving..
# Train Loss: 0.028 | Train Accuracy: 99.140% | Test Loss: 0.212 | Test Accuracy: 94.230%
#
# Epoch: 91
# Training Time : 34s915ms
# Train Loss: 0.025 | Train Accuracy: 99.232% | Test Loss: 0.220 | Test Accuracy: 94.130%
#
# Epoch: 92
# Training Time : 34s918ms
# Train Loss: 0.023 | Train Accuracy: 99.314% | Test Loss: 0.218 | Test Accuracy: 94.170%
#
# Epoch: 93
# Training Time : 34s929ms
# Saving..
# Train Loss: 0.021 | Train Accuracy: 99.350% | Test Loss: 0.213 | Test Accuracy: 94.420%
#
# Epoch: 94
# Training Time : 34s938ms
# Train Loss: 0.018 | Train Accuracy: 99.476% | Test Loss: 0.210 | Test Accuracy: 94.280%
#
# Epoch: 95
# Training Time : 34s918ms
# Train Loss: 0.015 | Train Accuracy: 99.588% | Test Loss: 0.210 | Test Accuracy: 94.300%
#
# Epoch: 96
# Training Time : 34s904ms
# Train Loss: 0.015 | Train Accuracy: 99.574% | Test Loss: 0.209 | Test Accuracy: 94.290%
#
# Epoch: 97
# Training Time : 34s911ms
# Train Loss: 0.014 | Train Accuracy: 99.602% | Test Loss: 0.212 | Test Accuracy: 94.330%
#
# Epoch: 98
# Training Time : 34s910ms
# Train Loss: 0.013 | Train Accuracy: 99.660% | Test Loss: 0.210 | Test Accuracy: 94.380%
#
# Epoch: 99
# Training Time : 34s907ms
# Train Loss: 0.013 | Train Accuracy: 99.660% | Test Loss: 0.210 | Test Accuracy: 94.390%
#
# Epoch: 100
# Training Time : 34s912ms
# Train Loss: 0.013 | Train Accuracy: 99.646% | Test Loss: 0.211 | Test Accuracy: 94.400%

# %%
print(f"Best Accuracy: {best_acc:.3f}%")
# Out:
# Best Accuracy: 94.420%

# %%
def plot_accuracies(train_accuracies, test_accuracies):
  plt.plot(train_accuracies, label='Train Accuracy')
  plt.plot(test_accuracies, label='Test Accuracy')
  plt.xlabel('Epochs')
  plt.ylabel('Accuracy')
  plt.legend()
  plt.grid(True)
  plt.title('Accuracy vs. No. of epochs')

# %%
def plot_losses(train_losses, test_losses):
  plt.plot(train_losses, label='Train Losses')
  plt.plot(test_losses, label='Test Losses')
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.legend()
  plt.grid(True)
  plt.title('Loss vs. No. of epochs')

# %%
def plot_lrs(train_lrs):
  plt.plot(train_lrs)
  plt.xlabel('Epochs')
  plt.ylabel('Learning rate')
  plt.grid(True)
  plt.title('Learning Rate vs. Epochs')

# %%
plot_accuracies(train_accuracies, test_accuracies)

# %%
plot_losses(train_losses, test_losses)

# %%
plot_lrs(train_lrs)

# %%
print('Saving final model..')
state = {
    'net': model.state_dict(),
    'acc': test_accuracies[-1],
    'epoch': number_of_epochs,
    'best_acc' : best_acc,
    'train_acc' : train_accuracies,
    'test_acc' : test_accuracies,
    'train_loss' : train_losses,
    'test_loss' : test_losses,
    'lr' : train_lrs
}
if not os.path.isdir('checkpoint'):
  os.mkdir('checkpoint')
torch.save(state, './checkpoint/resnet_50_dropout_final.pth')
# Out:
# Saving final model..

# %%
import numpy as np
import pickle
import pandas as pd

# Function to load CIFAR batch
def load_cifar_batch(file):
    with open(file, 'rb') as fo:
        batch = pickle.load(fo, encoding='bytes')
    return batch

# Specify the folder where the CIFAR-10 batch files are
cifar10_dir = './data/cifar-10-batches-py'

# Load the label names
meta_data_dict = load_cifar_batch(os.path.join(cifar10_dir, 'batches.meta'))
label_names = meta_data_dict[b'label_names']

# Load test data
test_batch = load_cifar_batch('./cifar_test_nolabels.pkl')
test_images = test_batch[b'data'].reshape(-1, 3, 32, 32).transpose(0, 2, 3, 1)

data_statistics = (
    (0.49139968, 0.48215827, 0.44653124),
     (0.24703233, 0.24348505, 0.26158768)
)

# Define transformation for data augmentation
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(*data_statistics, inplace=True)
])

# Apply data augmentation
augmented_test_images = torch.stack([transform(image) for image in test_images])

# Load the trained model
model = ResNet50()

checkpoint = torch.load('./checkpoint/resnet_50_dropout_best.pth')

# Check the keys in the checkpoint dictionary
print(checkpoint.keys())

# Assuming the model state dictionary is saved under a different key
# Adjust this according to the actual key in your checkpoint file
model.load_state_dict(checkpoint['net'])

model =  model.to(device)
augmented_test_images = augmented_test_images.to(device)

# Evaluate the model on test data
model.eval()
with torch.no_grad():
    outputs = model(augmented_test_images)
_, predicted = torch.max(outputs, 1)

predicted = predicted.to('cpu')

# Display the first 10 test images and predicted labels
plt.figure(figsize=(20, 4))
for i in range(10):
    plt.subplot(1, 10, i+1)
    plt.imshow(test_images[i])
    plt.title(label_names[predicted[i].item()].decode('utf-8'))
    plt.axis('off')
plt.show()

# Save the output in output.csv containing ID, Labels
output_data = {'ID': np.arange(len(predicted)), 'Labels': predicted.numpy()}
output_df = pd.DataFrame(output_data)
output_df.to_csv('resnet_50_dropout_best_output.csv', index=False)
# Out:
# dict_keys(['net', 'acc', 'epoch'])
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[34], line 54
#      52 model.eval()
#      53 with torch.no_grad():
# ---> 54     outputs = model(augmented_test_images)
#      55 _, predicted = torch.max(outputs, 1)
#      57 predicted = predicted.to('cpu')
#
# File ~/.local/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# Cell In[15], line 84, in ResNet.forward(self, x)
#      82 def forward(self, x):
#      83   out = F.relu(self.bn1(self.conv1(x)))
# ---> 84   out = self.layer1(out)
#      85   out = self.layer2(out)
#      86   out = self.layer3(out)
#
# File ~/.local/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.local/lib/python3.11/site-packages/torch/nn/modules/container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File ~/.local/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# Cell In[15], line 56, in Bottleneck.forward(self, x)
#      54 out = F.relu(self.bn2(self.conv2(out)))
#      55 out = self.dropout(self.bn3(self.conv3(out))) # Adding Dropout in Forward Pass
# ---> 56 out += self.shortcut(x)
#      57 out = F.relu(out)
#      58 return out
#
# File ~/.local/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.local/lib/python3.11/site-packages/torch/nn/modules/container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File ~/.local/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.local/lib/python3.11/site-packages/torch/nn/modules/batchnorm.py:175, in _BatchNorm.forward(self, input)
#     168     bn_training = (self.running_mean is None) and (self.running_var is None)
#     170 r"""
#     171 Buffers are only updated if they are to be tracked and we are in training mode. Thus they only need to be
#     172 passed when the update should occur (i.e. in training mode when they are tracked), or when buffer stats are
#     173 used for normalization (i.e. in eval mode when buffers are not None).
#     174 """
# --> 175 return F.batch_norm(
#     176     input,
#     177     # If buffers are not to be tracked, ensure that they won't be updated
#     178     self.running_mean
#     179     if not self.training or self.track_running_stats
#     180     else None,
#     181     self.running_var if not self.training or self.track_running_stats else None,
#     182     self.weight,
#     183     self.bias,
#     184     bn_training,
#     185     exponential_average_factor,
#     186     self.eps,
#     187 )
#
# File ~/.local/lib/python3.11/site-packages/torch/nn/functional.py:2482, in batch_norm(input, running_mean, running_var, weight, bias, training, momentum, eps)
#    2479 if training:
#    2480     _verify_batch_size(input.size())
# -> 2482 return torch.batch_norm(
#    2483     input, weight, bias, running_mean, running_var, training, momentum, eps, torch.backends.cudnn.enabled
#    2484 )
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 9.77 GiB. GPU 0 has a total capacity of 31.74 GiB of which 8.47 GiB is free. Including non-PyTorch memory, this process has 23.27 GiB memory in use. Of the allocated memory 22.22 GiB is allocated by PyTorch, and 665.35 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

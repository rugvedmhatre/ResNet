# %% [markdown]
# # ResNet-34 (with Dropout) on CIFAR-10 Dataset

# %% [markdown]
# Importing PyTorch and a few Python Libraries

# %%
pip install torch-summary
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch-summary in /home/rrm9598/.local/lib/python3.11/site-packages (1.4.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import sys
import time
import math

import torch
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import random_split, DataLoader
from torchvision.utils import make_grid

import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
import torch.nn.init as init

from torchsummary import summary

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Preparing the dataset
#
# We will be downloading the train and test CIFAR-10 dataset from torchvision. We will normalize and transform the dataset. For the training dataset, we will also be adding Random Crops and Random Horizontal Flips to generalize the model better.

# %%
data_statistics = (
    (0.49139968, 0.48215827, 0.44653124),
     (0.24703233, 0.24348505, 0.26158768)
) # Mean, Standard Deviation of CIFAR-10 dataset channels

train_transforms = transforms.Compose([
    transforms.RandomCrop(32, padding=4, padding_mode='reflect'), # Adding Random Crops
    transforms.RandomHorizontalFlip(), # Adding Random Horizontal Flips
    transforms.ToTensor(), # Channel x Image Height x Image Width
    transforms.Normalize(*data_statistics, inplace=True) # Output in the range of [-1, 1]
])

test_transforms = transforms.Compose([
    transforms.ToTensor(), # Channel x Image Height x Image Width
    transforms.Normalize(*data_statistics, inplace=True) # Output in the range of [-1, 1]
])

# %%
train_dataset = torchvision.datasets.CIFAR10(root='./data/', download=True, train=True, transform=train_transforms)
test_dataset = torchvision.datasets.CIFAR10(root='./data/', download=True, train=False, transform=test_transforms)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# <!-- We will also be splitting the dataset further into training and validation dataset with a validation ratio of `0.2` -->
#
# We will now create data loaders to retreive images in batches. We are selecting the batch size as `128` images for our train loader. And we are selecting the batch size as `100` images for our test loader.
#
# *From PyTorch Documentation: For data loading, passing pin_memory=True to a DataLoader will automatically put the fetched data Tensors in pinned memory, and thus enables faster data transfer to CUDA-enabled GPUs.*

# %%
train_batch_size = 128
test_batch_size = 100

train_dl = DataLoader(train_dataset, train_batch_size, shuffle=True, num_workers=3, pin_memory=True)
test_dl = DataLoader(test_dataset, test_batch_size, shuffle=False, num_workers=3, pin_memory=True)

classes = ('plane', 'car', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck')

# %% [markdown]
# We create the following function to display a batch of images from the dataset. And we also need to denormalize the pixels values to bring them back into the range (0,1).

# %%
def denormalize(images, means, stds):
  means = torch.tensor(means).reshape(1, 3, 1, 1)
  stds = torch.tensor(stds).reshape(1, 3, 1, 1)
  return images * stds + means

def show_batch(dl):
  for images, labels in dl:
    fig, ax = plt.subplots(figsize=(12, 12))
    ax.set_xticks([])
    ax.set_yticks([])
    denorm_images = denormalize(images, *data_statistics)
    ax.imshow(make_grid(denorm_images[:64], 8).permute(1, 2, 0))
    break

# %%
show_batch(train_dl)

# %% [markdown]
# To seamlessly use a GPU, if one is available, we define a couple of helper functions (`get_default_device` & `to_device`) and a helper class `DeviceDataLoader` to move our model & data to the GPU as required.

# %%
def get_default_device():
  # Pick GPU, if available, else CPU
  if torch.cuda.is_available():
    return torch.device('cuda')
  else:
    return torch.device('cpu')

def to_device(data, device):
  # Move tensors to chosen device
  if isinstance(data, (list, tuple)):
    # If the instance is a list/tuple, transfer each element to chosen device
    return [to_device(x, device) for x in data]
  return data.to(device, non_blocking=True)
  # non_blocking=True doesn't block the execution of the host device until transfers complete

class DeviceDataLoader():
  # Wrap a dataloader to move data to a device
  def __init__(self, dl, device):
    self.dl = dl
    self.device = device

  def __iter__(self):
    # Yield a batch of data after moving it to device
    for b in self.dl:
      yield to_device(b, self.device)

  def __len__(self):
    # Number of batches
    return len(self.dl)

# %%
# Get the default device
device = get_default_device()
device
# Out:
# device(type='cuda')

# %%
train_dl = DeviceDataLoader(train_dl, device)
test_dl = DeviceDataLoader(test_dl, device)

# %% [markdown]
# ## Network Architecture

# %% [markdown]
# Testing the models mentioned in the `pytorch-cifar` [GitHub Repository](https://github.com/kuangliu/pytorch-cifar).

# %% [markdown]
# ### ResNet Architecture

# %%
class BasicBlock(nn.Module):
  expansion = 1

  def __init__(self, in_planes, planes, stride=1):
    super(BasicBlock, self).__init__()
    self.conv1 = nn.Conv2d(
        in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
    self.bn1 = nn.BatchNorm2d(planes)
    self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                            stride=1, padding=1, bias=False)
    self.bn2 = nn.BatchNorm2d(planes)
    self.dropout = nn.Dropout(0.2) # Adding Dropout Layer

    self.shortcut = nn.Sequential()
    if stride != 1 or in_planes != self.expansion*planes:
      self.shortcut = nn.Sequential(
          nn.Conv2d(in_planes, self.expansion*planes,
                    kernel_size=1, stride=stride, bias=False),
          nn.BatchNorm2d(self.expansion*planes)
      )

  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))
    out = self.dropout(self.bn2(self.conv2(out))) # Adding Dropout in Forward
    out += self.shortcut(x)
    out = F.relu(out)
    return out

class ResNet(nn.Module):
  def __init__(self, block, num_blocks, num_classes=10):
    super(ResNet, self).__init__()
    self.in_planes = 64

    self.conv1 = nn.Conv2d(3, 64, kernel_size=3,
                            stride=1, padding=1, bias=False)
    self.bn1 = nn.BatchNorm2d(64)
    self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
    self.layer2 = self._make_layer(block, 96, num_blocks[1], stride=2)
    self.layer3 = self._make_layer(block, 128, num_blocks[2], stride=2)
    self.layer4 = self._make_layer(block, 192, num_blocks[3], stride=2)
    self.linear = nn.Linear(192*block.expansion, num_classes)

  def _make_layer(self, block, planes, num_blocks, stride):
    strides = [stride] + [1]*(num_blocks-1)
    layers = []
    for stride in strides:
      layers.append(block(self.in_planes, planes, stride))
      self.in_planes = planes * block.expansion
    return nn.Sequential(*layers)

  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))
    out = self.layer1(out)
    out = self.layer2(out)
    out = self.layer3(out)
    out = self.layer4(out)
    out = F.avg_pool2d(out, 4)
    out = out.view(out.size(0), -1)
    out = self.linear(out)
    return out

def ResNet18():
  return ResNet(BasicBlock, [2, 2, 2, 2])

def ResNet9():
  return ResNet(BasicBlock, [1, 1, 1, 1])

def ResNet34():
    return ResNet(BasicBlock, [3, 4, 6, 3])

# %% [markdown]
# ### ResNet34

# %%
model = ResNet34()

# %%
model =  model.to(device)
if device == 'cuda':
  model = torch.nn.DataParallel(model)
  cudnn.benchmark = True

# %%
summary(model, input_size=(3, 32, 32))
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            1,728
# ├─BatchNorm2d: 1-2                       128
# ├─Sequential: 1-3                        --
# |    └─BasicBlock: 2-1                   --
# |    |    └─Conv2d: 3-1                  36,864
# |    |    └─BatchNorm2d: 3-2             128
# |    |    └─Conv2d: 3-3                  36,864
# |    |    └─BatchNorm2d: 3-4             128
# |    |    └─Dropout: 3-5                 --
# |    |    └─Sequential: 3-6              --
# |    └─BasicBlock: 2-2                   --
# |    |    └─Conv2d: 3-7                  36,864
# |    |    └─BatchNorm2d: 3-8             128
# |    |    └─Conv2d: 3-9                  36,864
# |    |    └─BatchNorm2d: 3-10            128
# |    |    └─Dropout: 3-11                --
# |    |    └─Sequential: 3-12             --
# |    └─BasicBlock: 2-3                   --
# |    |    └─Conv2d: 3-13                 36,864
# |    |    └─BatchNorm2d: 3-14            128
# |    |    └─Conv2d: 3-15                 36,864
# |    |    └─BatchNorm2d: 3-16            128
# |    |    └─Dropout: 3-17                --
# |    |    └─Sequential: 3-18             --
# ├─Sequential: 1-4                        --
# |    └─BasicBlock: 2-4                   --
# |    |    └─Conv2d: 3-19                 55,296
# |    |    └─BatchNorm2d: 3-20            192
# |    |    └─Conv2d: 3-21                 82,944
# |    |    └─BatchNorm2d: 3-22            192
# |    |    └─Dropout: 3-23                --
# |    |    └─Sequential: 3-24             6,336
# |    └─BasicBlock: 2-5                   --
# |    |    └─Conv2d: 3-25                 82,944
# |    |    └─BatchNorm2d: 3-26            192
# |    |    └─Conv2d: 3-27                 82,944
# |    |    └─BatchNorm2d: 3-28            192
# |    |    └─Dropout: 3-29                --
# |    |    └─Sequential: 3-30             --
# |    └─BasicBlock: 2-6                   --
# |    |    └─Conv2d: 3-31                 82,944
# |    |    └─BatchNorm2d: 3-32            192
# |    |    └─Conv2d: 3-33                 82,944
# |    |    └─BatchNorm2d: 3-34            192
# |    |    └─Dropout: 3-35                --
# |    |    └─Sequential: 3-36             --
# |    └─BasicBlock: 2-7                   --
# |    |    └─Conv2d: 3-37                 82,944
# |    |    └─BatchNorm2d: 3-38            192
# |    |    └─Conv2d: 3-39                 82,944
# |    |    └─BatchNorm2d: 3-40            192
# |    |    └─Dropout: 3-41                --
# |    |    └─Sequential: 3-42             --
# ├─Sequential: 1-5                        --
# |    └─BasicBlock: 2-8                   --
# |    |    └─Conv2d: 3-43                 110,592
# |    |    └─BatchNorm2d: 3-44            256
# |    |    └─Conv2d: 3-45                 147,456
# |    |    └─BatchNorm2d: 3-46            256
# |    |    └─Dropout: 3-47                --
# |    |    └─Sequential: 3-48             12,544
# |    └─BasicBlock: 2-9                   --
# |    |    └─Conv2d: 3-49                 147,456
# |    |    └─BatchNorm2d: 3-50            256
# |    |    └─Conv2d: 3-51                 147,456
# |    |    └─BatchNorm2d: 3-52            256
# |    |    └─Dropout: 3-53                --
# |    |    └─Sequential: 3-54             --
# |    └─BasicBlock: 2-10                  --
# |    |    └─Conv2d: 3-55                 147,456
# |    |    └─BatchNorm2d: 3-56            256
# |    |    └─Conv2d: 3-57                 147,456
# |    |    └─BatchNorm2d: 3-58            256
# |    |    └─Dropout: 3-59                --
# |    |    └─Sequential: 3-60             --
# |    └─BasicBlock: 2-11                  --
# |    |    └─Conv2d: 3-61                 147,456
# |    |    └─BatchNorm2d: 3-62            256
# |    |    └─Conv2d: 3-63                 147,456
# |    |    └─BatchNorm2d: 3-64            256
# |    |    └─Dropout: 3-65                --
# |    |    └─Sequential: 3-66             --
# |    └─BasicBlock: 2-12                  --
# |    |    └─Conv2d: 3-67                 147,456
# |    |    └─BatchNorm2d: 3-68            256
# |    |    └─Conv2d: 3-69                 147,456
# |    |    └─BatchNorm2d: 3-70            256
# |    |    └─Dropout: 3-71                --
# |    |    └─Sequential: 3-72             --
# |    └─BasicBlock: 2-13                  --
# |    |    └─Conv2d: 3-73                 147,456
# |    |    └─BatchNorm2d: 3-74            256
# |    |    └─Conv2d: 3-75                 147,456
# |    |    └─BatchNorm2d: 3-76            256
# |    |    └─Dropout: 3-77                --
# |    |    └─Sequential: 3-78             --
# ├─Sequential: 1-6                        --
# |    └─BasicBlock: 2-14                  --
# |    |    └─Conv2d: 3-79                 221,184
# |    |    └─BatchNorm2d: 3-80            384
# |    |    └─Conv2d: 3-81                 331,776
# |    |    └─BatchNorm2d: 3-82            384
# |    |    └─Dropout: 3-83                --
# |    |    └─Sequential: 3-84             24,960
# |    └─BasicBlock: 2-15                  --
# |    |    └─Conv2d: 3-85                 331,776
# |    |    └─BatchNorm2d: 3-86            384
# |    |    └─Conv2d: 3-87                 331,776
# |    |    └─BatchNorm2d: 3-88            384
# |    |    └─Dropout: 3-89                --
# |    |    └─Sequential: 3-90             --
# |    └─BasicBlock: 2-16                  --
# |    |    └─Conv2d: 3-91                 331,776
# |    |    └─BatchNorm2d: 3-92            384
# |    |    └─Conv2d: 3-93                 331,776
# |    |    └─BatchNorm2d: 3-94            384
# |    |    └─Dropout: 3-95                --
# |    |    └─Sequential: 3-96             --
# ├─Linear: 1-7                            1,930
# =================================================================
# Total params: 4,525,066
# Trainable params: 4,525,066
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            1,728
# ├─BatchNorm2d: 1-2                       128
# ├─Sequential: 1-3                        --
# |    └─BasicBlock: 2-1                   --
# |    |    └─Conv2d: 3-1                  36,864
# |    |    └─BatchNorm2d: 3-2             128
# |    |    └─Conv2d: 3-3                  36,864
# |    |    └─BatchNorm2d: 3-4             128
# |    |    └─Dropout: 3-5                 --
# |    |    └─Sequential: 3-6              --
# |    └─BasicBlock: 2-2                   --
# |    |    └─Conv2d: 3-7                  36,864
# |    |    └─BatchNorm2d: 3-8             128
# |    |    └─Conv2d: 3-9                  36,864
# |    |    └─BatchNorm2d: 3-10            128
# |    |    └─Dropout: 3-11                --
# |    |    └─Sequential: 3-12             --
# |    └─BasicBlock: 2-3                   --
# |    |    └─Conv2d: 3-13                 36,864
# |    |    └─BatchNorm2d: 3-14            128
# |    |    └─Conv2d: 3-15                 36,864
# |    |    └─BatchNorm2d: 3-16            128
# |    |    └─Dropout: 3-17                --
# |    |    └─Sequential: 3-18             --
# ├─Sequential: 1-4                        --
# |    └─BasicBlock: 2-4                   --
# |    |    └─Conv2d: 3-19                 55,296
# |    |    └─BatchNorm2d: 3-20            192
# |    |    └─Conv2d: 3-21                 82,944
# |    |    └─BatchNorm2d: 3-22            192
# |    |    └─Dropout: 3-23                --
# |    |    └─Sequential: 3-24             6,336
# |    └─BasicBlock: 2-5                   --
# |    |    └─Conv2d: 3-25                 82,944
# |    |    └─BatchNorm2d: 3-26            192
# |    |    └─Conv2d: 3-27                 82,944
# |    |    └─BatchNorm2d: 3-28            192
# |    |    └─Dropout: 3-29                --
# |    |    └─Sequential: 3-30             --
# |    └─BasicBlock: 2-6                   --
# |    |    └─Conv2d: 3-31                 82,944
# |    |    └─BatchNorm2d: 3-32            192
# |    |    └─Conv2d: 3-33                 82,944
# |    |    └─BatchNorm2d: 3-34            192
# |    |    └─Dropout: 3-35                --
# |    |    └─Sequential: 3-36             --
# |    └─BasicBlock: 2-7                   --
# |    |    └─Conv2d: 3-37                 82,944
# |    |    └─BatchNorm2d: 3-38            192
# |    |    └─Conv2d: 3-39                 82,944
# |    |    └─BatchNorm2d: 3-40            192
# |    |    └─Dropout: 3-41                --
# |    |    └─Sequential: 3-42             --
# ├─Sequential: 1-5                        --
# |    └─BasicBlock: 2-8                   --
# |    |    └─Conv2d: 3-43                 110,592
# |    |    └─BatchNorm2d: 3-44            256
# |    |    └─Conv2d: 3-45                 147,456
# |    |    └─BatchNorm2d: 3-46            256
# |    |    └─Dropout: 3-47                --
# |    |    └─Sequential: 3-48             12,544
# |    └─BasicBlock: 2-9                   --
# |    |    └─Conv2d: 3-49                 147,456
# |    |    └─BatchNorm2d: 3-50            256
# |    |    └─Conv2d: 3-51                 147,456
# |    |    └─BatchNorm2d: 3-52            256
# |    |    └─Dropout: 3-53                --
# |    |    └─Sequential: 3-54             --
# |    └─BasicBlock: 2-10                  --
# |    |    └─Conv2d: 3-55                 147,456
# |    |    └─BatchNorm2d: 3-56            256
# |    |    └─Conv2d: 3-57                 147,456
# |    |    └─BatchNorm2d: 3-58            256
# |    |    └─Dropout: 3-59                --
# |    |    └─Sequential: 3-60             --
# |    └─BasicBlock: 2-11                  --
# |    |    └─Conv2d: 3-61                 147,456
# |    |    └─BatchNorm2d: 3-62            256
# |    |    └─Conv2d: 3-63                 147,456
# |    |    └─BatchNorm2d: 3-64            256
# |    |    └─Dropout: 3-65                --
# |    |    └─Sequential: 3-66             --
# |    └─BasicBlock: 2-12                  --
# |    |    └─Conv2d: 3-67                 147,456
# |    |    └─BatchNorm2d: 3-68            256
# |    |    └─Conv2d: 3-69                 147,456
# |    |    └─BatchNorm2d: 3-70            256
# |    |    └─Dropout: 3-71                --
# |    |    └─Sequential: 3-72             --
# |    └─BasicBlock: 2-13                  --
# |    |    └─Conv2d: 3-73                 147,456
# |    |    └─BatchNorm2d: 3-74            256
# |    |    └─Conv2d: 3-75                 147,456
# |    |    └─BatchNorm2d: 3-76            256
# |    |    └─Dropout: 3-77                --
# |    |    └─Sequential: 3-78             --
# ├─Sequential: 1-6                        --
# |    └─BasicBlock: 2-14                  --
# |    |    └─Conv2d: 3-79                 221,184
# |    |    └─BatchNorm2d: 3-80            384
# |    |    └─Conv2d: 3-81                 331,776
# |    |    └─BatchNorm2d: 3-82            384
# |    |    └─Dropout: 3-83                --
# |    |    └─Sequential: 3-84             24,960
# |    └─BasicBlock: 2-15                  --
# |    |    └─Conv2d: 3-85                 331,776
# |    |    └─BatchNorm2d: 3-86            384
# |    |    └─Conv2d: 3-87                 331,776
# |    |    └─BatchNorm2d: 3-88            384
# |    |    └─Dropout: 3-89                --
# |    |    └─Sequential: 3-90             --
# |    └─BasicBlock: 2-16                  --
# |    |    └─Conv2d: 3-91                 331,776
# |    |    └─BatchNorm2d: 3-92            384
# |    |    └─Conv2d: 3-93                 331,776
# |    |    └─BatchNorm2d: 3-94            384
# |    |    └─Dropout: 3-95                --
# |    |    └─Sequential: 3-96             --
# ├─Linear: 1-7                            1,930
# =================================================================
# Total params: 4,525,066
# Trainable params: 4,525,066
# Non-trainable params: 0
# =================================================================

# %% [markdown]
# ## Model Training

# %%
# Helper Function to Format Time
def format_time(seconds):
  days = int(seconds / 3600/24)
  seconds = seconds - days*3600*24
  hours = int(seconds / 3600)
  seconds = seconds - hours*3600
  minutes = int(seconds / 60)
  seconds = seconds - minutes*60
  secondsf = int(seconds)
  seconds = seconds - secondsf
  millis = int(seconds*1000)

  f = ''
  i = 1
  if days > 0:
    f += str(days) + 'D'
    i += 1
  if hours > 0 and i <= 2:
    f += str(hours) + 'h'
    i += 1
  if minutes > 0 and i <= 2:
    f += str(minutes) + 'm'
    i += 1
  if secondsf > 0 and i <= 2:
    f += str(secondsf) + 's'
    i += 1
  if millis > 0 and i <= 2:
    f += str(millis) + 'ms'
    i += 1
  if f == '':
    f = '0ms'
  return f

# %% [markdown]
# Loss: CrossEntropyLoss
#
# Optimizer: SGD
#
# Learning Rate: 0.1
#
# Momentum: 0.9
#
# Weight Decay: 5e-4
#
# Number of Epochs: 100
#
# Scheduler: CosineAnnealingLR

# %%
lr = 0.1
momentum = 0.9
weight_decay = 5e-4

start_epoch = 1
number_of_epochs = 100
best_acc = 0


criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=lr,
                      momentum=momentum, weight_decay=weight_decay)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=number_of_epochs)

# %%
# Helper Function to get Learning Rate
def get_lr(optimizer):
  for param_group in optimizer.param_groups:
    return param_group['lr']

# %%
def train(epoch):
  print('\nEpoch: %d' % epoch)
  start_time = time.time()

  model.train()
  train_loss = 0
  correct = 0
  total = 0
  for batch_idx, (inputs, targets) in enumerate(train_dl):
    # inputs, targets = inputs.to(device), targets.to(device)
    optimizer.zero_grad()
    outputs = model(inputs)
    loss = criterion(outputs, targets)
    loss.backward()
    optimizer.step()

    train_loss += loss.item()
    _, predicted = outputs.max(1)
    total += targets.size(0)
    correct += predicted.eq(targets).sum().item()

  cur_time = time.time()
  epoch_time = cur_time - start_time
  print(f"Training Time : {format_time(epoch_time)}")

  return train_loss/(batch_idx+1), 100.*correct/total, get_lr(optimizer)

# %%
def test(epoch):
  global best_acc
  model.eval()
  test_loss = 0
  correct = 0
  total = 0
  with torch.no_grad():
    for batch_idx, (inputs, targets) in enumerate(test_dl):
      outputs = model(inputs)
      loss = criterion(outputs, targets)

      test_loss += loss.item()
      _, predicted = outputs.max(1)
      total += targets.size(0)
      correct += predicted.eq(targets).sum().item()
      
  # Save checkpoint.
  acc = 100.*correct/total
  if acc > best_acc:
    print('Saving..')
    state = {
        'net': model.state_dict(),
        'acc': acc,
        'epoch': epoch,
    }
    if not os.path.isdir('checkpoint'):
      os.mkdir('checkpoint')
    torch.save(state, './checkpoint/resnet_34_dropout_best.pth')
    best_acc = acc

  return test_loss/(batch_idx+1), 100.*correct/total

# %%
train_losses = []
train_accuracies = []
train_lrs = []

test_losses = []
test_accuracies = []

for epoch in range(start_epoch, start_epoch + number_of_epochs):
  epoch_train_loss, epoch_train_accuracy, epoch_lr = train(epoch)
  train_losses.append(epoch_train_loss)
  train_accuracies.append(epoch_train_accuracy)
  train_lrs.append(epoch_lr)

  epoch_test_loss, epoch_test_accuracy = test(epoch)
  test_losses.append(epoch_test_loss)
  test_accuracies.append(epoch_test_accuracy)

  scheduler.step()
  print(f"Train Loss: {epoch_train_loss:.3f} | Train Accuracy: {epoch_train_accuracy:.3f}% | Test Loss: {epoch_test_loss:.3f} | Test Accuracy: {epoch_test_accuracy:.3f}%")
# Out:
# Epoch: 1
# Training Time : 22s375ms
# Saving..
# Train Loss: 1.888 | Train Accuracy: 30.136% | Test Loss: 1.537 | Test Accuracy: 42.760%
#
# Epoch: 2
# Training Time : 21s221ms
# Saving..
# Train Loss: 1.449 | Train Accuracy: 46.636% | Test Loss: 1.366 | Test Accuracy: 49.630%
#
# Epoch: 3
# Training Time : 21s201ms
# Saving..
# Train Loss: 1.169 | Train Accuracy: 57.944% | Test Loss: 1.030 | Test Accuracy: 63.200%
#
# Epoch: 4
# Training Time : 21s205ms
# Saving..
# Train Loss: 0.984 | Train Accuracy: 65.036% | Test Loss: 1.007 | Test Accuracy: 65.240%
#
# Epoch: 5
# Training Time : 21s234ms
# Train Loss: 0.860 | Train Accuracy: 69.788% | Test Loss: 1.102 | Test Accuracy: 63.890%
#
# Epoch: 6
# Training Time : 21s195ms
# Saving..
# Train Loss: 0.755 | Train Accuracy: 73.646% | Test Loss: 0.769 | Test Accuracy: 73.620%
#
# Epoch: 7
# Training Time : 21s158ms
# Train Loss: 0.683 | Train Accuracy: 76.274% | Test Loss: 0.872 | Test Accuracy: 71.020%
#
# Epoch: 8
# Training Time : 21s147ms
# Saving..
# Train Loss: 0.645 | Train Accuracy: 77.760% | Test Loss: 0.661 | Test Accuracy: 77.680%
#
# Epoch: 9
# Training Time : 21s111ms
# Saving..
# Train Loss: 0.606 | Train Accuracy: 79.278% | Test Loss: 0.643 | Test Accuracy: 77.930%
#
# Epoch: 10
# Training Time : 21s163ms
# Train Loss: 0.582 | Train Accuracy: 79.864% | Test Loss: 0.711 | Test Accuracy: 76.000%
#
# Epoch: 11
# Training Time : 21s204ms
# Saving..
# Train Loss: 0.564 | Train Accuracy: 80.580% | Test Loss: 0.624 | Test Accuracy: 78.630%
#
# Epoch: 12
# Training Time : 21s219ms
# Saving..
# Train Loss: 0.535 | Train Accuracy: 81.628% | Test Loss: 0.596 | Test Accuracy: 80.140%
#
# Epoch: 13
# Training Time : 21s197ms
# Saving..
# Train Loss: 0.525 | Train Accuracy: 81.922% | Test Loss: 0.592 | Test Accuracy: 80.580%
#
# Epoch: 14
# Training Time : 21s159ms
# Train Loss: 0.514 | Train Accuracy: 82.356% | Test Loss: 0.648 | Test Accuracy: 77.850%
#
# Epoch: 15
# Training Time : 21s137ms
# Train Loss: 0.496 | Train Accuracy: 82.994% | Test Loss: 0.640 | Test Accuracy: 78.790%
#
# Epoch: 16
# Training Time : 21s110ms
# Saving..
# Train Loss: 0.483 | Train Accuracy: 83.550% | Test Loss: 0.585 | Test Accuracy: 81.130%
#
# Epoch: 17
# Training Time : 21s161ms
# Train Loss: 0.480 | Train Accuracy: 83.554% | Test Loss: 0.565 | Test Accuracy: 81.040%
#
# Epoch: 18
# Training Time : 21s87ms
# Train Loss: 0.465 | Train Accuracy: 84.000% | Test Loss: 0.729 | Test Accuracy: 76.960%
#
# Epoch: 19
# Training Time : 21s119ms
# Train Loss: 0.460 | Train Accuracy: 84.414% | Test Loss: 0.626 | Test Accuracy: 78.830%
#
# Epoch: 20
# Training Time : 21s171ms
# Saving..
# Train Loss: 0.444 | Train Accuracy: 84.818% | Test Loss: 0.465 | Test Accuracy: 84.180%
#
# Epoch: 21
# Training Time : 21s158ms
# Train Loss: 0.441 | Train Accuracy: 84.982% | Test Loss: 0.712 | Test Accuracy: 77.430%
#
# Epoch: 22
# Training Time : 21s111ms
# Train Loss: 0.437 | Train Accuracy: 84.994% | Test Loss: 0.505 | Test Accuracy: 82.970%
#
# Epoch: 23
# Training Time : 21s154ms
# Train Loss: 0.423 | Train Accuracy: 85.522% | Test Loss: 0.602 | Test Accuracy: 79.650%
#
# Epoch: 24
# Training Time : 21s89ms
# Train Loss: 0.420 | Train Accuracy: 85.844% | Test Loss: 0.501 | Test Accuracy: 83.350%
#
# Epoch: 25
# Training Time : 21s96ms
# Train Loss: 0.407 | Train Accuracy: 86.004% | Test Loss: 0.681 | Test Accuracy: 79.100%
#
# Epoch: 26
# Training Time : 21s159ms
# Train Loss: 0.398 | Train Accuracy: 86.368% | Test Loss: 0.477 | Test Accuracy: 83.440%
#
# Epoch: 27
# Training Time : 21s125ms
# Train Loss: 0.400 | Train Accuracy: 86.504% | Test Loss: 0.515 | Test Accuracy: 83.140%
#
# Epoch: 28
# Training Time : 21s135ms
# Train Loss: 0.394 | Train Accuracy: 86.564% | Test Loss: 0.507 | Test Accuracy: 83.010%
#
# Epoch: 29
# Training Time : 21s104ms
# Train Loss: 0.389 | Train Accuracy: 86.842% | Test Loss: 0.559 | Test Accuracy: 81.180%
#
# Epoch: 30
# Training Time : 21s168ms
# Train Loss: 0.385 | Train Accuracy: 86.988% | Test Loss: 0.532 | Test Accuracy: 82.030%
#
# Epoch: 31
# Training Time : 21s176ms
# Saving..
# Train Loss: 0.379 | Train Accuracy: 87.006% | Test Loss: 0.423 | Test Accuracy: 85.900%
#
# Epoch: 32
# Training Time : 21s178ms
# Saving..
# Train Loss: 0.370 | Train Accuracy: 87.372% | Test Loss: 0.391 | Test Accuracy: 86.760%
#
# Epoch: 33
# Training Time : 21s151ms
# Saving..
# Train Loss: 0.363 | Train Accuracy: 87.558% | Test Loss: 0.396 | Test Accuracy: 86.840%
#
# Epoch: 34
# Training Time : 21s94ms
# Train Loss: 0.360 | Train Accuracy: 87.818% | Test Loss: 0.465 | Test Accuracy: 85.060%
#
# Epoch: 35
# Training Time : 21s79ms
# Train Loss: 0.355 | Train Accuracy: 87.980% | Test Loss: 0.441 | Test Accuracy: 85.660%
#
# Epoch: 36
# Training Time : 21s163ms
# Train Loss: 0.351 | Train Accuracy: 87.962% | Test Loss: 0.471 | Test Accuracy: 84.760%
#
# Epoch: 37
# Training Time : 21s182ms
# Train Loss: 0.343 | Train Accuracy: 88.254% | Test Loss: 0.403 | Test Accuracy: 86.560%
#
# Epoch: 38
# Training Time : 21s120ms
# Saving..
# Train Loss: 0.339 | Train Accuracy: 88.394% | Test Loss: 0.383 | Test Accuracy: 86.930%
#
# Epoch: 39
# Training Time : 21s143ms
# Saving..
# Train Loss: 0.339 | Train Accuracy: 88.502% | Test Loss: 0.367 | Test Accuracy: 87.690%
#
# Epoch: 40
# Training Time : 21s152ms
# Train Loss: 0.326 | Train Accuracy: 88.860% | Test Loss: 0.457 | Test Accuracy: 85.150%
#
# Epoch: 41
# Training Time : 21s112ms
# Train Loss: 0.327 | Train Accuracy: 88.866% | Test Loss: 0.482 | Test Accuracy: 84.130%
#
# Epoch: 42
# Training Time : 21s190ms
# Train Loss: 0.317 | Train Accuracy: 89.046% | Test Loss: 0.418 | Test Accuracy: 86.370%
#
# Epoch: 43
# Training Time : 21s144ms
# Train Loss: 0.308 | Train Accuracy: 89.504% | Test Loss: 0.422 | Test Accuracy: 86.440%
#
# Epoch: 44
# Training Time : 21s177ms
# Train Loss: 0.308 | Train Accuracy: 89.376% | Test Loss: 0.420 | Test Accuracy: 85.740%
#
# Epoch: 45
# Training Time : 21s163ms
# Train Loss: 0.304 | Train Accuracy: 89.586% | Test Loss: 0.393 | Test Accuracy: 87.070%
#
# Epoch: 46
# Training Time : 21s165ms
# Train Loss: 0.297 | Train Accuracy: 89.824% | Test Loss: 0.428 | Test Accuracy: 86.290%
#
# Epoch: 47
# Training Time : 21s109ms
# Saving..
# Train Loss: 0.291 | Train Accuracy: 90.104% | Test Loss: 0.378 | Test Accuracy: 87.770%
#
# Epoch: 48
# Training Time : 21s112ms
# Train Loss: 0.281 | Train Accuracy: 90.398% | Test Loss: 0.429 | Test Accuracy: 86.460%
#
# Epoch: 49
# Training Time : 21s156ms
# Train Loss: 0.281 | Train Accuracy: 90.424% | Test Loss: 0.584 | Test Accuracy: 82.890%
#
# Epoch: 50
# Training Time : 21s91ms
# Train Loss: 0.279 | Train Accuracy: 90.498% | Test Loss: 0.380 | Test Accuracy: 87.430%
#
# Epoch: 51
# Training Time : 21s184ms
# Train Loss: 0.266 | Train Accuracy: 90.834% | Test Loss: 0.373 | Test Accuracy: 87.670%
#
# Epoch: 52
# Training Time : 21s222ms
# Saving..
# Train Loss: 0.264 | Train Accuracy: 90.928% | Test Loss: 0.335 | Test Accuracy: 88.960%
#
# Epoch: 53
# Training Time : 21s209ms
# Train Loss: 0.262 | Train Accuracy: 91.044% | Test Loss: 0.433 | Test Accuracy: 86.030%
#
# Epoch: 54
# Training Time : 21s172ms
# Train Loss: 0.253 | Train Accuracy: 91.402% | Test Loss: 0.390 | Test Accuracy: 87.120%
#
# Epoch: 55
# Training Time : 21s137ms
# Train Loss: 0.246 | Train Accuracy: 91.628% | Test Loss: 0.407 | Test Accuracy: 86.980%
#
# Epoch: 56
# Training Time : 21s139ms
# Train Loss: 0.239 | Train Accuracy: 91.828% | Test Loss: 0.348 | Test Accuracy: 88.680%
#
# Epoch: 57
# Training Time : 21s120ms
# Saving..
# Train Loss: 0.237 | Train Accuracy: 91.848% | Test Loss: 0.302 | Test Accuracy: 90.050%
#
# Epoch: 58
# Training Time : 21s130ms
# Train Loss: 0.227 | Train Accuracy: 92.240% | Test Loss: 0.381 | Test Accuracy: 87.840%
#
# Epoch: 59
# Training Time : 21s133ms
# Train Loss: 0.222 | Train Accuracy: 92.372% | Test Loss: 0.365 | Test Accuracy: 88.190%
#
# Epoch: 60
# Training Time : 21s103ms
# Saving..
# Train Loss: 0.216 | Train Accuracy: 92.476% | Test Loss: 0.296 | Test Accuracy: 90.320%
#
# Epoch: 61
# Training Time : 21s215ms
# Train Loss: 0.210 | Train Accuracy: 92.786% | Test Loss: 0.318 | Test Accuracy: 89.710%
#
# Epoch: 62
# Training Time : 21s130ms
# Train Loss: 0.201 | Train Accuracy: 93.172% | Test Loss: 0.312 | Test Accuracy: 89.660%
#
# Epoch: 63
# Training Time : 21s147ms
# Saving..
# Train Loss: 0.199 | Train Accuracy: 93.148% | Test Loss: 0.276 | Test Accuracy: 90.850%
#
# Epoch: 64
# Training Time : 21s151ms
# Train Loss: 0.183 | Train Accuracy: 93.712% | Test Loss: 0.297 | Test Accuracy: 90.750%
#
# Epoch: 65
# Training Time : 21s156ms
# Train Loss: 0.185 | Train Accuracy: 93.674% | Test Loss: 0.324 | Test Accuracy: 89.750%
#
# Epoch: 66
# Training Time : 21s173ms
# Train Loss: 0.171 | Train Accuracy: 94.102% | Test Loss: 0.323 | Test Accuracy: 89.990%
#
# Epoch: 67
# Training Time : 21s198ms
# Train Loss: 0.167 | Train Accuracy: 94.264% | Test Loss: 0.325 | Test Accuracy: 89.670%
#
# Epoch: 68
# Training Time : 21s177ms
# Saving..
# Train Loss: 0.160 | Train Accuracy: 94.534% | Test Loss: 0.262 | Test Accuracy: 91.580%
#
# Epoch: 69
# Training Time : 21s186ms
# Train Loss: 0.150 | Train Accuracy: 94.882% | Test Loss: 0.284 | Test Accuracy: 90.930%
#
# Epoch: 70
# Training Time : 21s67ms
# Train Loss: 0.143 | Train Accuracy: 95.208% | Test Loss: 0.288 | Test Accuracy: 90.890%
#
# Epoch: 71
# Training Time : 21s71ms
# Saving..
# Train Loss: 0.136 | Train Accuracy: 95.262% | Test Loss: 0.253 | Test Accuracy: 91.840%
#
# Epoch: 72
# Training Time : 21s145ms
# Saving..
# Train Loss: 0.130 | Train Accuracy: 95.528% | Test Loss: 0.255 | Test Accuracy: 91.990%
#
# Epoch: 73
# Training Time : 21s226ms
# Train Loss: 0.125 | Train Accuracy: 95.664% | Test Loss: 0.258 | Test Accuracy: 91.890%
#
# Epoch: 74
# Training Time : 21s180ms
# Saving..
# Train Loss: 0.116 | Train Accuracy: 95.972% | Test Loss: 0.244 | Test Accuracy: 92.360%
#
# Epoch: 75
# Training Time : 21s202ms
# Saving..
# Train Loss: 0.112 | Train Accuracy: 96.130% | Test Loss: 0.222 | Test Accuracy: 92.920%
#
# Epoch: 76
# Training Time : 21s207ms
# Train Loss: 0.098 | Train Accuracy: 96.678% | Test Loss: 0.232 | Test Accuracy: 92.910%
#
# Epoch: 77
# Training Time : 21s169ms
# Train Loss: 0.093 | Train Accuracy: 96.850% | Test Loss: 0.235 | Test Accuracy: 92.920%
#
# Epoch: 78
# Training Time : 21s160ms
# Train Loss: 0.083 | Train Accuracy: 97.138% | Test Loss: 0.239 | Test Accuracy: 92.600%
#
# Epoch: 79
# Training Time : 21s162ms
# Saving..
# Train Loss: 0.074 | Train Accuracy: 97.450% | Test Loss: 0.221 | Test Accuracy: 93.570%
#
# Epoch: 80
# Training Time : 21s132ms
# Train Loss: 0.068 | Train Accuracy: 97.644% | Test Loss: 0.235 | Test Accuracy: 93.140%
#
# Epoch: 81
# Training Time : 21s252ms
# Train Loss: 0.059 | Train Accuracy: 98.044% | Test Loss: 0.238 | Test Accuracy: 93.450%
#
# Epoch: 82
# Training Time : 21s155ms
# Saving..
# Train Loss: 0.052 | Train Accuracy: 98.168% | Test Loss: 0.219 | Test Accuracy: 93.750%
#
# Epoch: 83
# Training Time : 21s205ms
# Train Loss: 0.048 | Train Accuracy: 98.388% | Test Loss: 0.238 | Test Accuracy: 93.410%
#
# Epoch: 84
# Training Time : 21s146ms
# Saving..
# Train Loss: 0.042 | Train Accuracy: 98.618% | Test Loss: 0.208 | Test Accuracy: 94.200%
#
# Epoch: 85
# Training Time : 21s154ms
# Saving..
# Train Loss: 0.036 | Train Accuracy: 98.852% | Test Loss: 0.207 | Test Accuracy: 94.560%
#
# Epoch: 86
# Training Time : 21s200ms
# Train Loss: 0.031 | Train Accuracy: 99.006% | Test Loss: 0.207 | Test Accuracy: 94.320%
#
# Epoch: 87
# Training Time : 21s105ms
# Saving..
# Train Loss: 0.025 | Train Accuracy: 99.198% | Test Loss: 0.196 | Test Accuracy: 94.710%
#
# Epoch: 88
# Training Time : 21s157ms
# Saving..
# Train Loss: 0.023 | Train Accuracy: 99.314% | Test Loss: 0.198 | Test Accuracy: 94.990%
#
# Epoch: 89
# Training Time : 21s184ms
# Train Loss: 0.018 | Train Accuracy: 99.418% | Test Loss: 0.194 | Test Accuracy: 94.920%
#
# Epoch: 90
# Training Time : 21s156ms
# Train Loss: 0.016 | Train Accuracy: 99.540% | Test Loss: 0.199 | Test Accuracy: 94.930%
#
# Epoch: 91
# Training Time : 21s118ms
# Saving..
# Train Loss: 0.014 | Train Accuracy: 99.580% | Test Loss: 0.196 | Test Accuracy: 95.250%
#
# Epoch: 92
# Training Time : 21s199ms
# Saving..
# Train Loss: 0.013 | Train Accuracy: 99.622% | Test Loss: 0.190 | Test Accuracy: 95.300%
#
# Epoch: 93
# Training Time : 21s217ms
# Train Loss: 0.012 | Train Accuracy: 99.692% | Test Loss: 0.192 | Test Accuracy: 95.280%
#
# Epoch: 94
# Training Time : 21s137ms
# Train Loss: 0.010 | Train Accuracy: 99.712% | Test Loss: 0.190 | Test Accuracy: 95.280%
#
# Epoch: 95
# Training Time : 21s129ms
# Train Loss: 0.009 | Train Accuracy: 99.768% | Test Loss: 0.190 | Test Accuracy: 95.270%
#
# Epoch: 96
# Training Time : 21s112ms
# Train Loss: 0.009 | Train Accuracy: 99.770% | Test Loss: 0.190 | Test Accuracy: 95.230%
#
# Epoch: 97
# Training Time : 21s165ms
# Saving..
# Train Loss: 0.008 | Train Accuracy: 99.760% | Test Loss: 0.188 | Test Accuracy: 95.360%
#
# Epoch: 98
# Training Time : 21s146ms
# Train Loss: 0.007 | Train Accuracy: 99.834% | Test Loss: 0.190 | Test Accuracy: 95.350%
#
# Epoch: 99
# Training Time : 21s223ms
# Saving..
# Train Loss: 0.008 | Train Accuracy: 99.812% | Test Loss: 0.190 | Test Accuracy: 95.370%
#
# Epoch: 100
# Training Time : 21s168ms
# Train Loss: 0.008 | Train Accuracy: 99.806% | Test Loss: 0.188 | Test Accuracy: 95.370%

# %%
print(f"Best Accuracy: {best_acc:.3f}%")
# Out:
# Best Accuracy: 95.370%

# %%
def plot_accuracies(train_accuracies, test_accuracies):
  plt.plot(train_accuracies, label='Train Accuracy')
  plt.plot(test_accuracies, label='Test Accuracy')
  plt.xlabel('Epochs')
  plt.ylabel('Accuracy')
  plt.legend()
  plt.grid(True)
  plt.title('Accuracy vs. No. of epochs')

# %%
def plot_losses(train_losses, test_losses):
  plt.plot(train_losses, label='Train Losses')
  plt.plot(test_losses, label='Test Losses')
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.legend()
  plt.grid(True)
  plt.title('Loss vs. No. of epochs')

# %%
def plot_lrs(train_lrs):
  plt.plot(train_lrs)
  plt.xlabel('Epochs')
  plt.ylabel('Learning rate')
  plt.grid(True)
  plt.title('Learning Rate vs. Epochs')

# %%
plot_accuracies(train_accuracies, test_accuracies)

# %%
plot_losses(train_losses, test_losses)

# %%
plot_lrs(train_lrs)

# %%
print('Saving final model..')
state = {
    'net': model.state_dict(),
    'acc': test_accuracies[-1],
    'epoch': number_of_epochs,
    'best_acc' : best_acc,
    'train_acc' : train_accuracies,
    'test_acc' : test_accuracies,
    'train_loss' : train_losses,
    'test_loss' : test_losses,
    'lr' : train_lrs
}
if not os.path.isdir('checkpoint'):
  os.mkdir('checkpoint')
torch.save(state, './checkpoint/resnet_34_dropout_final.pth')
# Out:
# Saving final model..

# %%
import numpy as np
import pickle
import pandas as pd

# Function to load CIFAR batch
def load_cifar_batch(file):
    with open(file, 'rb') as fo:
        batch = pickle.load(fo, encoding='bytes')
    return batch

# Specify the folder where the CIFAR-10 batch files are
cifar10_dir = './data/cifar-10-batches-py'

# Load the label names
meta_data_dict = load_cifar_batch(os.path.join(cifar10_dir, 'batches.meta'))
label_names = meta_data_dict[b'label_names']

# Load test data
test_batch = load_cifar_batch('./cifar_test_nolabels.pkl')
test_images = test_batch[b'data'].reshape(-1, 3, 32, 32).transpose(0, 2, 3, 1)

data_statistics = (
    (0.49139968, 0.48215827, 0.44653124),
     (0.24703233, 0.24348505, 0.26158768)
)

# Define transformation for data augmentation
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(*data_statistics, inplace=True)
])

# Apply data augmentation
augmented_test_images = torch.stack([transform(image) for image in test_images])

# Load the trained model
model = ResNet34()

checkpoint = torch.load('./checkpoint/resnet_34_dropout_best.pth')

# Check the keys in the checkpoint dictionary
print(checkpoint.keys())

# Assuming the model state dictionary is saved under a different key
# Adjust this according to the actual key in your checkpoint file
model.load_state_dict(checkpoint['net'])

model =  model.to(device)
augmented_test_images = augmented_test_images.to(device)

# Evaluate the model on test data
model.eval()
with torch.no_grad():
    outputs = model(augmented_test_images)
_, predicted = torch.max(outputs, 1)

predicted = predicted.to('cpu')

# Display the first 10 test images and predicted labels
plt.figure(figsize=(20, 4))
for i in range(10):
    plt.subplot(1, 10, i+1)
    plt.imshow(test_images[i])
    plt.title(label_names[predicted[i].item()].decode('utf-8'))
    plt.axis('off')
plt.show()

# Save the output in output.csv containing ID, Labels
output_data = {'ID': np.arange(len(predicted)), 'Labels': predicted.numpy()}
output_df = pd.DataFrame(output_data)
output_df.to_csv('resnet_34_dropout_best_output.csv', index=False)
# Out:
# dict_keys(['net', 'acc', 'epoch'])

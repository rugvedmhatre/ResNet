# %% [markdown]
# # ResNet-9 on CIFAR-10 Dataset

# %% [markdown]
# Importing PyTorch and a few Python Libraries

# %%
pip install torch-summary
# Out:
# Collecting torch-summary
#   Downloading torch_summary-1.4.5-py3-none-any.whl.metadata (18 kB)
# Downloading torch_summary-1.4.5-py3-none-any.whl (16 kB)
# Installing collected packages: torch-summary
# Successfully installed torch-summary-1.4.5
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import sys
import time
import math

import torch
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import random_split, DataLoader
from torchvision.utils import make_grid

import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
import torch.nn.init as init

from torchsummary import summary

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Preparing the dataset
#
# We will be downloading the train and test CIFAR-10 dataset from torchvision. We will normalize and transform the dataset. For the training dataset, we will also be adding Random Crops and Random Horizontal Flips to generalize the model better.

# %%
data_statistics = (
    (0.49139968, 0.48215827, 0.44653124),
     (0.24703233, 0.24348505, 0.26158768)
) # Mean, Standard Deviation of CIFAR-10 dataset channels

train_transforms = transforms.Compose([
    transforms.RandomCrop(32, padding=4, padding_mode='reflect'), # Adding Random Crops
    transforms.RandomHorizontalFlip(), # Adding Random Horizontal Flips
    transforms.ToTensor(), # Channel x Image Height x Image Width
    transforms.Normalize(*data_statistics, inplace=True) # Output in the range of [-1, 1]
])

test_transforms = transforms.Compose([
    transforms.ToTensor(), # Channel x Image Height x Image Width
    transforms.Normalize(*data_statistics, inplace=True) # Output in the range of [-1, 1]
])

# %%
train_dataset = torchvision.datasets.CIFAR10(root='./data/', download=True, train=True, transform=train_transforms)
test_dataset = torchvision.datasets.CIFAR10(root='./data/', download=True, train=False, transform=test_transforms)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:04<00:00, 34986876.81it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data/
# Files already downloaded and verified

# %% [markdown]
# <!-- We will also be splitting the dataset further into training and validation dataset with a validation ratio of `0.2` -->
#
# We will now create data loaders to retreive images in batches. We are selecting the batch size as `128` images for our train loader. And we are selecting the batch size as `100` images for our test loader.
#
# *From PyTorch Documentation: For data loading, passing pin_memory=True to a DataLoader will automatically put the fetched data Tensors in pinned memory, and thus enables faster data transfer to CUDA-enabled GPUs.*

# %%
train_batch_size = 128
test_batch_size = 100

train_dl = DataLoader(train_dataset, train_batch_size, shuffle=True, num_workers=3, pin_memory=True)
test_dl = DataLoader(test_dataset, test_batch_size, shuffle=False, num_workers=3, pin_memory=True)

classes = ('plane', 'car', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck')

# %% [markdown]
# We create the following function to display a batch of images from the dataset. And we also need to denormalize the pixels values to bring them back into the range (0,1).

# %%
def denormalize(images, means, stds):
  means = torch.tensor(means).reshape(1, 3, 1, 1)
  stds = torch.tensor(stds).reshape(1, 3, 1, 1)
  return images * stds + means

def show_batch(dl):
  for images, labels in dl:
    fig, ax = plt.subplots(figsize=(12, 12))
    ax.set_xticks([])
    ax.set_yticks([])
    denorm_images = denormalize(images, *data_statistics)
    ax.imshow(make_grid(denorm_images[:64], 8).permute(1, 2, 0))
    break

# %%
show_batch(train_dl)

# %% [markdown]
# To seamlessly use a GPU, if one is available, we define a couple of helper functions (`get_default_device` & `to_device`) and a helper class `DeviceDataLoader` to move our model & data to the GPU as required.

# %%
def get_default_device():
  # Pick GPU, if available, else CPU
  if torch.cuda.is_available():
    return torch.device('cuda')
  else:
    return torch.device('cpu')

def to_device(data, device):
  # Move tensors to chosen device
  if isinstance(data, (list, tuple)):
    # If the instance is a list/tuple, transfer each element to chosen device
    return [to_device(x, device) for x in data]
  return data.to(device, non_blocking=True)
  # non_blocking=True doesn't block the execution of the host device until transfers complete

class DeviceDataLoader():
  # Wrap a dataloader to move data to a device
  def __init__(self, dl, device):
    self.dl = dl
    self.device = device

  def __iter__(self):
    # Yield a batch of data after moving it to device
    for b in self.dl:
      yield to_device(b, self.device)

  def __len__(self):
    # Number of batches
    return len(self.dl)

# %%
# Get the default device
device = get_default_device()
device
# Out:
# device(type='cuda')

# %%
train_dl = DeviceDataLoader(train_dl, device)
test_dl = DeviceDataLoader(test_dl, device)

# %% [markdown]
# ## Network Architecture

# %% [markdown]
# Testing the models mentioned in the `pytorch-cifar` [GitHub Repository](https://github.com/kuangliu/pytorch-cifar).

# %% [markdown]
# ### ResNet Architecture

# %%
class BasicBlock(nn.Module):
  expansion = 1

  def __init__(self, in_planes, planes, stride=1):
    super(BasicBlock, self).__init__()
    self.conv1 = nn.Conv2d(
        in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
    self.bn1 = nn.BatchNorm2d(planes)
    self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                            stride=1, padding=1, bias=False)
    self.bn2 = nn.BatchNorm2d(planes)

    self.shortcut = nn.Sequential()
    if stride != 1 or in_planes != self.expansion*planes:
      self.shortcut = nn.Sequential(
          nn.Conv2d(in_planes, self.expansion*planes,
                    kernel_size=1, stride=stride, bias=False),
          nn.BatchNorm2d(self.expansion*planes)
      )

  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))
    out = self.bn2(self.conv2(out))
    out += self.shortcut(x)
    out = F.relu(out)
    return out

class ResNet(nn.Module):
  def __init__(self, block, num_blocks, num_classes=10):
    super(ResNet, self).__init__()
    self.in_planes = 64

    self.conv1 = nn.Conv2d(3, 64, kernel_size=3,
                            stride=1, padding=1, bias=False)
    self.bn1 = nn.BatchNorm2d(64)
    self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
    self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
    self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
    self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
    self.linear = nn.Linear(512*block.expansion, num_classes)

  def _make_layer(self, block, planes, num_blocks, stride):
    strides = [stride] + [1]*(num_blocks-1)
    layers = []
    for stride in strides:
      layers.append(block(self.in_planes, planes, stride))
      self.in_planes = planes * block.expansion
    return nn.Sequential(*layers)

  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))
    out = self.layer1(out)
    out = self.layer2(out)
    out = self.layer3(out)
    out = self.layer4(out)
    out = F.avg_pool2d(out, 4)
    out = out.view(out.size(0), -1)
    out = self.linear(out)
    return out

def ResNet18():
  return ResNet(BasicBlock, [2, 2, 2, 2])

def ResNet9():
  return ResNet(BasicBlock, [1, 1, 1, 1])

# %% [markdown]
# ### ResNet9

# %%
model = ResNet9()

# %%
model =  model.to(device)
if device == 'cuda':
  model = torch.nn.DataParallel(model)
  cudnn.benchmark = True

# %%
summary(model, input_size=(3, 32, 32))
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            1,728
# ├─BatchNorm2d: 1-2                       128
# ├─Sequential: 1-3                        --
# |    └─BasicBlock: 2-1                   --
# |    |    └─Conv2d: 3-1                  36,864
# |    |    └─BatchNorm2d: 3-2             128
# |    |    └─Conv2d: 3-3                  36,864
# |    |    └─BatchNorm2d: 3-4             128
# |    |    └─Sequential: 3-5              --
# ├─Sequential: 1-4                        --
# |    └─BasicBlock: 2-2                   --
# |    |    └─Conv2d: 3-6                  73,728
# |    |    └─BatchNorm2d: 3-7             256
# |    |    └─Conv2d: 3-8                  147,456
# |    |    └─BatchNorm2d: 3-9             256
# |    |    └─Sequential: 3-10             8,448
# ├─Sequential: 1-5                        --
# |    └─BasicBlock: 2-3                   --
# |    |    └─Conv2d: 3-11                 294,912
# |    |    └─BatchNorm2d: 3-12            512
# |    |    └─Conv2d: 3-13                 589,824
# |    |    └─BatchNorm2d: 3-14            512
# |    |    └─Sequential: 3-15             33,280
# ├─Sequential: 1-6                        --
# |    └─BasicBlock: 2-4                   --
# |    |    └─Conv2d: 3-16                 1,179,648
# |    |    └─BatchNorm2d: 3-17            1,024
# |    |    └─Conv2d: 3-18                 2,359,296
# |    |    └─BatchNorm2d: 3-19            1,024
# |    |    └─Sequential: 3-20             132,096
# ├─Linear: 1-7                            5,130
# =================================================================
# Total params: 4,903,242
# Trainable params: 4,903,242
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            1,728
# ├─BatchNorm2d: 1-2                       128
# ├─Sequential: 1-3                        --
# |    └─BasicBlock: 2-1                   --
# |    |    └─Conv2d: 3-1                  36,864
# |    |    └─BatchNorm2d: 3-2             128
# |    |    └─Conv2d: 3-3                  36,864
# |    |    └─BatchNorm2d: 3-4             128
# |    |    └─Sequential: 3-5              --
# ├─Sequential: 1-4                        --
# |    └─BasicBlock: 2-2                   --
# |    |    └─Conv2d: 3-6                  73,728
# |    |    └─BatchNorm2d: 3-7             256
# |    |    └─Conv2d: 3-8                  147,456
# |    |    └─BatchNorm2d: 3-9             256
# |    |    └─Sequential: 3-10             8,448
# ├─Sequential: 1-5                        --
# |    └─BasicBlock: 2-3                   --
# |    |    └─Conv2d: 3-11                 294,912
# |    |    └─BatchNorm2d: 3-12            512
# |    |    └─Conv2d: 3-13                 589,824
# |    |    └─BatchNorm2d: 3-14            512
# |    |    └─Sequential: 3-15             33,280
# ├─Sequential: 1-6                        --
# |    └─BasicBlock: 2-4                   --
# |    |    └─Conv2d: 3-16                 1,179,648
# |    |    └─BatchNorm2d: 3-17            1,024
# |    |    └─Conv2d: 3-18                 2,359,296
# |    |    └─BatchNorm2d: 3-19            1,024
# |    |    └─Sequential: 3-20             132,096
# ├─Linear: 1-7                            5,130
# =================================================================
# Total params: 4,903,242
# Trainable params: 4,903,242
# Non-trainable params: 0
# =================================================================

# %% [markdown]
# ## Model Training

# %%
# Helper Function to Format Time
def format_time(seconds):
  days = int(seconds / 3600/24)
  seconds = seconds - days*3600*24
  hours = int(seconds / 3600)
  seconds = seconds - hours*3600
  minutes = int(seconds / 60)
  seconds = seconds - minutes*60
  secondsf = int(seconds)
  seconds = seconds - secondsf
  millis = int(seconds*1000)

  f = ''
  i = 1
  if days > 0:
    f += str(days) + 'D'
    i += 1
  if hours > 0 and i <= 2:
    f += str(hours) + 'h'
    i += 1
  if minutes > 0 and i <= 2:
    f += str(minutes) + 'm'
    i += 1
  if secondsf > 0 and i <= 2:
    f += str(secondsf) + 's'
    i += 1
  if millis > 0 and i <= 2:
    f += str(millis) + 'ms'
    i += 1
  if f == '':
    f = '0ms'
  return f

# %% [markdown]
# Loss: CrossEntropyLoss
#
# Optimizer: SGD
#
# Learning Rate: 0.1
#
# Momentum: 0.9
#
# Weight Decay: 5e-4
#
# Number of Epochs: 100
#
# Scheduler: CosineAnnealingLR

# %%
lr = 0.1
momentum = 0.9
weight_decay = 5e-4

start_epoch = 1
number_of_epochs = 100
best_acc = 0


criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=lr,
                      momentum=momentum, weight_decay=weight_decay)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=number_of_epochs)

# %%
# Helper Function to get Learning Rate
def get_lr(optimizer):
  for param_group in optimizer.param_groups:
    return param_group['lr']

# %%
def train(epoch):
  print('\nEpoch: %d' % epoch)
  start_time = time.time()

  model.train()
  train_loss = 0
  correct = 0
  total = 0
  for batch_idx, (inputs, targets) in enumerate(train_dl):
    # inputs, targets = inputs.to(device), targets.to(device)
    optimizer.zero_grad()
    outputs = model(inputs)
    loss = criterion(outputs, targets)
    loss.backward()
    optimizer.step()

    train_loss += loss.item()
    _, predicted = outputs.max(1)
    total += targets.size(0)
    correct += predicted.eq(targets).sum().item()

  cur_time = time.time()
  epoch_time = cur_time - start_time
  print(f"Training Time : {format_time(epoch_time)}")

  return train_loss/(batch_idx+1), 100.*correct/total, get_lr(optimizer)

# %%
def test(epoch):
  global best_acc
  model.eval()
  test_loss = 0
  correct = 0
  total = 0
  with torch.no_grad():
    for batch_idx, (inputs, targets) in enumerate(test_dl):
      outputs = model(inputs)
      loss = criterion(outputs, targets)

      test_loss += loss.item()
      _, predicted = outputs.max(1)
      total += targets.size(0)
      correct += predicted.eq(targets).sum().item()
      
  # Save checkpoint.
  acc = 100.*correct/total
  if acc > best_acc:
    print('Saving..')
    state = {
        'net': model.state_dict(),
        'acc': acc,
        'epoch': epoch,
    }
    if not os.path.isdir('checkpoint'):
      os.mkdir('checkpoint')
    torch.save(state, './checkpoint/resnet_9_vanilla_best.pth')
    best_acc = acc

  return test_loss/(batch_idx+1), 100.*correct/total

# %%
train_losses = []
train_accuracies = []
train_lrs = []

test_losses = []
test_accuracies = []

for epoch in range(start_epoch, start_epoch + number_of_epochs):
  epoch_train_loss, epoch_train_accuracy, epoch_lr = train(epoch)
  train_losses.append(epoch_train_loss)
  train_accuracies.append(epoch_train_accuracy)
  train_lrs.append(epoch_lr)

  epoch_test_loss, epoch_test_accuracy = test(epoch)
  test_losses.append(epoch_test_loss)
  test_accuracies.append(epoch_test_accuracy)

  scheduler.step()
  print(f"Train Loss: {epoch_train_loss:.3f} | Train Accuracy: {epoch_train_accuracy:.3f}% | Test Loss: {epoch_test_loss:.3f} | Test Accuracy: {epoch_test_accuracy:.3f}%")
# Out:
# Epoch: 1
# Training Time : 15s638ms
# Saving..
# Train Loss: 1.520 | Train Accuracy: 44.114% | Test Loss: 1.323 | Test Accuracy: 52.210%
#
# Epoch: 2
# Training Time : 15s72ms
# Saving..
# Train Loss: 1.023 | Train Accuracy: 63.560% | Test Loss: 1.006 | Test Accuracy: 64.840%
#
# Epoch: 3
# Training Time : 14s611ms
# Saving..
# Train Loss: 0.832 | Train Accuracy: 70.526% | Test Loss: 0.790 | Test Accuracy: 72.050%
#
# Epoch: 4
# Training Time : 14s748ms
# Saving..
# Train Loss: 0.701 | Train Accuracy: 75.454% | Test Loss: 0.683 | Test Accuracy: 76.500%
#
# Epoch: 5
# Training Time : 14s508ms
# Train Loss: 0.614 | Train Accuracy: 78.822% | Test Loss: 0.756 | Test Accuracy: 74.260%
#
# Epoch: 6
# Training Time : 14s833ms
# Train Loss: 0.561 | Train Accuracy: 80.516% | Test Loss: 0.910 | Test Accuracy: 71.090%
#
# Epoch: 7
# Training Time : 14s404ms
# Saving..
# Train Loss: 0.528 | Train Accuracy: 81.602% | Test Loss: 0.637 | Test Accuracy: 78.230%
#
# Epoch: 8
# Training Time : 15s645ms
# Saving..
# Train Loss: 0.502 | Train Accuracy: 82.718% | Test Loss: 0.595 | Test Accuracy: 79.750%
#
# Epoch: 9
# Training Time : 15s278ms
# Saving..
# Train Loss: 0.475 | Train Accuracy: 83.668% | Test Loss: 0.547 | Test Accuracy: 81.810%
#
# Epoch: 10
# Training Time : 15s713ms
# Train Loss: 0.465 | Train Accuracy: 83.924% | Test Loss: 0.603 | Test Accuracy: 79.900%
#
# Epoch: 11
# Training Time : 15s301ms
# Train Loss: 0.449 | Train Accuracy: 84.474% | Test Loss: 0.727 | Test Accuracy: 75.780%
#
# Epoch: 12
# Training Time : 15s599ms
# Train Loss: 0.435 | Train Accuracy: 84.940% | Test Loss: 0.706 | Test Accuracy: 78.380%
#
# Epoch: 13
# Training Time : 14s421ms
# Train Loss: 0.426 | Train Accuracy: 85.346% | Test Loss: 0.556 | Test Accuracy: 81.360%
#
# Epoch: 14
# Training Time : 14s852ms
# Train Loss: 0.418 | Train Accuracy: 85.616% | Test Loss: 0.684 | Test Accuracy: 78.760%
#
# Epoch: 15
# Training Time : 15s632ms
# Train Loss: 0.408 | Train Accuracy: 85.896% | Test Loss: 0.643 | Test Accuracy: 79.440%
#
# Epoch: 16
# Training Time : 15s939ms
# Saving..
# Train Loss: 0.399 | Train Accuracy: 86.338% | Test Loss: 0.491 | Test Accuracy: 83.350%
#
# Epoch: 17
# Training Time : 15s390ms
# Train Loss: 0.396 | Train Accuracy: 86.366% | Test Loss: 0.515 | Test Accuracy: 82.680%
#
# Epoch: 18
# Training Time : 15s523ms
# Train Loss: 0.384 | Train Accuracy: 86.848% | Test Loss: 0.700 | Test Accuracy: 78.380%
#
# Epoch: 19
# Training Time : 14s251ms
# Train Loss: 0.376 | Train Accuracy: 87.048% | Test Loss: 0.629 | Test Accuracy: 79.220%
#
# Epoch: 20
# Training Time : 14s504ms
# Train Loss: 0.369 | Train Accuracy: 87.438% | Test Loss: 0.494 | Test Accuracy: 83.310%
#
# Epoch: 21
# Training Time : 14s208ms
# Train Loss: 0.367 | Train Accuracy: 87.340% | Test Loss: 0.489 | Test Accuracy: 83.180%
#
# Epoch: 22
# Training Time : 14s344ms
# Train Loss: 0.363 | Train Accuracy: 87.612% | Test Loss: 0.525 | Test Accuracy: 82.440%
#
# Epoch: 23
# Training Time : 14s322ms
# Train Loss: 0.357 | Train Accuracy: 87.704% | Test Loss: 0.566 | Test Accuracy: 81.800%
#
# Epoch: 24
# Training Time : 14s713ms
# Train Loss: 0.352 | Train Accuracy: 87.856% | Test Loss: 0.590 | Test Accuracy: 80.430%
#
# Epoch: 25
# Training Time : 15s817ms
# Train Loss: 0.354 | Train Accuracy: 87.770% | Test Loss: 0.523 | Test Accuracy: 82.450%
#
# Epoch: 26
# Training Time : 15s373ms
# Saving..
# Train Loss: 0.351 | Train Accuracy: 87.924% | Test Loss: 0.440 | Test Accuracy: 85.530%
#
# Epoch: 27
# Training Time : 15s850ms
# Train Loss: 0.343 | Train Accuracy: 88.090% | Test Loss: 0.467 | Test Accuracy: 84.250%
#
# Epoch: 28
# Training Time : 15s172ms
# Train Loss: 0.337 | Train Accuracy: 88.500% | Test Loss: 0.463 | Test Accuracy: 84.480%
#
# Epoch: 29
# Training Time : 15s317ms
# Train Loss: 0.333 | Train Accuracy: 88.612% | Test Loss: 0.478 | Test Accuracy: 84.490%
#
# Epoch: 30
# Training Time : 14s240ms
# Train Loss: 0.326 | Train Accuracy: 88.760% | Test Loss: 0.622 | Test Accuracy: 79.490%
#
# Epoch: 31
# Training Time : 14s528ms
# Saving..
# Train Loss: 0.328 | Train Accuracy: 88.806% | Test Loss: 0.425 | Test Accuracy: 85.550%
#
# Epoch: 32
# Training Time : 14s276ms
# Train Loss: 0.320 | Train Accuracy: 88.998% | Test Loss: 0.460 | Test Accuracy: 84.430%
#
# Epoch: 33
# Training Time : 14s684ms
# Train Loss: 0.321 | Train Accuracy: 88.914% | Test Loss: 0.504 | Test Accuracy: 82.490%
#
# Epoch: 34
# Training Time : 14s215ms
# Train Loss: 0.314 | Train Accuracy: 89.194% | Test Loss: 0.457 | Test Accuracy: 84.400%
#
# Epoch: 35
# Training Time : 14s749ms
# Saving..
# Train Loss: 0.305 | Train Accuracy: 89.608% | Test Loss: 0.426 | Test Accuracy: 85.960%
#
# Epoch: 36
# Training Time : 14s217ms
# Train Loss: 0.305 | Train Accuracy: 89.442% | Test Loss: 0.564 | Test Accuracy: 81.920%
#
# Epoch: 37
# Training Time : 14s757ms
# Train Loss: 0.298 | Train Accuracy: 89.718% | Test Loss: 0.565 | Test Accuracy: 81.240%
#
# Epoch: 38
# Training Time : 14s302ms
# Train Loss: 0.295 | Train Accuracy: 89.852% | Test Loss: 0.583 | Test Accuracy: 80.850%
#
# Epoch: 39
# Training Time : 14s912ms
# Train Loss: 0.292 | Train Accuracy: 89.872% | Test Loss: 0.488 | Test Accuracy: 83.490%
#
# Epoch: 40
# Training Time : 14s272ms
# Train Loss: 0.287 | Train Accuracy: 90.002% | Test Loss: 0.616 | Test Accuracy: 80.970%
#
# Epoch: 41
# Training Time : 14s912ms
# Saving..
# Train Loss: 0.278 | Train Accuracy: 90.356% | Test Loss: 0.415 | Test Accuracy: 86.160%
#
# Epoch: 42
# Training Time : 14s515ms
# Saving..
# Train Loss: 0.277 | Train Accuracy: 90.644% | Test Loss: 0.397 | Test Accuracy: 86.310%
#
# Epoch: 43
# Training Time : 14s872ms
# Train Loss: 0.269 | Train Accuracy: 90.772% | Test Loss: 0.429 | Test Accuracy: 86.010%
#
# Epoch: 44
# Training Time : 15s98ms
# Train Loss: 0.263 | Train Accuracy: 90.862% | Test Loss: 0.436 | Test Accuracy: 85.580%
#
# Epoch: 45
# Training Time : 15s483ms
# Train Loss: 0.264 | Train Accuracy: 90.890% | Test Loss: 0.409 | Test Accuracy: 86.050%
#
# Epoch: 46
# Training Time : 15s355ms
# Saving..
# Train Loss: 0.261 | Train Accuracy: 91.020% | Test Loss: 0.403 | Test Accuracy: 86.690%
#
# Epoch: 47
# Training Time : 15s652ms
# Saving..
# Train Loss: 0.249 | Train Accuracy: 91.594% | Test Loss: 0.343 | Test Accuracy: 88.570%
#
# Epoch: 48
# Training Time : 15s30ms
# Train Loss: 0.249 | Train Accuracy: 91.502% | Test Loss: 0.362 | Test Accuracy: 87.880%
#
# Epoch: 49
# Training Time : 15s517ms
# Train Loss: 0.234 | Train Accuracy: 91.882% | Test Loss: 0.441 | Test Accuracy: 86.040%
#
# Epoch: 50
# Training Time : 14s787ms
# Train Loss: 0.238 | Train Accuracy: 91.834% | Test Loss: 0.346 | Test Accuracy: 88.360%
#
# Epoch: 51
# Training Time : 15s324ms
# Train Loss: 0.235 | Train Accuracy: 92.016% | Test Loss: 0.366 | Test Accuracy: 87.950%
#
# Epoch: 52
# Training Time : 15s620ms
# Train Loss: 0.227 | Train Accuracy: 92.242% | Test Loss: 0.387 | Test Accuracy: 87.290%
#
# Epoch: 53
# Training Time : 16s105ms
# Train Loss: 0.223 | Train Accuracy: 92.322% | Test Loss: 0.410 | Test Accuracy: 86.700%
#
# Epoch: 54
# Training Time : 16s37ms
# Train Loss: 0.215 | Train Accuracy: 92.442% | Test Loss: 0.355 | Test Accuracy: 88.340%
#
# Epoch: 55
# Training Time : 16s251ms
# Train Loss: 0.206 | Train Accuracy: 92.892% | Test Loss: 0.438 | Test Accuracy: 86.730%
#
# Epoch: 56
# Training Time : 14s816ms
# Train Loss: 0.207 | Train Accuracy: 92.824% | Test Loss: 0.413 | Test Accuracy: 87.210%
#
# Epoch: 57
# Training Time : 14s823ms
# Saving..
# Train Loss: 0.196 | Train Accuracy: 93.346% | Test Loss: 0.345 | Test Accuracy: 88.900%
#
# Epoch: 58
# Training Time : 15s280ms
# Train Loss: 0.188 | Train Accuracy: 93.504% | Test Loss: 0.342 | Test Accuracy: 88.880%
#
# Epoch: 59
# Training Time : 14s638ms
# Train Loss: 0.189 | Train Accuracy: 93.502% | Test Loss: 0.346 | Test Accuracy: 88.900%
#
# Epoch: 60
# Training Time : 15s233ms
# Saving..
# Train Loss: 0.179 | Train Accuracy: 93.758% | Test Loss: 0.334 | Test Accuracy: 89.260%
#
# Epoch: 61
# Training Time : 14s615ms
# Train Loss: 0.174 | Train Accuracy: 94.010% | Test Loss: 0.369 | Test Accuracy: 89.000%
#
# Epoch: 62
# Training Time : 16s131ms
# Train Loss: 0.170 | Train Accuracy: 94.168% | Test Loss: 0.352 | Test Accuracy: 88.940%
#
# Epoch: 63
# Training Time : 15s725ms
# Saving..
# Train Loss: 0.160 | Train Accuracy: 94.518% | Test Loss: 0.319 | Test Accuracy: 89.680%
#
# Epoch: 64
# Training Time : 15s949ms
# Saving..
# Train Loss: 0.157 | Train Accuracy: 94.658% | Test Loss: 0.329 | Test Accuracy: 90.000%
#
# Epoch: 65
# Training Time : 15s762ms
# Train Loss: 0.145 | Train Accuracy: 95.078% | Test Loss: 0.377 | Test Accuracy: 89.130%
#
# Epoch: 66
# Training Time : 15s803ms
# Train Loss: 0.142 | Train Accuracy: 95.016% | Test Loss: 0.319 | Test Accuracy: 89.760%
#
# Epoch: 67
# Training Time : 14s888ms
# Saving..
# Train Loss: 0.134 | Train Accuracy: 95.350% | Test Loss: 0.326 | Test Accuracy: 90.390%
#
# Epoch: 68
# Training Time : 14s897ms
# Train Loss: 0.128 | Train Accuracy: 95.562% | Test Loss: 0.368 | Test Accuracy: 89.160%
#
# Epoch: 69
# Training Time : 14s669ms
# Train Loss: 0.124 | Train Accuracy: 95.758% | Test Loss: 0.313 | Test Accuracy: 90.280%
#
# Epoch: 70
# Training Time : 14s657ms
# Saving..
# Train Loss: 0.109 | Train Accuracy: 96.338% | Test Loss: 0.292 | Test Accuracy: 91.020%
#
# Epoch: 71
# Training Time : 14s328ms
# Saving..
# Train Loss: 0.102 | Train Accuracy: 96.594% | Test Loss: 0.267 | Test Accuracy: 91.790%
#
# Epoch: 72
# Training Time : 14s598ms
# Train Loss: 0.098 | Train Accuracy: 96.632% | Test Loss: 0.324 | Test Accuracy: 90.680%
#
# Epoch: 73
# Training Time : 14s169ms
# Train Loss: 0.090 | Train Accuracy: 96.898% | Test Loss: 0.283 | Test Accuracy: 91.620%
#
# Epoch: 74
# Training Time : 14s428ms
# Saving..
# Train Loss: 0.082 | Train Accuracy: 97.234% | Test Loss: 0.257 | Test Accuracy: 92.060%
#
# Epoch: 75
# Training Time : 14s218ms
# Train Loss: 0.071 | Train Accuracy: 97.738% | Test Loss: 0.310 | Test Accuracy: 90.540%
#
# Epoch: 76
# Training Time : 14s564ms
# Train Loss: 0.064 | Train Accuracy: 97.908% | Test Loss: 0.273 | Test Accuracy: 91.930%
#
# Epoch: 77
# Training Time : 14s373ms
# Train Loss: 0.058 | Train Accuracy: 98.176% | Test Loss: 0.265 | Test Accuracy: 91.870%
#
# Epoch: 78
# Training Time : 14s692ms
# Saving..
# Train Loss: 0.054 | Train Accuracy: 98.302% | Test Loss: 0.248 | Test Accuracy: 92.460%
#
# Epoch: 79
# Training Time : 14s294ms
# Train Loss: 0.048 | Train Accuracy: 98.488% | Test Loss: 0.259 | Test Accuracy: 92.290%
#
# Epoch: 80
# Training Time : 14s511ms
# Saving..
# Train Loss: 0.040 | Train Accuracy: 98.814% | Test Loss: 0.244 | Test Accuracy: 93.260%
#
# Epoch: 81
# Training Time : 14s758ms
# Saving..
# Train Loss: 0.034 | Train Accuracy: 99.066% | Test Loss: 0.239 | Test Accuracy: 93.370%
#
# Epoch: 82
# Training Time : 15s72ms
# Train Loss: 0.031 | Train Accuracy: 99.110% | Test Loss: 0.243 | Test Accuracy: 93.240%
#
# Epoch: 83
# Training Time : 15s14ms
# Train Loss: 0.024 | Train Accuracy: 99.394% | Test Loss: 0.229 | Test Accuracy: 93.360%
#
# Epoch: 84
# Training Time : 15s169ms
# Saving..
# Train Loss: 0.020 | Train Accuracy: 99.540% | Test Loss: 0.222 | Test Accuracy: 93.570%
#
# Epoch: 85
# Training Time : 14s918ms
# Train Loss: 0.017 | Train Accuracy: 99.622% | Test Loss: 0.233 | Test Accuracy: 93.500%
#
# Epoch: 86
# Training Time : 15s256ms
# Saving..
# Train Loss: 0.015 | Train Accuracy: 99.724% | Test Loss: 0.220 | Test Accuracy: 93.810%
#
# Epoch: 87
# Training Time : 14s310ms
# Train Loss: 0.013 | Train Accuracy: 99.766% | Test Loss: 0.216 | Test Accuracy: 93.690%
#
# Epoch: 88
# Training Time : 14s700ms
# Saving..
# Train Loss: 0.012 | Train Accuracy: 99.790% | Test Loss: 0.211 | Test Accuracy: 93.840%
#
# Epoch: 89
# Training Time : 15s329ms
# Saving..
# Train Loss: 0.011 | Train Accuracy: 99.844% | Test Loss: 0.209 | Test Accuracy: 93.890%
#
# Epoch: 90
# Training Time : 15s648ms
# Saving..
# Train Loss: 0.010 | Train Accuracy: 99.864% | Test Loss: 0.213 | Test Accuracy: 93.900%
#
# Epoch: 91
# Training Time : 14s844ms
# Saving..
# Train Loss: 0.009 | Train Accuracy: 99.882% | Test Loss: 0.209 | Test Accuracy: 94.140%
#
# Epoch: 92
# Training Time : 15s465ms
# Train Loss: 0.009 | Train Accuracy: 99.876% | Test Loss: 0.210 | Test Accuracy: 93.980%
#
# Epoch: 93
# Training Time : 14s232ms
# Train Loss: 0.008 | Train Accuracy: 99.902% | Test Loss: 0.212 | Test Accuracy: 94.020%
#
# Epoch: 94
# Training Time : 14s545ms
# Train Loss: 0.008 | Train Accuracy: 99.926% | Test Loss: 0.209 | Test Accuracy: 93.980%
#
# Epoch: 95
# Training Time : 14s185ms
# Train Loss: 0.008 | Train Accuracy: 99.934% | Test Loss: 0.208 | Test Accuracy: 94.050%
#
# Epoch: 96
# Training Time : 14s550ms
# Saving..
# Train Loss: 0.007 | Train Accuracy: 99.922% | Test Loss: 0.206 | Test Accuracy: 94.170%
#
# Epoch: 97
# Training Time : 14s2ms
# Train Loss: 0.007 | Train Accuracy: 99.942% | Test Loss: 0.207 | Test Accuracy: 93.980%
#
# Epoch: 98
# Training Time : 14s464ms
# Train Loss: 0.007 | Train Accuracy: 99.918% | Test Loss: 0.210 | Test Accuracy: 93.990%
#
# Epoch: 99
# Training Time : 14s974ms
# Train Loss: 0.007 | Train Accuracy: 99.922% | Test Loss: 0.208 | Test Accuracy: 94.080%
#
# Epoch: 100
# Training Time : 15s88ms
# Train Loss: 0.007 | Train Accuracy: 99.938% | Test Loss: 0.206 | Test Accuracy: 94.090%

# %%
print(f"Best Accuracy: {best_acc:.3f}%")
# Out:
# Best Accuracy: 94.170%

# %%
def plot_accuracies(train_accuracies, test_accuracies):
  plt.plot(train_accuracies, label='Train Accuracy')
  plt.plot(test_accuracies, label='Test Accuracy')
  plt.xlabel('Epochs')
  plt.ylabel('Accuracy')
  plt.legend()
  plt.grid(True)
  plt.title('Accuracy vs. No. of epochs')

# %%
def plot_losses(train_losses, test_losses):
  plt.plot(train_losses, label='Train Losses')
  plt.plot(test_losses, label='Test Losses')
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.legend()
  plt.grid(True)
  plt.title('Loss vs. No. of epochs')

# %%
def plot_lrs(train_lrs):
  plt.plot(train_lrs)
  plt.xlabel('Epochs')
  plt.ylabel('Learning rate')
  plt.grid(True)
  plt.title('Learning Rate vs. Epochs')

# %%
plot_accuracies(train_accuracies, test_accuracies)

# %%
plot_losses(train_losses, test_losses)

# %%
plot_lrs(train_lrs)

# %%
print('Saving final model..')
state = {
    'net': model.state_dict(),
    'acc': test_accuracies[-1],
    'epoch': number_of_epochs,
    'best_acc' : best_acc,
    'train_acc' : train_accuracies,
    'test_acc' : test_accuracies,
    'train_loss' : train_losses,
    'test_loss' : test_losses,
    'lr' : train_lrs
}
if not os.path.isdir('checkpoint'):
  os.mkdir('checkpoint')
torch.save(state, './checkpoint/resnet_9_vanilla_final.pth')
# Out:
# Saving final model..

# %%
import numpy as np
import pickle
import pandas as pd

# Function to load CIFAR batch
def load_cifar_batch(file):
    with open(file, 'rb') as fo:
        batch = pickle.load(fo, encoding='bytes')
    return batch

# Specify the folder where the CIFAR-10 batch files are
cifar10_dir = '/kaggle/input/deep-learning-mini-project-spring-24-nyu/cifar-10-python/cifar-10-batches-py'

# Load the label names
meta_data_dict = load_cifar_batch(os.path.join(cifar10_dir, 'batches.meta'))
label_names = meta_data_dict[b'label_names']

# Load test data
test_batch = load_cifar_batch('/kaggle/input/deep-learning-mini-project-spring-24-nyu/cifar_test_nolabels.pkl')
test_images = test_batch[b'data'].reshape(-1, 3, 32, 32).transpose(0, 2, 3, 1)

data_statistics = (
    (0.49139968, 0.48215827, 0.44653124),
     (0.24703233, 0.24348505, 0.26158768)
)

# Define transformation for data augmentation
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(*data_statistics, inplace=True)
])

# Apply data augmentation
augmented_test_images = torch.stack([transform(image) for image in test_images])

# Load the trained model
model = ResNet9()

checkpoint = torch.load('/kaggle/working/checkpoint/resnet_9_vanilla_best.pth')

# Check the keys in the checkpoint dictionary
print(checkpoint.keys())

# Assuming the model state dictionary is saved under a different key
# Adjust this according to the actual key in your checkpoint file
model.load_state_dict(checkpoint['net'])

model =  model.to(device)
augmented_test_images = augmented_test_images.to(device)

# Evaluate the model on test data
model.eval()
with torch.no_grad():
    outputs = model(augmented_test_images)
_, predicted = torch.max(outputs, 1)

predicted = predicted.to('cpu')

# Display the first 10 test images and predicted labels
plt.figure(figsize=(20, 4))
for i in range(10):
    plt.subplot(1, 10, i+1)
    plt.imshow(test_images[i])
    plt.title(label_names[predicted[i].item()].decode('utf-8'))
    plt.axis('off')
plt.show()

# Save the output in output.csv containing ID, Labels
output_data = {'ID': np.arange(len(predicted)), 'Labels': predicted.numpy()}
output_df = pd.DataFrame(output_data)
output_df.to_csv('resnet_9_vanilla_best_output.csv', index=False)
# Out:
# dict_keys(['net', 'acc', 'epoch'])

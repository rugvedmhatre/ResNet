# %% [markdown]
# # ResNet-18 on CIFAR-10 Dataset

# %% [markdown]
# Importing PyTorch and a few Python Libraries

# %%
import os
import sys
import time
import math

import torch
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import random_split, DataLoader
from torchvision.utils import make_grid

import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
import torch.nn.init as init

from torchsummary import summary

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Preparing the dataset
#
# We will be downloading the train and test CIFAR-10 dataset from torchvision. We will normalize and transform the dataset. For the training dataset, we will also be adding Random Crops and Random Horizontal Flips to generalize the model better.

# %%
data_statistics = (
    (0.49139968, 0.48215827, 0.44653124),
     (0.24703233, 0.24348505, 0.26158768)
) # Mean, Standard Deviation of CIFAR-10 dataset channels

train_transforms = transforms.Compose([
    transforms.RandomCrop(32, padding=4, padding_mode='reflect'), # Adding Random Crops
    transforms.RandomHorizontalFlip(), # Adding Random Horizontal Flips
    transforms.ToTensor(), # Channel x Image Height x Image Width
    transforms.Normalize(*data_statistics, inplace=True) # Output in the range of [-1, 1]
])

test_transforms = transforms.Compose([
    transforms.ToTensor(), # Channel x Image Height x Image Width
    transforms.Normalize(*data_statistics, inplace=True) # Output in the range of [-1, 1]
])

# %%
train_dataset = torchvision.datasets.CIFAR10(root='./data/', download=True, train=True, transform=train_transforms)
test_dataset = torchvision.datasets.CIFAR10(root='./data/', download=True, train=False, transform=test_transforms)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# <!-- We will also be splitting the dataset further into training and validation dataset with a validation ratio of `0.2` -->
#
# We will now create data loaders to retreive images in batches. We are selecting the batch size as `128` images for our train loader. And we are selecting the batch size as `100` images for our test loader.
#
# *From PyTorch Documentation: For data loading, passing pin_memory=True to a DataLoader will automatically put the fetched data Tensors in pinned memory, and thus enables faster data transfer to CUDA-enabled GPUs.*

# %%
# validation_ratio = 0.2
# train_dataset, validation_dataset = random_split(
#     dataset,
#     [int((1 - validation_ratio) * len(dataset)), int(validation_ratio * len(dataset))]
# )

train_batch_size = 128
test_batch_size = 100

train_dl = DataLoader(train_dataset, train_batch_size, shuffle=True, num_workers=2, pin_memory=True)
# validation_dl = DataLoader(validation_dataset, batch_size, shuffle=True, num_workers=3, pin_memory=True)
test_dl = DataLoader(test_dataset, test_batch_size, shuffle=False, num_workers=2, pin_memory=True)

classes = ('plane', 'car', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck')

# %% [markdown]
# We create the following function to display a batch of images from the dataset. And we also need to denormalize the pixels values to bring them back into the range (0,1).

# %%
def denormalize(images, means, stds):
  means = torch.tensor(means).reshape(1, 3, 1, 1)
  stds = torch.tensor(stds).reshape(1, 3, 1, 1)
  return images * stds + means

def show_batch(dl):
  for images, labels in dl:
    fig, ax = plt.subplots(figsize=(12, 12))
    ax.set_xticks([])
    ax.set_yticks([])
    denorm_images = denormalize(images, *data_statistics)
    ax.imshow(make_grid(denorm_images[:64], 8).permute(1, 2, 0))
    break

# %%
show_batch(train_dl)

# %% [markdown]
# To seamlessly use a GPU, if one is available, we define a couple of helper functions (`get_default_device` & `to_device`) and a helper class `DeviceDataLoader` to move our model & data to the GPU as required.

# %%
def get_default_device():
  # Pick GPU, if available, else CPU
  if torch.cuda.is_available():
    return torch.device('cuda')
  else:
    return torch.device('cpu')

def to_device(data, device):
  # Move tensors to chosen device
  if isinstance(data, (list, tuple)):
    # If the instance is a list/tuple, transfer each element to chosen device
    return [to_device(x, device) for x in data]
  return data.to(device, non_blocking=True)
  # non_blocking=True doesn't block the execution of the host device until transfers complete

class DeviceDataLoader():
  # Wrap a dataloader to move data to a device
  def __init__(self, dl, device):
    self.dl = dl
    self.device = device

  def __iter__(self):
    # Yield a batch of data after moving it to device
    for b in self.dl:
      yield to_device(b, self.device)

  def __len__(self):
    # Number of batches
    return len(self.dl)

# %%
# Get the default device
device = get_default_device()
device
# Out:
# device(type='cuda')

# %%
train_dl = DeviceDataLoader(train_dl, device)
# validation_dl = DeviceDataLoader(validation_dl, device)
test_dl = DeviceDataLoader(test_dl, device)

# %% [markdown]
# ## Network Architecture

# %% [markdown]
# Testing the models mentioned in the `pytorch-cifar` [GitHub Repository](https://github.com/kuangliu/pytorch-cifar).

# %% [markdown]
# ### PreActResNet18

# %%
class PreActBlock(nn.Module):
  '''Pre-activation version of the BasicBlock.'''
  expansion = 1

  def __init__(self, in_planes, planes, stride=1):
    super(PreActBlock, self).__init__()
    self.bn1 = nn.BatchNorm2d(in_planes)
    self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
    self.bn2 = nn.BatchNorm2d(planes)
    self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)

    if stride != 1 or in_planes != self.expansion*planes:
      self.shortcut = nn.Sequential(
          nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False)
      )

  def forward(self, x):
    out = F.relu(self.bn1(x))
    shortcut = self.shortcut(out) if hasattr(self, 'shortcut') else x
    out = self.conv1(out)
    out = self.conv2(F.relu(self.bn2(out)))
    out += shortcut
    return out

class PreActResNet(nn.Module):
  def __init__(self, block, num_blocks, num_classes=10):
    super(PreActResNet, self).__init__()
    self.in_planes = 64

    self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
    self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
    self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
    self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
    self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
    self.linear = nn.Linear(512*block.expansion, num_classes)

  def _make_layer(self, block, planes, num_blocks, stride):
    strides = [stride] + [1]*(num_blocks-1)
    layers = []
    for stride in strides:
        layers.append(block(self.in_planes, planes, stride))
        self.in_planes = planes * block.expansion
    return nn.Sequential(*layers)

  def forward(self, x):
    out = self.conv1(x)
    out = self.layer1(out)
    out = self.layer2(out)
    out = self.layer3(out)
    out = self.layer4(out)
    out = F.avg_pool2d(out, 4)
    out = out.view(out.size(0), -1)
    out = self.linear(out)
    return out

def PreActResNet18():
  return PreActResNet(PreActBlock, [2,2,2,2])

# %%
# model = PreActResNet18()

# %% [markdown]
# The number of parameters is `11,171,146`, which exceeds the 5 million limit.

# %% [markdown]
# ### ResNet18

# %%
class BasicBlock(nn.Module):
  expansion = 1

  def __init__(self, in_planes, planes, stride=1):
    super(BasicBlock, self).__init__()
    self.conv1 = nn.Conv2d(
        in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
    self.bn1 = nn.BatchNorm2d(planes)
    self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                            stride=1, padding=1, bias=False)
    self.bn2 = nn.BatchNorm2d(planes)

    self.shortcut = nn.Sequential()
    if stride != 1 or in_planes != self.expansion*planes:
      self.shortcut = nn.Sequential(
          nn.Conv2d(in_planes, self.expansion*planes,
                    kernel_size=1, stride=stride, bias=False),
          nn.BatchNorm2d(self.expansion*planes)
      )

  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))
    out = self.bn2(self.conv2(out))
    out += self.shortcut(x)
    out = F.relu(out)
    return out

class ResNet(nn.Module):
  def __init__(self, block, num_blocks, num_classes=10):
    super(ResNet, self).__init__()
    self.in_planes = 64

    self.conv1 = nn.Conv2d(3, 64, kernel_size=3,
                            stride=1, padding=1, bias=False)
    self.bn1 = nn.BatchNorm2d(64)
    self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
    self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
    self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
    self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
    self.linear = nn.Linear(512*block.expansion, num_classes)

  def _make_layer(self, block, planes, num_blocks, stride):
    strides = [stride] + [1]*(num_blocks-1)
    layers = []
    for stride in strides:
      layers.append(block(self.in_planes, planes, stride))
      self.in_planes = planes * block.expansion
    return nn.Sequential(*layers)

  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))
    out = self.layer1(out)
    out = self.layer2(out)
    out = self.layer3(out)
    out = self.layer4(out)
    out = F.avg_pool2d(out, 4)
    out = out.view(out.size(0), -1)
    out = self.linear(out)
    return out

def ResNet18():
  return ResNet(BasicBlock, [2, 2, 2, 2])

# %%
# model = ResNet18()

# %% [markdown]
# The number of parameters is `11,173,962`, which exceeds the 5 million limit.

# %% [markdown]
# ### ResNet9

# %%
def ResNet9():
  return ResNet(BasicBlock, [1, 1, 1, 1])

# %%
model = ResNet9()

# %% [markdown]
# ### PreActResNet9

# %%
def PreActResNet9():
  return PreActResNet(PreActBlock, [1,1,1,1])

# %%
# model = PreActResNet9()

# %%
model =  model.to(device)
if device == 'cuda':
  model = torch.nn.DataParallel(model)
  cudnn.benchmark = True

# %%
summary(model, input_size=(3, 32, 32))
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            1,728
# ├─BatchNorm2d: 1-2                       128
# ├─Sequential: 1-3                        --
# |    └─BasicBlock: 2-1                   --
# |    |    └─Conv2d: 3-1                  36,864
# |    |    └─BatchNorm2d: 3-2             128
# |    |    └─Conv2d: 3-3                  36,864
# |    |    └─BatchNorm2d: 3-4             128
# |    |    └─Sequential: 3-5              --
# ├─Sequential: 1-4                        --
# |    └─BasicBlock: 2-2                   --
# |    |    └─Conv2d: 3-6                  73,728
# |    |    └─BatchNorm2d: 3-7             256
# |    |    └─Conv2d: 3-8                  147,456
# |    |    └─BatchNorm2d: 3-9             256
# |    |    └─Sequential: 3-10             8,448
# ├─Sequential: 1-5                        --
# |    └─BasicBlock: 2-3                   --
# |    |    └─Conv2d: 3-11                 294,912
# |    |    └─BatchNorm2d: 3-12            512
# |    |    └─Conv2d: 3-13                 589,824
# |    |    └─BatchNorm2d: 3-14            512
# |    |    └─Sequential: 3-15             33,280
# ├─Sequential: 1-6                        --
# |    └─BasicBlock: 2-4                   --
# |    |    └─Conv2d: 3-16                 1,179,648
# |    |    └─BatchNorm2d: 3-17            1,024
# |    |    └─Conv2d: 3-18                 2,359,296
# |    |    └─BatchNorm2d: 3-19            1,024
# |    |    └─Sequential: 3-20             132,096
# ├─Linear: 1-7                            5,130
# =================================================================
# Total params: 4,903,242
# Trainable params: 4,903,242
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            1,728
# ├─BatchNorm2d: 1-2                       128
# ├─Sequential: 1-3                        --
# |    └─BasicBlock: 2-1                   --
# |    |    └─Conv2d: 3-1                  36,864
# |    |    └─BatchNorm2d: 3-2             128
# |    |    └─Conv2d: 3-3                  36,864
# |    |    └─BatchNorm2d: 3-4             128
# |    |    └─Sequential: 3-5              --
# ├─Sequential: 1-4                        --
# |    └─BasicBlock: 2-2                   --
# |    |    └─Conv2d: 3-6                  73,728
# |    |    └─BatchNorm2d: 3-7             256
# |    |    └─Conv2d: 3-8                  147,456
# |    |    └─BatchNorm2d: 3-9             256
# |    |    └─Sequential: 3-10             8,448
# ├─Sequential: 1-5                        --
# |    └─BasicBlock: 2-3                   --
# |    |    └─Conv2d: 3-11                 294,912
# |    |    └─BatchNorm2d: 3-12            512
# |    |    └─Conv2d: 3-13                 589,824
# |    |    └─BatchNorm2d: 3-14            512
# |    |    └─Sequential: 3-15             33,280
# ├─Sequential: 1-6                        --
# |    └─BasicBlock: 2-4                   --
# |    |    └─Conv2d: 3-16                 1,179,648
# |    |    └─BatchNorm2d: 3-17            1,024
# |    |    └─Conv2d: 3-18                 2,359,296
# |    |    └─BatchNorm2d: 3-19            1,024
# |    |    └─Sequential: 3-20             132,096
# ├─Linear: 1-7                            5,130
# =================================================================
# Total params: 4,903,242
# Trainable params: 4,903,242
# Non-trainable params: 0
# =================================================================

# %% [markdown]
# ## Model Training

# %%
# Helper Function
# term_width = int(100)

# TOTAL_BAR_LENGTH = 65.
# last_time = time.time()
# begin_time = last_time

# def progress_bar(current, total, msg=None):
#   global last_time, begin_time
#   if current == 0:
#     begin_time = time.time()  # Reset for new bar.

#   cur_len = int(TOTAL_BAR_LENGTH * current/total)
#   rest_len = int(TOTAL_BAR_LENGTH - cur_len) - 1

#   sys.stdout.write(' [')
#   for i in range(cur_len):
#     sys.stdout.write('=')
#   sys.stdout.write('>')
#   for i in range(rest_len):
#     sys.stdout.write('.')
#   sys.stdout.write(']')

#   cur_time = time.time()
#   step_time = cur_time - last_time
#   last_time = cur_time
#   tot_time = cur_time - begin_time

#   L = []
#   L.append('  Step: %s' % format_time(step_time))
#   L.append(' | Tot: %s' % format_time(tot_time))
#   if msg:
#     L.append(' | ' + msg)

#   msg = ''.join(L)
#   sys.stdout.write(msg)
#   for i in range(term_width-int(TOTAL_BAR_LENGTH)-len(msg)-3):
#     sys.stdout.write(' ')

#   # Go back to the center of the bar.
#   for i in range(term_width-int(TOTAL_BAR_LENGTH/2)+2):
#     sys.stdout.write('\b')
#   sys.stdout.write(' %d/%d ' % (current+1, total))

#   if current < total-1:
#     sys.stdout.write('\r')
#   else:
#     sys.stdout.write('\n')
#   sys.stdout.flush()

# %%
def format_time(seconds):
  days = int(seconds / 3600/24)
  seconds = seconds - days*3600*24
  hours = int(seconds / 3600)
  seconds = seconds - hours*3600
  minutes = int(seconds / 60)
  seconds = seconds - minutes*60
  secondsf = int(seconds)
  seconds = seconds - secondsf
  millis = int(seconds*1000)

  f = ''
  i = 1
  if days > 0:
    f += str(days) + 'D'
    i += 1
  if hours > 0 and i <= 2:
    f += str(hours) + 'h'
    i += 1
  if minutes > 0 and i <= 2:
    f += str(minutes) + 'm'
    i += 1
  if secondsf > 0 and i <= 2:
    f += str(secondsf) + 's'
    i += 1
  if millis > 0 and i <= 2:
    f += str(millis) + 'ms'
    i += 1
  if f == '':
    f = '0ms'
  return f

# %%
lr = 0.1
momentum = 0.9
weight_decay = 5e-4

start_epoch = 1
number_of_epochs = 100
best_acc = 0


criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=lr, weight_decay=weight_decay)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=number_of_epochs, eta_min = 0.005)

# %%
def get_lr(optimizer):
  for param_group in optimizer.param_groups:
    return param_group['lr']

# %%
def train(epoch):
  print('\nEpoch: %d' % epoch)
  start_time = time.time()

  model.train()
  train_loss = 0
  correct = 0
  total = 0
  for batch_idx, (inputs, targets) in enumerate(train_dl):
    # inputs, targets = inputs.to(device), targets.to(device)
    optimizer.zero_grad()
    outputs = model(inputs)
    loss = criterion(outputs, targets)
    loss.backward()
    optimizer.step()

    train_loss += loss.item()
    _, predicted = outputs.max(1)
    total += targets.size(0)
    correct += predicted.eq(targets).sum().item()

    if batch_idx % 50 == 0:
      print(f"Batch: {batch_idx}/{len(train_dl)} | Loss: {(train_loss/(batch_idx+1)):.3f} | Acc: {(100.*correct/total):.3f}%")

  cur_time = time.time()
  epoch_time = cur_time - start_time
  print(f"Time taken : {format_time(epoch_time)}")

  return train_loss/(batch_idx+1), 100.*correct/total, get_lr(optimizer)

# %%
def test(epoch):
  global best_acc
  model.eval()
  test_loss = 0
  correct = 0
  total = 0
  with torch.no_grad():
    for batch_idx, (inputs, targets) in enumerate(test_dl):
      # inputs, targets = inputs.to(device), targets.to(device)
      outputs = model(inputs)
      loss = criterion(outputs, targets)

      test_loss += loss.item()
      _, predicted = outputs.max(1)
      total += targets.size(0)
      correct += predicted.eq(targets).sum().item()
      
      if batch_idx % 50 == 0:
        print(f"Batch: {batch_idx}/{len(test_dl)} | Loss: {(test_loss/(batch_idx+1)):.3f} | Acc: {(100.*correct/total):.3f}%")
      # progress_bar(batch_idx, len(test_dl), 'Loss: %.3f | Acc: %.3f%% (%d/%d)'
      #               % (test_loss/(batch_idx+1), 100.*correct/total, correct, total))

  # Save checkpoint.
  acc = 100.*correct/total
  if acc > best_acc:
    print('Saving..')
    state = {
        'net': model.state_dict(),
        'acc': acc,
        'epoch': epoch,
    }
    if not os.path.isdir('try_checkpoint'):
      os.mkdir('try_checkpoint')
    torch.save(state, './try_checkpoint/ckpt.pth')
    best_acc = acc

  return test_loss/(batch_idx+1), 100.*correct/total

# %%
train_losses = []
train_accuracies = []
train_lrs = []

test_losses = []
test_accuracies = []

for epoch in range(start_epoch, start_epoch + number_of_epochs):
  epoch_train_loss, epoch_train_accuracy, epoch_lr = train(epoch)
  train_losses.append(epoch_train_loss)
  train_accuracies.append(epoch_train_accuracy)
  train_lrs.append(epoch_lr)

  epoch_test_loss, epoch_test_accuracy = test(epoch)
  test_losses.append(epoch_test_loss)
  test_accuracies.append(epoch_test_accuracy)

  scheduler.step()
# Out:
# Epoch: 1
# Batch: 0/391 | Loss: 2.443 | Acc: 9.375%
# Batch: 50/391 | Loss: 2.040 | Acc: 26.471%
# Batch: 100/391 | Loss: 1.877 | Acc: 31.606%
# Batch: 150/391 | Loss: 1.759 | Acc: 35.498%
# Batch: 200/391 | Loss: 1.672 | Acc: 38.514%
# Batch: 250/391 | Loss: 1.607 | Acc: 40.961%
# Batch: 300/391 | Loss: 1.553 | Acc: 42.995%
# Batch: 350/391 | Loss: 1.504 | Acc: 44.887%
# Time taken : 38s631ms
# Batch: 0/100 | Loss: 1.354 | Acc: 50.000%
# Batch: 50/100 | Loss: 1.350 | Acc: 52.804%
# Saving..
#
# Epoch: 2
# Batch: 0/391 | Loss: 1.448 | Acc: 53.906%
# Batch: 50/391 | Loss: 1.121 | Acc: 59.161%
# Batch: 100/391 | Loss: 1.104 | Acc: 59.831%
# Batch: 150/391 | Loss: 1.094 | Acc: 60.420%
# Batch: 200/391 | Loss: 1.078 | Acc: 61.035%
# Batch: 250/391 | Loss: 1.064 | Acc: 61.635%
# Batch: 300/391 | Loss: 1.048 | Acc: 62.222%
# Batch: 350/391 | Loss: 1.037 | Acc: 62.714%
# Time taken : 47s423ms
# Batch: 0/100 | Loss: 0.972 | Acc: 64.000%
# Batch: 50/100 | Loss: 1.018 | Acc: 64.843%
# Saving..
#
# Epoch: 3
# Batch: 0/391 | Loss: 0.979 | Acc: 64.062%
# Batch: 50/391 | Loss: 0.882 | Acc: 69.623%
# Batch: 100/391 | Loss: 0.882 | Acc: 68.974%
# Batch: 150/391 | Loss: 0.872 | Acc: 69.324%
# Batch: 200/391 | Loss: 0.865 | Acc: 69.434%
# Batch: 250/391 | Loss: 0.860 | Acc: 69.509%
# Batch: 300/391 | Loss: 0.853 | Acc: 69.788%
# Batch: 350/391 | Loss: 0.848 | Acc: 69.983%
# Time taken : 1m376ms
# Batch: 0/100 | Loss: 0.751 | Acc: 69.000%
# Batch: 50/100 | Loss: 0.871 | Acc: 69.627%
# Saving..
#
# Epoch: 4
# Batch: 0/391 | Loss: 0.853 | Acc: 71.094%
# Batch: 50/391 | Loss: 0.746 | Acc: 73.820%
# Batch: 100/391 | Loss: 0.741 | Acc: 73.801%
# Batch: 150/391 | Loss: 0.731 | Acc: 74.198%
# Batch: 200/391 | Loss: 0.728 | Acc: 74.215%
# Batch: 250/391 | Loss: 0.724 | Acc: 74.421%
# Batch: 300/391 | Loss: 0.720 | Acc: 74.577%
# Batch: 350/391 | Loss: 0.717 | Acc: 74.757%
# Time taken : 59s329ms
# Batch: 0/100 | Loss: 0.878 | Acc: 72.000%
# Batch: 50/100 | Loss: 1.138 | Acc: 63.667%
#
# Epoch: 5
# Batch: 0/391 | Loss: 0.806 | Acc: 71.094%
# Batch: 50/391 | Loss: 0.664 | Acc: 76.792%
# Batch: 100/391 | Loss: 0.654 | Acc: 77.174%
# Batch: 150/391 | Loss: 0.651 | Acc: 77.189%
# Batch: 200/391 | Loss: 0.647 | Acc: 77.491%
# Batch: 250/391 | Loss: 0.645 | Acc: 77.521%
# Batch: 300/391 | Loss: 0.643 | Acc: 77.538%
# Batch: 350/391 | Loss: 0.637 | Acc: 77.682%
# Time taken : 59s277ms
# Batch: 0/100 | Loss: 0.910 | Acc: 69.000%
# Batch: 50/100 | Loss: 0.919 | Acc: 70.549%
# Saving..
#
# Epoch: 6
# Batch: 0/391 | Loss: 0.719 | Acc: 74.219%
# Batch: 50/391 | Loss: 0.582 | Acc: 79.779%
# Batch: 100/391 | Loss: 0.583 | Acc: 79.896%
# Batch: 150/391 | Loss: 0.579 | Acc: 80.013%
# Batch: 200/391 | Loss: 0.579 | Acc: 79.944%
# Batch: 250/391 | Loss: 0.575 | Acc: 79.949%
# Batch: 300/391 | Loss: 0.575 | Acc: 79.838%
# Batch: 350/391 | Loss: 0.571 | Acc: 79.992%
# Time taken : 59s505ms
# Batch: 0/100 | Loss: 0.612 | Acc: 80.000%
# Batch: 50/100 | Loss: 0.760 | Acc: 74.353%
# Saving..
#
# Epoch: 7
# Batch: 0/391 | Loss: 0.641 | Acc: 78.906%
# Batch: 50/391 | Loss: 0.523 | Acc: 81.893%
# Batch: 100/391 | Loss: 0.524 | Acc: 81.799%
# Batch: 150/391 | Loss: 0.522 | Acc: 81.969%
# Batch: 200/391 | Loss: 0.520 | Acc: 82.004%
# Batch: 250/391 | Loss: 0.522 | Acc: 81.975%
# Batch: 300/391 | Loss: 0.520 | Acc: 82.016%
# Batch: 350/391 | Loss: 0.518 | Acc: 82.049%
# Time taken : 59s19ms
# Batch: 0/100 | Loss: 0.531 | Acc: 79.000%
# Batch: 50/100 | Loss: 0.625 | Acc: 79.020%
# Saving..
#
# Epoch: 8
# Batch: 0/391 | Loss: 0.466 | Acc: 82.031%
# Batch: 50/391 | Loss: 0.485 | Acc: 83.471%
# Batch: 100/391 | Loss: 0.486 | Acc: 83.377%
# Batch: 150/391 | Loss: 0.489 | Acc: 83.154%
# Batch: 200/391 | Loss: 0.485 | Acc: 83.291%
# Batch: 250/391 | Loss: 0.482 | Acc: 83.329%
# Batch: 300/391 | Loss: 0.479 | Acc: 83.443%
# Batch: 350/391 | Loss: 0.478 | Acc: 83.416%
# Time taken : 1m713ms
# Batch: 0/100 | Loss: 0.670 | Acc: 78.000%
# Batch: 50/100 | Loss: 0.654 | Acc: 79.549%
# Saving..
#
# Epoch: 9
# Batch: 0/391 | Loss: 0.443 | Acc: 84.375%
# Batch: 50/391 | Loss: 0.426 | Acc: 85.631%
# Batch: 100/391 | Loss: 0.427 | Acc: 85.489%
# Batch: 150/391 | Loss: 0.437 | Acc: 85.048%
# Batch: 200/391 | Loss: 0.441 | Acc: 84.927%
# Batch: 250/391 | Loss: 0.438 | Acc: 84.885%
# Batch: 300/391 | Loss: 0.439 | Acc: 84.819%
# Batch: 350/391 | Loss: 0.441 | Acc: 84.749%
# Time taken : 1m776ms
# Batch: 0/100 | Loss: 0.851 | Acc: 69.000%
# Batch: 50/100 | Loss: 0.766 | Acc: 74.686%
#
# Epoch: 10
# Batch: 0/391 | Loss: 0.357 | Acc: 85.156%
# Batch: 50/391 | Loss: 0.414 | Acc: 85.555%
# Batch: 100/391 | Loss: 0.411 | Acc: 85.791%
# Batch: 150/391 | Loss: 0.411 | Acc: 85.808%
# Batch: 200/391 | Loss: 0.417 | Acc: 85.549%
# Batch: 250/391 | Loss: 0.420 | Acc: 85.415%
# Batch: 300/391 | Loss: 0.420 | Acc: 85.377%
# Batch: 350/391 | Loss: 0.419 | Acc: 85.406%
# Time taken : 1m27ms
# Batch: 0/100 | Loss: 0.705 | Acc: 74.000%
# Batch: 50/100 | Loss: 0.656 | Acc: 78.157%
#
# Epoch: 11
# Batch: 0/391 | Loss: 0.405 | Acc: 83.594%
# Batch: 50/391 | Loss: 0.384 | Acc: 87.209%
# Batch: 100/391 | Loss: 0.384 | Acc: 86.812%
# Batch: 150/391 | Loss: 0.382 | Acc: 86.889%
# Batch: 200/391 | Loss: 0.385 | Acc: 86.641%
# Batch: 250/391 | Loss: 0.388 | Acc: 86.538%
# Batch: 300/391 | Loss: 0.387 | Acc: 86.631%
# Batch: 350/391 | Loss: 0.388 | Acc: 86.592%
# Time taken : 1m139ms
# Batch: 0/100 | Loss: 0.602 | Acc: 79.000%
# Batch: 50/100 | Loss: 0.641 | Acc: 79.510%
# Saving..
#
# Epoch: 12
# Batch: 0/391 | Loss: 0.320 | Acc: 89.844%
# Batch: 50/391 | Loss: 0.358 | Acc: 87.592%
# Batch: 100/391 | Loss: 0.359 | Acc: 87.454%
# Batch: 150/391 | Loss: 0.362 | Acc: 87.536%
# Batch: 200/391 | Loss: 0.370 | Acc: 87.181%
# Batch: 250/391 | Loss: 0.370 | Acc: 87.313%
# Batch: 300/391 | Loss: 0.370 | Acc: 87.256%
# Batch: 350/391 | Loss: 0.371 | Acc: 87.184%
# Time taken : 1m290ms
# Batch: 0/100 | Loss: 0.540 | Acc: 83.000%
# Batch: 50/100 | Loss: 0.601 | Acc: 79.784%
# Saving..
#
# Epoch: 13
# Batch: 0/391 | Loss: 0.396 | Acc: 87.500%
# Batch: 50/391 | Loss: 0.338 | Acc: 88.725%
# Batch: 100/391 | Loss: 0.340 | Acc: 88.451%
# Batch: 150/391 | Loss: 0.347 | Acc: 88.105%
# Batch: 200/391 | Loss: 0.347 | Acc: 88.079%
# Batch: 250/391 | Loss: 0.346 | Acc: 88.141%
# Batch: 300/391 | Loss: 0.346 | Acc: 88.144%
# Batch: 350/391 | Loss: 0.346 | Acc: 88.076%
# Time taken : 1m687ms
# Batch: 0/100 | Loss: 0.472 | Acc: 83.000%
# Batch: 50/100 | Loss: 0.434 | Acc: 85.667%
# Saving..
#
# Epoch: 14
# Batch: 0/391 | Loss: 0.318 | Acc: 87.500%
# Batch: 50/391 | Loss: 0.328 | Acc: 88.680%
# Batch: 100/391 | Loss: 0.326 | Acc: 88.552%
# Batch: 150/391 | Loss: 0.326 | Acc: 88.643%
# Batch: 200/391 | Loss: 0.327 | Acc: 88.635%
# Batch: 250/391 | Loss: 0.332 | Acc: 88.434%
# Batch: 300/391 | Loss: 0.331 | Acc: 88.424%
# Batch: 350/391 | Loss: 0.332 | Acc: 88.384%
# Time taken : 1m1s
# Batch: 0/100 | Loss: 0.702 | Acc: 78.000%
# Batch: 50/100 | Loss: 0.790 | Acc: 77.235%
#
# Epoch: 15
# Batch: 0/391 | Loss: 0.454 | Acc: 85.156%
# Batch: 50/391 | Loss: 0.306 | Acc: 89.200%
# Batch: 100/391 | Loss: 0.301 | Acc: 89.442%
# Batch: 150/391 | Loss: 0.305 | Acc: 89.280%
# Batch: 200/391 | Loss: 0.306 | Acc: 89.358%
# Batch: 250/391 | Loss: 0.308 | Acc: 89.283%
# Batch: 300/391 | Loss: 0.309 | Acc: 89.117%
# Batch: 350/391 | Loss: 0.313 | Acc: 89.002%
# Time taken : 1m1s
# Batch: 0/100 | Loss: 0.638 | Acc: 83.000%
# Batch: 50/100 | Loss: 0.659 | Acc: 78.922%
#
# Epoch: 16
# Batch: 0/391 | Loss: 0.282 | Acc: 91.406%
# Batch: 50/391 | Loss: 0.296 | Acc: 89.721%
# Batch: 100/391 | Loss: 0.287 | Acc: 90.153%
# Batch: 150/391 | Loss: 0.287 | Acc: 90.087%
# Batch: 200/391 | Loss: 0.294 | Acc: 89.836%
# Batch: 250/391 | Loss: 0.298 | Acc: 89.679%
# Batch: 300/391 | Loss: 0.301 | Acc: 89.579%
# Batch: 350/391 | Loss: 0.299 | Acc: 89.675%
# Time taken : 1m828ms
# Batch: 0/100 | Loss: 0.584 | Acc: 80.000%
# Batch: 50/100 | Loss: 0.557 | Acc: 81.725%
#
# Epoch: 17
# Batch: 0/391 | Loss: 0.265 | Acc: 90.625%
# Batch: 50/391 | Loss: 0.285 | Acc: 90.058%
# Batch: 100/391 | Loss: 0.281 | Acc: 90.207%
# Batch: 150/391 | Loss: 0.281 | Acc: 90.325%
# Batch: 200/391 | Loss: 0.285 | Acc: 90.209%
# Batch: 250/391 | Loss: 0.285 | Acc: 90.158%
# Batch: 300/391 | Loss: 0.284 | Acc: 90.140%
# Batch: 350/391 | Loss: 0.285 | Acc: 90.106%
# Time taken : 1m82ms
# Batch: 0/100 | Loss: 0.619 | Acc: 81.000%
# Batch: 50/100 | Loss: 0.596 | Acc: 80.863%
#
# Epoch: 18
# Batch: 0/391 | Loss: 0.311 | Acc: 89.062%
# Batch: 50/391 | Loss: 0.273 | Acc: 90.610%
# Batch: 100/391 | Loss: 0.268 | Acc: 90.718%
# Batch: 150/391 | Loss: 0.272 | Acc: 90.641%
# Batch: 200/391 | Loss: 0.270 | Acc: 90.703%
# Batch: 250/391 | Loss: 0.272 | Acc: 90.588%
# Batch: 300/391 | Loss: 0.274 | Acc: 90.490%
# Batch: 350/391 | Loss: 0.273 | Acc: 90.483%
# Time taken : 1m735ms
# Batch: 0/100 | Loss: 0.520 | Acc: 85.000%
# Batch: 50/100 | Loss: 0.582 | Acc: 81.529%
#
# Epoch: 19
# Batch: 0/391 | Loss: 0.319 | Acc: 89.062%
# Batch: 50/391 | Loss: 0.254 | Acc: 91.085%
# Batch: 100/391 | Loss: 0.252 | Acc: 91.050%
# Batch: 150/391 | Loss: 0.251 | Acc: 91.220%
# Batch: 200/391 | Loss: 0.247 | Acc: 91.367%
# Batch: 250/391 | Loss: 0.255 | Acc: 91.036%
# Batch: 300/391 | Loss: 0.257 | Acc: 91.007%
# Batch: 350/391 | Loss: 0.260 | Acc: 90.941%
# Time taken : 1m383ms
# Batch: 0/100 | Loss: 0.444 | Acc: 85.000%
# Batch: 50/100 | Loss: 0.583 | Acc: 81.706%
#
# Epoch: 20
# Batch: 0/391 | Loss: 0.203 | Acc: 93.750%
# Batch: 50/391 | Loss: 0.242 | Acc: 91.728%
# Batch: 100/391 | Loss: 0.249 | Acc: 91.391%
# Batch: 150/391 | Loss: 0.247 | Acc: 91.401%
# Batch: 200/391 | Loss: 0.250 | Acc: 91.383%
# Batch: 250/391 | Loss: 0.250 | Acc: 91.447%
# Batch: 300/391 | Loss: 0.252 | Acc: 91.321%
# Batch: 350/391 | Loss: 0.251 | Acc: 91.313%
# Time taken : 1m909ms
# Batch: 0/100 | Loss: 0.514 | Acc: 85.000%
# Batch: 50/100 | Loss: 0.519 | Acc: 84.510%
#
# Epoch: 21
# Batch: 0/391 | Loss: 0.242 | Acc: 92.188%
# Batch: 50/391 | Loss: 0.233 | Acc: 91.881%
# Batch: 100/391 | Loss: 0.230 | Acc: 92.087%
# Batch: 150/391 | Loss: 0.232 | Acc: 92.131%
# Batch: 200/391 | Loss: 0.234 | Acc: 91.997%
# Batch: 250/391 | Loss: 0.236 | Acc: 91.826%
# Batch: 300/391 | Loss: 0.237 | Acc: 91.780%
# Batch: 350/391 | Loss: 0.237 | Acc: 91.736%
# Time taken : 1m1s
# Batch: 0/100 | Loss: 0.333 | Acc: 89.000%
# Batch: 50/100 | Loss: 0.447 | Acc: 85.412%
# Saving..
#
# Epoch: 22
# Batch: 0/391 | Loss: 0.207 | Acc: 92.969%
# Batch: 50/391 | Loss: 0.227 | Acc: 92.142%
# Batch: 100/391 | Loss: 0.224 | Acc: 92.265%
# Batch: 150/391 | Loss: 0.226 | Acc: 92.053%
# Batch: 200/391 | Loss: 0.228 | Acc: 91.912%
# Batch: 250/391 | Loss: 0.231 | Acc: 91.851%
# Batch: 300/391 | Loss: 0.231 | Acc: 91.886%
# Batch: 350/391 | Loss: 0.230 | Acc: 91.938%
# Time taken : 1m865ms
# Batch: 0/100 | Loss: 0.521 | Acc: 82.000%
# Batch: 50/100 | Loss: 0.641 | Acc: 80.627%
#
# Epoch: 23
# Batch: 0/391 | Loss: 0.316 | Acc: 87.500%
# Batch: 50/391 | Loss: 0.206 | Acc: 92.754%
# Batch: 100/391 | Loss: 0.206 | Acc: 92.860%
# Batch: 150/391 | Loss: 0.209 | Acc: 92.839%
# Batch: 200/391 | Loss: 0.209 | Acc: 92.798%
# Batch: 250/391 | Loss: 0.212 | Acc: 92.698%
# Batch: 300/391 | Loss: 0.212 | Acc: 92.631%
# Batch: 350/391 | Loss: 0.215 | Acc: 92.506%
# Time taken : 58s483ms
# Batch: 0/100 | Loss: 0.391 | Acc: 88.000%
# Batch: 50/100 | Loss: 0.444 | Acc: 85.882%
# Saving..
#
# Epoch: 24
# Batch: 0/391 | Loss: 0.244 | Acc: 92.188%
# Batch: 50/391 | Loss: 0.201 | Acc: 93.244%
# Batch: 100/391 | Loss: 0.200 | Acc: 93.193%
# Batch: 150/391 | Loss: 0.201 | Acc: 93.129%
# Batch: 200/391 | Loss: 0.204 | Acc: 92.957%
# Batch: 250/391 | Loss: 0.205 | Acc: 92.944%
# Batch: 300/391 | Loss: 0.207 | Acc: 92.893%
# Batch: 350/391 | Loss: 0.207 | Acc: 92.877%
# Time taken : 57s950ms
# Batch: 0/100 | Loss: 0.466 | Acc: 85.000%
# Batch: 50/100 | Loss: 0.522 | Acc: 83.686%
#
# Epoch: 25
# Batch: 0/391 | Loss: 0.207 | Acc: 90.625%
# Batch: 50/391 | Loss: 0.188 | Acc: 93.490%
# Batch: 100/391 | Loss: 0.191 | Acc: 93.386%
# Batch: 150/391 | Loss: 0.190 | Acc: 93.409%
# Batch: 200/391 | Loss: 0.193 | Acc: 93.299%
# Batch: 250/391 | Loss: 0.197 | Acc: 93.137%
# Batch: 300/391 | Loss: 0.199 | Acc: 93.041%
# Batch: 350/391 | Loss: 0.201 | Acc: 93.007%
# Time taken : 57s846ms
# Batch: 0/100 | Loss: 0.427 | Acc: 88.000%
# Batch: 50/100 | Loss: 0.485 | Acc: 84.647%
#
# Epoch: 26
# Batch: 0/391 | Loss: 0.151 | Acc: 96.094%
# Batch: 50/391 | Loss: 0.189 | Acc: 93.581%
# Batch: 100/391 | Loss: 0.186 | Acc: 93.619%
# Batch: 150/391 | Loss: 0.186 | Acc: 93.636%
# Batch: 200/391 | Loss: 0.186 | Acc: 93.664%
# Batch: 250/391 | Loss: 0.187 | Acc: 93.601%
# Batch: 300/391 | Loss: 0.189 | Acc: 93.532%
# Batch: 350/391 | Loss: 0.190 | Acc: 93.478%
# Time taken : 59s477ms
# Batch: 0/100 | Loss: 0.169 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.386 | Acc: 87.882%
# Saving..
#
# Epoch: 27
# Batch: 0/391 | Loss: 0.175 | Acc: 94.531%
# Batch: 50/391 | Loss: 0.176 | Acc: 93.949%
# Batch: 100/391 | Loss: 0.174 | Acc: 93.889%
# Batch: 150/391 | Loss: 0.176 | Acc: 93.776%
# Batch: 200/391 | Loss: 0.179 | Acc: 93.676%
# Batch: 250/391 | Loss: 0.181 | Acc: 93.629%
# Batch: 300/391 | Loss: 0.181 | Acc: 93.623%
# Batch: 350/391 | Loss: 0.181 | Acc: 93.614%
# Time taken : 57s957ms
# Batch: 0/100 | Loss: 0.296 | Acc: 91.000%
# Batch: 50/100 | Loss: 0.413 | Acc: 87.608%
#
# Epoch: 28
# Batch: 0/391 | Loss: 0.092 | Acc: 97.656%
# Batch: 50/391 | Loss: 0.176 | Acc: 93.888%
# Batch: 100/391 | Loss: 0.175 | Acc: 94.067%
# Batch: 150/391 | Loss: 0.170 | Acc: 94.154%
# Batch: 200/391 | Loss: 0.174 | Acc: 94.014%
# Batch: 250/391 | Loss: 0.175 | Acc: 93.974%
# Batch: 300/391 | Loss: 0.176 | Acc: 93.914%
# Batch: 350/391 | Loss: 0.178 | Acc: 93.859%
# Time taken : 58s490ms
# Batch: 0/100 | Loss: 0.372 | Acc: 88.000%
# Batch: 50/100 | Loss: 0.408 | Acc: 87.137%
#
# Epoch: 29
# Batch: 0/391 | Loss: 0.145 | Acc: 93.750%
# Batch: 50/391 | Loss: 0.150 | Acc: 95.021%
# Batch: 100/391 | Loss: 0.155 | Acc: 94.771%
# Batch: 150/391 | Loss: 0.158 | Acc: 94.640%
# Batch: 200/391 | Loss: 0.158 | Acc: 94.698%
# Batch: 250/391 | Loss: 0.163 | Acc: 94.463%
# Batch: 300/391 | Loss: 0.167 | Acc: 94.308%
# Batch: 350/391 | Loss: 0.168 | Acc: 94.286%
# Time taken : 58s386ms
# Batch: 0/100 | Loss: 0.203 | Acc: 92.000%
# Batch: 50/100 | Loss: 0.410 | Acc: 87.686%
#
# Epoch: 30
# Batch: 0/391 | Loss: 0.182 | Acc: 94.531%
# Batch: 50/391 | Loss: 0.152 | Acc: 94.608%
# Batch: 100/391 | Loss: 0.149 | Acc: 94.717%
# Batch: 150/391 | Loss: 0.150 | Acc: 94.692%
# Batch: 200/391 | Loss: 0.150 | Acc: 94.667%
# Batch: 250/391 | Loss: 0.153 | Acc: 94.603%
# Batch: 300/391 | Loss: 0.155 | Acc: 94.529%
# Batch: 350/391 | Loss: 0.157 | Acc: 94.451%
# Time taken : 59s97ms
# Batch: 0/100 | Loss: 0.533 | Acc: 83.000%
# Batch: 50/100 | Loss: 0.495 | Acc: 85.569%
#
# Epoch: 31
# Batch: 0/391 | Loss: 0.082 | Acc: 98.438%
# Batch: 50/391 | Loss: 0.152 | Acc: 94.669%
# Batch: 100/391 | Loss: 0.148 | Acc: 94.879%
# Batch: 150/391 | Loss: 0.149 | Acc: 94.857%
# Batch: 200/391 | Loss: 0.151 | Acc: 94.757%
# Batch: 250/391 | Loss: 0.152 | Acc: 94.749%
# Batch: 300/391 | Loss: 0.155 | Acc: 94.632%
# Batch: 350/391 | Loss: 0.155 | Acc: 94.667%
# Time taken : 59s288ms
# Batch: 0/100 | Loss: 0.358 | Acc: 90.000%
# Batch: 50/100 | Loss: 0.376 | Acc: 88.137%
# Saving..
#
# Epoch: 32
# Batch: 0/391 | Loss: 0.138 | Acc: 93.750%
# Batch: 50/391 | Loss: 0.143 | Acc: 94.960%
# Batch: 100/391 | Loss: 0.143 | Acc: 94.933%
# Batch: 150/391 | Loss: 0.145 | Acc: 94.873%
# Batch: 200/391 | Loss: 0.148 | Acc: 94.819%
# Batch: 250/391 | Loss: 0.146 | Acc: 94.867%
# Batch: 300/391 | Loss: 0.146 | Acc: 94.928%
# Batch: 350/391 | Loss: 0.146 | Acc: 94.939%
# Time taken : 58s313ms
# Batch: 0/100 | Loss: 0.300 | Acc: 91.000%
# Batch: 50/100 | Loss: 0.347 | Acc: 88.882%
# Saving..
#
# Epoch: 33
# Batch: 0/391 | Loss: 0.145 | Acc: 95.312%
# Batch: 50/391 | Loss: 0.136 | Acc: 95.297%
# Batch: 100/391 | Loss: 0.138 | Acc: 95.220%
# Batch: 150/391 | Loss: 0.140 | Acc: 95.121%
# Batch: 200/391 | Loss: 0.140 | Acc: 95.106%
# Batch: 250/391 | Loss: 0.140 | Acc: 95.166%
# Batch: 300/391 | Loss: 0.143 | Acc: 95.071%
# Batch: 350/391 | Loss: 0.143 | Acc: 95.094%
# Time taken : 58s186ms
# Batch: 0/100 | Loss: 0.283 | Acc: 91.000%
# Batch: 50/100 | Loss: 0.370 | Acc: 88.549%
#
# Epoch: 34
# Batch: 0/391 | Loss: 0.179 | Acc: 93.750%
# Batch: 50/391 | Loss: 0.115 | Acc: 96.232%
# Batch: 100/391 | Loss: 0.123 | Acc: 95.800%
# Batch: 150/391 | Loss: 0.124 | Acc: 95.851%
# Batch: 200/391 | Loss: 0.132 | Acc: 95.511%
# Batch: 250/391 | Loss: 0.131 | Acc: 95.562%
# Batch: 300/391 | Loss: 0.132 | Acc: 95.520%
# Batch: 350/391 | Loss: 0.132 | Acc: 95.517%
# Time taken : 58s257ms
# Batch: 0/100 | Loss: 0.567 | Acc: 80.000%
# Batch: 50/100 | Loss: 0.602 | Acc: 83.412%
#
# Epoch: 35
# Batch: 0/391 | Loss: 0.169 | Acc: 95.312%
# Batch: 50/391 | Loss: 0.122 | Acc: 95.650%
# Batch: 100/391 | Loss: 0.126 | Acc: 95.653%
# Batch: 150/391 | Loss: 0.125 | Acc: 95.618%
# Batch: 200/391 | Loss: 0.127 | Acc: 95.538%
# Batch: 250/391 | Loss: 0.130 | Acc: 95.387%
# Batch: 300/391 | Loss: 0.130 | Acc: 95.414%
# Batch: 350/391 | Loss: 0.132 | Acc: 95.337%
# Time taken : 59s469ms
# Batch: 0/100 | Loss: 0.275 | Acc: 93.000%
# Batch: 50/100 | Loss: 0.366 | Acc: 88.765%
#
# Epoch: 36
# Batch: 0/391 | Loss: 0.083 | Acc: 97.656%
# Batch: 50/391 | Loss: 0.118 | Acc: 95.879%
# Batch: 100/391 | Loss: 0.111 | Acc: 96.179%
# Batch: 150/391 | Loss: 0.114 | Acc: 96.026%
# Batch: 200/391 | Loss: 0.116 | Acc: 95.958%
# Batch: 250/391 | Loss: 0.118 | Acc: 95.860%
# Batch: 300/391 | Loss: 0.121 | Acc: 95.775%
# Batch: 350/391 | Loss: 0.122 | Acc: 95.795%
# Time taken : 58s674ms
# Batch: 0/100 | Loss: 0.237 | Acc: 93.000%
# Batch: 50/100 | Loss: 0.333 | Acc: 89.902%
# Saving..
#
# Epoch: 37
# Batch: 0/391 | Loss: 0.136 | Acc: 94.531%
# Batch: 50/391 | Loss: 0.124 | Acc: 95.741%
# Batch: 100/391 | Loss: 0.115 | Acc: 96.055%
# Batch: 150/391 | Loss: 0.116 | Acc: 95.995%
# Batch: 200/391 | Loss: 0.116 | Acc: 95.977%
# Batch: 250/391 | Loss: 0.117 | Acc: 95.913%
# Batch: 300/391 | Loss: 0.119 | Acc: 95.860%
# Batch: 350/391 | Loss: 0.121 | Acc: 95.791%
# Time taken : 58s781ms
# Batch: 0/100 | Loss: 0.198 | Acc: 90.000%
# Batch: 50/100 | Loss: 0.341 | Acc: 89.647%
# Saving..
#
# Epoch: 38
# Batch: 0/391 | Loss: 0.073 | Acc: 98.438%
# Batch: 50/391 | Loss: 0.097 | Acc: 96.798%
# Batch: 100/391 | Loss: 0.101 | Acc: 96.728%
# Batch: 150/391 | Loss: 0.104 | Acc: 96.575%
# Batch: 200/391 | Loss: 0.105 | Acc: 96.514%
# Batch: 250/391 | Loss: 0.106 | Acc: 96.461%
# Batch: 300/391 | Loss: 0.107 | Acc: 96.371%
# Batch: 350/391 | Loss: 0.108 | Acc: 96.350%
# Time taken : 58s825ms
# Batch: 0/100 | Loss: 0.231 | Acc: 90.000%
# Batch: 50/100 | Loss: 0.342 | Acc: 89.510%
#
# Epoch: 39
# Batch: 0/391 | Loss: 0.046 | Acc: 99.219%
# Batch: 50/391 | Loss: 0.096 | Acc: 97.013%
# Batch: 100/391 | Loss: 0.102 | Acc: 96.666%
# Batch: 150/391 | Loss: 0.104 | Acc: 96.596%
# Batch: 200/391 | Loss: 0.108 | Acc: 96.397%
# Batch: 250/391 | Loss: 0.109 | Acc: 96.330%
# Batch: 300/391 | Loss: 0.108 | Acc: 96.340%
# Batch: 350/391 | Loss: 0.109 | Acc: 96.299%
# Time taken : 59s630ms
# Batch: 0/100 | Loss: 0.268 | Acc: 87.000%
# Batch: 50/100 | Loss: 0.363 | Acc: 88.882%
#
# Epoch: 40
# Batch: 0/391 | Loss: 0.099 | Acc: 96.094%
# Batch: 50/391 | Loss: 0.097 | Acc: 96.691%
# Batch: 100/391 | Loss: 0.097 | Acc: 96.697%
# Batch: 150/391 | Loss: 0.100 | Acc: 96.534%
# Batch: 200/391 | Loss: 0.100 | Acc: 96.490%
# Batch: 250/391 | Loss: 0.101 | Acc: 96.473%
# Batch: 300/391 | Loss: 0.102 | Acc: 96.410%
# Batch: 350/391 | Loss: 0.103 | Acc: 96.410%
# Time taken : 58s29ms
# Batch: 0/100 | Loss: 0.193 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.317 | Acc: 90.157%
# Saving..
#
# Epoch: 41
# Batch: 0/391 | Loss: 0.041 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.080 | Acc: 97.457%
# Batch: 100/391 | Loss: 0.092 | Acc: 96.883%
# Batch: 150/391 | Loss: 0.095 | Acc: 96.756%
# Batch: 200/391 | Loss: 0.095 | Acc: 96.809%
# Batch: 250/391 | Loss: 0.097 | Acc: 96.750%
# Batch: 300/391 | Loss: 0.097 | Acc: 96.711%
# Batch: 350/391 | Loss: 0.098 | Acc: 96.668%
# Time taken : 58s894ms
# Batch: 0/100 | Loss: 0.364 | Acc: 87.000%
# Batch: 50/100 | Loss: 0.433 | Acc: 87.294%
#
# Epoch: 42
# Batch: 0/391 | Loss: 0.145 | Acc: 92.969%
# Batch: 50/391 | Loss: 0.095 | Acc: 96.507%
# Batch: 100/391 | Loss: 0.092 | Acc: 96.720%
# Batch: 150/391 | Loss: 0.091 | Acc: 96.834%
# Batch: 200/391 | Loss: 0.092 | Acc: 96.848%
# Batch: 250/391 | Loss: 0.091 | Acc: 96.875%
# Batch: 300/391 | Loss: 0.091 | Acc: 96.909%
# Batch: 350/391 | Loss: 0.091 | Acc: 96.913%
# Time taken : 58s122ms
# Batch: 0/100 | Loss: 0.286 | Acc: 90.000%
# Batch: 50/100 | Loss: 0.318 | Acc: 90.608%
# Saving..
#
# Epoch: 43
# Batch: 0/391 | Loss: 0.117 | Acc: 95.312%
# Batch: 50/391 | Loss: 0.090 | Acc: 96.982%
# Batch: 100/391 | Loss: 0.080 | Acc: 97.378%
# Batch: 150/391 | Loss: 0.082 | Acc: 97.227%
# Batch: 200/391 | Loss: 0.085 | Acc: 97.081%
# Batch: 250/391 | Loss: 0.085 | Acc: 97.136%
# Batch: 300/391 | Loss: 0.087 | Acc: 97.015%
# Batch: 350/391 | Loss: 0.087 | Acc: 97.046%
# Time taken : 57s499ms
# Batch: 0/100 | Loss: 0.288 | Acc: 90.000%
# Batch: 50/100 | Loss: 0.344 | Acc: 90.078%
#
# Epoch: 44
# Batch: 0/391 | Loss: 0.130 | Acc: 95.312%
# Batch: 50/391 | Loss: 0.081 | Acc: 97.273%
# Batch: 100/391 | Loss: 0.081 | Acc: 97.254%
# Batch: 150/391 | Loss: 0.083 | Acc: 97.227%
# Batch: 200/391 | Loss: 0.084 | Acc: 97.167%
# Batch: 250/391 | Loss: 0.085 | Acc: 97.143%
# Batch: 300/391 | Loss: 0.086 | Acc: 97.111%
# Batch: 350/391 | Loss: 0.087 | Acc: 97.033%
# Time taken : 1m675ms
# Batch: 0/100 | Loss: 0.307 | Acc: 89.000%
# Batch: 50/100 | Loss: 0.344 | Acc: 89.804%
#
# Epoch: 45
# Batch: 0/391 | Loss: 0.123 | Acc: 95.312%
# Batch: 50/391 | Loss: 0.085 | Acc: 97.059%
# Batch: 100/391 | Loss: 0.083 | Acc: 97.246%
# Batch: 150/391 | Loss: 0.082 | Acc: 97.304%
# Batch: 200/391 | Loss: 0.084 | Acc: 97.194%
# Batch: 250/391 | Loss: 0.084 | Acc: 97.202%
# Batch: 300/391 | Loss: 0.085 | Acc: 97.163%
# Batch: 350/391 | Loss: 0.085 | Acc: 97.178%
# Time taken : 58s176ms
# Batch: 0/100 | Loss: 0.303 | Acc: 90.000%
# Batch: 50/100 | Loss: 0.338 | Acc: 90.275%
#
# Epoch: 46
# Batch: 0/391 | Loss: 0.089 | Acc: 95.312%
# Batch: 50/391 | Loss: 0.075 | Acc: 97.549%
# Batch: 100/391 | Loss: 0.074 | Acc: 97.649%
# Batch: 150/391 | Loss: 0.073 | Acc: 97.698%
# Batch: 200/391 | Loss: 0.074 | Acc: 97.637%
# Batch: 250/391 | Loss: 0.075 | Acc: 97.566%
# Batch: 300/391 | Loss: 0.075 | Acc: 97.511%
# Batch: 350/391 | Loss: 0.075 | Acc: 97.549%
# Time taken : 1m491ms
# Batch: 0/100 | Loss: 0.220 | Acc: 90.000%
# Batch: 50/100 | Loss: 0.333 | Acc: 90.059%
#
# Epoch: 47
# Batch: 0/391 | Loss: 0.065 | Acc: 98.438%
# Batch: 50/391 | Loss: 0.064 | Acc: 97.978%
# Batch: 100/391 | Loss: 0.064 | Acc: 98.004%
# Batch: 150/391 | Loss: 0.066 | Acc: 97.910%
# Batch: 200/391 | Loss: 0.067 | Acc: 97.843%
# Batch: 250/391 | Loss: 0.068 | Acc: 97.824%
# Batch: 300/391 | Loss: 0.069 | Acc: 97.778%
# Batch: 350/391 | Loss: 0.070 | Acc: 97.730%
# Time taken : 59s576ms
# Batch: 0/100 | Loss: 0.306 | Acc: 92.000%
# Batch: 50/100 | Loss: 0.350 | Acc: 90.294%
#
# Epoch: 48
# Batch: 0/391 | Loss: 0.097 | Acc: 96.875%
# Batch: 50/391 | Loss: 0.066 | Acc: 97.718%
# Batch: 100/391 | Loss: 0.062 | Acc: 97.989%
# Batch: 150/391 | Loss: 0.062 | Acc: 98.039%
# Batch: 200/391 | Loss: 0.062 | Acc: 98.006%
# Batch: 250/391 | Loss: 0.064 | Acc: 97.977%
# Batch: 300/391 | Loss: 0.063 | Acc: 97.978%
# Batch: 350/391 | Loss: 0.064 | Acc: 97.952%
# Time taken : 59s134ms
# Batch: 0/100 | Loss: 0.254 | Acc: 91.000%
# Batch: 50/100 | Loss: 0.338 | Acc: 90.471%
#
# Epoch: 49
# Batch: 0/391 | Loss: 0.061 | Acc: 98.438%
# Batch: 50/391 | Loss: 0.064 | Acc: 98.100%
# Batch: 100/391 | Loss: 0.064 | Acc: 97.973%
# Batch: 150/391 | Loss: 0.063 | Acc: 98.060%
# Batch: 200/391 | Loss: 0.064 | Acc: 97.998%
# Batch: 250/391 | Loss: 0.064 | Acc: 97.936%
# Batch: 300/391 | Loss: 0.065 | Acc: 97.874%
# Batch: 350/391 | Loss: 0.067 | Acc: 97.783%
# Time taken : 57s502ms
# Batch: 0/100 | Loss: 0.333 | Acc: 92.000%
# Batch: 50/100 | Loss: 0.442 | Acc: 88.392%
#
# Epoch: 50
# Batch: 0/391 | Loss: 0.072 | Acc: 96.875%
# Batch: 50/391 | Loss: 0.056 | Acc: 98.039%
# Batch: 100/391 | Loss: 0.053 | Acc: 98.291%
# Batch: 150/391 | Loss: 0.056 | Acc: 98.158%
# Batch: 200/391 | Loss: 0.057 | Acc: 98.134%
# Batch: 250/391 | Loss: 0.058 | Acc: 98.123%
# Batch: 300/391 | Loss: 0.059 | Acc: 98.064%
# Batch: 350/391 | Loss: 0.060 | Acc: 98.006%
# Time taken : 58s784ms
# Batch: 0/100 | Loss: 0.198 | Acc: 96.000%
# Batch: 50/100 | Loss: 0.322 | Acc: 90.745%
# Saving..
#
# Epoch: 51
# Batch: 0/391 | Loss: 0.047 | Acc: 96.875%
# Batch: 50/391 | Loss: 0.053 | Acc: 98.376%
# Batch: 100/391 | Loss: 0.053 | Acc: 98.337%
# Batch: 150/391 | Loss: 0.054 | Acc: 98.339%
# Batch: 200/391 | Loss: 0.054 | Acc: 98.340%
# Batch: 250/391 | Loss: 0.054 | Acc: 98.338%
# Batch: 300/391 | Loss: 0.055 | Acc: 98.235%
# Batch: 350/391 | Loss: 0.055 | Acc: 98.235%
# Time taken : 58s527ms
# Batch: 0/100 | Loss: 0.202 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.318 | Acc: 91.255%
# Saving..
#
# Epoch: 52
# Batch: 0/391 | Loss: 0.020 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.047 | Acc: 98.575%
# Batch: 100/391 | Loss: 0.049 | Acc: 98.468%
# Batch: 150/391 | Loss: 0.050 | Acc: 98.417%
# Batch: 200/391 | Loss: 0.050 | Acc: 98.410%
# Batch: 250/391 | Loss: 0.051 | Acc: 98.366%
# Batch: 300/391 | Loss: 0.051 | Acc: 98.386%
# Batch: 350/391 | Loss: 0.052 | Acc: 98.335%
# Time taken : 58s623ms
# Batch: 0/100 | Loss: 0.199 | Acc: 93.000%
# Batch: 50/100 | Loss: 0.308 | Acc: 91.020%
# Saving..
#
# Epoch: 53
# Batch: 0/391 | Loss: 0.090 | Acc: 97.656%
# Batch: 50/391 | Loss: 0.047 | Acc: 98.575%
# Batch: 100/391 | Loss: 0.048 | Acc: 98.507%
# Batch: 150/391 | Loss: 0.048 | Acc: 98.520%
# Batch: 200/391 | Loss: 0.049 | Acc: 98.496%
# Batch: 250/391 | Loss: 0.051 | Acc: 98.403%
# Batch: 300/391 | Loss: 0.051 | Acc: 98.396%
# Batch: 350/391 | Loss: 0.052 | Acc: 98.402%
# Time taken : 59s108ms
# Batch: 0/100 | Loss: 0.200 | Acc: 96.000%
# Batch: 50/100 | Loss: 0.300 | Acc: 91.353%
# Saving..
#
# Epoch: 54
# Batch: 0/391 | Loss: 0.070 | Acc: 97.656%
# Batch: 50/391 | Loss: 0.046 | Acc: 98.499%
# Batch: 100/391 | Loss: 0.045 | Acc: 98.600%
# Batch: 150/391 | Loss: 0.047 | Acc: 98.541%
# Batch: 200/391 | Loss: 0.046 | Acc: 98.574%
# Batch: 250/391 | Loss: 0.047 | Acc: 98.556%
# Batch: 300/391 | Loss: 0.046 | Acc: 98.609%
# Batch: 350/391 | Loss: 0.047 | Acc: 98.549%
# Time taken : 1m398ms
# Batch: 0/100 | Loss: 0.337 | Acc: 92.000%
# Batch: 50/100 | Loss: 0.395 | Acc: 89.451%
#
# Epoch: 55
# Batch: 0/391 | Loss: 0.027 | Acc: 99.219%
# Batch: 50/391 | Loss: 0.042 | Acc: 98.683%
# Batch: 100/391 | Loss: 0.042 | Acc: 98.693%
# Batch: 150/391 | Loss: 0.043 | Acc: 98.681%
# Batch: 200/391 | Loss: 0.043 | Acc: 98.647%
# Batch: 250/391 | Loss: 0.043 | Acc: 98.640%
# Batch: 300/391 | Loss: 0.044 | Acc: 98.637%
# Batch: 350/391 | Loss: 0.046 | Acc: 98.549%
# Time taken : 59s
# Batch: 0/100 | Loss: 0.223 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.350 | Acc: 90.333%
#
# Epoch: 56
# Batch: 0/391 | Loss: 0.035 | Acc: 99.219%
# Batch: 50/391 | Loss: 0.035 | Acc: 99.081%
# Batch: 100/391 | Loss: 0.036 | Acc: 98.948%
# Batch: 150/391 | Loss: 0.038 | Acc: 98.903%
# Batch: 200/391 | Loss: 0.042 | Acc: 98.760%
# Batch: 250/391 | Loss: 0.041 | Acc: 98.795%
# Batch: 300/391 | Loss: 0.042 | Acc: 98.775%
# Batch: 350/391 | Loss: 0.042 | Acc: 98.776%
# Time taken : 58s314ms
# Batch: 0/100 | Loss: 0.305 | Acc: 93.000%
# Batch: 50/100 | Loss: 0.327 | Acc: 91.098%
#
# Epoch: 57
# Batch: 0/391 | Loss: 0.048 | Acc: 98.438%
# Batch: 50/391 | Loss: 0.039 | Acc: 98.958%
# Batch: 100/391 | Loss: 0.039 | Acc: 98.863%
# Batch: 150/391 | Loss: 0.038 | Acc: 98.888%
# Batch: 200/391 | Loss: 0.038 | Acc: 98.892%
# Batch: 250/391 | Loss: 0.038 | Acc: 98.886%
# Batch: 300/391 | Loss: 0.037 | Acc: 98.938%
# Batch: 350/391 | Loss: 0.038 | Acc: 98.900%
# Time taken : 58s459ms
# Batch: 0/100 | Loss: 0.269 | Acc: 93.000%
# Batch: 50/100 | Loss: 0.314 | Acc: 91.373%
#
# Epoch: 58
# Batch: 0/391 | Loss: 0.029 | Acc: 99.219%
# Batch: 50/391 | Loss: 0.035 | Acc: 99.035%
# Batch: 100/391 | Loss: 0.033 | Acc: 99.157%
# Batch: 150/391 | Loss: 0.034 | Acc: 99.120%
# Batch: 200/391 | Loss: 0.034 | Acc: 99.087%
# Batch: 250/391 | Loss: 0.035 | Acc: 99.038%
# Batch: 300/391 | Loss: 0.035 | Acc: 99.040%
# Batch: 350/391 | Loss: 0.035 | Acc: 99.014%
# Time taken : 59s185ms
# Batch: 0/100 | Loss: 0.269 | Acc: 92.000%
# Batch: 50/100 | Loss: 0.319 | Acc: 91.255%
#
# Epoch: 59
# Batch: 0/391 | Loss: 0.018 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.034 | Acc: 99.020%
# Batch: 100/391 | Loss: 0.032 | Acc: 99.118%
# Batch: 150/391 | Loss: 0.032 | Acc: 99.110%
# Batch: 200/391 | Loss: 0.032 | Acc: 99.133%
# Batch: 250/391 | Loss: 0.033 | Acc: 99.100%
# Batch: 300/391 | Loss: 0.034 | Acc: 99.029%
# Batch: 350/391 | Loss: 0.034 | Acc: 99.030%
# Time taken : 57s910ms
# Batch: 0/100 | Loss: 0.226 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.336 | Acc: 91.333%
#
# Epoch: 60
# Batch: 0/391 | Loss: 0.041 | Acc: 98.438%
# Batch: 50/391 | Loss: 0.033 | Acc: 99.081%
# Batch: 100/391 | Loss: 0.032 | Acc: 99.103%
# Batch: 150/391 | Loss: 0.031 | Acc: 99.089%
# Batch: 200/391 | Loss: 0.030 | Acc: 99.129%
# Batch: 250/391 | Loss: 0.031 | Acc: 99.113%
# Batch: 300/391 | Loss: 0.032 | Acc: 99.071%
# Batch: 350/391 | Loss: 0.032 | Acc: 99.050%
# Time taken : 58s919ms
# Batch: 0/100 | Loss: 0.161 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.312 | Acc: 91.490%
#
# Epoch: 61
# Batch: 0/391 | Loss: 0.047 | Acc: 99.219%
# Batch: 50/391 | Loss: 0.026 | Acc: 99.341%
# Batch: 100/391 | Loss: 0.028 | Acc: 99.304%
# Batch: 150/391 | Loss: 0.028 | Acc: 99.291%
# Batch: 200/391 | Loss: 0.027 | Acc: 99.296%
# Batch: 250/391 | Loss: 0.029 | Acc: 99.231%
# Batch: 300/391 | Loss: 0.029 | Acc: 99.242%
# Batch: 350/391 | Loss: 0.030 | Acc: 99.205%
# Time taken : 57s820ms
# Batch: 0/100 | Loss: 0.261 | Acc: 92.000%
# Batch: 50/100 | Loss: 0.333 | Acc: 91.431%
#
# Epoch: 62
# Batch: 0/391 | Loss: 0.038 | Acc: 99.219%
# Batch: 50/391 | Loss: 0.030 | Acc: 99.004%
# Batch: 100/391 | Loss: 0.028 | Acc: 99.196%
# Batch: 150/391 | Loss: 0.027 | Acc: 99.265%
# Batch: 200/391 | Loss: 0.027 | Acc: 99.258%
# Batch: 250/391 | Loss: 0.027 | Acc: 99.284%
# Batch: 300/391 | Loss: 0.027 | Acc: 99.268%
# Batch: 350/391 | Loss: 0.027 | Acc: 99.272%
# Time taken : 59s312ms
# Batch: 0/100 | Loss: 0.221 | Acc: 93.000%
# Batch: 50/100 | Loss: 0.305 | Acc: 91.843%
# Saving..
#
# Epoch: 63
# Batch: 0/391 | Loss: 0.026 | Acc: 99.219%
# Batch: 50/391 | Loss: 0.024 | Acc: 99.311%
# Batch: 100/391 | Loss: 0.022 | Acc: 99.381%
# Batch: 150/391 | Loss: 0.023 | Acc: 99.405%
# Batch: 200/391 | Loss: 0.023 | Acc: 99.386%
# Batch: 250/391 | Loss: 0.023 | Acc: 99.384%
# Batch: 300/391 | Loss: 0.024 | Acc: 99.390%
# Batch: 350/391 | Loss: 0.024 | Acc: 99.370%
# Time taken : 58s944ms
# Batch: 0/100 | Loss: 0.175 | Acc: 96.000%
# Batch: 50/100 | Loss: 0.285 | Acc: 92.333%
# Saving..
#
# Epoch: 64
# Batch: 0/391 | Loss: 0.028 | Acc: 99.219%
# Batch: 50/391 | Loss: 0.020 | Acc: 99.617%
# Batch: 100/391 | Loss: 0.021 | Acc: 99.513%
# Batch: 150/391 | Loss: 0.021 | Acc: 99.514%
# Batch: 200/391 | Loss: 0.022 | Acc: 99.522%
# Batch: 250/391 | Loss: 0.022 | Acc: 99.514%
# Batch: 300/391 | Loss: 0.022 | Acc: 99.509%
# Batch: 350/391 | Loss: 0.022 | Acc: 99.517%
# Time taken : 1m1s
# Batch: 0/100 | Loss: 0.233 | Acc: 92.000%
# Batch: 50/100 | Loss: 0.296 | Acc: 91.667%
#
# Epoch: 65
# Batch: 0/391 | Loss: 0.010 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.021 | Acc: 99.556%
# Batch: 100/391 | Loss: 0.021 | Acc: 99.551%
# Batch: 150/391 | Loss: 0.022 | Acc: 99.508%
# Batch: 200/391 | Loss: 0.022 | Acc: 99.487%
# Batch: 250/391 | Loss: 0.022 | Acc: 99.493%
# Batch: 300/391 | Loss: 0.021 | Acc: 99.496%
# Batch: 350/391 | Loss: 0.021 | Acc: 99.481%
# Time taken : 1m1s
# Batch: 0/100 | Loss: 0.235 | Acc: 96.000%
# Batch: 50/100 | Loss: 0.308 | Acc: 91.961%
#
# Epoch: 66
# Batch: 0/391 | Loss: 0.015 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.019 | Acc: 99.510%
# Batch: 100/391 | Loss: 0.020 | Acc: 99.544%
# Batch: 150/391 | Loss: 0.019 | Acc: 99.571%
# Batch: 200/391 | Loss: 0.019 | Acc: 99.572%
# Batch: 250/391 | Loss: 0.018 | Acc: 99.614%
# Batch: 300/391 | Loss: 0.018 | Acc: 99.611%
# Batch: 350/391 | Loss: 0.019 | Acc: 99.577%
# Time taken : 1m1s
# Batch: 0/100 | Loss: 0.175 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.279 | Acc: 92.412%
# Saving..
#
# Epoch: 67
# Batch: 0/391 | Loss: 0.023 | Acc: 99.219%
# Batch: 50/391 | Loss: 0.016 | Acc: 99.632%
# Batch: 100/391 | Loss: 0.016 | Acc: 99.636%
# Batch: 150/391 | Loss: 0.016 | Acc: 99.627%
# Batch: 200/391 | Loss: 0.017 | Acc: 99.646%
# Batch: 250/391 | Loss: 0.016 | Acc: 99.651%
# Batch: 300/391 | Loss: 0.017 | Acc: 99.639%
# Batch: 350/391 | Loss: 0.017 | Acc: 99.653%
# Time taken : 1m443ms
# Batch: 0/100 | Loss: 0.235 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.295 | Acc: 91.961%
#
# Epoch: 68
# Batch: 0/391 | Loss: 0.024 | Acc: 99.219%
# Batch: 50/391 | Loss: 0.019 | Acc: 99.494%
# Batch: 100/391 | Loss: 0.018 | Acc: 99.598%
# Batch: 150/391 | Loss: 0.017 | Acc: 99.622%
# Batch: 200/391 | Loss: 0.017 | Acc: 99.650%
# Batch: 250/391 | Loss: 0.017 | Acc: 99.664%
# Batch: 300/391 | Loss: 0.016 | Acc: 99.678%
# Batch: 350/391 | Loss: 0.016 | Acc: 99.688%
# Time taken : 1m543ms
# Batch: 0/100 | Loss: 0.205 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.289 | Acc: 92.176%
#
# Epoch: 69
# Batch: 0/391 | Loss: 0.010 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.017 | Acc: 99.648%
# Batch: 100/391 | Loss: 0.016 | Acc: 99.691%
# Batch: 150/391 | Loss: 0.015 | Acc: 99.710%
# Batch: 200/391 | Loss: 0.015 | Acc: 99.720%
# Batch: 250/391 | Loss: 0.015 | Acc: 99.723%
# Batch: 300/391 | Loss: 0.014 | Acc: 99.735%
# Batch: 350/391 | Loss: 0.014 | Acc: 99.740%
# Time taken : 1m533ms
# Batch: 0/100 | Loss: 0.229 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.286 | Acc: 92.333%
#
# Epoch: 70
# Batch: 0/391 | Loss: 0.006 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.011 | Acc: 99.908%
# Batch: 100/391 | Loss: 0.012 | Acc: 99.838%
# Batch: 150/391 | Loss: 0.011 | Acc: 99.840%
# Batch: 200/391 | Loss: 0.012 | Acc: 99.790%
# Batch: 250/391 | Loss: 0.013 | Acc: 99.782%
# Batch: 300/391 | Loss: 0.013 | Acc: 99.785%
# Batch: 350/391 | Loss: 0.013 | Acc: 99.769%
# Time taken : 1m2s
# Batch: 0/100 | Loss: 0.275 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.285 | Acc: 92.353%
# Saving..
#
# Epoch: 71
# Batch: 0/391 | Loss: 0.009 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.014 | Acc: 99.801%
# Batch: 100/391 | Loss: 0.013 | Acc: 99.783%
# Batch: 150/391 | Loss: 0.013 | Acc: 99.762%
# Batch: 200/391 | Loss: 0.013 | Acc: 99.767%
# Batch: 250/391 | Loss: 0.013 | Acc: 99.779%
# Batch: 300/391 | Loss: 0.013 | Acc: 99.769%
# Batch: 350/391 | Loss: 0.013 | Acc: 99.755%
# Time taken : 1m948ms
# Batch: 0/100 | Loss: 0.189 | Acc: 96.000%
# Batch: 50/100 | Loss: 0.283 | Acc: 92.333%
#
# Epoch: 72
# Batch: 0/391 | Loss: 0.011 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.013 | Acc: 99.740%
# Batch: 100/391 | Loss: 0.012 | Acc: 99.807%
# Batch: 150/391 | Loss: 0.012 | Acc: 99.772%
# Batch: 200/391 | Loss: 0.012 | Acc: 99.771%
# Batch: 250/391 | Loss: 0.013 | Acc: 99.763%
# Batch: 300/391 | Loss: 0.013 | Acc: 99.779%
# Batch: 350/391 | Loss: 0.013 | Acc: 99.773%
# Time taken : 1m628ms
# Batch: 0/100 | Loss: 0.207 | Acc: 96.000%
# Batch: 50/100 | Loss: 0.284 | Acc: 92.686%
#
# Epoch: 73
# Batch: 0/391 | Loss: 0.004 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.011 | Acc: 99.786%
# Batch: 100/391 | Loss: 0.012 | Acc: 99.745%
# Batch: 150/391 | Loss: 0.011 | Acc: 99.788%
# Batch: 200/391 | Loss: 0.012 | Acc: 99.786%
# Batch: 250/391 | Loss: 0.012 | Acc: 99.807%
# Batch: 300/391 | Loss: 0.012 | Acc: 99.808%
# Batch: 350/391 | Loss: 0.011 | Acc: 99.817%
# Time taken : 1m747ms
# Batch: 0/100 | Loss: 0.241 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.277 | Acc: 92.686%
# Saving..
#
# Epoch: 74
# Batch: 0/391 | Loss: 0.005 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.010 | Acc: 99.877%
# Batch: 100/391 | Loss: 0.011 | Acc: 99.830%
# Batch: 150/391 | Loss: 0.011 | Acc: 99.809%
# Batch: 200/391 | Loss: 0.011 | Acc: 99.817%
# Batch: 250/391 | Loss: 0.011 | Acc: 99.810%
# Batch: 300/391 | Loss: 0.011 | Acc: 99.808%
# Batch: 350/391 | Loss: 0.011 | Acc: 99.817%
# Time taken : 59s383ms
# Batch: 0/100 | Loss: 0.242 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.269 | Acc: 92.843%
# Saving..
#
# Epoch: 75
# Batch: 0/391 | Loss: 0.012 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.011 | Acc: 99.877%
# Batch: 100/391 | Loss: 0.010 | Acc: 99.876%
# Batch: 150/391 | Loss: 0.011 | Acc: 99.845%
# Batch: 200/391 | Loss: 0.011 | Acc: 99.825%
# Batch: 250/391 | Loss: 0.011 | Acc: 99.819%
# Batch: 300/391 | Loss: 0.011 | Acc: 99.816%
# Batch: 350/391 | Loss: 0.011 | Acc: 99.809%
# Time taken : 1m1s
# Batch: 0/100 | Loss: 0.240 | Acc: 93.000%
# Batch: 50/100 | Loss: 0.284 | Acc: 92.627%
#
# Epoch: 76
# Batch: 0/391 | Loss: 0.006 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.009 | Acc: 99.923%
# Batch: 100/391 | Loss: 0.010 | Acc: 99.853%
# Batch: 150/391 | Loss: 0.009 | Acc: 99.855%
# Batch: 200/391 | Loss: 0.010 | Acc: 99.856%
# Batch: 250/391 | Loss: 0.010 | Acc: 99.847%
# Batch: 300/391 | Loss: 0.010 | Acc: 99.847%
# Batch: 350/391 | Loss: 0.010 | Acc: 99.849%
# Time taken : 1m616ms
# Batch: 0/100 | Loss: 0.237 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.275 | Acc: 92.686%
#
# Epoch: 77
# Batch: 0/391 | Loss: 0.006 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.008 | Acc: 99.923%
# Batch: 100/391 | Loss: 0.010 | Acc: 99.853%
# Batch: 150/391 | Loss: 0.009 | Acc: 99.865%
# Batch: 200/391 | Loss: 0.009 | Acc: 99.864%
# Batch: 250/391 | Loss: 0.010 | Acc: 99.851%
# Batch: 300/391 | Loss: 0.009 | Acc: 99.860%
# Batch: 350/391 | Loss: 0.009 | Acc: 99.869%
# Time taken : 59s61ms
# Batch: 0/100 | Loss: 0.261 | Acc: 93.000%
# Batch: 50/100 | Loss: 0.275 | Acc: 92.627%
#
# Epoch: 78
# Batch: 0/391 | Loss: 0.005 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.009 | Acc: 99.893%
# Batch: 100/391 | Loss: 0.009 | Acc: 99.915%
# Batch: 150/391 | Loss: 0.008 | Acc: 99.917%
# Batch: 200/391 | Loss: 0.008 | Acc: 99.914%
# Batch: 250/391 | Loss: 0.008 | Acc: 99.907%
# Batch: 300/391 | Loss: 0.008 | Acc: 99.901%
# Batch: 350/391 | Loss: 0.009 | Acc: 99.900%
# Time taken : 59s935ms
# Batch: 0/100 | Loss: 0.268 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.299 | Acc: 92.471%
#
# Epoch: 79
# Batch: 0/391 | Loss: 0.026 | Acc: 99.219%
# Batch: 50/391 | Loss: 0.010 | Acc: 99.831%
# Batch: 100/391 | Loss: 0.010 | Acc: 99.845%
# Batch: 150/391 | Loss: 0.009 | Acc: 99.845%
# Batch: 200/391 | Loss: 0.009 | Acc: 99.837%
# Batch: 250/391 | Loss: 0.009 | Acc: 99.851%
# Batch: 300/391 | Loss: 0.009 | Acc: 99.860%
# Batch: 350/391 | Loss: 0.009 | Acc: 99.869%
# Time taken : 59s409ms
# Batch: 0/100 | Loss: 0.217 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.270 | Acc: 92.824%
#
# Epoch: 80
# Batch: 0/391 | Loss: 0.009 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.009 | Acc: 99.847%
# Batch: 100/391 | Loss: 0.009 | Acc: 99.861%
# Batch: 150/391 | Loss: 0.008 | Acc: 99.907%
# Batch: 200/391 | Loss: 0.008 | Acc: 99.911%
# Batch: 250/391 | Loss: 0.008 | Acc: 99.904%
# Batch: 300/391 | Loss: 0.008 | Acc: 99.904%
# Batch: 350/391 | Loss: 0.008 | Acc: 99.911%
# Time taken : 59s347ms
# Batch: 0/100 | Loss: 0.219 | Acc: 93.000%
# Batch: 50/100 | Loss: 0.272 | Acc: 92.824%
# Saving..
#
# Epoch: 81
# Batch: 0/391 | Loss: 0.009 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.007 | Acc: 99.908%
# Batch: 100/391 | Loss: 0.007 | Acc: 99.938%
# Batch: 150/391 | Loss: 0.007 | Acc: 99.938%
# Batch: 200/391 | Loss: 0.007 | Acc: 99.934%
# Batch: 250/391 | Loss: 0.007 | Acc: 99.938%
# Batch: 300/391 | Loss: 0.007 | Acc: 99.938%
# Batch: 350/391 | Loss: 0.007 | Acc: 99.938%
# Time taken : 1m218ms
# Batch: 0/100 | Loss: 0.243 | Acc: 92.000%
# Batch: 50/100 | Loss: 0.272 | Acc: 92.549%
#
# Epoch: 82
# Batch: 0/391 | Loss: 0.008 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.007 | Acc: 99.969%
# Batch: 100/391 | Loss: 0.007 | Acc: 99.938%
# Batch: 150/391 | Loss: 0.007 | Acc: 99.917%
# Batch: 200/391 | Loss: 0.008 | Acc: 99.918%
# Batch: 250/391 | Loss: 0.008 | Acc: 99.922%
# Batch: 300/391 | Loss: 0.008 | Acc: 99.927%
# Batch: 350/391 | Loss: 0.007 | Acc: 99.931%
# Time taken : 59s31ms
# Batch: 0/100 | Loss: 0.220 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.274 | Acc: 92.490%
#
# Epoch: 83
# Batch: 0/391 | Loss: 0.005 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.008 | Acc: 99.939%
# Batch: 100/391 | Loss: 0.008 | Acc: 99.923%
# Batch: 150/391 | Loss: 0.008 | Acc: 99.922%
# Batch: 200/391 | Loss: 0.008 | Acc: 99.926%
# Batch: 250/391 | Loss: 0.007 | Acc: 99.932%
# Batch: 300/391 | Loss: 0.007 | Acc: 99.933%
# Batch: 350/391 | Loss: 0.007 | Acc: 99.929%
# Time taken : 59s813ms
# Batch: 0/100 | Loss: 0.239 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.280 | Acc: 92.784%
#
# Epoch: 84
# Batch: 0/391 | Loss: 0.006 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.007 | Acc: 99.939%
# Batch: 100/391 | Loss: 0.007 | Acc: 99.930%
# Batch: 150/391 | Loss: 0.007 | Acc: 99.928%
# Batch: 200/391 | Loss: 0.007 | Acc: 99.938%
# Batch: 250/391 | Loss: 0.007 | Acc: 99.935%
# Batch: 300/391 | Loss: 0.007 | Acc: 99.935%
# Batch: 350/391 | Loss: 0.007 | Acc: 99.931%
# Time taken : 1m452ms
# Batch: 0/100 | Loss: 0.224 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.273 | Acc: 92.686%
#
# Epoch: 85
# Batch: 0/391 | Loss: 0.004 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.007 | Acc: 99.908%
# Batch: 100/391 | Loss: 0.007 | Acc: 99.915%
# Batch: 150/391 | Loss: 0.007 | Acc: 99.917%
# Batch: 200/391 | Loss: 0.007 | Acc: 99.914%
# Batch: 250/391 | Loss: 0.007 | Acc: 99.928%
# Batch: 300/391 | Loss: 0.007 | Acc: 99.920%
# Batch: 350/391 | Loss: 0.007 | Acc: 99.920%
# Time taken : 59s773ms
# Batch: 0/100 | Loss: 0.219 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.271 | Acc: 92.706%
#
# Epoch: 86
# Batch: 0/391 | Loss: 0.007 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.006 | Acc: 99.969%
# Batch: 100/391 | Loss: 0.006 | Acc: 99.946%
# Batch: 150/391 | Loss: 0.006 | Acc: 99.948%
# Batch: 200/391 | Loss: 0.006 | Acc: 99.942%
# Batch: 250/391 | Loss: 0.006 | Acc: 99.944%
# Batch: 300/391 | Loss: 0.006 | Acc: 99.945%
# Batch: 350/391 | Loss: 0.007 | Acc: 99.947%
# Time taken : 58s799ms
# Batch: 0/100 | Loss: 0.220 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.272 | Acc: 92.706%
#
# Epoch: 87
# Batch: 0/391 | Loss: 0.022 | Acc: 98.438%
# Batch: 50/391 | Loss: 0.006 | Acc: 99.969%
# Batch: 100/391 | Loss: 0.006 | Acc: 99.954%
# Batch: 150/391 | Loss: 0.006 | Acc: 99.943%
# Batch: 200/391 | Loss: 0.007 | Acc: 99.934%
# Batch: 250/391 | Loss: 0.007 | Acc: 99.928%
# Batch: 300/391 | Loss: 0.007 | Acc: 99.935%
# Batch: 350/391 | Loss: 0.007 | Acc: 99.940%
# Time taken : 59s231ms
# Batch: 0/100 | Loss: 0.224 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.272 | Acc: 92.902%
#
# Epoch: 88
# Batch: 0/391 | Loss: 0.007 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.007 | Acc: 99.939%
# Batch: 100/391 | Loss: 0.006 | Acc: 99.954%
# Batch: 150/391 | Loss: 0.006 | Acc: 99.964%
# Batch: 200/391 | Loss: 0.006 | Acc: 99.949%
# Batch: 250/391 | Loss: 0.006 | Acc: 99.944%
# Batch: 300/391 | Loss: 0.006 | Acc: 99.938%
# Batch: 350/391 | Loss: 0.006 | Acc: 99.942%
# Time taken : 59s795ms
# Batch: 0/100 | Loss: 0.216 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.268 | Acc: 92.980%
# Saving..
#
# Epoch: 89
# Batch: 0/391 | Loss: 0.004 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.005 | Acc: 99.985%
# Batch: 100/391 | Loss: 0.006 | Acc: 99.946%
# Batch: 150/391 | Loss: 0.006 | Acc: 99.933%
# Batch: 200/391 | Loss: 0.006 | Acc: 99.934%
# Batch: 250/391 | Loss: 0.006 | Acc: 99.944%
# Batch: 300/391 | Loss: 0.006 | Acc: 99.953%
# Batch: 350/391 | Loss: 0.006 | Acc: 99.955%
# Time taken : 59s106ms
# Batch: 0/100 | Loss: 0.225 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.271 | Acc: 92.725%
#
# Epoch: 90
# Batch: 0/391 | Loss: 0.006 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.006 | Acc: 99.954%
# Batch: 100/391 | Loss: 0.006 | Acc: 99.969%
# Batch: 150/391 | Loss: 0.006 | Acc: 99.948%
# Batch: 200/391 | Loss: 0.006 | Acc: 99.953%
# Batch: 250/391 | Loss: 0.006 | Acc: 99.956%
# Batch: 300/391 | Loss: 0.006 | Acc: 99.961%
# Batch: 350/391 | Loss: 0.006 | Acc: 99.964%
# Time taken : 59s53ms
# Batch: 0/100 | Loss: 0.225 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.274 | Acc: 92.569%
#
# Epoch: 91
# Batch: 0/391 | Loss: 0.027 | Acc: 99.219%
# Batch: 50/391 | Loss: 0.006 | Acc: 99.939%
# Batch: 100/391 | Loss: 0.006 | Acc: 99.969%
# Batch: 150/391 | Loss: 0.006 | Acc: 99.974%
# Batch: 200/391 | Loss: 0.006 | Acc: 99.969%
# Batch: 250/391 | Loss: 0.006 | Acc: 99.966%
# Batch: 300/391 | Loss: 0.006 | Acc: 99.961%
# Batch: 350/391 | Loss: 0.006 | Acc: 99.960%
# Time taken : 59s492ms
# Batch: 0/100 | Loss: 0.247 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.273 | Acc: 92.706%
#
# Epoch: 92
# Batch: 0/391 | Loss: 0.007 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.006 | Acc: 100.000%
# Batch: 100/391 | Loss: 0.005 | Acc: 100.000%
# Batch: 150/391 | Loss: 0.006 | Acc: 99.979%
# Batch: 200/391 | Loss: 0.006 | Acc: 99.969%
# Batch: 250/391 | Loss: 0.006 | Acc: 99.969%
# Batch: 300/391 | Loss: 0.006 | Acc: 99.958%
# Batch: 350/391 | Loss: 0.006 | Acc: 99.953%
# Time taken : 59s874ms
# Batch: 0/100 | Loss: 0.254 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.268 | Acc: 92.667%
#
# Epoch: 93
# Batch: 0/391 | Loss: 0.005 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.006 | Acc: 99.923%
# Batch: 100/391 | Loss: 0.006 | Acc: 99.946%
# Batch: 150/391 | Loss: 0.006 | Acc: 99.964%
# Batch: 200/391 | Loss: 0.006 | Acc: 99.965%
# Batch: 250/391 | Loss: 0.006 | Acc: 99.960%
# Batch: 300/391 | Loss: 0.006 | Acc: 99.956%
# Batch: 350/391 | Loss: 0.006 | Acc: 99.958%
# Time taken : 59s268ms
# Batch: 0/100 | Loss: 0.253 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.271 | Acc: 92.843%
#
# Epoch: 94
# Batch: 0/391 | Loss: 0.003 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.005 | Acc: 100.000%
# Batch: 100/391 | Loss: 0.006 | Acc: 99.961%
# Batch: 150/391 | Loss: 0.006 | Acc: 99.964%
# Batch: 200/391 | Loss: 0.006 | Acc: 99.961%
# Batch: 250/391 | Loss: 0.006 | Acc: 99.966%
# Batch: 300/391 | Loss: 0.005 | Acc: 99.971%
# Batch: 350/391 | Loss: 0.005 | Acc: 99.973%
# Time taken : 59s121ms
# Batch: 0/100 | Loss: 0.232 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.269 | Acc: 92.843%
#
# Epoch: 95
# Batch: 0/391 | Loss: 0.005 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.005 | Acc: 99.985%
# Batch: 100/391 | Loss: 0.006 | Acc: 99.961%
# Batch: 150/391 | Loss: 0.006 | Acc: 99.959%
# Batch: 200/391 | Loss: 0.006 | Acc: 99.946%
# Batch: 250/391 | Loss: 0.006 | Acc: 99.950%
# Batch: 300/391 | Loss: 0.006 | Acc: 99.953%
# Batch: 350/391 | Loss: 0.006 | Acc: 99.958%
# Time taken : 1m43ms
# Batch: 0/100 | Loss: 0.247 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.269 | Acc: 92.863%
#
# Epoch: 96
# Batch: 0/391 | Loss: 0.009 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.005 | Acc: 99.954%
# Batch: 100/391 | Loss: 0.005 | Acc: 99.961%
# Batch: 150/391 | Loss: 0.006 | Acc: 99.943%
# Batch: 200/391 | Loss: 0.006 | Acc: 99.953%
# Batch: 250/391 | Loss: 0.006 | Acc: 99.956%
# Batch: 300/391 | Loss: 0.005 | Acc: 99.956%
# Batch: 350/391 | Loss: 0.006 | Acc: 99.958%
# Time taken : 59s670ms
# Batch: 0/100 | Loss: 0.249 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.269 | Acc: 92.882%
#
# Epoch: 97
# Batch: 0/391 | Loss: 0.002 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.005 | Acc: 99.985%
# Batch: 100/391 | Loss: 0.006 | Acc: 99.969%
# Batch: 150/391 | Loss: 0.006 | Acc: 99.959%
# Batch: 200/391 | Loss: 0.005 | Acc: 99.965%
# Batch: 250/391 | Loss: 0.006 | Acc: 99.969%
# Batch: 300/391 | Loss: 0.006 | Acc: 99.969%
# Batch: 350/391 | Loss: 0.006 | Acc: 99.967%
# Time taken : 59s499ms
# Batch: 0/100 | Loss: 0.248 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.268 | Acc: 92.980%
# Saving..
#
# Epoch: 98
# Batch: 0/391 | Loss: 0.002 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.005 | Acc: 99.939%
# Batch: 100/391 | Loss: 0.005 | Acc: 99.954%
# Batch: 150/391 | Loss: 0.005 | Acc: 99.943%
# Batch: 200/391 | Loss: 0.005 | Acc: 99.946%
# Batch: 250/391 | Loss: 0.005 | Acc: 99.956%
# Batch: 300/391 | Loss: 0.005 | Acc: 99.956%
# Batch: 350/391 | Loss: 0.005 | Acc: 99.958%
# Time taken : 59s774ms
# Batch: 0/100 | Loss: 0.253 | Acc: 96.000%
# Batch: 50/100 | Loss: 0.269 | Acc: 92.824%
#
# Epoch: 99
# Batch: 0/391 | Loss: 0.005 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.007 | Acc: 99.923%
# Batch: 100/391 | Loss: 0.006 | Acc: 99.930%
# Batch: 150/391 | Loss: 0.006 | Acc: 99.938%
# Batch: 200/391 | Loss: 0.006 | Acc: 99.953%
# Batch: 250/391 | Loss: 0.006 | Acc: 99.960%
# Batch: 300/391 | Loss: 0.006 | Acc: 99.961%
# Batch: 350/391 | Loss: 0.006 | Acc: 99.960%
# Time taken : 1m595ms
# Batch: 0/100 | Loss: 0.242 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.266 | Acc: 92.961%
#
# Epoch: 100
# Batch: 0/391 | Loss: 0.005 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.006 | Acc: 99.985%
# Batch: 100/391 | Loss: 0.006 | Acc: 99.961%
# Batch: 150/391 | Loss: 0.005 | Acc: 99.969%
# Batch: 200/391 | Loss: 0.005 | Acc: 99.973%
# Batch: 250/391 | Loss: 0.005 | Acc: 99.972%
# Batch: 300/391 | Loss: 0.005 | Acc: 99.971%
# Batch: 350/391 | Loss: 0.005 | Acc: 99.971%
# Time taken : 47s276ms
# Batch: 0/100 | Loss: 0.241 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.267 | Acc: 92.961%

# %%
def plot_accuracies(train_accuracies, test_accuracies):
  plt.plot(train_accuracies, label='Train Accuracy')
  plt.plot(test_accuracies, label='Test Accuracy')
  plt.xlabel('Epochs')
  plt.ylabel('Accuracy')
  plt.legend()
  plt.grid(True)
  plt.title('Accuracy vs. No. of epochs')

# %%
def plot_losses(train_losses, test_losses):
  plt.plot(train_losses, label='Train Losses')
  plt.plot(test_losses, label='Test Losses')
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.legend()
  plt.grid(True)
  plt.title('Loss vs. No. of epochs')

# %%
def plot_lrs(train_lrs):
  plt.plot(train_lrs)
  plt.xlabel('Epochs')
  plt.ylabel('Learning rate')
  plt.grid(True)
  plt.title('Learning Rate vs. Epochs')

# %%
plot_accuracies(train_accuracies, test_accuracies)

# %%
plot_losses(train_losses, test_losses)

# %%
plot_lrs(train_lrs)

# %%
print('Saving final model..')
state = {
    'net': model.state_dict(),
    'acc': test_accuracies[-1],
    'epoch': number_of_epochs,
}
if not os.path.isdir('try_checkpoint'):
  os.mkdir('try_checkpoint')
torch.save(state, './try_checkpoint/model_final.pth')
# Out:
# Saving final model..

# %%
import numpy as np
import pickle
from tqdm import tqdm
import pandas as pd
import os

# Function to load CIFAR batch
def load_cifar_batch(file):
    with open(file, 'rb') as fo:
        batch = pickle.load(fo, encoding='bytes')
    return batch

# Specify the folder where the CIFAR-10 batch files are
cifar10_dir = 'data/cifar-10-batches-py/'

# Load the label names
meta_data_dict = load_cifar_batch(os.path.join(cifar10_dir, 'batches.meta'))
label_names = meta_data_dict[b'label_names']

# Load test data
test_batch = load_cifar_batch('CIFAR-10/cifar_test_nolabels.pkl')
test_images = test_batch[b'data'].reshape(-1, 3, 32, 32).transpose(0, 2, 3, 1)

data_statistics = (
    (0.49139968, 0.48215827, 0.44653124),
     (0.24703233, 0.24348505, 0.26158768)
)

# Define transformation for data augmentation
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(*data_statistics, inplace=True)
])

# Apply data augmentation
augmented_test_images = torch.stack([transform(image) for image in test_images])

# Load the trained model
model = ResNet9()

checkpoint = torch.load('./try_checkpoint/ckpt.pth')

# Check the keys in the checkpoint dictionary
print(checkpoint.keys())

# Assuming the model state dictionary is saved under a different key
# Adjust this according to the actual key in your checkpoint file
model.load_state_dict(checkpoint['net'])

model =  model.to(device)

# Evaluate the model on test data
model.eval()
with torch.no_grad():
    outputs = model(augmented_test_images.to(device))
_, predicted = torch.max(outputs, 1)

predicted = predicted.to('cpu')
# Display the first 10 test images and predicted labels
plt.figure(figsize=(20, 4))
for i in range(10):
    plt.subplot(1, 10, i+1)
    plt.imshow(test_images[i])
    plt.title(label_names[predicted[i].item()].decode('utf-8'))
    plt.axis('off')
plt.show()

# Save the output in output.csv containing ID, Labels
output_data = {'ID': np.arange(len(predicted)), 'Labels': predicted.numpy()}
output_df = pd.DataFrame(output_data)
output_df.to_csv('output_rugved_resnet9_try.csv', index=False)
# Out:
# dict_keys(['net', 'acc', 'epoch'])

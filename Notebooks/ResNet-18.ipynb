# %% [markdown]
# # ResNet-18 on CIFAR-10 Dataset

# %% [markdown]
# Importing PyTorch and a few Python Libraries

# %%
import os
import sys
import time
import math

import torch
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import random_split, DataLoader
from torchvision.utils import make_grid

import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
import torch.nn.init as init

from torchsummary import summary

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Preparing the dataset
#
# We will be downloading the train and test CIFAR-10 dataset from torchvision. We will normalize and transform the dataset. For the training dataset, we will also be adding Random Crops and Random Horizontal Flips to generalize the model better.

# %%
data_statistics = (
    (0.49139968, 0.48215827, 0.44653124),
     (0.24703233, 0.24348505, 0.26158768)
) # Mean, Standard Deviation of CIFAR-10 dataset channels

train_transforms = transforms.Compose([
    transforms.RandomCrop(32, padding=4, padding_mode='reflect'), # Adding Random Crops
    transforms.RandomHorizontalFlip(), # Adding Random Horizontal Flips
    transforms.ToTensor(), # Channel x Image Height x Image Width
    transforms.Normalize(*data_statistics, inplace=True) # Output in the range of [-1, 1]
])

test_transforms = transforms.Compose([
    transforms.ToTensor(), # Channel x Image Height x Image Width
    transforms.Normalize(*data_statistics, inplace=True) # Output in the range of [-1, 1]
])

# %%
train_dataset = torchvision.datasets.CIFAR10(root='./data/', download=True, train=True, transform=train_transforms)
test_dataset = torchvision.datasets.CIFAR10(root='./data/', download=True, train=False, transform=test_transforms)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# <!-- We will also be splitting the dataset further into training and validation dataset with a validation ratio of `0.2` -->
#
# We will now create data loaders to retreive images in batches. We are selecting the batch size as `128` images for our train loader. And we are selecting the batch size as `100` images for our test loader.
#
# *From PyTorch Documentation: For data loading, passing pin_memory=True to a DataLoader will automatically put the fetched data Tensors in pinned memory, and thus enables faster data transfer to CUDA-enabled GPUs.*

# %%
# validation_ratio = 0.2
# train_dataset, validation_dataset = random_split(
#     dataset,
#     [int((1 - validation_ratio) * len(dataset)), int(validation_ratio * len(dataset))]
# )

train_batch_size = 128
test_batch_size = 100

train_dl = DataLoader(train_dataset, train_batch_size, shuffle=True, num_workers=2, pin_memory=True)
# validation_dl = DataLoader(validation_dataset, batch_size, shuffle=True, num_workers=3, pin_memory=True)
test_dl = DataLoader(test_dataset, test_batch_size, shuffle=False, num_workers=2, pin_memory=True)

classes = ('plane', 'car', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck')

# %% [markdown]
# We create the following function to display a batch of images from the dataset. And we also need to denormalize the pixels values to bring them back into the range (0,1).

# %%
def denormalize(images, means, stds):
  means = torch.tensor(means).reshape(1, 3, 1, 1)
  stds = torch.tensor(stds).reshape(1, 3, 1, 1)
  return images * stds + means

def show_batch(dl):
  for images, labels in dl:
    fig, ax = plt.subplots(figsize=(12, 12))
    ax.set_xticks([])
    ax.set_yticks([])
    denorm_images = denormalize(images, *data_statistics)
    ax.imshow(make_grid(denorm_images[:64], 8).permute(1, 2, 0))
    break

# %%
show_batch(train_dl)

# %% [markdown]
# To seamlessly use a GPU, if one is available, we define a couple of helper functions (`get_default_device` & `to_device`) and a helper class `DeviceDataLoader` to move our model & data to the GPU as required.

# %%
def get_default_device():
  # Pick GPU, if available, else CPU
  if torch.cuda.is_available():
    return torch.device('cuda')
  else:
    return torch.device('cpu')

def to_device(data, device):
  # Move tensors to chosen device
  if isinstance(data, (list, tuple)):
    # If the instance is a list/tuple, transfer each element to chosen device
    return [to_device(x, device) for x in data]
  return data.to(device, non_blocking=True)
  # non_blocking=True doesn't block the execution of the host device until transfers complete

class DeviceDataLoader():
  # Wrap a dataloader to move data to a device
  def __init__(self, dl, device):
    self.dl = dl
    self.device = device

  def __iter__(self):
    # Yield a batch of data after moving it to device
    for b in self.dl:
      yield to_device(b, self.device)

  def __len__(self):
    # Number of batches
    return len(self.dl)

# %%
# Get the default device
device = get_default_device()
device
# Out:
# device(type='cuda')

# %%
train_dl = DeviceDataLoader(train_dl, device)
# validation_dl = DeviceDataLoader(validation_dl, device)
test_dl = DeviceDataLoader(test_dl, device)

# %% [markdown]
# ## Network Architecture

# %% [markdown]
# Testing the models mentioned in the `pytorch-cifar` [GitHub Repository](https://github.com/kuangliu/pytorch-cifar).

# %% [markdown]
# ### PreActResNet18

# %%
class PreActBlock(nn.Module):
  '''Pre-activation version of the BasicBlock.'''
  expansion = 1

  def __init__(self, in_planes, planes, stride=1):
    super(PreActBlock, self).__init__()
    self.bn1 = nn.BatchNorm2d(in_planes)
    self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
    self.bn2 = nn.BatchNorm2d(planes)
    self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)

    if stride != 1 or in_planes != self.expansion*planes:
      self.shortcut = nn.Sequential(
          nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False)
      )

  def forward(self, x):
    out = F.relu(self.bn1(x))
    shortcut = self.shortcut(out) if hasattr(self, 'shortcut') else x
    out = self.conv1(out)
    out = self.conv2(F.relu(self.bn2(out)))
    out += shortcut
    return out

class PreActResNet(nn.Module):
  def __init__(self, block, num_blocks, num_classes=10):
    super(PreActResNet, self).__init__()
    self.in_planes = 64

    self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
    self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
    self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
    self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
    self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
    self.linear = nn.Linear(512*block.expansion, num_classes)

  def _make_layer(self, block, planes, num_blocks, stride):
    strides = [stride] + [1]*(num_blocks-1)
    layers = []
    for stride in strides:
        layers.append(block(self.in_planes, planes, stride))
        self.in_planes = planes * block.expansion
    return nn.Sequential(*layers)

  def forward(self, x):
    out = self.conv1(x)
    out = self.layer1(out)
    out = self.layer2(out)
    out = self.layer3(out)
    out = self.layer4(out)
    out = F.avg_pool2d(out, 4)
    out = out.view(out.size(0), -1)
    out = self.linear(out)
    return out

def PreActResNet18():
  return PreActResNet(PreActBlock, [2,2,2,2])

# %%
# model = PreActResNet18()

# %% [markdown]
# The number of parameters is `11,171,146`, which exceeds the 5 million limit.

# %% [markdown]
# ### ResNet18

# %%
class BasicBlock(nn.Module):
  expansion = 1

  def __init__(self, in_planes, planes, stride=1):
    super(BasicBlock, self).__init__()
    self.conv1 = nn.Conv2d(
        in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
    self.bn1 = nn.BatchNorm2d(planes)
    self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                            stride=1, padding=1, bias=False)
    self.bn2 = nn.BatchNorm2d(planes)

    self.shortcut = nn.Sequential()
    if stride != 1 or in_planes != self.expansion*planes:
      self.shortcut = nn.Sequential(
          nn.Conv2d(in_planes, self.expansion*planes,
                    kernel_size=1, stride=stride, bias=False),
          nn.BatchNorm2d(self.expansion*planes)
      )

  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))
    out = self.bn2(self.conv2(out))
    out += self.shortcut(x)
    out = F.relu(out)
    return out

class ResNet(nn.Module):
  def __init__(self, block, num_blocks, num_classes=10):
    super(ResNet, self).__init__()
    self.in_planes = 64

    self.conv1 = nn.Conv2d(3, 64, kernel_size=3,
                            stride=1, padding=1, bias=False)
    self.bn1 = nn.BatchNorm2d(64)
    self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
    self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
    self.layer3 = self._make_layer(block, 192, num_blocks[2], stride=2)
    self.layer4 = self._make_layer(block, 256, num_blocks[3], stride=2)
    self.linear = nn.Linear(256*block.expansion, num_classes)

  def _make_layer(self, block, planes, num_blocks, stride):
    strides = [stride] + [1]*(num_blocks-1)
    layers = []
    for stride in strides:
      layers.append(block(self.in_planes, planes, stride))
      self.in_planes = planes * block.expansion
    return nn.Sequential(*layers)

  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))
    out = self.layer1(out)
    out = self.layer2(out)
    out = self.layer3(out)
    out = self.layer4(out)
    out = F.avg_pool2d(out, 4)
    out = out.view(out.size(0), -1)
    out = self.linear(out)
    return out

def ResNet18():
  return ResNet(BasicBlock, [2, 3, 2, 2])

# %%
model = ResNet18()

# %% [markdown]
# The number of parameters is `11,173,962`, which exceeds the 5 million limit.

# %% [markdown]
# ### ResNet9

# %%
def ResNet9():
  return ResNet(BasicBlock, [1, 1, 1, 1])

# %%
# model = ResNet9()

# %% [markdown]
# ### PreActResNet9

# %%
def PreActResNet9():
  return PreActResNet(PreActBlock, [1,1,1,1])

# %%
# model = PreActResNet9()

# %%
model =  model.to(device)
if device == 'cuda':
  model = torch.nn.DataParallel(model)
  cudnn.benchmark = True

# %%
summary(model, input_size=(3, 32, 32))
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            1,728
# ├─BatchNorm2d: 1-2                       128
# ├─Sequential: 1-3                        --
# |    └─BasicBlock: 2-1                   --
# |    |    └─Conv2d: 3-1                  36,864
# |    |    └─BatchNorm2d: 3-2             128
# |    |    └─Conv2d: 3-3                  36,864
# |    |    └─BatchNorm2d: 3-4             128
# |    |    └─Sequential: 3-5              --
# |    └─BasicBlock: 2-2                   --
# |    |    └─Conv2d: 3-6                  36,864
# |    |    └─BatchNorm2d: 3-7             128
# |    |    └─Conv2d: 3-8                  36,864
# |    |    └─BatchNorm2d: 3-9             128
# |    |    └─Sequential: 3-10             --
# ├─Sequential: 1-4                        --
# |    └─BasicBlock: 2-3                   --
# |    |    └─Conv2d: 3-11                 73,728
# |    |    └─BatchNorm2d: 3-12            256
# |    |    └─Conv2d: 3-13                 147,456
# |    |    └─BatchNorm2d: 3-14            256
# |    |    └─Sequential: 3-15             8,448
# |    └─BasicBlock: 2-4                   --
# |    |    └─Conv2d: 3-16                 147,456
# |    |    └─BatchNorm2d: 3-17            256
# |    |    └─Conv2d: 3-18                 147,456
# |    |    └─BatchNorm2d: 3-19            256
# |    |    └─Sequential: 3-20             --
# |    └─BasicBlock: 2-5                   --
# |    |    └─Conv2d: 3-21                 147,456
# |    |    └─BatchNorm2d: 3-22            256
# |    |    └─Conv2d: 3-23                 147,456
# |    |    └─BatchNorm2d: 3-24            256
# |    |    └─Sequential: 3-25             --
# ├─Sequential: 1-5                        --
# |    └─BasicBlock: 2-6                   --
# |    |    └─Conv2d: 3-26                 221,184
# |    |    └─BatchNorm2d: 3-27            384
# |    |    └─Conv2d: 3-28                 331,776
# |    |    └─BatchNorm2d: 3-29            384
# |    |    └─Sequential: 3-30             24,960
# |    └─BasicBlock: 2-7                   --
# |    |    └─Conv2d: 3-31                 331,776
# |    |    └─BatchNorm2d: 3-32            384
# |    |    └─Conv2d: 3-33                 331,776
# |    |    └─BatchNorm2d: 3-34            384
# |    |    └─Sequential: 3-35             --
# ├─Sequential: 1-6                        --
# |    └─BasicBlock: 2-8                   --
# |    |    └─Conv2d: 3-36                 442,368
# |    |    └─BatchNorm2d: 3-37            512
# |    |    └─Conv2d: 3-38                 589,824
# |    |    └─BatchNorm2d: 3-39            512
# |    |    └─Sequential: 3-40             49,664
# |    └─BasicBlock: 2-9                   --
# |    |    └─Conv2d: 3-41                 589,824
# |    |    └─BatchNorm2d: 3-42            512
# |    |    └─Conv2d: 3-43                 589,824
# |    |    └─BatchNorm2d: 3-44            512
# |    |    └─Sequential: 3-45             --
# ├─Linear: 1-7                            2,570
# =================================================================
# Total params: 4,479,946
# Trainable params: 4,479,946
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            1,728
# ├─BatchNorm2d: 1-2                       128
# ├─Sequential: 1-3                        --
# |    └─BasicBlock: 2-1                   --
# |    |    └─Conv2d: 3-1                  36,864
# |    |    └─BatchNorm2d: 3-2             128
# |    |    └─Conv2d: 3-3                  36,864
# |    |    └─BatchNorm2d: 3-4             128
# |    |    └─Sequential: 3-5              --
# |    └─BasicBlock: 2-2                   --
# |    |    └─Conv2d: 3-6                  36,864
# |    |    └─BatchNorm2d: 3-7             128
# |    |    └─Conv2d: 3-8                  36,864
# |    |    └─BatchNorm2d: 3-9             128
# |    |    └─Sequential: 3-10             --
# ├─Sequential: 1-4                        --
# |    └─BasicBlock: 2-3                   --
# |    |    └─Conv2d: 3-11                 73,728
# |    |    └─BatchNorm2d: 3-12            256
# |    |    └─Conv2d: 3-13                 147,456
# |    |    └─BatchNorm2d: 3-14            256
# |    |    └─Sequential: 3-15             8,448
# |    └─BasicBlock: 2-4                   --
# |    |    └─Conv2d: 3-16                 147,456
# |    |    └─BatchNorm2d: 3-17            256
# |    |    └─Conv2d: 3-18                 147,456
# |    |    └─BatchNorm2d: 3-19            256
# |    |    └─Sequential: 3-20             --
# |    └─BasicBlock: 2-5                   --
# |    |    └─Conv2d: 3-21                 147,456
# |    |    └─BatchNorm2d: 3-22            256
# |    |    └─Conv2d: 3-23                 147,456
# |    |    └─BatchNorm2d: 3-24            256
# |    |    └─Sequential: 3-25             --
# ├─Sequential: 1-5                        --
# |    └─BasicBlock: 2-6                   --
# |    |    └─Conv2d: 3-26                 221,184
# |    |    └─BatchNorm2d: 3-27            384
# |    |    └─Conv2d: 3-28                 331,776
# |    |    └─BatchNorm2d: 3-29            384
# |    |    └─Sequential: 3-30             24,960
# |    └─BasicBlock: 2-7                   --
# |    |    └─Conv2d: 3-31                 331,776
# |    |    └─BatchNorm2d: 3-32            384
# |    |    └─Conv2d: 3-33                 331,776
# |    |    └─BatchNorm2d: 3-34            384
# |    |    └─Sequential: 3-35             --
# ├─Sequential: 1-6                        --
# |    └─BasicBlock: 2-8                   --
# |    |    └─Conv2d: 3-36                 442,368
# |    |    └─BatchNorm2d: 3-37            512
# |    |    └─Conv2d: 3-38                 589,824
# |    |    └─BatchNorm2d: 3-39            512
# |    |    └─Sequential: 3-40             49,664
# |    └─BasicBlock: 2-9                   --
# |    |    └─Conv2d: 3-41                 589,824
# |    |    └─BatchNorm2d: 3-42            512
# |    |    └─Conv2d: 3-43                 589,824
# |    |    └─BatchNorm2d: 3-44            512
# |    |    └─Sequential: 3-45             --
# ├─Linear: 1-7                            2,570
# =================================================================
# Total params: 4,479,946
# Trainable params: 4,479,946
# Non-trainable params: 0
# =================================================================

# %% [markdown]
# ## Model Training

# %%
# Helper Function
# term_width = int(100)

# TOTAL_BAR_LENGTH = 65.
# last_time = time.time()
# begin_time = last_time

# def progress_bar(current, total, msg=None):
#   global last_time, begin_time
#   if current == 0:
#     begin_time = time.time()  # Reset for new bar.

#   cur_len = int(TOTAL_BAR_LENGTH * current/total)
#   rest_len = int(TOTAL_BAR_LENGTH - cur_len) - 1

#   sys.stdout.write(' [')
#   for i in range(cur_len):
#     sys.stdout.write('=')
#   sys.stdout.write('>')
#   for i in range(rest_len):
#     sys.stdout.write('.')
#   sys.stdout.write(']')

#   cur_time = time.time()
#   step_time = cur_time - last_time
#   last_time = cur_time
#   tot_time = cur_time - begin_time

#   L = []
#   L.append('  Step: %s' % format_time(step_time))
#   L.append(' | Tot: %s' % format_time(tot_time))
#   if msg:
#     L.append(' | ' + msg)

#   msg = ''.join(L)
#   sys.stdout.write(msg)
#   for i in range(term_width-int(TOTAL_BAR_LENGTH)-len(msg)-3):
#     sys.stdout.write(' ')

#   # Go back to the center of the bar.
#   for i in range(term_width-int(TOTAL_BAR_LENGTH/2)+2):
#     sys.stdout.write('\b')
#   sys.stdout.write(' %d/%d ' % (current+1, total))

#   if current < total-1:
#     sys.stdout.write('\r')
#   else:
#     sys.stdout.write('\n')
#   sys.stdout.flush()

# %%
def format_time(seconds):
  days = int(seconds / 3600/24)
  seconds = seconds - days*3600*24
  hours = int(seconds / 3600)
  seconds = seconds - hours*3600
  minutes = int(seconds / 60)
  seconds = seconds - minutes*60
  secondsf = int(seconds)
  seconds = seconds - secondsf
  millis = int(seconds*1000)

  f = ''
  i = 1
  if days > 0:
    f += str(days) + 'D'
    i += 1
  if hours > 0 and i <= 2:
    f += str(hours) + 'h'
    i += 1
  if minutes > 0 and i <= 2:
    f += str(minutes) + 'm'
    i += 1
  if secondsf > 0 and i <= 2:
    f += str(secondsf) + 's'
    i += 1
  if millis > 0 and i <= 2:
    f += str(millis) + 'ms'
    i += 1
  if f == '':
    f = '0ms'
  return f

# %%
lr = 0.1
momentum = 0.9
weight_decay = 5e-4

start_epoch = 1
number_of_epochs = 100
best_acc = 0


criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=lr,
                      momentum=momentum, weight_decay=weight_decay)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=number_of_epochs)

# %%
def get_lr(optimizer):
  for param_group in optimizer.param_groups:
    return param_group['lr']

# %%
def train(epoch):
  print('\nEpoch: %d' % epoch)
  start_time = time.time()

  model.train()
  train_loss = 0
  correct = 0
  total = 0
  for batch_idx, (inputs, targets) in enumerate(train_dl):
    # inputs, targets = inputs.to(device), targets.to(device)
    optimizer.zero_grad()
    outputs = model(inputs)
    loss = criterion(outputs, targets)
    loss.backward()
    optimizer.step()

    train_loss += loss.item()
    _, predicted = outputs.max(1)
    total += targets.size(0)
    correct += predicted.eq(targets).sum().item()

    if batch_idx % 50 == 0:
      print(f"Batch: {batch_idx}/{len(train_dl)} | Loss: {(train_loss/(batch_idx+1)):.3f} | Acc: {(100.*correct/total):.3f}%")

  cur_time = time.time()
  epoch_time = cur_time - start_time
  print(f"Time taken : {format_time(epoch_time)}")

  return train_loss/(batch_idx+1), 100.*correct/total, get_lr(optimizer)

# %%
def test(epoch):
  global best_acc
  model.eval()
  test_loss = 0
  correct = 0
  total = 0
  with torch.no_grad():
    for batch_idx, (inputs, targets) in enumerate(test_dl):
      # inputs, targets = inputs.to(device), targets.to(device)
      outputs = model(inputs)
      loss = criterion(outputs, targets)

      test_loss += loss.item()
      _, predicted = outputs.max(1)
      total += targets.size(0)
      correct += predicted.eq(targets).sum().item()
      
      if batch_idx % 50 == 0:
        print(f"Batch: {batch_idx}/{len(test_dl)} | Loss: {(test_loss/(batch_idx+1)):.3f} | Acc: {(100.*correct/total):.3f}%")
      # progress_bar(batch_idx, len(test_dl), 'Loss: %.3f | Acc: %.3f%% (%d/%d)'
      #               % (test_loss/(batch_idx+1), 100.*correct/total, correct, total))

  # Save checkpoint.
  acc = 100.*correct/total
  if acc > best_acc:
    print('Saving..')
    state = {
        'net': model.state_dict(),
        'acc': acc,
        'epoch': epoch,
    }
    if not os.path.isdir('checkpoint_18'):
      os.mkdir('checkpoint_18')
    torch.save(state, './checkpoint_18/ckpt.pth')
    best_acc = acc

  return test_loss/(batch_idx+1), 100.*correct/total

# %%
train_losses = []
train_accuracies = []
train_lrs = []

test_losses = []
test_accuracies = []

for epoch in range(start_epoch, start_epoch + number_of_epochs):
  epoch_train_loss, epoch_train_accuracy, epoch_lr = train(epoch)
  train_losses.append(epoch_train_loss)
  train_accuracies.append(epoch_train_accuracy)
  train_lrs.append(epoch_lr)

  epoch_test_loss, epoch_test_accuracy = test(epoch)
  test_losses.append(epoch_test_loss)
  test_accuracies.append(epoch_test_accuracy)

  scheduler.step()
# Out:
# Epoch: 1
# Batch: 0/391 | Loss: 2.382 | Acc: 10.938%
# Batch: 50/391 | Loss: 2.105 | Acc: 23.744%
# Batch: 100/391 | Loss: 1.956 | Acc: 27.483%
# Batch: 150/391 | Loss: 1.870 | Acc: 30.034%
# Batch: 200/391 | Loss: 1.802 | Acc: 32.801%
# Batch: 250/391 | Loss: 1.757 | Acc: 34.556%
# Batch: 300/391 | Loss: 1.710 | Acc: 36.348%
# Batch: 350/391 | Loss: 1.672 | Acc: 37.858%
# Time taken : 1m194ms
# Batch: 0/100 | Loss: 1.705 | Acc: 40.000%
# Batch: 50/100 | Loss: 1.531 | Acc: 45.235%
# Saving..
#
# Epoch: 2
# Batch: 0/391 | Loss: 1.587 | Acc: 41.406%
# Batch: 50/391 | Loss: 1.357 | Acc: 50.169%
# Batch: 100/391 | Loss: 1.321 | Acc: 51.996%
# Batch: 150/391 | Loss: 1.290 | Acc: 53.223%
# Batch: 200/391 | Loss: 1.268 | Acc: 54.256%
# Batch: 250/391 | Loss: 1.245 | Acc: 55.145%
# Batch: 300/391 | Loss: 1.226 | Acc: 55.788%
# Batch: 350/391 | Loss: 1.207 | Acc: 56.468%
# Time taken : 59s625ms
# Batch: 0/100 | Loss: 1.037 | Acc: 64.000%
# Batch: 50/100 | Loss: 1.097 | Acc: 61.490%
# Saving..
#
# Epoch: 3
# Batch: 0/391 | Loss: 1.050 | Acc: 68.750%
# Batch: 50/391 | Loss: 1.024 | Acc: 63.097%
# Batch: 100/391 | Loss: 1.013 | Acc: 63.653%
# Batch: 150/391 | Loss: 1.013 | Acc: 63.742%
# Batch: 200/391 | Loss: 1.000 | Acc: 64.171%
# Batch: 250/391 | Loss: 0.989 | Acc: 64.592%
# Batch: 300/391 | Loss: 0.979 | Acc: 65.025%
# Batch: 350/391 | Loss: 0.970 | Acc: 65.371%
# Time taken : 1m661ms
# Batch: 0/100 | Loss: 1.012 | Acc: 67.000%
# Batch: 50/100 | Loss: 1.044 | Acc: 64.333%
# Saving..
#
# Epoch: 4
# Batch: 0/391 | Loss: 0.953 | Acc: 70.312%
# Batch: 50/391 | Loss: 0.872 | Acc: 68.964%
# Batch: 100/391 | Loss: 0.855 | Acc: 69.694%
# Batch: 150/391 | Loss: 0.861 | Acc: 69.557%
# Batch: 200/391 | Loss: 0.851 | Acc: 69.935%
# Batch: 250/391 | Loss: 0.841 | Acc: 70.334%
# Batch: 300/391 | Loss: 0.833 | Acc: 70.614%
# Batch: 350/391 | Loss: 0.824 | Acc: 70.911%
# Time taken : 1m2s
# Batch: 0/100 | Loss: 0.788 | Acc: 71.000%
# Batch: 50/100 | Loss: 0.773 | Acc: 73.157%
# Saving..
#
# Epoch: 5
# Batch: 0/391 | Loss: 0.861 | Acc: 73.438%
# Batch: 50/391 | Loss: 0.754 | Acc: 74.280%
# Batch: 100/391 | Loss: 0.735 | Acc: 74.729%
# Batch: 150/391 | Loss: 0.729 | Acc: 74.731%
# Batch: 200/391 | Loss: 0.721 | Acc: 74.946%
# Batch: 250/391 | Loss: 0.720 | Acc: 75.025%
# Batch: 300/391 | Loss: 0.713 | Acc: 75.254%
# Batch: 350/391 | Loss: 0.707 | Acc: 75.432%
# Time taken : 59s505ms
# Batch: 0/100 | Loss: 0.776 | Acc: 74.000%
# Batch: 50/100 | Loss: 0.726 | Acc: 74.980%
# Saving..
#
# Epoch: 6
# Batch: 0/391 | Loss: 0.744 | Acc: 73.438%
# Batch: 50/391 | Loss: 0.665 | Acc: 76.869%
# Batch: 100/391 | Loss: 0.651 | Acc: 77.205%
# Batch: 150/391 | Loss: 0.651 | Acc: 77.364%
# Batch: 200/391 | Loss: 0.643 | Acc: 77.705%
# Batch: 250/391 | Loss: 0.642 | Acc: 77.658%
# Batch: 300/391 | Loss: 0.638 | Acc: 77.816%
# Batch: 350/391 | Loss: 0.633 | Acc: 77.998%
# Time taken : 1m925ms
# Batch: 0/100 | Loss: 0.648 | Acc: 73.000%
# Batch: 50/100 | Loss: 0.664 | Acc: 77.196%
# Saving..
#
# Epoch: 7
# Batch: 0/391 | Loss: 0.626 | Acc: 78.125%
# Batch: 50/391 | Loss: 0.595 | Acc: 79.902%
# Batch: 100/391 | Loss: 0.579 | Acc: 80.005%
# Batch: 150/391 | Loss: 0.575 | Acc: 80.076%
# Batch: 200/391 | Loss: 0.575 | Acc: 80.158%
# Batch: 250/391 | Loss: 0.574 | Acc: 80.276%
# Batch: 300/391 | Loss: 0.573 | Acc: 80.331%
# Batch: 350/391 | Loss: 0.570 | Acc: 80.453%
# Time taken : 1m953ms
# Batch: 0/100 | Loss: 0.631 | Acc: 76.000%
# Batch: 50/100 | Loss: 0.631 | Acc: 78.314%
# Saving..
#
# Epoch: 8
# Batch: 0/391 | Loss: 0.687 | Acc: 79.688%
# Batch: 50/391 | Loss: 0.542 | Acc: 81.005%
# Batch: 100/391 | Loss: 0.543 | Acc: 80.863%
# Batch: 150/391 | Loss: 0.537 | Acc: 81.214%
# Batch: 200/391 | Loss: 0.532 | Acc: 81.569%
# Batch: 250/391 | Loss: 0.536 | Acc: 81.524%
# Batch: 300/391 | Loss: 0.535 | Acc: 81.634%
# Batch: 350/391 | Loss: 0.535 | Acc: 81.584%
# Time taken : 1m218ms
# Batch: 0/100 | Loss: 1.042 | Acc: 70.000%
# Batch: 50/100 | Loss: 0.716 | Acc: 75.569%
#
# Epoch: 9
# Batch: 0/391 | Loss: 0.487 | Acc: 86.719%
# Batch: 50/391 | Loss: 0.534 | Acc: 81.587%
# Batch: 100/391 | Loss: 0.525 | Acc: 81.915%
# Batch: 150/391 | Loss: 0.512 | Acc: 82.476%
# Batch: 200/391 | Loss: 0.511 | Acc: 82.358%
# Batch: 250/391 | Loss: 0.508 | Acc: 82.479%
# Batch: 300/391 | Loss: 0.506 | Acc: 82.581%
# Batch: 350/391 | Loss: 0.503 | Acc: 82.699%
# Time taken : 1m388ms
# Batch: 0/100 | Loss: 0.504 | Acc: 85.000%
# Batch: 50/100 | Loss: 0.544 | Acc: 81.686%
# Saving..
#
# Epoch: 10
# Batch: 0/391 | Loss: 0.442 | Acc: 81.250%
# Batch: 50/391 | Loss: 0.466 | Acc: 83.961%
# Batch: 100/391 | Loss: 0.454 | Acc: 84.414%
# Batch: 150/391 | Loss: 0.467 | Acc: 83.961%
# Batch: 200/391 | Loss: 0.472 | Acc: 83.699%
# Batch: 250/391 | Loss: 0.474 | Acc: 83.485%
# Batch: 300/391 | Loss: 0.475 | Acc: 83.407%
# Batch: 350/391 | Loss: 0.479 | Acc: 83.282%
# Time taken : 1m702ms
# Batch: 0/100 | Loss: 0.545 | Acc: 85.000%
# Batch: 50/100 | Loss: 0.580 | Acc: 79.980%
#
# Epoch: 11
# Batch: 0/391 | Loss: 0.397 | Acc: 87.500%
# Batch: 50/391 | Loss: 0.458 | Acc: 84.329%
# Batch: 100/391 | Loss: 0.459 | Acc: 84.244%
# Batch: 150/391 | Loss: 0.472 | Acc: 83.821%
# Batch: 200/391 | Loss: 0.469 | Acc: 83.932%
# Batch: 250/391 | Loss: 0.471 | Acc: 83.868%
# Batch: 300/391 | Loss: 0.468 | Acc: 84.001%
# Batch: 350/391 | Loss: 0.467 | Acc: 84.054%
# Time taken : 1m910ms
# Batch: 0/100 | Loss: 0.548 | Acc: 81.000%
# Batch: 50/100 | Loss: 0.574 | Acc: 80.941%
#
# Epoch: 12
# Batch: 0/391 | Loss: 0.536 | Acc: 82.031%
# Batch: 50/391 | Loss: 0.447 | Acc: 84.804%
# Batch: 100/391 | Loss: 0.442 | Acc: 84.793%
# Batch: 150/391 | Loss: 0.449 | Acc: 84.541%
# Batch: 200/391 | Loss: 0.445 | Acc: 84.709%
# Batch: 250/391 | Loss: 0.448 | Acc: 84.633%
# Batch: 300/391 | Loss: 0.452 | Acc: 84.520%
# Batch: 350/391 | Loss: 0.450 | Acc: 84.562%
# Time taken : 1m968ms
# Batch: 0/100 | Loss: 0.473 | Acc: 81.000%
# Batch: 50/100 | Loss: 0.591 | Acc: 80.804%
#
# Epoch: 13
# Batch: 0/391 | Loss: 0.436 | Acc: 86.719%
# Batch: 50/391 | Loss: 0.435 | Acc: 84.911%
# Batch: 100/391 | Loss: 0.429 | Acc: 85.187%
# Batch: 150/391 | Loss: 0.436 | Acc: 84.975%
# Batch: 200/391 | Loss: 0.435 | Acc: 85.059%
# Batch: 250/391 | Loss: 0.434 | Acc: 85.122%
# Batch: 300/391 | Loss: 0.438 | Acc: 85.019%
# Batch: 350/391 | Loss: 0.437 | Acc: 85.016%
# Time taken : 1m1s
# Batch: 0/100 | Loss: 0.572 | Acc: 80.000%
# Batch: 50/100 | Loss: 0.538 | Acc: 81.471%
#
# Epoch: 14
# Batch: 0/391 | Loss: 0.437 | Acc: 82.031%
# Batch: 50/391 | Loss: 0.412 | Acc: 86.075%
# Batch: 100/391 | Loss: 0.399 | Acc: 86.347%
# Batch: 150/391 | Loss: 0.410 | Acc: 86.098%
# Batch: 200/391 | Loss: 0.418 | Acc: 85.805%
# Batch: 250/391 | Loss: 0.421 | Acc: 85.654%
# Batch: 300/391 | Loss: 0.424 | Acc: 85.499%
# Batch: 350/391 | Loss: 0.426 | Acc: 85.434%
# Time taken : 1m803ms
# Batch: 0/100 | Loss: 0.554 | Acc: 84.000%
# Batch: 50/100 | Loss: 0.540 | Acc: 81.392%
#
# Epoch: 15
# Batch: 0/391 | Loss: 0.396 | Acc: 88.281%
# Batch: 50/391 | Loss: 0.398 | Acc: 86.275%
# Batch: 100/391 | Loss: 0.402 | Acc: 86.394%
# Batch: 150/391 | Loss: 0.404 | Acc: 86.326%
# Batch: 200/391 | Loss: 0.410 | Acc: 86.136%
# Batch: 250/391 | Loss: 0.413 | Acc: 85.987%
# Batch: 300/391 | Loss: 0.410 | Acc: 86.041%
# Batch: 350/391 | Loss: 0.411 | Acc: 85.955%
# Time taken : 1m157ms
# Batch: 0/100 | Loss: 0.498 | Acc: 81.000%
# Batch: 50/100 | Loss: 0.553 | Acc: 81.471%
#
# Epoch: 16
# Batch: 0/391 | Loss: 0.307 | Acc: 87.500%
# Batch: 50/391 | Loss: 0.386 | Acc: 86.703%
# Batch: 100/391 | Loss: 0.390 | Acc: 86.448%
# Batch: 150/391 | Loss: 0.403 | Acc: 86.020%
# Batch: 200/391 | Loss: 0.403 | Acc: 86.031%
# Batch: 250/391 | Loss: 0.404 | Acc: 86.062%
# Batch: 300/391 | Loss: 0.404 | Acc: 86.015%
# Batch: 350/391 | Loss: 0.406 | Acc: 85.964%
# Time taken : 1m488ms
# Batch: 0/100 | Loss: 0.426 | Acc: 84.000%
# Batch: 50/100 | Loss: 0.497 | Acc: 83.059%
# Saving..
#
# Epoch: 17
# Batch: 0/391 | Loss: 0.502 | Acc: 82.812%
# Batch: 50/391 | Loss: 0.377 | Acc: 87.056%
# Batch: 100/391 | Loss: 0.385 | Acc: 86.719%
# Batch: 150/391 | Loss: 0.384 | Acc: 86.708%
# Batch: 200/391 | Loss: 0.391 | Acc: 86.552%
# Batch: 250/391 | Loss: 0.393 | Acc: 86.414%
# Batch: 300/391 | Loss: 0.399 | Acc: 86.187%
# Batch: 350/391 | Loss: 0.398 | Acc: 86.260%
# Time taken : 1m663ms
# Batch: 0/100 | Loss: 0.534 | Acc: 83.000%
# Batch: 50/100 | Loss: 0.580 | Acc: 81.431%
#
# Epoch: 18
# Batch: 0/391 | Loss: 0.470 | Acc: 85.938%
# Batch: 50/391 | Loss: 0.355 | Acc: 87.822%
# Batch: 100/391 | Loss: 0.371 | Acc: 87.183%
# Batch: 150/391 | Loss: 0.380 | Acc: 87.003%
# Batch: 200/391 | Loss: 0.384 | Acc: 86.886%
# Batch: 250/391 | Loss: 0.382 | Acc: 86.915%
# Batch: 300/391 | Loss: 0.385 | Acc: 86.851%
# Batch: 350/391 | Loss: 0.385 | Acc: 86.850%
# Time taken : 1m879ms
# Batch: 0/100 | Loss: 0.452 | Acc: 87.000%
# Batch: 50/100 | Loss: 0.506 | Acc: 83.294%
#
# Epoch: 19
# Batch: 0/391 | Loss: 0.293 | Acc: 89.844%
# Batch: 50/391 | Loss: 0.371 | Acc: 87.224%
# Batch: 100/391 | Loss: 0.392 | Acc: 86.641%
# Batch: 150/391 | Loss: 0.396 | Acc: 86.367%
# Batch: 200/391 | Loss: 0.390 | Acc: 86.556%
# Batch: 250/391 | Loss: 0.388 | Acc: 86.616%
# Batch: 300/391 | Loss: 0.385 | Acc: 86.654%
# Batch: 350/391 | Loss: 0.386 | Acc: 86.599%
# Time taken : 1m813ms
# Batch: 0/100 | Loss: 0.607 | Acc: 79.000%
# Batch: 50/100 | Loss: 0.574 | Acc: 81.098%
#
# Epoch: 20
# Batch: 0/391 | Loss: 0.411 | Acc: 85.156%
# Batch: 50/391 | Loss: 0.362 | Acc: 87.515%
# Batch: 100/391 | Loss: 0.372 | Acc: 87.361%
# Batch: 150/391 | Loss: 0.371 | Acc: 87.381%
# Batch: 200/391 | Loss: 0.374 | Acc: 87.275%
# Batch: 250/391 | Loss: 0.376 | Acc: 87.232%
# Batch: 300/391 | Loss: 0.376 | Acc: 87.240%
# Batch: 350/391 | Loss: 0.377 | Acc: 87.155%
# Time taken : 1m837ms
# Batch: 0/100 | Loss: 0.451 | Acc: 85.000%
# Batch: 50/100 | Loss: 0.413 | Acc: 86.059%
# Saving..
#
# Epoch: 21
# Batch: 0/391 | Loss: 0.388 | Acc: 88.281%
# Batch: 50/391 | Loss: 0.358 | Acc: 87.653%
# Batch: 100/391 | Loss: 0.371 | Acc: 87.322%
# Batch: 150/391 | Loss: 0.369 | Acc: 87.547%
# Batch: 200/391 | Loss: 0.367 | Acc: 87.512%
# Batch: 250/391 | Loss: 0.369 | Acc: 87.419%
# Batch: 300/391 | Loss: 0.371 | Acc: 87.272%
# Batch: 350/391 | Loss: 0.373 | Acc: 87.228%
# Time taken : 1m881ms
# Batch: 0/100 | Loss: 0.517 | Acc: 78.000%
# Batch: 50/100 | Loss: 0.580 | Acc: 80.529%
#
# Epoch: 22
# Batch: 0/391 | Loss: 0.385 | Acc: 86.719%
# Batch: 50/391 | Loss: 0.327 | Acc: 88.756%
# Batch: 100/391 | Loss: 0.348 | Acc: 88.049%
# Batch: 150/391 | Loss: 0.352 | Acc: 88.007%
# Batch: 200/391 | Loss: 0.355 | Acc: 87.807%
# Batch: 250/391 | Loss: 0.359 | Acc: 87.693%
# Batch: 300/391 | Loss: 0.360 | Acc: 87.682%
# Batch: 350/391 | Loss: 0.364 | Acc: 87.558%
# Time taken : 1m834ms
# Batch: 0/100 | Loss: 0.525 | Acc: 85.000%
# Batch: 50/100 | Loss: 0.547 | Acc: 81.863%
#
# Epoch: 23
# Batch: 0/391 | Loss: 0.303 | Acc: 85.156%
# Batch: 50/391 | Loss: 0.348 | Acc: 87.439%
# Batch: 100/391 | Loss: 0.344 | Acc: 87.956%
# Batch: 150/391 | Loss: 0.343 | Acc: 88.105%
# Batch: 200/391 | Loss: 0.348 | Acc: 87.978%
# Batch: 250/391 | Loss: 0.351 | Acc: 87.889%
# Batch: 300/391 | Loss: 0.353 | Acc: 87.861%
# Batch: 350/391 | Loss: 0.356 | Acc: 87.807%
# Time taken : 1m1s
# Batch: 0/100 | Loss: 0.441 | Acc: 84.000%
# Batch: 50/100 | Loss: 0.527 | Acc: 82.490%
#
# Epoch: 24
# Batch: 0/391 | Loss: 0.399 | Acc: 88.281%
# Batch: 50/391 | Loss: 0.323 | Acc: 89.154%
# Batch: 100/391 | Loss: 0.334 | Acc: 88.575%
# Batch: 150/391 | Loss: 0.343 | Acc: 88.276%
# Batch: 200/391 | Loss: 0.350 | Acc: 88.095%
# Batch: 250/391 | Loss: 0.352 | Acc: 87.973%
# Batch: 300/391 | Loss: 0.352 | Acc: 87.946%
# Batch: 350/391 | Loss: 0.351 | Acc: 87.992%
# Time taken : 1m1s
# Batch: 0/100 | Loss: 0.645 | Acc: 80.000%
# Batch: 50/100 | Loss: 0.677 | Acc: 78.039%
#
# Epoch: 25
# Batch: 0/391 | Loss: 0.355 | Acc: 86.719%
# Batch: 50/391 | Loss: 0.334 | Acc: 88.465%
# Batch: 100/391 | Loss: 0.323 | Acc: 88.962%
# Batch: 150/391 | Loss: 0.329 | Acc: 88.840%
# Batch: 200/391 | Loss: 0.336 | Acc: 88.569%
# Batch: 250/391 | Loss: 0.336 | Acc: 88.614%
# Batch: 300/391 | Loss: 0.340 | Acc: 88.429%
# Batch: 350/391 | Loss: 0.341 | Acc: 88.317%
# Time taken : 59s760ms
# Batch: 0/100 | Loss: 0.343 | Acc: 86.000%
# Batch: 50/100 | Loss: 0.486 | Acc: 84.118%
#
# Epoch: 26
# Batch: 0/391 | Loss: 0.301 | Acc: 90.625%
# Batch: 50/391 | Loss: 0.316 | Acc: 88.940%
# Batch: 100/391 | Loss: 0.315 | Acc: 89.140%
# Batch: 150/391 | Loss: 0.328 | Acc: 88.540%
# Batch: 200/391 | Loss: 0.331 | Acc: 88.479%
# Batch: 250/391 | Loss: 0.338 | Acc: 88.253%
# Batch: 300/391 | Loss: 0.341 | Acc: 88.224%
# Batch: 350/391 | Loss: 0.342 | Acc: 88.172%
# Time taken : 1m1s
# Batch: 0/100 | Loss: 0.504 | Acc: 83.000%
# Batch: 50/100 | Loss: 0.483 | Acc: 83.882%
#
# Epoch: 27
# Batch: 0/391 | Loss: 0.407 | Acc: 87.500%
# Batch: 50/391 | Loss: 0.334 | Acc: 88.618%
# Batch: 100/391 | Loss: 0.336 | Acc: 88.645%
# Batch: 150/391 | Loss: 0.328 | Acc: 88.866%
# Batch: 200/391 | Loss: 0.328 | Acc: 88.845%
# Batch: 250/391 | Loss: 0.331 | Acc: 88.720%
# Batch: 300/391 | Loss: 0.332 | Acc: 88.735%
# Batch: 350/391 | Loss: 0.335 | Acc: 88.644%
# Time taken : 1m500ms
# Batch: 0/100 | Loss: 0.447 | Acc: 82.000%
# Batch: 50/100 | Loss: 0.482 | Acc: 84.000%
#
# Epoch: 28
# Batch: 0/391 | Loss: 0.403 | Acc: 85.156%
# Batch: 50/391 | Loss: 0.334 | Acc: 88.649%
# Batch: 100/391 | Loss: 0.327 | Acc: 88.877%
# Batch: 150/391 | Loss: 0.325 | Acc: 88.881%
# Batch: 200/391 | Loss: 0.324 | Acc: 88.899%
# Batch: 250/391 | Loss: 0.331 | Acc: 88.748%
# Batch: 300/391 | Loss: 0.331 | Acc: 88.722%
# Batch: 350/391 | Loss: 0.334 | Acc: 88.644%
# Time taken : 1m830ms
# Batch: 0/100 | Loss: 0.550 | Acc: 84.000%
# Batch: 50/100 | Loss: 0.540 | Acc: 82.196%
#
# Epoch: 29
# Batch: 0/391 | Loss: 0.405 | Acc: 86.719%
# Batch: 50/391 | Loss: 0.315 | Acc: 89.108%
# Batch: 100/391 | Loss: 0.315 | Acc: 89.101%
# Batch: 150/391 | Loss: 0.312 | Acc: 89.135%
# Batch: 200/391 | Loss: 0.318 | Acc: 89.008%
# Batch: 250/391 | Loss: 0.317 | Acc: 89.137%
# Batch: 300/391 | Loss: 0.324 | Acc: 88.902%
# Batch: 350/391 | Loss: 0.325 | Acc: 88.898%
# Time taken : 1m311ms
# Batch: 0/100 | Loss: 0.566 | Acc: 83.000%
# Batch: 50/100 | Loss: 0.419 | Acc: 86.333%
# Saving..
#
# Epoch: 30
# Batch: 0/391 | Loss: 0.195 | Acc: 92.969%
# Batch: 50/391 | Loss: 0.290 | Acc: 90.165%
# Batch: 100/391 | Loss: 0.301 | Acc: 89.689%
# Batch: 150/391 | Loss: 0.308 | Acc: 89.518%
# Batch: 200/391 | Loss: 0.308 | Acc: 89.622%
# Batch: 250/391 | Loss: 0.314 | Acc: 89.333%
# Batch: 300/391 | Loss: 0.316 | Acc: 89.260%
# Batch: 350/391 | Loss: 0.319 | Acc: 89.045%
# Time taken : 1m1s
# Batch: 0/100 | Loss: 0.523 | Acc: 85.000%
# Batch: 50/100 | Loss: 0.476 | Acc: 85.000%
#
# Epoch: 31
# Batch: 0/391 | Loss: 0.305 | Acc: 88.281%
# Batch: 50/391 | Loss: 0.281 | Acc: 89.951%
# Batch: 100/391 | Loss: 0.306 | Acc: 89.318%
# Batch: 150/391 | Loss: 0.303 | Acc: 89.585%
# Batch: 200/391 | Loss: 0.306 | Acc: 89.502%
# Batch: 250/391 | Loss: 0.308 | Acc: 89.445%
# Batch: 300/391 | Loss: 0.309 | Acc: 89.444%
# Batch: 350/391 | Loss: 0.310 | Acc: 89.416%
# Time taken : 1m933ms
# Batch: 0/100 | Loss: 0.350 | Acc: 89.000%
# Batch: 50/100 | Loss: 0.417 | Acc: 86.235%
#
# Epoch: 32
# Batch: 0/391 | Loss: 0.254 | Acc: 90.625%
# Batch: 50/391 | Loss: 0.317 | Acc: 89.078%
# Batch: 100/391 | Loss: 0.310 | Acc: 89.449%
# Batch: 150/391 | Loss: 0.301 | Acc: 89.916%
# Batch: 200/391 | Loss: 0.298 | Acc: 89.929%
# Batch: 250/391 | Loss: 0.302 | Acc: 89.803%
# Batch: 300/391 | Loss: 0.307 | Acc: 89.509%
# Batch: 350/391 | Loss: 0.307 | Acc: 89.508%
# Time taken : 1m66ms
# Batch: 0/100 | Loss: 0.662 | Acc: 78.000%
# Batch: 50/100 | Loss: 0.617 | Acc: 80.569%
#
# Epoch: 33
# Batch: 0/391 | Loss: 0.356 | Acc: 90.625%
# Batch: 50/391 | Loss: 0.290 | Acc: 90.334%
# Batch: 100/391 | Loss: 0.296 | Acc: 90.285%
# Batch: 150/391 | Loss: 0.295 | Acc: 90.185%
# Batch: 200/391 | Loss: 0.297 | Acc: 89.921%
# Batch: 250/391 | Loss: 0.302 | Acc: 89.707%
# Batch: 300/391 | Loss: 0.308 | Acc: 89.460%
# Batch: 350/391 | Loss: 0.309 | Acc: 89.445%
# Time taken : 1m1s
# Batch: 0/100 | Loss: 0.402 | Acc: 85.000%
# Batch: 50/100 | Loss: 0.511 | Acc: 83.294%
#
# Epoch: 34
# Batch: 0/391 | Loss: 0.385 | Acc: 84.375%
# Batch: 50/391 | Loss: 0.302 | Acc: 89.706%
# Batch: 100/391 | Loss: 0.297 | Acc: 89.828%
# Batch: 150/391 | Loss: 0.294 | Acc: 90.004%
# Batch: 200/391 | Loss: 0.288 | Acc: 90.124%
# Batch: 250/391 | Loss: 0.291 | Acc: 90.052%
# Batch: 300/391 | Loss: 0.292 | Acc: 89.953%
# Batch: 350/391 | Loss: 0.294 | Acc: 89.955%
# Time taken : 1m820ms
# Batch: 0/100 | Loss: 0.410 | Acc: 86.000%
# Batch: 50/100 | Loss: 0.406 | Acc: 86.412%
# Saving..
#
# Epoch: 35
# Batch: 0/391 | Loss: 0.446 | Acc: 85.938%
# Batch: 50/391 | Loss: 0.278 | Acc: 91.085%
# Batch: 100/391 | Loss: 0.288 | Acc: 90.370%
# Batch: 150/391 | Loss: 0.293 | Acc: 90.185%
# Batch: 200/391 | Loss: 0.295 | Acc: 90.112%
# Batch: 250/391 | Loss: 0.296 | Acc: 90.043%
# Batch: 300/391 | Loss: 0.301 | Acc: 89.885%
# Batch: 350/391 | Loss: 0.299 | Acc: 89.906%
# Time taken : 1m1s
# Batch: 0/100 | Loss: 0.438 | Acc: 86.000%
# Batch: 50/100 | Loss: 0.407 | Acc: 86.412%
# Saving..
#
# Epoch: 36
# Batch: 0/391 | Loss: 0.291 | Acc: 89.844%
# Batch: 50/391 | Loss: 0.290 | Acc: 90.349%
# Batch: 100/391 | Loss: 0.281 | Acc: 90.610%
# Batch: 150/391 | Loss: 0.282 | Acc: 90.527%
# Batch: 200/391 | Loss: 0.289 | Acc: 90.310%
# Batch: 250/391 | Loss: 0.289 | Acc: 90.199%
# Batch: 300/391 | Loss: 0.290 | Acc: 90.153%
# Batch: 350/391 | Loss: 0.291 | Acc: 90.093%
# Time taken : 1m657ms
# Batch: 0/100 | Loss: 0.329 | Acc: 87.000%
# Batch: 50/100 | Loss: 0.416 | Acc: 86.843%
# Saving..
#
# Epoch: 37
# Batch: 0/391 | Loss: 0.149 | Acc: 96.094%
# Batch: 50/391 | Loss: 0.264 | Acc: 91.008%
# Batch: 100/391 | Loss: 0.264 | Acc: 91.136%
# Batch: 150/391 | Loss: 0.274 | Acc: 90.806%
# Batch: 200/391 | Loss: 0.279 | Acc: 90.602%
# Batch: 250/391 | Loss: 0.283 | Acc: 90.392%
# Batch: 300/391 | Loss: 0.284 | Acc: 90.329%
# Batch: 350/391 | Loss: 0.283 | Acc: 90.398%
# Time taken : 59s950ms
# Batch: 0/100 | Loss: 0.498 | Acc: 85.000%
# Batch: 50/100 | Loss: 0.431 | Acc: 85.647%
#
# Epoch: 38
# Batch: 0/391 | Loss: 0.307 | Acc: 88.281%
# Batch: 50/391 | Loss: 0.256 | Acc: 91.422%
# Batch: 100/391 | Loss: 0.273 | Acc: 90.656%
# Batch: 150/391 | Loss: 0.279 | Acc: 90.423%
# Batch: 200/391 | Loss: 0.282 | Acc: 90.302%
# Batch: 250/391 | Loss: 0.288 | Acc: 89.996%
# Batch: 300/391 | Loss: 0.285 | Acc: 90.114%
# Batch: 350/391 | Loss: 0.287 | Acc: 90.084%
# Time taken : 1m89ms
# Batch: 0/100 | Loss: 0.523 | Acc: 81.000%
# Batch: 50/100 | Loss: 0.438 | Acc: 85.667%
#
# Epoch: 39
# Batch: 0/391 | Loss: 0.233 | Acc: 93.750%
# Batch: 50/391 | Loss: 0.256 | Acc: 91.253%
# Batch: 100/391 | Loss: 0.263 | Acc: 91.081%
# Batch: 150/391 | Loss: 0.264 | Acc: 90.987%
# Batch: 200/391 | Loss: 0.265 | Acc: 90.955%
# Batch: 250/391 | Loss: 0.271 | Acc: 90.756%
# Batch: 300/391 | Loss: 0.274 | Acc: 90.641%
# Batch: 350/391 | Loss: 0.276 | Acc: 90.589%
# Time taken : 1m1s
# Batch: 0/100 | Loss: 0.401 | Acc: 87.000%
# Batch: 50/100 | Loss: 0.424 | Acc: 86.471%
#
# Epoch: 40
# Batch: 0/391 | Loss: 0.320 | Acc: 89.062%
# Batch: 50/391 | Loss: 0.252 | Acc: 91.360%
# Batch: 100/391 | Loss: 0.258 | Acc: 91.074%
# Batch: 150/391 | Loss: 0.260 | Acc: 91.080%
# Batch: 200/391 | Loss: 0.267 | Acc: 90.862%
# Batch: 250/391 | Loss: 0.272 | Acc: 90.725%
# Batch: 300/391 | Loss: 0.274 | Acc: 90.641%
# Batch: 350/391 | Loss: 0.275 | Acc: 90.601%
# Time taken : 1m1s
# Batch: 0/100 | Loss: 0.506 | Acc: 86.000%
# Batch: 50/100 | Loss: 0.460 | Acc: 84.667%
#
# Epoch: 41
# Batch: 0/391 | Loss: 0.373 | Acc: 87.500%
# Batch: 50/391 | Loss: 0.258 | Acc: 91.054%
# Batch: 100/391 | Loss: 0.260 | Acc: 90.811%
# Batch: 150/391 | Loss: 0.259 | Acc: 90.966%
# Batch: 200/391 | Loss: 0.263 | Acc: 90.843%
# Batch: 250/391 | Loss: 0.266 | Acc: 90.756%
# Batch: 300/391 | Loss: 0.268 | Acc: 90.744%
# Batch: 350/391 | Loss: 0.271 | Acc: 90.698%
# Time taken : 1m1s
# Batch: 0/100 | Loss: 0.352 | Acc: 89.000%
# Batch: 50/100 | Loss: 0.371 | Acc: 88.020%
# Saving..
#
# Epoch: 42
# Batch: 0/391 | Loss: 0.190 | Acc: 93.750%
# Batch: 50/391 | Loss: 0.226 | Acc: 92.371%
# Batch: 100/391 | Loss: 0.246 | Acc: 91.600%
# Batch: 150/391 | Loss: 0.255 | Acc: 91.204%
# Batch: 200/391 | Loss: 0.257 | Acc: 91.266%
# Batch: 250/391 | Loss: 0.261 | Acc: 91.114%
# Batch: 300/391 | Loss: 0.260 | Acc: 91.152%
# Batch: 350/391 | Loss: 0.263 | Acc: 91.097%
# Time taken : 59s373ms
# Batch: 0/100 | Loss: 0.519 | Acc: 87.000%
# Batch: 50/100 | Loss: 0.471 | Acc: 84.765%
#
# Epoch: 43
# Batch: 0/391 | Loss: 0.249 | Acc: 91.406%
# Batch: 50/391 | Loss: 0.240 | Acc: 92.142%
# Batch: 100/391 | Loss: 0.234 | Acc: 92.172%
# Batch: 150/391 | Loss: 0.243 | Acc: 91.768%
# Batch: 200/391 | Loss: 0.247 | Acc: 91.500%
# Batch: 250/391 | Loss: 0.251 | Acc: 91.369%
# Batch: 300/391 | Loss: 0.254 | Acc: 91.269%
# Batch: 350/391 | Loss: 0.258 | Acc: 91.146%
# Time taken : 1m26ms
# Batch: 0/100 | Loss: 0.411 | Acc: 85.000%
# Batch: 50/100 | Loss: 0.431 | Acc: 85.843%
#
# Epoch: 44
# Batch: 0/391 | Loss: 0.341 | Acc: 89.062%
# Batch: 50/391 | Loss: 0.261 | Acc: 90.855%
# Batch: 100/391 | Loss: 0.256 | Acc: 91.050%
# Batch: 150/391 | Loss: 0.260 | Acc: 91.029%
# Batch: 200/391 | Loss: 0.258 | Acc: 91.134%
# Batch: 250/391 | Loss: 0.259 | Acc: 91.157%
# Batch: 300/391 | Loss: 0.257 | Acc: 91.209%
# Batch: 350/391 | Loss: 0.257 | Acc: 91.224%
# Time taken : 1m658ms
# Batch: 0/100 | Loss: 0.386 | Acc: 86.000%
# Batch: 50/100 | Loss: 0.389 | Acc: 87.137%
#
# Epoch: 45
# Batch: 0/391 | Loss: 0.196 | Acc: 96.094%
# Batch: 50/391 | Loss: 0.221 | Acc: 92.586%
# Batch: 100/391 | Loss: 0.232 | Acc: 92.257%
# Batch: 150/391 | Loss: 0.236 | Acc: 92.079%
# Batch: 200/391 | Loss: 0.235 | Acc: 91.970%
# Batch: 250/391 | Loss: 0.245 | Acc: 91.646%
# Batch: 300/391 | Loss: 0.246 | Acc: 91.616%
# Batch: 350/391 | Loss: 0.247 | Acc: 91.558%
# Time taken : 1m1s
# Batch: 0/100 | Loss: 0.509 | Acc: 86.000%
# Batch: 50/100 | Loss: 0.454 | Acc: 85.647%
#
# Epoch: 46
# Batch: 0/391 | Loss: 0.371 | Acc: 86.719%
# Batch: 50/391 | Loss: 0.229 | Acc: 92.264%
# Batch: 100/391 | Loss: 0.229 | Acc: 92.164%
# Batch: 150/391 | Loss: 0.233 | Acc: 91.981%
# Batch: 200/391 | Loss: 0.241 | Acc: 91.628%
# Batch: 250/391 | Loss: 0.242 | Acc: 91.633%
# Batch: 300/391 | Loss: 0.244 | Acc: 91.580%
# Batch: 350/391 | Loss: 0.242 | Acc: 91.618%
# Time taken : 1m1s
# Batch: 0/100 | Loss: 0.490 | Acc: 86.000%
# Batch: 50/100 | Loss: 0.516 | Acc: 84.137%
#
# Epoch: 47
# Batch: 0/391 | Loss: 0.261 | Acc: 90.625%
# Batch: 50/391 | Loss: 0.216 | Acc: 93.015%
# Batch: 100/391 | Loss: 0.229 | Acc: 92.520%
# Batch: 150/391 | Loss: 0.229 | Acc: 92.436%
# Batch: 200/391 | Loss: 0.233 | Acc: 92.191%
# Batch: 250/391 | Loss: 0.230 | Acc: 92.287%
# Batch: 300/391 | Loss: 0.235 | Acc: 92.099%
# Batch: 350/391 | Loss: 0.237 | Acc: 91.978%
# Time taken : 1m1s
# Batch: 0/100 | Loss: 0.378 | Acc: 87.000%
# Batch: 50/100 | Loss: 0.342 | Acc: 89.039%
# Saving..
#
# Epoch: 48
# Batch: 0/391 | Loss: 0.160 | Acc: 94.531%
# Batch: 50/391 | Loss: 0.207 | Acc: 93.183%
# Batch: 100/391 | Loss: 0.218 | Acc: 92.683%
# Batch: 150/391 | Loss: 0.219 | Acc: 92.726%
# Batch: 200/391 | Loss: 0.219 | Acc: 92.685%
# Batch: 250/391 | Loss: 0.224 | Acc: 92.545%
# Batch: 300/391 | Loss: 0.229 | Acc: 92.302%
# Batch: 350/391 | Loss: 0.231 | Acc: 92.243%
# Time taken : 1m963ms
# Batch: 0/100 | Loss: 0.426 | Acc: 89.000%
# Batch: 50/100 | Loss: 0.414 | Acc: 86.882%
#
# Epoch: 49
# Batch: 0/391 | Loss: 0.163 | Acc: 94.531%
# Batch: 50/391 | Loss: 0.221 | Acc: 92.295%
# Batch: 100/391 | Loss: 0.215 | Acc: 92.543%
# Batch: 150/391 | Loss: 0.210 | Acc: 92.700%
# Batch: 200/391 | Loss: 0.215 | Acc: 92.592%
# Batch: 250/391 | Loss: 0.222 | Acc: 92.340%
# Batch: 300/391 | Loss: 0.225 | Acc: 92.237%
# Batch: 350/391 | Loss: 0.230 | Acc: 92.078%
# Time taken : 59s787ms
# Batch: 0/100 | Loss: 0.390 | Acc: 85.000%
# Batch: 50/100 | Loss: 0.385 | Acc: 87.392%
#
# Epoch: 50
# Batch: 0/391 | Loss: 0.167 | Acc: 94.531%
# Batch: 50/391 | Loss: 0.209 | Acc: 92.540%
# Batch: 100/391 | Loss: 0.201 | Acc: 93.031%
# Batch: 150/391 | Loss: 0.204 | Acc: 92.948%
# Batch: 200/391 | Loss: 0.206 | Acc: 92.844%
# Batch: 250/391 | Loss: 0.215 | Acc: 92.629%
# Batch: 300/391 | Loss: 0.221 | Acc: 92.411%
# Batch: 350/391 | Loss: 0.225 | Acc: 92.290%
# Time taken : 1m925ms
# Batch: 0/100 | Loss: 0.362 | Acc: 89.000%
# Batch: 50/100 | Loss: 0.315 | Acc: 89.098%
# Saving..
#
# Epoch: 51
# Batch: 0/391 | Loss: 0.164 | Acc: 94.531%
# Batch: 50/391 | Loss: 0.202 | Acc: 93.275%
# Batch: 100/391 | Loss: 0.207 | Acc: 93.007%
# Batch: 150/391 | Loss: 0.210 | Acc: 92.881%
# Batch: 200/391 | Loss: 0.215 | Acc: 92.697%
# Batch: 250/391 | Loss: 0.215 | Acc: 92.605%
# Batch: 300/391 | Loss: 0.217 | Acc: 92.483%
# Batch: 350/391 | Loss: 0.220 | Acc: 92.352%
# Time taken : 1m40ms
# Batch: 0/100 | Loss: 0.309 | Acc: 88.000%
# Batch: 50/100 | Loss: 0.295 | Acc: 90.235%
# Saving..
#
# Epoch: 52
# Batch: 0/391 | Loss: 0.136 | Acc: 93.750%
# Batch: 50/391 | Loss: 0.192 | Acc: 93.428%
# Batch: 100/391 | Loss: 0.196 | Acc: 93.487%
# Batch: 150/391 | Loss: 0.196 | Acc: 93.383%
# Batch: 200/391 | Loss: 0.197 | Acc: 93.303%
# Batch: 250/391 | Loss: 0.197 | Acc: 93.277%
# Batch: 300/391 | Loss: 0.203 | Acc: 93.057%
# Batch: 350/391 | Loss: 0.204 | Acc: 93.007%
# Time taken : 1m67ms
# Batch: 0/100 | Loss: 0.379 | Acc: 86.000%
# Batch: 50/100 | Loss: 0.370 | Acc: 87.686%
#
# Epoch: 53
# Batch: 0/391 | Loss: 0.175 | Acc: 91.406%
# Batch: 50/391 | Loss: 0.195 | Acc: 93.122%
# Batch: 100/391 | Loss: 0.194 | Acc: 93.123%
# Batch: 150/391 | Loss: 0.198 | Acc: 92.922%
# Batch: 200/391 | Loss: 0.200 | Acc: 92.988%
# Batch: 250/391 | Loss: 0.203 | Acc: 92.875%
# Batch: 300/391 | Loss: 0.205 | Acc: 92.821%
# Batch: 350/391 | Loss: 0.206 | Acc: 92.835%
# Time taken : 1m2s
# Batch: 0/100 | Loss: 0.361 | Acc: 87.000%
# Batch: 50/100 | Loss: 0.341 | Acc: 88.627%
#
# Epoch: 54
# Batch: 0/391 | Loss: 0.181 | Acc: 93.750%
# Batch: 50/391 | Loss: 0.181 | Acc: 93.888%
# Batch: 100/391 | Loss: 0.179 | Acc: 93.936%
# Batch: 150/391 | Loss: 0.189 | Acc: 93.569%
# Batch: 200/391 | Loss: 0.191 | Acc: 93.462%
# Batch: 250/391 | Loss: 0.194 | Acc: 93.292%
# Batch: 300/391 | Loss: 0.197 | Acc: 93.195%
# Batch: 350/391 | Loss: 0.200 | Acc: 93.053%
# Time taken : 1m748ms
# Batch: 0/100 | Loss: 0.322 | Acc: 90.000%
# Batch: 50/100 | Loss: 0.333 | Acc: 89.137%
#
# Epoch: 55
# Batch: 0/391 | Loss: 0.177 | Acc: 96.094%
# Batch: 50/391 | Loss: 0.184 | Acc: 93.796%
# Batch: 100/391 | Loss: 0.192 | Acc: 93.255%
# Batch: 150/391 | Loss: 0.192 | Acc: 93.341%
# Batch: 200/391 | Loss: 0.196 | Acc: 93.295%
# Batch: 250/391 | Loss: 0.197 | Acc: 93.240%
# Batch: 300/391 | Loss: 0.198 | Acc: 93.249%
# Batch: 350/391 | Loss: 0.198 | Acc: 93.185%
# Time taken : 1m262ms
# Batch: 0/100 | Loss: 0.319 | Acc: 88.000%
# Batch: 50/100 | Loss: 0.346 | Acc: 88.843%
#
# Epoch: 56
# Batch: 0/391 | Loss: 0.274 | Acc: 90.625%
# Batch: 50/391 | Loss: 0.177 | Acc: 93.949%
# Batch: 100/391 | Loss: 0.175 | Acc: 94.222%
# Batch: 150/391 | Loss: 0.180 | Acc: 93.998%
# Batch: 200/391 | Loss: 0.183 | Acc: 93.859%
# Batch: 250/391 | Loss: 0.186 | Acc: 93.731%
# Batch: 300/391 | Loss: 0.189 | Acc: 93.620%
# Batch: 350/391 | Loss: 0.189 | Acc: 93.588%
# Time taken : 1m785ms
# Batch: 0/100 | Loss: 0.250 | Acc: 93.000%
# Batch: 50/100 | Loss: 0.342 | Acc: 88.843%
#
# Epoch: 57
# Batch: 0/391 | Loss: 0.170 | Acc: 94.531%
# Batch: 50/391 | Loss: 0.170 | Acc: 94.118%
# Batch: 100/391 | Loss: 0.170 | Acc: 94.175%
# Batch: 150/391 | Loss: 0.173 | Acc: 94.029%
# Batch: 200/391 | Loss: 0.176 | Acc: 93.886%
# Batch: 250/391 | Loss: 0.181 | Acc: 93.747%
# Batch: 300/391 | Loss: 0.182 | Acc: 93.685%
# Batch: 350/391 | Loss: 0.185 | Acc: 93.594%
# Time taken : 1m1s
# Batch: 0/100 | Loss: 0.382 | Acc: 89.000%
# Batch: 50/100 | Loss: 0.354 | Acc: 88.804%
#
# Epoch: 58
# Batch: 0/391 | Loss: 0.151 | Acc: 95.312%
# Batch: 50/391 | Loss: 0.160 | Acc: 94.807%
# Batch: 100/391 | Loss: 0.158 | Acc: 94.794%
# Batch: 150/391 | Loss: 0.164 | Acc: 94.443%
# Batch: 200/391 | Loss: 0.168 | Acc: 94.275%
# Batch: 250/391 | Loss: 0.172 | Acc: 94.083%
# Batch: 300/391 | Loss: 0.175 | Acc: 94.012%
# Batch: 350/391 | Loss: 0.177 | Acc: 93.973%
# Time taken : 1m609ms
# Batch: 0/100 | Loss: 0.271 | Acc: 92.000%
# Batch: 50/100 | Loss: 0.341 | Acc: 89.196%
#
# Epoch: 59
# Batch: 0/391 | Loss: 0.152 | Acc: 94.531%
# Batch: 50/391 | Loss: 0.143 | Acc: 94.960%
# Batch: 100/391 | Loss: 0.161 | Acc: 94.384%
# Batch: 150/391 | Loss: 0.162 | Acc: 94.350%
# Batch: 200/391 | Loss: 0.168 | Acc: 94.065%
# Batch: 250/391 | Loss: 0.169 | Acc: 94.117%
# Batch: 300/391 | Loss: 0.174 | Acc: 93.999%
# Batch: 350/391 | Loss: 0.173 | Acc: 94.010%
# Time taken : 1m81ms
# Batch: 0/100 | Loss: 0.290 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.289 | Acc: 91.255%
# Saving..
#
# Epoch: 60
# Batch: 0/391 | Loss: 0.191 | Acc: 92.969%
# Batch: 50/391 | Loss: 0.149 | Acc: 94.700%
# Batch: 100/391 | Loss: 0.155 | Acc: 94.624%
# Batch: 150/391 | Loss: 0.156 | Acc: 94.531%
# Batch: 200/391 | Loss: 0.159 | Acc: 94.411%
# Batch: 250/391 | Loss: 0.160 | Acc: 94.404%
# Batch: 300/391 | Loss: 0.160 | Acc: 94.456%
# Batch: 350/391 | Loss: 0.161 | Acc: 94.384%
# Time taken : 58s957ms
# Batch: 0/100 | Loss: 0.291 | Acc: 92.000%
# Batch: 50/100 | Loss: 0.295 | Acc: 90.392%
#
# Epoch: 61
# Batch: 0/391 | Loss: 0.119 | Acc: 96.094%
# Batch: 50/391 | Loss: 0.144 | Acc: 95.236%
# Batch: 100/391 | Loss: 0.143 | Acc: 95.196%
# Batch: 150/391 | Loss: 0.144 | Acc: 95.131%
# Batch: 200/391 | Loss: 0.147 | Acc: 95.037%
# Batch: 250/391 | Loss: 0.147 | Acc: 94.998%
# Batch: 300/391 | Loss: 0.148 | Acc: 94.957%
# Batch: 350/391 | Loss: 0.152 | Acc: 94.843%
# Time taken : 1m1s
# Batch: 0/100 | Loss: 0.433 | Acc: 91.000%
# Batch: 50/100 | Loss: 0.330 | Acc: 89.275%
#
# Epoch: 62
# Batch: 0/391 | Loss: 0.132 | Acc: 96.094%
# Batch: 50/391 | Loss: 0.139 | Acc: 95.251%
# Batch: 100/391 | Loss: 0.132 | Acc: 95.583%
# Batch: 150/391 | Loss: 0.132 | Acc: 95.545%
# Batch: 200/391 | Loss: 0.137 | Acc: 95.359%
# Batch: 250/391 | Loss: 0.141 | Acc: 95.244%
# Batch: 300/391 | Loss: 0.144 | Acc: 95.089%
# Batch: 350/391 | Loss: 0.148 | Acc: 94.921%
# Time taken : 1m1s
# Batch: 0/100 | Loss: 0.370 | Acc: 88.000%
# Batch: 50/100 | Loss: 0.330 | Acc: 89.980%
#
# Epoch: 63
# Batch: 0/391 | Loss: 0.121 | Acc: 94.531%
# Batch: 50/391 | Loss: 0.136 | Acc: 95.450%
# Batch: 100/391 | Loss: 0.139 | Acc: 95.312%
# Batch: 150/391 | Loss: 0.141 | Acc: 95.209%
# Batch: 200/391 | Loss: 0.143 | Acc: 95.141%
# Batch: 250/391 | Loss: 0.143 | Acc: 95.129%
# Batch: 300/391 | Loss: 0.145 | Acc: 95.011%
# Batch: 350/391 | Loss: 0.147 | Acc: 94.974%
# Time taken : 1m2s
# Batch: 0/100 | Loss: 0.393 | Acc: 89.000%
# Batch: 50/100 | Loss: 0.299 | Acc: 90.333%
# Saving..
#
# Epoch: 64
# Batch: 0/391 | Loss: 0.205 | Acc: 94.531%
# Batch: 50/391 | Loss: 0.139 | Acc: 95.404%
# Batch: 100/391 | Loss: 0.130 | Acc: 95.730%
# Batch: 150/391 | Loss: 0.130 | Acc: 95.592%
# Batch: 200/391 | Loss: 0.129 | Acc: 95.647%
# Batch: 250/391 | Loss: 0.133 | Acc: 95.558%
# Batch: 300/391 | Loss: 0.135 | Acc: 95.489%
# Batch: 350/391 | Loss: 0.136 | Acc: 95.444%
# Time taken : 1m517ms
# Batch: 0/100 | Loss: 0.344 | Acc: 89.000%
# Batch: 50/100 | Loss: 0.299 | Acc: 90.667%
# Saving..
#
# Epoch: 65
# Batch: 0/391 | Loss: 0.092 | Acc: 96.875%
# Batch: 50/391 | Loss: 0.123 | Acc: 95.849%
# Batch: 100/391 | Loss: 0.125 | Acc: 95.815%
# Batch: 150/391 | Loss: 0.119 | Acc: 96.006%
# Batch: 200/391 | Loss: 0.121 | Acc: 95.899%
# Batch: 250/391 | Loss: 0.124 | Acc: 95.842%
# Batch: 300/391 | Loss: 0.126 | Acc: 95.785%
# Batch: 350/391 | Loss: 0.127 | Acc: 95.729%
# Time taken : 1m1s
# Batch: 0/100 | Loss: 0.262 | Acc: 92.000%
# Batch: 50/100 | Loss: 0.253 | Acc: 91.902%
# Saving..
#
# Epoch: 66
# Batch: 0/391 | Loss: 0.059 | Acc: 98.438%
# Batch: 50/391 | Loss: 0.097 | Acc: 96.706%
# Batch: 100/391 | Loss: 0.101 | Acc: 96.713%
# Batch: 150/391 | Loss: 0.105 | Acc: 96.549%
# Batch: 200/391 | Loss: 0.111 | Acc: 96.315%
# Batch: 250/391 | Loss: 0.115 | Acc: 96.175%
# Batch: 300/391 | Loss: 0.117 | Acc: 96.065%
# Batch: 350/391 | Loss: 0.121 | Acc: 95.931%
# Time taken : 1m1s
# Batch: 0/100 | Loss: 0.341 | Acc: 89.000%
# Batch: 50/100 | Loss: 0.278 | Acc: 91.588%
#
# Epoch: 67
# Batch: 0/391 | Loss: 0.151 | Acc: 94.531%
# Batch: 50/391 | Loss: 0.118 | Acc: 95.925%
# Batch: 100/391 | Loss: 0.111 | Acc: 96.248%
# Batch: 150/391 | Loss: 0.111 | Acc: 96.228%
# Batch: 200/391 | Loss: 0.112 | Acc: 96.164%
# Batch: 250/391 | Loss: 0.116 | Acc: 96.013%
# Batch: 300/391 | Loss: 0.118 | Acc: 95.930%
# Batch: 350/391 | Loss: 0.118 | Acc: 95.867%
# Time taken : 57s923ms
# Batch: 0/100 | Loss: 0.204 | Acc: 93.000%
# Batch: 50/100 | Loss: 0.256 | Acc: 92.431%
# Saving..
#
# Epoch: 68
# Batch: 0/391 | Loss: 0.179 | Acc: 93.750%
# Batch: 50/391 | Loss: 0.109 | Acc: 96.523%
# Batch: 100/391 | Loss: 0.105 | Acc: 96.488%
# Batch: 150/391 | Loss: 0.107 | Acc: 96.430%
# Batch: 200/391 | Loss: 0.113 | Acc: 96.175%
# Batch: 250/391 | Loss: 0.115 | Acc: 96.128%
# Batch: 300/391 | Loss: 0.117 | Acc: 96.047%
# Batch: 350/391 | Loss: 0.118 | Acc: 95.991%
# Time taken : 1m1s
# Batch: 0/100 | Loss: 0.304 | Acc: 92.000%
# Batch: 50/100 | Loss: 0.304 | Acc: 90.392%
#
# Epoch: 69
# Batch: 0/391 | Loss: 0.082 | Acc: 97.656%
# Batch: 50/391 | Loss: 0.090 | Acc: 96.722%
# Batch: 100/391 | Loss: 0.090 | Acc: 96.813%
# Batch: 150/391 | Loss: 0.093 | Acc: 96.772%
# Batch: 200/391 | Loss: 0.095 | Acc: 96.688%
# Batch: 250/391 | Loss: 0.097 | Acc: 96.670%
# Batch: 300/391 | Loss: 0.099 | Acc: 96.566%
# Batch: 350/391 | Loss: 0.100 | Acc: 96.537%
# Time taken : 1m737ms
# Batch: 0/100 | Loss: 0.288 | Acc: 90.000%
# Batch: 50/100 | Loss: 0.289 | Acc: 91.255%
#
# Epoch: 70
# Batch: 0/391 | Loss: 0.078 | Acc: 96.875%
# Batch: 50/391 | Loss: 0.092 | Acc: 96.936%
# Batch: 100/391 | Loss: 0.089 | Acc: 96.937%
# Batch: 150/391 | Loss: 0.093 | Acc: 96.756%
# Batch: 200/391 | Loss: 0.094 | Acc: 96.727%
# Batch: 250/391 | Loss: 0.096 | Acc: 96.663%
# Batch: 300/391 | Loss: 0.095 | Acc: 96.714%
# Batch: 350/391 | Loss: 0.097 | Acc: 96.668%
# Time taken : 1m955ms
# Batch: 0/100 | Loss: 0.224 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.266 | Acc: 92.137%
#
# Epoch: 71
# Batch: 0/391 | Loss: 0.048 | Acc: 99.219%
# Batch: 50/391 | Loss: 0.089 | Acc: 96.936%
# Batch: 100/391 | Loss: 0.087 | Acc: 97.061%
# Batch: 150/391 | Loss: 0.084 | Acc: 97.222%
# Batch: 200/391 | Loss: 0.084 | Acc: 97.159%
# Batch: 250/391 | Loss: 0.085 | Acc: 97.149%
# Batch: 300/391 | Loss: 0.084 | Acc: 97.163%
# Batch: 350/391 | Loss: 0.085 | Acc: 97.142%
# Time taken : 1m545ms
# Batch: 0/100 | Loss: 0.217 | Acc: 92.000%
# Batch: 50/100 | Loss: 0.245 | Acc: 92.667%
#
# Epoch: 72
# Batch: 0/391 | Loss: 0.091 | Acc: 96.094%
# Batch: 50/391 | Loss: 0.091 | Acc: 96.875%
# Batch: 100/391 | Loss: 0.085 | Acc: 97.099%
# Batch: 150/391 | Loss: 0.081 | Acc: 97.232%
# Batch: 200/391 | Loss: 0.082 | Acc: 97.159%
# Batch: 250/391 | Loss: 0.081 | Acc: 97.199%
# Batch: 300/391 | Loss: 0.082 | Acc: 97.179%
# Batch: 350/391 | Loss: 0.084 | Acc: 97.109%
# Time taken : 58s970ms
# Batch: 0/100 | Loss: 0.304 | Acc: 93.000%
# Batch: 50/100 | Loss: 0.239 | Acc: 92.588%
# Saving..
#
# Epoch: 73
# Batch: 0/391 | Loss: 0.056 | Acc: 98.438%
# Batch: 50/391 | Loss: 0.067 | Acc: 97.794%
# Batch: 100/391 | Loss: 0.065 | Acc: 97.888%
# Batch: 150/391 | Loss: 0.064 | Acc: 97.910%
# Batch: 200/391 | Loss: 0.064 | Acc: 97.936%
# Batch: 250/391 | Loss: 0.066 | Acc: 97.877%
# Batch: 300/391 | Loss: 0.069 | Acc: 97.747%
# Batch: 350/391 | Loss: 0.071 | Acc: 97.625%
# Time taken : 59s264ms
# Batch: 0/100 | Loss: 0.401 | Acc: 90.000%
# Batch: 50/100 | Loss: 0.256 | Acc: 92.216%
#
# Epoch: 74
# Batch: 0/391 | Loss: 0.051 | Acc: 99.219%
# Batch: 50/391 | Loss: 0.071 | Acc: 97.656%
# Batch: 100/391 | Loss: 0.073 | Acc: 97.618%
# Batch: 150/391 | Loss: 0.073 | Acc: 97.568%
# Batch: 200/391 | Loss: 0.071 | Acc: 97.645%
# Batch: 250/391 | Loss: 0.071 | Acc: 97.653%
# Batch: 300/391 | Loss: 0.072 | Acc: 97.581%
# Batch: 350/391 | Loss: 0.071 | Acc: 97.594%
# Time taken : 1m707ms
# Batch: 0/100 | Loss: 0.206 | Acc: 96.000%
# Batch: 50/100 | Loss: 0.248 | Acc: 92.706%
# Saving..
#
# Epoch: 75
# Batch: 0/391 | Loss: 0.095 | Acc: 95.312%
# Batch: 50/391 | Loss: 0.063 | Acc: 97.978%
# Batch: 100/391 | Loss: 0.063 | Acc: 97.881%
# Batch: 150/391 | Loss: 0.063 | Acc: 97.853%
# Batch: 200/391 | Loss: 0.064 | Acc: 97.851%
# Batch: 250/391 | Loss: 0.063 | Acc: 97.890%
# Batch: 300/391 | Loss: 0.063 | Acc: 97.913%
# Batch: 350/391 | Loss: 0.064 | Acc: 97.861%
# Time taken : 59s66ms
# Batch: 0/100 | Loss: 0.374 | Acc: 92.000%
# Batch: 50/100 | Loss: 0.302 | Acc: 91.471%
#
# Epoch: 76
# Batch: 0/391 | Loss: 0.083 | Acc: 98.438%
# Batch: 50/391 | Loss: 0.054 | Acc: 98.284%
# Batch: 100/391 | Loss: 0.054 | Acc: 98.221%
# Batch: 150/391 | Loss: 0.051 | Acc: 98.386%
# Batch: 200/391 | Loss: 0.051 | Acc: 98.325%
# Batch: 250/391 | Loss: 0.050 | Acc: 98.360%
# Batch: 300/391 | Loss: 0.051 | Acc: 98.331%
# Batch: 350/391 | Loss: 0.052 | Acc: 98.255%
# Time taken : 1m345ms
# Batch: 0/100 | Loss: 0.276 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.259 | Acc: 92.843%
# Saving..
#
# Epoch: 77
# Batch: 0/391 | Loss: 0.049 | Acc: 97.656%
# Batch: 50/391 | Loss: 0.047 | Acc: 98.453%
# Batch: 100/391 | Loss: 0.048 | Acc: 98.383%
# Batch: 150/391 | Loss: 0.048 | Acc: 98.370%
# Batch: 200/391 | Loss: 0.049 | Acc: 98.348%
# Batch: 250/391 | Loss: 0.048 | Acc: 98.394%
# Batch: 300/391 | Loss: 0.049 | Acc: 98.365%
# Batch: 350/391 | Loss: 0.050 | Acc: 98.355%
# Time taken : 1m1s
# Batch: 0/100 | Loss: 0.176 | Acc: 96.000%
# Batch: 50/100 | Loss: 0.246 | Acc: 93.157%
# Saving..
#
# Epoch: 78
# Batch: 0/391 | Loss: 0.037 | Acc: 99.219%
# Batch: 50/391 | Loss: 0.036 | Acc: 98.866%
# Batch: 100/391 | Loss: 0.036 | Acc: 98.902%
# Batch: 150/391 | Loss: 0.038 | Acc: 98.800%
# Batch: 200/391 | Loss: 0.039 | Acc: 98.748%
# Batch: 250/391 | Loss: 0.041 | Acc: 98.711%
# Batch: 300/391 | Loss: 0.042 | Acc: 98.658%
# Batch: 350/391 | Loss: 0.043 | Acc: 98.616%
# Time taken : 1m1s
# Batch: 0/100 | Loss: 0.267 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.270 | Acc: 92.588%
#
# Epoch: 79
# Batch: 0/391 | Loss: 0.055 | Acc: 98.438%
# Batch: 50/391 | Loss: 0.049 | Acc: 98.392%
# Batch: 100/391 | Loss: 0.043 | Acc: 98.615%
# Batch: 150/391 | Loss: 0.040 | Acc: 98.732%
# Batch: 200/391 | Loss: 0.040 | Acc: 98.756%
# Batch: 250/391 | Loss: 0.039 | Acc: 98.780%
# Batch: 300/391 | Loss: 0.039 | Acc: 98.765%
# Batch: 350/391 | Loss: 0.040 | Acc: 98.742%
# Time taken : 1m716ms
# Batch: 0/100 | Loss: 0.174 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.246 | Acc: 93.333%
#
# Epoch: 80
# Batch: 0/391 | Loss: 0.026 | Acc: 98.438%
# Batch: 50/391 | Loss: 0.029 | Acc: 99.050%
# Batch: 100/391 | Loss: 0.030 | Acc: 99.025%
# Batch: 150/391 | Loss: 0.033 | Acc: 98.981%
# Batch: 200/391 | Loss: 0.034 | Acc: 98.927%
# Batch: 250/391 | Loss: 0.033 | Acc: 98.960%
# Batch: 300/391 | Loss: 0.033 | Acc: 98.949%
# Batch: 350/391 | Loss: 0.034 | Acc: 98.894%
# Time taken : 1m551ms
# Batch: 0/100 | Loss: 0.272 | Acc: 93.000%
# Batch: 50/100 | Loss: 0.234 | Acc: 93.765%
# Saving..
#
# Epoch: 81
# Batch: 0/391 | Loss: 0.017 | Acc: 99.219%
# Batch: 50/391 | Loss: 0.032 | Acc: 99.142%
# Batch: 100/391 | Loss: 0.028 | Acc: 99.196%
# Batch: 150/391 | Loss: 0.027 | Acc: 99.146%
# Batch: 200/391 | Loss: 0.026 | Acc: 99.176%
# Batch: 250/391 | Loss: 0.027 | Acc: 99.113%
# Batch: 300/391 | Loss: 0.028 | Acc: 99.076%
# Batch: 350/391 | Loss: 0.028 | Acc: 99.076%
# Time taken : 1m719ms
# Batch: 0/100 | Loss: 0.247 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.238 | Acc: 93.667%
# Saving..
#
# Epoch: 82
# Batch: 0/391 | Loss: 0.005 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.026 | Acc: 99.188%
# Batch: 100/391 | Loss: 0.024 | Acc: 99.250%
# Batch: 150/391 | Loss: 0.023 | Acc: 99.250%
# Batch: 200/391 | Loss: 0.023 | Acc: 99.254%
# Batch: 250/391 | Loss: 0.023 | Acc: 99.265%
# Batch: 300/391 | Loss: 0.024 | Acc: 99.240%
# Batch: 350/391 | Loss: 0.024 | Acc: 99.248%
# Time taken : 59s892ms
# Batch: 0/100 | Loss: 0.246 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.221 | Acc: 94.078%
# Saving..
#
# Epoch: 83
# Batch: 0/391 | Loss: 0.006 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.017 | Acc: 99.479%
# Batch: 100/391 | Loss: 0.017 | Acc: 99.505%
# Batch: 150/391 | Loss: 0.018 | Acc: 99.467%
# Batch: 200/391 | Loss: 0.018 | Acc: 99.456%
# Batch: 250/391 | Loss: 0.019 | Acc: 99.452%
# Batch: 300/391 | Loss: 0.019 | Acc: 99.460%
# Batch: 350/391 | Loss: 0.019 | Acc: 99.448%
# Time taken : 1m267ms
# Batch: 0/100 | Loss: 0.201 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.231 | Acc: 93.627%
#
# Epoch: 84
# Batch: 0/391 | Loss: 0.012 | Acc: 99.219%
# Batch: 50/391 | Loss: 0.015 | Acc: 99.571%
# Batch: 100/391 | Loss: 0.015 | Acc: 99.606%
# Batch: 150/391 | Loss: 0.015 | Acc: 99.596%
# Batch: 200/391 | Loss: 0.016 | Acc: 99.561%
# Batch: 250/391 | Loss: 0.015 | Acc: 99.564%
# Batch: 300/391 | Loss: 0.016 | Acc: 99.556%
# Batch: 350/391 | Loss: 0.016 | Acc: 99.564%
# Time taken : 1m1s
# Batch: 0/100 | Loss: 0.257 | Acc: 96.000%
# Batch: 50/100 | Loss: 0.219 | Acc: 93.961%
# Saving..
#
# Epoch: 85
# Batch: 0/391 | Loss: 0.010 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.017 | Acc: 99.510%
# Batch: 100/391 | Loss: 0.016 | Acc: 99.482%
# Batch: 150/391 | Loss: 0.015 | Acc: 99.534%
# Batch: 200/391 | Loss: 0.014 | Acc: 99.596%
# Batch: 250/391 | Loss: 0.014 | Acc: 99.608%
# Batch: 300/391 | Loss: 0.014 | Acc: 99.616%
# Batch: 350/391 | Loss: 0.014 | Acc: 99.615%
# Time taken : 1m574ms
# Batch: 0/100 | Loss: 0.221 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.217 | Acc: 93.804%
#
# Epoch: 86
# Batch: 0/391 | Loss: 0.034 | Acc: 99.219%
# Batch: 50/391 | Loss: 0.011 | Acc: 99.770%
# Batch: 100/391 | Loss: 0.011 | Acc: 99.737%
# Batch: 150/391 | Loss: 0.011 | Acc: 99.736%
# Batch: 200/391 | Loss: 0.010 | Acc: 99.763%
# Batch: 250/391 | Loss: 0.010 | Acc: 99.760%
# Batch: 300/391 | Loss: 0.010 | Acc: 99.782%
# Batch: 350/391 | Loss: 0.010 | Acc: 99.786%
# Time taken : 1m409ms
# Batch: 0/100 | Loss: 0.255 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.210 | Acc: 94.314%
# Saving..
#
# Epoch: 87
# Batch: 0/391 | Loss: 0.006 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.007 | Acc: 99.877%
# Batch: 100/391 | Loss: 0.007 | Acc: 99.884%
# Batch: 150/391 | Loss: 0.007 | Acc: 99.876%
# Batch: 200/391 | Loss: 0.007 | Acc: 99.860%
# Batch: 250/391 | Loss: 0.008 | Acc: 99.844%
# Batch: 300/391 | Loss: 0.008 | Acc: 99.839%
# Batch: 350/391 | Loss: 0.008 | Acc: 99.824%
# Time taken : 1m1s
# Batch: 0/100 | Loss: 0.284 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.206 | Acc: 94.529%
# Saving..
#
# Epoch: 88
# Batch: 0/391 | Loss: 0.002 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.005 | Acc: 99.893%
# Batch: 100/391 | Loss: 0.006 | Acc: 99.892%
# Batch: 150/391 | Loss: 0.006 | Acc: 99.881%
# Batch: 200/391 | Loss: 0.006 | Acc: 99.883%
# Batch: 250/391 | Loss: 0.006 | Acc: 99.869%
# Batch: 300/391 | Loss: 0.006 | Acc: 99.857%
# Batch: 350/391 | Loss: 0.007 | Acc: 99.844%
# Time taken : 59s321ms
# Batch: 0/100 | Loss: 0.274 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.201 | Acc: 94.451%
# Saving..
#
# Epoch: 89
# Batch: 0/391 | Loss: 0.010 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.004 | Acc: 99.954%
# Batch: 100/391 | Loss: 0.005 | Acc: 99.930%
# Batch: 150/391 | Loss: 0.005 | Acc: 99.907%
# Batch: 200/391 | Loss: 0.005 | Acc: 99.907%
# Batch: 250/391 | Loss: 0.006 | Acc: 99.888%
# Batch: 300/391 | Loss: 0.006 | Acc: 99.883%
# Batch: 350/391 | Loss: 0.006 | Acc: 99.889%
# Time taken : 1m265ms
# Batch: 0/100 | Loss: 0.247 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.205 | Acc: 94.647%
# Saving..
#
# Epoch: 90
# Batch: 0/391 | Loss: 0.003 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.005 | Acc: 99.923%
# Batch: 100/391 | Loss: 0.005 | Acc: 99.915%
# Batch: 150/391 | Loss: 0.005 | Acc: 99.902%
# Batch: 200/391 | Loss: 0.006 | Acc: 99.899%
# Batch: 250/391 | Loss: 0.005 | Acc: 99.913%
# Batch: 300/391 | Loss: 0.005 | Acc: 99.909%
# Batch: 350/391 | Loss: 0.005 | Acc: 99.911%
# Time taken : 59s571ms
# Batch: 0/100 | Loss: 0.251 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.202 | Acc: 94.549%
#
# Epoch: 91
# Batch: 0/391 | Loss: 0.010 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.004 | Acc: 99.939%
# Batch: 100/391 | Loss: 0.005 | Acc: 99.930%
# Batch: 150/391 | Loss: 0.004 | Acc: 99.948%
# Batch: 200/391 | Loss: 0.004 | Acc: 99.949%
# Batch: 250/391 | Loss: 0.004 | Acc: 99.950%
# Batch: 300/391 | Loss: 0.004 | Acc: 99.943%
# Batch: 350/391 | Loss: 0.004 | Acc: 99.942%
# Time taken : 59s805ms
# Batch: 0/100 | Loss: 0.270 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.199 | Acc: 94.765%
# Saving..
#
# Epoch: 92
# Batch: 0/391 | Loss: 0.001 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.004 | Acc: 99.908%
# Batch: 100/391 | Loss: 0.004 | Acc: 99.923%
# Batch: 150/391 | Loss: 0.004 | Acc: 99.938%
# Batch: 200/391 | Loss: 0.004 | Acc: 99.942%
# Batch: 250/391 | Loss: 0.004 | Acc: 99.938%
# Batch: 300/391 | Loss: 0.004 | Acc: 99.948%
# Batch: 350/391 | Loss: 0.004 | Acc: 99.947%
# Time taken : 1m1s
# Batch: 0/100 | Loss: 0.271 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.200 | Acc: 94.745%
#
# Epoch: 93
# Batch: 0/391 | Loss: 0.001 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.003 | Acc: 99.985%
# Batch: 100/391 | Loss: 0.003 | Acc: 99.985%
# Batch: 150/391 | Loss: 0.003 | Acc: 99.974%
# Batch: 200/391 | Loss: 0.003 | Acc: 99.977%
# Batch: 250/391 | Loss: 0.003 | Acc: 99.972%
# Batch: 300/391 | Loss: 0.003 | Acc: 99.969%
# Batch: 350/391 | Loss: 0.003 | Acc: 99.969%
# Time taken : 59s838ms
# Batch: 0/100 | Loss: 0.264 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.202 | Acc: 94.725%
#
# Epoch: 94
# Batch: 0/391 | Loss: 0.003 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.004 | Acc: 99.954%
# Batch: 100/391 | Loss: 0.004 | Acc: 99.946%
# Batch: 150/391 | Loss: 0.004 | Acc: 99.943%
# Batch: 200/391 | Loss: 0.003 | Acc: 99.942%
# Batch: 250/391 | Loss: 0.003 | Acc: 99.947%
# Batch: 300/391 | Loss: 0.003 | Acc: 99.945%
# Batch: 350/391 | Loss: 0.004 | Acc: 99.947%
# Time taken : 59s173ms
# Batch: 0/100 | Loss: 0.269 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.200 | Acc: 94.824%
#
# Epoch: 95
# Batch: 0/391 | Loss: 0.001 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.003 | Acc: 99.969%
# Batch: 100/391 | Loss: 0.003 | Acc: 99.977%
# Batch: 150/391 | Loss: 0.003 | Acc: 99.974%
# Batch: 200/391 | Loss: 0.003 | Acc: 99.961%
# Batch: 250/391 | Loss: 0.003 | Acc: 99.960%
# Batch: 300/391 | Loss: 0.003 | Acc: 99.964%
# Batch: 350/391 | Loss: 0.003 | Acc: 99.964%
# Time taken : 1m42ms
# Batch: 0/100 | Loss: 0.267 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.201 | Acc: 94.686%
#
# Epoch: 96
# Batch: 0/391 | Loss: 0.002 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.004 | Acc: 99.939%
# Batch: 100/391 | Loss: 0.004 | Acc: 99.938%
# Batch: 150/391 | Loss: 0.004 | Acc: 99.948%
# Batch: 200/391 | Loss: 0.003 | Acc: 99.957%
# Batch: 250/391 | Loss: 0.003 | Acc: 99.947%
# Batch: 300/391 | Loss: 0.003 | Acc: 99.948%
# Batch: 350/391 | Loss: 0.003 | Acc: 99.951%
# Time taken : 55s140ms
# Batch: 0/100 | Loss: 0.260 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.199 | Acc: 94.765%
#
# Epoch: 97
# Batch: 0/391 | Loss: 0.001 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.003 | Acc: 99.985%
# Batch: 100/391 | Loss: 0.003 | Acc: 99.977%
# Batch: 150/391 | Loss: 0.003 | Acc: 99.984%
# Batch: 200/391 | Loss: 0.003 | Acc: 99.984%
# Batch: 250/391 | Loss: 0.003 | Acc: 99.978%
# Batch: 300/391 | Loss: 0.003 | Acc: 99.974%
# Batch: 350/391 | Loss: 0.003 | Acc: 99.973%
# Time taken : 41s346ms
# Batch: 0/100 | Loss: 0.262 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.198 | Acc: 94.627%
#
# Epoch: 98
# Batch: 0/391 | Loss: 0.003 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.003 | Acc: 99.985%
# Batch: 100/391 | Loss: 0.003 | Acc: 99.985%
# Batch: 150/391 | Loss: 0.003 | Acc: 99.979%
# Batch: 200/391 | Loss: 0.003 | Acc: 99.969%
# Batch: 250/391 | Loss: 0.003 | Acc: 99.966%
# Batch: 300/391 | Loss: 0.003 | Acc: 99.964%
# Batch: 350/391 | Loss: 0.003 | Acc: 99.969%
# Time taken : 25s402ms
# Batch: 0/100 | Loss: 0.255 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.198 | Acc: 94.706%
#
# Epoch: 99
# Batch: 0/391 | Loss: 0.001 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.003 | Acc: 99.954%
# Batch: 100/391 | Loss: 0.003 | Acc: 99.969%
# Batch: 150/391 | Loss: 0.003 | Acc: 99.969%
# Batch: 200/391 | Loss: 0.003 | Acc: 99.961%
# Batch: 250/391 | Loss: 0.003 | Acc: 99.963%
# Batch: 300/391 | Loss: 0.003 | Acc: 99.964%
# Batch: 350/391 | Loss: 0.003 | Acc: 99.962%
# Time taken : 18s504ms
# Batch: 0/100 | Loss: 0.248 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.198 | Acc: 94.784%
#
# Epoch: 100
# Batch: 0/391 | Loss: 0.005 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.002 | Acc: 100.000%
# Batch: 100/391 | Loss: 0.003 | Acc: 99.992%
# Batch: 150/391 | Loss: 0.003 | Acc: 99.990%
# Batch: 200/391 | Loss: 0.003 | Acc: 99.988%
# Batch: 250/391 | Loss: 0.003 | Acc: 99.984%
# Batch: 300/391 | Loss: 0.003 | Acc: 99.979%
# Batch: 350/391 | Loss: 0.003 | Acc: 99.980%
# Time taken : 18s179ms
# Batch: 0/100 | Loss: 0.272 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.201 | Acc: 94.627%

# %%
def plot_accuracies(train_accuracies, test_accuracies):
  plt.plot(train_accuracies, label='Train Accuracy')
  plt.plot(test_accuracies, label='Test Accuracy')
  plt.xlabel('Epochs')
  plt.ylabel('Accuracy')
  plt.legend()
  plt.grid(True)
  plt.title('Accuracy vs. No. of epochs')

# %%
def plot_losses(train_losses, test_losses):
  plt.plot(train_losses, label='Train Losses')
  plt.plot(test_losses, label='Test Losses')
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.legend()
  plt.grid(True)
  plt.title('Loss vs. No. of epochs')

# %%
def plot_lrs(train_lrs):
  plt.plot(train_lrs)
  plt.xlabel('Epochs')
  plt.ylabel('Learning rate')
  plt.grid(True)
  plt.title('Learning Rate vs. Epochs')

# %%
plot_accuracies(train_accuracies, test_accuracies)

# %%
plot_losses(train_losses, test_losses)

# %%
plot_lrs(train_lrs)

# %%
print('Saving final model..')
state = {
    'net': model.state_dict(),
    'acc': test_accuracies[-1],
    'epoch': number_of_epochs,
}
if not os.path.isdir('checkpoint_18'):
  os.mkdir('checkpoint_18')
torch.save(state, './checkpoint_18/model_final.pth')
# Out:
# Saving final model..

# %%
import numpy as np
import pickle
from tqdm import tqdm
import pandas as pd

# Function to load CIFAR batch
def load_cifar_batch(file):
    with open(file, 'rb') as fo:
        batch = pickle.load(fo, encoding='bytes')
    return batch

# Specify the folder where the CIFAR-10 batch files are
cifar10_dir = 'data/cifar-10-batches-py/'

# Load the label names
meta_data_dict = load_cifar_batch(os.path.join(cifar10_dir, 'batches.meta'))
label_names = meta_data_dict[b'label_names']

# Load test data
test_batch = load_cifar_batch('CIFAR-10/cifar_test_nolabels.pkl')
test_images = test_batch[b'data'].reshape(-1, 3, 32, 32).transpose(0, 2, 3, 1)

data_statistics = (
    (0.49139968, 0.48215827, 0.44653124),
     (0.24703233, 0.24348505, 0.26158768)
)

# Define transformation for data augmentation
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(*data_statistics, inplace=True)
])

# Apply data augmentation
augmented_test_images = torch.stack([transform(image) for image in test_images])

# Load the trained model
model = ResNet18()

checkpoint = torch.load('./checkpoint_18/ckpt.pth')

# Check the keys in the checkpoint dictionary
print(checkpoint.keys())

# Assuming the model state dictionary is saved under a different key
# Adjust this according to the actual key in your checkpoint file
model.load_state_dict(checkpoint['net'])

model =  model.to(device)

# Evaluate the model on test data
model.eval()
with torch.no_grad():
    outputs = model(augmented_test_images.to(device))
_, predicted = torch.max(outputs, 1)

predicted = predicted.to('cpu')

# Display the first 10 test images and predicted labels
plt.figure(figsize=(20, 4))
for i in range(10):
    plt.subplot(1, 10, i+1)
    plt.imshow(test_images[i])
    plt.title(label_names[predicted[i].item()].decode('utf-8'))
    plt.axis('off')
plt.show()

# Save the output in output.csv containing ID, Labels
output_data = {'ID': np.arange(len(predicted)), 'Labels': predicted.numpy()}
output_df = pd.DataFrame(output_data)
output_df.to_csv('output_rugved_resnet18.csv', index=False)
# Out:
# dict_keys(['net', 'acc', 'epoch'])

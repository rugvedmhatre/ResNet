# %% [markdown]
# # ResNet-18 on CIFAR-10 Dataset

# %% [markdown]
# Importing PyTorch and a few Python Libraries

# %%
import os
import sys
import time
import math

import torch
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import random_split, DataLoader
from torchvision.utils import make_grid

import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
import torch.nn.init as init

from torchsummary import summary

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Preparing the dataset
#
# We will be downloading the train and test CIFAR-10 dataset from torchvision. We will normalize and transform the dataset. For the training dataset, we will also be adding Random Crops and Random Horizontal Flips to generalize the model better.

# %%
data_statistics = (
    (0.49139968, 0.48215827, 0.44653124),
     (0.24703233, 0.24348505, 0.26158768)
) # Mean, Standard Deviation of CIFAR-10 dataset channels

train_transforms = transforms.Compose([
    transforms.RandomCrop(32, padding=4, padding_mode='reflect'), # Adding Random Crops
    transforms.RandomHorizontalFlip(), # Adding Random Horizontal Flips
    transforms.ToTensor(), # Channel x Image Height x Image Width
    transforms.Normalize(*data_statistics, inplace=True) # Output in the range of [-1, 1]
])

test_transforms = transforms.Compose([
    transforms.ToTensor(), # Channel x Image Height x Image Width
    transforms.Normalize(*data_statistics, inplace=True) # Output in the range of [-1, 1]
])

# %%
train_dataset = torchvision.datasets.CIFAR10(root='./data/', download=True, train=True, transform=train_transforms)
test_dataset = torchvision.datasets.CIFAR10(root='./data/', download=True, train=False, transform=test_transforms)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# <!-- We will also be splitting the dataset further into training and validation dataset with a validation ratio of `0.2` -->
#
# We will now create data loaders to retreive images in batches. We are selecting the batch size as `128` images for our train loader. And we are selecting the batch size as `100` images for our test loader.
#
# *From PyTorch Documentation: For data loading, passing pin_memory=True to a DataLoader will automatically put the fetched data Tensors in pinned memory, and thus enables faster data transfer to CUDA-enabled GPUs.*

# %%
# validation_ratio = 0.2
# train_dataset, validation_dataset = random_split(
#     dataset,
#     [int((1 - validation_ratio) * len(dataset)), int(validation_ratio * len(dataset))]
# )

train_batch_size = 128
test_batch_size = 100

train_dl = DataLoader(train_dataset, train_batch_size, shuffle=True, num_workers=2, pin_memory=True)
# validation_dl = DataLoader(validation_dataset, batch_size, shuffle=True, num_workers=3, pin_memory=True)
test_dl = DataLoader(test_dataset, test_batch_size, shuffle=False, num_workers=2, pin_memory=True)

classes = ('plane', 'car', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck')

# %% [markdown]
# We create the following function to display a batch of images from the dataset. And we also need to denormalize the pixels values to bring them back into the range (0,1).

# %%
def denormalize(images, means, stds):
  means = torch.tensor(means).reshape(1, 3, 1, 1)
  stds = torch.tensor(stds).reshape(1, 3, 1, 1)
  return images * stds + means

def show_batch(dl):
  for images, labels in dl:
    fig, ax = plt.subplots(figsize=(12, 12))
    ax.set_xticks([])
    ax.set_yticks([])
    denorm_images = denormalize(images, *data_statistics)
    ax.imshow(make_grid(denorm_images[:64], 8).permute(1, 2, 0))
    break

# %%
show_batch(train_dl)

# %% [markdown]
# To seamlessly use a GPU, if one is available, we define a couple of helper functions (`get_default_device` & `to_device`) and a helper class `DeviceDataLoader` to move our model & data to the GPU as required.

# %%
def get_default_device():
  # Pick GPU, if available, else CPU
  if torch.cuda.is_available():
    return torch.device('cuda')
  else:
    return torch.device('cpu')

def to_device(data, device):
  # Move tensors to chosen device
  if isinstance(data, (list, tuple)):
    # If the instance is a list/tuple, transfer each element to chosen device
    return [to_device(x, device) for x in data]
  return data.to(device, non_blocking=True)
  # non_blocking=True doesn't block the execution of the host device until transfers complete

class DeviceDataLoader():
  # Wrap a dataloader to move data to a device
  def __init__(self, dl, device):
    self.dl = dl
    self.device = device

  def __iter__(self):
    # Yield a batch of data after moving it to device
    for b in self.dl:
      yield to_device(b, self.device)

  def __len__(self):
    # Number of batches
    return len(self.dl)

# %%
# Get the default device
device = get_default_device()
device
# Out:
# device(type='cuda')

# %%
train_dl = DeviceDataLoader(train_dl, device)
# validation_dl = DeviceDataLoader(validation_dl, device)
test_dl = DeviceDataLoader(test_dl, device)

# %% [markdown]
# ## Network Architecture

# %% [markdown]
# Testing the models mentioned in the `pytorch-cifar` [GitHub Repository](https://github.com/kuangliu/pytorch-cifar).

# %% [markdown]
# ### ResNet18

# %%
class BasicBlock(nn.Module):
  expansion = 1

  def __init__(self, in_planes, planes, stride=1):
    super(BasicBlock, self).__init__()
    self.conv1 = nn.Conv2d(
        in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
    self.bn1 = nn.BatchNorm2d(planes)
    self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                            stride=1, padding=1, bias=False)
    self.bn2 = nn.BatchNorm2d(planes)

    self.shortcut = nn.Sequential()
    if stride != 1 or in_planes != self.expansion*planes:
      self.shortcut = nn.Sequential(
          nn.Conv2d(in_planes, self.expansion*planes,
                    kernel_size=1, stride=stride, bias=False),
          nn.BatchNorm2d(self.expansion*planes)
      )

  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))
    out = self.bn2(self.conv2(out))
    out += self.shortcut(x)
    out = F.relu(out)
    return out

class ResNet(nn.Module):
  def __init__(self, block, num_blocks, num_classes=10):
    super(ResNet, self).__init__()
    self.in_planes = 64

    self.conv1 = nn.Conv2d(3, 64, kernel_size=3,
                            stride=1, padding=1, bias=False)
    self.bn1 = nn.BatchNorm2d(64)
    self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
    self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
    self.layer3 = self._make_layer(block, 192, num_blocks[2], stride=2)
    self.layer4 = self._make_layer(block, 256, num_blocks[3], stride=2)
    self.linear = nn.Linear(256*block.expansion, num_classes)

  def _make_layer(self, block, planes, num_blocks, stride):
    strides = [stride] + [1]*(num_blocks-1)
    layers = []
    for stride in strides:
      layers.append(block(self.in_planes, planes, stride))
      self.in_planes = planes * block.expansion
    return nn.Sequential(*layers)

  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))
    out = self.layer1(out)
    out = self.layer2(out)
    out = self.layer3(out)
    out = self.layer4(out)
    out = F.avg_pool2d(out, 4)
    out = out.view(out.size(0), -1)
    out = self.linear(out)
    return out

def ResNet18():
  return ResNet(BasicBlock, [2, 3, 2, 2])

# %%
model = ResNet18()

# %% [markdown]
# The number of parameters is `11,173,962`, which exceeds the 5 million limit.

# %%
model =  model.to(device)
if device == 'cuda':
  model = torch.nn.DataParallel(model)
  cudnn.benchmark = True

# %%
summary(model, input_size=(3, 32, 32))
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            1,728
# ├─BatchNorm2d: 1-2                       128
# ├─Sequential: 1-3                        --
# |    └─BasicBlock: 2-1                   --
# |    |    └─Conv2d: 3-1                  36,864
# |    |    └─BatchNorm2d: 3-2             128
# |    |    └─Conv2d: 3-3                  36,864
# |    |    └─BatchNorm2d: 3-4             128
# |    |    └─Sequential: 3-5              --
# |    └─BasicBlock: 2-2                   --
# |    |    └─Conv2d: 3-6                  36,864
# |    |    └─BatchNorm2d: 3-7             128
# |    |    └─Conv2d: 3-8                  36,864
# |    |    └─BatchNorm2d: 3-9             128
# |    |    └─Sequential: 3-10             --
# ├─Sequential: 1-4                        --
# |    └─BasicBlock: 2-3                   --
# |    |    └─Conv2d: 3-11                 73,728
# |    |    └─BatchNorm2d: 3-12            256
# |    |    └─Conv2d: 3-13                 147,456
# |    |    └─BatchNorm2d: 3-14            256
# |    |    └─Sequential: 3-15             8,448
# |    └─BasicBlock: 2-4                   --
# |    |    └─Conv2d: 3-16                 147,456
# |    |    └─BatchNorm2d: 3-17            256
# |    |    └─Conv2d: 3-18                 147,456
# |    |    └─BatchNorm2d: 3-19            256
# |    |    └─Sequential: 3-20             --
# |    └─BasicBlock: 2-5                   --
# |    |    └─Conv2d: 3-21                 147,456
# |    |    └─BatchNorm2d: 3-22            256
# |    |    └─Conv2d: 3-23                 147,456
# |    |    └─BatchNorm2d: 3-24            256
# |    |    └─Sequential: 3-25             --
# ├─Sequential: 1-5                        --
# |    └─BasicBlock: 2-6                   --
# |    |    └─Conv2d: 3-26                 221,184
# |    |    └─BatchNorm2d: 3-27            384
# |    |    └─Conv2d: 3-28                 331,776
# |    |    └─BatchNorm2d: 3-29            384
# |    |    └─Sequential: 3-30             24,960
# |    └─BasicBlock: 2-7                   --
# |    |    └─Conv2d: 3-31                 331,776
# |    |    └─BatchNorm2d: 3-32            384
# |    |    └─Conv2d: 3-33                 331,776
# |    |    └─BatchNorm2d: 3-34            384
# |    |    └─Sequential: 3-35             --
# ├─Sequential: 1-6                        --
# |    └─BasicBlock: 2-8                   --
# |    |    └─Conv2d: 3-36                 442,368
# |    |    └─BatchNorm2d: 3-37            512
# |    |    └─Conv2d: 3-38                 589,824
# |    |    └─BatchNorm2d: 3-39            512
# |    |    └─Sequential: 3-40             49,664
# |    └─BasicBlock: 2-9                   --
# |    |    └─Conv2d: 3-41                 589,824
# |    |    └─BatchNorm2d: 3-42            512
# |    |    └─Conv2d: 3-43                 589,824
# |    |    └─BatchNorm2d: 3-44            512
# |    |    └─Sequential: 3-45             --
# ├─Linear: 1-7                            2,570
# =================================================================
# Total params: 4,479,946
# Trainable params: 4,479,946
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            1,728
# ├─BatchNorm2d: 1-2                       128
# ├─Sequential: 1-3                        --
# |    └─BasicBlock: 2-1                   --
# |    |    └─Conv2d: 3-1                  36,864
# |    |    └─BatchNorm2d: 3-2             128
# |    |    └─Conv2d: 3-3                  36,864
# |    |    └─BatchNorm2d: 3-4             128
# |    |    └─Sequential: 3-5              --
# |    └─BasicBlock: 2-2                   --
# |    |    └─Conv2d: 3-6                  36,864
# |    |    └─BatchNorm2d: 3-7             128
# |    |    └─Conv2d: 3-8                  36,864
# |    |    └─BatchNorm2d: 3-9             128
# |    |    └─Sequential: 3-10             --
# ├─Sequential: 1-4                        --
# |    └─BasicBlock: 2-3                   --
# |    |    └─Conv2d: 3-11                 73,728
# |    |    └─BatchNorm2d: 3-12            256
# |    |    └─Conv2d: 3-13                 147,456
# |    |    └─BatchNorm2d: 3-14            256
# |    |    └─Sequential: 3-15             8,448
# |    └─BasicBlock: 2-4                   --
# |    |    └─Conv2d: 3-16                 147,456
# |    |    └─BatchNorm2d: 3-17            256
# |    |    └─Conv2d: 3-18                 147,456
# |    |    └─BatchNorm2d: 3-19            256
# |    |    └─Sequential: 3-20             --
# |    └─BasicBlock: 2-5                   --
# |    |    └─Conv2d: 3-21                 147,456
# |    |    └─BatchNorm2d: 3-22            256
# |    |    └─Conv2d: 3-23                 147,456
# |    |    └─BatchNorm2d: 3-24            256
# |    |    └─Sequential: 3-25             --
# ├─Sequential: 1-5                        --
# |    └─BasicBlock: 2-6                   --
# |    |    └─Conv2d: 3-26                 221,184
# |    |    └─BatchNorm2d: 3-27            384
# |    |    └─Conv2d: 3-28                 331,776
# |    |    └─BatchNorm2d: 3-29            384
# |    |    └─Sequential: 3-30             24,960
# |    └─BasicBlock: 2-7                   --
# |    |    └─Conv2d: 3-31                 331,776
# |    |    └─BatchNorm2d: 3-32            384
# |    |    └─Conv2d: 3-33                 331,776
# |    |    └─BatchNorm2d: 3-34            384
# |    |    └─Sequential: 3-35             --
# ├─Sequential: 1-6                        --
# |    └─BasicBlock: 2-8                   --
# |    |    └─Conv2d: 3-36                 442,368
# |    |    └─BatchNorm2d: 3-37            512
# |    |    └─Conv2d: 3-38                 589,824
# |    |    └─BatchNorm2d: 3-39            512
# |    |    └─Sequential: 3-40             49,664
# |    └─BasicBlock: 2-9                   --
# |    |    └─Conv2d: 3-41                 589,824
# |    |    └─BatchNorm2d: 3-42            512
# |    |    └─Conv2d: 3-43                 589,824
# |    |    └─BatchNorm2d: 3-44            512
# |    |    └─Sequential: 3-45             --
# ├─Linear: 1-7                            2,570
# =================================================================
# Total params: 4,479,946
# Trainable params: 4,479,946
# Non-trainable params: 0
# =================================================================

# %% [markdown]
# ## Model Training

# %%
def format_time(seconds):
  days = int(seconds / 3600/24)
  seconds = seconds - days*3600*24
  hours = int(seconds / 3600)
  seconds = seconds - hours*3600
  minutes = int(seconds / 60)
  seconds = seconds - minutes*60
  secondsf = int(seconds)
  seconds = seconds - secondsf
  millis = int(seconds*1000)

  f = ''
  i = 1
  if days > 0:
    f += str(days) + 'D'
    i += 1
  if hours > 0 and i <= 2:
    f += str(hours) + 'h'
    i += 1
  if minutes > 0 and i <= 2:
    f += str(minutes) + 'm'
    i += 1
  if secondsf > 0 and i <= 2:
    f += str(secondsf) + 's'
    i += 1
  if millis > 0 and i <= 2:
    f += str(millis) + 'ms'
    i += 1
  if f == '':
    f = '0ms'
  return f

# %%
lr = 0.1
momentum = 0.9
weight_decay = 5e-4

start_epoch = 1
number_of_epochs = 100
best_acc = 0


criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=lr,
                      momentum=momentum, weight_decay=weight_decay)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=number_of_epochs)

# %%
def get_lr(optimizer):
  for param_group in optimizer.param_groups:
    return param_group['lr']

# %%
def train(epoch):
  print('\nEpoch: %d' % epoch)
  start_time = time.time()

  model.train()
  train_loss = 0
  correct = 0
  total = 0
  for batch_idx, (inputs, targets) in enumerate(train_dl):
    # inputs, targets = inputs.to(device), targets.to(device)
    optimizer.zero_grad()
    outputs = model(inputs)
    loss = criterion(outputs, targets)
    loss.backward()
    optimizer.step()

    train_loss += loss.item()
    _, predicted = outputs.max(1)
    total += targets.size(0)
    correct += predicted.eq(targets).sum().item()


  cur_time = time.time()
  epoch_time = cur_time - start_time
  print(f"Time taken : {format_time(epoch_time)}")

  return train_loss/(batch_idx+1), 100.*correct/total, get_lr(optimizer)

# %%
def test(epoch):
  global best_acc
  model.eval()
  test_loss = 0
  correct = 0
  total = 0
  with torch.no_grad():
    for batch_idx, (inputs, targets) in enumerate(test_dl):
      # inputs, targets = inputs.to(device), targets.to(device)
      outputs = model(inputs)
      loss = criterion(outputs, targets)

      test_loss += loss.item()
      _, predicted = outputs.max(1)
      total += targets.size(0)
      correct += predicted.eq(targets).sum().item()
      

  # Save checkpoint.
  acc = 100.*correct/total
  if acc > best_acc:
    print('Saving..')
    state = {
        'net': model.state_dict(),
        'acc': acc,
        'epoch': epoch,
    }
    if not os.path.isdir('checkpoint'):
      os.mkdir('checkpoint')
    torch.save(state, './checkpoint/ResNet_18_best.pth')
    best_acc = acc

  return test_loss/(batch_idx+1), 100.*correct/total

# %%
train_losses = []
train_accuracies = []
train_lrs = []

test_losses = []
test_accuracies = []

for epoch in range(start_epoch, start_epoch + number_of_epochs):
  epoch_train_loss, epoch_train_accuracy, epoch_lr = train(epoch)
  train_losses.append(epoch_train_loss)
  train_accuracies.append(epoch_train_accuracy)
  train_lrs.append(epoch_lr)

  epoch_test_loss, epoch_test_accuracy = test(epoch)
  test_losses.append(epoch_test_loss)
  test_accuracies.append(epoch_test_accuracy)

  scheduler.step()

  print(f"Train Loss: {epoch_train_loss:.3f} | Train Accuracy: {epoch_train_accuracy:.3f}% | Test Loss: {epoch_test_loss:.3f} | Test Accuracy: {epoch_test_accuracy:.3f}%")
# Out:
# Epoch: 1
# Time taken : 36s996ms
# Saving..
# Train Loss: 1.618 | Train Accuracy: 40.074% | Test Loss: 1.424 | Test Accuracy: 48.360%
#
# Epoch: 2
# Time taken : 36s374ms
# Saving..
# Train Loss: 1.163 | Train Accuracy: 58.132% | Test Loss: 1.125 | Test Accuracy: 59.900%
#
# Epoch: 3
# Time taken : 36s329ms
# Saving..
# Train Loss: 0.920 | Train Accuracy: 67.282% | Test Loss: 0.807 | Test Accuracy: 71.950%
#
# Epoch: 4
# Time taken : 36s575ms
# Train Loss: 0.764 | Train Accuracy: 73.340% | Test Loss: 0.906 | Test Accuracy: 68.660%
#
# Epoch: 5
# Time taken : 36s797ms
# Saving..
# Train Loss: 0.655 | Train Accuracy: 77.348% | Test Loss: 0.643 | Test Accuracy: 77.660%
#
# Epoch: 6
# Time taken : 36s813ms
# Train Loss: 0.592 | Train Accuracy: 79.546% | Test Loss: 0.798 | Test Accuracy: 73.280%
#
# Epoch: 7
# Time taken : 36s731ms
# Train Loss: 0.552 | Train Accuracy: 81.116% | Test Loss: 0.718 | Test Accuracy: 75.910%
#
# Epoch: 8
# Time taken : 36s404ms
# Train Loss: 0.520 | Train Accuracy: 82.090% | Test Loss: 0.700 | Test Accuracy: 77.150%
#
# Epoch: 9
# Time taken : 36s833ms
# Saving..
# Train Loss: 0.497 | Train Accuracy: 83.000% | Test Loss: 0.528 | Test Accuracy: 82.430%
#
# Epoch: 10
# Time taken : 36s584ms
# Train Loss: 0.479 | Train Accuracy: 83.562% | Test Loss: 0.550 | Test Accuracy: 81.120%
#
# Epoch: 11
# Time taken : 46s348ms
# Train Loss: 0.463 | Train Accuracy: 84.192% | Test Loss: 0.641 | Test Accuracy: 79.340%
#
# Epoch: 12
# Time taken : 53s617ms
# Train Loss: 0.452 | Train Accuracy: 84.536% | Test Loss: 0.612 | Test Accuracy: 79.890%
#
# Epoch: 13
# Time taken : 51s906ms
# Train Loss: 0.436 | Train Accuracy: 85.186% | Test Loss: 0.593 | Test Accuracy: 80.290%
#
# Epoch: 14
# Time taken : 53s541ms
# Train Loss: 0.422 | Train Accuracy: 85.506% | Test Loss: 0.605 | Test Accuracy: 80.010%
#
# Epoch: 15
# Time taken : 1m7s
# Train Loss: 0.415 | Train Accuracy: 85.724% | Test Loss: 0.543 | Test Accuracy: 81.110%
#
# Epoch: 16
# Time taken : 1m11s
# Saving..
# Train Loss: 0.404 | Train Accuracy: 86.236% | Test Loss: 0.459 | Test Accuracy: 84.350%
#
# Epoch: 17
# Time taken : 1m10s
# Saving..
# Train Loss: 0.403 | Train Accuracy: 86.236% | Test Loss: 0.447 | Test Accuracy: 84.660%
#
# Epoch: 18
# Time taken : 1m11s
# Train Loss: 0.386 | Train Accuracy: 86.914% | Test Loss: 0.499 | Test Accuracy: 82.500%
#
# Epoch: 19
# Time taken : 1m13s
# Train Loss: 0.387 | Train Accuracy: 86.882% | Test Loss: 0.471 | Test Accuracy: 83.840%
#
# Epoch: 20
# Time taken : 1m10s
# Train Loss: 0.372 | Train Accuracy: 87.332% | Test Loss: 0.482 | Test Accuracy: 84.080%
#
# Epoch: 21
# Time taken : 1m14s
# Train Loss: 0.365 | Train Accuracy: 87.524% | Test Loss: 0.703 | Test Accuracy: 77.740%
#
# Epoch: 22
# Time taken : 1m12s
# Train Loss: 0.364 | Train Accuracy: 87.550% | Test Loss: 0.502 | Test Accuracy: 83.070%
#
# Epoch: 23
# Time taken : 1m12s
# Train Loss: 0.355 | Train Accuracy: 87.918% | Test Loss: 0.487 | Test Accuracy: 83.150%
#
# Epoch: 24
# Time taken : 1m12s
# Saving..
# Train Loss: 0.354 | Train Accuracy: 87.994% | Test Loss: 0.418 | Test Accuracy: 85.950%
#
# Epoch: 25
# Time taken : 1m10s
# Train Loss: 0.351 | Train Accuracy: 87.954% | Test Loss: 0.427 | Test Accuracy: 85.700%
#
# Epoch: 26
# Time taken : 1m12s
# Train Loss: 0.343 | Train Accuracy: 88.298% | Test Loss: 0.454 | Test Accuracy: 84.610%
#
# Epoch: 27
# Time taken : 1m11s
# Train Loss: 0.333 | Train Accuracy: 88.696% | Test Loss: 0.415 | Test Accuracy: 85.860%
#
# Epoch: 28
# Time taken : 1m11s
# Saving..
# Train Loss: 0.332 | Train Accuracy: 88.746% | Test Loss: 0.384 | Test Accuracy: 87.030%
#
# Epoch: 29
# Time taken : 1m13s
# Train Loss: 0.322 | Train Accuracy: 89.090% | Test Loss: 0.404 | Test Accuracy: 86.400%
#
# Epoch: 30
# Time taken : 1m11s
# Train Loss: 0.326 | Train Accuracy: 88.882% | Test Loss: 0.545 | Test Accuracy: 83.160%
#
# Epoch: 31
# Time taken : 1m12s
# Train Loss: 0.315 | Train Accuracy: 89.156% | Test Loss: 0.507 | Test Accuracy: 83.790%
#
# Epoch: 32
# Time taken : 1m11s
# Train Loss: 0.313 | Train Accuracy: 89.156% | Test Loss: 0.638 | Test Accuracy: 80.350%
#
# Epoch: 33
# Time taken : 1m12s
# Train Loss: 0.308 | Train Accuracy: 89.474% | Test Loss: 0.476 | Test Accuracy: 84.500%
#
# Epoch: 34
# Time taken : 1m11s
# Train Loss: 0.301 | Train Accuracy: 89.694% | Test Loss: 0.391 | Test Accuracy: 86.830%
#
# Epoch: 35
# Time taken : 1m11s
# Train Loss: 0.303 | Train Accuracy: 89.672% | Test Loss: 0.399 | Test Accuracy: 86.580%
#
# Epoch: 36
# Time taken : 1m12s
# Train Loss: 0.296 | Train Accuracy: 89.876% | Test Loss: 0.469 | Test Accuracy: 85.280%
#
# Epoch: 37
# Time taken : 1m11s
# Saving..
# Train Loss: 0.292 | Train Accuracy: 90.054% | Test Loss: 0.348 | Test Accuracy: 88.240%
#
# Epoch: 38
# Time taken : 1m11s
# Train Loss: 0.287 | Train Accuracy: 90.244% | Test Loss: 0.390 | Test Accuracy: 86.740%
#
# Epoch: 39
# Time taken : 1m12s
# Train Loss: 0.277 | Train Accuracy: 90.538% | Test Loss: 0.478 | Test Accuracy: 84.710%
#
# Epoch: 40
# Time taken : 1m10s
# Saving..
# Train Loss: 0.274 | Train Accuracy: 90.686% | Test Loss: 0.340 | Test Accuracy: 88.540%
#
# Epoch: 41
# Time taken : 1m11s
# Train Loss: 0.270 | Train Accuracy: 90.822% | Test Loss: 0.383 | Test Accuracy: 87.440%
#
# Epoch: 42
# Time taken : 1m10s
# Train Loss: 0.264 | Train Accuracy: 90.942% | Test Loss: 0.465 | Test Accuracy: 84.830%
#
# Epoch: 43
# Time taken : 1m12s
# Train Loss: 0.257 | Train Accuracy: 91.226% | Test Loss: 0.467 | Test Accuracy: 85.160%
#
# Epoch: 44
# Time taken : 1m11s
# Train Loss: 0.257 | Train Accuracy: 91.154% | Test Loss: 0.390 | Test Accuracy: 86.720%
#
# Epoch: 45
# Time taken : 1m12s
# Train Loss: 0.252 | Train Accuracy: 91.340% | Test Loss: 0.374 | Test Accuracy: 87.960%
#
# Epoch: 46
# Time taken : 1m11s
# Train Loss: 0.246 | Train Accuracy: 91.702% | Test Loss: 0.435 | Test Accuracy: 86.010%
#
# Epoch: 47
# Time taken : 1m12s
# Train Loss: 0.241 | Train Accuracy: 91.748% | Test Loss: 0.367 | Test Accuracy: 87.740%
#
# Epoch: 48
# Time taken : 1m11s
# Train Loss: 0.233 | Train Accuracy: 92.100% | Test Loss: 0.377 | Test Accuracy: 87.640%
#
# Epoch: 49
# Time taken : 1m10s
# Train Loss: 0.223 | Train Accuracy: 92.390% | Test Loss: 0.420 | Test Accuracy: 86.400%
#
# Epoch: 50
# Time taken : 1m11s
# Saving..
# Train Loss: 0.225 | Train Accuracy: 92.316% | Test Loss: 0.299 | Test Accuracy: 89.960%
#
# Epoch: 51
# Time taken : 1m10s
# Train Loss: 0.221 | Train Accuracy: 92.290% | Test Loss: 0.319 | Test Accuracy: 89.590%
#
# Epoch: 52
# Time taken : 1m11s
# Train Loss: 0.209 | Train Accuracy: 92.790% | Test Loss: 0.320 | Test Accuracy: 89.580%
#
# Epoch: 53
# Time taken : 1m11s
# Train Loss: 0.209 | Train Accuracy: 92.788% | Test Loss: 0.301 | Test Accuracy: 89.910%
#
# Epoch: 54
# Time taken : 1m11s
# Train Loss: 0.195 | Train Accuracy: 93.306% | Test Loss: 0.319 | Test Accuracy: 89.340%
#
# Epoch: 55
# Time taken : 1m12s
# Saving..
# Train Loss: 0.193 | Train Accuracy: 93.444% | Test Loss: 0.314 | Test Accuracy: 90.050%
#
# Epoch: 56
# Time taken : 1m12s
# Train Loss: 0.189 | Train Accuracy: 93.606% | Test Loss: 0.315 | Test Accuracy: 89.680%
#
# Epoch: 57
# Time taken : 1m14s
# Train Loss: 0.182 | Train Accuracy: 93.786% | Test Loss: 0.344 | Test Accuracy: 88.650%
#
# Epoch: 58
# Time taken : 1m13s
# Train Loss: 0.179 | Train Accuracy: 93.852% | Test Loss: 0.301 | Test Accuracy: 89.980%
#
# Epoch: 59
# Time taken : 1m11s
# Train Loss: 0.170 | Train Accuracy: 94.092% | Test Loss: 0.319 | Test Accuracy: 89.610%
#
# Epoch: 60
# Time taken : 1m12s
# Train Loss: 0.165 | Train Accuracy: 94.310% | Test Loss: 0.320 | Test Accuracy: 89.700%
#
# Epoch: 61
# Time taken : 1m10s
# Saving..
# Train Loss: 0.156 | Train Accuracy: 94.726% | Test Loss: 0.295 | Test Accuracy: 90.330%
#
# Epoch: 62
# Time taken : 1m10s
# Train Loss: 0.151 | Train Accuracy: 94.856% | Test Loss: 0.332 | Test Accuracy: 89.830%
#
# Epoch: 63
# Time taken : 1m10s
# Train Loss: 0.142 | Train Accuracy: 95.184% | Test Loss: 0.326 | Test Accuracy: 89.780%
#
# Epoch: 64
# Time taken : 1m12s
# Train Loss: 0.140 | Train Accuracy: 95.178% | Test Loss: 0.340 | Test Accuracy: 89.330%
#
# Epoch: 65
# Time taken : 1m13s
# Train Loss: 0.129 | Train Accuracy: 95.612% | Test Loss: 0.429 | Test Accuracy: 86.890%
#
# Epoch: 66
# Time taken : 1m11s
# Saving..
# Train Loss: 0.124 | Train Accuracy: 95.708% | Test Loss: 0.279 | Test Accuracy: 91.440%
#
# Epoch: 67
# Time taken : 1m11s
# Train Loss: 0.115 | Train Accuracy: 96.116% | Test Loss: 0.316 | Test Accuracy: 90.610%
#
# Epoch: 68
# Time taken : 1m10s
# Saving..
# Train Loss: 0.112 | Train Accuracy: 96.144% | Test Loss: 0.273 | Test Accuracy: 91.610%
#
# Epoch: 69
# Time taken : 1m10s
# Saving..
# Train Loss: 0.104 | Train Accuracy: 96.434% | Test Loss: 0.252 | Test Accuracy: 92.030%
#
# Epoch: 70
# Time taken : 1m11s
# Train Loss: 0.098 | Train Accuracy: 96.718% | Test Loss: 0.283 | Test Accuracy: 91.220%
#
# Epoch: 71
# Time taken : 1m11s
# Saving..
# Train Loss: 0.091 | Train Accuracy: 96.846% | Test Loss: 0.267 | Test Accuracy: 92.040%
#
# Epoch: 72
# Time taken : 1m11s
# Saving..
# Train Loss: 0.084 | Train Accuracy: 97.150% | Test Loss: 0.243 | Test Accuracy: 92.490%
#
# Epoch: 73
# Time taken : 1m10s
# Saving..
# Train Loss: 0.078 | Train Accuracy: 97.308% | Test Loss: 0.241 | Test Accuracy: 92.580%
#
# Epoch: 74
# Time taken : 1m2s
# Saving..
# Train Loss: 0.074 | Train Accuracy: 97.516% | Test Loss: 0.234 | Test Accuracy: 92.870%
#
# Epoch: 75
# Time taken : 56s191ms
# Saving..
# Train Loss: 0.066 | Train Accuracy: 97.798% | Test Loss: 0.227 | Test Accuracy: 93.210%
#
# Epoch: 76
# Time taken : 55s228ms
# Train Loss: 0.057 | Train Accuracy: 98.130% | Test Loss: 0.225 | Test Accuracy: 93.140%
#
# Epoch: 77
# Time taken : 55s459ms
# Saving..
# Train Loss: 0.050 | Train Accuracy: 98.362% | Test Loss: 0.229 | Test Accuracy: 93.260%
#
# Epoch: 78
# Time taken : 55s541ms
# Train Loss: 0.043 | Train Accuracy: 98.582% | Test Loss: 0.247 | Test Accuracy: 93.160%
#
# Epoch: 79
# Time taken : 56s52ms
# Train Loss: 0.037 | Train Accuracy: 98.806% | Test Loss: 0.254 | Test Accuracy: 92.870%
#
# Epoch: 80
# Time taken : 54s934ms
# Saving..
# Train Loss: 0.032 | Train Accuracy: 98.972% | Test Loss: 0.217 | Test Accuracy: 93.960%
#
# Epoch: 81
# Time taken : 45s133ms
# Saving..
# Train Loss: 0.028 | Train Accuracy: 99.102% | Test Loss: 0.223 | Test Accuracy: 94.050%
#
# Epoch: 82
# Time taken : 36s944ms
# Saving..
# Train Loss: 0.023 | Train Accuracy: 99.256% | Test Loss: 0.219 | Test Accuracy: 94.090%
#
# Epoch: 83
# Time taken : 36s441ms
# Saving..
# Train Loss: 0.021 | Train Accuracy: 99.314% | Test Loss: 0.210 | Test Accuracy: 94.110%
#
# Epoch: 84
# Time taken : 36s670ms
# Saving..
# Train Loss: 0.015 | Train Accuracy: 99.574% | Test Loss: 0.215 | Test Accuracy: 94.320%
#
# Epoch: 85
# Time taken : 36s540ms
# Saving..
# Train Loss: 0.013 | Train Accuracy: 99.620% | Test Loss: 0.198 | Test Accuracy: 94.690%
#
# Epoch: 86
# Time taken : 36s917ms
# Saving..
# Train Loss: 0.010 | Train Accuracy: 99.764% | Test Loss: 0.200 | Test Accuracy: 94.880%
#
# Epoch: 87
# Time taken : 36s797ms
# Saving..
# Train Loss: 0.008 | Train Accuracy: 99.824% | Test Loss: 0.194 | Test Accuracy: 95.030%
#
# Epoch: 88
# Time taken : 36s989ms
# Train Loss: 0.007 | Train Accuracy: 99.836% | Test Loss: 0.193 | Test Accuracy: 94.840%
#
# Epoch: 89
# Time taken : 36s996ms
# Train Loss: 0.006 | Train Accuracy: 99.898% | Test Loss: 0.193 | Test Accuracy: 95.020%
#
# Epoch: 90
# Time taken : 36s722ms
# Train Loss: 0.005 | Train Accuracy: 99.908% | Test Loss: 0.192 | Test Accuracy: 95.020%
#
# Epoch: 91
# Time taken : 36s704ms
# Train Loss: 0.005 | Train Accuracy: 99.930% | Test Loss: 0.187 | Test Accuracy: 94.990%
#
# Epoch: 92
# Time taken : 36s788ms
# Saving..
# Train Loss: 0.004 | Train Accuracy: 99.946% | Test Loss: 0.187 | Test Accuracy: 95.140%
#
# Epoch: 93
# Time taken : 37s388ms
# Train Loss: 0.004 | Train Accuracy: 99.926% | Test Loss: 0.190 | Test Accuracy: 95.000%
#
# Epoch: 94
# Time taken : 37s567ms
# Saving..
# Train Loss: 0.003 | Train Accuracy: 99.960% | Test Loss: 0.188 | Test Accuracy: 95.190%
#
# Epoch: 95
# Time taken : 37s623ms
# Train Loss: 0.003 | Train Accuracy: 99.952% | Test Loss: 0.186 | Test Accuracy: 95.160%
#
# Epoch: 96
# Time taken : 37s599ms
# Train Loss: 0.003 | Train Accuracy: 99.966% | Test Loss: 0.185 | Test Accuracy: 95.140%
#
# Epoch: 97
# Time taken : 37s525ms
# Train Loss: 0.003 | Train Accuracy: 99.962% | Test Loss: 0.185 | Test Accuracy: 95.140%
#
# Epoch: 98
# Time taken : 37s329ms
# Train Loss: 0.003 | Train Accuracy: 99.958% | Test Loss: 0.186 | Test Accuracy: 95.110%
#
# Epoch: 99
# Time taken : 37s361ms
# Train Loss: 0.003 | Train Accuracy: 99.980% | Test Loss: 0.185 | Test Accuracy: 95.160%
#
# Epoch: 100
# Time taken : 37s336ms
# Train Loss: 0.003 | Train Accuracy: 99.974% | Test Loss: 0.185 | Test Accuracy: 95.130%

# %%
print('Best Accuracy : ', best_acc)
# Out:
# Best Accuracy :  95.19

# %%
def plot_accuracies(train_accuracies, test_accuracies):
  plt.plot(train_accuracies, label='Train Accuracy')
  plt.plot(test_accuracies, label='Test Accuracy')
  plt.xlabel('Epochs')
  plt.ylabel('Accuracy')
  plt.legend()
  plt.grid(True)
  plt.title('Accuracy vs. No. of epochs')

# %%
def plot_losses(train_losses, test_losses):
  plt.plot(train_losses, label='Train Losses')
  plt.plot(test_losses, label='Test Losses')
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.legend()
  plt.grid(True)
  plt.title('Loss vs. No. of epochs')

# %%
def plot_lrs(train_lrs):
  plt.plot(train_lrs)
  plt.xlabel('Epochs')
  plt.ylabel('Learning rate')
  plt.grid(True)
  plt.title('Learning Rate vs. Epochs')

# %%
plot_accuracies(train_accuracies, test_accuracies)

# %%
plot_losses(train_losses, test_losses)

# %%
plot_lrs(train_lrs)

# %%
print('Saving final model..')
state = {
    'net': model.state_dict(),
    'acc': test_accuracies[-1],
    'epoch': number_of_epochs,
    'best_acc' : best_acc,
    'train_acc' : train_accuracies,
    'test_acc' : test_accuracies,
    'train_loss' : train_losses,
    'test_loss' : test_losses,
    'lr' : train_lrs
}
if not os.path.isdir('checkpoint'):
  os.mkdir('checkpoint')
torch.save(state, './checkpoint/ResNet_18_final.pth')
# Out:
# Saving final model..

# %%
import numpy as np
import pickle
from tqdm import tqdm
import pandas as pd

# Function to load CIFAR batch
def load_cifar_batch(file):
    with open(file, 'rb') as fo:
        batch = pickle.load(fo, encoding='bytes')
    return batch

# Specify the folder where the CIFAR-10 batch files are
cifar10_dir = 'data/cifar-10-batches-py/'

# Load the label names
meta_data_dict = load_cifar_batch(os.path.join(cifar10_dir, 'batches.meta'))
label_names = meta_data_dict[b'label_names']

# Load test data
test_batch = load_cifar_batch('CIFAR-10/cifar_test_nolabels.pkl')
test_images = test_batch[b'data'].reshape(-1, 3, 32, 32).transpose(0, 2, 3, 1)

data_statistics = (
    (0.49139968, 0.48215827, 0.44653124),
     (0.24703233, 0.24348505, 0.26158768)
)

# Define transformation for data augmentation
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(*data_statistics, inplace=True)
])

# Apply data augmentation
augmented_test_images = torch.stack([transform(image) for image in test_images])

# Load the trained model
model = ResNet18()

checkpoint = torch.load('./checkpoint/ResNet_18_best.pth')

# Check the keys in the checkpoint dictionary
print(checkpoint.keys())

# Assuming the model state dictionary is saved under a different key
# Adjust this according to the actual key in your checkpoint file
model.load_state_dict(checkpoint['net'])

model =  model.to(device)

# Evaluate the model on test data
model.eval()
with torch.no_grad():
    outputs = model(augmented_test_images.to(device))
_, predicted = torch.max(outputs, 1)

predicted = predicted.to('cpu')

# Display the first 10 test images and predicted labels
plt.figure(figsize=(20, 4))
for i in range(10):
    plt.subplot(1, 10, i+1)
    plt.imshow(test_images[i])
    plt.title(label_names[predicted[i].item()].decode('utf-8'))
    plt.axis('off')
plt.show()

# Save the output in output.csv containing ID, Labels
output_data = {'ID': np.arange(len(predicted)), 'Labels': predicted.numpy()}
output_df = pd.DataFrame(output_data)
output_df.to_csv('output_resnet18.csv', index=False)
# Out:
# dict_keys(['net', 'acc', 'epoch'])
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[47], line 54
#      52 model.eval()
#      53 with torch.no_grad():
# ---> 54     outputs = model(augmented_test_images.to(device))
#      55 _, predicted = torch.max(outputs, 1)
#      57 predicted = predicted.to('cpu')
#
# File ~/.local/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# Cell In[29], line 51, in ResNet.forward(self, x)
#      50 def forward(self, x):
# ---> 51   out = F.relu(self.bn1(self.conv1(x)))
#      52   out = self.layer1(out)
#      53   out = self.layer2(out)
#
# File ~/.local/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.local/lib/python3.11/site-packages/torch/nn/modules/conv.py:460, in Conv2d.forward(self, input)
#     459 def forward(self, input: Tensor) -> Tensor:
# --> 460     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/.local/lib/python3.11/site-packages/torch/nn/modules/conv.py:456, in Conv2d._conv_forward(self, input, weight, bias)
#     452 if self.padding_mode != 'zeros':
#     453     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     454                     weight, bias, self.stride,
#     455                     _pair(0), self.dilation, self.groups)
# --> 456 return F.conv2d(input, weight, bias, self.stride,
#     457                 self.padding, self.dilation, self.groups)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 2.44 GiB. GPU 0 has a total capacity of 31.74 GiB of which 1.48 GiB is free. Process 606249 has 1.28 GiB memory in use. Including non-PyTorch memory, this process has 996.00 MiB memory in use. Process 649822 has 26.75 GiB memory in use. Process 657610 has 1.25 GiB memory in use. Of the allocated memory 239.80 MiB is allocated by PyTorch, and 354.20 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %% [markdown]
# # ResNet-18 on CIFAR-10 Dataset

# %% [markdown]
# Importing PyTorch and a few Python Libraries

# %%
pip install torch-summary
# Out:
# Requirement already satisfied: torch-summary in /opt/conda/lib/python3.10/site-packages (1.4.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import sys
import time
import math

import torch
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import random_split, DataLoader
from torchvision.utils import make_grid

import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
import torch.nn.init as init

from torchsummary import summary

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Preparing the dataset
#
# We will be downloading the train and test CIFAR-10 dataset from torchvision. We will normalize and transform the dataset. For the training dataset, we will also be adding Random Crops and Random Horizontal Flips to generalize the model better.

# %%
data_statistics = (
    (0.49139968, 0.48215827, 0.44653124),
     (0.24703233, 0.24348505, 0.26158768)
) # Mean, Standard Deviation of CIFAR-10 dataset channels

train_transforms = transforms.Compose([
    transforms.RandomCrop(32, padding=4, padding_mode='reflect'), # Adding Random Crops
    transforms.RandomHorizontalFlip(), # Adding Random Horizontal Flips
    transforms.ToTensor(), # Channel x Image Height x Image Width
    transforms.Normalize(*data_statistics, inplace=True) # Output in the range of [-1, 1]
])

test_transforms = transforms.Compose([
    transforms.ToTensor(), # Channel x Image Height x Image Width
    transforms.Normalize(*data_statistics, inplace=True) # Output in the range of [-1, 1]
])

# %%
train_dataset = torchvision.datasets.CIFAR10(root='./data/', download=True, train=True, transform=train_transforms)
test_dataset = torchvision.datasets.CIFAR10(root='./data/', download=True, train=False, transform=test_transforms)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:15<00:00, 11165792.17it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data/
# Files already downloaded and verified

# %% [markdown]
# <!-- We will also be splitting the dataset further into training and validation dataset with a validation ratio of `0.2` -->
#
# We will now create data loaders to retreive images in batches. We are selecting the batch size as `128` images for our train loader. And we are selecting the batch size as `100` images for our test loader.
#
# *From PyTorch Documentation: For data loading, passing pin_memory=True to a DataLoader will automatically put the fetched data Tensors in pinned memory, and thus enables faster data transfer to CUDA-enabled GPUs.*

# %%
# validation_ratio = 0.2
# train_dataset, validation_dataset = random_split(
#     dataset,
#     [int((1 - validation_ratio) * len(dataset)), int(validation_ratio * len(dataset))]
# )

train_batch_size = 128
test_batch_size = 100

train_dl = DataLoader(train_dataset, train_batch_size, shuffle=True, num_workers=2, pin_memory=True)
# validation_dl = DataLoader(validation_dataset, batch_size, shuffle=True, num_workers=3, pin_memory=True)
test_dl = DataLoader(test_dataset, test_batch_size, shuffle=False, num_workers=2, pin_memory=True)

classes = ('plane', 'car', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck')

# %% [markdown]
# We create the following function to display a batch of images from the dataset. And we also need to denormalize the pixels values to bring them back into the range (0,1).

# %%
def denormalize(images, means, stds):
  means = torch.tensor(means).reshape(1, 3, 1, 1)
  stds = torch.tensor(stds).reshape(1, 3, 1, 1)
  return images * stds + means

def show_batch(dl):
  for images, labels in dl:
    fig, ax = plt.subplots(figsize=(12, 12))
    ax.set_xticks([])
    ax.set_yticks([])
    denorm_images = denormalize(images, *data_statistics)
    ax.imshow(make_grid(denorm_images[:64], 8).permute(1, 2, 0))
    break

# %%
show_batch(train_dl)

# %% [markdown]
# To seamlessly use a GPU, if one is available, we define a couple of helper functions (`get_default_device` & `to_device`) and a helper class `DeviceDataLoader` to move our model & data to the GPU as required.

# %%
def get_default_device():
  # Pick GPU, if available, else CPU
  if torch.cuda.is_available():
    return torch.device('cuda')
  else:
    return torch.device('cpu')

def to_device(data, device):
  # Move tensors to chosen device
  if isinstance(data, (list, tuple)):
    # If the instance is a list/tuple, transfer each element to chosen device
    return [to_device(x, device) for x in data]
  return data.to(device, non_blocking=True)
  # non_blocking=True doesn't block the execution of the host device until transfers complete

class DeviceDataLoader():
  # Wrap a dataloader to move data to a device
  def __init__(self, dl, device):
    self.dl = dl
    self.device = device

  def __iter__(self):
    # Yield a batch of data after moving it to device
    for b in self.dl:
      yield to_device(b, self.device)

  def __len__(self):
    # Number of batches
    return len(self.dl)

# %%
# Get the default device
device = get_default_device()
device
# Out:
# device(type='cuda')

# %%
train_dl = DeviceDataLoader(train_dl, device)
# validation_dl = DeviceDataLoader(validation_dl, device)
test_dl = DeviceDataLoader(test_dl, device)

# %% [markdown]
# ## Network Architecture

# %% [markdown]
# Testing the models mentioned in the `pytorch-cifar` [GitHub Repository](https://github.com/kuangliu/pytorch-cifar).

# %% [markdown]
# ### PreActResNet18

# %%
class PreActBlock(nn.Module):
  '''Pre-activation version of the BasicBlock.'''
  expansion = 1

  def __init__(self, in_planes, planes, stride=1):
    super(PreActBlock, self).__init__()
    self.bn1 = nn.BatchNorm2d(in_planes)
    self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
    self.bn2 = nn.BatchNorm2d(planes)
    self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)

    if stride != 1 or in_planes != self.expansion*planes:
      self.shortcut = nn.Sequential(
          nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False)
      )

  def forward(self, x):
    out = F.relu(self.bn1(x))
    shortcut = self.shortcut(out) if hasattr(self, 'shortcut') else x
    out = self.conv1(out)
    out = self.conv2(F.relu(self.bn2(out)))
    out += shortcut
    return out

class PreActResNet(nn.Module):
  def __init__(self, block, num_blocks, num_classes=10):
    super(PreActResNet, self).__init__()
    self.in_planes = 64

    self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
    self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
    self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
    self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
    self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
    self.linear = nn.Linear(512*block.expansion, num_classes)

  def _make_layer(self, block, planes, num_blocks, stride):
    strides = [stride] + [1]*(num_blocks-1)
    layers = []
    for stride in strides:
        layers.append(block(self.in_planes, planes, stride))
        self.in_planes = planes * block.expansion
    return nn.Sequential(*layers)

  def forward(self, x):
    out = self.conv1(x)
    out = self.layer1(out)
    out = self.layer2(out)
    out = self.layer3(out)
    out = self.layer4(out)
    out = F.avg_pool2d(out, 4)
    out = out.view(out.size(0), -1)
    out = self.linear(out)
    return out

def PreActResNet18():
  return PreActResNet(PreActBlock, [2,2,2,2])

# %%
# model = PreActResNet18()

# %% [markdown]
# The number of parameters is `11,171,146`, which exceeds the 5 million limit.

# %% [markdown]
# ### ResNet18

# %%
class BasicBlock(nn.Module):
  expansion = 1

  def __init__(self, in_planes, planes, stride=1):
    super(BasicBlock, self).__init__()
    self.conv1 = nn.Conv2d(
        in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
    self.bn1 = nn.BatchNorm2d(planes)
    self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                            stride=1, padding=1, bias=False)
    self.bn2 = nn.BatchNorm2d(planes)

    self.shortcut = nn.Sequential()
    if stride != 1 or in_planes != self.expansion*planes:
      self.shortcut = nn.Sequential(
          nn.Conv2d(in_planes, self.expansion*planes,
                    kernel_size=1, stride=stride, bias=False),
          nn.BatchNorm2d(self.expansion*planes)
      )

  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))
    out = self.bn2(self.conv2(out))
    out += self.shortcut(x)
    out = F.relu(out)
    return out

class ResNet(nn.Module):
  def __init__(self, block, num_blocks, num_classes=10):
    super(ResNet, self).__init__()
    self.in_planes = 64

    self.conv1 = nn.Conv2d(3, 64, kernel_size=3,
                            stride=1, padding=1, bias=False)
    self.bn1 = nn.BatchNorm2d(64)
    self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
    self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
    self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
    self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
    self.linear = nn.Linear(512*block.expansion, num_classes)

  def _make_layer(self, block, planes, num_blocks, stride):
    strides = [stride] + [1]*(num_blocks-1)
    layers = []
    for stride in strides:
      layers.append(block(self.in_planes, planes, stride))
      self.in_planes = planes * block.expansion
    return nn.Sequential(*layers)

  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))
    out = self.layer1(out)
    out = self.layer2(out)
    out = self.layer3(out)
    out = self.layer4(out)
    out = F.avg_pool2d(out, 4)
    out = out.view(out.size(0), -1)
    out = self.linear(out)
    return out

def ResNet18():
  return ResNet(BasicBlock, [2, 2, 2, 2])

# %%
# model = ResNet18()

# %% [markdown]
# The number of parameters is `11,173,962`, which exceeds the 5 million limit.

# %% [markdown]
# ### ResNet9

# %%
def ResNet9():
  return ResNet(BasicBlock, [1, 1, 1, 1])

# %%
model = ResNet9()

# %% [markdown]
# ### PreActResNet9

# %%
def PreActResNet9():
  return PreActResNet(PreActBlock, [1,1,1,1])

# %%
# model = PreActResNet9()

# %%
model =  model.to(device)
if device == 'cuda':
  model = torch.nn.DataParallel(model)
  cudnn.benchmark = True

# %%
summary(model, input_size=(3, 32, 32))
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            1,728
# ├─BatchNorm2d: 1-2                       128
# ├─Sequential: 1-3                        --
# |    └─BasicBlock: 2-1                   --
# |    |    └─Conv2d: 3-1                  36,864
# |    |    └─BatchNorm2d: 3-2             128
# |    |    └─Conv2d: 3-3                  36,864
# |    |    └─BatchNorm2d: 3-4             128
# |    |    └─Sequential: 3-5              --
# ├─Sequential: 1-4                        --
# |    └─BasicBlock: 2-2                   --
# |    |    └─Conv2d: 3-6                  73,728
# |    |    └─BatchNorm2d: 3-7             256
# |    |    └─Conv2d: 3-8                  147,456
# |    |    └─BatchNorm2d: 3-9             256
# |    |    └─Sequential: 3-10             8,448
# ├─Sequential: 1-5                        --
# |    └─BasicBlock: 2-3                   --
# |    |    └─Conv2d: 3-11                 294,912
# |    |    └─BatchNorm2d: 3-12            512
# |    |    └─Conv2d: 3-13                 589,824
# |    |    └─BatchNorm2d: 3-14            512
# |    |    └─Sequential: 3-15             33,280
# ├─Sequential: 1-6                        --
# |    └─BasicBlock: 2-4                   --
# |    |    └─Conv2d: 3-16                 1,179,648
# |    |    └─BatchNorm2d: 3-17            1,024
# |    |    └─Conv2d: 3-18                 2,359,296
# |    |    └─BatchNorm2d: 3-19            1,024
# |    |    └─Sequential: 3-20             132,096
# ├─Linear: 1-7                            5,130
# =================================================================
# Total params: 4,903,242
# Trainable params: 4,903,242
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            1,728
# ├─BatchNorm2d: 1-2                       128
# ├─Sequential: 1-3                        --
# |    └─BasicBlock: 2-1                   --
# |    |    └─Conv2d: 3-1                  36,864
# |    |    └─BatchNorm2d: 3-2             128
# |    |    └─Conv2d: 3-3                  36,864
# |    |    └─BatchNorm2d: 3-4             128
# |    |    └─Sequential: 3-5              --
# ├─Sequential: 1-4                        --
# |    └─BasicBlock: 2-2                   --
# |    |    └─Conv2d: 3-6                  73,728
# |    |    └─BatchNorm2d: 3-7             256
# |    |    └─Conv2d: 3-8                  147,456
# |    |    └─BatchNorm2d: 3-9             256
# |    |    └─Sequential: 3-10             8,448
# ├─Sequential: 1-5                        --
# |    └─BasicBlock: 2-3                   --
# |    |    └─Conv2d: 3-11                 294,912
# |    |    └─BatchNorm2d: 3-12            512
# |    |    └─Conv2d: 3-13                 589,824
# |    |    └─BatchNorm2d: 3-14            512
# |    |    └─Sequential: 3-15             33,280
# ├─Sequential: 1-6                        --
# |    └─BasicBlock: 2-4                   --
# |    |    └─Conv2d: 3-16                 1,179,648
# |    |    └─BatchNorm2d: 3-17            1,024
# |    |    └─Conv2d: 3-18                 2,359,296
# |    |    └─BatchNorm2d: 3-19            1,024
# |    |    └─Sequential: 3-20             132,096
# ├─Linear: 1-7                            5,130
# =================================================================
# Total params: 4,903,242
# Trainable params: 4,903,242
# Non-trainable params: 0
# =================================================================

# %% [markdown]
# ## Model Training

# %%
# Helper Function
# term_width = int(100)

# TOTAL_BAR_LENGTH = 65.
# last_time = time.time()
# begin_time = last_time

# def progress_bar(current, total, msg=None):
#   global last_time, begin_time
#   if current == 0:
#     begin_time = time.time()  # Reset for new bar.

#   cur_len = int(TOTAL_BAR_LENGTH * current/total)
#   rest_len = int(TOTAL_BAR_LENGTH - cur_len) - 1

#   sys.stdout.write(' [')
#   for i in range(cur_len):
#     sys.stdout.write('=')
#   sys.stdout.write('>')
#   for i in range(rest_len):
#     sys.stdout.write('.')
#   sys.stdout.write(']')

#   cur_time = time.time()
#   step_time = cur_time - last_time
#   last_time = cur_time
#   tot_time = cur_time - begin_time

#   L = []
#   L.append('  Step: %s' % format_time(step_time))
#   L.append(' | Tot: %s' % format_time(tot_time))
#   if msg:
#     L.append(' | ' + msg)

#   msg = ''.join(L)
#   sys.stdout.write(msg)
#   for i in range(term_width-int(TOTAL_BAR_LENGTH)-len(msg)-3):
#     sys.stdout.write(' ')

#   # Go back to the center of the bar.
#   for i in range(term_width-int(TOTAL_BAR_LENGTH/2)+2):
#     sys.stdout.write('\b')
#   sys.stdout.write(' %d/%d ' % (current+1, total))

#   if current < total-1:
#     sys.stdout.write('\r')
#   else:
#     sys.stdout.write('\n')
#   sys.stdout.flush()

# %%
def format_time(seconds):
  days = int(seconds / 3600/24)
  seconds = seconds - days*3600*24
  hours = int(seconds / 3600)
  seconds = seconds - hours*3600
  minutes = int(seconds / 60)
  seconds = seconds - minutes*60
  secondsf = int(seconds)
  seconds = seconds - secondsf
  millis = int(seconds*1000)

  f = ''
  i = 1
  if days > 0:
    f += str(days) + 'D'
    i += 1
  if hours > 0 and i <= 2:
    f += str(hours) + 'h'
    i += 1
  if minutes > 0 and i <= 2:
    f += str(minutes) + 'm'
    i += 1
  if secondsf > 0 and i <= 2:
    f += str(secondsf) + 's'
    i += 1
  if millis > 0 and i <= 2:
    f += str(millis) + 'ms'
    i += 1
  if f == '':
    f = '0ms'
  return f

# %%
lr = 0.1
momentum = 0.9
weight_decay = 5e-4

start_epoch = 1
number_of_epochs = 100
best_acc = 0


criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=lr,
                      momentum=momentum, weight_decay=weight_decay)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=number_of_epochs)

# %%
def get_lr(optimizer):
  for param_group in optimizer.param_groups:
    return param_group['lr']

# %%
def train(epoch):
  print('\nEpoch: %d' % epoch)
  start_time = time.time()

  model.train()
  train_loss = 0
  correct = 0
  total = 0
  for batch_idx, (inputs, targets) in enumerate(train_dl):
    # inputs, targets = inputs.to(device), targets.to(device)
    optimizer.zero_grad()
    outputs = model(inputs)
    loss = criterion(outputs, targets)
    loss.backward()
    optimizer.step()

    train_loss += loss.item()
    _, predicted = outputs.max(1)
    total += targets.size(0)
    correct += predicted.eq(targets).sum().item()

    if batch_idx % 50 == 0:
      print(f"Batch: {batch_idx}/{len(train_dl)} | Loss: {(train_loss/(batch_idx+1)):.3f} | Acc: {(100.*correct/total):.3f}%")

  cur_time = time.time()
  epoch_time = cur_time - start_time
  print(f"Time taken : {format_time(epoch_time)}")

  return train_loss/(batch_idx+1), 100.*correct/total, get_lr(optimizer)

# %%
def test(epoch):
  global best_acc
  model.eval()
  test_loss = 0
  correct = 0
  total = 0
  with torch.no_grad():
    for batch_idx, (inputs, targets) in enumerate(test_dl):
      # inputs, targets = inputs.to(device), targets.to(device)
      outputs = model(inputs)
      loss = criterion(outputs, targets)

      test_loss += loss.item()
      _, predicted = outputs.max(1)
      total += targets.size(0)
      correct += predicted.eq(targets).sum().item()
      
      if batch_idx % 50 == 0:
        print(f"Batch: {batch_idx}/{len(test_dl)} | Loss: {(test_loss/(batch_idx+1)):.3f} | Acc: {(100.*correct/total):.3f}%")
      # progress_bar(batch_idx, len(test_dl), 'Loss: %.3f | Acc: %.3f%% (%d/%d)'
      #               % (test_loss/(batch_idx+1), 100.*correct/total, correct, total))

  # Save checkpoint.
  acc = 100.*correct/total
  if acc > best_acc:
    print('Saving..')
    state = {
        'net': model.state_dict(),
        'acc': acc,
        'epoch': epoch,
    }
    if not os.path.isdir('checkpoint'):
      os.mkdir('checkpoint')
    torch.save(state, './checkpoint/ckpt.pth')
    best_acc = acc

  return test_loss/(batch_idx+1), 100.*correct/total

# %%
train_losses = []
train_accuracies = []
train_lrs = []

test_losses = []
test_accuracies = []

for epoch in range(start_epoch, start_epoch + number_of_epochs):
  epoch_train_loss, epoch_train_accuracy, epoch_lr = train(epoch)
  train_losses.append(epoch_train_loss)
  train_accuracies.append(epoch_train_accuracy)
  train_lrs.append(epoch_lr)

  epoch_test_loss, epoch_test_accuracy = test(epoch)
  test_losses.append(epoch_test_loss)
  test_accuracies.append(epoch_test_accuracy)

  scheduler.step()
# Out:
# Epoch: 1
# Batch: 0/391 | Loss: 2.311 | Acc: 7.812%
# Batch: 50/391 | Loss: 2.208 | Acc: 23.729%
# Batch: 100/391 | Loss: 1.971 | Acc: 29.626%
# Batch: 150/391 | Loss: 1.858 | Acc: 32.818%
# Batch: 200/391 | Loss: 1.777 | Acc: 35.308%
# Batch: 250/391 | Loss: 1.716 | Acc: 37.326%
# Batch: 300/391 | Loss: 1.665 | Acc: 39.257%
# Batch: 350/391 | Loss: 1.616 | Acc: 40.983%
# Time taken : 19s900ms
# Batch: 0/100 | Loss: 1.251 | Acc: 56.000%
# Batch: 50/100 | Loss: 1.317 | Acc: 53.137%
# Saving..
#
# Epoch: 2
# Batch: 0/391 | Loss: 1.217 | Acc: 52.344%
# Batch: 50/391 | Loss: 1.241 | Acc: 55.515%
# Batch: 100/391 | Loss: 1.211 | Acc: 56.420%
# Batch: 150/391 | Loss: 1.194 | Acc: 56.995%
# Batch: 200/391 | Loss: 1.186 | Acc: 57.160%
# Batch: 250/391 | Loss: 1.166 | Acc: 57.934%
# Batch: 300/391 | Loss: 1.143 | Acc: 58.796%
# Batch: 350/391 | Loss: 1.127 | Acc: 59.473%
# Time taken : 18s383ms
# Batch: 0/100 | Loss: 1.114 | Acc: 62.000%
# Batch: 50/100 | Loss: 1.155 | Acc: 60.706%
# Saving..
#
# Epoch: 3
# Batch: 0/391 | Loss: 0.870 | Acc: 69.531%
# Batch: 50/391 | Loss: 0.949 | Acc: 65.885%
# Batch: 100/391 | Loss: 0.942 | Acc: 66.453%
# Batch: 150/391 | Loss: 0.938 | Acc: 66.593%
# Batch: 200/391 | Loss: 0.934 | Acc: 66.962%
# Batch: 250/391 | Loss: 0.928 | Acc: 67.138%
# Batch: 300/391 | Loss: 0.919 | Acc: 67.499%
# Batch: 350/391 | Loss: 0.913 | Acc: 67.673%
# Time taken : 18s478ms
# Batch: 0/100 | Loss: 0.766 | Acc: 76.000%
# Batch: 50/100 | Loss: 0.926 | Acc: 67.843%
# Saving..
#
# Epoch: 4
# Batch: 0/391 | Loss: 0.774 | Acc: 75.781%
# Batch: 50/391 | Loss: 0.810 | Acc: 71.140%
# Batch: 100/391 | Loss: 0.808 | Acc: 71.101%
# Batch: 150/391 | Loss: 0.803 | Acc: 71.296%
# Batch: 200/391 | Loss: 0.790 | Acc: 71.875%
# Batch: 250/391 | Loss: 0.784 | Acc: 72.252%
# Batch: 300/391 | Loss: 0.772 | Acc: 72.755%
# Batch: 350/391 | Loss: 0.763 | Acc: 73.104%
# Time taken : 18s326ms
# Batch: 0/100 | Loss: 0.759 | Acc: 75.000%
# Batch: 50/100 | Loss: 0.880 | Acc: 68.627%
# Saving..
#
# Epoch: 5
# Batch: 0/391 | Loss: 0.621 | Acc: 76.562%
# Batch: 50/391 | Loss: 0.696 | Acc: 75.613%
# Batch: 100/391 | Loss: 0.684 | Acc: 76.006%
# Batch: 150/391 | Loss: 0.674 | Acc: 76.392%
# Batch: 200/391 | Loss: 0.665 | Acc: 76.745%
# Batch: 250/391 | Loss: 0.666 | Acc: 76.749%
# Batch: 300/391 | Loss: 0.659 | Acc: 76.970%
# Batch: 350/391 | Loss: 0.655 | Acc: 77.148%
# Time taken : 18s218ms
# Batch: 0/100 | Loss: 0.520 | Acc: 79.000%
# Batch: 50/100 | Loss: 0.627 | Acc: 78.000%
# Saving..
#
# Epoch: 6
# Batch: 0/391 | Loss: 0.468 | Acc: 87.500%
# Batch: 50/391 | Loss: 0.596 | Acc: 79.213%
# Batch: 100/391 | Loss: 0.606 | Acc: 78.883%
# Batch: 150/391 | Loss: 0.605 | Acc: 78.984%
# Batch: 200/391 | Loss: 0.607 | Acc: 78.945%
# Batch: 250/391 | Loss: 0.602 | Acc: 79.109%
# Batch: 300/391 | Loss: 0.600 | Acc: 79.155%
# Batch: 350/391 | Loss: 0.599 | Acc: 79.182%
# Time taken : 18s575ms
# Batch: 0/100 | Loss: 0.520 | Acc: 83.000%
# Batch: 50/100 | Loss: 0.605 | Acc: 79.471%
# Saving..
#
# Epoch: 7
# Batch: 0/391 | Loss: 0.600 | Acc: 78.906%
# Batch: 50/391 | Loss: 0.557 | Acc: 80.852%
# Batch: 100/391 | Loss: 0.549 | Acc: 80.902%
# Batch: 150/391 | Loss: 0.553 | Acc: 80.815%
# Batch: 200/391 | Loss: 0.550 | Acc: 80.947%
# Batch: 250/391 | Loss: 0.554 | Acc: 80.889%
# Batch: 300/391 | Loss: 0.553 | Acc: 80.881%
# Batch: 350/391 | Loss: 0.550 | Acc: 81.043%
# Time taken : 18s351ms
# Batch: 0/100 | Loss: 0.635 | Acc: 81.000%
# Batch: 50/100 | Loss: 0.671 | Acc: 76.843%
#
# Epoch: 8
# Batch: 0/391 | Loss: 0.606 | Acc: 76.562%
# Batch: 50/391 | Loss: 0.540 | Acc: 81.710%
# Batch: 100/391 | Loss: 0.534 | Acc: 81.761%
# Batch: 150/391 | Loss: 0.523 | Acc: 82.181%
# Batch: 200/391 | Loss: 0.523 | Acc: 81.969%
# Batch: 250/391 | Loss: 0.521 | Acc: 82.075%
# Batch: 300/391 | Loss: 0.524 | Acc: 81.917%
# Batch: 350/391 | Loss: 0.525 | Acc: 81.889%
# Time taken : 18s154ms
# Batch: 0/100 | Loss: 0.596 | Acc: 80.000%
# Batch: 50/100 | Loss: 0.592 | Acc: 79.451%
# Saving..
#
# Epoch: 9
# Batch: 0/391 | Loss: 0.361 | Acc: 88.281%
# Batch: 50/391 | Loss: 0.511 | Acc: 82.521%
# Batch: 100/391 | Loss: 0.508 | Acc: 82.433%
# Batch: 150/391 | Loss: 0.506 | Acc: 82.595%
# Batch: 200/391 | Loss: 0.501 | Acc: 82.708%
# Batch: 250/391 | Loss: 0.498 | Acc: 82.819%
# Batch: 300/391 | Loss: 0.497 | Acc: 82.867%
# Batch: 350/391 | Loss: 0.498 | Acc: 82.781%
# Time taken : 18s533ms
# Batch: 0/100 | Loss: 0.538 | Acc: 85.000%
# Batch: 50/100 | Loss: 0.728 | Acc: 76.039%
#
# Epoch: 10
# Batch: 0/391 | Loss: 0.461 | Acc: 85.156%
# Batch: 50/391 | Loss: 0.492 | Acc: 83.272%
# Batch: 100/391 | Loss: 0.485 | Acc: 83.563%
# Batch: 150/391 | Loss: 0.487 | Acc: 83.433%
# Batch: 200/391 | Loss: 0.481 | Acc: 83.602%
# Batch: 250/391 | Loss: 0.483 | Acc: 83.451%
# Batch: 300/391 | Loss: 0.484 | Acc: 83.399%
# Batch: 350/391 | Loss: 0.485 | Acc: 83.320%
# Time taken : 18s619ms
# Batch: 0/100 | Loss: 0.709 | Acc: 74.000%
# Batch: 50/100 | Loss: 0.745 | Acc: 75.333%
#
# Epoch: 11
# Batch: 0/391 | Loss: 0.538 | Acc: 76.562%
# Batch: 50/391 | Loss: 0.450 | Acc: 84.329%
# Batch: 100/391 | Loss: 0.454 | Acc: 84.066%
# Batch: 150/391 | Loss: 0.454 | Acc: 84.147%
# Batch: 200/391 | Loss: 0.456 | Acc: 84.204%
# Batch: 250/391 | Loss: 0.457 | Acc: 84.216%
# Batch: 300/391 | Loss: 0.458 | Acc: 84.128%
# Batch: 350/391 | Loss: 0.458 | Acc: 84.150%
# Time taken : 18s376ms
# Batch: 0/100 | Loss: 1.000 | Acc: 65.000%
# Batch: 50/100 | Loss: 0.876 | Acc: 69.039%
#
# Epoch: 12
# Batch: 0/391 | Loss: 0.431 | Acc: 88.281%
# Batch: 50/391 | Loss: 0.441 | Acc: 85.279%
# Batch: 100/391 | Loss: 0.448 | Acc: 84.661%
# Batch: 150/391 | Loss: 0.447 | Acc: 84.592%
# Batch: 200/391 | Loss: 0.445 | Acc: 84.635%
# Batch: 250/391 | Loss: 0.451 | Acc: 84.518%
# Batch: 300/391 | Loss: 0.448 | Acc: 84.679%
# Batch: 350/391 | Loss: 0.453 | Acc: 84.468%
# Time taken : 18s493ms
# Batch: 0/100 | Loss: 0.769 | Acc: 77.000%
# Batch: 50/100 | Loss: 0.710 | Acc: 77.490%
#
# Epoch: 13
# Batch: 0/391 | Loss: 0.582 | Acc: 78.906%
# Batch: 50/391 | Loss: 0.438 | Acc: 85.325%
# Batch: 100/391 | Loss: 0.429 | Acc: 85.342%
# Batch: 150/391 | Loss: 0.430 | Acc: 85.172%
# Batch: 200/391 | Loss: 0.430 | Acc: 85.168%
# Batch: 250/391 | Loss: 0.432 | Acc: 85.172%
# Batch: 300/391 | Loss: 0.435 | Acc: 85.032%
# Batch: 350/391 | Loss: 0.437 | Acc: 84.972%
# Time taken : 18s221ms
# Batch: 0/100 | Loss: 0.566 | Acc: 84.000%
# Batch: 50/100 | Loss: 0.502 | Acc: 83.020%
# Saving..
#
# Epoch: 14
# Batch: 0/391 | Loss: 0.353 | Acc: 88.281%
# Batch: 50/391 | Loss: 0.381 | Acc: 86.719%
# Batch: 100/391 | Loss: 0.403 | Acc: 86.023%
# Batch: 150/391 | Loss: 0.408 | Acc: 86.005%
# Batch: 200/391 | Loss: 0.417 | Acc: 85.720%
# Batch: 250/391 | Loss: 0.417 | Acc: 85.685%
# Batch: 300/391 | Loss: 0.420 | Acc: 85.616%
# Batch: 350/391 | Loss: 0.423 | Acc: 85.521%
# Time taken : 18s565ms
# Batch: 0/100 | Loss: 0.640 | Acc: 81.000%
# Batch: 50/100 | Loss: 0.561 | Acc: 81.569%
#
# Epoch: 15
# Batch: 0/391 | Loss: 0.445 | Acc: 89.062%
# Batch: 50/391 | Loss: 0.384 | Acc: 86.612%
# Batch: 100/391 | Loss: 0.402 | Acc: 86.108%
# Batch: 150/391 | Loss: 0.401 | Acc: 86.134%
# Batch: 200/391 | Loss: 0.411 | Acc: 85.704%
# Batch: 250/391 | Loss: 0.415 | Acc: 85.595%
# Batch: 300/391 | Loss: 0.414 | Acc: 85.636%
# Batch: 350/391 | Loss: 0.413 | Acc: 85.686%
# Time taken : 18s471ms
# Batch: 0/100 | Loss: 0.527 | Acc: 82.000%
# Batch: 50/100 | Loss: 0.537 | Acc: 81.784%
#
# Epoch: 16
# Batch: 0/391 | Loss: 0.291 | Acc: 89.062%
# Batch: 50/391 | Loss: 0.385 | Acc: 87.056%
# Batch: 100/391 | Loss: 0.391 | Acc: 86.773%
# Batch: 150/391 | Loss: 0.394 | Acc: 86.408%
# Batch: 200/391 | Loss: 0.400 | Acc: 86.155%
# Batch: 250/391 | Loss: 0.403 | Acc: 86.062%
# Batch: 300/391 | Loss: 0.405 | Acc: 86.049%
# Batch: 350/391 | Loss: 0.407 | Acc: 85.973%
# Time taken : 17s826ms
# Batch: 0/100 | Loss: 0.790 | Acc: 76.000%
# Batch: 50/100 | Loss: 0.695 | Acc: 78.098%
#
# Epoch: 17
# Batch: 0/391 | Loss: 0.383 | Acc: 87.500%
# Batch: 50/391 | Loss: 0.364 | Acc: 87.301%
# Batch: 100/391 | Loss: 0.379 | Acc: 86.757%
# Batch: 150/391 | Loss: 0.390 | Acc: 86.507%
# Batch: 200/391 | Loss: 0.394 | Acc: 86.412%
# Batch: 250/391 | Loss: 0.403 | Acc: 86.165%
# Batch: 300/391 | Loss: 0.401 | Acc: 86.184%
# Batch: 350/391 | Loss: 0.402 | Acc: 86.158%
# Time taken : 18s221ms
# Batch: 0/100 | Loss: 0.534 | Acc: 79.000%
# Batch: 50/100 | Loss: 0.583 | Acc: 80.549%
#
# Epoch: 18
# Batch: 0/391 | Loss: 0.344 | Acc: 85.938%
# Batch: 50/391 | Loss: 0.392 | Acc: 86.520%
# Batch: 100/391 | Loss: 0.386 | Acc: 86.726%
# Batch: 150/391 | Loss: 0.390 | Acc: 86.564%
# Batch: 200/391 | Loss: 0.397 | Acc: 86.190%
# Batch: 250/391 | Loss: 0.393 | Acc: 86.286%
# Batch: 300/391 | Loss: 0.397 | Acc: 86.228%
# Batch: 350/391 | Loss: 0.398 | Acc: 86.242%
# Time taken : 18s261ms
# Batch: 0/100 | Loss: 0.648 | Acc: 78.000%
# Batch: 50/100 | Loss: 0.518 | Acc: 82.902%
# Saving..
#
# Epoch: 19
# Batch: 0/391 | Loss: 0.491 | Acc: 85.156%
# Batch: 50/391 | Loss: 0.375 | Acc: 87.286%
# Batch: 100/391 | Loss: 0.391 | Acc: 86.688%
# Batch: 150/391 | Loss: 0.384 | Acc: 87.076%
# Batch: 200/391 | Loss: 0.390 | Acc: 86.711%
# Batch: 250/391 | Loss: 0.386 | Acc: 86.821%
# Batch: 300/391 | Loss: 0.388 | Acc: 86.685%
# Batch: 350/391 | Loss: 0.390 | Acc: 86.514%
# Time taken : 18s441ms
# Batch: 0/100 | Loss: 0.451 | Acc: 87.000%
# Batch: 50/100 | Loss: 0.508 | Acc: 82.824%
#
# Epoch: 20
# Batch: 0/391 | Loss: 0.341 | Acc: 86.719%
# Batch: 50/391 | Loss: 0.359 | Acc: 87.316%
# Batch: 100/391 | Loss: 0.361 | Acc: 87.345%
# Batch: 150/391 | Loss: 0.371 | Acc: 87.159%
# Batch: 200/391 | Loss: 0.374 | Acc: 87.049%
# Batch: 250/391 | Loss: 0.377 | Acc: 86.940%
# Batch: 300/391 | Loss: 0.378 | Acc: 86.900%
# Batch: 350/391 | Loss: 0.379 | Acc: 86.961%
# Time taken : 18s142ms
# Batch: 0/100 | Loss: 0.572 | Acc: 78.000%
# Batch: 50/100 | Loss: 0.510 | Acc: 82.922%
# Saving..
#
# Epoch: 21
# Batch: 0/391 | Loss: 0.389 | Acc: 85.156%
# Batch: 50/391 | Loss: 0.349 | Acc: 87.883%
# Batch: 100/391 | Loss: 0.357 | Acc: 87.778%
# Batch: 150/391 | Loss: 0.362 | Acc: 87.531%
# Batch: 200/391 | Loss: 0.367 | Acc: 87.329%
# Batch: 250/391 | Loss: 0.375 | Acc: 87.058%
# Batch: 300/391 | Loss: 0.376 | Acc: 87.067%
# Batch: 350/391 | Loss: 0.375 | Acc: 87.073%
# Time taken : 18s640ms
# Batch: 0/100 | Loss: 0.558 | Acc: 80.000%
# Batch: 50/100 | Loss: 0.539 | Acc: 82.353%
#
# Epoch: 22
# Batch: 0/391 | Loss: 0.311 | Acc: 87.500%
# Batch: 50/391 | Loss: 0.360 | Acc: 87.714%
# Batch: 100/391 | Loss: 0.369 | Acc: 87.152%
# Batch: 150/391 | Loss: 0.372 | Acc: 87.215%
# Batch: 200/391 | Loss: 0.369 | Acc: 87.282%
# Batch: 250/391 | Loss: 0.375 | Acc: 87.120%
# Batch: 300/391 | Loss: 0.372 | Acc: 87.251%
# Batch: 350/391 | Loss: 0.375 | Acc: 87.079%
# Time taken : 18s442ms
# Batch: 0/100 | Loss: 0.545 | Acc: 82.000%
# Batch: 50/100 | Loss: 0.598 | Acc: 80.392%
#
# Epoch: 23
# Batch: 0/391 | Loss: 0.289 | Acc: 90.625%
# Batch: 50/391 | Loss: 0.343 | Acc: 88.128%
# Batch: 100/391 | Loss: 0.347 | Acc: 87.980%
# Batch: 150/391 | Loss: 0.355 | Acc: 87.660%
# Batch: 200/391 | Loss: 0.362 | Acc: 87.547%
# Batch: 250/391 | Loss: 0.361 | Acc: 87.578%
# Batch: 300/391 | Loss: 0.363 | Acc: 87.580%
# Batch: 350/391 | Loss: 0.363 | Acc: 87.638%
# Time taken : 18s769ms
# Batch: 0/100 | Loss: 0.526 | Acc: 82.000%
# Batch: 50/100 | Loss: 0.476 | Acc: 83.980%
# Saving..
#
# Epoch: 24
# Batch: 0/391 | Loss: 0.291 | Acc: 90.625%
# Batch: 50/391 | Loss: 0.334 | Acc: 88.434%
# Batch: 100/391 | Loss: 0.339 | Acc: 88.312%
# Batch: 150/391 | Loss: 0.348 | Acc: 87.986%
# Batch: 200/391 | Loss: 0.351 | Acc: 87.916%
# Batch: 250/391 | Loss: 0.353 | Acc: 87.889%
# Batch: 300/391 | Loss: 0.361 | Acc: 87.622%
# Batch: 350/391 | Loss: 0.363 | Acc: 87.533%
# Time taken : 18s410ms
# Batch: 0/100 | Loss: 0.657 | Acc: 79.000%
# Batch: 50/100 | Loss: 0.718 | Acc: 76.686%
#
# Epoch: 25
# Batch: 0/391 | Loss: 0.352 | Acc: 85.938%
# Batch: 50/391 | Loss: 0.334 | Acc: 88.572%
# Batch: 100/391 | Loss: 0.344 | Acc: 88.127%
# Batch: 150/391 | Loss: 0.348 | Acc: 87.971%
# Batch: 200/391 | Loss: 0.352 | Acc: 87.830%
# Batch: 250/391 | Loss: 0.353 | Acc: 87.817%
# Batch: 300/391 | Loss: 0.354 | Acc: 87.651%
# Batch: 350/391 | Loss: 0.354 | Acc: 87.745%
# Time taken : 18s529ms
# Batch: 0/100 | Loss: 0.491 | Acc: 83.000%
# Batch: 50/100 | Loss: 0.470 | Acc: 84.353%
# Saving..
#
# Epoch: 26
# Batch: 0/391 | Loss: 0.333 | Acc: 89.844%
# Batch: 50/391 | Loss: 0.327 | Acc: 88.496%
# Batch: 100/391 | Loss: 0.330 | Acc: 88.390%
# Batch: 150/391 | Loss: 0.331 | Acc: 88.488%
# Batch: 200/391 | Loss: 0.334 | Acc: 88.530%
# Batch: 250/391 | Loss: 0.337 | Acc: 88.449%
# Batch: 300/391 | Loss: 0.345 | Acc: 88.190%
# Batch: 350/391 | Loss: 0.350 | Acc: 88.032%
# Time taken : 18s891ms
# Batch: 0/100 | Loss: 0.560 | Acc: 80.000%
# Batch: 50/100 | Loss: 0.517 | Acc: 82.667%
#
# Epoch: 27
# Batch: 0/391 | Loss: 0.396 | Acc: 83.594%
# Batch: 50/391 | Loss: 0.356 | Acc: 88.097%
# Batch: 100/391 | Loss: 0.346 | Acc: 88.049%
# Batch: 150/391 | Loss: 0.339 | Acc: 88.374%
# Batch: 200/391 | Loss: 0.339 | Acc: 88.406%
# Batch: 250/391 | Loss: 0.345 | Acc: 88.356%
# Batch: 300/391 | Loss: 0.352 | Acc: 88.061%
# Batch: 350/391 | Loss: 0.354 | Acc: 87.983%
# Time taken : 19s116ms
# Batch: 0/100 | Loss: 0.833 | Acc: 77.000%
# Batch: 50/100 | Loss: 0.678 | Acc: 78.961%
#
# Epoch: 28
# Batch: 0/391 | Loss: 0.302 | Acc: 91.406%
# Batch: 50/391 | Loss: 0.331 | Acc: 88.526%
# Batch: 100/391 | Loss: 0.332 | Acc: 88.482%
# Batch: 150/391 | Loss: 0.342 | Acc: 88.147%
# Batch: 200/391 | Loss: 0.342 | Acc: 88.192%
# Batch: 250/391 | Loss: 0.340 | Acc: 88.275%
# Batch: 300/391 | Loss: 0.340 | Acc: 88.149%
# Batch: 350/391 | Loss: 0.340 | Acc: 88.172%
# Time taken : 19s16ms
# Batch: 0/100 | Loss: 0.510 | Acc: 81.000%
# Batch: 50/100 | Loss: 0.544 | Acc: 82.216%
#
# Epoch: 29
# Batch: 0/391 | Loss: 0.316 | Acc: 92.969%
# Batch: 50/391 | Loss: 0.323 | Acc: 89.032%
# Batch: 100/391 | Loss: 0.319 | Acc: 89.024%
# Batch: 150/391 | Loss: 0.324 | Acc: 88.985%
# Batch: 200/391 | Loss: 0.330 | Acc: 88.755%
# Batch: 250/391 | Loss: 0.335 | Acc: 88.599%
# Batch: 300/391 | Loss: 0.335 | Acc: 88.564%
# Batch: 350/391 | Loss: 0.336 | Acc: 88.495%
# Time taken : 19s466ms
# Batch: 0/100 | Loss: 0.391 | Acc: 86.000%
# Batch: 50/100 | Loss: 0.455 | Acc: 84.490%
# Saving..
#
# Epoch: 30
# Batch: 0/391 | Loss: 0.280 | Acc: 91.406%
# Batch: 50/391 | Loss: 0.328 | Acc: 88.863%
# Batch: 100/391 | Loss: 0.327 | Acc: 88.714%
# Batch: 150/391 | Loss: 0.333 | Acc: 88.592%
# Batch: 200/391 | Loss: 0.338 | Acc: 88.402%
# Batch: 250/391 | Loss: 0.335 | Acc: 88.527%
# Batch: 300/391 | Loss: 0.338 | Acc: 88.398%
# Batch: 350/391 | Loss: 0.337 | Acc: 88.388%
# Time taken : 19s153ms
# Batch: 0/100 | Loss: 0.508 | Acc: 84.000%
# Batch: 50/100 | Loss: 0.516 | Acc: 83.255%
#
# Epoch: 31
# Batch: 0/391 | Loss: 0.256 | Acc: 91.406%
# Batch: 50/391 | Loss: 0.310 | Acc: 89.430%
# Batch: 100/391 | Loss: 0.320 | Acc: 89.024%
# Batch: 150/391 | Loss: 0.320 | Acc: 89.156%
# Batch: 200/391 | Loss: 0.321 | Acc: 89.109%
# Batch: 250/391 | Loss: 0.324 | Acc: 89.025%
# Batch: 300/391 | Loss: 0.325 | Acc: 88.915%
# Batch: 350/391 | Loss: 0.328 | Acc: 88.782%
# Time taken : 19s450ms
# Batch: 0/100 | Loss: 0.453 | Acc: 86.000%
# Batch: 50/100 | Loss: 0.410 | Acc: 86.588%
# Saving..
#
# Epoch: 32
# Batch: 0/391 | Loss: 0.365 | Acc: 86.719%
# Batch: 50/391 | Loss: 0.328 | Acc: 88.664%
# Batch: 100/391 | Loss: 0.321 | Acc: 88.916%
# Batch: 150/391 | Loss: 0.318 | Acc: 89.021%
# Batch: 200/391 | Loss: 0.322 | Acc: 88.942%
# Batch: 250/391 | Loss: 0.319 | Acc: 89.081%
# Batch: 300/391 | Loss: 0.322 | Acc: 88.953%
# Batch: 350/391 | Loss: 0.324 | Acc: 88.907%
# Time taken : 18s321ms
# Batch: 0/100 | Loss: 0.584 | Acc: 81.000%
# Batch: 50/100 | Loss: 0.506 | Acc: 83.647%
#
# Epoch: 33
# Batch: 0/391 | Loss: 0.284 | Acc: 89.844%
# Batch: 50/391 | Loss: 0.310 | Acc: 89.139%
# Batch: 100/391 | Loss: 0.308 | Acc: 89.325%
# Batch: 150/391 | Loss: 0.314 | Acc: 89.280%
# Batch: 200/391 | Loss: 0.313 | Acc: 89.288%
# Batch: 250/391 | Loss: 0.314 | Acc: 89.212%
# Batch: 300/391 | Loss: 0.315 | Acc: 89.143%
# Batch: 350/391 | Loss: 0.318 | Acc: 89.051%
# Time taken : 18s140ms
# Batch: 0/100 | Loss: 0.471 | Acc: 86.000%
# Batch: 50/100 | Loss: 0.461 | Acc: 84.569%
#
# Epoch: 34
# Batch: 0/391 | Loss: 0.334 | Acc: 85.156%
# Batch: 50/391 | Loss: 0.292 | Acc: 89.767%
# Batch: 100/391 | Loss: 0.311 | Acc: 89.140%
# Batch: 150/391 | Loss: 0.318 | Acc: 88.964%
# Batch: 200/391 | Loss: 0.325 | Acc: 88.759%
# Batch: 250/391 | Loss: 0.324 | Acc: 88.801%
# Batch: 300/391 | Loss: 0.322 | Acc: 88.959%
# Batch: 350/391 | Loss: 0.321 | Acc: 88.927%
# Time taken : 18s367ms
# Batch: 0/100 | Loss: 0.519 | Acc: 84.000%
# Batch: 50/100 | Loss: 0.492 | Acc: 83.686%
#
# Epoch: 35
# Batch: 0/391 | Loss: 0.322 | Acc: 89.062%
# Batch: 50/391 | Loss: 0.286 | Acc: 90.227%
# Batch: 100/391 | Loss: 0.285 | Acc: 90.153%
# Batch: 150/391 | Loss: 0.289 | Acc: 89.906%
# Batch: 200/391 | Loss: 0.293 | Acc: 89.902%
# Batch: 250/391 | Loss: 0.298 | Acc: 89.716%
# Batch: 300/391 | Loss: 0.301 | Acc: 89.659%
# Batch: 350/391 | Loss: 0.306 | Acc: 89.481%
# Time taken : 18s598ms
# Batch: 0/100 | Loss: 0.423 | Acc: 85.000%
# Batch: 50/100 | Loss: 0.571 | Acc: 81.706%
#
# Epoch: 36
# Batch: 0/391 | Loss: 0.305 | Acc: 92.188%
# Batch: 50/391 | Loss: 0.303 | Acc: 89.706%
# Batch: 100/391 | Loss: 0.310 | Acc: 89.434%
# Batch: 150/391 | Loss: 0.311 | Acc: 89.430%
# Batch: 200/391 | Loss: 0.307 | Acc: 89.513%
# Batch: 250/391 | Loss: 0.307 | Acc: 89.511%
# Batch: 300/391 | Loss: 0.309 | Acc: 89.426%
# Batch: 350/391 | Loss: 0.312 | Acc: 89.338%
# Time taken : 18s446ms
# Batch: 0/100 | Loss: 0.499 | Acc: 80.000%
# Batch: 50/100 | Loss: 0.485 | Acc: 83.706%
#
# Epoch: 37
# Batch: 0/391 | Loss: 0.368 | Acc: 86.719%
# Batch: 50/391 | Loss: 0.284 | Acc: 90.411%
# Batch: 100/391 | Loss: 0.292 | Acc: 90.053%
# Batch: 150/391 | Loss: 0.294 | Acc: 90.025%
# Batch: 200/391 | Loss: 0.299 | Acc: 89.813%
# Batch: 250/391 | Loss: 0.303 | Acc: 89.623%
# Batch: 300/391 | Loss: 0.306 | Acc: 89.493%
# Batch: 350/391 | Loss: 0.305 | Acc: 89.581%
# Time taken : 18s293ms
# Batch: 0/100 | Loss: 0.418 | Acc: 84.000%
# Batch: 50/100 | Loss: 0.494 | Acc: 83.706%
#
# Epoch: 38
# Batch: 0/391 | Loss: 0.206 | Acc: 93.750%
# Batch: 50/391 | Loss: 0.261 | Acc: 91.176%
# Batch: 100/391 | Loss: 0.276 | Acc: 90.524%
# Batch: 150/391 | Loss: 0.290 | Acc: 90.020%
# Batch: 200/391 | Loss: 0.297 | Acc: 89.766%
# Batch: 250/391 | Loss: 0.300 | Acc: 89.632%
# Batch: 300/391 | Loss: 0.301 | Acc: 89.639%
# Batch: 350/391 | Loss: 0.298 | Acc: 89.790%
# Time taken : 18s351ms
# Batch: 0/100 | Loss: 0.490 | Acc: 85.000%
# Batch: 50/100 | Loss: 0.524 | Acc: 82.765%
#
# Epoch: 39
# Batch: 0/391 | Loss: 0.402 | Acc: 84.375%
# Batch: 50/391 | Loss: 0.264 | Acc: 90.610%
# Batch: 100/391 | Loss: 0.265 | Acc: 90.664%
# Batch: 150/391 | Loss: 0.268 | Acc: 90.439%
# Batch: 200/391 | Loss: 0.277 | Acc: 90.236%
# Batch: 250/391 | Loss: 0.282 | Acc: 90.093%
# Batch: 300/391 | Loss: 0.289 | Acc: 89.911%
# Batch: 350/391 | Loss: 0.291 | Acc: 89.819%
# Time taken : 18s239ms
# Batch: 0/100 | Loss: 0.571 | Acc: 79.000%
# Batch: 50/100 | Loss: 0.513 | Acc: 82.745%
#
# Epoch: 40
# Batch: 0/391 | Loss: 0.228 | Acc: 91.406%
# Batch: 50/391 | Loss: 0.268 | Acc: 90.487%
# Batch: 100/391 | Loss: 0.278 | Acc: 90.161%
# Batch: 150/391 | Loss: 0.277 | Acc: 90.330%
# Batch: 200/391 | Loss: 0.280 | Acc: 90.256%
# Batch: 250/391 | Loss: 0.284 | Acc: 90.308%
# Batch: 300/391 | Loss: 0.287 | Acc: 90.199%
# Batch: 350/391 | Loss: 0.290 | Acc: 90.086%
# Time taken : 18s4ms
# Batch: 0/100 | Loss: 0.419 | Acc: 88.000%
# Batch: 50/100 | Loss: 0.425 | Acc: 86.392%
# Saving..
#
# Epoch: 41
# Batch: 0/391 | Loss: 0.212 | Acc: 90.625%
# Batch: 50/391 | Loss: 0.270 | Acc: 90.702%
# Batch: 100/391 | Loss: 0.275 | Acc: 90.532%
# Batch: 150/391 | Loss: 0.280 | Acc: 90.211%
# Batch: 200/391 | Loss: 0.276 | Acc: 90.392%
# Batch: 250/391 | Loss: 0.276 | Acc: 90.416%
# Batch: 300/391 | Loss: 0.284 | Acc: 90.205%
# Batch: 350/391 | Loss: 0.285 | Acc: 90.146%
# Time taken : 18s515ms
# Batch: 0/100 | Loss: 0.351 | Acc: 86.000%
# Batch: 50/100 | Loss: 0.423 | Acc: 85.843%
#
# Epoch: 42
# Batch: 0/391 | Loss: 0.223 | Acc: 92.188%
# Batch: 50/391 | Loss: 0.262 | Acc: 90.947%
# Batch: 100/391 | Loss: 0.264 | Acc: 90.888%
# Batch: 150/391 | Loss: 0.264 | Acc: 90.982%
# Batch: 200/391 | Loss: 0.267 | Acc: 90.831%
# Batch: 250/391 | Loss: 0.270 | Acc: 90.818%
# Batch: 300/391 | Loss: 0.274 | Acc: 90.570%
# Batch: 350/391 | Loss: 0.277 | Acc: 90.500%
# Time taken : 18s361ms
# Batch: 0/100 | Loss: 0.406 | Acc: 86.000%
# Batch: 50/100 | Loss: 0.429 | Acc: 85.588%
#
# Epoch: 43
# Batch: 0/391 | Loss: 0.216 | Acc: 92.969%
# Batch: 50/391 | Loss: 0.249 | Acc: 91.728%
# Batch: 100/391 | Loss: 0.263 | Acc: 91.050%
# Batch: 150/391 | Loss: 0.264 | Acc: 91.008%
# Batch: 200/391 | Loss: 0.269 | Acc: 90.796%
# Batch: 250/391 | Loss: 0.272 | Acc: 90.693%
# Batch: 300/391 | Loss: 0.273 | Acc: 90.620%
# Batch: 350/391 | Loss: 0.274 | Acc: 90.574%
# Time taken : 17s770ms
# Batch: 0/100 | Loss: 0.424 | Acc: 86.000%
# Batch: 50/100 | Loss: 0.454 | Acc: 85.039%
#
# Epoch: 44
# Batch: 0/391 | Loss: 0.357 | Acc: 86.719%
# Batch: 50/391 | Loss: 0.271 | Acc: 90.885%
# Batch: 100/391 | Loss: 0.259 | Acc: 91.282%
# Batch: 150/391 | Loss: 0.254 | Acc: 91.339%
# Batch: 200/391 | Loss: 0.264 | Acc: 90.936%
# Batch: 250/391 | Loss: 0.266 | Acc: 90.908%
# Batch: 300/391 | Loss: 0.266 | Acc: 90.898%
# Batch: 350/391 | Loss: 0.270 | Acc: 90.712%
# Time taken : 18s185ms
# Batch: 0/100 | Loss: 0.446 | Acc: 86.000%
# Batch: 50/100 | Loss: 0.408 | Acc: 85.980%
#
# Epoch: 45
# Batch: 0/391 | Loss: 0.239 | Acc: 91.406%
# Batch: 50/391 | Loss: 0.235 | Acc: 92.065%
# Batch: 100/391 | Loss: 0.242 | Acc: 91.778%
# Batch: 150/391 | Loss: 0.246 | Acc: 91.603%
# Batch: 200/391 | Loss: 0.249 | Acc: 91.500%
# Batch: 250/391 | Loss: 0.253 | Acc: 91.325%
# Batch: 300/391 | Loss: 0.259 | Acc: 91.108%
# Batch: 350/391 | Loss: 0.260 | Acc: 91.010%
# Time taken : 18s136ms
# Batch: 0/100 | Loss: 0.475 | Acc: 81.000%
# Batch: 50/100 | Loss: 0.647 | Acc: 80.000%
#
# Epoch: 46
# Batch: 0/391 | Loss: 0.337 | Acc: 89.844%
# Batch: 50/391 | Loss: 0.253 | Acc: 91.636%
# Batch: 100/391 | Loss: 0.253 | Acc: 91.507%
# Batch: 150/391 | Loss: 0.252 | Acc: 91.499%
# Batch: 200/391 | Loss: 0.261 | Acc: 91.169%
# Batch: 250/391 | Loss: 0.262 | Acc: 91.064%
# Batch: 300/391 | Loss: 0.263 | Acc: 90.962%
# Batch: 350/391 | Loss: 0.265 | Acc: 90.841%
# Time taken : 18s44ms
# Batch: 0/100 | Loss: 0.408 | Acc: 85.000%
# Batch: 50/100 | Loss: 0.435 | Acc: 85.412%
#
# Epoch: 47
# Batch: 0/391 | Loss: 0.236 | Acc: 92.969%
# Batch: 50/391 | Loss: 0.245 | Acc: 91.651%
# Batch: 100/391 | Loss: 0.246 | Acc: 91.685%
# Batch: 150/391 | Loss: 0.249 | Acc: 91.494%
# Batch: 200/391 | Loss: 0.249 | Acc: 91.511%
# Batch: 250/391 | Loss: 0.248 | Acc: 91.565%
# Batch: 300/391 | Loss: 0.253 | Acc: 91.367%
# Batch: 350/391 | Loss: 0.254 | Acc: 91.366%
# Time taken : 18s232ms
# Batch: 0/100 | Loss: 0.461 | Acc: 86.000%
# Batch: 50/100 | Loss: 0.458 | Acc: 86.118%
#
# Epoch: 48
# Batch: 0/391 | Loss: 0.081 | Acc: 98.438%
# Batch: 50/391 | Loss: 0.228 | Acc: 91.973%
# Batch: 100/391 | Loss: 0.240 | Acc: 91.801%
# Batch: 150/391 | Loss: 0.244 | Acc: 91.505%
# Batch: 200/391 | Loss: 0.246 | Acc: 91.465%
# Batch: 250/391 | Loss: 0.250 | Acc: 91.347%
# Batch: 300/391 | Loss: 0.250 | Acc: 91.323%
# Batch: 350/391 | Loss: 0.253 | Acc: 91.199%
# Time taken : 17s823ms
# Batch: 0/100 | Loss: 0.322 | Acc: 89.000%
# Batch: 50/100 | Loss: 0.368 | Acc: 87.706%
# Saving..
#
# Epoch: 49
# Batch: 0/391 | Loss: 0.215 | Acc: 92.188%
# Batch: 50/391 | Loss: 0.239 | Acc: 91.973%
# Batch: 100/391 | Loss: 0.235 | Acc: 91.932%
# Batch: 150/391 | Loss: 0.230 | Acc: 92.167%
# Batch: 200/391 | Loss: 0.233 | Acc: 92.083%
# Batch: 250/391 | Loss: 0.237 | Acc: 91.967%
# Batch: 300/391 | Loss: 0.240 | Acc: 91.822%
# Batch: 350/391 | Loss: 0.245 | Acc: 91.651%
# Time taken : 18s80ms
# Batch: 0/100 | Loss: 0.333 | Acc: 88.000%
# Batch: 50/100 | Loss: 0.334 | Acc: 88.863%
# Saving..
#
# Epoch: 50
# Batch: 0/391 | Loss: 0.263 | Acc: 91.406%
# Batch: 50/391 | Loss: 0.229 | Acc: 92.126%
# Batch: 100/391 | Loss: 0.235 | Acc: 91.723%
# Batch: 150/391 | Loss: 0.233 | Acc: 91.856%
# Batch: 200/391 | Loss: 0.237 | Acc: 91.748%
# Batch: 250/391 | Loss: 0.236 | Acc: 91.811%
# Batch: 300/391 | Loss: 0.238 | Acc: 91.728%
# Batch: 350/391 | Loss: 0.236 | Acc: 91.789%
# Time taken : 18s12ms
# Batch: 0/100 | Loss: 0.386 | Acc: 87.000%
# Batch: 50/100 | Loss: 0.428 | Acc: 86.137%
#
# Epoch: 51
# Batch: 0/391 | Loss: 0.163 | Acc: 96.094%
# Batch: 50/391 | Loss: 0.240 | Acc: 91.896%
# Batch: 100/391 | Loss: 0.227 | Acc: 92.172%
# Batch: 150/391 | Loss: 0.231 | Acc: 92.156%
# Batch: 200/391 | Loss: 0.233 | Acc: 92.048%
# Batch: 250/391 | Loss: 0.229 | Acc: 92.141%
# Batch: 300/391 | Loss: 0.231 | Acc: 92.125%
# Batch: 350/391 | Loss: 0.235 | Acc: 91.978%
# Time taken : 18s172ms
# Batch: 0/100 | Loss: 0.473 | Acc: 84.000%
# Batch: 50/100 | Loss: 0.486 | Acc: 84.255%
#
# Epoch: 52
# Batch: 0/391 | Loss: 0.137 | Acc: 97.656%
# Batch: 50/391 | Loss: 0.219 | Acc: 92.800%
# Batch: 100/391 | Loss: 0.222 | Acc: 92.613%
# Batch: 150/391 | Loss: 0.220 | Acc: 92.544%
# Batch: 200/391 | Loss: 0.219 | Acc: 92.572%
# Batch: 250/391 | Loss: 0.217 | Acc: 92.651%
# Batch: 300/391 | Loss: 0.220 | Acc: 92.546%
# Batch: 350/391 | Loss: 0.225 | Acc: 92.343%
# Time taken : 18s209ms
# Batch: 0/100 | Loss: 0.361 | Acc: 87.000%
# Batch: 50/100 | Loss: 0.382 | Acc: 87.176%
#
# Epoch: 53
# Batch: 0/391 | Loss: 0.213 | Acc: 92.188%
# Batch: 50/391 | Loss: 0.216 | Acc: 92.555%
# Batch: 100/391 | Loss: 0.212 | Acc: 92.659%
# Batch: 150/391 | Loss: 0.215 | Acc: 92.679%
# Batch: 200/391 | Loss: 0.218 | Acc: 92.510%
# Batch: 250/391 | Loss: 0.218 | Acc: 92.486%
# Batch: 300/391 | Loss: 0.218 | Acc: 92.533%
# Batch: 350/391 | Loss: 0.219 | Acc: 92.484%
# Time taken : 17s937ms
# Batch: 0/100 | Loss: 0.344 | Acc: 87.000%
# Batch: 50/100 | Loss: 0.387 | Acc: 87.843%
#
# Epoch: 54
# Batch: 0/391 | Loss: 0.157 | Acc: 94.531%
# Batch: 50/391 | Loss: 0.203 | Acc: 92.969%
# Batch: 100/391 | Loss: 0.206 | Acc: 92.891%
# Batch: 150/391 | Loss: 0.209 | Acc: 92.917%
# Batch: 200/391 | Loss: 0.211 | Acc: 92.817%
# Batch: 250/391 | Loss: 0.216 | Acc: 92.598%
# Batch: 300/391 | Loss: 0.220 | Acc: 92.411%
# Batch: 350/391 | Loss: 0.220 | Acc: 92.386%
# Time taken : 18s77ms
# Batch: 0/100 | Loss: 0.360 | Acc: 84.000%
# Batch: 50/100 | Loss: 0.405 | Acc: 87.471%
#
# Epoch: 55
# Batch: 0/391 | Loss: 0.190 | Acc: 93.750%
# Batch: 50/391 | Loss: 0.203 | Acc: 93.091%
# Batch: 100/391 | Loss: 0.193 | Acc: 93.286%
# Batch: 150/391 | Loss: 0.202 | Acc: 92.964%
# Batch: 200/391 | Loss: 0.208 | Acc: 92.689%
# Batch: 250/391 | Loss: 0.210 | Acc: 92.657%
# Batch: 300/391 | Loss: 0.212 | Acc: 92.605%
# Batch: 350/391 | Loss: 0.213 | Acc: 92.626%
# Time taken : 17s957ms
# Batch: 0/100 | Loss: 0.299 | Acc: 91.000%
# Batch: 50/100 | Loss: 0.385 | Acc: 87.627%
#
# Epoch: 56
# Batch: 0/391 | Loss: 0.183 | Acc: 94.531%
# Batch: 50/391 | Loss: 0.188 | Acc: 93.382%
# Batch: 100/391 | Loss: 0.194 | Acc: 93.247%
# Batch: 150/391 | Loss: 0.196 | Acc: 93.139%
# Batch: 200/391 | Loss: 0.196 | Acc: 93.175%
# Batch: 250/391 | Loss: 0.202 | Acc: 92.903%
# Batch: 300/391 | Loss: 0.203 | Acc: 92.914%
# Batch: 350/391 | Loss: 0.204 | Acc: 92.869%
# Time taken : 18s74ms
# Batch: 0/100 | Loss: 0.345 | Acc: 85.000%
# Batch: 50/100 | Loss: 0.356 | Acc: 88.843%
# Saving..
#
# Epoch: 57
# Batch: 0/391 | Loss: 0.216 | Acc: 92.188%
# Batch: 50/391 | Loss: 0.176 | Acc: 93.857%
# Batch: 100/391 | Loss: 0.175 | Acc: 93.897%
# Batch: 150/391 | Loss: 0.178 | Acc: 93.776%
# Batch: 200/391 | Loss: 0.186 | Acc: 93.455%
# Batch: 250/391 | Loss: 0.190 | Acc: 93.317%
# Batch: 300/391 | Loss: 0.199 | Acc: 93.023%
# Batch: 350/391 | Loss: 0.200 | Acc: 92.995%
# Time taken : 18s348ms
# Batch: 0/100 | Loss: 0.235 | Acc: 92.000%
# Batch: 50/100 | Loss: 0.345 | Acc: 88.529%
#
# Epoch: 58
# Batch: 0/391 | Loss: 0.181 | Acc: 94.531%
# Batch: 50/391 | Loss: 0.181 | Acc: 93.566%
# Batch: 100/391 | Loss: 0.181 | Acc: 93.704%
# Batch: 150/391 | Loss: 0.181 | Acc: 93.797%
# Batch: 200/391 | Loss: 0.185 | Acc: 93.719%
# Batch: 250/391 | Loss: 0.186 | Acc: 93.576%
# Batch: 300/391 | Loss: 0.188 | Acc: 93.516%
# Batch: 350/391 | Loss: 0.192 | Acc: 93.378%
# Time taken : 18s177ms
# Batch: 0/100 | Loss: 0.370 | Acc: 89.000%
# Batch: 50/100 | Loss: 0.353 | Acc: 88.765%
#
# Epoch: 59
# Batch: 0/391 | Loss: 0.263 | Acc: 90.625%
# Batch: 50/391 | Loss: 0.171 | Acc: 94.317%
# Batch: 100/391 | Loss: 0.182 | Acc: 93.866%
# Batch: 150/391 | Loss: 0.178 | Acc: 93.972%
# Batch: 200/391 | Loss: 0.178 | Acc: 93.983%
# Batch: 250/391 | Loss: 0.185 | Acc: 93.713%
# Batch: 300/391 | Loss: 0.186 | Acc: 93.672%
# Batch: 350/391 | Loss: 0.189 | Acc: 93.554%
# Time taken : 17s876ms
# Batch: 0/100 | Loss: 0.533 | Acc: 83.000%
# Batch: 50/100 | Loss: 0.572 | Acc: 83.118%
#
# Epoch: 60
# Batch: 0/391 | Loss: 0.118 | Acc: 96.094%
# Batch: 50/391 | Loss: 0.171 | Acc: 94.485%
# Batch: 100/391 | Loss: 0.174 | Acc: 94.152%
# Batch: 150/391 | Loss: 0.166 | Acc: 94.361%
# Batch: 200/391 | Loss: 0.168 | Acc: 94.248%
# Batch: 250/391 | Loss: 0.172 | Acc: 94.152%
# Batch: 300/391 | Loss: 0.176 | Acc: 93.999%
# Batch: 350/391 | Loss: 0.178 | Acc: 93.892%
# Time taken : 18s12ms
# Batch: 0/100 | Loss: 0.324 | Acc: 90.000%
# Batch: 50/100 | Loss: 0.329 | Acc: 90.000%
# Saving..
#
# Epoch: 61
# Batch: 0/391 | Loss: 0.119 | Acc: 94.531%
# Batch: 50/391 | Loss: 0.163 | Acc: 94.424%
# Batch: 100/391 | Loss: 0.172 | Acc: 94.137%
# Batch: 150/391 | Loss: 0.173 | Acc: 94.009%
# Batch: 200/391 | Loss: 0.176 | Acc: 93.898%
# Batch: 250/391 | Loss: 0.177 | Acc: 93.822%
# Batch: 300/391 | Loss: 0.177 | Acc: 93.812%
# Batch: 350/391 | Loss: 0.180 | Acc: 93.723%
# Time taken : 18s77ms
# Batch: 0/100 | Loss: 0.477 | Acc: 86.000%
# Batch: 50/100 | Loss: 0.349 | Acc: 88.510%
#
# Epoch: 62
# Batch: 0/391 | Loss: 0.161 | Acc: 92.969%
# Batch: 50/391 | Loss: 0.165 | Acc: 94.240%
# Batch: 100/391 | Loss: 0.162 | Acc: 94.261%
# Batch: 150/391 | Loss: 0.156 | Acc: 94.578%
# Batch: 200/391 | Loss: 0.157 | Acc: 94.504%
# Batch: 250/391 | Loss: 0.161 | Acc: 94.425%
# Batch: 300/391 | Loss: 0.164 | Acc: 94.305%
# Batch: 350/391 | Loss: 0.166 | Acc: 94.300%
# Time taken : 18s658ms
# Batch: 0/100 | Loss: 0.311 | Acc: 89.000%
# Batch: 50/100 | Loss: 0.374 | Acc: 88.216%
#
# Epoch: 63
# Batch: 0/391 | Loss: 0.117 | Acc: 95.312%
# Batch: 50/391 | Loss: 0.156 | Acc: 95.021%
# Batch: 100/391 | Loss: 0.150 | Acc: 95.181%
# Batch: 150/391 | Loss: 0.148 | Acc: 95.142%
# Batch: 200/391 | Loss: 0.151 | Acc: 94.990%
# Batch: 250/391 | Loss: 0.155 | Acc: 94.783%
# Batch: 300/391 | Loss: 0.159 | Acc: 94.630%
# Batch: 350/391 | Loss: 0.160 | Acc: 94.631%
# Time taken : 18s292ms
# Batch: 0/100 | Loss: 0.215 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.354 | Acc: 88.980%
#
# Epoch: 64
# Batch: 0/391 | Loss: 0.138 | Acc: 96.875%
# Batch: 50/391 | Loss: 0.135 | Acc: 95.496%
# Batch: 100/391 | Loss: 0.136 | Acc: 95.429%
# Batch: 150/391 | Loss: 0.144 | Acc: 95.131%
# Batch: 200/391 | Loss: 0.149 | Acc: 94.889%
# Batch: 250/391 | Loss: 0.153 | Acc: 94.699%
# Batch: 300/391 | Loss: 0.155 | Acc: 94.632%
# Batch: 350/391 | Loss: 0.156 | Acc: 94.600%
# Time taken : 18s401ms
# Batch: 0/100 | Loss: 0.373 | Acc: 89.000%
# Batch: 50/100 | Loss: 0.308 | Acc: 89.784%
# Saving..
#
# Epoch: 65
# Batch: 0/391 | Loss: 0.123 | Acc: 97.656%
# Batch: 50/391 | Loss: 0.134 | Acc: 95.328%
# Batch: 100/391 | Loss: 0.140 | Acc: 95.227%
# Batch: 150/391 | Loss: 0.142 | Acc: 95.173%
# Batch: 200/391 | Loss: 0.144 | Acc: 95.079%
# Batch: 250/391 | Loss: 0.147 | Acc: 94.939%
# Batch: 300/391 | Loss: 0.148 | Acc: 94.895%
# Batch: 350/391 | Loss: 0.149 | Acc: 94.821%
# Time taken : 18s365ms
# Batch: 0/100 | Loss: 0.332 | Acc: 86.000%
# Batch: 50/100 | Loss: 0.337 | Acc: 89.745%
#
# Epoch: 66
# Batch: 0/391 | Loss: 0.109 | Acc: 96.094%
# Batch: 50/391 | Loss: 0.137 | Acc: 95.221%
# Batch: 100/391 | Loss: 0.138 | Acc: 95.235%
# Batch: 150/391 | Loss: 0.134 | Acc: 95.344%
# Batch: 200/391 | Loss: 0.134 | Acc: 95.410%
# Batch: 250/391 | Loss: 0.138 | Acc: 95.269%
# Batch: 300/391 | Loss: 0.139 | Acc: 95.266%
# Batch: 350/391 | Loss: 0.141 | Acc: 95.143%
# Time taken : 18s593ms
# Batch: 0/100 | Loss: 0.232 | Acc: 93.000%
# Batch: 50/100 | Loss: 0.349 | Acc: 89.275%
#
# Epoch: 67
# Batch: 0/391 | Loss: 0.078 | Acc: 99.219%
# Batch: 50/391 | Loss: 0.118 | Acc: 95.956%
# Batch: 100/391 | Loss: 0.126 | Acc: 95.769%
# Batch: 150/391 | Loss: 0.129 | Acc: 95.556%
# Batch: 200/391 | Loss: 0.129 | Acc: 95.616%
# Batch: 250/391 | Loss: 0.132 | Acc: 95.555%
# Batch: 300/391 | Loss: 0.134 | Acc: 95.460%
# Batch: 350/391 | Loss: 0.135 | Acc: 95.346%
# Time taken : 18s396ms
# Batch: 0/100 | Loss: 0.287 | Acc: 93.000%
# Batch: 50/100 | Loss: 0.317 | Acc: 90.490%
# Saving..
#
# Epoch: 68
# Batch: 0/391 | Loss: 0.158 | Acc: 93.750%
# Batch: 50/391 | Loss: 0.104 | Acc: 96.645%
# Batch: 100/391 | Loss: 0.113 | Acc: 96.279%
# Batch: 150/391 | Loss: 0.113 | Acc: 96.218%
# Batch: 200/391 | Loss: 0.116 | Acc: 96.094%
# Batch: 250/391 | Loss: 0.118 | Acc: 95.963%
# Batch: 300/391 | Loss: 0.120 | Acc: 95.928%
# Batch: 350/391 | Loss: 0.121 | Acc: 95.869%
# Time taken : 18s175ms
# Batch: 0/100 | Loss: 0.201 | Acc: 92.000%
# Batch: 50/100 | Loss: 0.309 | Acc: 90.451%
#
# Epoch: 69
# Batch: 0/391 | Loss: 0.073 | Acc: 98.438%
# Batch: 50/391 | Loss: 0.110 | Acc: 96.369%
# Batch: 100/391 | Loss: 0.114 | Acc: 96.148%
# Batch: 150/391 | Loss: 0.118 | Acc: 95.959%
# Batch: 200/391 | Loss: 0.120 | Acc: 95.907%
# Batch: 250/391 | Loss: 0.120 | Acc: 95.857%
# Batch: 300/391 | Loss: 0.120 | Acc: 95.891%
# Batch: 350/391 | Loss: 0.123 | Acc: 95.782%
# Time taken : 18s111ms
# Batch: 0/100 | Loss: 0.456 | Acc: 88.000%
# Batch: 50/100 | Loss: 0.372 | Acc: 88.412%
#
# Epoch: 70
# Batch: 0/391 | Loss: 0.124 | Acc: 97.656%
# Batch: 50/391 | Loss: 0.104 | Acc: 96.523%
# Batch: 100/391 | Loss: 0.100 | Acc: 96.674%
# Batch: 150/391 | Loss: 0.103 | Acc: 96.559%
# Batch: 200/391 | Loss: 0.105 | Acc: 96.479%
# Batch: 250/391 | Loss: 0.107 | Acc: 96.346%
# Batch: 300/391 | Loss: 0.110 | Acc: 96.270%
# Batch: 350/391 | Loss: 0.114 | Acc: 96.132%
# Time taken : 18s384ms
# Batch: 0/100 | Loss: 0.371 | Acc: 90.000%
# Batch: 50/100 | Loss: 0.314 | Acc: 90.706%
# Saving..
#
# Epoch: 71
# Batch: 0/391 | Loss: 0.160 | Acc: 93.750%
# Batch: 50/391 | Loss: 0.108 | Acc: 96.431%
# Batch: 100/391 | Loss: 0.098 | Acc: 96.829%
# Batch: 150/391 | Loss: 0.098 | Acc: 96.797%
# Batch: 200/391 | Loss: 0.100 | Acc: 96.638%
# Batch: 250/391 | Loss: 0.102 | Acc: 96.498%
# Batch: 300/391 | Loss: 0.104 | Acc: 96.465%
# Batch: 350/391 | Loss: 0.105 | Acc: 96.399%
# Time taken : 18s5ms
# Batch: 0/100 | Loss: 0.314 | Acc: 93.000%
# Batch: 50/100 | Loss: 0.311 | Acc: 90.314%
#
# Epoch: 72
# Batch: 0/391 | Loss: 0.210 | Acc: 92.188%
# Batch: 50/391 | Loss: 0.087 | Acc: 97.135%
# Batch: 100/391 | Loss: 0.090 | Acc: 97.084%
# Batch: 150/391 | Loss: 0.086 | Acc: 97.185%
# Batch: 200/391 | Loss: 0.087 | Acc: 97.143%
# Batch: 250/391 | Loss: 0.087 | Acc: 97.164%
# Batch: 300/391 | Loss: 0.089 | Acc: 97.064%
# Batch: 350/391 | Loss: 0.092 | Acc: 96.953%
# Time taken : 17s940ms
# Batch: 0/100 | Loss: 0.456 | Acc: 89.000%
# Batch: 50/100 | Loss: 0.307 | Acc: 90.373%
# Saving..
#
# Epoch: 73
# Batch: 0/391 | Loss: 0.128 | Acc: 97.656%
# Batch: 50/391 | Loss: 0.099 | Acc: 96.615%
# Batch: 100/391 | Loss: 0.089 | Acc: 97.107%
# Batch: 150/391 | Loss: 0.086 | Acc: 97.248%
# Batch: 200/391 | Loss: 0.089 | Acc: 97.085%
# Batch: 250/391 | Loss: 0.089 | Acc: 97.077%
# Batch: 300/391 | Loss: 0.089 | Acc: 97.064%
# Batch: 350/391 | Loss: 0.091 | Acc: 97.011%
# Time taken : 18s281ms
# Batch: 0/100 | Loss: 0.251 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.321 | Acc: 90.490%
#
# Epoch: 74
# Batch: 0/391 | Loss: 0.110 | Acc: 96.094%
# Batch: 50/391 | Loss: 0.083 | Acc: 97.089%
# Batch: 100/391 | Loss: 0.082 | Acc: 97.231%
# Batch: 150/391 | Loss: 0.079 | Acc: 97.346%
# Batch: 200/391 | Loss: 0.079 | Acc: 97.330%
# Batch: 250/391 | Loss: 0.081 | Acc: 97.311%
# Batch: 300/391 | Loss: 0.081 | Acc: 97.314%
# Batch: 350/391 | Loss: 0.081 | Acc: 97.327%
# Time taken : 17s785ms
# Batch: 0/100 | Loss: 0.251 | Acc: 92.000%
# Batch: 50/100 | Loss: 0.314 | Acc: 91.020%
# Saving..
#
# Epoch: 75
# Batch: 0/391 | Loss: 0.061 | Acc: 98.438%
# Batch: 50/391 | Loss: 0.072 | Acc: 97.702%
# Batch: 100/391 | Loss: 0.071 | Acc: 97.672%
# Batch: 150/391 | Loss: 0.074 | Acc: 97.563%
# Batch: 200/391 | Loss: 0.075 | Acc: 97.497%
# Batch: 250/391 | Loss: 0.075 | Acc: 97.448%
# Batch: 300/391 | Loss: 0.076 | Acc: 97.397%
# Batch: 350/391 | Loss: 0.077 | Acc: 97.382%
# Time taken : 18s3ms
# Batch: 0/100 | Loss: 0.227 | Acc: 91.000%
# Batch: 50/100 | Loss: 0.272 | Acc: 92.059%
# Saving..
#
# Epoch: 76
# Batch: 0/391 | Loss: 0.060 | Acc: 98.438%
# Batch: 50/391 | Loss: 0.062 | Acc: 97.947%
# Batch: 100/391 | Loss: 0.062 | Acc: 98.004%
# Batch: 150/391 | Loss: 0.063 | Acc: 97.899%
# Batch: 200/391 | Loss: 0.064 | Acc: 97.851%
# Batch: 250/391 | Loss: 0.063 | Acc: 97.855%
# Batch: 300/391 | Loss: 0.063 | Acc: 97.885%
# Batch: 350/391 | Loss: 0.066 | Acc: 97.794%
# Time taken : 18s183ms
# Batch: 0/100 | Loss: 0.232 | Acc: 92.000%
# Batch: 50/100 | Loss: 0.267 | Acc: 91.843%
#
# Epoch: 77
# Batch: 0/391 | Loss: 0.035 | Acc: 99.219%
# Batch: 50/391 | Loss: 0.059 | Acc: 97.978%
# Batch: 100/391 | Loss: 0.055 | Acc: 98.175%
# Batch: 150/391 | Loss: 0.055 | Acc: 98.246%
# Batch: 200/391 | Loss: 0.056 | Acc: 98.235%
# Batch: 250/391 | Loss: 0.058 | Acc: 98.117%
# Batch: 300/391 | Loss: 0.059 | Acc: 98.095%
# Batch: 350/391 | Loss: 0.059 | Acc: 98.072%
# Time taken : 18s197ms
# Batch: 0/100 | Loss: 0.284 | Acc: 90.000%
# Batch: 50/100 | Loss: 0.257 | Acc: 92.137%
# Saving..
#
# Epoch: 78
# Batch: 0/391 | Loss: 0.080 | Acc: 97.656%
# Batch: 50/391 | Loss: 0.049 | Acc: 98.606%
# Batch: 100/391 | Loss: 0.048 | Acc: 98.631%
# Batch: 150/391 | Loss: 0.049 | Acc: 98.562%
# Batch: 200/391 | Loss: 0.050 | Acc: 98.476%
# Batch: 250/391 | Loss: 0.051 | Acc: 98.438%
# Batch: 300/391 | Loss: 0.052 | Acc: 98.375%
# Batch: 350/391 | Loss: 0.052 | Acc: 98.355%
# Time taken : 18s410ms
# Batch: 0/100 | Loss: 0.142 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.274 | Acc: 91.784%
#
# Epoch: 79
# Batch: 0/391 | Loss: 0.038 | Acc: 98.438%
# Batch: 50/391 | Loss: 0.041 | Acc: 98.882%
# Batch: 100/391 | Loss: 0.041 | Acc: 98.847%
# Batch: 150/391 | Loss: 0.040 | Acc: 98.882%
# Batch: 200/391 | Loss: 0.042 | Acc: 98.741%
# Batch: 250/391 | Loss: 0.044 | Acc: 98.683%
# Batch: 300/391 | Loss: 0.045 | Acc: 98.648%
# Batch: 350/391 | Loss: 0.045 | Acc: 98.618%
# Time taken : 18s127ms
# Batch: 0/100 | Loss: 0.125 | Acc: 97.000%
# Batch: 50/100 | Loss: 0.262 | Acc: 92.314%
#
# Epoch: 80
# Batch: 0/391 | Loss: 0.032 | Acc: 99.219%
# Batch: 50/391 | Loss: 0.040 | Acc: 98.805%
# Batch: 100/391 | Loss: 0.041 | Acc: 98.786%
# Batch: 150/391 | Loss: 0.040 | Acc: 98.800%
# Batch: 200/391 | Loss: 0.040 | Acc: 98.842%
# Batch: 250/391 | Loss: 0.040 | Acc: 98.845%
# Batch: 300/391 | Loss: 0.040 | Acc: 98.837%
# Batch: 350/391 | Loss: 0.039 | Acc: 98.851%
# Time taken : 18s547ms
# Batch: 0/100 | Loss: 0.134 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.239 | Acc: 92.882%
# Saving..
#
# Epoch: 81
# Batch: 0/391 | Loss: 0.028 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.036 | Acc: 98.989%
# Batch: 100/391 | Loss: 0.035 | Acc: 99.010%
# Batch: 150/391 | Loss: 0.036 | Acc: 98.934%
# Batch: 200/391 | Loss: 0.035 | Acc: 99.009%
# Batch: 250/391 | Loss: 0.035 | Acc: 99.004%
# Batch: 300/391 | Loss: 0.034 | Acc: 99.009%
# Batch: 350/391 | Loss: 0.033 | Acc: 99.054%
# Time taken : 18s489ms
# Batch: 0/100 | Loss: 0.155 | Acc: 93.000%
# Batch: 50/100 | Loss: 0.232 | Acc: 93.314%
# Saving..
#
# Epoch: 82
# Batch: 0/391 | Loss: 0.017 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.028 | Acc: 99.173%
# Batch: 100/391 | Loss: 0.029 | Acc: 99.172%
# Batch: 150/391 | Loss: 0.029 | Acc: 99.193%
# Batch: 200/391 | Loss: 0.028 | Acc: 99.227%
# Batch: 250/391 | Loss: 0.029 | Acc: 99.209%
# Batch: 300/391 | Loss: 0.029 | Acc: 99.190%
# Batch: 350/391 | Loss: 0.030 | Acc: 99.183%
# Time taken : 18s103ms
# Batch: 0/100 | Loss: 0.261 | Acc: 92.000%
# Batch: 50/100 | Loss: 0.242 | Acc: 93.137%
#
# Epoch: 83
# Batch: 0/391 | Loss: 0.029 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.024 | Acc: 99.510%
# Batch: 100/391 | Loss: 0.024 | Acc: 99.474%
# Batch: 150/391 | Loss: 0.023 | Acc: 99.483%
# Batch: 200/391 | Loss: 0.024 | Acc: 99.444%
# Batch: 250/391 | Loss: 0.024 | Acc: 99.437%
# Batch: 300/391 | Loss: 0.024 | Acc: 99.416%
# Batch: 350/391 | Loss: 0.024 | Acc: 99.412%
# Time taken : 18s555ms
# Batch: 0/100 | Loss: 0.173 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.225 | Acc: 93.412%
# Saving..
#
# Epoch: 84
# Batch: 0/391 | Loss: 0.019 | Acc: 99.219%
# Batch: 50/391 | Loss: 0.022 | Acc: 99.540%
# Batch: 100/391 | Loss: 0.022 | Acc: 99.505%
# Batch: 150/391 | Loss: 0.022 | Acc: 99.467%
# Batch: 200/391 | Loss: 0.023 | Acc: 99.425%
# Batch: 250/391 | Loss: 0.023 | Acc: 99.406%
# Batch: 300/391 | Loss: 0.023 | Acc: 99.419%
# Batch: 350/391 | Loss: 0.022 | Acc: 99.421%
# Time taken : 18s439ms
# Batch: 0/100 | Loss: 0.237 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.236 | Acc: 93.686%
# Saving..
#
# Epoch: 85
# Batch: 0/391 | Loss: 0.022 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.020 | Acc: 99.510%
# Batch: 100/391 | Loss: 0.019 | Acc: 99.528%
# Batch: 150/391 | Loss: 0.020 | Acc: 99.477%
# Batch: 200/391 | Loss: 0.019 | Acc: 99.518%
# Batch: 250/391 | Loss: 0.019 | Acc: 99.533%
# Batch: 300/391 | Loss: 0.019 | Acc: 99.533%
# Batch: 350/391 | Loss: 0.020 | Acc: 99.515%
# Time taken : 18s239ms
# Batch: 0/100 | Loss: 0.195 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.217 | Acc: 94.020%
# Saving..
#
# Epoch: 86
# Batch: 0/391 | Loss: 0.013 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.014 | Acc: 99.801%
# Batch: 100/391 | Loss: 0.014 | Acc: 99.714%
# Batch: 150/391 | Loss: 0.015 | Acc: 99.695%
# Batch: 200/391 | Loss: 0.015 | Acc: 99.693%
# Batch: 250/391 | Loss: 0.015 | Acc: 99.686%
# Batch: 300/391 | Loss: 0.015 | Acc: 99.689%
# Batch: 350/391 | Loss: 0.015 | Acc: 99.682%
# Time taken : 18s204ms
# Batch: 0/100 | Loss: 0.163 | Acc: 96.000%
# Batch: 50/100 | Loss: 0.218 | Acc: 94.235%
# Saving..
#
# Epoch: 87
# Batch: 0/391 | Loss: 0.010 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.013 | Acc: 99.801%
# Batch: 100/391 | Loss: 0.013 | Acc: 99.776%
# Batch: 150/391 | Loss: 0.013 | Acc: 99.772%
# Batch: 200/391 | Loss: 0.013 | Acc: 99.755%
# Batch: 250/391 | Loss: 0.013 | Acc: 99.751%
# Batch: 300/391 | Loss: 0.013 | Acc: 99.746%
# Batch: 350/391 | Loss: 0.014 | Acc: 99.742%
# Time taken : 18s316ms
# Batch: 0/100 | Loss: 0.180 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.217 | Acc: 93.980%
#
# Epoch: 88
# Batch: 0/391 | Loss: 0.017 | Acc: 99.219%
# Batch: 50/391 | Loss: 0.012 | Acc: 99.770%
# Batch: 100/391 | Loss: 0.013 | Acc: 99.752%
# Batch: 150/391 | Loss: 0.013 | Acc: 99.741%
# Batch: 200/391 | Loss: 0.012 | Acc: 99.771%
# Batch: 250/391 | Loss: 0.012 | Acc: 99.773%
# Batch: 300/391 | Loss: 0.012 | Acc: 99.785%
# Batch: 350/391 | Loss: 0.012 | Acc: 99.771%
# Time taken : 17s936ms
# Batch: 0/100 | Loss: 0.176 | Acc: 94.000%
# Batch: 50/100 | Loss: 0.208 | Acc: 94.196%
# Saving..
#
# Epoch: 89
# Batch: 0/391 | Loss: 0.006 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.010 | Acc: 99.816%
# Batch: 100/391 | Loss: 0.010 | Acc: 99.838%
# Batch: 150/391 | Loss: 0.011 | Acc: 99.850%
# Batch: 200/391 | Loss: 0.011 | Acc: 99.817%
# Batch: 250/391 | Loss: 0.011 | Acc: 99.819%
# Batch: 300/391 | Loss: 0.011 | Acc: 99.813%
# Batch: 350/391 | Loss: 0.011 | Acc: 99.811%
# Time taken : 18s535ms
# Batch: 0/100 | Loss: 0.167 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.215 | Acc: 94.098%
#
# Epoch: 90
# Batch: 0/391 | Loss: 0.007 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.009 | Acc: 99.908%
# Batch: 100/391 | Loss: 0.009 | Acc: 99.892%
# Batch: 150/391 | Loss: 0.010 | Acc: 99.871%
# Batch: 200/391 | Loss: 0.010 | Acc: 99.860%
# Batch: 250/391 | Loss: 0.010 | Acc: 99.851%
# Batch: 300/391 | Loss: 0.010 | Acc: 99.836%
# Batch: 350/391 | Loss: 0.010 | Acc: 99.829%
# Time taken : 18s259ms
# Batch: 0/100 | Loss: 0.191 | Acc: 96.000%
# Batch: 50/100 | Loss: 0.217 | Acc: 94.137%
#
# Epoch: 91
# Batch: 0/391 | Loss: 0.010 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.009 | Acc: 99.893%
# Batch: 100/391 | Loss: 0.009 | Acc: 99.861%
# Batch: 150/391 | Loss: 0.009 | Acc: 99.850%
# Batch: 200/391 | Loss: 0.009 | Acc: 99.852%
# Batch: 250/391 | Loss: 0.009 | Acc: 99.857%
# Batch: 300/391 | Loss: 0.009 | Acc: 99.865%
# Batch: 350/391 | Loss: 0.009 | Acc: 99.860%
# Time taken : 18s733ms
# Batch: 0/100 | Loss: 0.157 | Acc: 96.000%
# Batch: 50/100 | Loss: 0.205 | Acc: 94.333%
# Saving..
#
# Epoch: 92
# Batch: 0/391 | Loss: 0.005 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.009 | Acc: 99.877%
# Batch: 100/391 | Loss: 0.008 | Acc: 99.899%
# Batch: 150/391 | Loss: 0.008 | Acc: 99.907%
# Batch: 200/391 | Loss: 0.008 | Acc: 99.903%
# Batch: 250/391 | Loss: 0.008 | Acc: 99.907%
# Batch: 300/391 | Loss: 0.008 | Acc: 99.901%
# Batch: 350/391 | Loss: 0.008 | Acc: 99.900%
# Time taken : 18s624ms
# Batch: 0/100 | Loss: 0.153 | Acc: 95.000%
# Batch: 50/100 | Loss: 0.209 | Acc: 94.392%
# Saving..
#
# Epoch: 93
# Batch: 0/391 | Loss: 0.007 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.008 | Acc: 99.908%
# Batch: 100/391 | Loss: 0.008 | Acc: 99.923%
# Batch: 150/391 | Loss: 0.008 | Acc: 99.912%
# Batch: 200/391 | Loss: 0.008 | Acc: 99.922%
# Batch: 250/391 | Loss: 0.008 | Acc: 99.919%
# Batch: 300/391 | Loss: 0.008 | Acc: 99.914%
# Batch: 350/391 | Loss: 0.008 | Acc: 99.920%
# Time taken : 18s329ms
# Batch: 0/100 | Loss: 0.146 | Acc: 96.000%
# Batch: 50/100 | Loss: 0.205 | Acc: 94.627%
# Saving..
#
# Epoch: 94
# Batch: 0/391 | Loss: 0.007 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.008 | Acc: 99.908%
# Batch: 100/391 | Loss: 0.008 | Acc: 99.923%
# Batch: 150/391 | Loss: 0.008 | Acc: 99.912%
# Batch: 200/391 | Loss: 0.008 | Acc: 99.903%
# Batch: 250/391 | Loss: 0.008 | Acc: 99.904%
# Batch: 300/391 | Loss: 0.008 | Acc: 99.907%
# Batch: 350/391 | Loss: 0.008 | Acc: 99.909%
# Time taken : 18s325ms
# Batch: 0/100 | Loss: 0.133 | Acc: 97.000%
# Batch: 50/100 | Loss: 0.206 | Acc: 94.529%
#
# Epoch: 95
# Batch: 0/391 | Loss: 0.010 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.009 | Acc: 99.847%
# Batch: 100/391 | Loss: 0.008 | Acc: 99.869%
# Batch: 150/391 | Loss: 0.008 | Acc: 99.897%
# Batch: 200/391 | Loss: 0.008 | Acc: 99.899%
# Batch: 250/391 | Loss: 0.008 | Acc: 99.910%
# Batch: 300/391 | Loss: 0.007 | Acc: 99.917%
# Batch: 350/391 | Loss: 0.007 | Acc: 99.918%
# Time taken : 18s502ms
# Batch: 0/100 | Loss: 0.128 | Acc: 97.000%
# Batch: 50/100 | Loss: 0.203 | Acc: 94.627%
# Saving..
#
# Epoch: 96
# Batch: 0/391 | Loss: 0.007 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.007 | Acc: 99.954%
# Batch: 100/391 | Loss: 0.007 | Acc: 99.946%
# Batch: 150/391 | Loss: 0.007 | Acc: 99.928%
# Batch: 200/391 | Loss: 0.007 | Acc: 99.922%
# Batch: 250/391 | Loss: 0.007 | Acc: 99.928%
# Batch: 300/391 | Loss: 0.007 | Acc: 99.927%
# Batch: 350/391 | Loss: 0.007 | Acc: 99.935%
# Time taken : 18s611ms
# Batch: 0/100 | Loss: 0.134 | Acc: 97.000%
# Batch: 50/100 | Loss: 0.205 | Acc: 94.431%
#
# Epoch: 97
# Batch: 0/391 | Loss: 0.005 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.007 | Acc: 99.893%
# Batch: 100/391 | Loss: 0.007 | Acc: 99.938%
# Batch: 150/391 | Loss: 0.007 | Acc: 99.907%
# Batch: 200/391 | Loss: 0.007 | Acc: 99.903%
# Batch: 250/391 | Loss: 0.007 | Acc: 99.913%
# Batch: 300/391 | Loss: 0.007 | Acc: 99.927%
# Batch: 350/391 | Loss: 0.007 | Acc: 99.920%
# Time taken : 18s503ms
# Batch: 0/100 | Loss: 0.138 | Acc: 97.000%
# Batch: 50/100 | Loss: 0.203 | Acc: 94.490%
#
# Epoch: 98
# Batch: 0/391 | Loss: 0.011 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.007 | Acc: 99.908%
# Batch: 100/391 | Loss: 0.006 | Acc: 99.954%
# Batch: 150/391 | Loss: 0.007 | Acc: 99.943%
# Batch: 200/391 | Loss: 0.007 | Acc: 99.930%
# Batch: 250/391 | Loss: 0.007 | Acc: 99.928%
# Batch: 300/391 | Loss: 0.007 | Acc: 99.933%
# Batch: 350/391 | Loss: 0.007 | Acc: 99.933%
# Time taken : 18s333ms
# Batch: 0/100 | Loss: 0.142 | Acc: 97.000%
# Batch: 50/100 | Loss: 0.205 | Acc: 94.569%
#
# Epoch: 99
# Batch: 0/391 | Loss: 0.004 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.007 | Acc: 99.923%
# Batch: 100/391 | Loss: 0.007 | Acc: 99.930%
# Batch: 150/391 | Loss: 0.007 | Acc: 99.938%
# Batch: 200/391 | Loss: 0.007 | Acc: 99.946%
# Batch: 250/391 | Loss: 0.007 | Acc: 99.941%
# Batch: 300/391 | Loss: 0.007 | Acc: 99.940%
# Batch: 350/391 | Loss: 0.007 | Acc: 99.947%
# Time taken : 18s341ms
# Batch: 0/100 | Loss: 0.138 | Acc: 97.000%
# Batch: 50/100 | Loss: 0.205 | Acc: 94.353%
#
# Epoch: 100
# Batch: 0/391 | Loss: 0.008 | Acc: 100.000%
# Batch: 50/391 | Loss: 0.007 | Acc: 99.877%
# Batch: 100/391 | Loss: 0.007 | Acc: 99.899%
# Batch: 150/391 | Loss: 0.008 | Acc: 99.897%
# Batch: 200/391 | Loss: 0.007 | Acc: 99.914%
# Batch: 250/391 | Loss: 0.007 | Acc: 99.916%
# Batch: 300/391 | Loss: 0.007 | Acc: 99.927%
# Batch: 350/391 | Loss: 0.007 | Acc: 99.933%
# Time taken : 18s387ms
# Batch: 0/100 | Loss: 0.133 | Acc: 97.000%
# Batch: 50/100 | Loss: 0.204 | Acc: 94.392%

# %%
def plot_accuracies(train_accuracies, test_accuracies):
  plt.plot(train_accuracies, label='Train Accuracy')
  plt.plot(test_accuracies, label='Test Accuracy')
  plt.xlabel('Epochs')
  plt.ylabel('Accuracy')
  plt.legend()
  plt.grid(True)
  plt.title('Accuracy vs. No. of epochs')

# %%
def plot_losses(train_losses, test_losses):
  plt.plot(train_losses, label='Train Losses')
  plt.plot(test_losses, label='Test Losses')
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.legend()
  plt.grid(True)
  plt.title('Loss vs. No. of epochs')

# %%
def plot_lrs(train_lrs):
  plt.plot(train_lrs)
  plt.xlabel('Epochs')
  plt.ylabel('Learning rate')
  plt.grid(True)
  plt.title('Learning Rate vs. Epochs')

# %%
plot_accuracies(train_accuracies, test_accuracies)

# %%
plot_losses(train_losses, test_losses)

# %%
plot_lrs(train_lrs)

# %%
print('Saving final model..')
state = {
    'net': model.state_dict(),
    'acc': test_accuracies[-1],
    'epoch': number_of_epochs,
}
if not os.path.isdir('checkpoint'):
  os.mkdir('checkpoint')
torch.save(state, './checkpoint/model_final.pth')
# Out:
# Saving final model..

# %%
import numpy as np
import pickle
from tqdm import tqdm
import pandas as pd

# Function to load CIFAR batch
def load_cifar_batch(file):
    with open(file, 'rb') as fo:
        batch = pickle.load(fo, encoding='bytes')
    return batch

# Specify the folder where the CIFAR-10 batch files are
cifar10_dir = '/kaggle/working/data/cifar-10-batches-py'

# Load the label names
meta_data_dict = load_cifar_batch(os.path.join(cifar10_dir, 'batches.meta'))
label_names = meta_data_dict[b'label_names']

# Load test data
test_batch = load_cifar_batch('/kaggle/input/dl-miniproject-test/cifar_test_nolabels.pkl')
test_images = test_batch[b'data'].reshape(-1, 3, 32, 32).transpose(0, 2, 3, 1)

data_statistics = (
    (0.49139968, 0.48215827, 0.44653124),
     (0.24703233, 0.24348505, 0.26158768)
)

# Define transformation for data augmentation
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(*data_statistics, inplace=True)
])

# Apply data augmentation
augmented_test_images = torch.stack([transform(image) for image in test_images])

# Load the trained model
model = ResNet9()

checkpoint = torch.load('/kaggle/working/checkpoint/model_final.pth')

# Check the keys in the checkpoint dictionary
print(checkpoint.keys())

# Assuming the model state dictionary is saved under a different key
# Adjust this according to the actual key in your checkpoint file
model.load_state_dict(checkpoint['net'])

# model =  model.to(device)

# Evaluate the model on test data
model.eval()
with torch.no_grad():
    outputs = model(augmented_test_images)
_, predicted = torch.max(outputs, 1)

# Display the first 10 test images and predicted labels
plt.figure(figsize=(20, 4))
for i in range(10):
    plt.subplot(1, 10, i+1)
    plt.imshow(test_images[i])
    plt.title(label_names[predicted[i].item()].decode('utf-8'))
    plt.axis('off')
plt.show()

# Save the output in output.csv containing ID, Labels
output_data = {'ID': np.arange(len(predicted)), 'Labels': predicted.numpy()}
output_df = pd.DataFrame(output_data)
output_df.to_csv('output_rugved_resnet9.csv', index=False)
# Out:
# dict_keys(['net', 'acc', 'epoch'])

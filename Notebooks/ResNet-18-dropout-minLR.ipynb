# %% [markdown]
# # ResNet-18 on CIFAR-10 Dataset

# %% [markdown]
# Importing PyTorch and a few Python Libraries

# %%
import os
import sys
import time
import math

import torch
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import random_split, DataLoader
from torchvision.utils import make_grid

import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
import torch.nn.init as init

from torchsummary import summary

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Preparing the dataset
#
# We will be downloading the train and test CIFAR-10 dataset from torchvision. We will normalize and transform the dataset. For the training dataset, we will also be adding Random Crops and Random Horizontal Flips to generalize the model better.

# %%
data_statistics = (
    (0.49139968, 0.48215827, 0.44653124),
     (0.24703233, 0.24348505, 0.26158768)
) # Mean, Standard Deviation of CIFAR-10 dataset channels

train_transforms = transforms.Compose([
    transforms.RandomCrop(32, padding=4, padding_mode='reflect'), # Adding Random Crops
    transforms.RandomHorizontalFlip(), # Adding Random Horizontal Flips
    transforms.ToTensor(), # Channel x Image Height x Image Width
    transforms.Normalize(*data_statistics, inplace=True) # Output in the range of [-1, 1]
])

test_transforms = transforms.Compose([
    transforms.ToTensor(), # Channel x Image Height x Image Width
    transforms.Normalize(*data_statistics, inplace=True) # Output in the range of [-1, 1]
])

# %%
train_dataset = torchvision.datasets.CIFAR10(root='./data/', download=True, train=True, transform=train_transforms)
test_dataset = torchvision.datasets.CIFAR10(root='./data/', download=True, train=False, transform=test_transforms)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# <!-- We will also be splitting the dataset further into training and validation dataset with a validation ratio of `0.2` -->
#
# We will now create data loaders to retreive images in batches. We are selecting the batch size as `128` images for our train loader. And we are selecting the batch size as `100` images for our test loader.
#
# *From PyTorch Documentation: For data loading, passing pin_memory=True to a DataLoader will automatically put the fetched data Tensors in pinned memory, and thus enables faster data transfer to CUDA-enabled GPUs.*

# %%
# validation_ratio = 0.2
# train_dataset, validation_dataset = random_split(
#     dataset,
#     [int((1 - validation_ratio) * len(dataset)), int(validation_ratio * len(dataset))]
# )

train_batch_size = 128
test_batch_size = 100

train_dl = DataLoader(train_dataset, train_batch_size, shuffle=True, num_workers=2, pin_memory=True)
# validation_dl = DataLoader(validation_dataset, batch_size, shuffle=True, num_workers=3, pin_memory=True)
test_dl = DataLoader(test_dataset, test_batch_size, shuffle=False, num_workers=2, pin_memory=True)

classes = ('plane', 'car', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck')

# %% [markdown]
# We create the following function to display a batch of images from the dataset. And we also need to denormalize the pixels values to bring them back into the range (0,1).

# %%
def denormalize(images, means, stds):
  means = torch.tensor(means).reshape(1, 3, 1, 1)
  stds = torch.tensor(stds).reshape(1, 3, 1, 1)
  return images * stds + means

def show_batch(dl):
  for images, labels in dl:
    fig, ax = plt.subplots(figsize=(12, 12))
    ax.set_xticks([])
    ax.set_yticks([])
    denorm_images = denormalize(images, *data_statistics)
    ax.imshow(make_grid(denorm_images[:64], 8).permute(1, 2, 0))
    break

# %%
show_batch(train_dl)

# %% [markdown]
# To seamlessly use a GPU, if one is available, we define a couple of helper functions (`get_default_device` & `to_device`) and a helper class `DeviceDataLoader` to move our model & data to the GPU as required.

# %%
def get_default_device():
  # Pick GPU, if available, else CPU
  if torch.cuda.is_available():
    return torch.device('cuda')
  else:
    return torch.device('cpu')

def to_device(data, device):
  # Move tensors to chosen device
  if isinstance(data, (list, tuple)):
    # If the instance is a list/tuple, transfer each element to chosen device
    return [to_device(x, device) for x in data]
  return data.to(device, non_blocking=True)
  # non_blocking=True doesn't block the execution of the host device until transfers complete

class DeviceDataLoader():
  # Wrap a dataloader to move data to a device
  def __init__(self, dl, device):
    self.dl = dl
    self.device = device

  def __iter__(self):
    # Yield a batch of data after moving it to device
    for b in self.dl:
      yield to_device(b, self.device)

  def __len__(self):
    # Number of batches
    return len(self.dl)

# %%
# Get the default device
device = get_default_device()
device
# Out:
# device(type='cuda')

# %%
train_dl = DeviceDataLoader(train_dl, device)
# validation_dl = DeviceDataLoader(validation_dl, device)
test_dl = DeviceDataLoader(test_dl, device)

# %% [markdown]
# ## Network Architecture

# %% [markdown]
# Testing the models mentioned in the `pytorch-cifar` [GitHub Repository](https://github.com/kuangliu/pytorch-cifar).

# %% [markdown]
# ### ResNet18

# %%
class BasicBlock(nn.Module):
  expansion = 1

  def __init__(self, in_planes, planes, stride=1):
    super(BasicBlock, self).__init__()
    self.conv1 = nn.Conv2d(
        in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
    self.bn1 = nn.BatchNorm2d(planes)
    self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                            stride=1, padding=1, bias=False)
    self.bn2 = nn.BatchNorm2d(planes)
    self.bn2 = nn.Dropout(p = 0.2)

    self.shortcut = nn.Sequential()
    if stride != 1 or in_planes != self.expansion*planes:
      self.shortcut = nn.Sequential(
          nn.Conv2d(in_planes, self.expansion*planes,
                    kernel_size=1, stride=stride, bias=False),
          nn.BatchNorm2d(self.expansion*planes)
      )

  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))
    out = self.bn2(self.conv2(out))
    out += self.shortcut(x)
    out = F.relu(out)
    return out

class ResNet(nn.Module):
  def __init__(self, block, num_blocks, num_classes=10):
    super(ResNet, self).__init__()
    self.in_planes = 64

    self.conv1 = nn.Conv2d(3, 64, kernel_size=3,
                            stride=1, padding=1, bias=False)
    self.bn1 = nn.BatchNorm2d(64)
    self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
    self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
    self.layer3 = self._make_layer(block, 192, num_blocks[2], stride=2)
    self.layer4 = self._make_layer(block, 256, num_blocks[3], stride=2)
    self.linear = nn.Linear(256*block.expansion, num_classes)

  def _make_layer(self, block, planes, num_blocks, stride):
    strides = [stride] + [1]*(num_blocks-1)
    layers = []
    for stride in strides:
      layers.append(block(self.in_planes, planes, stride))
      self.in_planes = planes * block.expansion
    return nn.Sequential(*layers)

  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))
    out = self.layer1(out)
    out = self.layer2(out)
    out = self.layer3(out)
    out = self.layer4(out)
    out = F.avg_pool2d(out, 4)
    out = out.view(out.size(0), -1)
    out = self.linear(out)
    return out

def ResNet18():
  return ResNet(BasicBlock, [2, 3, 2, 2])

# %%
model = ResNet18()

# %%
model =  model.to(device)
if device == 'cuda':
  model = torch.nn.DataParallel(model)
  cudnn.benchmark = True

# %%
summary(model, input_size=(3, 32, 32))
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            1,728
# ├─BatchNorm2d: 1-2                       128
# ├─Sequential: 1-3                        --
# |    └─BasicBlock: 2-1                   --
# |    |    └─Conv2d: 3-1                  36,864
# |    |    └─BatchNorm2d: 3-2             128
# |    |    └─Conv2d: 3-3                  36,864
# |    |    └─Dropout: 3-4                 --
# |    |    └─Sequential: 3-5              --
# |    └─BasicBlock: 2-2                   --
# |    |    └─Conv2d: 3-6                  36,864
# |    |    └─BatchNorm2d: 3-7             128
# |    |    └─Conv2d: 3-8                  36,864
# |    |    └─Dropout: 3-9                 --
# |    |    └─Sequential: 3-10             --
# ├─Sequential: 1-4                        --
# |    └─BasicBlock: 2-3                   --
# |    |    └─Conv2d: 3-11                 73,728
# |    |    └─BatchNorm2d: 3-12            256
# |    |    └─Conv2d: 3-13                 147,456
# |    |    └─Dropout: 3-14                --
# |    |    └─Sequential: 3-15             8,448
# |    └─BasicBlock: 2-4                   --
# |    |    └─Conv2d: 3-16                 147,456
# |    |    └─BatchNorm2d: 3-17            256
# |    |    └─Conv2d: 3-18                 147,456
# |    |    └─Dropout: 3-19                --
# |    |    └─Sequential: 3-20             --
# |    └─BasicBlock: 2-5                   --
# |    |    └─Conv2d: 3-21                 147,456
# |    |    └─BatchNorm2d: 3-22            256
# |    |    └─Conv2d: 3-23                 147,456
# |    |    └─Dropout: 3-24                --
# |    |    └─Sequential: 3-25             --
# ├─Sequential: 1-5                        --
# |    └─BasicBlock: 2-6                   --
# |    |    └─Conv2d: 3-26                 221,184
# |    |    └─BatchNorm2d: 3-27            384
# |    |    └─Conv2d: 3-28                 331,776
# |    |    └─Dropout: 3-29                --
# |    |    └─Sequential: 3-30             24,960
# |    └─BasicBlock: 2-7                   --
# |    |    └─Conv2d: 3-31                 331,776
# |    |    └─BatchNorm2d: 3-32            384
# |    |    └─Conv2d: 3-33                 331,776
# |    |    └─Dropout: 3-34                --
# |    |    └─Sequential: 3-35             --
# ├─Sequential: 1-6                        --
# |    └─BasicBlock: 2-8                   --
# |    |    └─Conv2d: 3-36                 442,368
# |    |    └─BatchNorm2d: 3-37            512
# |    |    └─Conv2d: 3-38                 589,824
# |    |    └─Dropout: 3-39                --
# |    |    └─Sequential: 3-40             49,664
# |    └─BasicBlock: 2-9                   --
# |    |    └─Conv2d: 3-41                 589,824
# |    |    └─BatchNorm2d: 3-42            512
# |    |    └─Conv2d: 3-43                 589,824
# |    |    └─Dropout: 3-44                --
# |    |    └─Sequential: 3-45             --
# ├─Linear: 1-7                            2,570
# =================================================================
# Total params: 4,477,130
# Trainable params: 4,477,130
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            1,728
# ├─BatchNorm2d: 1-2                       128
# ├─Sequential: 1-3                        --
# |    └─BasicBlock: 2-1                   --
# |    |    └─Conv2d: 3-1                  36,864
# |    |    └─BatchNorm2d: 3-2             128
# |    |    └─Conv2d: 3-3                  36,864
# |    |    └─Dropout: 3-4                 --
# |    |    └─Sequential: 3-5              --
# |    └─BasicBlock: 2-2                   --
# |    |    └─Conv2d: 3-6                  36,864
# |    |    └─BatchNorm2d: 3-7             128
# |    |    └─Conv2d: 3-8                  36,864
# |    |    └─Dropout: 3-9                 --
# |    |    └─Sequential: 3-10             --
# ├─Sequential: 1-4                        --
# |    └─BasicBlock: 2-3                   --
# |    |    └─Conv2d: 3-11                 73,728
# |    |    └─BatchNorm2d: 3-12            256
# |    |    └─Conv2d: 3-13                 147,456
# |    |    └─Dropout: 3-14                --
# |    |    └─Sequential: 3-15             8,448
# |    └─BasicBlock: 2-4                   --
# |    |    └─Conv2d: 3-16                 147,456
# |    |    └─BatchNorm2d: 3-17            256
# |    |    └─Conv2d: 3-18                 147,456
# |    |    └─Dropout: 3-19                --
# |    |    └─Sequential: 3-20             --
# |    └─BasicBlock: 2-5                   --
# |    |    └─Conv2d: 3-21                 147,456
# |    |    └─BatchNorm2d: 3-22            256
# |    |    └─Conv2d: 3-23                 147,456
# |    |    └─Dropout: 3-24                --
# |    |    └─Sequential: 3-25             --
# ├─Sequential: 1-5                        --
# |    └─BasicBlock: 2-6                   --
# |    |    └─Conv2d: 3-26                 221,184
# |    |    └─BatchNorm2d: 3-27            384
# |    |    └─Conv2d: 3-28                 331,776
# |    |    └─Dropout: 3-29                --
# |    |    └─Sequential: 3-30             24,960
# |    └─BasicBlock: 2-7                   --
# |    |    └─Conv2d: 3-31                 331,776
# |    |    └─BatchNorm2d: 3-32            384
# |    |    └─Conv2d: 3-33                 331,776
# |    |    └─Dropout: 3-34                --
# |    |    └─Sequential: 3-35             --
# ├─Sequential: 1-6                        --
# |    └─BasicBlock: 2-8                   --
# |    |    └─Conv2d: 3-36                 442,368
# |    |    └─BatchNorm2d: 3-37            512
# |    |    └─Conv2d: 3-38                 589,824
# |    |    └─Dropout: 3-39                --
# |    |    └─Sequential: 3-40             49,664
# |    └─BasicBlock: 2-9                   --
# |    |    └─Conv2d: 3-41                 589,824
# |    |    └─BatchNorm2d: 3-42            512
# |    |    └─Conv2d: 3-43                 589,824
# |    |    └─Dropout: 3-44                --
# |    |    └─Sequential: 3-45             --
# ├─Linear: 1-7                            2,570
# =================================================================
# Total params: 4,477,130
# Trainable params: 4,477,130
# Non-trainable params: 0
# =================================================================

# %% [markdown]
# ## Model Training

# %%
def format_time(seconds):
  days = int(seconds / 3600/24)
  seconds = seconds - days*3600*24
  hours = int(seconds / 3600)
  seconds = seconds - hours*3600
  minutes = int(seconds / 60)
  seconds = seconds - minutes*60
  secondsf = int(seconds)
  seconds = seconds - secondsf
  millis = int(seconds*1000)

  f = ''
  i = 1
  if days > 0:
    f += str(days) + 'D'
    i += 1
  if hours > 0 and i <= 2:
    f += str(hours) + 'h'
    i += 1
  if minutes > 0 and i <= 2:
    f += str(minutes) + 'm'
    i += 1
  if secondsf > 0 and i <= 2:
    f += str(secondsf) + 's'
    i += 1
  if millis > 0 and i <= 2:
    f += str(millis) + 'ms'
    i += 1
  if f == '':
    f = '0ms'
  return f

# %%
lr = 0.1
momentum = 0.9
weight_decay = 5e-4

start_epoch = 1
number_of_epochs = 100
best_acc = 0


criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=lr,
                      momentum=momentum, weight_decay=weight_decay)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=number_of_epochs, eta_min = 0.003)

# %%
def get_lr(optimizer):
  for param_group in optimizer.param_groups:
    return param_group['lr']

# %%
def train(epoch):
  print('\nEpoch: %d' % epoch)
  start_time = time.time()

  model.train()
  train_loss = 0
  correct = 0
  total = 0
  for batch_idx, (inputs, targets) in enumerate(train_dl):
    # inputs, targets = inputs.to(device), targets.to(device)
    optimizer.zero_grad()
    outputs = model(inputs)
    loss = criterion(outputs, targets)
    loss.backward()
    optimizer.step()

    train_loss += loss.item()
    _, predicted = outputs.max(1)
    total += targets.size(0)
    correct += predicted.eq(targets).sum().item()

  cur_time = time.time()
  epoch_time = cur_time - start_time
  print(f"Time taken : {format_time(epoch_time)}")

  return train_loss/(batch_idx+1), 100.*correct/total, get_lr(optimizer)

# %%
def test(epoch):
  global best_acc
  model.eval()
  test_loss = 0
  correct = 0
  total = 0
  with torch.no_grad():
    for batch_idx, (inputs, targets) in enumerate(test_dl):
      # inputs, targets = inputs.to(device), targets.to(device)
      outputs = model(inputs)
      loss = criterion(outputs, targets)

      test_loss += loss.item()
      _, predicted = outputs.max(1)
      total += targets.size(0)
      correct += predicted.eq(targets).sum().item()
      
      # if batch_idx % 50 == 0:
      #   print(f"Batch: {batch_idx}/{len(test_dl)} | Loss: {(test_loss/(batch_idx+1)):.3f} | Acc: {(100.*correct/total):.3f}%")

  # Save checkpoint.
  acc = 100.*correct/total
  
  if acc > best_acc:
    print('Saving..')
    state = {
        'net': model.state_dict(),
        'acc': acc,
        'epoch': epoch,
    }
    if not os.path.isdir('checkpoint'):
      os.mkdir('checkpoint')
    torch.save(state, './checkpoint/ResNet_18_dropout_minLR_best.pth')
    best_acc = acc

  return test_loss/(batch_idx+1), 100.*correct/total

# %%
train_losses = []
train_accuracies = []
train_lrs = []

test_losses = []
test_accuracies = []

for epoch in range(start_epoch, start_epoch + number_of_epochs):
  epoch_train_loss, epoch_train_accuracy, epoch_lr = train(epoch)
  train_losses.append(epoch_train_loss)
  train_accuracies.append(epoch_train_accuracy)
  train_lrs.append(epoch_lr)

  epoch_test_loss, epoch_test_accuracy = test(epoch)
  test_losses.append(epoch_test_loss)
  test_accuracies.append(epoch_test_accuracy)
  scheduler.step()
  print(f"Train Loss: {epoch_train_loss:.3f} | Train Accuracy: {epoch_train_accuracy:.3f}% | Test Loss: {epoch_test_loss:.3f} | Test Accuracy: {epoch_test_accuracy:.3f}%")
# Out:
# Epoch: 1
# Time taken : 24s260ms
# Saving..
# Train Loss: 1.515 | Train Accuracy: 44.168% | Test Loss: 1.190 | Test Accuracy: 57.170%
#
# Epoch: 2
# Time taken : 17s936ms
# Saving..
# Train Loss: 1.089 | Train Accuracy: 61.058% | Test Loss: 1.048 | Test Accuracy: 63.530%
#
# Epoch: 3
# Time taken : 18s24ms
# Saving..
# Train Loss: 0.910 | Train Accuracy: 68.020% | Test Loss: 0.908 | Test Accuracy: 68.080%
#
# Epoch: 4
# Time taken : 17s974ms
# Saving..
# Train Loss: 0.784 | Train Accuracy: 72.568% | Test Loss: 0.809 | Test Accuracy: 72.020%
#
# Epoch: 5
# Time taken : 18s5ms
# Saving..
# Train Loss: 0.686 | Train Accuracy: 76.322% | Test Loss: 0.678 | Test Accuracy: 76.990%
#
# Epoch: 6
# Time taken : 18s8ms
# Saving..
# Train Loss: 0.632 | Train Accuracy: 78.198% | Test Loss: 0.665 | Test Accuracy: 77.930%
#
# Epoch: 7
# Time taken : 17s956ms
# Saving..
# Train Loss: 0.587 | Train Accuracy: 79.850% | Test Loss: 0.568 | Test Accuracy: 80.670%
#
# Epoch: 8
# Time taken : 17s919ms
# Train Loss: 0.563 | Train Accuracy: 80.756% | Test Loss: 0.611 | Test Accuracy: 79.420%
#
# Epoch: 9
# Time taken : 17s974ms
# Train Loss: 0.541 | Train Accuracy: 81.622% | Test Loss: 0.621 | Test Accuracy: 80.020%
#
# Epoch: 10
# Time taken : 17s855ms
# Train Loss: 0.527 | Train Accuracy: 81.598% | Test Loss: 0.691 | Test Accuracy: 77.610%
#
# Epoch: 11
# Time taken : 17s956ms
# Train Loss: 0.507 | Train Accuracy: 82.874% | Test Loss: 0.674 | Test Accuracy: 78.390%
#
# Epoch: 12
# Time taken : 18s79ms
# Train Loss: 0.488 | Train Accuracy: 83.224% | Test Loss: 0.717 | Test Accuracy: 76.060%
#
# Epoch: 13
# Time taken : 17s950ms
# Saving..
# Train Loss: 0.485 | Train Accuracy: 83.420% | Test Loss: 0.545 | Test Accuracy: 81.620%
#
# Epoch: 14
# Time taken : 18s47ms
# Saving..
# Train Loss: 0.463 | Train Accuracy: 84.334% | Test Loss: 0.451 | Test Accuracy: 85.090%
#
# Epoch: 15
# Time taken : 18s88ms
# Train Loss: 0.458 | Train Accuracy: 84.288% | Test Loss: 0.562 | Test Accuracy: 81.120%
#
# Epoch: 16
# Time taken : 18s50ms
# Train Loss: 0.442 | Train Accuracy: 84.830% | Test Loss: 0.550 | Test Accuracy: 81.160%
#
# Epoch: 17
# Time taken : 18s55ms
# Train Loss: 0.441 | Train Accuracy: 85.134% | Test Loss: 0.607 | Test Accuracy: 80.710%
#
# Epoch: 18
# Time taken : 18s88ms
# Train Loss: 0.426 | Train Accuracy: 85.274% | Test Loss: 0.600 | Test Accuracy: 80.280%
#
# Epoch: 19
# Time taken : 18s15ms
# Saving..
# Train Loss: 0.422 | Train Accuracy: 85.610% | Test Loss: 0.437 | Test Accuracy: 85.160%
#
# Epoch: 20
# Time taken : 17s961ms
# Train Loss: 0.419 | Train Accuracy: 85.688% | Test Loss: 0.606 | Test Accuracy: 79.970%
#
# Epoch: 21
# Time taken : 18s8ms
# Saving..
# Train Loss: 0.408 | Train Accuracy: 86.150% | Test Loss: 0.436 | Test Accuracy: 85.270%
#
# Epoch: 22
# Time taken : 17s981ms
# Train Loss: 0.409 | Train Accuracy: 86.060% | Test Loss: 0.458 | Test Accuracy: 84.720%
#
# Epoch: 23
# Time taken : 17s971ms
# Saving..
# Train Loss: 0.402 | Train Accuracy: 86.294% | Test Loss: 0.450 | Test Accuracy: 85.340%
#
# Epoch: 24
# Time taken : 17s968ms
# Train Loss: 0.393 | Train Accuracy: 86.474% | Test Loss: 0.561 | Test Accuracy: 82.030%
#
# Epoch: 25
# Time taken : 18s37ms
# Train Loss: 0.390 | Train Accuracy: 86.614% | Test Loss: 0.527 | Test Accuracy: 82.580%
#
# Epoch: 26
# Time taken : 18s63ms
# Train Loss: 0.384 | Train Accuracy: 86.922% | Test Loss: 0.463 | Test Accuracy: 84.680%
#
# Epoch: 27
# Time taken : 18s116ms
# Train Loss: 0.376 | Train Accuracy: 87.116% | Test Loss: 0.567 | Test Accuracy: 82.030%
#
# Epoch: 28
# Time taken : 18s26ms
# Saving..
# Train Loss: 0.377 | Train Accuracy: 87.146% | Test Loss: 0.427 | Test Accuracy: 85.800%
#
# Epoch: 29
# Time taken : 17s948ms
# Train Loss: 0.371 | Train Accuracy: 87.418% | Test Loss: 0.496 | Test Accuracy: 83.760%
#
# Epoch: 30
# Time taken : 18s40ms
# Train Loss: 0.364 | Train Accuracy: 87.502% | Test Loss: 0.560 | Test Accuracy: 82.360%
#
# Epoch: 31
# Time taken : 18s60ms
# Train Loss: 0.356 | Train Accuracy: 87.896% | Test Loss: 0.541 | Test Accuracy: 83.640%
#
# Epoch: 32
# Time taken : 17s965ms
# Train Loss: 0.359 | Train Accuracy: 87.664% | Test Loss: 0.535 | Test Accuracy: 83.460%
#
# Epoch: 33
# Time taken : 18s27ms
# Saving..
# Train Loss: 0.350 | Train Accuracy: 88.118% | Test Loss: 0.401 | Test Accuracy: 86.610%
#
# Epoch: 34
# Time taken : 17s988ms
# Train Loss: 0.344 | Train Accuracy: 88.200% | Test Loss: 0.514 | Test Accuracy: 83.410%
#
# Epoch: 35
# Time taken : 18s72ms
# Train Loss: 0.345 | Train Accuracy: 88.256% | Test Loss: 0.438 | Test Accuracy: 85.450%
#
# Epoch: 36
# Time taken : 18s57ms
# Train Loss: 0.340 | Train Accuracy: 88.354% | Test Loss: 0.444 | Test Accuracy: 85.860%
#
# Epoch: 37
# Time taken : 18s108ms
# Train Loss: 0.332 | Train Accuracy: 88.704% | Test Loss: 0.505 | Test Accuracy: 84.220%
#
# Epoch: 38
# Time taken : 18s23ms
# Train Loss: 0.327 | Train Accuracy: 88.850% | Test Loss: 0.439 | Test Accuracy: 85.310%
#
# Epoch: 39
# Time taken : 18s5ms
# Train Loss: 0.319 | Train Accuracy: 89.032% | Test Loss: 0.767 | Test Accuracy: 78.650%
#
# Epoch: 40
# Time taken : 17s976ms
# Saving..
# Train Loss: 0.326 | Train Accuracy: 89.026% | Test Loss: 0.411 | Test Accuracy: 86.730%
#
# Epoch: 41
# Time taken : 18s61ms
# Saving..
# Train Loss: 0.321 | Train Accuracy: 89.052% | Test Loss: 0.376 | Test Accuracy: 87.950%
#
# Epoch: 42
# Time taken : 18s63ms
# Train Loss: 0.312 | Train Accuracy: 89.372% | Test Loss: 0.402 | Test Accuracy: 86.730%
#
# Epoch: 43
# Time taken : 17s954ms
# Train Loss: 0.304 | Train Accuracy: 89.568% | Test Loss: 0.449 | Test Accuracy: 85.700%
#
# Epoch: 44
# Time taken : 18s59ms
# Saving..
# Train Loss: 0.300 | Train Accuracy: 89.790% | Test Loss: 0.366 | Test Accuracy: 88.460%
#
# Epoch: 45
# Time taken : 18s82ms
# Train Loss: 0.294 | Train Accuracy: 89.944% | Test Loss: 0.429 | Test Accuracy: 86.680%
#
# Epoch: 46
# Time taken : 18s44ms
# Train Loss: 0.295 | Train Accuracy: 89.900% | Test Loss: 0.499 | Test Accuracy: 84.950%
#
# Epoch: 47
# Time taken : 18s89ms
# Train Loss: 0.289 | Train Accuracy: 90.114% | Test Loss: 0.444 | Test Accuracy: 86.230%
#
# Epoch: 48
# Time taken : 18s
# Train Loss: 0.287 | Train Accuracy: 90.208% | Test Loss: 0.365 | Test Accuracy: 88.120%
#
# Epoch: 49
# Time taken : 18s29ms
# Train Loss: 0.282 | Train Accuracy: 90.406% | Test Loss: 0.504 | Test Accuracy: 85.100%
#
# Epoch: 50
# Time taken : 18s2ms
# Train Loss: 0.272 | Train Accuracy: 90.680% | Test Loss: 0.444 | Test Accuracy: 86.270%
#
# Epoch: 51
# Time taken : 18s8ms
# Saving..
# Train Loss: 0.274 | Train Accuracy: 90.846% | Test Loss: 0.359 | Test Accuracy: 88.830%
#
# Epoch: 52
# Time taken : 18s59ms
# Train Loss: 0.262 | Train Accuracy: 91.124% | Test Loss: 0.380 | Test Accuracy: 88.270%
#
# Epoch: 53
# Time taken : 17s995ms
# Train Loss: 0.259 | Train Accuracy: 91.196% | Test Loss: 0.384 | Test Accuracy: 88.100%
#
# Epoch: 54
# Time taken : 18s49ms
# Train Loss: 0.256 | Train Accuracy: 91.260% | Test Loss: 0.371 | Test Accuracy: 88.160%
#
# Epoch: 55
# Time taken : 18s34ms
# Saving..
# Train Loss: 0.244 | Train Accuracy: 91.550% | Test Loss: 0.316 | Test Accuracy: 89.920%
#
# Epoch: 56
# Time taken : 17s933ms
# Train Loss: 0.245 | Train Accuracy: 91.576% | Test Loss: 0.369 | Test Accuracy: 87.860%
#
# Epoch: 57
# Time taken : 18s12ms
# Train Loss: 0.235 | Train Accuracy: 91.998% | Test Loss: 0.433 | Test Accuracy: 86.810%
#
# Epoch: 58
# Time taken : 18s2ms
# Train Loss: 0.234 | Train Accuracy: 91.972% | Test Loss: 0.403 | Test Accuracy: 87.840%
#
# Epoch: 59
# Time taken : 17s937ms
# Train Loss: 0.226 | Train Accuracy: 92.272% | Test Loss: 0.307 | Test Accuracy: 89.760%
#
# Epoch: 60
# Time taken : 17s955ms
# Saving..
# Train Loss: 0.216 | Train Accuracy: 92.596% | Test Loss: 0.299 | Test Accuracy: 90.790%
#
# Epoch: 61
# Time taken : 18s9ms
# Train Loss: 0.212 | Train Accuracy: 92.724% | Test Loss: 0.291 | Test Accuracy: 90.600%
#
# Epoch: 62
# Time taken : 18s38ms
# Train Loss: 0.207 | Train Accuracy: 93.016% | Test Loss: 0.353 | Test Accuracy: 89.130%
#
# Epoch: 63
# Time taken : 17s885ms
# Train Loss: 0.201 | Train Accuracy: 93.146% | Test Loss: 0.368 | Test Accuracy: 88.640%
#
# Epoch: 64
# Time taken : 18s10ms
# Saving..
# Train Loss: 0.194 | Train Accuracy: 93.214% | Test Loss: 0.302 | Test Accuracy: 90.840%
#
# Epoch: 65
# Time taken : 17s971ms
# Train Loss: 0.185 | Train Accuracy: 93.660% | Test Loss: 0.308 | Test Accuracy: 90.560%
#
# Epoch: 66
# Time taken : 18s61ms
# Train Loss: 0.176 | Train Accuracy: 93.960% | Test Loss: 0.400 | Test Accuracy: 88.050%
#
# Epoch: 67
# Time taken : 18s71ms
# Train Loss: 0.179 | Train Accuracy: 93.804% | Test Loss: 0.381 | Test Accuracy: 89.020%
#
# Epoch: 68
# Time taken : 17s991ms
# Train Loss: 0.168 | Train Accuracy: 94.260% | Test Loss: 0.362 | Test Accuracy: 89.620%
#
# Epoch: 69
# Time taken : 17s997ms
# Saving..
# Train Loss: 0.159 | Train Accuracy: 94.416% | Test Loss: 0.268 | Test Accuracy: 91.960%
#
# Epoch: 70
# Time taken : 18s42ms
# Train Loss: 0.158 | Train Accuracy: 94.482% | Test Loss: 0.309 | Test Accuracy: 90.640%
#
# Epoch: 71
# Time taken : 18s29ms
# Train Loss: 0.153 | Train Accuracy: 94.640% | Test Loss: 0.298 | Test Accuracy: 90.830%
#
# Epoch: 72
# Time taken : 17s981ms
# Saving..
# Train Loss: 0.143 | Train Accuracy: 95.018% | Test Loss: 0.267 | Test Accuracy: 92.180%
#
# Epoch: 73
# Time taken : 18s28ms
# Train Loss: 0.132 | Train Accuracy: 95.428% | Test Loss: 0.327 | Test Accuracy: 90.860%
#
# Epoch: 74
# Time taken : 18s21ms
# Train Loss: 0.126 | Train Accuracy: 95.582% | Test Loss: 0.291 | Test Accuracy: 91.240%
#
# Epoch: 75
# Time taken : 18s72ms
# Saving..
# Train Loss: 0.119 | Train Accuracy: 95.850% | Test Loss: 0.263 | Test Accuracy: 92.480%
#
# Epoch: 76
# Time taken : 17s988ms
# Saving..
# Train Loss: 0.110 | Train Accuracy: 96.220% | Test Loss: 0.259 | Test Accuracy: 92.710%
#
# Epoch: 77
# Time taken : 18s16ms
# Train Loss: 0.110 | Train Accuracy: 96.132% | Test Loss: 0.296 | Test Accuracy: 91.550%
#
# Epoch: 78
# Time taken : 17s924ms
# Train Loss: 0.099 | Train Accuracy: 96.566% | Test Loss: 0.273 | Test Accuracy: 92.210%
#
# Epoch: 79
# Time taken : 18s17ms
# Train Loss: 0.095 | Train Accuracy: 96.656% | Test Loss: 0.258 | Test Accuracy: 92.710%
#
# Epoch: 80
# Time taken : 18s54ms
# Saving..
# Train Loss: 0.089 | Train Accuracy: 96.948% | Test Loss: 0.244 | Test Accuracy: 93.070%
#
# Epoch: 81
# Time taken : 17s898ms
# Train Loss: 0.080 | Train Accuracy: 97.200% | Test Loss: 0.273 | Test Accuracy: 92.400%
#
# Epoch: 82
# Time taken : 17s906ms
# Saving..
# Train Loss: 0.072 | Train Accuracy: 97.520% | Test Loss: 0.251 | Test Accuracy: 93.100%
#
# Epoch: 83
# Time taken : 18s25ms
# Train Loss: 0.068 | Train Accuracy: 97.638% | Test Loss: 0.250 | Test Accuracy: 92.970%
#
# Epoch: 84
# Time taken : 18s86ms
# Train Loss: 0.063 | Train Accuracy: 97.886% | Test Loss: 0.253 | Test Accuracy: 93.010%
#
# Epoch: 85
# Time taken : 18s1ms
# Saving..
# Train Loss: 0.054 | Train Accuracy: 98.140% | Test Loss: 0.240 | Test Accuracy: 93.640%
#
# Epoch: 86
# Time taken : 17s981ms
# Train Loss: 0.049 | Train Accuracy: 98.338% | Test Loss: 0.242 | Test Accuracy: 93.620%
#
# Epoch: 87
# Time taken : 18s43ms
# Saving..
# Train Loss: 0.044 | Train Accuracy: 98.458% | Test Loss: 0.231 | Test Accuracy: 93.990%
#
# Epoch: 88
# Time taken : 17s752ms
# Train Loss: 0.037 | Train Accuracy: 98.718% | Test Loss: 0.234 | Test Accuracy: 93.820%
#
# Epoch: 89
# Time taken : 17s999ms
# Saving..
# Train Loss: 0.035 | Train Accuracy: 98.804% | Test Loss: 0.240 | Test Accuracy: 94.080%
#
# Epoch: 90
# Time taken : 17s890ms
# Saving..
# Train Loss: 0.031 | Train Accuracy: 98.914% | Test Loss: 0.224 | Test Accuracy: 94.300%
#
# Epoch: 91
# Time taken : 17s963ms
# Saving..
# Train Loss: 0.028 | Train Accuracy: 99.096% | Test Loss: 0.233 | Test Accuracy: 94.410%
#
# Epoch: 92
# Time taken : 17s829ms
# Train Loss: 0.025 | Train Accuracy: 99.206% | Test Loss: 0.242 | Test Accuracy: 94.210%
#
# Epoch: 93
# Time taken : 17s942ms
# Saving..
# Train Loss: 0.021 | Train Accuracy: 99.320% | Test Loss: 0.234 | Test Accuracy: 94.530%
#
# Epoch: 94
# Time taken : 17s867ms
# Train Loss: 0.020 | Train Accuracy: 99.400% | Test Loss: 0.235 | Test Accuracy: 94.500%
#
# Epoch: 95
# Time taken : 18s232ms
# Train Loss: 0.018 | Train Accuracy: 99.446% | Test Loss: 0.235 | Test Accuracy: 94.320%
#
# Epoch: 96
# Time taken : 17s896ms
# Saving..
# Train Loss: 0.016 | Train Accuracy: 99.508% | Test Loss: 0.233 | Test Accuracy: 94.590%
#
# Epoch: 97
# Time taken : 17s914ms
# Saving..
# Train Loss: 0.015 | Train Accuracy: 99.500% | Test Loss: 0.215 | Test Accuracy: 94.790%
#
# Epoch: 98
# Time taken : 18s105ms
# Train Loss: 0.013 | Train Accuracy: 99.604% | Test Loss: 0.238 | Test Accuracy: 94.640%
#
# Epoch: 99
# Time taken : 18s99ms
# Train Loss: 0.013 | Train Accuracy: 99.610% | Test Loss: 0.225 | Test Accuracy: 94.740%
#
# Epoch: 100
# Time taken : 17s938ms
# Train Loss: 0.014 | Train Accuracy: 99.592% | Test Loss: 0.233 | Test Accuracy: 94.720%

# %%
print('Best Accuracy : ', best_acc)
# Out:
# Best Accuracy :  94.79

# %%
def plot_accuracies(train_accuracies, test_accuracies):
  plt.plot(train_accuracies, label='Train Accuracy')
  plt.plot(test_accuracies, label='Test Accuracy')
  plt.xlabel('Epochs')
  plt.ylabel('Accuracy')
  plt.legend()
  plt.grid(True)
  plt.title('Accuracy vs. No. of epochs')

# %%
def plot_losses(train_losses, test_losses):
  plt.plot(train_losses, label='Train Losses')
  plt.plot(test_losses, label='Test Losses')
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.legend()
  plt.grid(True)
  plt.title('Loss vs. No. of epochs')

# %%
def plot_lrs(train_lrs):
  plt.plot(train_lrs)
  plt.xlabel('Epochs')
  plt.ylabel('Learning rate')
  plt.grid(True)
  plt.title('Learning Rate vs. Epochs')

# %%
plot_accuracies(train_accuracies, test_accuracies)

# %%
plot_losses(train_losses, test_losses)

# %%
plot_lrs(train_lrs)

# %%
print('Saving final model..')
state = {
    'net': model.state_dict(),
    'acc': test_accuracies[-1],
    'epoch': number_of_epochs,
    'best_acc' : best_acc,
    'train_acc' : train_accuracies,
    'test_acc' : test_accuracies,
    'train_loss' : train_losses,
    'test_loss' : test_losses,
    'lr' : train_lrs
}
if not os.path.isdir('checkpoint'):
  os.mkdir('checkpoint')
torch.save(state, './checkpoint/ResNet_18_dropout_minLR_final.pth')
# Out:
# Saving final model..

# %%
import numpy as np
import pickle
from tqdm import tqdm
import pandas as pd

# Function to load CIFAR batch
def load_cifar_batch(file):
    with open(file, 'rb') as fo:
        batch = pickle.load(fo, encoding='bytes')
    return batch

# Specify the folder where the CIFAR-10 batch files are
cifar10_dir = 'data/cifar-10-batches-py/'

# Load the label names
meta_data_dict = load_cifar_batch(os.path.join(cifar10_dir, 'batches.meta'))
label_names = meta_data_dict[b'label_names']

# Load test data
test_batch = load_cifar_batch('CIFAR-10/cifar_test_nolabels.pkl')
test_images = test_batch[b'data'].reshape(-1, 3, 32, 32).transpose(0, 2, 3, 1)

data_statistics = (
    (0.49139968, 0.48215827, 0.44653124),
     (0.24703233, 0.24348505, 0.26158768)
)

# Define transformation for data augmentation
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(*data_statistics, inplace=True)
])

# Apply data augmentation
augmented_test_images = torch.stack([transform(image) for image in test_images])

# Load the trained model
model = ResNet18()

checkpoint = torch.load('./checkpoint/ResNet_18_dropout_minLR_best.pth')

# Check the keys in the checkpoint dictionary
print(checkpoint.keys())

# Assuming the model state dictionary is saved under a different key
# Adjust this according to the actual key in your checkpoint file
model.load_state_dict(checkpoint['net'])

model =  model.to(device)

# Evaluate the model on test data
model.eval()
with torch.no_grad():
    outputs = model(augmented_test_images.to(device))
_, predicted = torch.max(outputs, 1)

predicted = predicted.to('cpu')

# Display the first 10 test images and predicted labels
plt.figure(figsize=(20, 4))
for i in range(10):
    plt.subplot(1, 10, i+1)
    plt.imshow(test_images[i])
    plt.title(label_names[predicted[i].item()].decode('utf-8'))
    plt.axis('off')
plt.show()

# Save the output in output.csv containing ID, Labels
output_data = {'ID': np.arange(len(predicted)), 'Labels': predicted.numpy()}
output_df = pd.DataFrame(output_data)
output_df.to_csv('output_resnet18_dp_minLR.csv', index=False)
# Out:
# dict_keys(['net', 'acc', 'epoch'])
